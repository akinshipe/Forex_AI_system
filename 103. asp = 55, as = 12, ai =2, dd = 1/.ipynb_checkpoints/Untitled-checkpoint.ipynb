# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime, timedelta

all_currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]



headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
raw_df = pd.read_csv("../raw_weekly_data/NZDCAD10080.csv", names = headers )

needed_weeks_df = raw_df.loc[(raw_df['date'] >= "2015.01.01")   ]   

needed_weeks_df = needed_weeks_df.reset_index(drop=True)

available_weeks = needed_weeks_df['date'].values



#print(raw_df)
print(available_weeks)
# Out:
# ['2015.01.04' '2015.01.11' '2015.01.18' '2015.01.25' '2015.02.01'
#  '2015.02.08' '2015.02.15' '2015.02.22' '2015.03.01' '2015.03.08'
#  '2015.03.15' '2015.03.22' '2015.03.29' '2015.04.05' '2015.04.12'
#  '2015.04.19' '2015.04.26' '2015.05.03' '2015.05.10' '2015.05.17'
#  '2015.05.24' '2015.05.31' '2015.06.07' '2015.06.14' '2015.06.21'
#  '2015.06.28' '2015.07.05' '2015.07.12' '2015.07.19' '2015.07.26'
#  '2015.08.02' '2015.08.09' '2015.08.16' '2015.08.23' '2015.08.30'
#  '2015.09.06' '2015.09.13' '2015.09.20' '2015.09.27' '2015.10.04'
#  '2015.10.11' '2015.10.18' '2015.10.25' '2015.11.01' '2015.11.08'
#  '2015.11.15' '2015.11.22' '2015.11.29' '2015.12.06' '2015.12.13'
#  '2015.12.20' '2015.12.27' '2016.01.03' '2016.01.10' '2016.01.17'
#  '2016.01.24' '2016.01.31' '2016.02.07' '2016.02.14' '2016.02.21'
#  '2016.02.28' '2016.03.06' '2016.03.13' '2016.03.20' '2016.03.27'
#  '2016.04.03' '2016.04.10' '2016.04.17' '2016.04.24' '2016.05.01'
#  '2016.05.08' '2016.05.15' '2016.05.22' '2016.05.29' '2016.06.05'
#  '2016.06.12' '2016.06.19' '2016.06.26' '2016.07.03' '2016.07.10'
#  '2016.07.17' '2016.07.24' '2016.07.31' '2016.08.07' '2016.08.14'
#  '2016.08.21' '2016.08.28' '2016.09.04' '2016.09.11' '2016.09.18'
#  '2016.09.25' '2016.10.02' '2016.10.09' '2016.10.16' '2016.10.23'
#  '2016.10.30' '2016.11.06' '2016.11.13' '2016.11.20' '2016.11.27'
#  '2016.12.04' '2016.12.11' '2016.12.18' '2016.12.25' '2017.01.01'
#  '2017.01.08' '2017.01.15' '2017.01.22' '2017.01.29' '2017.02.05'
#  '2017.02.12' '2017.02.19' '2017.02.26' '2017.03.05' '2017.03.19'
#  '2020.09.06' '2020.09.13' '2020.09.20' '2020.09.27' '2020.10.04'
#  '2020.10.11' '2020.10.18' '2020.10.25' '2020.11.01' '2020.11.08'
#  '2020.11.15' '2020.11.22' '2020.11.29' '2020.12.06' '2020.12.13'
#  '2020.12.20' '2020.12.27' '2021.01.03' '2021.01.10' '2021.01.17'
#  '2021.01.24' '2021.01.31' '2021.02.07' '2021.02.14' '2021.02.21'
#  '2021.02.28' '2021.03.07' '2021.03.14' '2021.03.21' '2021.03.28'
#  '2021.04.04' '2021.04.11' '2021.04.18' '2021.04.25' '2021.05.02'
#  '2021.05.09' '2021.05.16' '2021.05.23' '2021.05.30' '2021.06.06'
#  '2021.06.13' '2021.06.20' '2021.06.27' '2021.07.04' '2021.07.11'
#  '2021.07.18' '2021.07.25' '2021.08.01' '2021.08.08' '2021.08.15'
#  '2021.08.22' '2021.08.29' '2021.09.05' '2021.09.12' '2021.09.19'
#  '2021.09.26' '2021.10.03' '2021.10.10' '2021.10.17' '2021.10.24'
#  '2021.10.31' '2021.11.07' '2021.11.14' '2021.11.21' '2021.11.28']

# %%
for y in available_weeks:
    
    current_date = datetime.strptime(y, '%Y.%m.%d').strftime('%A')
    
    if current_date != 'Sunday':
        available_weeks = [x for x in available_weeks if x != y]
        print(y)

# %%
for a in available_weeks:
  
  
    path = "./files/" + a

    try: 
        os.makedirs(path)
        control_file = pd.DataFrame()
        
        for  b in range(8):
            control_file['control' + str(b)] = -1
            
            
        control_file.to_csv(path + '/control.csv')
        
        

    except OSError as error: 
         print(error)

# %%
all_currency_pair_df = []

for d in all_currency_pairs:
    
    current_currency_df = pd.read_csv("../raw_weekly_data/" + d + ".csv", names = headers ) 
    
    current_currency_df = current_currency_df.iloc[::-1]
    current_currency_df = current_currency_df.reset_index(drop=True)
      
    current_currency_df = {'name': d.replace('10080',''),'dataframe': current_currency_df }
    
    all_currency_pair_df.append(current_currency_df)
    

print(all_currency_pair_df)
# Out:
# [{'name': 'USDCHF', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  0.91625  0.92690  0.91625  0.92396   37199
# 1     2021.11.28  00:00  0.92287  0.92729  0.91574  0.91767  170181
# 2     2021.11.21  00:00  0.92768  0.93736  0.92151  0.92393  154242
# 3     2021.11.14  00:00  0.91932  0.93297  0.91869  0.92866  153577
# 4     2021.11.07  00:00  0.91268  0.92377  0.91016  0.92097  150396
# ...          ...    ...      ...      ...      ...      ...     ...
# 2597  1971.01.31  00:00  4.29680  4.29690  4.29650  4.29690       5
# 2598  1971.01.24  00:00  4.30050  4.30050  4.29630  4.29630       5
# 2599  1971.01.17  00:00  4.30290  4.30290  4.29960  4.29960       5
# 2600  1971.01.10  00:00  4.31020  4.31020  4.30760  4.30760       5
# 2601  1971.01.03  00:00  4.31800  4.31800  4.31030  4.31090       5
#
# [2602 rows x 7 columns]}, {'name': 'GBPUSD', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021
# 1447  1993.05.02  00:00  1.30420  1.30420  1.29080  1.29490       5
# 1448  1993.04.25  00:00  1.31890  1.31890  1.30470  1.30470       5
# 1449  1993.04.18  00:00  1.32660  1.32660  1.31320  1.31320       5
# 1450  1993.04.11  00:00  1.31770  1.33640  1.31770  1.33140       5
# 1451  1993.04.04  00:00  1.31610  1.32550  1.31610  1.31740       5
#
# [1452 rows x 7 columns]}]

# %%
acceptable_signal_percent = 70

analysis_span = 52

analysis_interval = 3

no_of_weeks_analysis = [c for c in range(0, analysis_span, analysis_interval)]

all_time_next_week_trade =[]

for e in available_weeks:
    
    next_week_trade = []

    for f in all_currency_pair_df:
        
        
        current_currency_df = f['dataframe'].copy(deep = True)

        current_currency_df = current_currency_df.loc[(current_currency_df['date'] <= e )   ] 
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True)
        
        

        current_currency_df = current_currency_df.head(52)
        
        #print(f['name'], current_currency_df)

        needed_value_list = []
        
        needed_direction_list = []
        
        for g in no_of_weeks_analysis:
            
            needed_value = current_currency_df.copy()['close'][g]
            
            needed_value_list.append(needed_value)
            
            
        
        #print(f['name'], needed_value_list)
       
        
        for index, h in enumerate(needed_value_list):
            
            if index == 0:
                
                continue
                
            if h - needed_value_list[index-1] > 0 :
                
                needed_direction_list.append('S')
            
            else:
                
                needed_direction_list.append('B')
                
                
        #print(f['name'],needed_direction_list)  
        
        if (100 * needed_direction_list.count('S') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'S'})
        
        if ( 100 * needed_direction_list.count('B') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'B'})
    
    
    
    if len(next_week_trade) > 0:
        
        all_time_next_week_trade.append( {'week': e, 'next_week_trades': next_week_trade} )
    
    
    
    
    #print('--------------------------------------------------------------------------------------------', e )
    #print(next_week_trade)
    #print(len(next_week_trade))
    
    
    
if len(all_time_next_week_trade) == 0:
             
    raise Exception("no week passed the acceptable_signal_percent ")
        
        
    
print(len(all_time_next_week_trade))
# Out:
# 316

# %%
# creating a dataframe for nextweek trades and saving it in csv

for i in all_time_next_week_trade:
    
    current_week_data = i['next_week_trades']
    current_week_name = i['week']
    
    currency_name =[]
    trade_direction = []
    
    for j in current_week_data:
        
        currency_name.append(j['name'])
        trade_direction.append(j['direction'])
        
        
    
    
    
    
    next_week_trades_dataframe = pd.DataFrame()
    next_week_trades_dataframe['name']= currency_name
    next_week_trades_dataframe['direction'] = trade_direction
    
    
    print(next_week_trades_dataframe)

    next_week_trades_dataframe.to_csv("files/" + current_week_name + '/next_week_trades.csv')
# Out:
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  EURCHF         S
#      name direction
# 0  EURUSD         S
# 1  EURCHF         S
# 2  EURGBP         S
# 3  EURCAD         S
#      name direction
# 0  EURUSD         S
# 1  EURCHF         S
# 2  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  EURGBP         S
#      name direction
# 0  EURUSD         S
# 1  EURCHF         S
# 2  EURGBP         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
# 4  EURNZD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
# 4  EURJPY         S
# 5  EURCAD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDCAD         B
# 3  AUDUSD         S
# 4  NZDUSD         S
# 5  GBPCHF         B
# 6  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
# 4  EURNZD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  EURGBP         S
# 3  EURJPY         S
# 4  EURCAD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDCAD         B
# 3  AUDUSD         S
# 4  NZDUSD         S
# 5  GBPCHF         B
# 6  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  EURCHF         S
# 3  CADCHF         B
# 4  EURGBP         S
# 5  EURJPY         S
# 6  EURCAD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
# 4  EURNZD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  EURJPY         S
# 3  EURCAD         S
#      name direction
# 0  EURUSD         S
# 1  NZDUSD         S
# 2  EURGBP         S
#      name direction
# 0  EURUSD         S
# 1  USDJPY         B
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  USDCAD         B
# 4  EURCHF         S
# 5  EURJPY         S
# 6  EURCAD         S
#      name direction
# 0  EURUSD         S
# 1  NZDUSD         S
# 2  EURCHF         S
# 3  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  USDJPY         B
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  USDCAD         B
# 4  EURJPY         S
#      name direction
# 0  EURUSD         S
# 1  NZDUSD         S
# 2  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  NZDUSD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  USDCAD         B
# 4  AUDUSD         S
# 5  EURJPY         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  USDJPY         B
# 3  NZDUSD         S
# 4  AUDCHF         S
#      name direction
# 0  GBPUSD         S
# 1  EURUSD         S
# 2  USDJPY         B
# 3  NZDUSD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  USDCAD         B
# 4  AUDUSD         S
# 5  EURJPY         S
#      name direction
# 0  EURUSD         S
# 1  USDJPY         B
# 2  NZDUSD         S
# 3  EURGBP         S
#      name direction
# 0  GBPUSD         S
# 1  USDJPY         B
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  USDCAD         B
# 4  AUDUSD         S
# 5  GBPCAD         B
# 6  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  NZDUSD         S
# 2  AUDCHF         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDCAD         B
# 3  AUDUSD         S
# 4  GBPCAD         B
# 5  EURJPY         S
# 6  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  NZDUSD         S
# 2  AUDCHF         S
#      name direction
# 0  USDCAD         B
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
# 2  GBPCAD         B
# 3  NZDJPY         S
#      name direction
# 0  AUDCHF         S
# 1  NZDCAD         B
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
# 2  GBPCAD         B
#      name direction
# 0  AUDCHF         S
# 1  NZDCAD         B
#      name direction
# 0  GBPAUD         B
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
# 2  GBPCAD         B
# 3  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  AUDJPY         S
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
# 2  GBPCAD         B
# 3  EURJPY         S
# 4  NZDJPY         S
#      name direction
# 0  USDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  USDCAD         B
# 1  GBPCAD         B
# 2  NZDJPY         S
#      name direction
# 0  USDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
# 2  GBPCAD         B
# 3  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  EURCAD         B
#      name direction
# 0  USDCHF         B
# 1  USDCAD         B
#      name direction
# 0  USDCAD         B
# 1  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  NZDJPY         S
#      name direction
# 0  CADJPY         S
#      name direction
# 0  NZDJPY         S
#      name direction
# 0  EURGBP         B
# 1  GBPJPY         S
# 2  CADJPY         S
#      name direction
# 0  AUDJPY         S
#      name direction
# 0  CHFJPY         S
# 1  GBPJPY         S
# 2  EURJPY         S
# 3  CADJPY         S
#      name direction
# 0  EURCHF         B
# 1  AUDJPY         S
#      name direction
# 0  CHFJPY         S
# 1  GBPJPY         S
# 2  EURJPY         S
# 3  CADJPY         S
#      name direction
# 0  EURJPY         S
# 1  AUDJPY         S
# 2  AUDNZD         S
#      name direction
# 0  CHFJPY         S
# 1  GBPJPY         S
# 2  EURJPY         S
# 3  CADJPY         S
#      name direction
# 0  USDJPY         S
# 1  EURJPY         S
# 2  AUDJPY         S
#      name direction
# 0  CHFJPY         S
# 1  EURGBP         B
# 2  GBPJPY         S
# 3  EURJPY         S
# 4  CADJPY         S
# 5  AUDNZD         S
#      name direction
# 0  AUDUSD         B
# 1  EURGBP         B
#      name direction
# 0  GBPUSD         S
# 1  USDJPY         S
# 2  AUDJPY         S
#      name direction
# 0  GBPJPY         S
# 1  EURJPY         S
# 2  CADJPY         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         B
# 2  EURGBP         B
#      name direction
# 0  GBPUSD         S
# 1  USDJPY         S
# 2  GBPAUD         S
# 3  EURJPY         S
# 4  EURAUD         S
# 5  AUDJPY         S
#      name direction
# 0  AUDUSD         B
# 1  CHFJPY         S
# 2  GBPJPY         S
# 3  EURJPY         S
# 4  CADJPY         S
#      name direction
# 0  AUDUSD         B
# 1  NZDUSD         B
# 2  NZDCHF         B
# 3  EURGBP         B
#      name direction
# 0  GBPUSD         S
# 1  NZDUSD         B
# 2  GBPAUD         S
# 3  EURAUD         S
#      name direction
# 0  CADJPY         S
# 1  AUDNZD         S
#      name direction
# 0  GBPUSD         S
# 1  NZDUSD         B
# 2  NZDCHF         B
# 3  EURGBP         B
#      name direction
# 0  GBPUSD         S
# 1  GBPAUD         S
# 2  EURAUD         S
#      name direction
# 0  CHFJPY         S
# 1  EURJPY         S
# 2  CADJPY         S
#      name direction
# 0  GBPUSD         S
# 1  EURGBP         B
# 2  GBPJPY         S
#      name direction
# 0  GBPUSD         S
# 1  GBPAUD         S
# 2  EURAUD         S
#      name direction
# 0  GBPCHF         S
# 1  GBPJPY         S
# 2  EURJPY         S
# 3  CADJPY         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
# 4  GBPJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDJPY         S
# 2  GBPAUD         S
#      name direction
# 0  GBPCHF         S
# 1  GBPJPY         S
#      name direction
# 0  GBPUSD         S
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  GBPJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDJPY         S
#      name direction
# 0  GBPCAD         S
#      name direction
# 0  AUDUSD         B
# 1  NZDCHF         B
# 2  EURGBP         B
# 3  GBPCAD         S
#      name direction
# 0  GBPCAD         S
#      name direction
# 0  AUDUSD         B
# 1  NZDCHF         B
# 2  EURGBP         B
# 3  GBPCAD         S
#      name direction
# 0  GBPCAD         S
#      name direction
# 0  AUDUSD         B
# 1  GBPCHF         S
# 2  NZDCHF         B
# 3  EURGBP         B
# 4  GBPJPY         S
# 5  GBPCAD         S
#      name direction
# 0  AUDUSD         B
# 1  NZDCHF         B
# 2  GBPJPY         S
# 3  GBPCAD         S
# 4  EURAUD         S
# 5  EURNZD         S
#      name direction
# 0  NZDCHF         B
# 1  GBPJPY         S
#      name direction
# 0  GBPUSD         S
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  NZDCHF         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  AUDCAD         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  AUDCAD         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  EURCHF         S
# 1  EURCAD         B
#      name direction
# 0  AUDCAD         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  EURCHF         S
# 1  CHFJPY         B
#      name direction
# 0  AUDJPY         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  AUDJPY         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  CHFJPY         B
# 1  EURJPY         B
#      name direction
# 0  AUDJPY         B
#      name direction
# 0  GBPJPY         S
#      name direction
# 0  AUDUSD         B
# 1  EURCHF         S
# 2  CHFJPY         B
#      name direction
# 0  AUDJPY         B
# 1  NZDCAD         S
#      name direction
# 0  GBPJPY         S
# 1  GBPCAD         S
#      name direction
# 0  AUDUSD         B
# 1  CHFJPY         B
# 2  EURJPY         B
#      name direction
# 0  AUDJPY         B
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURUSD         B
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURUSD         B
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURUSD         B
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURUSD         B
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         B
# 1  EURJPY         B
# 2  EURAUD         B
#      name direction
# 0  EURUSD         B
#      name direction
# 0  EURUSD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURUSD         B
#      name direction
# 0  EURCHF         B
# 1  AUDNZD         S
#      name direction
# 0  EURUSD         B
# 1  EURCAD         B
# 2  EURAUD         B
#      name direction
# 0  EURUSD         B
# 1  EURCHF         B
# 2  EURNZD         B
#      name direction
# 0  EURCHF         B
# 1  EURJPY         B
# 2  EURAUD         B
# 3  AUDNZD         S
#      name direction
# 0  EURUSD         B
# 1  EURCHF         B
#      name direction
# 0  EURCHF         B
# 1  EURNZD         B
# 2  AUDCAD         S
#      name direction
# 0  EURCHF         B
# 1  EURJPY         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURNZD         B
# 1  AUDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURNZD         B
# 1  AUDCAD         S
# 2  AUDNZD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURNZD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  AUDUSD         S
# 1  NZDCHF         S
# 2  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURCAD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDCHF         S
# 3  AUDCAD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
#      name direction
# 0  AUDUSD         S
# 1  EURCHF         B
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDCHF         S
# 3  AUDCAD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  AUDUSD         S
# 3  EURCAD         B
#      name direction
# 0  AUDUSD         S
# 1  NZDUSD         S
# 2  CADJPY         S
# 3  NZDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDUSD         S
# 3  NZDCHF         S
# 4  EURNZD         B
# 5  AUDJPY         S
# 6  NZDJPY         S
# 7  AUDCAD         S
#      name direction
# 0  EURCAD         B
#      name direction
# 0  AUDUSD         S
#      name direction
# 0  AUDUSD         S
# 1  NZDUSD         S
# 2  NZDCHF         S
# 3  EURNZD         B
# 4  NZDJPY         S
# 5  AUDCAD         S
#      name direction
# 0  AUDUSD         S
#      name direction
# 0  AUDUSD         S
# 1  NZDJPY         S
#      name direction
# 0  GBPUSD         S
#      name direction
# 0  EURUSD         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDJPY         S
#      name direction
# 0  EURUSD         S
# 1  GBPCHF         S
#      name direction
# 0  USDCAD         B
# 1  CADJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  NZDCHF         S
# 5  EURNZD         B
# 6  AUDJPY         S
# 7  NZDJPY         S
#      name direction
# 0  EURUSD         S
# 1  GBPCHF         S
#      name direction
# 0  USDCAD         B
# 1  EURJPY         S
# 2  NZDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  NZDJPY         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  GBPCHF         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  GBPCHF         S
#      name direction
# 0  AUDCAD         S
# 1  NZDCAD         S
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
# 2  NZDUSD         S
#      name direction
# 0  USDCHF         B
# 1  EURUSD         S
# 2  USDJPY         B
# 3  GBPCHF         S
#      name direction
# 0  EURUSD         S
# 1  EURNZD         S
# 2  NZDCAD         S
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
#      name direction
# 0  EURUSD         S
# 1  GBPCHF         S
#      name direction
# 0  EURUSD         S
# 1  USDCAD         B
# 2  NZDCAD         S
#      name direction
# 0  USDCAD         B
#      name direction
# 0  GBPCHF         S
#      name direction
# 0  EURUSD         S
# 1  USDCAD         B
# 2  NZDCAD         S
#      name direction
# 0  USDCAD         B
# 1  AUDNZD         S
#      name direction
# 0  GBPCHF         S
#      name direction
# 0  USDCAD         B
# 1  NZDCAD         S
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
# 2  NZDUSD         S
# 3  AUDNZD         S
#      name direction
# 0  GBPCHF         S
#      name direction
# 0  EURJPY         S
# 1  NZDCAD         S
#      name direction
# 0  AUDUSD         S
# 1  NZDUSD         S
#      name direction
# 0  GBPCHF         S
#      name direction
# 0  EURJPY         S
# 1  NZDCAD         S
#      name direction
# 0  USDJPY         S
# 1  AUDNZD         S
#      name direction
# 0  GBPCHF         S
# 1  EURCHF         S
#      name direction
# 0  EURJPY         S
# 1  AUDNZD         S
#      name direction
# 0  USDCAD         B
# 1  AUDNZD         S
#      name direction
# 0  GBPCHF         S
# 1  EURCHF         S
#      name direction
# 0  EURJPY         S
# 1  AUDNZD         S
#      name direction
# 0  USDCAD         B
#      name direction
# 0  GBPCHF         S
# 1  EURCHF         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURUSD         S
# 1  USDCAD         B
# 2  EURCHF         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  USDCAD         B
# 1  EURJPY         S
#      name direction
# 0  EURUSD         S
# 1  USDCAD         B
# 2  GBPCHF         S
# 3  EURCHF         S
# 4  GBPJPY         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURCHF         S
# 1  AUDCAD         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURCHF         S
# 1  AUDCAD         S
#      name direction
# 0  AUDCAD         S
#      name direction
# 0  EURCAD         S
#      name direction
# 0  EURCAD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURCHF         S
# 1  EURCAD         S
#      name direction
# 0  EURCHF         S
# 1  CADCHF         S
# 2  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  EURCAD         S
#      name direction
# 0  EURCHF         S
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  CADCHF         S
# 2  EURJPY         S
# 3  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  EURCAD         S
#      name direction
# 0  EURCHF         S
# 1  AUDCAD         S
# 2  NZDCAD         S
#      name direction
# 0  USDCAD         B
# 1  EURCHF         S
# 2  CADCHF         S
# 3  EURJPY         S
# 4  EURNZD         B
# 5  AUDCAD         S
# 6  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  GBPAUD         B
#      name direction
# 0  AUDUSD         S
# 1  EURCHF         S
# 2  EURAUD         B
# 3  AUDCAD         S
# 4  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  CADCHF         S
# 2  EURJPY         S
# 3  AUDCAD         S
# 4  NZDCAD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURCHF         S
# 1  AUDCAD         S
# 2  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  CADCHF         S
# 2  EURJPY         S
#      name direction
# 0  EURCHF         S
# 1  EURCAD         S
#      name direction
# 0  EURCHF         S
# 1  NZDCAD         S
#      name direction
# 0  EURCHF         S
# 1  EURJPY         S
#      name direction
# 0  EURCAD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURCAD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURJPY         S
#      name direction
# 0  CHFJPY         B
# 1  GBPCAD         B
# 2  GBPAUD         B
#      name direction
# 0  EURGBP         S
# 1  GBPJPY         B
#      name direction
# 0  AUDUSD         B
# 1  CHFJPY         B
#      name direction
# 0  USDCHF         S
# 1  EURGBP         S
# 2  GBPJPY         B
#      name direction
# 0  EURJPY         S
#      name direction
# 0  AUDUSD         B
# 1  CHFJPY         B
#      name direction
# 0  USDCHF         S
#      name direction
# 0  CADCHF         S
# 1  EURJPY         S
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  USDCHF         S
#      name direction
# 0  CADCHF         S
# 1  EURJPY         S
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  USDCHF         S
# 1  CADCHF         S
# 2  EURGBP         S
#      name direction
# 0  AUDUSD         B
# 1  CADCHF         S
# 2  EURJPY         S
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  USDCHF         S
# 1  USDJPY         S
# 2  EURGBP         S
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
# 2  CADCHF         S
#      name direction
# 0  CHFJPY         B
#      name direction
# 0  USDCHF         S
# 1  EURGBP         S
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
# 2  CADCHF         S
#      name direction
# 0  USDCHF         S
# 1  USDJPY         S
# 2  EURGBP         S
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
# 2  AUDJPY         B
#      name direction
# 0  AUDUSD         B
# 1  AUDJPY         B
#      name direction
# 0  USDCHF         S
# 1  EURGBP         S
# 2  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  AUDJPY         B
#      name direction
# 0  AUDUSD         B
# 1  NZDUSD         B
# 2  CHFJPY         B
# 3  NZDCHF         B
# 4  AUDJPY         B
#      name direction
# 0  USDCHF         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  AUDJPY         B
# 4  AUDCAD         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  GBPAUD         S
# 5  CADJPY         B
# 6  AUDJPY         B
# 7  NZDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDUSD         B
# 3  CHFJPY         B
# 4  AUDCHF         B
# 5  NZDCHF         B
# 6  EURNZD         S
# 7  AUDJPY         B
# 8  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  EURNZD         S
# 4  AUDJPY         B
# 5  AUDCAD         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  AUDCHF         B
# 5  GBPJPY         B
# 6  GBPAUD         S
# 7  CADJPY         B
# 8  AUDJPY         B
# 9  NZDJPY         B
#       name direction
# 0   GBPUSD         B
# 1   USDCAD         S
# 2   AUDUSD         B
# 3   NZDUSD         B
# 4   CADCHF         B
# 5   AUDCHF         B
# 6   NZDCHF         B
# 7   GBPJPY         B
# 8   EURCAD         S
# 9   EURNZD         S
# 10  CADJPY         B
# 11  AUDJPY         B
# 12  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  AUDCHF         B
# 3  EURGBP         S
# 4  EURJPY         B
# 5  EURAUD         S
# 6  EURNZD         S
# 7  AUDJPY         B
# 8  AUDCAD         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  GBPJPY         B
# 4  CADJPY         B
# 5  AUDJPY         B
# 6  NZDJPY         B
#       name direction
# 0   USDCAD         S
# 1   AUDUSD         B
# 2   NZDUSD         B
# 3   CHFJPY         B
# 4   AUDCHF         B
# 5   NZDCHF         B
# 6   GBPJPY         B
# 7   EURJPY         B
# 8   EURNZD         S
# 9   CADJPY         B
# 10  AUDJPY         B
# 11  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  EURJPY         B
# 4  EURNZD         S
# 5  AUDJPY         B
# 6  AUDCAD         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  CHFJPY         B
# 5  GBPJPY         B
# 6  CADJPY         B
# 7  AUDJPY         B
# 8  NZDJPY         B
#       name direction
# 0   GBPUSD         B
# 1   USDCAD         S
# 2   AUDUSD         B
# 3   NZDUSD         B
# 4   CHFJPY         B
# 5   NZDCHF         B
# 6   GBPJPY         B
# 7   EURJPY         B
# 8   EURNZD         S
# 9   CADJPY         B
# 10  AUDJPY         B
# 11  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  EURJPY         B
# 5  EURNZD         S
# 6  CADJPY         B
# 7  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  CHFJPY         B
# 5  GBPJPY         B
# 6  EURJPY         B
# 7  CADJPY         B
# 8  AUDJPY         B
# 9  NZDJPY         B
#       name direction
# 0   GBPUSD         B
# 1   USDCAD         S
# 2   AUDUSD         B
# 3   NZDUSD         B
# 4   CHFJPY         B
# 5   NZDCHF         B
# 6   GBPJPY         B
# 7   EURJPY         B
# 8   EURCAD         S
# 9   EURNZD         S
# 10  CADJPY         B
# 11  AUDJPY         B
# 12  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  EURJPY         B
# 5  EURNZD         S
# 6  CADJPY         B
# 7  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  CHFJPY         B
# 4  EURGBP         S
# 5  GBPJPY         B
# 6  EURJPY         B
# 7  CADJPY         B
# 8  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDUSD         B
# 3  CHFJPY         B
# 4  GBPJPY         B
# 5  EURJPY         B
# 6  EURNZD         S
# 7  CADJPY         B
# 8  AUDJPY         B
# 9  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  EURJPY         B
# 5  EURNZD         S
# 6  CADJPY         B
# 7  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  CHFJPY         B
# 3  EURGBP         S
# 4  GBPJPY         B
# 5  EURJPY         B
# 6  CADJPY         B
#      name direction
# 0  GBPUSD         B
# 1  CHFJPY         B
# 2  GBPJPY         B
# 3  EURJPY         B
# 4  EURCAD         S
# 5  EURNZD         S
# 6  CADJPY         B
# 7  AUDJPY         B
#      name direction
# 0  USDCAD         S
# 1  EURGBP         S
# 2  GBPJPY         B
# 3  EURJPY         B
# 4  EURNZD         S
# 5  CADJPY         B
# 6  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  CADJPY         B
#      name direction
# 0  GBPJPY         B
# 1  EURJPY         B
# 2  EURCAD         S
# 3  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURGBP         S
# 2  EURJPY         B
# 3  EURNZD         S
# 4  AUDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  CADJPY         B
#      name direction
# 0  NZDCHF         B
# 1  EURGBP         S
# 2  GBPJPY         B
# 3  EURCAD         S
# 4  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  GBPAUD         B
# 2  EURJPY         B
#      name direction
# 0  EURCHF         S
# 1  CHFJPY         B
# 2  NZDCHF         S
# 3  EURGBP         S
#      name direction
# 0  NZDCHF         B
# 1  EURGBP         S
# 2  GBPJPY         B
# 3  EURCAD         S
# 4  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURGBP         S
# 2  GBPCAD         B
# 3  GBPAUD         B
# 4  EURJPY         B
# 5  AUDJPY         B
#      name direction
# 0  CHFJPY         B
# 1  EURGBP         S
#      name direction
# 0  EURGBP         S
# 1  GBPJPY         B
# 2  EURCAD         S
# 3  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURJPY         B
#      name direction
# 0  USDJPY         B
# 1  CHFJPY         B
# 2  EURGBP         S
#      name direction
# 0  NZDCHF         B
# 1  EURGBP         S
# 2  GBPJPY         B
# 3  EURCAD         S
# 4  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURJPY         B
# 2  CADJPY         B
# 3  AUDJPY         B
# 4  NZDJPY         B
#      name direction
# 0  USDJPY         B
# 1  CHFJPY         B
# 2  EURGBP         S
# 3  GBPJPY         B
# 4  CADJPY         B
#      name direction
# 0  EURGBP         S
# 1  GBPJPY         B
# 2  EURNZD         S
#      name direction
# 0  USDJPY         B
# 1  USDCAD         S
# 2  EURCHF         S
# 3  EURJPY         B
#      name direction
# 0  EURUSD         S
# 1  USDJPY         B
# 2  EURCHF         S
# 3  CHFJPY         B
# 4  NZDCHF         S
# 5  EURGBP         S
# 6  EURCAD         S
#      name direction
# 0  EURGBP         S
# 1  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURCHF         S

# %%
all_currency_thirty_minutes_data = {}

for z in all_currency_pairs:
    current_currency = z.replace('10080','')
    current_currency_df = pd.read_csv('../raw_30_minutes_data/' + current_currency + '30.csv', names=headers ) 
    
    all_currency_thirty_minutes_data[current_currency] = current_currency_df
    
    #print( current_currency, )
    
    
print(len(all_currency_thirty_minutes_data))
# Out:
# 27

# %%
qualified_weeks =[]

for k in all_time_next_week_trade:
    
    current_week_data = k['next_week_trades']
    current_week_date = k['week']
    
    current_week_date = datetime.strptime(current_week_date, '%Y.%m.%d')

    week_start_date  = current_week_date + timedelta(days=7)
    week_end_date = current_week_date + timedelta(days=12)
    
    week_start_date = week_start_date.strftime("%Y.%m.%d")
    week_end_date = week_end_date.strftime("%Y.%m.%d")      

    
    

    #print(current_week_date, week_start_date, week_end_date)
    
    qualified_currencies = 0
   
    for l in current_week_data:
        
        
        current_currency = l['name'] 
        
        current_currency_df = all_currency_thirty_minutes_data[l['name']].copy()
        
        
        
        
        current_currency_df = current_currency_df.loc[  (current_currency_df['date'] >= week_start_date)
                                                   
                                                                                 & 
                                                              (current_currency_df['date'] <= week_end_date)
                                                            ]  
    
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True )
        #print( week_start_date, current_currency, current_currency_df)
        
       
        current_currency_dataframe_row_ammount = len(current_currency_df.index)
        
        if  current_currency_dataframe_row_ammount < 238:
            
            print(current_currency,  len(current_currency_df), week_start_date, 'is less than 238')
            continue
            #raise Exception("lenght is lesss than 238")
            
            
        
        if  current_currency_dataframe_row_ammount != 240:
            
            if (current_currency_df['ignore'].tail(1).values == '22:30' ):
                
                
                
                last_row = current_currency_df.copy().tail(1)
                
                last_row.tail()['ignore'] = '23:00'
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
                
                last_row.tail()['ignore'] = '23:30'
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
                #print(current_currency, current_currency_df)
                
                if  len(current_currency_df.index) != 240:
              
                    print(current_currency, current_currency_df)
                    raise Exception("number of rows is still wrong after repair")
        
            else:
                
                print(current_currency,  len(current_currency_df), week_start_date, "can't be repaired, skipping it")
                continue
        
        if current_currency_df['ignore'].iloc[-1] != '23:30' :
        
            print(current_currency, current_currency_df)
            raise Exception("last row is not 23:30")
        
        
      
            
             
        
        
       
        current_currency_df.to_csv("files/" + k['week'] + '/' + current_currency +".csv", index=None)
        
        qualified_currencies = qualified_currencies +1
        
        
        
    if qualified_currencies == len(current_week_data):
            
        qualified_weeks.append(k)
        
    
   
        
        #print(current_currency_df)
        
        
        
    #print('-----------------------------------------------------------------------------------------------', week_start_date)


print(qualified_weeks)
# Out:
# EURCHF 0 2015.01.11 is less than 238
# EURCHF 239 2015.02.08 can't be repaired, skipping it
# USDCAD 182 2015.12.20 is less than 238
# GBPCAD 182 2015.12.20 is less than 238
# NZDJPY 182 2015.12.20 is less than 238
# USDCAD 184 2015.12.27 is less than 238
# GBPUSD 237 2016.10.09 is less than 238
# EURGBP 237 2016.10.09 is less than 238
# GBPJPY 237 2016.10.09 is less than 238
# GBPCAD 228 2016.12.25 is less than 238
# NZDCAD 218 2017.09.03 is less than 238
# GBPJPY 239 2017.09.10 can't be repaired, skipping it
# GBPCAD 239 2017.09.10 can't be repaired, skipping it
# EURCHF 180 2017.12.24 is less than 238
# USDCAD 174 2018.12.23 is less than 238
# CADJPY 174 2018.12.23 is less than 238
# GBPUSD 178 2018.12.30 is less than 238
# USDCAD 178 2018.12.30 is less than 238
# AUDUSD 178 2018.12.30 is less than 238
# NZDUSD 178 2018.12.30 is less than 238
# NZDCHF 172 2018.12.30 is less than 238
# EURNZD 178 2018.12.30 is less than 238
# AUDJPY 178 2018.12.30 is less than 238
# NZDJPY 178 2018.12.30 is less than 238
# GBPAUD 224 2020.03.29 is less than 238
# USDCAD 186 2020.12.20 is less than 238
# AUDUSD 186 2020.12.20 is less than 238
# CADCHF 186 2020.12.20 is less than 238
# GBPUSD 233 2021.06.13 is less than 238
# AUDUSD 233 2021.06.13 is less than 238
# NZDUSD 233 2021.06.13 is less than 238
# CHFJPY 233 2021.06.13 is less than 238
# GBPJPY 233 2021.06.13 is less than 238
# EURJPY 233 2021.06.13 is less than 238
# EURNZD 233 2021.06.13 is less than 238
# CADJPY 233 2021.06.13 is less than 238
# AUDJPY 233 2021.06.13 is less than 238
# NZDJPY 233 2021.06.13 is less than 238
# USDCAD 176 2021.12.05 is less than 238
# EURCHF 175 2021.12.05 is less than 238
# [{'week': '2015.01.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}, {'week': '2015.01.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.01.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.02.08', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.02.15', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}, {'week': '2015.02.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}, {'week': '2015.03.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.03.08', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}, {'week': '2015.03.15', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}, {'week': '2015.03.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.03.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.04.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CADCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}, {'week': '2015.04.12', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.04.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}, {'week': '2015.04.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}, {'week': '2015.05.03', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}, {'week': '2015.05.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}, {'week': '2015.05.17', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD',  ...

# %%
timeframe = []
trade_values = []

for m in qualified_weeks:

    
    
    current_week = m['week']
    current_week_data = m['next_week_trades']
    
    current_week_drawdown_df = pd.DataFrame()
    
  
    current_week_dfs = []
    
    for n in current_week_data:
        
        
        
        current_currency = n['name']
        current_currency_direction = n['direction']
        current_currency_df =  pd.read_csv("files/" + current_week + '/' + current_currency +".csv" ) 
        
        #print(current_currency_df)
        maximal_draw_down =[]
        pips_corrector = 100000
            
        if current_currency.endswith('JPY'):
                
            pips_corrector = 1000
            
        
        
        
        for o in range(240):
                   
            if current_currency_direction == 'B':
                
                
                profit = current_currency_df.loc[o,'low'] - current_currency_df.loc[0,'open']
                
              
            if current_currency_direction == 'S':
                
                #print(current_currency, current_week)
                profit = current_currency_df.loc[0,'open'] - current_currency_df.loc[o,'high']
            
            
            
            maximal_draw_down.append(profit*pips_corrector)
    
                
        
        current_week_drawdown_df[current_currency] = maximal_draw_down
            
            
    current_week_drawdown_df['empty'] = ['' for r in range(240)]      
    current_week_drawdown_df["sum"] = current_week_drawdown_df.drop("empty", axis=1, inplace=False).sum(axis=1)        
    print(current_week_drawdown_df)
        
    
    
    
    
    
    
    
    
    
    print('--------------------------------------------------------------------------------------------------', m)
# Out:
#      EURUSD  EURCHF  EURGBP  EURCAD empty     sum
# 0    -145.0   -54.0  -107.0  -154.0        -460.0
# 1    -126.0   -91.0   -82.0  -122.0        -421.0
# 2    -201.0  -322.0   -72.0  -199.0        -794.0
# 3    -204.0  -292.0   -71.0  -159.0        -726.0
# 4    -127.0   186.0   -26.0   -56.0         -23.0
# ..      ...     ...     ...     ...   ...     ...
# 235  3068.0   704.0  1448.0 -1355.0        3865.0
# 236  3052.0   797.0  1443.0 -1309.0        3983.0
# 237  3204.0   845.0  1474.0 -1100.0        4423.0
# 238  3189.0   681.0  1429.0 -1123.0        4176.0
# 239  3360.0   675.0  1539.0 -1089.0        4485.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      EURUSD  EURCHF  EURGBP empty     sum
# 0     -66.0   -51.0    -1.0        -118.0
# 1       8.0   -84.0    23.0         -53.0
# 2       9.0    -1.0    76.0          84.0
# 3      68.0    48.0    41.0         157.0
# 4    -512.0  -183.0  -209.0        -904.0
# ..      ...     ...     ...   ...     ...
# 235 -1509.0 -6255.0  -696.0       -8460.0
# 236 -1490.0 -5555.0  -671.0       -7716.0
# 237 -1656.0 -5582.0  -747.0       -7985.0
# 238 -1502.0 -5707.0  -664.0       -7873.0
# 239 -1421.0 -5757.0  -650.0       -7828.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  EURGBP empty     sum
# 0     -49.0   -87.0   -77.0        -213.0
# 1      43.0   -76.0  -106.0        -139.0
# 2      46.0   -20.0  -103.0         -77.0
# 3      82.0    27.0   -82.0          27.0
# 4     106.0    33.0   -92.0          47.0
# ..      ...     ...     ...   ...     ...
# 235 -1405.0   -80.0   565.0        -920.0
# 236 -1506.0  -132.0   585.0       -1053.0
# 237 -1496.0  -110.0   594.0       -1012.0
# 238 -1509.0  -118.0   591.0       -1036.0
# 239 -1584.0  -117.0   615.0       -1086.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'
columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  GBPCHF  EURGBP  EURNZD empty     sum
# 0    -138.0  -177.0  -100.0   -71.0   -87.0        -573.0
# 1    -187.0  -196.0   209.0   -66.0  -123.0        -363.0
# 2    -198.0  -173.0   313.0   -39.0  -193.0        -290.0
# 3    -203.0   -54.0   309.0    25.0  -174.0         -97.0
# 4    -212.0   -98.0   185.0    13.0  -207.0        -319.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235 -2112.0 -3255.0 -2350.0 -1205.0  -137.0       -9059.0
# 236 -2159.0 -3357.0 -2350.0 -1258.0     6.0       -9118.0
# 237 -2287.0 -3428.0 -2605.0 -1335.0  -113.0       -9768.0
# 238 -2287.0 -3428.0 -2605.0 -1335.0  -113.0       -9768.0
# 239 -2287.0 -3428.0 -2605.0 -1335.0  -113.0       -9768.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.08', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCHF  EURUSD  EURGBP  EURJPY  EURCAD empty     sum
# 0     -16.0   -20.0   -12.0   -38.0  -156.0        -242.0
# 1     212.0   196.0    73.0    80.0  -166.0         395.0
# 2     297.0   276.0   109.0   102.0   -13.0         771.0
# 3     249.0   284.0    91.0   178.0    -5.0         797.0
# 4     270.0   388.0   123.0   316.0    94.0        1191.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235 -1719.0  -645.0  -756.0   128.0 -1344.0       -4336.0
# 236 -1501.0  -318.0  -711.0   362.0 -1123.0       -3291.0
# 237 -1481.0  -358.0  -691.0   311.0 -1169.0       -3388.0
# 238 -1481.0  -358.0  -691.0   311.0 -1169.0       -3388.0
# 239 -1481.0  -358.0  -691.0   311.0 -1169.0       -3388.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.15', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      USDCHF  EURUSD  USDCAD  AUDUSD  NZDUSD  GBPCHF  EURGBP empty     sum
# 0     -73.0   -72.0  -113.0   -67.0   -83.0   -45.0   -44.0        -497.0
# 1     -83.0   -50.0   -42.0   -80.0  -115.0   -41.0   -32.0        -443.0
# 2     -48.0   -70.0   -96.0  -116.0   -99.0    43.0   -13.0        -399.0
# 3     -52.0   -72.0   -93.0   -62.0   -87.0    59.0   -10.0        -317.0
# 4     -84.0   -52.0   -92.0  -140.0  -140.0    49.0    17.0        -442.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...     ...
# 235  -896.0  -938.0 -1324.0   948.0  -409.0 -1048.0  -501.0       -4168.0
# 236  -888.0  -941.0 -1306.0   947.0  -426.0 -1045.0  -509.0       -4168.0
# 237  -875.0  -920.0 -1290.0   978.0  -419.0  -988.0  -464.0       -3978.0
# 238  -894.0  -864.0 -1255.0   968.0  -403.0 -1010.0  -442.0       -3900.0
# 239 -1180.0  -918.0 -1312.0   983.0  -567.0 -1402.0  -479.0       -4875.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  GBPCHF  EURGBP empty     sum
# 0     -78.0   -18.0   -30.0  -177.0        -303.0
# 1     -59.0    31.0    -2.0  -174.0        -204.0
# 2     -88.0    34.0    27.0  -197.0        -224.0
# 3     -31.0   -37.0    97.0  -204.0        -175.0
# 4    -150.0  -166.0    58.0  -241.0        -499.0
# ..      ...     ...     ...     ...   ...     ...
# 235  2636.0  3948.0  1412.0  1142.0        9138.0
# 236  2685.0  3947.0  1379.0  1116.0        9127.0
# 237  2682.0  3923.0  1380.0  1119.0        9104.0
# 238  2674.0  3922.0  1448.0  1117.0        9161.0
# 239  2840.0  3972.0  1350.0  1075.0        9237.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      USDCHF  EURUSD  EURCHF  CADCHF  EURGBP  EURJPY  EURCAD empty     sum
# 0       0.0     0.0   -74.0   -73.0     0.0    -7.0  -106.0        -260.0
# 1      18.0    70.0   -44.0  -136.0    36.0    20.0   -88.0        -124.0
# 2      44.0    -5.0   -63.0  -109.0    10.0  -104.0   -94.0        -321.0
# 3      11.0  -105.0  -105.0   -84.0   -24.0  -141.0  -205.0        -653.0
# 4       0.0  -137.0  -112.0   -53.0   -43.0  -170.0  -194.0        -709.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...     ...
# 235 -2627.0 -1958.0   882.0  -218.0   309.0  -799.0   897.0       -3514.0
# 236 -2717.0 -2155.0   868.0   -89.0   221.0 -1032.0   952.0       -3952.0
# 237 -2756.0 -2201.0   816.0  -122.0   176.0 -1154.0   902.0       -4339.0
# 238 -2752.0 -2162.0   844.0  -128.0   169.0 -1103.0   942.0       -4190.0
# 239 -2759.0 -2062.0   912.0  -379.0   199.0 -1087.0   881.0       -4295.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CADCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      USDCHF  EURUSD  EURGBP empty    sum
# 0     -84.0  -106.0   -80.0       -270.0
# 1    -120.0   -87.0   -26.0       -233.0
# 2     -90.0   -27.0    11.0       -106.0
# 3      75.0   103.0    30.0        208.0
# 4       6.0    36.0    34.0         76.0
# ..      ...     ...     ...   ...    ...
# 235   197.0  -612.0   600.0        185.0
# 236   198.0  -623.0   606.0        181.0
# 237   215.0  -586.0   623.0        252.0
# 238   213.0  -589.0   641.0        265.0
# 239   162.0  -645.0   628.0        145.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.12', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  GBPCHF  EURGBP  EURNZD empty      sum
# 0     -58.0   -20.0   -31.0     0.0   -78.0         -187.0
# 1     -75.0   -51.0    28.0     4.0    31.0          -63.0
# 2     -47.0   -62.0   -39.0   -18.0  -108.0         -274.0
# 3       8.0   -26.0   -78.0   -24.0   -80.0         -200.0
# 4      -1.0   -23.0    -8.0   -10.0   -38.0          -80.0
# ..      ...     ...     ...     ...     ...   ...      ...
# 235   225.0 -3374.0 -3506.0 -2392.0 -5864.0       -14911.0
# 236   399.0 -3379.0 -3507.0 -2457.0 -5854.0       -14798.0
# 237   209.0 -3550.0 -3537.0 -2493.0 -5988.0       -15359.0
# 238   159.0 -3533.0 -3557.0 -2432.0 -5835.0       -15198.0
# 239   147.0 -3458.0 -3557.0 -2375.0 -5695.0       -14938.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCHF  EURUSD  EURJPY  EURCAD empty    sum
# 0     -71.0   -90.0   -31.0  -113.0       -305.0
# 1    -106.0   -76.0   -63.0  -174.0       -419.0
# 2     -75.0   -27.0   -29.0  -151.0       -282.0
# 3     -66.0   -36.0   -21.0   -57.0       -180.0
# 4     -38.0    -1.0    51.0   -74.0        -62.0
# ..      ...     ...     ...     ...   ...    ...
# 235  -267.0  -136.0   312.0   468.0        377.0
# 236  -268.0  -216.0   271.0   463.0        250.0
# 237  -268.0  -244.0   254.0   465.0        207.0
# 238  -250.0  -165.0   376.0   457.0        418.0
# 239  -230.0  -183.0   326.0   471.0        384.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      EURUSD  NZDUSD  EURGBP empty     sum
# 0     -53.0   -53.0    -3.0        -109.0
# 1     -19.0   143.0     6.0         130.0
# 2     -33.0    90.0   -23.0          34.0
# 3      14.0   215.0   -23.0         206.0
# 4      26.0   306.0   -23.0         309.0
# ..      ...     ...     ...   ...     ...
# 235 -2661.0  -396.0  -326.0       -3383.0
# 236 -2638.0  -395.0  -332.0       -3365.0
# 237 -2529.0  -302.0  -301.0       -3132.0
# 238 -2497.0  -295.0  -280.0       -3072.0
# 239 -2491.0  -175.0  -300.0       -2966.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.03', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      EURUSD  USDJPY empty     sum
# 0       0.0   -17.0         -17.0
# 1      52.0    79.0         131.0
# 2      28.0   100.0         128.0
# 3      19.0   125.0         144.0
# 4      51.0   113.0         164.0
# ..      ...     ...   ...     ...
# 235  4325.0  2238.0        6563.0
# 236  4348.0  2239.0        6587.0
# 237  4390.0  2252.0        6642.0
# 238  4300.0  2226.0        6526.0
# 239  4317.0  2223.0        6540.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
#      USDCHF  EURUSD  USDJPY  USDCAD  EURCHF  EURJPY  EURCAD empty    sum
# 0     -25.0   -37.0     0.0    -8.0   -11.0   -81.0   -49.0       -211.0
# 1      16.0    31.0    33.0    17.0    -1.0   -31.0   -22.0         43.0
# 2      20.0    35.0    31.0     4.0    16.0   -13.0    13.0        106.0
# 3     -18.0    11.0     9.0   -56.0     0.0   -22.0    33.0        -43.0
# 4     -34.0   -35.0    13.0   -18.0    14.0   -66.0   -49.0       -175.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...    ...
# 235  -386.0   146.0  2460.0  1434.0   578.0 -2547.0 -1477.0        208.0
# 236  -339.0   204.0  2548.0  1551.0   568.0 -2619.0 -1515.0        398.0
# 237  -355.0   181.0  2563.0  1476.0   558.0 -2660.0 -1545.0        218.0
# 238  -323.0   192.0  2595.0  1503.0   546.0 -2659.0 -1499.0        355.0
# 239  -346.0   138.0  2611.0  1496.0   459.0 -2718.0 -1549.0         91.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.17', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      EURUSD  NZDUSD  EURCHF  EURGBP empty     sum
# 0     -41.0  -106.0   -16.0   -98.0        -261.0
# 1     -34.0   -89.0    82.0   -57.0         -98.0
# 2      21.0   -64.0    55.0   -58.0         -46.0
# 3      51.0   -95.0    65.0   -55.0         -34.0
# 4     153.0  -187.0   123.0    41.0         130.0
# ..      ...     ...     ...     ...   ...     ...
# 235 -1524.0   398.0 -1190.0 -1087.0       -3403.0
# 236 -1351.0   431.0 -1194.0 -1021.0       -3135.0
# 237 -1336.0   406.0 -1192.0 -1015.0       -3137.0
# 238 -1372.0   392.0 -1198.0 -1007.0       -3185.0
# 239 -1334.0   367.0 -1152.0 -1006.0       -3125.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.24', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  USDJPY empty     sum
# 0     -36.0   -46.0   -51.0        -133.0
# 1       6.0   -37.0   -31.0         -62.0
# 2      16.0   -55.0   -39.0         -78.0
# 3      11.0   -77.0    12.0         -54.0
# 4      12.0   -65.0    42.0         -11.0
# ..      ...     ...     ...   ...     ...
# 235 -2901.0 -1742.0 -2175.0       -6818.0
# 236 -2864.0 -1785.0 -2181.0       -6830.0
# 237 -2930.0 -1676.0 -2218.0       -6824.0
# 238 -2997.0 -1698.0 -2235.0       -6930.0
# 239 -2988.0 -1678.0 -2264.0       -6930.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.31', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
#      USDCHF  EURUSD  USDJPY  USDCAD  EURJPY empty     sum
# 0     -81.0  -176.0     0.0   -37.0  -263.0        -557.0
# 1    -113.0  -101.0   -22.0  -102.0  -199.0        -537.0
# 2     -73.0   -93.0    38.0    -8.0  -208.0        -344.0
# 3     -79.0  -138.0   109.0   -42.0  -296.0        -446.0
# 4     -71.0  -139.0   111.0   -34.0  -282.0        -415.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235 -1303.0 -1512.0  -576.0  -607.0 -1177.0       -5175.0
# 236 -1329.0 -1439.0  -559.0  -538.0 -1141.0       -5006.0
# 237 -1294.0 -1406.0  -501.0  -475.0 -1118.0       -4794.0
# 238 -1284.0 -1372.0  -490.0  -484.0 -1096.0       -4726.0
# 239 -1292.0 -1398.0  -516.0  -493.0 -1134.0       -4833.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.07', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}]}
#      EURUSD  NZDUSD  EURGBP empty     sum
# 0      -3.0   -24.0   -15.0         -42.0
# 1      15.0   -41.0    -5.0         -31.0
# 2      65.0   -11.0     2.0          56.0
# 3     113.0   -23.0    48.0         138.0
# 4      41.0   -17.0    33.0          57.0
# ..      ...     ...     ...   ...     ...
# 235  2076.0   572.0   639.0        3287.0
# 236  2059.0   576.0   653.0        3288.0
# 237  2038.0   592.0   635.0        3265.0
# 238  1979.0   575.0   641.0        3195.0
# 239  2027.0   620.0   683.0        3330.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  EURUSD  NZDUSD empty     sum
# 0     -47.0   -32.0  -162.0        -241.0
# 1     -13.0   133.0   -53.0          67.0
# 2    -174.0  -107.0  -148.0        -429.0
# 3    -326.0   -22.0   -57.0        -405.0
# 4    -210.0    21.0   -67.0        -256.0
# ..      ...     ...     ...   ...     ...
# 235  1068.0  -956.0  1278.0        1390.0
# 236  1081.0  -941.0  1345.0        1485.0
# 237  1089.0 -1044.0  1242.0        1287.0
# 238   907.0 -1072.0  1244.0        1079.0
# 239  1033.0 -1046.0  1264.0        1251.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.21', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}]}
#      USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  EURJPY empty     sum
# 0     -50.0  -168.0   -23.0    -7.0   -38.0  -375.0        -661.0
# 1     -39.0  -134.0    -7.0    28.0   -24.0  -299.0        -475.0
# 2    -197.0  -540.0  -144.0  -101.0  -169.0 -1070.0       -2221.0
# 3     -67.0  -495.0   336.0   -88.0  -157.0  -984.0       -1455.0
# 4    -117.0  -588.0   243.0  -122.0  -365.0 -1033.0       -1982.0
# ..      ...     ...     ...     ...     ...     ...   ...     ...
# 235  -230.0 -1570.0   824.0   908.0   379.0 -2826.0       -2515.0
# 236  -242.0 -1606.0   833.0   868.0   282.0 -2903.0       -2768.0
# 237  -318.0 -1658.0   795.0   814.0   302.0 -2947.0       -3012.0
# 238  -437.0 -1762.0   723.0   738.0   298.0 -2967.0       -3407.0
# 239  -604.0 -1776.0   704.0   715.0   331.0 -2985.0       -3615.0
#
# [240 rows x 8 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.28', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
#      GBPUSD  EURUSD  USDJPY  NZDUSD  AUDCHF empty     sum
# 0    -122.0  -153.0     0.0   -15.0  -192.0        -482.0
# 1    -147.0  -392.0   131.0   -32.0  -141.0        -581.0
# 2    -188.0  -416.0   214.0   -85.0  -347.0        -822.0
# 3     -37.0  -298.0   147.0   -78.0  -276.0        -542.0
# 4     -76.0  -354.0   128.0  -156.0  -310.0        -768.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235 -1150.0  2447.0  1735.0  1750.0 -1271.0        3511.0
# 236 -1103.0  2489.0  1723.0  1761.0 -1244.0        3626.0
# 237 -1077.0  2489.0  1752.0  1738.0 -1261.0        3641.0
# 238 -1035.0  2553.0  1748.0  1736.0 -1299.0        3703.0
# 239 -1045.0  2649.0  1738.0  1718.0 -1347.0        3713.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.05', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
#      GBPUSD  EURUSD  USDJPY  NZDUSD empty     sum
# 0     -35.0   -27.0    -6.0   -86.0        -154.0
# 1     -30.0   -20.0    30.0   -33.0         -53.0
# 2    -107.0  -102.0    36.0   -87.0        -260.0
# 3     -93.0   -86.0    47.0  -104.0        -236.0
# 4     -79.0   -53.0    54.0  -103.0        -181.0
# ..      ...     ...     ...     ...   ...     ...
# 235   883.0 -1498.0  -323.0  -554.0       -1492.0
# 236   900.0 -1514.0  -291.0  -557.0       -1462.0
# 237   903.0 -1476.0  -265.0  -572.0       -1410.0
# 238   899.0 -1475.0  -250.0  -618.0       -1444.0
# 239   818.0 -1468.0  -238.0  -625.0       -1513.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.12', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}]}
#      USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  EURJPY empty    sum
# 0       0.0   -23.0   -65.0   -54.0   -36.0    -9.0       -187.0
# 1     -68.0   -15.0   -76.0   -20.0   -20.0    32.0       -167.0
# 2      16.0   -44.0   -19.0    18.0   -65.0   -82.0       -176.0
# 3      -3.0   -44.0    46.0    40.0   -80.0   -84.0       -125.0
# 4      20.0     7.0    11.0    -2.0  -136.0   -37.0       -137.0
# ..      ...     ...     ...     ...     ...     ...   ...    ...
# 235   303.0  -151.0   108.0   347.0  -470.0  -316.0       -179.0
# 236   372.0  -115.0   140.0   408.0  -352.0  -287.0        166.0
# 237   350.0  -129.0   105.0   311.0  -397.0  -283.0        -43.0
# 238   326.0  -140.0   126.0   313.0  -412.0  -314.0       -101.0
# 239   259.0   -98.0    97.0   444.0  -394.0  -297.0         11.0
#
# [240 rows x 8 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.19', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
#      EURUSD  USDJPY  NZDUSD  EURGBP empty    sum
# 0    -111.0    -2.0   -28.0   -63.0       -204.0
# 1    -124.0    -1.0   -39.0   -79.0       -243.0
# 2    -100.0    46.0   -25.0   -68.0       -147.0
# 3     -87.0    33.0    77.0   -51.0        -28.0
# 4     -67.0    52.0    90.0   -27.0         48.0
# ..      ...     ...     ...     ...   ...    ...
# 235   -18.0   257.0  -352.0  -605.0       -718.0
# 236     0.0   273.0  -289.0  -613.0       -629.0
# 237    13.0   263.0  -237.0  -601.0       -562.0
# 238   115.0   336.0  -178.0  -559.0       -286.0
# 239    62.0   322.0  -213.0  -569.0       -398.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.26', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      GBPUSD  USDJPY empty     sum
# 0     -98.0     0.0         -98.0
# 1    -106.0    20.0         -86.0
# 2     -79.0    68.0         -11.0
# 3    -122.0   112.0         -10.0
# 4    -108.0   123.0          15.0
# ..      ...     ...   ...     ...
# 235 -1695.0    76.0       -1619.0
# 236 -1670.0    95.0       -1575.0
# 237 -1658.0   112.0       -1546.0
# 238 -1650.0   128.0       -1522.0
# 239 -1687.0   133.0       -1554.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.02', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
#      USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  GBPCAD  NZDJPY empty     sum
# 0     -70.0   -57.0   -43.0   -35.0   -66.0  -101.0  -175.0        -547.0
# 1       6.0   -48.0    26.0   -25.0   -84.0  -168.0  -129.0        -422.0
# 2      21.0   -21.0    32.0    -1.0   -65.0   -87.0   -92.0        -213.0
# 3      86.0    50.0    82.0    13.0   -48.0   -78.0  -142.0         -37.0
# 4      84.0    90.0    79.0    15.0   -44.0   -59.0  -173.0          -8.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...     ...
# 235 -2800.0 -2473.0 -2172.0   677.0   388.0  1601.0  -599.0       -5378.0
# 236 -2800.0 -2473.0 -2150.0   790.0   404.0  1760.0  -581.0       -5050.0
# 237 -2756.0 -2525.0 -2141.0   755.0   350.0  1707.0  -613.0       -5223.0
# 238 -2804.0 -2578.0 -2129.0   708.0   412.0  1690.0  -556.0       -5257.0
# 239 -2984.0 -2744.0 -2197.0   739.0   395.0  1552.0  -518.0       -5757.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.09', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD  NZDUSD  AUDCHF empty     sum
# 0     -14.0  -158.0  -152.0        -324.0
# 1      -7.0  -122.0  -228.0        -357.0
# 2     -19.0  -267.0  -199.0        -485.0
# 3      82.0  -167.0   -48.0        -133.0
# 4     161.0   146.0   212.0         519.0
# ..      ...     ...     ...   ...     ...
# 235   337.0  1913.0    16.0        2266.0
# 236   349.0  1917.0    16.0        2282.0
# 237   320.0  1961.0    26.0        2307.0
# 238   310.0  1922.0    30.0        2262.0
# 239   197.0  1917.0    26.0        2140.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.16', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
#      GBPUSD  USDCAD empty     sum
# 0     -53.0   -15.0         -68.0
# 1       3.0    26.0          29.0
# 2     -21.0    32.0          11.0
# 3     -54.0   138.0          84.0
# 4     -66.0   220.0         154.0
# ..      ...     ...   ...     ...
# 235  2195.0   344.0        2539.0
# 236  2214.0   395.0        2609.0
# 237  2225.0   478.0        2703.0
# 238  2237.0   520.0        2757.0
# 239  2315.0   522.0        2837.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.23', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}]}
#      USDCHF  EURUSD  USDCAD  AUDUSD  GBPCAD  EURJPY  NZDJPY empty     sum
# 0     -34.0   -65.0   -18.0   -14.0    -5.0   -67.0   -16.0        -219.0
# 1     -20.0   -31.0   -20.0    61.0   -55.0   -88.0     0.0        -153.0
# 2      11.0     4.0    38.0   -38.0    52.0   -65.0   -53.0         -51.0
# 3      58.0    89.0    90.0    -9.0   235.0  -167.0  -110.0         186.0
# 4      46.0    16.0    90.0   -55.0   254.0  -228.0   -65.0          58.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...     ...
# 235  -292.0 -1859.0    -4.0 -1665.0  3296.0 -4079.0 -1355.0       -5958.0
# 236  -226.0 -1798.0     2.0 -1642.0  3308.0 -4077.0 -1365.0       -5798.0
# 237  -267.0 -1852.0    10.0 -1625.0  3281.0 -4082.0 -1265.0       -5800.0
# 238  -309.0 -1846.0    11.0 -1661.0  3299.0 -4082.0 -1263.0       -5851.0
# 239  -293.0 -1824.0    61.0 -1702.0  3363.0 -4052.0 -1262.0       -5709.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.30', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD  NZDUSD  AUDCHF empty     sum
# 0       0.0   -90.0   -73.0        -163.0
# 1      72.0  -190.0   -76.0        -194.0
# 2      74.0  -188.0   -54.0        -168.0
# 3       5.0  -162.0   -19.0        -176.0
# 4     -25.0  -116.0  -113.0        -254.0
# ..      ...     ...     ...   ...     ...
# 235  -763.0 -1114.0  -984.0       -2861.0
# 236  -770.0 -1105.0 -1082.0       -2957.0
# 237  -352.0 -1036.0 -1193.0       -2581.0
# 238  -349.0 -1015.0 -1116.0       -2480.0
# 239  -349.0 -1024.0 -1090.0       -2463.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
#      USDCAD empty     sum
# 0       0.0           0.0
# 1      28.0          28.0
# 2      14.0          14.0
# 3     -44.0         -44.0
# 4     -43.0         -43.0
# ..      ...   ...     ...
# 235  1084.0        1084.0
# 236  1025.0        1025.0
# 237   966.0         966.0
# 238   958.0         958.0
# 239  1040.0        1040.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.13', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}]}
#      USDCHF  USDCAD  GBPCAD  NZDJPY empty     sum
# 0       0.0   -50.0  -149.0   -69.0        -268.0
# 1     123.0   -46.0  -141.0  -108.0        -172.0
# 2     192.0   -65.0   -34.0  -170.0         -77.0
# 3     280.0   -92.0   -79.0  -193.0         -84.0
# 4     279.0   -52.0   -44.0  -136.0          47.0
# ..      ...     ...     ...     ...   ...     ...
# 235  -634.0 -1443.0 -2268.0  -478.0       -4823.0
# 236  -630.0 -1491.0 -2267.0  -621.0       -5009.0
# 237  -543.0 -1768.0 -2836.0  -721.0       -5868.0
# 238  -486.0 -1774.0 -2965.0  -643.0       -5868.0
# 239  -509.0 -1801.0 -2988.0  -605.0       -5903.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.20', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      AUDCHF  NZDCAD empty    sum
# 0     -53.0   -25.0        -78.0
# 1     -33.0   -54.0        -87.0
# 2     -94.0   -22.0       -116.0
# 3     -70.0   -51.0       -121.0
# 4     -59.0  -123.0       -182.0
# ..      ...     ...   ...    ...
# 235 -1952.0  1794.0       -158.0
# 236 -1956.0  1746.0       -210.0
# 237 -1955.0  1680.0       -275.0
# 238 -1976.0  1676.0       -300.0
# 239 -2051.0  1686.0       -365.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.27', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
#      USDCHF  USDCAD  GBPCAD empty     sum
# 0       0.0   -63.0   -26.0         -89.0
# 1     214.0    30.0    45.0         289.0
# 2     228.0    33.0    -6.0         255.0
# 3     224.0    77.0    57.0         358.0
# 4     212.0    93.0   105.0         410.0
# ..      ...     ...     ...   ...     ...
# 235  2838.0  2685.0  2671.0        8194.0
# 236  2882.0  2763.0  2685.0        8330.0
# 237  2827.0  2691.0  2485.0        8003.0
# 238  2803.0  2703.0  2453.0        7959.0
# 239  2768.0  2586.0  2298.0        7652.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.11', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}]}
#      AUDCHF  NZDCAD empty    sum
# 0     -73.0    -9.0        -82.0
# 1    -137.0     3.0       -134.0
# 2    -136.0    86.0        -50.0
# 3    -134.0    80.0        -54.0
# 4    -186.0    95.0        -91.0
# ..      ...     ...   ...    ...
# 235    33.0  -301.0       -268.0
# 236    38.0  -351.0       -313.0
# 237    72.0  -346.0       -274.0
# 238    72.0  -346.0       -274.0
# 239    72.0  -346.0       -274.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.18', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
#      GBPAUD empty     sum
# 0    -537.0        -537.0
# 1    -384.0        -384.0
# 2    -496.0        -496.0
# 3    -539.0        -539.0
# 4    -642.0        -642.0
# ..      ...   ...     ...
# 235 -3333.0       -3333.0
# 236 -3349.0       -3349.0
# 237 -3415.0       -3415.0
# 238 -3462.0       -3462.0
# 239 -3425.0       -3425.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.25', 'next_week_trades': [{'name': 'GBPAUD', 'direction': 'B'}]}
#      USDCHF  USDCAD  GBPCAD  NZDJPY empty     sum
# 0     -35.0     0.0     0.0   -48.0         -83.0
# 1      59.0    28.0   -87.0  -153.0        -153.0
# 2     106.0    74.0     8.0  -122.0          66.0
# 3     106.0    33.0   -56.0  -176.0         -93.0
# 4      75.0    20.0    -8.0  -115.0         -28.0
# ..      ...     ...     ...     ...   ...     ...
# 235   268.0   124.0  2492.0   154.0        3038.0
# 236   230.0   127.0  2512.0   160.0        3029.0
# 237   247.0   128.0  2496.0   174.0        3045.0
# 238   228.0   234.0  2673.0   219.0        3354.0
# 239    98.0   233.0  2707.0   194.0        3232.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD  AUDJPY empty     sum
# 0       0.0  -195.0        -195.0
# 1      70.0  -173.0        -103.0
# 2     112.0   -97.0          15.0
# 3     189.0    93.0         282.0
# 4     152.0   -82.0          70.0
# ..      ...     ...   ...     ...
# 235   344.0 -1931.0       -1587.0
# 236   384.0 -1905.0       -1521.0
# 237   394.0 -1885.0       -1491.0
# 238   411.0 -1917.0       -1506.0
# 239   478.0 -1868.0       -1390.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.08', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}]}
#      USDCHF  USDCAD  GBPCAD  EURJPY  NZDJPY empty     sum
# 0     -23.0  -101.0   -14.0   -57.0   -44.0        -239.0
# 1     -16.0   -45.0    23.0     5.0   -11.0         -44.0
# 2       3.0   -20.0    84.0   -35.0    31.0          63.0
# 3       3.0     4.0   141.0   -32.0    67.0         183.0
# 4       3.0    -9.0   148.0     3.0    55.0         200.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235 -3343.0    53.0  1086.0 -3939.0 -2858.0       -9001.0
# 236 -3357.0    11.0  1112.0 -3929.0 -2847.0       -9010.0
# 237 -3314.0    59.0  1159.0 -3914.0 -2822.0       -8832.0
# 238 -3364.0     1.0  1049.0 -3902.0 -2785.0       -9001.0
# 239 -3371.0   -84.0   875.0 -3892.0 -2850.0       -9322.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD empty     sum
# 0     -40.0         -40.0
# 1     -37.0         -37.0
# 2      26.0          26.0
# 3      86.0          86.0
# 4     176.0         176.0
# ..      ...   ...     ...
# 235  3637.0        3637.0
# 236  3617.0        3617.0
# 237  3649.0        3649.0
# 238  3646.0        3646.0
# 239  3676.0        3676.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.29', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}]}
#      EURCHF empty    sum
# 0    -145.0       -145.0
# 1     -65.0        -65.0
# 2     -35.0        -35.0
# 3    -110.0       -110.0
# 4    -133.0       -133.0
# ..      ...   ...    ...
# 235   122.0        122.0
# 236   114.0        114.0
# 237   128.0        128.0
# 238   135.0        135.0
# 239   136.0        136.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.06', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
#      EURCHF empty    sum
# 0     -69.0        -69.0
# 1      -5.0         -5.0
# 2     -13.0        -13.0
# 3     204.0        204.0
# 4     110.0        110.0
# ..      ...   ...    ...
# 235   116.0        116.0
# 236   101.0        101.0
# 237    87.0         87.0
# 238    52.0         52.0
# 239     4.0          4.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.27', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
#      USDCHF  USDCAD  GBPCAD  NZDJPY empty     sum
# 0     -91.0  -103.0  -268.0   -11.0        -473.0
# 1     -39.0    83.0   -47.0   345.0         342.0
# 2    -627.0  -100.0   213.0   365.0        -149.0
# 3    -334.0    -9.0    92.0   327.0          76.0
# 4    -192.0   160.0    -3.0    12.0         -23.0
# ..      ...     ...     ...     ...   ...     ...
# 235   454.0  3753.0  1625.0  1312.0        7144.0
# 236   653.0  3629.0  1384.0  1281.0        6947.0
# 237   655.0  3522.0  1232.0  1229.0        6638.0
# 238   747.0  3601.0  1304.0  1045.0        6697.0
# 239   679.0  3564.0  1326.0  1041.0        6610.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.03', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD  EURCAD empty      sum
# 0     -59.0  -293.0         -352.0
# 1    -252.0  -575.0         -827.0
# 2    -289.0  -555.0         -844.0
# 3    -193.0  -375.0         -568.0
# 4    -200.0  -389.0         -589.0
# ..      ...     ...   ...      ...
# 235 -4555.0 -6853.0       -11408.0
# 236 -4425.0 -6769.0       -11194.0
# 237 -4433.0 -6778.0       -11211.0
# 238 -4531.0 -6831.0       -11362.0
# 239 -4726.0 -7018.0       -11744.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.10', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
#      USDCHF  USDCAD empty     sum
# 0       0.0   -41.0         -41.0
# 1     193.0    73.0         266.0
# 2     278.0    17.0         295.0
# 3     343.0    43.0         386.0
# 4     186.0    19.0         205.0
# ..      ...     ...   ...     ...
# 235 -3010.0  -872.0       -3882.0
# 236 -2971.0  -886.0       -3857.0
# 237 -2932.0  -792.0       -3724.0
# 238 -2985.0  -773.0       -3758.0
# 239 -3048.0  -739.0       -3787.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.24', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}]}
#      USDCAD  NZDJPY empty     sum
# 0     -82.0   -57.0        -139.0
# 1      46.0   -44.0           2.0
# 2      65.0   125.0         190.0
# 3      91.0   200.0         291.0
# 4      16.0   -17.0          -1.0
# ..      ...     ...   ...     ...
# 235 -2575.0  -860.0       -3435.0
# 236 -2586.0  -762.0       -3348.0
# 237 -2631.0  -744.0       -3375.0
# 238 -2617.0  -784.0       -3401.0
# 239 -2635.0  -752.0       -3387.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.02.14', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      USDCAD  NZDJPY empty     sum
# 0     -24.0   -15.0         -39.0
# 1      63.0   118.0         181.0
# 2      67.0    46.0         113.0
# 3      68.0   -15.0          53.0
# 4      13.0  -136.0        -123.0
# ..      ...     ...   ...     ...
# 235 -2072.0   785.0       -1287.0
# 236 -2103.0   870.0       -1233.0
# 237 -2319.0   843.0       -1476.0
# 238 -2319.0   843.0       -1476.0
# 239 -2319.0   843.0       -1476.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
#      CADJPY empty    sum
# 0     -21.0        -21.0
# 1    -124.0       -124.0
# 2    -242.0       -242.0
# 3    -239.0       -239.0
# 4    -250.0       -250.0
# ..      ...   ...    ...
# 235  -652.0       -652.0
# 236  -640.0       -640.0
# 237  -626.0       -626.0
# 238  -639.0       -639.0
# 239  -600.0       -600.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.20', 'next_week_trades': [{'name': 'CADJPY', 'direction': 'S'}]}
#      NZDJPY empty     sum
# 0    -181.0        -181.0
# 1    -118.0        -118.0
# 2    -229.0        -229.0
# 3    -379.0        -379.0
# 4    -377.0        -377.0
# ..      ...   ...     ...
# 235 -1735.0       -1735.0
# 236 -1735.0       -1735.0
# 237 -1726.0       -1726.0
# 238 -1753.0       -1753.0
# 239 -1802.0       -1802.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.03', 'next_week_trades': [{'name': 'NZDJPY', 'direction': 'S'}]}
#      EURGBP  GBPJPY  CADJPY empty      sum
# 0     -33.0  -157.0  -176.0         -366.0
# 1       2.0   -11.0  -169.0         -178.0
# 2       9.0  -194.0  -190.0         -375.0
# 3      75.0  -159.0  -194.0         -278.0
# 4      89.0  -226.0   -73.0         -210.0
# ..      ...     ...     ...   ...      ...
# 235 -1636.0 -7483.0 -4620.0       -13739.0
# 236 -1616.0 -7368.0 -4566.0       -13550.0
# 237 -1677.0 -7371.0 -4627.0       -13675.0
# 238 -1677.0 -7410.0 -4683.0       -13770.0
# 239 -1779.0 -7702.0 -4735.0       -14216.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.10', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
#      AUDJPY empty     sum
# 0     -92.0         -92.0
# 1    -218.0        -218.0
# 2    -539.0        -539.0
# 3    -508.0        -508.0
# 4    -515.0        -515.0
# ..      ...   ...     ...
# 235  1753.0        1753.0
# 236  1691.0        1691.0
# 237  1729.0        1729.0
# 238  1734.0        1734.0
# 239  1738.0        1738.0
#
# [240 rows x 3 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.24', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}]}
#      CHFJPY  GBPJPY  EURJPY  CADJPY empty     sum
# 0     -34.0  -222.0  -116.0  -166.0        -538.0
# 1    -159.0  -345.0  -244.0  -321.0       -1069.0
# 2    -154.0  -297.0  -211.0  -316.0        -978.0
# 3    -220.0  -471.0  -256.0  -405.0       -1352.0
# 4    -303.0  -623.0  -373.0  -422.0       -1721.0
# ..      ...     ...     ...     ...   ...     ...
# 235 -1293.0 -1747.0  -856.0 -1320.0       -5216.0
# 236 -1341.0 -1806.0  -896.0 -1364.0       -5407.0
# 237 -1384.0 -1837.0  -963.0 -1377.0       -5561.0
# 238 -1331.0 -1773.0  -910.0 -1375.0       -5389.0
# 239 -1291.0 -1723.0  -855.0 -1378.0       -5247.0
#
# [240 rows x 6 columns]
# ...
#      GBPUSD  USDCAD  EURGBP  GBPJPY  CADJPY empty     sum
# 0       0.0   -66.0  -109.0     0.0     0.0        -175.0
# 1       6.0   -66.0   -71.0    10.0    25.0         -96.0
# 2     -24.0  -250.0   -85.0    28.0     8.0        -323.0
# 3     -82.0  -319.0   -91.0    47.0   -36.0        -481.0
# 4    -113.0  -354.0   -86.0    19.0   -65.0        -599.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235   -52.0   246.0  -392.0  -842.0  -177.0       -1217.0
# 236   -16.0   260.0  -385.0  -834.0  -182.0       -1157.0
# 237   -34.0   262.0  -395.0  -876.0  -189.0       -1232.0
# 238   -21.0   233.0  -379.0  -868.0  -205.0       -1240.0
# 239   -43.0   256.0  -389.0  -854.0  -186.0       -1216.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.01', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
#      NZDCHF  EURGBP  GBPJPY  EURCAD  EURNZD empty      sum
# 0     -56.0  -138.0     0.0   -78.0  -117.0         -389.0
# 1     -96.0  -123.0    82.0   -86.0  -170.0         -393.0
# 2     -44.0  -143.0   108.0  -120.0  -247.0         -446.0
# 3      25.0  -114.0   291.0   -48.0  -215.0          -61.0
# 4      45.0  -127.0   211.0   -92.0  -205.0         -168.0
# ..      ...     ...     ...     ...     ...   ...      ...
# 235 -1736.0  -944.0 -2204.0 -2708.0 -3953.0       -11545.0
# 236 -1687.0  -948.0 -2217.0 -2692.0 -3768.0       -11312.0
# 237 -1710.0  -948.0 -2185.0 -2574.0 -3829.0       -11246.0
# 238 -1753.0  -958.0 -2213.0 -2592.0 -3954.0       -11470.0
# 239 -1757.0  -963.0 -2203.0 -2590.0 -3958.0       -11471.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.08', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCAD  GBPAUD  EURJPY empty     sum
# 0    -292.0     0.0  -110.0        -402.0
# 1    -268.0   166.0    13.0         -89.0
# 2    -269.0   224.0   129.0          84.0
# 3    -228.0   368.0   218.0         358.0
# 4    -200.0   333.0   221.0         354.0
# ..      ...     ...     ...   ...     ...
# 235  1888.0 -2163.0  1319.0        1044.0
# 236  1863.0 -2270.0  1300.0         893.0
# 237  1897.0 -2316.0  1289.0         870.0
# 238  1925.0 -2316.0  1301.0         910.0
# 239  1917.0 -2319.0  1300.0         898.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.15', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
#      EURCHF  CHFJPY  NZDCHF  EURGBP empty     sum
# 0     -60.0  -124.0  -210.0  -118.0        -512.0
# 1     -72.0    21.0  -192.0  -141.0        -384.0
# 2     -57.0    36.0  -222.0  -139.0        -382.0
# 3     -44.0   125.0  -174.0  -102.0        -195.0
# 4     -56.0   126.0  -218.0   -98.0        -246.0
# ..      ...     ...     ...     ...   ...     ...
# 235 -1151.0  -350.0 -1780.0   -56.0       -3337.0
# 236 -1122.0  -363.0 -1776.0   -65.0       -3326.0
# 237 -1117.0  -374.0 -1777.0   -78.0       -3346.0
# 238 -1123.0  -408.0 -1736.0   -81.0       -3348.0
# 239 -1103.0  -380.0 -1722.0   -86.0       -3291.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      NZDCHF  EURGBP  GBPJPY  EURCAD  EURNZD empty     sum
# 0     -27.0   -51.0     0.0  -229.0  -318.0        -625.0
# 1     -15.0  -111.0    74.0  -226.0  -385.0        -663.0
# 2     113.0   -92.0    74.0  -252.0  -375.0        -532.0
# 3     109.0   -97.0   174.0  -238.0  -466.0        -518.0
# 4     112.0  -123.0   198.0  -256.0  -487.0        -556.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235   136.0   249.0   202.0  -986.0  -204.0        -603.0
# 236    94.0   248.0   157.0 -1019.0  -297.0        -817.0
# 237    39.0   210.0    46.0 -1185.0  -455.0       -1345.0
# 238    39.0   207.0    37.0 -1215.0  -438.0       -1370.0
# 239    18.0   190.0    47.0 -1276.0  -454.0       -1475.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.29', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCAD  EURGBP  GBPCAD  GBPAUD  EURJPY  AUDJPY empty     sum
# 0     -35.0  -160.0     0.0     0.0   -22.0   -28.0        -245.0
# 1     -50.0  -167.0   -61.0   338.0    10.0   -19.0          51.0
# 2     -76.0  -169.0    67.0   224.0    -4.0    59.0         101.0
# 3     -55.0  -162.0   178.0    96.0    16.0   190.0         263.0
# 4     -52.0  -160.0   189.0   107.0    19.0   190.0         293.0
# ..      ...     ...     ...     ...     ...     ...   ...     ...
# 235  -741.0  -165.0  -232.0  1216.0  -821.0  -785.0       -1528.0
# 236  -689.0  -174.0  -228.0  1198.0  -818.0  -786.0       -1497.0
# 237  -689.0  -186.0  -209.0  1193.0  -783.0  -776.0       -1450.0
# 238  -873.0  -194.0  -164.0  1226.0  -794.0  -852.0       -1651.0
# 239  -907.0  -193.0   -23.0  1314.0  -816.0  -860.0       -1485.0
#
# [240 rows x 8 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.05', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
#      CHFJPY  EURGBP empty     sum
# 0     -25.0  -165.0        -190.0
# 1      37.0  -161.0        -124.0
# 2      38.0  -175.0        -137.0
# 3      64.0  -197.0        -133.0
# 4     102.0  -200.0         -98.0
# ..      ...     ...   ...     ...
# 235  1861.0  -524.0        1337.0
# 236  1887.0  -521.0        1366.0
# 237  1873.0  -482.0        1391.0
# 238  1855.0  -477.0        1378.0
# 239  1938.0  -480.0        1458.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.12', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      EURGBP  GBPJPY  EURCAD  EURNZD empty     sum
# 0      -2.0   -85.0  -120.0  -443.0        -650.0
# 1      19.0   -68.0  -169.0  -175.0        -393.0
# 2      18.0   -66.0  -129.0  -149.0        -326.0
# 3      14.0   161.0  -110.0  -169.0        -104.0
# 4      -5.0   116.0  -111.0  -182.0        -182.0
# ..      ...     ...     ...     ...   ...     ...
# 235   181.0  -749.0  1641.0     8.0        1081.0
# 236   188.0  -752.0  1646.0    -6.0        1076.0
# 237   174.0  -805.0  1587.0   -61.0         895.0
# 238   176.0  -803.0  1642.0   -58.0         957.0
# 239   169.0  -820.0  1657.0   -51.0         955.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.19', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCAD  EURJPY empty     sum
# 0       0.0  -211.0        -211.0
# 1       6.0  -196.0        -190.0
# 2       0.0  -163.0        -163.0
# 3     218.0    44.0         262.0
# 4     185.0    50.0         235.0
# ..      ...     ...   ...     ...
# 235  1762.0  1078.0        2840.0
# 236  1793.0  1111.0        2904.0
# 237  1688.0  1079.0        2767.0
# 238  1701.0  1078.0        2779.0
# 239  1692.0  1099.0        2791.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.26', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}]}
#      USDJPY  CHFJPY  EURGBP empty     sum
# 0       0.0     0.0  -129.0        -129.0
# 1      97.0   154.0  -135.0         116.0
# 2     123.0   253.0  -140.0         236.0
# 3     158.0   286.0  -142.0         302.0
# 4     140.0   269.0  -138.0         271.0
# ..      ...     ...     ...   ...     ...
# 235  2140.0  2908.0   416.0        5464.0
# 236  2126.0  3007.0   380.0        5513.0
# 237  2084.0  3013.0   400.0        5497.0
# 238  2102.0  3022.0   392.0        5516.0
# 239  2136.0  2980.0   401.0        5517.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.03', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
#      NZDCHF  EURGBP  GBPJPY  EURCAD  EURNZD empty    sum
# 0    -160.0   -49.0  -190.0  -230.0  -120.0       -749.0
# 1    -130.0   -64.0   -74.0  -268.0  -223.0       -759.0
# 2      60.0   -72.0    18.0  -223.0   105.0       -112.0
# 3     187.0   -47.0   231.0  -134.0   288.0        525.0
# 4     187.0   -37.0   225.0  -171.0   255.0        459.0
# ..      ...     ...     ...     ...     ...   ...    ...
# 235   186.0  -346.0 -1021.0  -604.0   975.0       -810.0
# 236   175.0  -369.0 -1031.0  -670.0   952.0       -943.0
# 237   246.0  -368.0 -1034.0  -713.0  1049.0       -820.0
# 238   216.0  -352.0  -972.0  -684.0   999.0       -793.0
# 239   209.0  -362.0  -963.0  -724.0   990.0       -850.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.10', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDCAD  EURJPY  CADJPY  AUDJPY  NZDJPY empty     sum
# 0     -45.0   -67.0   -53.0   -81.0   -23.0        -269.0
# 1     -36.0   -78.0   -23.0   -72.0   -27.0        -236.0
# 2     -87.0  -100.0   -78.0   -88.0    29.0        -324.0
# 3     -82.0     3.0   -21.0     8.0   109.0          17.0
# 4    -100.0    19.0    -7.0    -1.0    95.0           6.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235  -191.0  -503.0   228.0   837.0   415.0         786.0
# 236  -277.0  -537.0   169.0   863.0   467.0         685.0
# 237  -258.0  -519.0   180.0   873.0   490.0         766.0
# 238  -157.0  -453.0   273.0   952.0   568.0        1183.0
# 239  -208.0  -439.0   238.0   939.0   583.0        1113.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.17', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
#      USDJPY  CHFJPY  EURGBP  GBPJPY  CADJPY empty     sum
# 0      -8.0   -23.0   -28.0   -24.0   -25.0        -108.0
# 1       0.0   238.0   -22.0    57.0    43.0         316.0
# 2      -4.0   224.0   -27.0    19.0    17.0         229.0
# 3      65.0   284.0   -24.0   140.0    99.0         564.0
# 4      35.0   238.0    -8.0   113.0   107.0         485.0
# ..      ...     ...     ...     ...     ...   ...     ...
# 235  -785.0  -119.0 -1299.0 -3282.0 -1074.0       -6559.0
# 236  -780.0  -110.0 -1291.0 -3201.0 -1063.0       -6445.0
# 237  -764.0  -108.0 -1322.0 -3198.0 -1101.0       -6493.0
# 238  -764.0  -108.0 -1322.0 -3198.0 -1101.0       -6493.0
# 239  -764.0  -108.0 -1322.0 -3198.0 -1101.0       -6493.0
#
# [240 rows x 7 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.24', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
#      EURGBP  GBPJPY  EURNZD empty    sum
# 0     -29.0     0.0  -118.0       -147.0
# 1     -18.0   113.0  -144.0        -49.0
# 2     -59.0   150.0  -267.0       -176.0
# 3     -61.0   275.0  -339.0       -125.0
# 4     -66.0   187.0  -394.0       -273.0
# ..      ...     ...     ...   ...    ...
# 235   388.0    54.0   -94.0        348.0
# 236   386.0    20.0   -89.0        317.0
# 237   410.0    14.0   -58.0        366.0
# 238   412.0    22.0   -51.0        383.0
# 239   382.0   -23.0  -129.0        230.0
#
# [240 rows x 5 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.31', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}]}
#      USDJPY  USDCAD  EURCHF  EURJPY empty     sum
# 0       0.0  -111.0   -71.0   -44.0        -226.0
# 1      43.0  -158.0   -77.0     8.0        -184.0
# 2      12.0  -153.0   -79.0    -5.0        -225.0
# 3      73.0  -130.0   -64.0    37.0         -84.0
# 4      17.0  -201.0   -91.0    -7.0        -282.0
# ..      ...     ...     ...     ...   ...     ...
# 235     7.0 -1258.0   499.0 -1762.0       -2514.0
# 236    27.0 -1268.0   498.0 -1745.0       -2488.0
# 237    59.0 -1165.0   511.0 -1697.0       -2292.0
# 238    56.0 -1160.0   500.0 -1726.0       -2330.0
# 239    94.0 -1117.0   520.0 -1723.0       -2226.0
#
# [240 rows x 6 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.07', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}]}
#      EURUSD  USDJPY  EURCHF  CHFJPY  NZDCHF  EURGBP  EURCAD empty     sum
# 0      -9.0   -20.0   -49.0  -119.0   -85.0   -48.0   -52.0        -382.0
# 1      27.0    38.0   -76.0    79.0   -58.0   -70.0    -5.0         -65.0
# 2      31.0   102.0   -89.0    95.0   -26.0   -89.0   -59.0         -35.0
# 3     115.0   147.0   -57.0   145.0   -27.0   -69.0    -9.0         245.0
# 4       2.0   104.0   -74.0   169.0   -37.0   -90.0  -104.0         -30.0
# ..      ...     ...     ...     ...     ...     ...     ...   ...     ...
# 235  -335.0  -845.0   396.0   -31.0  2080.0 -1020.0 -2006.0       -1761.0
# 236  -308.0  -788.0   350.0   -38.0  2080.0  -993.0 -2047.0       -1744.0
# 237  -352.0  -827.0   373.0   -35.0  1969.0  -949.0 -2114.0       -1935.0
# 238  -405.0  -809.0   314.0  -357.0  1907.0 -1011.0 -2238.0       -2599.0
# 239  -405.0  -731.0   296.0  -154.0  1872.0 -1018.0 -2243.0       -2383.0
#
# [240 rows x 9 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
#      EURGBP  EURNZD empty     sum
# 0    -163.0  -860.0       -1023.0
# 1    -209.0  -832.0       -1041.0
# 2    -117.0  -588.0        -705.0
# 3     -18.0  -361.0        -379.0
# 4     -64.0  -362.0        -426.0
# ..      ...     ...   ...     ...
# 235  -859.0 -2502.0       -3361.0
# 236  -866.0 -2599.0       -3465.0
# 237  -826.0 -2482.0       -3308.0
# 238  -806.0 -2449.0       -3255.0
# 239  -833.0 -2524.0       -3357.0
#
# [240 rows x 4 columns]
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.21', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
