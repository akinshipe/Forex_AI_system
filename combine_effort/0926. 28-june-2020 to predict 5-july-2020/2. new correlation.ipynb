# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 18:27:34.547917

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.35286     USDJPY    0.30556     GBPUSD    0.49237
# 1      NZDCAD    0.32450     EURJPY    0.30208     AUDCAD    0.45833
# 2      USDCHF    0.28824     GBPUSD    0.27217     AUDUSD    0.45833
# 3      GBPUSD    0.28090     AUDNZD    0.25000     NZDUSD    0.40825
# 4      AUDCAD    0.24418     GBPCAD    0.19094     NZDCAD    0.38516
# 5      EURUSD    0.23775     AUDCAD    0.16477     USDJPY    0.37500
# 6      NZDUSD    0.23775     EURCAD    0.13608     CHFJPY    0.32824
# 7      CHFJPY    0.21627     CHFJPY    0.11111     EURJPY    0.32824
# 8      EURJPY    0.20064     USDCHF    0.11111     GBPCHF    0.28721
# 9      CADCHF    0.20064     EURGBP    0.10985     EURGBP    0.25678
# 10     AUDUSD    0.19485     EURNZD    0.08183     NZDJPY    0.25000
# 11     CADJPY    0.12039     AUDUSD    0.08183     EURAUD    0.25000
# 12     EURCAD    0.12039     NZDJPY    0.05648     USDCAD    0.20412
# 13     NZDJPY    0.09829     AUDCHF    0.05455     EURUSD    0.20412
# 14     NZDCHF    0.07711     EURUSD    0.05455     CADJPY    0.16667
# 15     GBPCHF    0.05366     GBPCHF    0.05455     EURNZD    0.16667
# 16     USDCAD    0.04670     NZDUSD    0.05455     AUDJPY    0.12309
# 17     EURGBP    0.04013     CADCHF    0.05455     USDCHF    0.12309
# 18     GBPJPY    0.04013     CADJPY    0.05455     AUDCHF    0.12309
# 19     GBPAUD    0.03382     AUDJPY    0.02778     GBPJPY    0.08206
# 20     EURAUD    0.03382     EURCHF    0.02778     NZDCHF    0.08206
# 21     GBPCAD    0.03382     EURAUD    0.02746     EURCHF    0.08206
# 22     AUDCHF    0.03382     GBPAUD    0.02746     AUDNZD    0.04167
# 23     AUDJPY    0.02764     NZDCHF    0.02746     EURCAD    0.00000
# 24     AUDNZD    0.01638     NZDCAD    0.02746     GBPAUD    0.00000
# 25     EURCHF    0.00970     GBPJPY    0.00000     GBPCAD    0.00000
# 26     EURNZD    0.00321     USDCAD    0.00000     CADCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPUSD    0.60010     NZDUSD    0.53452  ...     GBPCAD    0.39318
# 1      AUDCAD    0.57735     NZDJPY    0.42857  ...     GBPUSD    0.32660
# 2      AUDUSD    0.57735     AUDUSD    0.42857  ...     GBPCHF    0.29778
# 3      NZDCAD    0.49237     AUDCAD    0.42857  ...     USDJPY    0.28123
# 4      NZDUSD    0.49099     USDJPY    0.35635  ...     AUDUSD    0.26212
# 5      GBPCHF    0.49099     GBPUSD    0.35635  ...     EURGBP    0.24495
# 6      EURGBP    0.44444     GBPCHF    0.35635  ...     CADCHF    0.24495
# 7      USDJPY    0.44444     CADJPY    0.35635  ...     AUDCHF    0.22935
# 8      NZDJPY    0.38889     NZDCAD    0.32733  ...     EURUSD    0.21246
# 9      USDCAD    0.32733     GBPJPY    0.21822  ...     NZDCAD    0.19612
# 10     EURUSD    0.32733     EURGBP    0.21822  ...     AUDCAD    0.19612
# 11     GBPJPY    0.32733     USDCAD    0.21822  ...     EURCAD    0.16330
# 12     AUDCHF    0.28868     EURUSD    0.21822  ...     GBPJPY    0.16330
# 13     CADJPY    0.28868     GBPAUD    0.21822  ...     EURAUD    0.14744
# 14     EURAUD    0.28868     AUDJPY    0.08909  ...     GBPAUD    0.14744
# 15     EURJPY    0.21822     EURJPY    0.08909  ...     USDCHF    0.14744
# 16     AUDJPY    0.21822     EURNZD    0.08909  ...     AUDNZD    0.08333
# 17     USDCHF    0.21822     USDCHF    0.08909  ...     CADJPY    0.08165
# 18     NZDCHF    0.21822     GBPCAD    0.08909  ...     EURCHF    0.06580
# 19     CHFJPY    0.21822     NZDCHF    0.08909  ...     USDCAD    0.06553
# 20     EURCHF    0.21822     CADCHF    0.08909  ...     NZDCHF    0.04903
# 21     GBPAUD    0.16667     CHFJPY    0.08909  ...     EURNZD    0.04903
# 22     EURNZD    0.16667     EURCHF    0.08909  ...     NZDUSD    0.04903
# 23     AUDNZD    0.11111     AUDNZD    0.08909  ...     CHFJPY    0.03309
# 24     EURCAD    0.05455     EURCAD    0.04762  ...     AUDJPY    0.03309
# 25     GBPCAD    0.05455     EURAUD    0.04762  ...     EURJPY    0.00000
# 26     CADCHF    0.05455     AUDCHF    0.04762  ...     NZDJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.49099     USDJPY    0.53340     USDJPY    0.66667
# 1      GBPCAD    0.46371     EURGBP    0.45303     EURGBP    0.38889
# 2      EURGBP    0.43939     EURJPY    0.41414     GBPAUD    0.38889
# 3      USDJPY    0.38889     GBPCHF    0.41414     GBPCHF    0.32733
# 4      GBPUSD    0.27217     CHFJPY    0.41414     USDCHF    0.32733
# 5      CHFJPY    0.25000     GBPAUD    0.30151     EURCAD    0.21822
# 6      AUDNZD    0.25000     GBPCAD    0.30151     USDCAD    0.21822
# 7      NZDCAD    0.24716     AUDJPY    0.21212     EURCHF    0.21822
# 8      GBPAUD    0.24716     GBPUSD    0.21212     CHFJPY    0.21822
# 9      EURNZD    0.21822     AUDCHF    0.19192     NZDCHF    0.21822
# 10     AUDCHF    0.19094     USDCHF    0.19192     GBPUSD    0.21822
# 11     EURJPY    0.16477     NZDCAD    0.17911     AUDJPY    0.21822
# 12     NZDCHF    0.16477     EURNZD    0.12309     GBPCAD    0.21822
# 13     GBPJPY    0.13608     NZDJPY    0.12309     EURJPY    0.21822
# 14     EURCAD    0.13608     AUDNZD    0.12309     NZDCAD    0.12309
# 15     AUDJPY    0.11111     CADCHF    0.10050     AUDNZD    0.11111
# 16     EURCHF    0.11111     NZDUSD    0.10050     NZDJPY    0.11111
# 17     EURAUD    0.10985     USDCAD    0.10050     EURNZD    0.11111
# 18     AUDCAD    0.10985     EURCAD    0.10050     EURUSD    0.05455
# 19     NZDUSD    0.08183     EURUSD    0.10050     NZDUSD    0.05455
# 20     EURUSD    0.08183     AUDUSD    0.08206     GBPJPY    0.05455
# 21     NZDJPY    0.05648     EURAUD    0.08206     CADCHF    0.05455
# 22     CADJPY    0.05455     CADJPY    0.08206     EURAUD    0.00000
# 23     CADCHF    0.05455     AUDCAD    0.08206     CADJPY    0.00000
# 24     AUDUSD    0.05455     NZDCHF    0.01010     AUDCHF    0.00000
# 25     USDCHF    0.02778     EURCHF    0.01010     AUDCAD    0.00000
# 26     USDCAD    0.00000     GBPJPY    0.01010     AUDUSD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.81650
# 1      GBPAUD    0.50000
# 2      USDCHF    0.40825
# 3      EURCHF    0.40825
# 4      AUDJPY    0.40825
# 5      EURJPY    0.40825
# 6      NZDCHF    0.40825
# 7      CHFJPY    0.40825
# 8      AUDNZD    0.40825
# 9      EURCAD    0.21822
# 10     AUDCHF    0.21822
# 11     AUDCAD    0.21822
# 12     NZDJPY    0.21822
# 13     AUDUSD    0.21822
# 14     EURAUD    0.21822
# 15     GBPJPY    0.20000
# 16     USDCAD    0.20000
# 17     EURUSD    0.20000
# 18     CADJPY    0.00000
# 19     NZDCAD    0.00000
# 20     GBPCHF    0.00000
# 21     EURNZD    0.00000
# 22     CADCHF    0.00000
# 23     GBPCAD    0.00000
# 24     GBPUSD    0.00000
# 25     NZDUSD    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           1
