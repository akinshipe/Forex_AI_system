# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 14:45:40.952444

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.32450     USDJPY    0.30556     AUDCAD    0.53340
# 1      USDJPY    0.31366     AUDNZD    0.30208     EURJPY    0.41414
# 2      USDCHF    0.28824     EURJPY    0.30208     AUDUSD    0.41414
# 3      GBPUSD    0.24418     GBPUSD    0.21822     NZDUSD    0.39394
# 4      AUDCAD    0.24418     AUDCAD    0.21822     GBPUSD    0.39394
# 5      NZDUSD    0.23775     GBPCAD    0.19094     EURAUD    0.32824
# 6      EURJPY    0.23775     USDCHF    0.16477     NZDJPY    0.32824
# 7      EURUSD    0.23775     AUDUSD    0.13608     NZDCAD    0.32824
# 8      CHFJPY    0.21627     CHFJPY    0.11111     CHFJPY    0.30151
# 9      CADCHF    0.20064     EURCAD    0.08183     EURNZD    0.28721
# 10     AUDUSD    0.19485     NZDCAD    0.08183     USDJPY    0.28721
# 11     CADJPY    0.12039     EURNZD    0.08183     AUDCHF    0.21212
# 12     EURCAD    0.12039     EURAUD    0.08183     AUDJPY    0.21212
# 13     NZDJPY    0.09829     NZDJPY    0.05648     EURCHF    0.19192
# 14     USDCAD    0.08353     USDCAD    0.05455     NZDCHF    0.19192
# 15     NZDCHF    0.07711     EURUSD    0.05455     GBPCHF    0.19192
# 16     GBPJPY    0.07711     EURGBP    0.05455     CADJPY    0.19192
# 17     AUDNZD    0.05366     NZDUSD    0.05455     EURUSD    0.19192
# 18     GBPCHF    0.05366     EURCHF    0.02778     EURGBP    0.17911
# 19     EURGBP    0.04013     GBPAUD    0.02778     AUDNZD    0.12309
# 20     GBPAUD    0.03382     AUDJPY    0.02778     GBPAUD    0.10050
# 21     EURAUD    0.03382     NZDCHF    0.02746     USDCAD    0.10050
# 22     GBPCAD    0.03382     GBPJPY    0.00000     USDCHF    0.10050
# 23     AUDJPY    0.02764     CADJPY    0.00000     GBPJPY    0.08206
# 24     EURCHF    0.02764     AUDCHF    0.00000     EURCAD    0.01010
# 25     EURNZD    0.00321     CADCHF    0.00000     GBPCAD    0.01010
# 26     AUDCHF    0.00321     GBPCHF    0.00000     CADCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDCAD    0.49099     AUDCAD    0.53452  ...     GBPCAD    0.39318
# 1      AUDUSD    0.49099     AUDUSD    0.53452  ...     GBPCHF    0.29778
# 2      GBPUSD    0.46429     GBPUSD    0.40825  ...     AUDCHF    0.27783
# 3      NZDUSD    0.46429     NZDCAD    0.40825  ...     GBPUSD    0.27783
# 4      NZDCAD    0.37796     USDJPY    0.40825  ...     AUDUSD    0.26212
# 5      GBPCHF    0.33929     NZDUSD    0.40825  ...     EURGBP    0.24495
# 6      EURJPY    0.33929     GBPCHF    0.40825  ...     CADCHF    0.24495
# 7      CHFJPY    0.33929     EURGBP    0.35635  ...     USDJPY    0.23028
# 8      NZDJPY    0.33929     GBPAUD    0.35635  ...     EURUSD    0.21246
# 9      CADJPY    0.32733     NZDJPY    0.25000  ...     GBPJPY    0.21246
# 10     GBPJPY    0.32733     AUDNZD    0.25000  ...     NZDCAD    0.19612
# 11     EURGBP    0.32733     CADCHF    0.16667  ...     AUDCAD    0.19612
# 12     USDJPY    0.32733     GBPJPY    0.16667  ...     EURCAD    0.16330
# 13     EURUSD    0.32733     GBPCAD    0.16667  ...     EURAUD    0.14744
# 14     AUDCHF    0.21822     EURCAD    0.16667  ...     GBPAUD    0.14744
# 15     EURAUD    0.21822     CADJPY    0.16667  ...     USDCHF    0.14744
# 16     AUDJPY    0.19643     EURUSD    0.16667  ...     EURCHF    0.11580
# 17     USDCHF    0.19643     AUDCHF    0.08909  ...     USDCAD    0.11440
# 18     GBPAUD    0.19643     EURAUD    0.08909  ...     CADJPY    0.08165
# 19     NZDCHF    0.19643     EURNZD    0.08909  ...     NZDCHF    0.04903
# 20     EURCHF    0.19643     NZDCHF    0.00000  ...     EURJPY    0.04903
# 21     USDCAD    0.19643     CHFJPY    0.00000  ...     EURNZD    0.04903
# 22     EURNZD    0.18898     EURJPY    0.00000  ...     NZDUSD    0.04903
# 23     EURCAD    0.07143     AUDJPY    0.00000  ...     CHFJPY    0.03309
# 24     AUDNZD    0.07143     EURCHF    0.00000  ...     AUDJPY    0.03309
# 25     GBPCAD    0.05455     USDCAD    0.00000  ...     AUDNZD    0.03309
# 26     CADCHF    0.05455     USDCHF    0.00000  ...     NZDJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.46371     USDJPY    0.45833     USDJPY    0.66667
# 1      GBPCHF    0.40825     CHFJPY    0.40825     USDCHF    0.49099
# 2      USDJPY    0.38889     EURGBP    0.38516     GBPCAD    0.38889
# 3      EURGBP    0.35460     EURJPY    0.32824     EURGBP    0.38889
# 4      NZDCAD    0.32733     GBPCAD    0.32824     GBPCHF    0.32733
# 5      AUDCHF    0.27217     GBPCHF    0.32824     NZDCAD    0.28868
# 6      CHFJPY    0.25000     AUDCHF    0.28721     EURNZD    0.28868
# 7      EURNZD    0.21822     EURNZD    0.25000     USDCAD    0.21822
# 8      EURCAD    0.21822     GBPAUD    0.20412     NZDUSD    0.21822
# 9      AUDCAD    0.19094     USDCHF    0.20412     CHFJPY    0.21822
# 10     EURAUD    0.19094     NZDCAD    0.16667     GBPUSD    0.21822
# 11     GBPUSD    0.19094     AUDCAD    0.16667     GBPAUD    0.21822
# 12     GBPAUD    0.16667     EURAUD    0.16667     EURJPY    0.21822
# 13     EURJPY    0.16477     NZDCHF    0.12309     EURAUD    0.16667
# 14     AUDNZD    0.16477     GBPUSD    0.12309     AUDCAD    0.16667
# 15     NZDCHF    0.16477     NZDUSD    0.12309     AUDCHF    0.16667
# 16     GBPJPY    0.13608     AUDJPY    0.12309     CADJPY    0.16667
# 17     CADCHF    0.13608     EURCHF    0.12309     AUDUSD    0.16667
# 18     AUDUSD    0.13608     CADCHF    0.08206     EURUSD    0.11111
# 19     CADJPY    0.13608     CADJPY    0.08206     GBPJPY    0.11111
# 20     EURCHF    0.11111     EURCAD    0.08206     CADCHF    0.11111
# 21     AUDJPY    0.11111     EURUSD    0.08206     EURCAD    0.05455
# 22     USDCHF    0.10985     AUDUSD    0.08206     NZDCHF    0.05455
# 23     NZDUSD    0.08183     NZDJPY    0.04167     AUDJPY    0.05455
# 24     USDCAD    0.08183     GBPJPY    0.04167     NZDJPY    0.05455
# 25     EURUSD    0.08183     AUDNZD    0.04167     EURCHF    0.05455
# 26     NZDJPY    0.05648     USDCAD    0.00000     AUDNZD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.81650
# 1      GBPAUD    0.53452
# 2      USDCHF    0.40825
# 3      NZDCHF    0.40825
# 4      AUDJPY    0.40825
# 5      EURJPY    0.40825
# 6      EURCHF    0.40825
# 7      CHFJPY    0.40825
# 8      NZDJPY    0.25000
# 9      EURCAD    0.25000
# 10     GBPCAD    0.25000
# 11     AUDNZD    0.25000
# 12     CADCHF    0.25000
# 13     GBPJPY    0.16667
# 14     CADJPY    0.16667
# 15     EURUSD    0.16667
# 16     NZDCAD    0.10206
# 17     AUDCHF    0.08909
# 18     AUDUSD    0.08909
# 19     EURAUD    0.08909
# 20     EURNZD    0.08909
# 21     AUDCAD    0.08909
# 22     EURGBP    0.08909
# 23     GBPUSD    0.00000
# 24     GBPCHF    0.00000
# 25     NZDUSD    0.00000
# 26     USDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           1
