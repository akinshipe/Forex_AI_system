# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 10:56:28.462742

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.36218     USDJPY    0.46371     USDJPY    0.40825
# 1      USDJPY    0.35955     USDCHF    0.20536     AUDCAD    0.40825
# 2      USDCHF    0.32026     AUDNZD    0.20536     EURJPY    0.40825
# 3      AUDCAD    0.24418     GBPCAD    0.19643     USDCHF    0.30151
# 4      EURJPY    0.24019     AUDJPY    0.19094     GBPUSD    0.30151
# 5      NZDUSD    0.24019     NZDCAD    0.14382     AUDUSD    0.30151
# 6      CHFJPY    0.21246     AUDCAD    0.14382     NZDUSD    0.30151
# 7      GBPUSD    0.20192     GBPUSD    0.14382     EURAUD    0.30151
# 8      EURUSD    0.19872     EURJPY    0.14382     CHFJPY    0.30151
# 9      CADCHF    0.19872     CADJPY    0.13363     NZDCAD    0.20412
# 10     AUDUSD    0.19872     NZDUSD    0.07143     NZDJPY    0.20412
# 11     CADJPY    0.15743     EURNZD    0.06250     AUDNZD    0.20412
# 12     EURCAD    0.11859     GBPJPY    0.06250     AUDCHF    0.20000
# 13     NZDJPY    0.09237     USDCAD    0.06250     EURUSD    0.20000
# 14     USDCAD    0.08006     GBPAUD    0.05455     GBPJPY    0.10050
# 15     GBPJPY    0.08006     NZDJPY    0.04725     GBPAUD    0.10050
# 16     NZDCHF    0.04167     CHFJPY    0.01849     EURCHF    0.10050
# 17     GBPCAD    0.03846     GBPCHF    0.00899     EURNZD    0.10050
# 18     GBPAUD    0.03846     EURCHF    0.00899     CADJPY    0.10050
# 19     EURNZD    0.03846     EURUSD    0.00000     AUDJPY    0.10050
# 20     EURAUD    0.03548     EURAUD    0.00000     GBPCHF    0.10050
# 21     GBPCHF    0.03269     EURCAD    0.00000     USDCAD    0.10050
# 22     AUDJPY    0.03269     NZDCHF    0.00000     EURGBP    0.10050
# 23     AUDNZD    0.00649     AUDCHF    0.00000     NZDCHF    0.00000
# 24     AUDCHF    0.00321     CADCHF    0.00000     GBPCAD    0.00000
# 25     EURCHF    0.00321     AUDUSD    0.00000     CADCHF    0.00000
# 26     EURGBP    0.00000     EURGBP    0.00000     EURCAD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDJPY    0.49099     USDJPY    0.65465  ...     GBPCAD    0.39906
# 1      NZDCAD    0.47246     NZDCAD    0.50000  ...     AUDUSD    0.33092
# 2      AUDUSD    0.47246     AUDCAD    0.50000  ...     GBPUSD    0.31795
# 3      AUDCAD    0.47246     AUDUSD    0.50000  ...     GBPCHF    0.29778
# 4      NZDUSD    0.46429     USDCHF    0.40825  ...     EURGBP    0.28365
# 5      GBPUSD    0.46429     NZDUSD    0.40825  ...     GBPJPY    0.28365
# 6      USDCHF    0.33929     GBPUSD    0.40825  ...     AUDCAD    0.27156
# 7      USDCAD    0.33929     AUDCHF    0.21822  ...     AUDCHF    0.27156
# 8      EURJPY    0.32733     NZDJPY    0.21822  ...     EURUSD    0.24982
# 9      NZDJPY    0.32733     EURAUD    0.21822  ...     CADCHF    0.24982
# 10     CHFJPY    0.32733     GBPAUD    0.21822  ...     NZDCAD    0.23684
# 11     EURAUD    0.32733     AUDNZD    0.21822  ...     USDJPY    0.19852
# 12     CADJPY    0.21822     CADCHF    0.21822  ...     EURCAD    0.16871
# 13     EURNZD    0.21822     GBPCHF    0.21822  ...     GBPAUD    0.15573
# 14     EURGBP    0.21822     GBPJPY    0.20000  ...     EURAUD    0.14368
# 15     GBPJPY    0.21822     EURCAD    0.20000  ...     EURCHF    0.13497
# 16     AUDCHF    0.19643     CADJPY    0.20000  ...     EURJPY    0.12157
# 17     AUDJPY    0.19643     USDCAD    0.20000  ...     USDCHF    0.12157
# 18     GBPCHF    0.19643     EURUSD    0.20000  ...     NZDUSD    0.12157
# 19     EURUSD    0.19643     EURGBP    0.20000  ...     USDCAD    0.12157
# 20     AUDNZD    0.19643     NZDCHF    0.00000  ...     NZDJPY    0.08515
# 21     GBPCAD    0.07143     GBPCAD    0.00000  ...     NZDCHF    0.07462
# 22     GBPAUD    0.07143     CHFJPY    0.00000  ...     EURNZD    0.07462
# 23     EURCAD    0.07143     EURJPY    0.00000  ...     AUDNZD    0.06732
# 24     NZDCHF    0.07143     EURCHF    0.00000  ...     CADJPY    0.05366
# 25     CADCHF    0.07143     EURNZD    0.00000  ...     CHFJPY    0.04963
# 26     EURCHF    0.07143     AUDJPY    0.00000  ...     AUDJPY    0.04963
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.46429     EURGBP    0.53340     EURGBP    0.49099
# 1      EURGBP    0.40089     GBPCHF    0.49237     USDJPY    0.49099
# 2      GBPCHF    0.39551     USDJPY    0.45833     GBPCHF    0.46429
# 3      AUDUSD    0.26726     GBPCAD    0.40825     GBPAUD    0.33929
# 4      EURAUD    0.26726     EURNZD    0.32824     GBPCAD    0.33929
# 5      AUDCHF    0.26726     CHFJPY    0.32824     USDCHF    0.33929
# 6      GBPUSD    0.26068     GBPAUD    0.28721     EURNZD    0.21822
# 7      NZDCAD    0.26068     GBPUSD    0.28721     CHFJPY    0.21822
# 8      AUDCAD    0.26068     EURJPY    0.25000     EURJPY    0.21822
# 9      USDJPY    0.21822     AUDCHF    0.20412     GBPJPY    0.21822
# 10     EURNZD    0.19643     NZDCHF    0.20412     NZDUSD    0.19643
# 11     GBPJPY    0.19643     NZDCAD    0.16667     GBPUSD    0.19643
# 12     GBPAUD    0.19094     AUDCAD    0.16667     EURUSD    0.19643
# 13     CHFJPY    0.15714     AUDJPY    0.12309     AUDCHF    0.19643
# 14     EURCHF    0.14382     USDCHF    0.12309     EURCHF    0.19643
# 15     NZDCHF    0.13363     GBPJPY    0.12309     AUDUSD    0.18898
# 16     CADCHF    0.13363     EURCHF    0.12309     AUDCAD    0.18898
# 17     EURUSD    0.13363     NZDUSD    0.12309     NZDCAD    0.18898
# 18     EURCAD    0.13363     EURAUD    0.08206     NZDCHF    0.07143
# 19     AUDNZD    0.07143     CADJPY    0.08206     USDCAD    0.07143
# 20     USDCAD    0.07143     AUDUSD    0.08206     CADCHF    0.07143
# 21     NZDUSD    0.06250     USDCAD    0.08206     EURCAD    0.07143
# 22     USDCHF    0.06250     NZDJPY    0.04167     AUDJPY    0.07143
# 23     AUDJPY    0.05455     AUDNZD    0.04167     AUDNZD    0.07143
# 24     NZDJPY    0.04725     CADCHF    0.00000     EURAUD    0.05455
# 25     EURJPY    0.00899     EURCAD    0.00000     CADJPY    0.05455
# 26     CADJPY    0.00000     EURUSD    0.00000     NZDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.53452
# 1      GBPAUD    0.53452
# 2      EURGBP    0.40825
# 3      EURCAD    0.40825
# 4      GBPCHF    0.35635
# 5      NZDCHF    0.25000
# 6      AUDJPY    0.25000
# 7      EURNZD    0.25000
# 8      EURJPY    0.25000
# 9      GBPCAD    0.25000
# 10     USDCHF    0.25000
# 11     CHFJPY    0.25000
# 12     EURCHF    0.25000
# 13     GBPUSD    0.16667
# 14     NZDUSD    0.16667
# 15     AUDUSD    0.10206
# 16     AUDCAD    0.10206
# 17     NZDCAD    0.10206
# 18     AUDCHF    0.08909
# 19     CADCHF    0.08909
# 20     EURAUD    0.08909
# 21     NZDJPY    0.08909
# 22     AUDNZD    0.08909
# 23     GBPJPY    0.00000
# 24     USDCAD    0.00000
# 25     CADJPY    0.00000
# 26     EURUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
