# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:52:39.962032

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.31127     NZDCAD    0.40089     NZDCAD    0.50252
# 1      GBPJPY    0.27146     EURUSD    0.33036     AUDCAD    0.40825
# 2      EURUSD    0.25223     AUDCAD    0.27866     EURUSD    0.40825
# 3      GBPCHF    0.22935     GBPJPY    0.27866     USDJPY    0.34641
# 4      CADJPY    0.22740     GBPCHF    0.26726     EURCHF    0.31449
# 5      NZDCAD    0.19025     EURCAD    0.26726     EURCAD    0.30151
# 6      EURCAD    0.17138     GBPUSD    0.26726     USDCAD    0.30151
# 7      EURAUD    0.12721     NZDUSD    0.20536     NZDUSD    0.30151
# 8      EURCHF    0.12039     EURNZD    0.19094     GBPJPY    0.30151
# 9      GBPUSD    0.10895     GBPCAD    0.15714     GBPUSD    0.30151
# 10     AUDCAD    0.10895     NZDCHF    0.14382     AUDNZD    0.21822
# 11     USDJPY    0.10701     AUDNZD    0.14382     EURNZD    0.20412
# 12     CHFJPY    0.10417     CADJPY    0.14382     EURJPY    0.20412
# 13     NZDUSD    0.10417     AUDUSD    0.13363     CHFJPY    0.20412
# 14     AUDUSD    0.09054     EURCHF    0.12016     GBPCHF    0.20000
# 15     NZDCHF    0.06019     USDJPY    0.12016     CADCHF    0.10483
# 16     GBPCAD    0.06019     CADCHF    0.08183     NZDCHF    0.10483
# 17     AUDCHF    0.05366     EURAUD    0.07143     NZDJPY    0.10483
# 18     USDCHF    0.04670     USDCHF    0.07143     AUDJPY    0.10050
# 19     GBPAUD    0.04013     EURJPY    0.07143     USDCHF    0.10050
# 20     AUDNZD    0.03382     USDCAD    0.07143     GBPAUD    0.10050
# 21     USDCAD    0.03382     EURGBP    0.07143     EURGBP    0.10050
# 22     CADCHF    0.03097     GBPAUD    0.06250     EURAUD    0.00000
# 23     AUDJPY    0.01638     AUDCHF    0.06250     CADJPY    0.00000
# 24     EURGBP    0.00970     AUDJPY    0.06250     GBPCAD    0.00000
# 25     NZDJPY    0.00876     NZDJPY    0.01849     AUDCHF    0.00000
# 26     EURNZD    0.00321     CHFJPY    0.01849     AUDUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURCHF    0.47246     GBPJPY    0.53452  ...     USDCHF    0.19485
# 1      AUDNZD    0.37796     AUDNZD    0.40825  ...     AUDNZD    0.19485
# 2      GBPJPY    0.37796     USDCAD    0.40825  ...     GBPCAD    0.19061
# 3      USDJPY    0.34247     EURJPY    0.40825  ...     GBPCHF    0.18021
# 4      USDCAD    0.33929     AUDCHF    0.35635  ...     EURUSD    0.15198
# 5      NZDCAD    0.33929     EURCAD    0.35635  ...     AUDJPY    0.14744
# 6      GBPCHF    0.33929     AUDUSD    0.35635  ...     GBPUSD    0.13497
# 7      EURUSD    0.32733     EURCHF    0.35635  ...     AUDCAD    0.13497
# 8      CHFJPY    0.32733     NZDCAD    0.25000  ...     NZDJPY    0.09632
# 9      EURCAD    0.32733     GBPCHF    0.25000  ...     EURGBP    0.09054
# 10     NZDUSD    0.21822     USDCHF    0.16667  ...     GBPJPY    0.07881
# 11     AUDCAD    0.21822     CHFJPY    0.16667  ...     EURCAD    0.07114
# 12     EURJPY    0.19643     NZDUSD    0.16667  ...     EURJPY    0.06553
# 13     GBPUSD    0.19643     EURUSD    0.16667  ...     NZDUSD    0.06118
# 14     AUDJPY    0.18898     EURGBP    0.16667  ...     NZDCHF    0.06019
# 15     NZDJPY    0.09449     GBPAUD    0.10206  ...     USDJPY    0.06019
# 16     GBPAUD    0.09449     USDJPY    0.10206  ...     CADJPY    0.06019
# 17     NZDCHF    0.09449     EURAUD    0.10206  ...     CADCHF    0.05506
# 18     CADJPY    0.09449     AUDJPY    0.10206  ...     AUDCHF    0.05366
# 19     CADCHF    0.09449     CADCHF    0.08909  ...     NZDCAD    0.05366
# 20     USDCHF    0.07143     NZDCHF    0.08909  ...     USDCAD    0.04670
# 21     GBPCAD    0.07143     CADJPY    0.08909  ...     EURCHF    0.04013
# 22     EURGBP    0.07143     NZDJPY    0.08909  ...     GBPAUD    0.04013
# 23     EURNZD    0.05455     AUDCAD    0.08909  ...     EURAUD    0.03382
# 24     EURAUD    0.05455     GBPUSD    0.00000  ...     CHFJPY    0.02150
# 25     AUDCHF    0.05455     GBPCAD    0.00000  ...     AUDUSD    0.00970
# 26     AUDUSD    0.05455     EURNZD    0.00000  ...     EURNZD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDUSD    0.32733     NZDUSD    0.50443     NZDUSD    0.57735
# 1      NZDCAD    0.27217     USDCAD    0.37284     USDCAD    0.47246
# 2      GBPCHF    0.27217     GBPUSD    0.37284     AUDNZD    0.40000
# 3      GBPUSD    0.27217     EURJPY    0.31180     NZDJPY    0.40000
# 4      EURNZD    0.25000     EURUSD    0.31180     CADJPY    0.40000
# 5      GBPJPY    0.24716     EURNZD    0.31180     GBPJPY    0.40000
# 6      AUDCAD    0.24716     AUDNZD    0.28571     EURJPY    0.37796
# 7      EURUSD    0.21822     NZDCAD    0.28511     GBPUSD    0.37796
# 8      AUDCHF    0.21822     GBPJPY    0.28511     EURUSD    0.28868
# 9      USDCHF    0.19094     EURCHF    0.25163     AUDUSD    0.28868
# 10     USDCAD    0.19094     AUDUSD    0.21822     CHFJPY    0.28868
# 11     AUDUSD    0.13608     GBPCHF    0.21822     AUDCHF    0.28868
# 12     EURCAD    0.13608     AUDCHF    0.21822     EURNZD    0.28868
# 13     CADJPY    0.10985     NZDJPY    0.20588     EURCHF    0.20000
# 14     AUDNZD    0.10985     EURCAD    0.15352     NZDCAD    0.18898
# 15     NZDCHF    0.10985     USDCHF    0.15352     EURGBP    0.18898
# 16     GBPCAD    0.08472     EURGBP    0.15352     GBPCHF    0.18898
# 17     CHFJPY    0.08472     CADJPY    0.13363     USDJPY    0.10660
# 18     NZDJPY    0.08472     CHFJPY    0.13363     GBPAUD    0.10000
# 19     EURAUD    0.08183     AUDCAD    0.13363     NZDCHF    0.10000
# 20     EURCHF    0.05648     USDJPY    0.12599     CADCHF    0.10000
# 21     USDJPY    0.05648     GBPCAD    0.08909     AUDJPY    0.10000
# 22     GBPAUD    0.05455     GBPAUD    0.06580     GBPCAD    0.09449
# 23     EURJPY    0.05455     AUDJPY    0.06580     USDCHF    0.09449
# 24     AUDJPY    0.05455     NZDCHF    0.02288     EURCAD    0.00000
# 25     EURGBP    0.05455     CADCHF    0.02288     EURAUD    0.00000
# 26     CADCHF    0.02778     EURAUD    0.00000     AUDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDUSD    0.81650
# 1      NZDJPY    0.65465
# 2      AUDUSD    0.65465
# 3      CADJPY    0.65465
# 4      AUDCHF    0.65465
# 5      GBPJPY    0.65465
# 6      USDCAD    0.60000
# 7      EURNZD    0.60000
# 8      EURJPY    0.60000
# 9      GBPUSD    0.60000
# 10     GBPAUD    0.50000
# 11     AUDJPY    0.50000
# 12     EURAUD    0.50000
# 13     USDCHF    0.40825
# 14     NZDCAD    0.40825
# 15     EURGBP    0.40825
# 16     CHFJPY    0.40825
# 17     GBPCHF    0.40825
# 18     EURUSD    0.40825
# 19     NZDCHF    0.21822
# 20     EURCAD    0.21822
# 21     CADCHF    0.21822
# 22     EURCHF    0.21822
# 23     AUDCAD    0.21822
# 24     GBPCAD    0.20000
# 25     AUDNZD    0.20000
# 26     USDJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
