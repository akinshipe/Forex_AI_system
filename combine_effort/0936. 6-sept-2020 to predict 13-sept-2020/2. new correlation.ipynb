# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:27:31.692475

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.29778     GBPUSD    0.37796     AUDUSD    0.33333
# 1      NZDCAD    0.26212     AUDUSD    0.35000     NZDUSD    0.29013
# 2      GBPUSD    0.23028     NZDCAD    0.33296     GBPUSD    0.29013
# 3      NZDUSD    0.18021     CHFJPY    0.28868     CADJPY    0.23570
# 4      USDCHF    0.16667     NZDUSD    0.28284     NZDCAD    0.23570
# 5      AUDCAD    0.14804     AUDCAD    0.24456     NZDJPY    0.23570
# 6      CHFJPY    0.13457     USDJPY    0.23783     GBPJPY    0.23570
# 7      AUDCHF    0.13234     EURAUD    0.23623     AUDJPY    0.18157
# 8      CADJPY    0.09869     EURJPY    0.20000     CHFJPY    0.18157
# 9      EURJPY    0.08333     NZDJPY    0.19026     USDCAD    0.18157
# 10     NZDJPY    0.08333     EURUSD    0.14434     EURUSD    0.18157
# 11     EURCHF    0.08165     USDCAD    0.14434     USDJPY    0.17408
# 12     CADCHF    0.08165     AUDJPY    0.14434     EURCHF    0.12599
# 13     EURCAD    0.08165     GBPCHF    0.14142     AUDCHF    0.12599
# 14     AUDNZD    0.06580     USDCHF    0.09782     AUDCAD    0.12599
# 15     AUDUSD    0.06580     EURNZD    0.09513     USDCHF    0.12599
# 16     EURUSD    0.06580     EURGBP    0.09513     GBPCHF    0.11547
# 17     GBPCAD    0.06553     GBPAUD    0.09513     EURJPY    0.06667
# 18     GBPAUD    0.04963     GBPJPY    0.09449     EURNZD    0.05803
# 19     USDCAD    0.04963     CADJPY    0.09449     AUDNZD    0.05803
# 20     NZDCHF    0.04903     EURCHF    0.04757     EURAUD    0.05803
# 21     AUDJPY    0.03364     AUDNZD    0.04757     GBPAUD    0.05803
# 22     GBPCHF    0.03309     NZDCHF    0.04725     GBPCAD    0.05803
# 23     EURAUD    0.03269     EURCAD    0.00000     NZDCHF    0.05803
# 24     GBPJPY    0.01638     GBPCAD    0.00000     CADCHF    0.05803
# 25     EURNZD    0.00000     AUDCHF    0.00000     EURCAD    0.00000
# 26     EURGBP    0.00000     CADCHF    0.00000     EURGBP    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPUSD    0.40825     AUDJPY    0.32733  ...     GBPCAD    0.35286
# 1      CHFJPY    0.35355     CHFJPY    0.32733  ...     GBPCHF    0.26108
# 2      CADJPY    0.35355     GBPUSD    0.32733  ...     USDJPY    0.23153
# 3      GBPJPY    0.35355     GBPJPY    0.32733  ...     AUDUSD    0.22531
# 4      AUDJPY    0.35355     USDCHF    0.25000  ...     AUDCAD    0.22531
# 5      EURUSD    0.30151     EURUSD    0.25000  ...     EURGBP    0.20261
# 6      USDCAD    0.30151     USDCAD    0.25000  ...     EURCHF    0.20261
# 7      AUDUSD    0.30151     AUDUSD    0.25000  ...     EURCAD    0.20261
# 8      EURCHF    0.30151     EURCHF    0.25000  ...     CADCHF    0.20261
# 9      USDCHF    0.25000     CADJPY    0.25000  ...     AUDCHF    0.17898
# 10     EURJPY    0.25000     GBPAUD    0.21822  ...     GBPAUD    0.17898
# 11     GBPCAD    0.20045     AUDCAD    0.21822  ...     CHFJPY    0.16530
# 12     GBPAUD    0.20045     AUDCHF    0.21822  ...     GBPUSD    0.14368
# 13     EURCAD    0.13363     EURJPY    0.16667  ...     EURUSD    0.14368
# 14     EURNZD    0.13363     NZDCAD    0.10206  ...     NZDCAD    0.10895
# 15     EURAUD    0.13363     EURAUD    0.10206  ...     GBPJPY    0.10895
# 16     NZDJPY    0.13363     EURGBP    0.10206  ...     AUDJPY    0.08181
# 17     NZDCAD    0.13363     GBPCHF    0.10206  ...     USDCAD    0.06732
# 18     EURGBP    0.13363     GBPCAD    0.00000  ...     AUDNZD    0.06204
# 19     NZDCHF    0.13363     EURCAD    0.00000  ...     EURJPY    0.04963
# 20     CADCHF    0.13363     NZDCHF    0.00000  ...     USDCHF    0.04963
# 21     GBPCHF    0.13363     EURNZD    0.00000  ...     EURNZD    0.04052
# 22     NZDUSD    0.13363     CADCHF    0.00000  ...     NZDJPY    0.03309
# 23     USDJPY    0.13363     NZDJPY    0.00000  ...     NZDUSD    0.02764
# 24     AUDNZD    0.13363     NZDUSD    0.00000  ...     CADJPY    0.01959
# 25     AUDCHF    0.07538     USDJPY    0.00000  ...     EURAUD    0.00649
# 26     AUDCAD    0.00000     AUDNZD    0.00000  ...     NZDCHF    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.35747     EURAUD    0.41414     EURAUD    0.60714
# 1      CHFJPY    0.30208     USDJPY    0.41414     NZDCHF    0.60714
# 2      EURGBP    0.22172     NZDCHF    0.41414     GBPUSD    0.49099
# 3      GBPCAD    0.20180     USDCHF    0.28511     EURNZD    0.46429
# 4      GBPCHF    0.20180     CHFJPY    0.24232     AUDJPY    0.37796
# 5      EURJPY    0.19026     AUDJPY    0.24232     GBPJPY    0.37796
# 6      GBPAUD    0.18552     GBPUSD    0.21212     CHFJPY    0.37796
# 7      EURCHF    0.18552     CADCHF    0.21212     GBPCHF    0.33929
# 8      AUDCAD    0.17216     GBPAUD    0.21212     NZDCAD    0.33929
# 9      USDCHF    0.17216     EURNZD    0.19192     NZDUSD    0.33929
# 10     AUDJPY    0.16477     AUDCHF    0.15352     CADCHF    0.33929
# 11     EURAUD    0.14382     NZDJPY    0.12309     USDJPY    0.33929
# 12     NZDCHF    0.12585     GBPJPY    0.12309     NZDJPY    0.33929
# 13     AUDCHF    0.10985     NZDCAD    0.12309     AUDCHF    0.26189
# 14     AUDUSD    0.09513     GBPCHF    0.10050     AUDUSD    0.26189
# 15     NZDJPY    0.08597     EURCAD    0.08206     USDCAD    0.26189
# 16     CADCHF    0.06727     CADJPY    0.08206     EURUSD    0.26189
# 17     EURCAD    0.06727     EURGBP    0.08206     USDCHF    0.20045
# 18     NZDUSD    0.06727     EURCHF    0.06580     EURGBP    0.19643
# 19     EURNZD    0.04977     AUDCAD    0.06580     EURCAD    0.19643
# 20     NZDCAD    0.04977     EURJPY    0.05803     GBPAUD    0.19643
# 21     AUDNZD    0.04977     AUDUSD    0.05803     AUDNZD    0.19643
# 22     USDCAD    0.02746     USDCAD    0.03161     EURJPY    0.13363
# 23     EURUSD    0.02746     EURUSD    0.03161     CADJPY    0.09449
# 24     CADJPY    0.00899     GBPCAD    0.01010     AUDCAD    0.09449
# 25     GBPJPY    0.00899     NZDUSD    0.01010     GBPCAD    0.07143
# 26     GBPUSD    0.00899     AUDNZD    0.01010     EURCHF    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCHF    0.61237
# 1      EURAUD    0.58333
# 2      GBPUSD    0.53452
# 3      AUDNZD    0.40825
# 4      NZDCHF    0.40825
# 5      EURNZD    0.40825
# 6      USDCAD    0.40825
# 7      EURCAD    0.40825
# 8      EURJPY    0.40825
# 9      CADCHF    0.40825
# 10     AUDCAD    0.35635
# 11     EURGBP    0.25000
# 12     GBPCHF    0.25000
# 13     NZDCAD    0.16667
# 14     AUDUSD    0.10206
# 15     CADJPY    0.10206
# 16     EURUSD    0.10206
# 17     USDCHF    0.10206
# 18     AUDCHF    0.08909
# 19     CHFJPY    0.08909
# 20     GBPJPY    0.08909
# 21     GBPAUD    0.08909
# 22     AUDJPY    0.08909
# 23     GBPCAD    0.00000
# 24     NZDUSD    0.00000
# 25     USDJPY    0.00000
# 26     NZDJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
