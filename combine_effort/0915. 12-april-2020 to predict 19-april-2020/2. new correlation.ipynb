# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-12 08:53:02.594508

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.31366     NZDCAD    0.33333     USDJPY    0.39394
# 1      USDCHF    0.28824     USDJPY    0.27217     CADJPY    0.30151
# 2      USDJPY    0.28090     USDCHF    0.26726     AUDJPY    0.28721
# 3      NZDCAD    0.27536     AUDCAD    0.26726     GBPCAD    0.28721
# 4      CHFJPY    0.25223     EURCAD    0.26726     AUDUSD    0.24232
# 5      EURUSD    0.23775     EURJPY    0.26726     EURJPY    0.21212
# 6      NZDUSD    0.23282     CHFJPY    0.20751     AUDNZD    0.19192
# 7      AUDCAD    0.19485     USDCAD    0.20180     GBPJPY    0.19192
# 8      GBPUSD    0.19485     CADJPY    0.20180     USDCAD    0.19192
# 9      AUDUSD    0.19025     GBPUSD    0.20180     NZDJPY    0.17911
# 10     NZDJPY    0.16386     GBPAUD    0.14142     GBPAUD    0.17408
# 11     EURCAD    0.12039     EURUSD    0.13363     EURAUD    0.12309
# 12     GBPAUD    0.11433     NZDUSD    0.13363     USDCHF    0.12309
# 13     NZDCHF    0.11433     CADCHF    0.13363     AUDCHF    0.12309
# 14     GBPJPY    0.11433     NZDJPY    0.06917     EURCAD    0.10050
# 15     EURCHF    0.10895     AUDJPY    0.06917     GBPCHF    0.10050
# 16     EURGBP    0.09054     EURGBP    0.06727     NZDUSD    0.10050
# 17     CADCHF    0.09054     AUDUSD    0.06727     EURUSD    0.10050
# 18     GBPCAD    0.08353     EURAUD    0.06667     EURGBP    0.10050
# 19     CADJPY    0.08353     NZDCHF    0.06667     CADCHF    0.08206
# 20     GBPCHF    0.07711     AUDCHF    0.06667     EURNZD    0.08206
# 21     AUDCHF    0.07114     GBPCAD    0.00000     CHFJPY    0.03161
# 22     EURAUD    0.04670     GBPJPY    0.00000     EURCHF    0.03161
# 23     EURNZD    0.04013     EURNZD    0.00000     GBPUSD    0.01010
# 24     AUDJPY    0.04013     EURCHF    0.00000     NZDCHF    0.01010
# 25     AUDNZD    0.03382     GBPCHF    0.00000     AUDCAD    0.01010
# 26     USDCAD    0.00321     AUDNZD    0.00000     NZDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.49099     EURJPY    0.81650  ...     GBPCAD    0.40482
# 1      AUDNZD    0.33929     CHFJPY    0.60000  ...     GBPUSD    0.36876
# 2      USDJPY    0.32733     GBPAUD    0.50000  ...     GBPJPY    0.36876
# 3      CHFJPY    0.21822     AUDCAD    0.40825  ...     EURGBP    0.33307
# 4      NZDCAD    0.21822     EURAUD    0.40825  ...     EURUSD    0.32450
# 5      USDCHF    0.21822     AUDUSD    0.21822  ...     GBPCHF    0.31807
# 6      GBPUSD    0.19643     NZDUSD    0.21822  ...     AUDUSD    0.29758
# 7      GBPCAD    0.19643     EURCHF    0.21822  ...     NZDCAD    0.28824
# 8      EURNZD    0.19643     CADCHF    0.21822  ...     EURJPY    0.25223
# 9      CADJPY    0.19643     AUDCHF    0.21822  ...     AUDCHF    0.25223
# 10     CADCHF    0.18898     USDCHF    0.20000  ...     EURCHF    0.21627
# 11     NZDUSD    0.09449     NZDJPY    0.20000  ...     AUDCAD    0.20773
# 12     AUDUSD    0.09449     AUDJPY    0.20000  ...     NZDCHF    0.20773
# 13     AUDCHF    0.09449     EURNZD    0.20000  ...     EURCAD    0.20064
# 14     NZDCHF    0.09449     EURCAD    0.20000  ...     AUDJPY    0.20064
# 15     GBPCHF    0.09449     AUDNZD    0.20000  ...     NZDUSD    0.17138
# 16     GBPJPY    0.07143     GBPUSD    0.20000  ...     NZDJPY    0.15743
# 17     USDCAD    0.07143     USDJPY    0.20000  ...     CADCHF    0.15198
# 18     EURCAD    0.07143     EURUSD    0.20000  ...     CHFJPY    0.15198
# 19     NZDJPY    0.05455     GBPCAD    0.00000  ...     AUDNZD    0.12721
# 20     EURUSD    0.05455     GBPJPY    0.00000  ...     EURAUD    0.12721
# 21     AUDCAD    0.05455     NZDCHF    0.00000  ...     EURNZD    0.12039
# 22     EURGBP    0.05455     GBPCHF    0.00000  ...     USDJPY    0.12039
# 23     AUDJPY    0.05455     CADJPY    0.00000  ...     GBPAUD    0.11433
# 24     EURAUD    0.05455     USDCAD    0.00000  ...     USDCHF    0.11433
# 25     EURCHF    0.04029     NZDCAD    0.00000  ...     USDCAD    0.07711
# 26     GBPAUD    0.04029     EURGBP    0.00000  ...     CADJPY    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.65908     GBPCAD    0.61237     GBPCAD    0.73214
# 1      GBPCHF    0.52177     EURAUD    0.40825     GBPCHF    0.66144
# 2      AUDUSD    0.49321     AUDCHF    0.40825     NZDCHF    0.66144
# 3      AUDCHF    0.47087     GBPCHF    0.40000     EURCAD    0.60714
# 4      GBPUSD    0.45701     EURCAD    0.40000     EURCHF    0.56408
# 5      EURCHF    0.43939     EURGBP    0.40000     EURGBP    0.49099
# 6      AUDCAD    0.41349     AUDUSD    0.31449     NZDCAD    0.49099
# 7      EURCAD    0.41349     EURCHF    0.31449     EURNZD    0.46429
# 8      EURUSD    0.39551     AUDCAD    0.30151     AUDCHF    0.37796
# 9      GBPJPY    0.39551     NZDCHF    0.30151     GBPJPY    0.33929
# 10     NZDCAD    0.33634     GBPUSD    0.30151     GBPUSD    0.33929
# 11     EURAUD    0.33634     GBPJPY    0.30151     AUDNZD    0.33929
# 12     NZDCHF    0.33634     NZDCAD    0.30151     CHFJPY    0.21822
# 13     EURGBP    0.32127     EURNZD    0.20412     EURAUD    0.21822
# 14     CADCHF    0.26068     AUDJPY    0.20412     USDJPY    0.21822
# 15     EURJPY    0.26068     CADCHF    0.20412     AUDCAD    0.21822
# 16     AUDJPY    0.17216     EURUSD    0.20000     EURUSD    0.21822
# 17     NZDJPY    0.17216     GBPAUD    0.11547     USDCHF    0.21822
# 18     NZDUSD    0.12585     NZDJPY    0.10483     USDCAD    0.19643
# 19     EURNZD    0.12585     CHFJPY    0.10483     CADCHF    0.18898
# 20     GBPAUD    0.09513     AUDNZD    0.10050     NZDUSD    0.09449
# 21     USDCAD    0.08597     EURJPY    0.10050     AUDUSD    0.09449
# 22     CADJPY    0.04977     USDCAD    0.10050     CADJPY    0.07143
# 23     CHFJPY    0.03257     USDJPY    0.10050     EURJPY    0.05455
# 24     USDJPY    0.02746     CADJPY    0.00000     AUDJPY    0.05455
# 25     USDCHF    0.00899     NZDUSD    0.00000     NZDJPY    0.05455
# 26     AUDNZD    0.00899     USDCHF    0.00000     GBPAUD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.66667
# 1      GBPCHF    0.66667
# 2      NZDCHF    0.66667
# 3      GBPCAD    0.58333
# 4      EURCHF    0.53452
# 5      AUDCHF    0.53452
# 6      EURNZD    0.40825
# 7      CHFJPY    0.40825
# 8      EURCAD    0.40825
# 9      USDJPY    0.40825
# 10     GBPUSD    0.40825
# 11     GBPJPY    0.25000
# 12     NZDCAD    0.25000
# 13     EURAUD    0.25000
# 14     EURJPY    0.25000
# 15     AUDCAD    0.25000
# 16     USDCAD    0.16667
# 17     CADJPY    0.16667
# 18     GBPAUD    0.10206
# 19     AUDUSD    0.08909
# 20     CADCHF    0.08909
# 21     NZDUSD    0.08909
# 22     NZDJPY    0.00000
# 23     USDCHF    0.00000
# 24     AUDJPY    0.00000
# 25     EURUSD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
