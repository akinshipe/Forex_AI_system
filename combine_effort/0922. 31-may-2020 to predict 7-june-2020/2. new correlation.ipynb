# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 10:53:53.010732

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.40032     USDJPY    0.46371     EURJPY    0.49237
# 1      USDJPY    0.36470     USDCHF    0.20536     AUDCAD    0.39394
# 2      USDCHF    0.32026     GBPUSD    0.20536     CHFJPY    0.39394
# 3      EURJPY    0.28000     NZDCAD    0.20536     USDJPY    0.32824
# 4      NZDUSD    0.28000     AUDCAD    0.20536     NZDUSD    0.32824
# 5      CHFJPY    0.24495     EURJPY    0.20536     USDCHF    0.30151
# 6      EURUSD    0.24019     AUDJPY    0.19094     GBPUSD    0.30151
# 7      AUDUSD    0.24019     AUDNZD    0.14382     AUDUSD    0.30151
# 8      AUDCAD    0.24019     NZDUSD    0.13363     EURAUD    0.30151
# 9      GBPUSD    0.24019     CADJPY    0.13363     NZDJPY    0.28721
# 10     CADCHF    0.20000     GBPCAD    0.13363     CADJPY    0.21212
# 11     NZDJPY    0.12361     CHFJPY    0.08183     GBPJPY    0.21212
# 12     CADJPY    0.12039     EURUSD    0.06250     EURGBP    0.21212
# 13     GBPJPY    0.12000     AUDUSD    0.06250     AUDCHF    0.21212
# 14     EURCAD    0.12000     NZDCHF    0.06250     EURUSD    0.21212
# 15     AUDJPY    0.04052     GBPAUD    0.05455     AUDJPY    0.19192
# 16     AUDNZD    0.04052     EURCHF    0.05455     NZDCAD    0.19192
# 17     GBPCHF    0.04052     NZDJPY    0.01849     AUDNZD    0.17911
# 18     GBPAUD    0.04013     GBPCHF    0.00899     GBPAUD    0.12309
# 19     EURAUD    0.04013     GBPJPY    0.00000     EURCHF    0.12309
# 20     GBPCAD    0.04000     EURCAD    0.00000     EURNZD    0.12309
# 21     EURNZD    0.04000     EURAUD    0.00000     USDCAD    0.12309
# 22     NZDCHF    0.04000     EURNZD    0.00000     EURCAD    0.10050
# 23     USDCAD    0.04000     AUDCHF    0.00000     GBPCHF    0.10050
# 24     AUDCHF    0.00000     USDCAD    0.00000     NZDCHF    0.01010
# 25     EURCHF    0.00000     CADCHF    0.00000     GBPCAD    0.01010
# 26     EURGBP    0.00000     EURGBP    0.00000     CADCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPUSD    0.60714     USDJPY    0.66667  ...     GBPCAD    0.44574
# 1      NZDUSD    0.60714     NZDCAD    0.61237  ...     GBPCHF    0.34319
# 2      AUDCAD    0.60010     AUDCAD    0.61237  ...     EURGBP    0.33092
# 3      NZDCAD    0.60010     AUDUSD    0.61237  ...     AUDUSD    0.33092
# 4      AUDUSD    0.60010     GBPUSD    0.58333  ...     AUDCAD    0.31795
# 5      USDJPY    0.49099     NZDUSD    0.58333  ...     GBPUSD    0.31795
# 6      EURAUD    0.46429     USDCHF    0.40825  ...     AUDCHF    0.31795
# 7      EURNZD    0.37796     GBPJPY    0.40825  ...     GBPJPY    0.28365
# 8      EURGBP    0.37796     EURGBP    0.40825  ...     EURUSD    0.24982
# 9      GBPCHF    0.33929     EURUSD    0.40825  ...     NZDCAD    0.23684
# 10     AUDCHF    0.33929     USDCAD    0.40825  ...     CADCHF    0.20261
# 11     USDCAD    0.33929     AUDCHF    0.35635  ...     EURAUD    0.19025
# 12     CHFJPY    0.32733     GBPCHF    0.35635  ...     EURCHF    0.18286
# 13     EURJPY    0.32733     NZDJPY    0.35635  ...     USDJPY    0.14943
# 14     NZDJPY    0.32733     EURAUD    0.35635  ...     NZDUSD    0.12157
# 15     NZDCHF    0.21822     EURCAD    0.25000  ...     NZDCHF    0.12157
# 16     GBPJPY    0.21822     GBPCAD    0.25000  ...     USDCAD    0.12157
# 17     GBPCAD    0.21822     GBPAUD    0.25000  ...     EURJPY    0.12157
# 18     CADJPY    0.21822     CADCHF    0.25000  ...     EURCAD    0.12157
# 19     AUDJPY    0.19643     EURNZD    0.25000  ...     EURNZD    0.12157
# 20     USDCHF    0.19643     CADJPY    0.25000  ...     GBPAUD    0.10895
# 21     EURUSD    0.19643     AUDJPY    0.16667  ...     AUDJPY    0.09688
# 22     EURCAD    0.07143     CHFJPY    0.16667  ...     NZDJPY    0.08515
# 23     GBPAUD    0.07143     EURJPY    0.16667  ...     USDCHF    0.07462
# 24     CADCHF    0.07143     EURCHF    0.16667  ...     AUDNZD    0.06732
# 25     EURCHF    0.07143     NZDCHF    0.16667  ...     CADJPY    0.05366
# 26     AUDNZD    0.05455     AUDNZD    0.08909  ...     CHFJPY    0.04963
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.53452     GBPCHF    0.61237     EURGBP    0.66144
# 1      EURGBP    0.40089     EURGBP    0.53340     GBPCHF    0.60714
# 2      GBPCHF    0.39551     GBPCAD    0.53340     USDJPY    0.49099
# 3      AUDUSD    0.33929     USDJPY    0.45833     GBPCAD    0.49099
# 4      NZDCAD    0.33036     EURNZD    0.45833     EURNZD    0.37796
# 5      AUDCAD    0.33036     GBPUSD    0.40825     NZDUSD    0.33929
# 6      GBPUSD    0.33036     CHFJPY    0.32824     EURCHF    0.33929
# 7      EURNZD    0.26726     AUDCHF    0.32824     AUDCHF    0.33929
# 8      EURAUD    0.26726     NZDCHF    0.32824     GBPUSD    0.33929
# 9      AUDCHF    0.26726     NZDCAD    0.28721     NZDCAD    0.32733
# 10     GBPJPY    0.26726     AUDCAD    0.28721     AUDCAD    0.32733
# 11     USDJPY    0.21822     EURJPY    0.25000     AUDUSD    0.32733
# 12     EURCHF    0.21822     NZDUSD    0.25000     GBPJPY    0.21822
# 13     EURUSD    0.20536     EURCHF    0.25000     EURJPY    0.21822
# 14     NZDCHF    0.20536     AUDUSD    0.20412     AUDNZD    0.21822
# 15     GBPAUD    0.19094     EURAUD    0.20412     NZDCHF    0.21822
# 16     AUDNZD    0.14382     AUDNZD    0.17118     CHFJPY    0.21822
# 17     EURCAD    0.13363     GBPAUD    0.16667     GBPAUD    0.19643
# 18     CADCHF    0.13363     GBPJPY    0.12309     EURAUD    0.19643
# 19     NZDUSD    0.13363     CADCHF    0.12309     EURUSD    0.19643
# 20     NZDJPY    0.12016     AUDJPY    0.12309     USDCHF    0.19643
# 21     CHFJPY    0.08183     EURUSD    0.12309     CADCHF    0.07143
# 22     EURJPY    0.06250     CADJPY    0.08206     EURCAD    0.07143
# 23     USDCHF    0.06250     NZDJPY    0.04167     AUDJPY    0.07143
# 24     AUDJPY    0.05455     USDCAD    0.04167     USDCAD    0.07143
# 25     CADJPY    0.00000     EURCAD    0.00000     CADJPY    0.05455
# 26     USDCAD    0.00000     USDCHF    0.00000     NZDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.65465
# 1      EURNZD    0.53452
# 2      USDJPY    0.53452
# 3      EURCAD    0.53452
# 4      GBPAUD    0.53452
# 5      GBPCAD    0.53452
# 6      GBPCHF    0.52381
# 7      AUDNZD    0.42857
# 8      GBPUSD    0.35635
# 9      NZDUSD    0.35635
# 10     USDCHF    0.21822
# 11     EURUSD    0.21822
# 12     NZDCAD    0.21822
# 13     AUDCAD    0.21822
# 14     GBPJPY    0.21822
# 15     AUDUSD    0.21822
# 16     USDCAD    0.21822
# 17     AUDJPY    0.08909
# 18     CADJPY    0.08909
# 19     EURCHF    0.08909
# 20     CHFJPY    0.08909
# 21     NZDCHF    0.08909
# 22     CADCHF    0.08909
# 23     EURJPY    0.08909
# 24     EURAUD    0.04762
# 25     NZDJPY    0.04762
# 26     AUDCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
