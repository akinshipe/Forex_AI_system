# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:35:20.711926
# 2021-12-06 23:35:20.724690
# 2021-12-06 23:36:20.730190
# 2021-12-06 23:37:20.740865
# 2021-12-06 23:38:20.759411
# 2021-12-06 23:39:20.769549
# 2021-12-06 23:40:20.782274
# 2021-12-06 23:41:20.785684
# 2021-12-06 23:42:20.803659
# 2021-12-06 23:43:20.819106
# 2021-12-06 23:44:20.828843
# 2021-12-06 23:45:20.852511
# 2021-12-06 23:46:20.867097
# 2021-12-06 23:47:20.870242
# 2021-12-06 23:48:20.888599
# 2021-12-06 23:49:20.906050
# 2021-12-06 23:50:20.925356
# 2021-12-06 23:51:20.942770
# 2021-12-06 23:52:20.960334
# 2021-12-06 23:53:20.979002
# 2021-12-06 23:54:20.995522
# 2021-12-06 23:55:21.005387
# 2021-12-06 23:56:21.013147
# 2021-12-06 23:57:21.031420
# 2021-12-06 23:58:21.045064
# 2021-12-06 23:59:21.052598
# 2021-12-07 00:00:21.059828
# 2021-12-07 00:01:21.068905
# 2021-12-07 00:02:21.090332
# 2021-12-07 00:03:21.109480
# 2021-12-07 00:04:21.120999
# 2021-12-07 00:05:21.141108
# 2021-12-07 00:06:21.149952
# 2021-12-07 00:07:21.159065
# 2021-12-07 00:08:21.172647
# 2021-12-07 00:09:21.179543
# 2021-12-07 00:10:21.198597
# 2021-12-07 00:11:21.202566
# 2021-12-07 00:12:21.219533
# 2021-12-07 00:13:21.239576
# 2021-12-07 00:14:21.256877
# 2021-12-07 00:15:21.264869
# 2021-12-07 00:16:21.267284
# 2021-12-07 00:17:21.282778
# 2021-12-07 00:18:21.304603
# 2021-12-07 00:19:21.309729
# 2021-12-07 00:20:21.324527
# 2021-12-07 00:21:21.328912
# 2021-12-07 00:22:21.347823
# 2021-12-07 00:23:21.350502
# 2021-12-07 00:24:21.355743
# 2021-12-07 00:25:21.362649
# 2021-12-07 00:26:21.373061
# 2021-12-07 04:37:24.328615
# 2021-12-07 04:38:24.328800
# 2021-12-07 04:39:24.344731
# 2021-12-07 04:40:24.352583
# 2021-12-07 04:41:24.366727
# 2021-12-07 04:42:24.385263
# 2021-12-07 04:43:24.397179
# 2021-12-07 04:44:24.398335
# 2021-12-07 04:45:24.411292
# 2021-12-07 04:46:24.436230
# 2021-12-07 04:47:24.437711
# 2021-12-07 04:48:24.450639
# 2021-12-07 04:49:24.459720

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 10 [-0.96099829]
# GBPUSD 20 [1.]
# EURUSD 15 [0.99733568]
# USDJPY 10 [-0.95387]
# USDCAD 15 [-0.71289924]
# NZDUSD 50 [0.23057173]
# GBPCHF 10 [0.797]
# EURCHF 15 [0.51430121]
# CADCHF 20 [0.91600541]
# NZDCHF 30 [0.70750469]
# EURGBP 10 [-0.66760183]
# GBPJPY 10 [1.]
# GBPCAD 10 [0.7905]
# GBPAUD 15 [-0.42878404]
# EURCAD 20 [-0.69037024]
# CADJPY 10 [0.75230893]
# NZDJPY 15 [1.]
# NZDCAD 15 [0.87028552]
# ['S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
