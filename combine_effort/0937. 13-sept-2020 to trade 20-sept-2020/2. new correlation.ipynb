# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 09:00:04.891995

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.34542     NZDCAD    0.38620     NZDCAD    0.31180
# 1      NZDCAD    0.26212     GBPUSD    0.34586     USDJPY    0.21822
# 2      GBPUSD    0.23028     AUDUSD    0.29187     AUDCHF    0.20588
# 3      AUDCAD    0.19852     CHFJPY    0.29187     EURUSD    0.19048
# 4      USDCHF    0.16667     AUDCAD    0.29187     AUDUSD    0.19048
# 5      CADJPY    0.14744     USDJPY    0.25882     AUDCAD    0.19048
# 6      CHFJPY    0.13457     NZDUSD    0.25882     CHFJPY    0.19048
# 7      AUDCHF    0.13234     EURAUD    0.20751     AUDNZD    0.15352
# 8      NZDUSD    0.13074     NZDJPY    0.15714     GBPCAD    0.15352
# 9      EURCAD    0.13074     EURUSD    0.14833     NZDUSD    0.15352
# 10     CADCHF    0.13074     GBPAUD    0.12016     NZDJPY    0.15352
# 11     AUDNZD    0.11580     GBPCHF    0.12016     EURNZD    0.15352
# 12     EURUSD    0.11580     AUDNZD    0.10702     GBPUSD    0.15352
# 13     USDCAD    0.09869     USDCAD    0.10702     GBPAUD    0.15352
# 14     EURJPY    0.08333     AUDJPY    0.10702     EURJPY    0.12599
# 15     AUDJPY    0.08333     EURJPY    0.09782     USDCHF    0.12599
# 16     EURCHF    0.08165     USDCHF    0.09782     GBPJPY    0.08909
# 17     EURAUD    0.08165     EURNZD    0.08472     EURCAD    0.08909
# 18     AUDUSD    0.06580     EURGBP    0.08472     CADJPY    0.08909
# 19     GBPCAD    0.06553     GBPJPY    0.06917     AUDJPY    0.08909
# 20     GBPAUD    0.04963     CADJPY    0.06917     EURGBP    0.08909
# 21     EURNZD    0.04903     NZDCHF    0.03257     EURCHF    0.02288
# 22     GBPCHF    0.03309     AUDCHF    0.03257     USDCAD    0.02288
# 23     NZDJPY    0.03309     EURCHF    0.03257     NZDCHF    0.00000
# 24     GBPJPY    0.01638     GBPCAD    0.01849     EURAUD    0.00000
# 25     NZDCHF    0.00000     EURCAD    0.01849     CADCHF    0.00000
# 26     EURGBP    0.00000     CADCHF    0.01849     GBPCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CHFJPY    0.35355     CHFJPY    0.42857  ...     GBPCAD    0.35286
# 1      AUDCHF    0.35355     NZDCAD    0.35635  ...     GBPCHF    0.26108
# 2      EURUSD    0.30151     GBPAUD    0.35635  ...     AUDUSD    0.22531
# 3      USDCHF    0.25000     AUDCHF    0.35635  ...     EURGBP    0.20261
# 4      GBPAUD    0.20045     USDCHF    0.32733  ...     EURCHF    0.20261
# 5      GBPCAD    0.20045     EURUSD    0.32733  ...     USDJPY    0.18286
# 6      GBPUSD    0.13363     EURCHF    0.21822  ...     AUDCHF    0.17898
# 7      NZDCAD    0.13363     EURJPY    0.21822  ...     AUDCAD    0.17898
# 8      NZDJPY    0.13363     EURGBP    0.21822  ...     GBPAUD    0.17898
# 9      EURNZD    0.13363     GBPCHF    0.21822  ...     CHFJPY    0.16530
# 10     EURAUD    0.13363     CADCHF    0.08909  ...     EURCAD    0.15573
# 11     EURCAD    0.13363     USDJPY    0.08909  ...     CADCHF    0.15573
# 12     EURGBP    0.13363     NZDJPY    0.08909  ...     GBPUSD    0.14368
# 13     NZDCHF    0.13363     AUDJPY    0.08909  ...     NZDCAD    0.10895
# 14     CADCHF    0.13363     EURNZD    0.08909  ...     GBPJPY    0.10895
# 15     GBPCHF    0.13363     EURCAD    0.08909  ...     EURUSD    0.09688
# 16     NZDUSD    0.13363     GBPCAD    0.08909  ...     NZDUSD    0.07462
# 17     USDJPY    0.13363     GBPJPY    0.08909  ...     USDCHF    0.04963
# 18     AUDNZD    0.13363     GBPUSD    0.08909  ...     EURJPY    0.04963
# 19     EURJPY    0.07538     NZDCHF    0.08909  ...     EURAUD    0.04052
# 20     GBPJPY    0.06804     NZDUSD    0.08909  ...     NZDCHF    0.04052
# 21     CADJPY    0.06804     AUDNZD    0.08909  ...     AUDJPY    0.03309
# 22     AUDJPY    0.06804     AUDUSD    0.04762  ...     CADJPY    0.02764
# 23     EURCHF    0.00000     USDCAD    0.04762  ...     USDCAD    0.01959
# 24     AUDUSD    0.00000     EURAUD    0.04762  ...     NZDJPY    0.01478
# 25     USDCAD    0.00000     CADJPY    0.04762  ...     AUDNZD    0.01478
# 26     AUDCAD    0.00000     AUDCAD    0.04762  ...     EURNZD    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.33929     CHFJPY    0.37284     EURNZD    0.46429
# 1      CHFJPY    0.29579     EURAUD    0.30151     EURAUD    0.46429
# 2      EURCHF    0.26068     USDJPY    0.30151     NZDCHF    0.46429
# 3      EURGBP    0.21822     NZDCHF    0.30151     CHFJPY    0.37796
# 4      GBPCHF    0.20536     GBPAUD    0.21212     GBPUSD    0.33929
# 5      GBPCAD    0.20536     GBPUSD    0.21212     NZDCAD    0.33929
# 6      GBPAUD    0.19643     EURNZD    0.19192     EURUSD    0.26189
# 7      USDCHF    0.18898     EURCHF    0.17911     AUDJPY    0.21822
# 8      AUDJPY    0.14382     USDCHF    0.17408     GBPJPY    0.21822
# 9      EURAUD    0.13363     EURUSD    0.15352     USDCHF    0.20045
# 10     AUDCHF    0.12585     AUDJPY    0.12309     NZDJPY    0.19643
# 11     NZDCHF    0.12585     NZDCAD    0.12309     EURCAD    0.19643
# 12     AUDUSD    0.12016     GBPJPY    0.12309     GBPAUD    0.19643
# 13     AUDCAD    0.12016     GBPCHF    0.10050     EURGBP    0.19643
# 14     EURJPY    0.09449     CADCHF    0.10050     CADCHF    0.19643
# 15     NZDJPY    0.07143     EURCAD    0.08206     GBPCHF    0.19643
# 16     NZDUSD    0.07143     CADJPY    0.08206     NZDUSD    0.19643
# 17     EURCAD    0.06250     EURGBP    0.08206     USDJPY    0.19643
# 18     CADCHF    0.06250     AUDUSD    0.06580     AUDNZD    0.19643
# 19     EURNZD    0.05455     AUDCAD    0.06580     EURCHF    0.18898
# 20     EURUSD    0.01849     EURJPY    0.05803     AUDCHF    0.09449
# 21     USDCAD    0.00899     AUDCHF    0.03161     AUDUSD    0.09449
# 22     NZDCAD    0.00899     USDCAD    0.03161     USDCAD    0.09449
# 23     AUDNZD    0.00899     GBPCAD    0.01010     AUDCAD    0.09449
# 24     CADJPY    0.00000     NZDUSD    0.01010     GBPCAD    0.07143
# 25     GBPJPY    0.00000     NZDJPY    0.01010     CADJPY    0.05455
# 26     GBPUSD    0.00000     AUDNZD    0.01010     EURJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCHF    0.61237
# 1      EURJPY    0.61237
# 2      EURAUD    0.35635
# 3      AUDCAD    0.35635
# 4      AUDUSD    0.35635
# 5      CADJPY    0.35635
# 6      GBPCAD    0.25000
# 7      USDJPY    0.25000
# 8      NZDUSD    0.25000
# 9      NZDJPY    0.25000
# 10     GBPUSD    0.25000
# 11     AUDNZD    0.16667
# 12     EURCAD    0.16667
# 13     GBPAUD    0.16667
# 14     CADCHF    0.16667
# 15     GBPJPY    0.16667
# 16     NZDCHF    0.16667
# 17     AUDCHF    0.16667
# 18     AUDJPY    0.16667
# 19     NZDCAD    0.16667
# 20     EURNZD    0.16667
# 21     USDCHF    0.10206
# 22     EURUSD    0.10206
# 23     CHFJPY    0.08909
# 24     USDCAD    0.08909
# 25     GBPCHF    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
