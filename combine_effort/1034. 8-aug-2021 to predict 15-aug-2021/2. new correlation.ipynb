# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:47:01.764488

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.36775     CADJPY    0.28868     GBPCAD    0.34641
# 1      CHFJPY    0.30215     NZDCAD    0.27217     EURUSD    0.30151
# 2      EURJPY    0.25853     EURUSD    0.25000     NZDCAD    0.30151
# 3      USDCHF    0.25223     GBPCHF    0.22591     AUDCAD    0.30151
# 4      CADJPY    0.21914     AUDCAD    0.21822     EURGBP    0.20412
# 5      NZDUSD    0.21914     EURCAD    0.21822     NZDJPY    0.20412
# 6      GBPJPY    0.21101     GBPJPY    0.20787     CADJPY    0.20412
# 7      EURCAD    0.20646     NZDUSD    0.19094     EURNZD    0.20412
# 8      AUDNZD    0.19678     CHFJPY    0.16667     GBPJPY    0.20412
# 9      AUDCAD    0.18831     EURNZD    0.16477     AUDCHF    0.20412
# 10     NZDCAD    0.18094     EURJPY    0.14434     GBPUSD    0.20000
# 11     GBPUSD    0.18094     USDCAD    0.13608     EURCAD    0.20000
# 12     AUDUSD    0.11613     GBPCAD    0.12309     USDCHF    0.20000
# 13     AUDJPY    0.10714     USDCHF    0.11111     GBPCHF    0.20000
# 14     EURGBP    0.10123     NZDCHF    0.10985     NZDUSD    0.20000
# 15     GBPAUD    0.10123     GBPUSD    0.10985     USDCAD    0.20000
# 16     EURNZD    0.09054     EURGBP    0.08472     CHFJPY    0.10483
# 17     USDJPY    0.09054     AUDCHF    0.08183     GBPAUD    0.10483
# 18     CADCHF    0.07722     CADCHF    0.05648     EURJPY    0.10483
# 19     GBPCHF    0.05313     USDJPY    0.05648     AUDUSD    0.10483
# 20     EURAUD    0.04516     EURCHF    0.05455     EURCHF    0.10050
# 21     GBPCAD    0.04423     AUDNZD    0.05455     AUDJPY    0.10050
# 22     NZDJPY    0.03517     GBPAUD    0.02778     AUDNZD    0.10050
# 23     EURCHF    0.02597     AUDUSD    0.02778     NZDCHF    0.00000
# 24     AUDCHF    0.00970     EURAUD    0.02746     CADCHF    0.00000
# 25     USDCAD    0.00970     AUDJPY    0.00000     EURAUD    0.00000
# 26     NZDCHF    0.00672     NZDJPY    0.00000     USDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66667     USDCHF    0.66667  ...     USDCHF    0.23775
# 1      NZDCAD    0.66667     NZDCAD    0.66667  ...     AUDCAD    0.20646
# 2      NZDUSD    0.66667     NZDUSD    0.66667  ...     EURUSD    0.19872
# 3      USDCHF    0.49099     AUDCAD    0.58333  ...     EURCAD    0.19872
# 4      AUDCAD    0.49099     EURUSD    0.53452  ...     GBPCAD    0.18254
# 5      GBPUSD    0.49099     EURNZD    0.53452  ...     USDJPY    0.15743
# 6      EURCAD    0.49099     GBPUSD    0.53452  ...     NZDJPY    0.15724
# 7      GBPCAD    0.43082     CADCHF    0.40825  ...     CADJPY    0.15505
# 8      EURNZD    0.38889     EURCAD    0.40825  ...     GBPUSD    0.13074
# 9      USDJPY    0.28868     EURGBP    0.40825  ...     AUDNZD    0.11859
# 10     CADCHF    0.28868     GBPCAD    0.35635  ...     AUDJPY    0.11613
# 11     AUDCHF    0.28868     GBPJPY    0.25000  ...     CADCHF    0.11342
# 12     GBPCHF    0.21822     CHFJPY    0.16667  ...     NZDCHF    0.11342
# 13     NZDCHF    0.21822     AUDJPY    0.16667  ...     EURJPY    0.11342
# 14     AUDUSD    0.18464     EURAUD    0.08909  ...     GBPAUD    0.08760
# 15     EURGBP    0.16667     USDJPY    0.08909  ...     AUDCHF    0.07711
# 16     GBPJPY    0.16667     USDCAD    0.08909  ...     USDCAD    0.07711
# 17     CHFJPY    0.12309     AUDUSD    0.08909  ...     EURNZD    0.07711
# 18     NZDJPY    0.11111     GBPCHF    0.08909  ...     EURGBP    0.07462
# 19     AUDNZD    0.11111     AUDCHF    0.08909  ...     NZDCAD    0.04903
# 20     EURJPY    0.05455     EURJPY    0.08909  ...     EURAUD    0.03846
# 21     AUDJPY    0.05455     GBPAUD    0.08909  ...     AUDUSD    0.03846
# 22     USDCAD    0.05455     EURCHF    0.08909  ...     EURCHF    0.03548
# 23     GBPAUD    0.00000     AUDNZD    0.08909  ...     GBPJPY    0.01747
# 24     EURAUD    0.00000     CADJPY    0.00000  ...     NZDUSD    0.00990
# 25     CADJPY    0.00000     NZDJPY    0.00000  ...     CHFJPY    0.00990
# 26     EURCHF    0.00000     NZDCHF    0.00000  ...     GBPCHF    0.00990
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.30151     AUDCAD    0.32824     USDCHF    0.37796
# 1      NZDJPY    0.28284     NZDJPY    0.25000     AUDCAD    0.37796
# 2      USDCHF    0.27217     GBPCAD    0.23570     EURCAD    0.37796
# 3      AUDCAD    0.26726     USDCHF    0.20412     NZDUSD    0.28868
# 4      CADJPY    0.14142     EURCAD    0.20412     NZDCAD    0.28868
# 5      EURJPY    0.14142     GBPCHF    0.20412     NZDJPY    0.28868
# 6      EURUSD    0.13608     EURJPY    0.17118     EURGBP    0.28868
# 7      GBPAUD    0.13608     CHFJPY    0.17118     EURUSD    0.28868
# 8      EURCAD    0.13363     GBPJPY    0.16667     GBPCAD    0.21320
# 9      EURCHF    0.13363     NZDCAD    0.12309     CADJPY    0.20000
# 10     GBPJPY    0.07274     AUDNZD    0.12309     CADCHF    0.20000
# 11     EURGBP    0.06917     EURUSD    0.12309     USDJPY    0.20000
# 12     CADCHF    0.06917     EURAUD    0.08909     AUDJPY    0.18898
# 13     GBPCHF    0.06917     EURCHF    0.08206     CHFJPY    0.10660
# 14     USDJPY    0.06917     AUDJPY    0.08206     AUDUSD    0.10660
# 15     NZDCHF    0.06727     GBPAUD    0.04280     AUDCHF    0.10000
# 16     GBPUSD    0.06727     AUDUSD    0.04280     GBPAUD    0.10000
# 17     EURAUD    0.06727     AUDCHF    0.04167     EURCHF    0.10000
# 18     EURNZD    0.06727     CADCHF    0.04167     EURAUD    0.10000
# 19     AUDJPY    0.06667     EURNZD    0.04167     GBPCHF    0.09449
# 20     USDCAD    0.06667     CADJPY    0.04167     USDCAD    0.09449
# 21     NZDCAD    0.06667     USDJPY    0.04167     EURJPY    0.09449
# 22     AUDCHF    0.00000     EURGBP    0.04167     GBPUSD    0.09449
# 23     CHFJPY    0.00000     NZDCHF    0.00000     NZDCHF    0.09449
# 24     NZDUSD    0.00000     GBPUSD    0.00000     EURNZD    0.00000
# 25     AUDUSD    0.00000     NZDUSD    0.00000     GBPJPY    0.00000
# 26     AUDNZD    0.00000     USDCAD    0.00000     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCAD    0.50000
# 1      USDCHF    0.40825
# 2      NZDCAD    0.40825
# 3      NZDUSD    0.40825
# 4      GBPJPY    0.40825
# 5      EURUSD    0.32733
# 6      USDCAD    0.32733
# 7      EURNZD    0.32733
# 8      GBPCHF    0.32733
# 9      EURCHF    0.32733
# 10     EURJPY    0.32733
# 11     GBPUSD    0.32733
# 12     GBPCAD    0.21822
# 13     EURAUD    0.21822
# 14     GBPAUD    0.21822
# 15     AUDNZD    0.21822
# 16     AUDCHF    0.21822
# 17     AUDUSD    0.21822
# 18     USDJPY    0.21822
# 19     CHFJPY    0.10206
# 20     AUDJPY    0.10206
# 21     AUDCAD    0.10206
# 22     NZDCHF    0.00000
# 23     CADCHF    0.00000
# 24     CADJPY    0.00000
# 25     NZDJPY    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
