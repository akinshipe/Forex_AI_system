# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:59:27.185109

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.26704     EURJPY    0.50830     EURJPY    0.66339
# 1      GBPJPY    0.22999     EURNZD    0.38889     EURAUD    0.48038
# 2      AUDNZD    0.21246     CHFJPY    0.38446     AUDCHF    0.42366
# 3      CHFJPY    0.21246     EURUSD    0.35460     EURNZD    0.38516
# 4      CADJPY    0.21246     AUDNZD    0.30556     CADCHF    0.36690
# 5      EURNZD    0.19872     EURGBP    0.30208     AUDCAD    0.31868
# 6      NZDJPY    0.18254     USDCHF    0.25000     CADJPY    0.30261
# 7      NZDUSD    0.17485     CADJPY    0.22591     CHFJPY    0.25678
# 8      GBPUSD    0.17485     AUDCHF    0.19767     GBPUSD    0.25163
# 9      EURUSD    0.16386     EURAUD    0.19767     NZDCAD    0.25163
# 10     AUDCHF    0.15549     GBPJPY    0.19305     AUDNZD    0.20588
# 11     AUDUSD    0.14417     AUDJPY    0.16667     NZDUSD    0.18157
# 12     USDJPY    0.11859     AUDUSD    0.16667     NZDCHF    0.18157
# 13     NZDCAD    0.09803     EURCAD    0.16477     EURGBP    0.17118
# 14     GBPCHF    0.09237     GBPAUD    0.16477     EURUSD    0.17118
# 15     AUDJPY    0.09237     NZDUSD    0.14434     GBPJPY    0.10483
# 16     EURGBP    0.08006     NZDJPY    0.12309     NZDJPY    0.10483
# 17     EURAUD    0.07258     GBPCAD    0.11111     GBPCAD    0.09890
# 18     EURCHF    0.05338     GBPCHF    0.08909     AUDUSD    0.09890
# 19     USDCAD    0.04516     NZDCHF    0.08909     USDJPY    0.09890
# 20     USDCHF    0.04167     CADCHF    0.08909     USDCHF    0.09890
# 21     GBPAUD    0.03846     GBPUSD    0.08472     GBPCHF    0.06052
# 22     GBPCAD    0.03548     EURCHF    0.08472     EURCAD    0.04280
# 23     AUDCAD    0.01352     USDJPY    0.08183     GBPAUD    0.03161
# 24     NZDCHF    0.00990     USDCAD    0.05455     USDCAD    0.03161
# 25     CADCHF    0.00990     AUDCAD    0.02778     EURCHF    0.02288
# 26     EURCAD    0.00000     NZDCAD    0.00000     AUDJPY    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.82916     EURJPY    0.66667  ...     GBPUSD    0.16530
# 1      CHFJPY    0.53452     GBPAUD    0.33333  ...     EURUSD    0.13497
# 2      CADJPY    0.45227     AUDCAD    0.33333  ...     AUDNZD    0.13234
# 3      EURGBP    0.35355     USDCAD    0.33333  ...     CADJPY    0.13234
# 4      EURUSD    0.35355     AUDUSD    0.33333  ...     CHFJPY    0.11580
# 5      USDJPY    0.35355     EURNZD    0.33333  ...     USDJPY    0.08760
# 6      EURAUD    0.35355     CHFJPY    0.33333  ...     EURAUD    0.08181
# 7      GBPUSD    0.35355     NZDCAD    0.27217  ...     CADCHF    0.08181
# 8      AUDCHF    0.30151     NZDUSD    0.27217  ...     NZDCHF    0.08181
# 9      GBPCAD    0.30151     AUDJPY    0.27217  ...     GBPJPY    0.06255
# 10     USDCHF    0.30151     EURAUD    0.27217  ...     USDCAD    0.06204
# 11     CADCHF    0.30151     AUDCHF    0.27217  ...     EURCHF    0.04728
# 12     AUDNZD    0.25000     EURCAD    0.27217  ...     EURCAD    0.04052
# 13     GBPCHF    0.19612     GBPUSD    0.27217  ...     EURGBP    0.04052
# 14     GBPJPY    0.13363     EURGBP    0.21822  ...     AUDUSD    0.02432
# 15     GBPAUD    0.13363     AUDNZD    0.21822  ...     GBPCAD    0.01959
# 16     EURNZD    0.13363     GBPCAD    0.21822  ...     AUDCHF    0.01198
# 17     USDCAD    0.13363     NZDCHF    0.21822  ...     EURJPY    0.01198
# 18     NZDCHF    0.07538     CADCHF    0.21822  ...     NZDJPY    0.01198
# 19     EURCHF    0.07538     USDJPY    0.21822  ...     AUDCAD    0.01198
# 20     NZDJPY    0.07538     EURUSD    0.21822  ...     NZDCAD    0.01198
# 21     EURCAD    0.06804     EURCHF    0.16667  ...     GBPAUD    0.00649
# 22     AUDUSD    0.06804     NZDJPY    0.16667  ...     EURNZD    0.00649
# 23     AUDCAD    0.06804     USDCHF    0.16667  ...     USDCHF    0.00649
# 24     NZDUSD    0.00000     GBPJPY    0.11111  ...     GBPCHF    0.00167
# 25     AUDJPY    0.00000     CADJPY    0.11111  ...     NZDUSD    0.00167
# 26     NZDCAD    0.00000     GBPCHF    0.11111  ...     AUDJPY    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      CADJPY    0.22591     GBPCAD    0.48038     GBPCAD    0.36364
# 1      NZDCHF    0.20787     GBPCHF    0.37796     EURNZD    0.34247
# 2      GBPUSD    0.19767     GBPAUD    0.37284     NZDJPY    0.31818
# 3      EURUSD    0.19094     EURGBP    0.31180     NZDCHF    0.31818
# 4      USDJPY    0.19094     AUDJPY    0.28571     GBPAUD    0.26189
# 5      USDCAD    0.19094     AUDNZD    0.28571     USDCAD    0.26189
# 6      USDCHF    0.16667     USDCAD    0.28511     GBPCHF    0.23652
# 7      AUDJPY    0.16667     GBPJPY    0.21822     NZDUSD    0.21320
# 8      EURNZD    0.16667     NZDJPY    0.21822     NZDCAD    0.21320
# 9      AUDNZD    0.16667     AUDUSD    0.20588     EURAUD    0.21320
# 10     GBPAUD    0.16477     GBPUSD    0.19048     AUDJPY    0.21320
# 11     NZDJPY    0.12309     EURCHF    0.19048     EURCAD    0.18464
# 12     GBPCAD    0.11111     CHFJPY    0.13363     GBPJPY    0.16116
# 13     AUDCAD    0.11111     EURNZD    0.13363     AUDCAD    0.12309
# 14     EURCAD    0.10985     AUDCHF    0.12599     AUDUSD    0.12309
# 15     EURGBP    0.10985     NZDCHF    0.12599     GBPUSD    0.10660
# 16     EURJPY    0.08472     CADJPY    0.12599     USDJPY    0.10660
# 17     AUDCHF    0.08472     NZDUSD    0.12599     EURUSD    0.10660
# 18     EURAUD    0.08472     EURCAD    0.08909     EURGBP    0.10660
# 19     GBPCHF    0.05939     EURUSD    0.08909     AUDNZD    0.07538
# 20     CADCHF    0.05939     CADCHF    0.05455     CHFJPY    0.04029
# 21     EURCHF    0.05648     NZDCAD    0.04762     EURJPY    0.02273
# 22     GBPJPY    0.03217     EURJPY    0.04762     CADJPY    0.02273
# 23     AUDUSD    0.02778     EURAUD    0.04762     AUDCHF    0.02273
# 24     CHFJPY    0.02746     USDJPY    0.02288     CADCHF    0.02273
# 25     NZDUSD    0.00000     AUDCAD    0.02288     EURCHF    0.02273
# 26     NZDCAD    0.00000     USDCHF    0.02288     USDCHF    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.42857
# 1      EURAUD    0.35635
# 2      EURJPY    0.32733
# 3      EURCHF    0.32733
# 4      USDCHF    0.21822
# 5      CHFJPY    0.21822
# 6      GBPAUD    0.21822
# 7      GBPJPY    0.21822
# 8      CADJPY    0.21822
# 9      NZDJPY    0.21822
# 10     GBPCHF    0.21822
# 11     AUDUSD    0.21822
# 12     USDCAD    0.21822
# 13     AUDCAD    0.21822
# 14     EURNZD    0.21822
# 15     AUDCHF    0.08909
# 16     AUDJPY    0.08909
# 17     GBPUSD    0.08909
# 18     NZDUSD    0.08909
# 19     EURCAD    0.08909
# 20     NZDCAD    0.08909
# 21     EURGBP    0.04762
# 22     NZDCHF    0.04762
# 23     CADCHF    0.04762
# 24     USDJPY    0.04762
# 25     EURUSD    0.04762
# 26     AUDNZD    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
