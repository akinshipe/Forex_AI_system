# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 11:56:39.189819

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.27743     USDCHF    0.33929     USDJPY    0.37500
# 1      NZDCAD    0.23775     EURCAD    0.33036     CADJPY    0.37500
# 2      CHFJPY    0.20646     USDJPY    0.32733     EURAUD    0.32824
# 3      USDCHF    0.20192     CADJPY    0.32733     USDCAD    0.28721
# 4      USDJPY    0.19872     USDCAD    0.26726     AUDJPY    0.25678
# 5      AUDCAD    0.19872     CADCHF    0.26726     USDCHF    0.25000
# 6      NZDUSD    0.19678     EURAUD    0.26726     AUDNZD    0.25000
# 7      GBPAUD    0.16013     NZDCAD    0.26068     EURJPY    0.20412
# 8      EURUSD    0.15743     AUDJPY    0.25882     AUDCHF    0.20412
# 9      AUDUSD    0.15573     EURUSD    0.20536     EURCAD    0.20412
# 10     EURGBP    0.12581     EURNZD    0.19643     AUDUSD    0.17118
# 11     GBPCAD    0.12179     AUDCHF    0.19643     EURCHF    0.17118
# 12     EURCAD    0.12179     EURJPY    0.19643     EURNZD    0.16667
# 13     EURNZD    0.12179     GBPUSD    0.14382     GBPCAD    0.16667
# 14     AUDCHF    0.11859     GBPAUD    0.12016     CADCHF    0.12309
# 15     GBPJPY    0.11859     NZDJPY    0.12016     GBPUSD    0.12309
# 16     GBPUSD    0.11613     EURGBP    0.12016     NZDCAD    0.08206
# 17     EURCHF    0.11613     CHFJPY    0.08183     AUDCAD    0.08206
# 18     NZDJPY    0.08006     NZDUSD    0.06250     NZDJPY    0.04280
# 19     NZDCHF    0.07711     AUDCAD    0.06250     GBPCHF    0.04280
# 20     GBPCHF    0.07711     GBPCAD    0.05455     GBPAUD    0.04280
# 21     CADCHF    0.04167     GBPJPY    0.05455     GBPJPY    0.04167
# 22     EURAUD    0.04167     GBPCHF    0.04725     CHFJPY    0.04167
# 23     AUDJPY    0.04167     AUDUSD    0.01849     EURGBP    0.04167
# 24     USDCAD    0.04167     AUDNZD    0.01849     NZDUSD    0.00000
# 25     CADJPY    0.03846     EURCHF    0.00899     EURUSD    0.00000
# 26     AUDNZD    0.00649     NZDCHF    0.00000     NZDCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPCAD    0.57735     AUDNZD    0.66667  ...     GBPCAD    0.37589
# 1      AUDUSD    0.50000     NZDCAD    0.66667  ...     EURJPY    0.31253
# 2      USDCAD    0.47246     GBPCAD    0.58333  ...     GBPUSD    0.31253
# 3      NZDJPY    0.40000     EURNZD    0.40825  ...     GBPJPY    0.29417
# 4      AUDJPY    0.40000     EURCAD    0.40825  ...     AUDUSD    0.28123
# 5      AUDNZD    0.37796     AUDUSD    0.40825  ...     EURUSD    0.26212
# 6      EURUSD    0.37796     NZDUSD    0.40825  ...     NZDCAD    0.26212
# 7      NZDUSD    0.37796     CADCHF    0.35635  ...     EURGBP    0.23028
# 8      USDJPY    0.28868     EURJPY    0.25000  ...     GBPCHF    0.22935
# 9      NZDCAD    0.28868     NZDCHF    0.25000  ...     AUDCHF    0.21246
# 10     CHFJPY    0.28868     USDCHF    0.25000  ...     AUDCAD    0.21246
# 11     CADJPY    0.28868     GBPCHF    0.25000  ...     EURCAD    0.19612
# 12     EURNZD    0.28868     USDCAD    0.25000  ...     AUDJPY    0.19612
# 13     EURAUD    0.28868     EURUSD    0.25000  ...     CHFJPY    0.18094
# 14     GBPJPY    0.28868     GBPJPY    0.16667  ...     NZDUSD    0.14804
# 15     GBPAUD    0.21320     USDJPY    0.16667  ...     EURCHF    0.14804
# 16     EURGBP    0.18898     CADJPY    0.16667  ...     EURAUD    0.13074
# 17     GBPUSD    0.18898     AUDJPY    0.16667  ...     AUDNZD    0.11580
# 18     CADCHF    0.18898     NZDJPY    0.16667  ...     CADCHF    0.11440
# 19     GBPCHF    0.18898     GBPAUD    0.10206  ...     USDCAD    0.11440
# 20     EURJPY    0.09449     AUDCHF    0.08909  ...     NZDCHF    0.09829
# 21     EURCAD    0.09449     EURCHF    0.08909  ...     GBPAUD    0.08165
# 22     NZDCHF    0.09449     EURAUD    0.08909  ...     NZDJPY    0.08165
# 23     AUDCHF    0.09449     AUDCAD    0.08909  ...     EURNZD    0.04903
# 24     AUDCAD    0.09449     CHFJPY    0.00000  ...     USDJPY    0.04903
# 25     EURCHF    0.00000     GBPUSD    0.00000  ...     CADJPY    0.03269
# 26     USDCHF    0.00000     EURGBP    0.00000  ...     USDCHF    0.03269
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.64950     GBPCAD    0.58333     GBPCAD    0.72222
# 1      GBPUSD    0.45134     EURCAD    0.40825     EURCAD    0.49099
# 2      AUDUSD    0.43541     AUDUSD    0.38516     NZDCAD    0.38889
# 3      EURCAD    0.43444     NZDCAD    0.32824     EURAUD    0.38889
# 4      EURUSD    0.39747     EURAUD    0.32824     EURGBP    0.32733
# 5      CADCHF    0.34586     AUDCAD    0.32824     GBPCHF    0.32733
# 6      GBPCHF    0.34238     CADCHF    0.28721     GBPUSD    0.32733
# 7      EURJPY    0.29579     GBPUSD    0.28721     CADCHF    0.32733
# 8      AUDCAD    0.29579     GBPCHF    0.25678     AUDUSD    0.28868
# 9      AUDCHF    0.25882     EURUSD    0.20412     NZDCHF    0.21822
# 10     EURCHF    0.24661     EURJPY    0.20412     AUDCAD    0.21822
# 11     NZDCAD    0.24661     AUDCHF    0.20412     AUDNZD    0.21822
# 12     GBPJPY    0.22591     NZDCHF    0.20412     AUDCHF    0.21822
# 13     USDCAD    0.20751     EURCHF    0.17118     USDCAD    0.21822
# 14     EURAUD    0.20751     EURGBP    0.16667     EURUSD    0.21822
# 15     GBPAUD    0.13876     GBPJPY    0.16667     GBPJPY    0.16667
# 16     EURGBP    0.13876     EURNZD    0.16667     EURNZD    0.16667
# 17     CHFJPY    0.08472     USDCAD    0.12309     GBPAUD    0.12309
# 18     NZDCHF    0.06917     GBPAUD    0.04280     CHFJPY    0.11111
# 19     CADJPY    0.05648     AUDJPY    0.04280     EURCHF    0.11111
# 20     USDJPY    0.05648     NZDJPY    0.04280     CADJPY    0.11111
# 21     USDCHF    0.01849     USDCHF    0.04167     USDJPY    0.11111
# 22     EURNZD    0.01849     CADJPY    0.04167     USDCHF    0.11111
# 23     NZDUSD    0.01849     CHFJPY    0.04167     EURJPY    0.05455
# 24     AUDJPY    0.00478     USDJPY    0.04167     NZDUSD    0.05455
# 25     NZDJPY    0.00478     AUDNZD    0.04167     AUDJPY    0.00000
# 26     AUDNZD    0.00478     NZDUSD    0.00000     NZDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.80178
# 1      EURNZD    0.65465
# 2      EURCAD    0.65465
# 3      USDCHF    0.53452
# 4      GBPCHF    0.53452
# 5      NZDCAD    0.53452
# 6      NZDCHF    0.53452
# 7      AUDNZD    0.53452
# 8      EURCHF    0.42857
# 9      AUDCAD    0.42857
# 10     AUDCHF    0.42857
# 11     EURAUD    0.42857
# 12     USDCAD    0.35635
# 13     NZDUSD    0.32733
# 14     AUDUSD    0.32733
# 15     GBPAUD    0.32733
# 16     CHFJPY    0.21822
# 17     EURGBP    0.21822
# 18     GBPUSD    0.21822
# 19     GBPJPY    0.08909
# 20     USDJPY    0.08909
# 21     CADJPY    0.08909
# 22     AUDJPY    0.08909
# 23     NZDJPY    0.08909
# 24     EURUSD    0.08909
# 25     EURJPY    0.08909
# 26     CADCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
