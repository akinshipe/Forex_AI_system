# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:13:46.657877

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDCHF    0.36876     EURCHF    0.38052     EURCHF    0.47076
# 1      EURCHF    0.35588     GBPAUD    0.27866     EURGBP    0.40825
# 2      CADCHF    0.28824     CADCHF    0.27866     EURUSD    0.37500
# 3      NZDCHF    0.25223     EURGBP    0.26068     CADJPY    0.28721
# 4      GBPAUD    0.24418     NZDCHF    0.22172     EURAUD    0.25678
# 5      USDJPY    0.19485     USDCHF    0.22172     NZDCAD    0.25000
# 6      EURUSD    0.17138     CHFJPY    0.20180     AUDCAD    0.25000
# 7      EURNZD    0.17138     EURJPY    0.16477     CADCHF    0.25000
# 8      AUDCHF    0.17138     AUDCAD    0.16477     GBPAUD    0.25000
# 9      GBPCAD    0.16386     CADJPY    0.14382     AUDUSD    0.20412
# 10     EURCAD    0.15743     AUDCHF    0.14382     CHFJPY    0.20412
# 11     GBPCHF    0.15743     USDJPY    0.12585     NZDCHF    0.20412
# 12     CHFJPY    0.15743     GBPJPY    0.10702     GBPJPY    0.17118
# 13     GBPUSD    0.12721     NZDCAD    0.10702     GBPCAD    0.17118
# 14     GBPJPY    0.12721     USDCAD    0.08597     AUDNZD    0.17118
# 15     NZDUSD    0.09054     GBPUSD    0.08597     NZDUSD    0.13363
# 16     EURJPY    0.09054     EURNZD    0.08597     AUDCHF    0.12309
# 17     AUDNZD    0.07711     AUDNZD    0.06727     EURJPY    0.12309
# 18     CADJPY    0.07114     GBPCAD    0.06727     EURNZD    0.12309
# 19     EURAUD    0.05366     EURCAD    0.06727     AUDJPY    0.12309
# 20     AUDCAD    0.05366     AUDUSD    0.04977     GBPCHF    0.08909
# 21     AUDUSD    0.04670     EURUSD    0.03257     EURCAD    0.08206
# 22     USDCAD    0.04013     EURAUD    0.03257     NZDJPY    0.08206
# 23     NZDJPY    0.03382     AUDJPY    0.02746     USDCAD    0.08206
# 24     EURGBP    0.03382     GBPCHF    0.02746     GBPUSD    0.04167
# 25     NZDCAD    0.02150     NZDUSD    0.02746     USDCHF    0.04167
# 26     AUDJPY    0.00321     NZDJPY    0.00899     USDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADCHF    0.50000     EURCAD    0.61237  ...     GBPCHF    0.36218
# 1      EURUSD    0.40000     EURCHF    0.61237  ...     USDCHF    0.31807
# 2      EURCHF    0.40000     CADJPY    0.61237  ...     EURNZD    0.27743
# 3      NZDCAD    0.28868     EURAUD    0.50000  ...     NZDCAD    0.25732
# 4      AUDJPY    0.28868     NZDCAD    0.50000  ...     USDJPY    0.24418
# 5      AUDUSD    0.28868     USDCAD    0.50000  ...     EURCHF    0.24418
# 6      EURAUD    0.28868     EURJPY    0.50000  ...     CADCHF    0.23775
# 7      EURJPY    0.28868     AUDCAD    0.50000  ...     EURGBP    0.23775
# 8      NZDUSD    0.21320     NZDCHF    0.50000  ...     EURCAD    0.20192
# 9      GBPJPY    0.20000     CHFJPY    0.40825  ...     EURUSD    0.19678
# 10     EURGBP    0.18898     AUDCHF    0.40825  ...     AUDCAD    0.16871
# 11     CADJPY    0.18898     GBPJPY    0.32733  ...     AUDUSD    0.16386
# 12     NZDCHF    0.18898     AUDJPY    0.32733  ...     AUDNZD    0.12179
# 13     GBPCHF    0.10660     NZDJPY    0.32733  ...     GBPCAD    0.11859
# 14     USDCHF    0.10000     CADCHF    0.32733  ...     AUDCHF    0.11613
# 15     GBPUSD    0.10000     GBPUSD    0.25000  ...     NZDCHF    0.11613
# 16     EURNZD    0.09449     NZDUSD    0.25000  ...     CADJPY    0.11613
# 17     CHFJPY    0.09449     USDCHF    0.25000  ...     NZDJPY    0.08353
# 18     USDCAD    0.09449     AUDUSD    0.21822  ...     GBPUSD    0.08353
# 19     AUDCAD    0.09449     EURUSD    0.21822  ...     GBPJPY    0.08353
# 20     GBPCAD    0.00000     EURGBP    0.10206  ...     USDCAD    0.08006
# 21     GBPAUD    0.00000     GBPCAD    0.10206  ...     EURAUD    0.07462
# 22     EURCAD    0.00000     GBPCHF    0.10206  ...     EURJPY    0.04516
# 23     AUDCHF    0.00000     USDJPY    0.10206  ...     AUDJPY    0.04167
# 24     NZDJPY    0.00000     EURNZD    0.00000  ...     GBPAUD    0.04167
# 25     USDJPY    0.00000     GBPAUD    0.00000  ...     CHFJPY    0.03846
# 26     AUDNZD    0.00000     AUDNZD    0.00000  ...     NZDUSD    0.03548
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.40825     USDCHF    0.66667     AUDUSD    0.76376
# 1      USDCHF    0.33634     AUDUSD    0.61237     USDCHF    0.66144
# 2      EURNZD    0.33634     USDJPY    0.40825     GBPAUD    0.60010
# 3      AUDUSD    0.33634     GBPAUD    0.37500     NZDUSD    0.56408
# 4      EURCHF    0.28284     NZDUSD    0.31180     USDJPY    0.49099
# 5      GBPAUD    0.26726     EURNZD    0.28721     EURUSD    0.37796
# 6      CADCHF    0.26726     EURCHF    0.25678     GBPUSD    0.37796
# 7      EURGBP    0.26726     EURAUD    0.25678     AUDCHF    0.32733
# 8      USDJPY    0.26726     GBPUSD    0.25000     NZDCAD    0.32733
# 9      GBPJPY    0.20751     EURUSD    0.25000     EURAUD    0.32733
# 10     EURUSD    0.20751     CADCHF    0.25000     AUDJPY    0.21822
# 11     NZDCAD    0.20751     NZDCAD    0.16667     CHFJPY    0.19643
# 12     EURCAD    0.20000     AUDCAD    0.16667     AUDCAD    0.19643
# 13     AUDCAD    0.13608     GBPCHF    0.13363     EURNZD    0.19643
# 14     AUDCHF    0.13363     CADJPY    0.12309     EURCHF    0.18898
# 15     CADJPY    0.13363     AUDJPY    0.12309     CADCHF    0.09449
# 16     EURAUD    0.06917     EURCAD    0.12309     GBPJPY    0.09449
# 17     USDCAD    0.06727     USDCAD    0.08206     CADJPY    0.07143
# 18     NZDCHF    0.06727     AUDCHF    0.08206     EURGBP    0.07143
# 19     GBPUSD    0.06727     NZDJPY    0.08206     NZDCHF    0.07143
# 20     AUDNZD    0.06667     EURJPY    0.08206     USDCAD    0.07143
# 21     GBPCAD    0.06667     AUDNZD    0.04280     EURCAD    0.05455
# 22     CHFJPY    0.06667     GBPCAD    0.04280     EURJPY    0.05455
# 23     NZDUSD    0.00000     GBPJPY    0.04280     GBPCAD    0.05455
# 24     NZDJPY    0.00000     NZDCHF    0.00000     NZDJPY    0.05455
# 25     AUDJPY    0.00000     CHFJPY    0.00000     AUDNZD    0.05455
# 26     EURJPY    0.00000     EURGBP    0.00000     GBPCHF    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDUSD    0.65465
# 1      GBPAUD    0.60000
# 2      USDCHF    0.50000
# 3      NZDUSD    0.50000
# 4      EURCHF    0.40825
# 5      GBPCAD    0.40825
# 6      AUDCHF    0.40825
# 7      EURGBP    0.40825
# 8      USDJPY    0.40825
# 9      CADCHF    0.21822
# 10     NZDJPY    0.21822
# 11     GBPJPY    0.21822
# 12     EURUSD    0.21822
# 13     AUDJPY    0.21822
# 14     EURJPY    0.20000
# 15     EURAUD    0.20000
# 16     NZDCAD    0.20000
# 17     AUDCAD    0.20000
# 18     EURNZD    0.20000
# 19     AUDNZD    0.20000
# 20     NZDCHF    0.20000
# 21     USDCAD    0.20000
# 22     EURCAD    0.00000
# 23     CADJPY    0.00000
# 24     CHFJPY    0.00000
# 25     GBPUSD    0.00000
# 26     GBPCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
