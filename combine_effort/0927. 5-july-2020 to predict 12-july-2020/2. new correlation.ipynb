# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 18:28:57.683266

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.34542     USDJPY    0.36711     GBPUSD    0.49237
# 1      NZDCAD    0.28710     GBPUSD    0.27217     AUDUSD    0.45833
# 2      GBPUSD    0.28710     AUDNZD    0.25000     AUDCAD    0.45833
# 3      USDCHF    0.25223     EURJPY    0.25000     NZDUSD    0.40825
# 4      EURUSD    0.24175     GBPCAD    0.19094     NZDCAD    0.38516
# 5      EURJPY    0.20646     AUDCAD    0.16477     USDJPY    0.37500
# 6      AUDCAD    0.20646     CHFJPY    0.11111     GBPCHF    0.28721
# 7      NZDUSD    0.19678     USDCHF    0.11111     EURGBP    0.25678
# 8      CADCHF    0.19678     EURGBP    0.10985     EURJPY    0.25000
# 9      CHFJPY    0.18286     EURCAD    0.08183     CHFJPY    0.25000
# 10     EURCAD    0.16116     AUDUSD    0.08183     NZDJPY    0.25000
# 11     AUDUSD    0.15198     EURNZD    0.08183     EURAUD    0.25000
# 12     CADJPY    0.11613     NZDJPY    0.05648     USDCAD    0.20412
# 13     AUDCHF    0.07114     EURUSD    0.05455     CADJPY    0.16667
# 14     EURAUD    0.07114     AUDCHF    0.05455     EURNZD    0.16667
# 15     NZDJPY    0.06580     NZDUSD    0.05455     AUDJPY    0.12309
# 16     AUDNZD    0.06580     GBPCHF    0.05455     AUDNZD    0.12309
# 17     GBPCHF    0.06580     AUDJPY    0.02778     AUDCHF    0.12309
# 18     AUDJPY    0.06204     EURCHF    0.02778     EURUSD    0.12309
# 19     GBPJPY    0.04516     EURAUD    0.02746     GBPJPY    0.08206
# 20     EURNZD    0.04516     GBPAUD    0.02746     NZDCHF    0.08206
# 21     USDCAD    0.04516     NZDCHF    0.02746     EURCHF    0.08206
# 22     EURGBP    0.04516     NZDCAD    0.02746     USDCHF    0.04167
# 23     NZDCHF    0.03548     CADJPY    0.00000     GBPAUD    0.00000
# 24     GBPAUD    0.02597     GBPJPY    0.00000     EURCAD    0.00000
# 25     GBPCAD    0.02597     CADCHF    0.00000     GBPCAD    0.00000
# 26     EURCHF    0.02597     USDCAD    0.00000     CADCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDCAD    0.49237     NZDJPY    0.42857  ...     GBPCAD    0.38858
# 1      AUDUSD    0.49237     AUDUSD    0.42857  ...     GBPUSD    0.31795
# 2      GBPUSD    0.49099     NZDUSD    0.42857  ...     GBPCHF    0.29778
# 3      USDJPY    0.44444     AUDCAD    0.42857  ...     USDJPY    0.28123
# 4      NZDCAD    0.40825     USDJPY    0.35635  ...     CADCHF    0.24982
# 5      GBPCHF    0.38889     NZDCAD    0.32733  ...     EURGBP    0.23684
# 6      NZDUSD    0.38889     AUDNZD    0.21822  ...     AUDUSD    0.21627
# 7      EURGBP    0.32733     EURNZD    0.21822  ...     EURUSD    0.20261
# 8      NZDJPY    0.28868     GBPCAD    0.21822  ...     EURCAD    0.20261
# 9      EURCHF    0.21822     GBPUSD    0.21822  ...     AUDCHF    0.19025
# 10     USDCAD    0.21822     CADJPY    0.21822  ...     NZDCAD    0.15573
# 11     EURUSD    0.21822     EURCHF    0.21822  ...     AUDCAD    0.15573
# 12     GBPJPY    0.21822     GBPCHF    0.21822  ...     GBPJPY    0.15573
# 13     EURAUD    0.18464     NZDCHF    0.08909  ...     GBPAUD    0.14368
# 14     AUDCHF    0.18464     GBPJPY    0.08909  ...     EURAUD    0.10895
# 15     CADCHF    0.16667     USDCAD    0.08909  ...     USDCHF    0.10895
# 16     GBPAUD    0.16667     EURUSD    0.08909  ...     EURCHF    0.10123
# 17     CADJPY    0.16667     AUDJPY    0.08909  ...     CADJPY    0.08760
# 18     AUDJPY    0.11111     EURCAD    0.08909  ...     USDCAD    0.07462
# 19     USDCHF    0.11111     CADCHF    0.08909  ...     CHFJPY    0.06732
# 20     EURJPY    0.11111     USDCHF    0.04762  ...     AUDJPY    0.06732
# 21     NZDCHF    0.11111     EURAUD    0.04762  ...     NZDJPY    0.03309
# 22     CHFJPY    0.11111     EURJPY    0.04762  ...     AUDNZD    0.03309
# 23     AUDNZD    0.11111     GBPAUD    0.04762  ...     NZDCHF    0.00649
# 24     EURNZD    0.05455     AUDCHF    0.04762  ...     EURJPY    0.00649
# 25     EURCAD    0.05455     CHFJPY    0.04762  ...     EURNZD    0.00649
# 26     GBPCAD    0.05455     EURGBP    0.04762  ...     NZDUSD    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.41349     USDJPY    0.61237     USDJPY    0.66667
# 1      GBPCAD    0.39551     CHFJPY    0.40825     GBPAUD    0.38889
# 2      USDJPY    0.38620     EURJPY    0.40825     CHFJPY    0.38889
# 3      EURGBP    0.35747     EURGBP    0.31449     NZDCHF    0.38889
# 4      CHFJPY    0.30208     AUDJPY    0.30151     AUDJPY    0.38889
# 5      GBPUSD    0.20180     GBPCHF    0.30151     EURJPY    0.38889
# 6      NZDCAD    0.18552     NZDJPY    0.20412     NZDJPY    0.28868
# 7      GBPAUD    0.18552     CADJPY    0.20412     EURCAD    0.21822
# 8      AUDJPY    0.16477     USDCHF    0.20412     GBPJPY    0.21822
# 9      EURJPY    0.16477     GBPCAD    0.20000     EURGBP    0.21822
# 10     AUDNZD    0.16477     GBPAUD    0.20000     EURUSD    0.21822
# 11     EURCHF    0.16477     NZDCAD    0.10483     EURCHF    0.21822
# 12     EURCAD    0.14382     EURCHF    0.10050     AUDCHF    0.18464
# 13     EURNZD    0.14382     EURUSD    0.10050     AUDUSD    0.18464
# 14     AUDCHF    0.12585     AUDNZD    0.10050     EURAUD    0.18464
# 15     NZDJPY    0.10702     GBPJPY    0.10050     AUDCAD    0.18464
# 16     NZDCHF    0.08597     GBPUSD    0.10050     CADJPY    0.16667
# 17     CADCHF    0.06727     NZDCHF    0.10050     USDCHF    0.16667
# 18     GBPJPY    0.06727     AUDCHF    0.10050     GBPCHF    0.16667
# 19     CADJPY    0.06727     NZDUSD    0.00000     CADCHF    0.11111
# 20     USDCAD    0.06727     CADCHF    0.00000     NZDUSD    0.11111
# 21     EURAUD    0.04977     EURAUD    0.00000     AUDNZD    0.11111
# 22     AUDCAD    0.04977     EURNZD    0.00000     NZDCAD    0.06804
# 23     USDCHF    0.02746     AUDUSD    0.00000     GBPCAD    0.05455
# 24     NZDUSD    0.00899     USDCAD    0.00000     GBPUSD    0.05455
# 25     AUDUSD    0.00899     AUDCAD    0.00000     EURNZD    0.05455
# 26     EURUSD    0.00899     EURCAD    0.00000     USDCAD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.81650
# 1      EURJPY    0.65465
# 2      CHFJPY    0.65465
# 3      NZDCHF    0.40825
# 4      EURUSD    0.40825
# 5      AUDJPY    0.40825
# 6      GBPJPY    0.40825
# 7      USDCHF    0.21822
# 8      AUDCAD    0.21822
# 9      NZDJPY    0.21822
# 10     EURAUD    0.21822
# 11     GBPAUD    0.21822
# 12     EURGBP    0.21822
# 13     AUDCHF    0.21822
# 14     NZDUSD    0.21822
# 15     AUDUSD    0.21822
# 16     GBPUSD    0.20000
# 17     GBPCAD    0.20000
# 18     EURCHF    0.20000
# 19     GBPCHF    0.20000
# 20     EURNZD    0.20000
# 21     CADJPY    0.20000
# 22     AUDNZD    0.20000
# 23     CADCHF    0.00000
# 24     EURCAD    0.00000
# 25     USDCAD    0.00000
# 26     NZDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           1
