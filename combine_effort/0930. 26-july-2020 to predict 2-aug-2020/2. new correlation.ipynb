# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:07:28.271273

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.29778     GBPUSD    0.27217     GBPUSD    0.31449
# 1      NZDCAD    0.26449     AUDNZD    0.25000     GBPCHF    0.31449
# 2      GBPUSD    0.26449     USDJPY    0.24716     EURGBP    0.25678
# 3      USDCHF    0.18286     EURJPY    0.19767     USDJPY    0.25678
# 4      NZDUSD    0.16871     EURAUD    0.19094     NZDCAD    0.25163
# 5      AUDCAD    0.14943     EURCAD    0.19094     AUDUSD    0.25163
# 6      EURJPY    0.13497     GBPCAD    0.19094     AUDCAD    0.25163
# 7      EURUSD    0.13497     AUDCAD    0.16477     NZDUSD    0.24232
# 8      CADCHF    0.12157     CHFJPY    0.16477     EURAUD    0.24232
# 9      EURCAD    0.12157     NZDJPY    0.11111     USDCAD    0.17911
# 10     GBPCHF    0.11580     USDCHF    0.11111     CADJPY    0.17911
# 11     CHFJPY    0.11580     CADCHF    0.10985     EURCAD    0.17911
# 12     CADJPY    0.10895     NZDUSD    0.10985     NZDJPY    0.17118
# 13     AUDUSD    0.08760     USDCAD    0.10985     AUDCHF    0.17118
# 14     AUDJPY    0.08515     EURGBP    0.10985     CHFJPY    0.17118
# 15     AUDCHF    0.06204     AUDUSD    0.08183     NZDCHF    0.10483
# 16     EURGBP    0.05366     AUDCHF    0.05455     GBPJPY    0.10483
# 17     NZDJPY    0.04728     GBPCHF    0.05455     GBPCAD    0.10483
# 18     EURNZD    0.04052     CADJPY    0.05455     GBPAUD    0.10483
# 19     NZDCHF    0.04052     GBPAUD    0.02778     CADCHF    0.10483
# 20     USDCAD    0.04052     NZDCAD    0.02778     EURJPY    0.09890
# 21     AUDNZD    0.03309     NZDCHF    0.02746     USDCHF    0.04280
# 22     EURAUD    0.02764     EURCHF    0.02746     EURNZD    0.04280
# 23     GBPJPY    0.01959     EURNZD    0.02746     AUDJPY    0.03161
# 24     GBPAUD    0.01478     AUDJPY    0.02746     EURCHF    0.03161
# 25     GBPCAD    0.01478     GBPJPY    0.00000     EURUSD    0.03161
# 26     EURCHF    0.00649     EURUSD    0.00000     AUDNZD    0.03161
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDJPY    0.34247     GBPCAD    0.40825  ...     GBPCAD    0.46321
# 1      GBPCHF    0.34247     AUDNZD    0.33333  ...     GBPUSD    0.34542
# 2      NZDCAD    0.30151     GBPCHF    0.33333  ...     GBPCHF    0.33333
# 3      AUDCAD    0.30151     EURNZD    0.33333  ...     AUDUSD    0.27783
# 4      AUDUSD    0.30151     CADCHF    0.33333  ...     USDJPY    0.25000
# 5      GBPUSD    0.26189     USDJPY    0.27217  ...     EURCAD    0.24495
# 6      USDCHF    0.21320     USDCAD    0.27217  ...     CADCHF    0.24495
# 7      EURCAD    0.21320     CADJPY    0.27217  ...     EURGBP    0.22935
# 8      EURJPY    0.21320     EURAUD    0.27217  ...     EURUSD    0.22935
# 9      EURGBP    0.21320     NZDCHF    0.27217  ...     AUDCAD    0.21506
# 10     NZDUSD    0.18464     GBPUSD    0.27217  ...     GBPAUD    0.21506
# 11     EURAUD    0.18464     GBPAUD    0.27217  ...     EURCHF    0.21246
# 12     EURNZD    0.18464     NZDJPY    0.21822  ...     NZDCAD    0.18094
# 13     AUDNZD    0.18464     AUDJPY    0.21822  ...     AUDCHF    0.18094
# 14     GBPAUD    0.12309     EURCAD    0.21822  ...     GBPJPY    0.18094
# 15     EURCHF    0.12309     EURGBP    0.21822  ...     USDCHF    0.09869
# 16     CHFJPY    0.12309     GBPJPY    0.21822  ...     CHFJPY    0.08333
# 17     AUDJPY    0.12309     AUDCHF    0.21822  ...     USDCAD    0.08165
# 18     EURUSD    0.12309     CHFJPY    0.21822  ...     EURJPY    0.06553
# 19     AUDCHF    0.10660     EURCHF    0.21822  ...     EURAUD    0.06553
# 20     NZDJPY    0.10660     NZDUSD    0.21822  ...     AUDJPY    0.05046
# 21     GBPJPY    0.04029     EURJPY    0.16667  ...     NZDUSD    0.03269
# 22     GBPCAD    0.04029     AUDUSD    0.16667  ...     NZDJPY    0.01701
# 23     NZDCHF    0.04029     EURUSD    0.16667  ...     CADJPY    0.01638
# 24     CADJPY    0.04029     AUDCAD    0.16667  ...     NZDCHF    0.00000
# 25     USDCAD    0.04029     NZDCAD    0.16667  ...     EURNZD    0.00000
# 26     CADCHF    0.04029     USDCHF    0.11111  ...     AUDNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.43939     USDJPY    0.66667     USDJPY    0.76376
# 1      GBPCHF    0.35460     USDCHF    0.37500     NZDCHF    0.49099
# 2      GBPCAD    0.32733     CHFJPY    0.25000     AUDJPY    0.38889
# 3      EURGBP    0.30208     EURGBP    0.25000     EURAUD    0.38889
# 4      CHFJPY    0.30208     GBPCAD    0.20412     GBPAUD    0.38889
# 5      EURJPY    0.19767     GBPAUD    0.20412     CHFJPY    0.38889
# 6      EURCAD    0.19094     GBPCHF    0.20412     CADCHF    0.32733
# 7      NZDCAD    0.16667     CADCHF    0.20412     USDCHF    0.28868
# 8      GBPAUD    0.16667     NZDCHF    0.20412     NZDJPY    0.28868
# 9      AUDJPY    0.16477     GBPUSD    0.20412     EURJPY    0.28868
# 10     EURNZD    0.16477     EURJPY    0.17118     AUDCHF    0.28868
# 11     EURCHF    0.16477     NZDCAD    0.13363     GBPJPY    0.21822
# 12     GBPUSD    0.13608     AUDCAD    0.13363     EURNZD    0.16667
# 13     NZDJPY    0.11111     AUDUSD    0.13363     AUDNZD    0.11111
# 14     AUDNZD    0.11111     AUDJPY    0.12309     EURCHF    0.11111
# 15     CADCHF    0.10985     EURAUD    0.12309     NZDUSD    0.11111
# 16     USDCAD    0.10985     USDCAD    0.12309     EURUSD    0.11111
# 17     AUDCAD    0.10985     EURCAD    0.08206     AUDUSD    0.06804
# 18     AUDCHF    0.08183     CADJPY    0.08206     AUDCAD    0.06804
# 19     EURAUD    0.05455     EURUSD    0.08206     NZDCAD    0.06804
# 20     CADJPY    0.05455     EURCHF    0.08206     GBPUSD    0.05455
# 21     AUDUSD    0.05455     NZDUSD    0.08206     GBPCAD    0.05455
# 22     USDCHF    0.02778     AUDNZD    0.08206     GBPCHF    0.05455
# 23     NZDCHF    0.02746     AUDCHF    0.04167     CADJPY    0.05455
# 24     NZDUSD    0.02746     EURNZD    0.04167     USDCAD    0.05455
# 25     GBPJPY    0.00000     NZDJPY    0.04167     EURCAD    0.00000
# 26     EURUSD    0.00000     GBPJPY    0.00000     EURGBP    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.66667
# 1      NZDCHF    0.66667
# 2      EURAUD    0.66667
# 3      CHFJPY    0.53452
# 4      AUDCHF    0.53452
# 5      AUDJPY    0.53452
# 6      GBPJPY    0.53452
# 7      NZDUSD    0.53452
# 8      NZDJPY    0.53452
# 9      EURNZD    0.40825
# 10     USDCHF    0.40825
# 11     CADCHF    0.40825
# 12     AUDCAD    0.40825
# 13     GBPCHF    0.40825
# 14     AUDUSD    0.40825
# 15     NZDCAD    0.40825
# 16     EURUSD    0.40825
# 17     EURJPY    0.40825
# 18     EURGBP    0.35635
# 19     EURCAD    0.35635
# 20     GBPAUD    0.25000
# 21     CADJPY    0.25000
# 22     GBPCAD    0.25000
# 23     GBPUSD    0.25000
# 24     USDCAD    0.25000
# 25     EURCHF    0.08909
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
