# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:08:50.270838

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.26449     EURAUD    0.25882     NZDCAD    0.42857
# 1      GBPUSD    0.26449     EURJPY    0.24456     AUDCAD    0.37796
# 2      USDJPY    0.26108     GBPUSD    0.20751     AUDUSD    0.37796
# 3      USDCHF    0.14943     AUDNZD    0.19767     GBPUSD    0.37284
# 4      AUDCAD    0.14943     AUDCAD    0.19767     GBPCHF    0.37284
# 5      NZDUSD    0.13497     NZDJPY    0.19767     EURAUD    0.37284
# 6      GBPCHF    0.11580     CHFJPY    0.19767     NZDUSD    0.31180
# 7      CHFJPY    0.11580     USDJPY    0.17216     NZDJPY    0.31180
# 8      CADJPY    0.10895     EURCAD    0.17216     USDJPY    0.28511
# 9      EURJPY    0.10123     GBPCAD    0.17216     EURGBP    0.28511
# 10     EURUSD    0.10123     EURGBP    0.12016     AUDCHF    0.25163
# 11     CADCHF    0.08760     NZDUSD    0.12016     USDCAD    0.21822
# 12     EURCAD    0.08760     AUDUSD    0.10702     NZDCHF    0.21822
# 13     AUDJPY    0.08515     CADCHF    0.08472     GBPJPY    0.15352
# 14     NZDJPY    0.08181     GBPAUD    0.08472     EURCAD    0.13363
# 15     USDCAD    0.07462     AUDCHF    0.06917     EURNZD    0.13363
# 16     AUDCHF    0.06204     GBPCHF    0.06917     AUDJPY    0.08909
# 17     EURGBP    0.05366     CADJPY    0.06917     AUDNZD    0.08909
# 18     AUDUSD    0.05366     AUDJPY    0.05648     CHFJPY    0.08909
# 19     NZDCHF    0.04052     NZDCAD    0.05648     EURCHF    0.08909
# 20     EURCHF    0.04052     USDCHF    0.05648     EURUSD    0.08909
# 21     AUDNZD    0.03309     NZDCHF    0.03257     GBPCAD    0.06580
# 22     GBPJPY    0.01959     EURNZD    0.03257     CADJPY    0.06580
# 23     GBPAUD    0.01478     USDCAD    0.03257     CADCHF    0.06580
# 24     GBPCAD    0.01478     GBPJPY    0.01849     EURJPY    0.02288
# 25     EURAUD    0.00649     EURCHF    0.01849     USDCHF    0.02288
# 26     EURNZD    0.00649     EURUSD    0.01849     GBPAUD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDJPY    0.35355     GBPCAD    0.50918  ...     GBPCAD    0.46321
# 1      NZDUSD    0.35355     CADCHF    0.40825  ...     GBPUSD    0.34542
# 2      NZDCAD    0.30151     NZDCHF    0.33333  ...     GBPCHF    0.33333
# 3      AUDUSD    0.25000     USDJPY    0.33333  ...     AUDUSD    0.31127
# 4      AUDCAD    0.25000     EURAUD    0.33333  ...     USDJPY    0.28123
# 5      GBPCAD    0.20045     GBPCHF    0.33333  ...     EURCAD    0.27783
# 6      USDJPY    0.20045     GBPAUD    0.33333  ...     CADCHF    0.27783
# 7      GBPCHF    0.20045     EURGBP    0.27217  ...     EURUSD    0.26318
# 8      CADCHF    0.20045     NZDJPY    0.27217  ...     EURCHF    0.24495
# 9      USDCAD    0.13363     CADJPY    0.27217  ...     EURGBP    0.22935
# 10     EURAUD    0.13363     EURNZD    0.27217  ...     AUDCAD    0.21506
# 11     CADJPY    0.13363     GBPUSD    0.27217  ...     GBPAUD    0.21506
# 12     NZDCHF    0.13363     AUDNZD    0.27217  ...     NZDCAD    0.18094
# 13     GBPUSD    0.13363     USDCAD    0.27217  ...     AUDCHF    0.18094
# 14     USDCHF    0.07538     AUDCHF    0.21822  ...     GBPJPY    0.18094
# 15     EURCAD    0.07538     GBPJPY    0.21822  ...     USDCHF    0.13234
# 16     EURJPY    0.07538     CHFJPY    0.21822  ...     EURJPY    0.09869
# 17     EURNZD    0.06804     EURCHF    0.21822  ...     CHFJPY    0.08333
# 18     AUDNZD    0.06804     EURCAD    0.21822  ...     NZDUSD    0.06553
# 19     GBPAUD    0.06804     NZDUSD    0.21822  ...     AUDJPY    0.05046
# 20     GBPJPY    0.06804     AUDJPY    0.21822  ...     NZDJPY    0.05046
# 21     AUDCHF    0.00000     NZDCAD    0.21822  ...     USDCAD    0.04903
# 22     AUDJPY    0.00000     EURJPY    0.16667  ...     EURAUD    0.03269
# 23     CHFJPY    0.00000     AUDUSD    0.16667  ...     EURNZD    0.03269
# 24     EURCHF    0.00000     EURUSD    0.16667  ...     CADJPY    0.01638
# 25     EURUSD    0.00000     AUDCAD    0.16667  ...     NZDCHF    0.00000
# 26     EURGBP    0.00000     USDCHF    0.11111  ...     AUDNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.52579     USDJPY    0.66375     USDJPY    0.76376
# 1      GBPCHF    0.34586     USDCHF    0.34066     EURAUD    0.49099
# 2      CHFJPY    0.33887     NZDCHF    0.31449     NZDCHF    0.49099
# 3      GBPCAD    0.31175     GBPAUD    0.31449     USDCHF    0.43082
# 4      EURGBP    0.29579     EURAUD    0.24232     GBPAUD    0.38889
# 5      EURJPY    0.24456     EURGBP    0.24232     CADCHF    0.32733
# 6      GBPAUD    0.22591     CADCHF    0.17911     NZDJPY    0.28868
# 7      GBPUSD    0.20751     GBPUSD    0.17911     AUDJPY    0.28868
# 8      NZDJPY    0.19767     GBPCAD    0.17911     CHFJPY    0.28868
# 9      AUDJPY    0.19767     GBPCHF    0.17911     AUDCHF    0.28868
# 10     EURCAD    0.17216     CHFJPY    0.17118     NZDCAD    0.18464
# 11     EURCHF    0.15714     NZDJPY    0.17118     EURJPY    0.18464
# 12     EURAUD    0.12016     AUDJPY    0.17118     EURNZD    0.16667
# 13     EURNZD    0.10702     USDCAD    0.10483     EURCAD    0.12309
# 14     NZDCAD    0.08472     AUDCHF    0.09890     AUDNZD    0.11111
# 15     AUDCAD    0.08472     EURJPY    0.09890     GBPJPY    0.11111
# 16     USDCHF    0.08472     AUDCAD    0.06052     AUDUSD    0.06804
# 17     CADCHF    0.08472     AUDUSD    0.06052     AUDCAD    0.06804
# 18     AUDCHF    0.06917     EURNZD    0.04280     GBPCAD    0.05455
# 19     CADJPY    0.06917     NZDUSD    0.04280     GBPUSD    0.05455
# 20     AUDNZD    0.05648     EURUSD    0.04280     GBPCHF    0.05455
# 21     NZDCHF    0.03257     EURCAD    0.04280     CADJPY    0.05455
# 22     AUDUSD    0.03257     EURCHF    0.04280     USDCAD    0.05455
# 23     USDCAD    0.03257     AUDNZD    0.04280     EURCHF    0.00000
# 24     GBPJPY    0.01849     CADJPY    0.03161     NZDUSD    0.00000
# 25     NZDUSD    0.01849     GBPJPY    0.03161     EURUSD    0.00000
# 26     EURUSD    0.01849     NZDCAD    0.02288     EURGBP    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.81650
# 1      EURAUD    0.81650
# 2      NZDCHF    0.81650
# 3      NZDJPY    0.66667
# 4      EURNZD    0.58333
# 5      CADCHF    0.58333
# 6      AUDCHF    0.53452
# 7      CHFJPY    0.53452
# 8      GBPJPY    0.53452
# 9      AUDJPY    0.53452
# 10     NZDCAD    0.53452
# 11     NZDUSD    0.53452
# 12     GBPCHF    0.40825
# 13     AUDUSD    0.40825
# 14     AUDCAD    0.40825
# 15     GBPAUD    0.40825
# 16     EURJPY    0.40825
# 17     EURUSD    0.40825
# 18     USDCHF    0.40825
# 19     EURCAD    0.35635
# 20     GBPUSD    0.25000
# 21     USDCAD    0.25000
# 22     CADJPY    0.25000
# 23     EURGBP    0.16667
# 24     AUDNZD    0.16667
# 25     GBPCAD    0.08909
# 26     EURCHF    0.08909
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
