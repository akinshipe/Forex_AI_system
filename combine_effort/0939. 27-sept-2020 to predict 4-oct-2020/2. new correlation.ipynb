# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 11:55:01.501651

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.34542     NZDCAD    0.38889     EURUSD    0.37796
# 1      NZDCAD    0.26212     GBPUSD    0.35460     NZDCAD    0.29013
# 2      GBPUSD    0.26212     USDJPY    0.32733     GBPUSD    0.29013
# 3      AUDCAD    0.19852     AUDUSD    0.28868     EURCAD    0.23570
# 4      USDCHF    0.16667     AUDCAD    0.28868     AUDUSD    0.18157
# 5      CHFJPY    0.16667     NZDUSD    0.27217     AUDCAD    0.18157
# 6      NZDUSD    0.16330     EURUSD    0.25000     CHFJPY    0.18157
# 7      AUDNZD    0.14804     CHFJPY    0.25000     USDJPY    0.17408
# 8      EURUSD    0.14804     NZDJPY    0.21822     USDCHF    0.12599
# 9      EURCAD    0.13074     EURAUD    0.21822     EURCHF    0.12599
# 10     EURJPY    0.11580     USDCHF    0.11111     EURJPY    0.12599
# 11     NZDJPY    0.11580     EURNZD    0.10985     GBPCAD    0.11547
# 12     CADJPY    0.11440     EURCAD    0.08183     NZDJPY    0.11547
# 13     AUDCHF    0.09869     AUDJPY    0.08183     EURAUD    0.11547
# 14     AUDUSD    0.09829     AUDNZD    0.08183     GBPAUD    0.11547
# 15     EURCHF    0.08165     GBPCHF    0.08183     AUDNZD    0.11547
# 16     CADCHF    0.08165     USDCAD    0.08183     NZDCHF    0.11547
# 17     GBPCAD    0.06553     EURJPY    0.05648     NZDUSD    0.11547
# 18     USDCAD    0.06553     GBPAUD    0.05455     AUDCHF    0.06052
# 19     GBPAUD    0.04963     GBPJPY    0.05455     GBPJPY    0.05803
# 20     AUDJPY    0.04963     NZDCHF    0.05455     CADCHF    0.05803
# 21     GBPJPY    0.04903     CADJPY    0.05455     EURNZD    0.05803
# 22     EURGBP    0.04903     CADCHF    0.05455     CADJPY    0.05803
# 23     GBPCHF    0.03309     EURGBP    0.05455     AUDJPY    0.05803
# 24     NZDCHF    0.03269     AUDCHF    0.02778     GBPCHF    0.05803
# 25     EURAUD    0.00000     EURCHF    0.02778     EURGBP    0.05803
# 26     EURNZD    0.00000     GBPCAD    0.00000     USDCAD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.36364     NZDCAD    0.58333  ...     GBPCAD    0.31366
# 1      NZDCAD    0.34247     EURUSD    0.53452  ...     GBPCHF    0.22531
# 2      EURCAD    0.26189     EURCAD    0.40825  ...     EURGBP    0.19678
# 3      USDJPY    0.26189     GBPAUD    0.35635  ...     EURCHF    0.16116
# 4      GBPUSD    0.26189     USDCAD    0.35635  ...     CADCHF    0.16116
# 5      EURJPY    0.21320     USDCHF    0.25000  ...     AUDUSD    0.15198
# 6      AUDCHF    0.21320     USDJPY    0.25000  ...     CHFJPY    0.14804
# 7      CHFJPY    0.18464     AUDUSD    0.25000  ...     AUDCAD    0.14368
# 8      USDCAD    0.12309     AUDCAD    0.25000  ...     GBPAUD    0.14368
# 9      GBPAUD    0.12309     CHFJPY    0.25000  ...     USDJPY    0.13636
# 10     AUDCAD    0.10660     GBPUSD    0.25000  ...     GBPJPY    0.11613
# 11     AUDUSD    0.10660     NZDJPY    0.16667  ...     EURCAD    0.11613
# 12     NZDJPY    0.04029     CADJPY    0.16667  ...     AUDCHF    0.10714
# 13     AUDJPY    0.04029     EURNZD    0.16667  ...     USDCHF    0.09869
# 14     CADJPY    0.04029     EURAUD    0.16667  ...     GBPUSD    0.07114
# 15     EURNZD    0.04029     EURJPY    0.16667  ...     NZDCAD    0.07114
# 16     EURAUD    0.04029     EURGBP    0.16667  ...     EURJPY    0.06204
# 17     EURGBP    0.04029     NZDCHF    0.16667  ...     NZDCHF    0.03548
# 18     AUDNZD    0.04029     AUDCHF    0.16667  ...     CADJPY    0.03548
# 19     GBPCAD    0.04029     CADCHF    0.16667  ...     EURUSD    0.02597
# 20     GBPJPY    0.04029     GBPCHF    0.16667  ...     AUDNZD    0.02597
# 21     NZDCHF    0.04029     NZDUSD    0.16667  ...     AUDJPY    0.01959
# 22     CADCHF    0.04029     EURCHF    0.10206  ...     NZDJPY    0.01959
# 23     GBPCHF    0.04029     GBPCAD    0.00000  ...     USDCAD    0.00970
# 24     NZDUSD    0.04029     GBPJPY    0.00000  ...     NZDUSD    0.00000
# 25     EURCHF    0.02273     AUDJPY    0.00000  ...     EURAUD    0.00000
# 26     USDCHF    0.02273     AUDNZD    0.00000  ...     EURNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      CHFJPY    0.21822     EURAUD    0.40000     NZDCHF    0.46429
# 1      EURGBP    0.20536     NZDCHF    0.40000     NZDCAD    0.46429
# 2      EURAUD    0.20536     CHFJPY    0.31449     EURAUD    0.46429
# 3      USDJPY    0.20536     EURNZD    0.30151     EURNZD    0.46429
# 4      GBPAUD    0.19643     NZDCAD    0.30151     EURCHF    0.34247
# 5      NZDCHF    0.19643     GBPUSD    0.30151     GBPUSD    0.33929
# 6      GBPCHF    0.19643     USDCHF    0.21822     EURUSD    0.26189
# 7      EURCHF    0.19094     EURCHF    0.21822     CHFJPY    0.21822
# 8      USDCHF    0.19094     EURUSD    0.21822     CADJPY    0.19643
# 9      GBPCAD    0.13363     NZDJPY    0.20000     AUDNZD    0.19643
# 10     EURNZD    0.12585     NZDUSD    0.20000     NZDJPY    0.19643
# 11     NZDCAD    0.08183     GBPAUD    0.20000     NZDUSD    0.19643
# 12     EURUSD    0.08183     AUDCHF    0.10483     EURJPY    0.18898
# 13     EURCAD    0.07143     AUDUSD    0.10483     AUDCHF    0.09449
# 14     NZDJPY    0.07143     AUDCAD    0.10483     AUDUSD    0.09449
# 15     GBPUSD    0.07143     AUDJPY    0.10050     AUDCAD    0.09449
# 16     GBPJPY    0.07143     CADJPY    0.10050     AUDJPY    0.07143
# 17     AUDJPY    0.07143     EURGBP    0.10050     EURCAD    0.07143
# 18     CADJPY    0.07143     GBPJPY    0.10050     EURGBP    0.07143
# 19     CADCHF    0.07143     CADCHF    0.10050     GBPCAD    0.07143
# 20     AUDNZD    0.06250     GBPCHF    0.10050     GBPJPY    0.07143
# 21     USDCAD    0.06250     USDJPY    0.10050     CADCHF    0.07143
# 22     AUDCHF    0.05455     EURCAD    0.00000     GBPCHF    0.07143
# 23     AUDUSD    0.04725     EURJPY    0.00000     USDJPY    0.07143
# 24     AUDCAD    0.04725     GBPCAD    0.00000     GBPAUD    0.05455
# 25     EURJPY    0.01849     USDCAD    0.00000     USDCAD    0.05455
# 26     NZDUSD    0.00000     AUDNZD    0.00000     USDCHF    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCHF    0.50000
# 1      USDJPY    0.40825
# 2      NZDCAD    0.40825
# 3      EURJPY    0.40825
# 4      EURAUD    0.40825
# 5      CADJPY    0.40825
# 6      EURNZD    0.40825
# 7      NZDCHF    0.40825
# 8      GBPUSD    0.40825
# 9      EURUSD    0.21822
# 10     USDCAD    0.21822
# 11     GBPAUD    0.21822
# 12     AUDNZD    0.20000
# 13     GBPCAD    0.20000
# 14     AUDJPY    0.20000
# 15     GBPJPY    0.20000
# 16     EURCAD    0.20000
# 17     NZDJPY    0.00000
# 18     AUDCAD    0.00000
# 19     USDCHF    0.00000
# 20     AUDCHF    0.00000
# 21     CADCHF    0.00000
# 22     CHFJPY    0.00000
# 23     GBPCHF    0.00000
# 24     NZDUSD    0.00000
# 25     AUDUSD    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
