# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:00:22.035425

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.26704     EURJPY    0.50830     EURJPY    0.66339
# 1      CHFJPY    0.25732     CHFJPY    0.44444     EURAUD    0.42366
# 2      NZDJPY    0.22999     EURUSD    0.40825     AUDCHF    0.42366
# 3      GBPJPY    0.22999     EURNZD    0.33887     CADCHF    0.36690
# 4      NZDUSD    0.22018     USDCHF    0.30208     CHFJPY    0.34066
# 5      GBPUSD    0.22018     EURGBP    0.30208     EURNZD    0.31868
# 6      AUDNZD    0.21246     AUDNZD    0.24716     CADJPY    0.30261
# 7      CADJPY    0.21246     AUDJPY    0.22591     AUDCAD    0.25163
# 8      EURUSD    0.20646     AUDUSD    0.22591     EURGBP    0.24232
# 9      AUDUSD    0.19219     CADJPY    0.22591     EURUSD    0.24232
# 10     EURNZD    0.15743     EURCAD    0.21822     AUDNZD    0.20588
# 11     AUDCHF    0.15549     GBPAUD    0.21822     GBPUSD    0.18157
# 12     NZDCAD    0.14417     NZDUSD    0.20787     NZDCAD    0.18157
# 13     AUDJPY    0.13678     AUDCHF    0.19767     GBPCAD    0.17118
# 14     USDJPY    0.11859     GBPJPY    0.19305     USDJPY    0.17118
# 15     GBPCHF    0.09237     NZDJPY    0.19305     USDCHF    0.17118
# 16     USDCAD    0.08760     GBPUSD    0.14434     NZDCHF    0.10483
# 17     USDCHF    0.08353     EURAUD    0.14434     GBPJPY    0.10483
# 18     GBPAUD    0.08006     CADCHF    0.14434     GBPAUD    0.10483
# 19     EURGBP    0.08006     USDJPY    0.13608     NZDUSD    0.10483
# 20     GBPCAD    0.07711     GBPCAD    0.11111     GBPCHF    0.06052
# 21     AUDCAD    0.05836     USDCAD    0.10985     AUDJPY    0.06052
# 22     NZDCHF    0.05338     GBPCHF    0.08909     USDCAD    0.04280
# 23     EURCHF    0.05338     EURCHF    0.08472     EURCAD    0.03161
# 24     EURAUD    0.03002     AUDCAD    0.08472     EURCHF    0.02288
# 25     CADCHF    0.00990     NZDCAD    0.05939     AUDUSD    0.02288
# 26     EURCAD    0.00000     NZDCHF    0.03077     NZDJPY    0.01468
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.85280     EURJPY    0.76376  ...     GBPUSD    0.18711
# 1      CHFJPY    0.43082     CHFJPY    0.50000  ...     AUDNZD    0.16667
# 2      EURUSD    0.42640     AUDCHF    0.40825  ...     CADJPY    0.16667
# 3      USDCHF    0.36364     EURCAD    0.40825  ...     EURUSD    0.14804
# 4      EURAUD    0.36364     NZDJPY    0.37500  ...     CHFJPY    0.13457
# 5      AUDCHF    0.36364     CADJPY    0.37500  ...     EURAUD    0.10206
# 6      CADCHF    0.36364     EURGBP    0.32733  ...     NZDCHF    0.10206
# 7      CADJPY    0.31818     EURAUD    0.32733  ...     EURCAD    0.08165
# 8      AUDNZD    0.30151     GBPCAD    0.32733  ...     EURGBP    0.08165
# 9      EURCHF    0.21320     GBPUSD    0.32733  ...     CADCHF    0.05046
# 10     GBPJPY    0.20696     AUDNZD    0.32733  ...     USDCAD    0.04963
# 11     USDJPY    0.18464     CADCHF    0.32733  ...     USDJPY    0.04903
# 12     EURNZD    0.18464     USDJPY    0.32733  ...     GBPJPY    0.03501
# 13     EURCAD    0.18464     EURUSD    0.32733  ...     NZDCAD    0.03501
# 14     EURGBP    0.18464     USDCHF    0.25000  ...     AUDCAD    0.03501
# 15     GBPUSD    0.10660     NZDCHF    0.21822  ...     NZDJPY    0.03501
# 16     GBPCAD    0.10660     EURCHF    0.21822  ...     GBPCHF    0.03364
# 17     AUDUSD    0.10660     GBPJPY    0.16667  ...     AUDCHF    0.01724
# 18     AUDCAD    0.10660     GBPCHF    0.16667  ...     EURJPY    0.01724
# 19     GBPCHF    0.07538     NZDUSD    0.10206  ...     EURCHF    0.01701
# 20     NZDCHF    0.07538     AUDJPY    0.10206  ...     AUDJPY    0.01701
# 21     NZDJPY    0.07538     NZDCAD    0.10206  ...     NZDUSD    0.01701
# 22     GBPAUD    0.04029     GBPAUD    0.00000  ...     USDCHF    0.01638
# 23     USDCAD    0.04029     AUDUSD    0.00000  ...     EURNZD    0.01638
# 24     NZDUSD    0.02273     USDCAD    0.00000  ...     GBPCAD    0.01638
# 25     AUDJPY    0.02273     EURNZD    0.00000  ...     GBPAUD    0.00000
# 26     NZDCAD    0.02273     AUDCAD    0.00000  ...     AUDUSD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.28868     GBPUSD    0.37796     GBPCAD    0.35355
# 1      EURUSD    0.27217     GBPCHF    0.37796     GBPUSD    0.35355
# 2      USDJPY    0.27217     GBPCAD    0.31180     EURNZD    0.27217
# 3      USDCHF    0.24716     AUDNZD    0.28571     GBPCHF    0.25000
# 4      AUDNZD    0.24716     GBPAUD    0.21822     USDCAD    0.20045
# 5      CADJPY    0.22591     GBPJPY    0.21822     GBPAUD    0.20045
# 6      AUDCAD    0.19767     EURCHF    0.19048     GBPJPY    0.19612
# 7      EURCAD    0.19094     AUDCAD    0.19048     AUDNZD    0.16667
# 8      CADCHF    0.14434     EURGBP    0.15352     NZDJPY    0.16667
# 9      NZDCHF    0.12309     USDCHF    0.13363     NZDCHF    0.16667
# 10     CHFJPY    0.11111     USDCAD    0.13363     NZDCAD    0.07538
# 11     GBPCAD    0.11111     USDJPY    0.13363     AUDJPY    0.07538
# 12     EURGBP    0.10985     EURAUD    0.12599     CADJPY    0.07538
# 13     USDCAD    0.10985     AUDCHF    0.12599     EURAUD    0.07538
# 14     NZDCAD    0.08909     NZDCAD    0.12599     USDCHF    0.07538
# 15     NZDUSD    0.08909     AUDJPY    0.12599     AUDCHF    0.07538
# 16     EURNZD    0.08472     CADJPY    0.12599     CADCHF    0.07538
# 17     AUDCHF    0.08472     EURUSD    0.06580     NZDUSD    0.07538
# 18     AUDJPY    0.08472     EURCAD    0.06580     EURCAD    0.06804
# 19     EURJPY    0.08472     CADCHF    0.05455     CHFJPY    0.06804
# 20     GBPAUD    0.08183     NZDUSD    0.05455     USDJPY    0.06804
# 21     GBPCHF    0.05939     NZDCHF    0.05455     EURGBP    0.06804
# 22     EURCHF    0.05648     EURJPY    0.04762     EURJPY    0.00000
# 23     AUDUSD    0.05648     AUDUSD    0.04762     EURCHF    0.00000
# 24     GBPJPY    0.03217     NZDJPY    0.03056     AUDUSD    0.00000
# 25     NZDJPY    0.03217     EURNZD    0.02288     AUDCAD    0.00000
# 26     EURAUD    0.00000     CHFJPY    0.02288     EURUSD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.42857
# 1      GBPUSD    0.42857
# 2      USDCHF    0.21822
# 3      NZDJPY    0.21822
# 4      EURNZD    0.21822
# 5      GBPAUD    0.21822
# 6      GBPJPY    0.21822
# 7      CADJPY    0.21822
# 8      CHFJPY    0.21822
# 9      GBPCHF    0.21822
# 10     AUDUSD    0.21822
# 11     USDCAD    0.21822
# 12     AUDCAD    0.21822
# 13     AUDJPY    0.08909
# 14     AUDCHF    0.08909
# 15     NZDUSD    0.08909
# 16     NZDCAD    0.08909
# 17     EURCAD    0.08909
# 18     EURAUD    0.04762
# 19     EURGBP    0.04762
# 20     EURJPY    0.04762
# 21     NZDCHF    0.04762
# 22     CADCHF    0.04762
# 23     EURCHF    0.04762
# 24     USDJPY    0.04762
# 25     EURUSD    0.04762
# 26     AUDNZD    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
