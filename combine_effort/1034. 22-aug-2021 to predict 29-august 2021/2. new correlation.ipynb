# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 19:24:21.576377

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.36775     GBPCHF    0.30556     NZDCAD    0.50252
# 1      EURJPY    0.26318     NZDCAD    0.27217     GBPUSD    0.40000
# 2      CADJPY    0.22531     EURUSD    0.25000     EURUSD    0.40000
# 3      CHFJPY    0.21914     CADJPY    0.22591     AUDCAD    0.40000
# 4      NZDUSD    0.21914     GBPJPY    0.22591     NZDUSD    0.40000
# 5      USDCHF    0.21753     AUDCAD    0.21822     EURNZD    0.31449
# 6      GBPJPY    0.21434     AUDCHF    0.21822     AUDCHF    0.31449
# 7      AUDNZD    0.19678     GBPUSD    0.19094     GBPCHF    0.30151
# 8      AUDCAD    0.18831     NZDUSD    0.19094     GBPCAD    0.21822
# 9      NZDCAD    0.18094     EURGBP    0.16667     EURCAD    0.20412
# 10     GBPUSD    0.18094     EURNZD    0.16477     USDCHF    0.20000
# 11     EURCAD    0.16116     EURCAD    0.13608     CADJPY    0.20000
# 12     AUDUSD    0.11613     AUDNZD    0.13608     GBPJPY    0.20000
# 13     GBPAUD    0.10123     EURAUD    0.11111     EURGBP    0.20000
# 14     GBPCHF    0.09869     NZDCHF    0.10985     NZDCHF    0.20000
# 15     EURGBP    0.09054     CADCHF    0.08472     CHFJPY    0.10483
# 16     USDJPY    0.09054     EURJPY    0.08472     CADCHF    0.10050
# 17     NZDJPY    0.08292     USDCAD    0.08183     EURJPY    0.10050
# 18     EURAUD    0.08058     GBPCAD    0.05939     USDCAD    0.10050
# 19     EURNZD    0.08058     USDJPY    0.05648     USDJPY    0.10050
# 20     AUDJPY    0.07114     USDCHF    0.05648     GBPAUD    0.00000
# 21     EURCHF    0.07114     EURCHF    0.05455     EURAUD    0.00000
# 22     NZDCHF    0.05313     AUDJPY    0.05455     EURCHF    0.00000
# 23     GBPCAD    0.04083     CHFJPY    0.02778     AUDUSD    0.00000
# 24     AUDCHF    0.03548     AUDUSD    0.02778     AUDJPY    0.00000
# 25     USDCAD    0.03548     GBPAUD    0.02746     NZDJPY    0.00000
# 26     CADCHF    0.00672     NZDJPY    0.00000     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66667     NZDCAD    0.81650  ...     CADJPY    0.20261
# 1      NZDCAD    0.66667     AUDCAD    0.81650  ...     AUDJPY    0.20064
# 2      NZDUSD    0.66667     NZDUSD    0.81650  ...     EURCAD    0.20000
# 3      USDCHF    0.57735     EURUSD    0.66667  ...     NZDJPY    0.17150
# 4      EURNZD    0.49237     GBPUSD    0.66667  ...     EURJPY    0.16330
# 5      AUDCAD    0.49099     USDCHF    0.53452  ...     USDCHF    0.16116
# 6      GBPUSD    0.49099     AUDCHF    0.53452  ...     AUDCAD    0.16116
# 7      EURCAD    0.44444     EURNZD    0.53452  ...     AUDNZD    0.16013
# 8      USDJPY    0.28868     GBPAUD    0.53452  ...     EURUSD    0.16013
# 9      AUDCHF    0.28868     EURGBP    0.53452  ...     GBPCAD    0.12666
# 10     NZDCHF    0.21822     USDJPY    0.53452  ...     NZDCHF    0.12361
# 11     GBPJPY    0.21822     AUDUSD    0.53452  ...     GBPAUD    0.12157
# 12     EURGBP    0.21822     EURAUD    0.40825  ...     EURGBP    0.12039
# 13     GBPCHF    0.21822     AUDNZD    0.27217  ...     USDJPY    0.12039
# 14     GBPAUD    0.18464     CHFJPY    0.25000  ...     EURAUD    0.12000
# 15     AUDUSD    0.18464     USDCAD    0.25000  ...     EURNZD    0.12000
# 16     AUDNZD    0.18464     CADCHF    0.25000  ...     CADCHF    0.08333
# 17     GBPCAD    0.12309     GBPCHF    0.25000  ...     GBPUSD    0.08165
# 18     CADCHF    0.11111     GBPJPY    0.25000  ...     AUDCHF    0.08006
# 19     EURJPY    0.11111     EURCHF    0.25000  ...     AUDUSD    0.08006
# 20     EURCHF    0.11111     NZDJPY    0.16667  ...     USDCAD    0.08006
# 21     USDCAD    0.11111     NZDCHF    0.16667  ...     GBPJPY    0.04222
# 22     EURAUD    0.06804     EURCAD    0.16667  ...     CHFJPY    0.04120
# 23     CADJPY    0.05455     EURJPY    0.08909  ...     NZDUSD    0.04120
# 24     NZDJPY    0.05455     GBPCAD    0.08909  ...     EURCHF    0.04013
# 25     CHFJPY    0.00000     AUDJPY    0.08909  ...     NZDCAD    0.00000
# 26     AUDJPY    0.00000     CADJPY    0.00000  ...     GBPCHF    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.28284     AUDCAD    0.31449     EURCAD    0.43082
# 1      AUDCAD    0.26726     EURCAD    0.25678     USDCHF    0.42640
# 2      GBPCAD    0.21822     NZDCAD    0.24232     EURGBP    0.34247
# 3      USDCHF    0.20751     GBPCHF    0.24232     CADJPY    0.26189
# 4      CADJPY    0.20751     EURJPY    0.24232     NZDJPY    0.26189
# 5      EURJPY    0.20751     GBPCAD    0.20588     AUDCAD    0.26189
# 6      EURCAD    0.20000     NZDJPY    0.17118     AUDCHF    0.21320
# 7      EURAUD    0.13608     USDCHF    0.10483     AUDJPY    0.21320
# 8      EURGBP    0.13608     NZDCHF    0.10483     USDCAD    0.18464
# 9      EURUSD    0.13608     CADJPY    0.10483     NZDCAD    0.18464
# 10     EURCHF    0.13363     GBPJPY    0.10483     NZDUSD    0.18464
# 11     AUDJPY    0.13363     GBPUSD    0.10483     EURUSD    0.18464
# 12     GBPJPY    0.06917     EURGBP    0.10483     CADCHF    0.18464
# 13     USDJPY    0.06917     NZDUSD    0.10483     EURCHF    0.12309
# 14     CADCHF    0.06917     EURUSD    0.10483     EURJPY    0.12309
# 15     NZDCHF    0.06727     AUDCHF    0.09890     USDJPY    0.10660
# 16     GBPAUD    0.06727     CHFJPY    0.09890     CHFJPY    0.10660
# 17     EURNZD    0.06727     EURNZD    0.09890     EURAUD    0.07538
# 18     AUDNZD    0.06667     GBPAUD    0.04280     GBPJPY    0.04029
# 19     NZDCAD    0.06667     EURCHF    0.04280     GBPUSD    0.04029
# 20     USDCAD    0.00000     AUDUSD    0.04280     GBPCHF    0.04029
# 21     CHFJPY    0.00000     AUDJPY    0.04280     NZDCHF    0.04029
# 22     AUDUSD    0.00000     AUDNZD    0.04280     GBPCAD    0.02273
# 23     GBPCHF    0.00000     CADCHF    0.03161     EURNZD    0.02273
# 24     GBPUSD    0.00000     USDCAD    0.03161     GBPAUD    0.02273
# 25     AUDCHF    0.00000     USDJPY    0.03161     AUDUSD    0.02273
# 26     NZDUSD    0.00000     EURAUD    0.02288     AUDNZD    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCAD    0.40825
# 1      CADJPY    0.33333
# 2      NZDCAD    0.33333
# 3      AUDCAD    0.33333
# 4      NZDUSD    0.33333
# 5      CHFJPY    0.27217
# 6      EURUSD    0.27217
# 7      USDCAD    0.27217
# 8      GBPCHF    0.27217
# 9      EURCHF    0.27217
# 10     CADCHF    0.27217
# 11     NZDJPY    0.27217
# 12     NZDCHF    0.27217
# 13     GBPUSD    0.27217
# 14     GBPJPY    0.27217
# 15     USDCHF    0.21822
# 16     AUDJPY    0.21822
# 17     EURNZD    0.21822
# 18     EURGBP    0.21822
# 19     EURJPY    0.21822
# 20     GBPAUD    0.21822
# 21     GBPCAD    0.21822
# 22     AUDCHF    0.21822
# 23     AUDUSD    0.21822
# 24     USDJPY    0.21822
# 25     EURAUD    0.16667
# 26     AUDNZD    0.11111
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
