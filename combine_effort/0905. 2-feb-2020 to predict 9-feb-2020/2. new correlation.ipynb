# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 11:01:01.380801

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.28090     USDCHF    0.41349     USDCHF    0.41414
# 1      CHFJPY    0.24495     CADCHF    0.33929     EURAUD    0.41414
# 2      USDCHF    0.24019     USDJPY    0.33036     USDJPY    0.39394
# 3      EURUSD    0.24019     CADJPY    0.33036     CADJPY    0.39394
# 4      EURNZD    0.20064     NZDCAD    0.33036     EURCAD    0.30151
# 5      NZDCAD    0.20000     EURUSD    0.26726     NZDCAD    0.30151
# 6      GBPJPY    0.20000     EURAUD    0.26726     CADCHF    0.30151
# 7      NZDUSD    0.16116     USDCAD    0.20536     AUDCHF    0.30151
# 8      USDJPY    0.16013     EURCAD    0.20536     USDCAD    0.28721
# 9      GBPUSD    0.16013     EURNZD    0.19643     AUDJPY    0.28721
# 10     AUDUSD    0.12157     AUDJPY    0.19094     EURCHF    0.24232
# 11     EURAUD    0.12039     CHFJPY    0.15714     EURNZD    0.19192
# 12     EURCAD    0.12039     GBPUSD    0.14382     EURGBP    0.17911
# 13     AUDCAD    0.12000     NZDUSD    0.13363     GBPUSD    0.12309
# 14     CADCHF    0.12000     AUDCHF    0.13363     NZDUSD    0.12309
# 15     AUDNZD    0.08058     EURJPY    0.12585     AUDUSD    0.12309
# 16     EURCHF    0.08058     EURCHF    0.08183     EURUSD    0.10050
# 17     AUDJPY    0.08006     GBPJPY    0.07143     GBPCAD    0.08206
# 18     NZDJPY    0.08006     AUDCAD    0.06250     NZDJPY    0.08206
# 19     EURGBP    0.08006     NZDJPY    0.05455     AUDCAD    0.08206
# 20     GBPCHF    0.04052     EURGBP    0.05455     GBPCHF    0.06580
# 21     NZDCHF    0.04013     GBPCAD    0.05455     GBPAUD    0.03161
# 22     GBPAUD    0.04000     AUDUSD    0.05455     CHFJPY    0.03161
# 23     GBPCAD    0.04000     GBPCHF    0.04725     GBPJPY    0.01010
# 24     CADJPY    0.04000     GBPAUD    0.00899     EURJPY    0.01010
# 25     AUDCHF    0.00000     AUDNZD    0.00899     NZDCHF    0.01010
# 26     USDCAD    0.00000     NZDCHF    0.00000     AUDNZD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDJPY    0.60010     EURNZD    0.80178  ...     EURJPY    0.33307
# 1      CADJPY    0.60010     AUDNZD    0.65465  ...     GBPCAD    0.32233
# 2      EURAUD    0.49099     NZDUSD    0.65465  ...     GBPJPY    0.32233
# 3      AUDJPY    0.44444     NZDCHF    0.53452  ...     EURUSD    0.28710
# 4      USDCHF    0.38889     NZDCAD    0.53452  ...     GBPUSD    0.28710
# 5      AUDCHF    0.32733     AUDCAD    0.53452  ...     AUDUSD    0.26449
# 6      USDCAD    0.32733     AUDUSD    0.53452  ...     CHFJPY    0.26318
# 7      AUDUSD    0.28868     EURAUD    0.53452  ...     GBPCHF    0.22531
# 8      EURNZD    0.28868     AUDCHF    0.53452  ...     EURGBP    0.20646
# 9      EURCHF    0.28868     NZDJPY    0.52381  ...     AUDJPY    0.19678
# 10     EURCAD    0.21822     AUDJPY    0.52381  ...     NZDCAD    0.16116
# 11     AUDNZD    0.21822     GBPCAD    0.52381  ...     CADCHF    0.16116
# 12     CADCHF    0.21822     USDCHF    0.42857  ...     EURCAD    0.15198
# 13     GBPCAD    0.16667     EURCHF    0.42857  ...     NZDUSD    0.13636
# 14     NZDJPY    0.16667     CADJPY    0.35635  ...     AUDCHF    0.12581
# 15     GBPCHF    0.12309     GBPCHF    0.35635  ...     USDCHF    0.11613
# 16     GBPUSD    0.11111     USDCAD    0.35635  ...     EURAUD    0.09054
# 17     GBPJPY    0.11111     USDJPY    0.35635  ...     GBPAUD    0.08058
# 18     GBPAUD    0.11111     GBPAUD    0.32733  ...     CADJPY    0.08058
# 19     AUDCAD    0.11111     EURCAD    0.21822  ...     AUDCAD    0.08058
# 20     NZDCHF    0.05455     CHFJPY    0.21822  ...     EURCHF    0.05519
# 21     EURJPY    0.05455     EURUSD    0.21822  ...     AUDNZD    0.05519
# 22     NZDUSD    0.05455     CADCHF    0.08909  ...     NZDJPY    0.04516
# 23     EURUSD    0.05455     EURJPY    0.08909  ...     USDJPY    0.04516
# 24     NZDCAD    0.05455     GBPUSD    0.04762  ...     USDCAD    0.03548
# 25     CHFJPY    0.00000     GBPJPY    0.04762  ...     NZDCHF    0.00970
# 26     EURGBP    0.00000     EURGBP    0.04762  ...     EURNZD    0.00970
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      CADCHF    0.46371     GBPCAD    0.69752     GBPCAD    0.60010
# 1      GBPCAD    0.44444     AUDUSD    0.53340     EURCAD    0.46429
# 2      EURUSD    0.40825     GBPCHF    0.50443     CADCHF    0.46429
# 3      AUDUSD    0.38889     EURUSD    0.50252     AUDUSD    0.37796
# 4      GBPUSD    0.38446     EURCAD    0.50252     GBPCHF    0.34247
# 5      EURCAD    0.32733     CADCHF    0.50252     EURUSD    0.33929
# 6      GBPJPY    0.32733     GBPUSD    0.49237     NZDCAD    0.33929
# 7      EURJPY    0.30208     EURJPY    0.41414     EURJPY    0.33929
# 8      GBPCHF    0.28868     GBPJPY    0.39394     EURAUD    0.33929
# 9      AUDCHF    0.27217     AUDCAD    0.32824     GBPUSD    0.32733
# 10     CHFJPY    0.22591     AUDCHF    0.30151     GBPJPY    0.32733
# 11     NZDCAD    0.21822     NZDCAD    0.30151     AUDCAD    0.21822
# 12     AUDCAD    0.21822     EURCHF    0.24232     AUDCHF    0.19643
# 13     USDCAD    0.19094     EURAUD    0.21212     NZDCHF    0.19643
# 14     EURGBP    0.16667     NZDCHF    0.19192     EURNZD    0.18898
# 15     EURAUD    0.13608     GBPAUD    0.17911     EURGBP    0.18898
# 16     EURCHF    0.11111     EURGBP    0.17911     CHFJPY    0.18898
# 17     USDCHF    0.10985     CHFJPY    0.17911     EURCHF    0.09449
# 18     GBPAUD    0.10985     USDCAD    0.12309     CADJPY    0.07143
# 19     EURNZD    0.08183     AUDJPY    0.08206     AUDNZD    0.07143
# 20     CADJPY    0.08183     NZDUSD    0.08206     NZDUSD    0.07143
# 21     USDJPY    0.08183     NZDJPY    0.08206     USDCAD    0.07143
# 22     AUDJPY    0.02778     USDCHF    0.01010     USDJPY    0.07143
# 23     NZDJPY    0.02778     CADJPY    0.01010     GBPAUD    0.05455
# 24     AUDNZD    0.02746     EURNZD    0.01010     AUDJPY    0.05455
# 25     NZDCHF    0.00000     USDJPY    0.01010     NZDJPY    0.05455
# 26     NZDUSD    0.00000     AUDNZD    0.01010     USDCHF    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCAD    0.81650
# 1      GBPCAD    0.80178
# 2      NZDCAD    0.66667
# 3      CADCHF    0.58333
# 4      GBPCHF    0.58333
# 5      AUDNZD    0.40825
# 6      EURUSD    0.40825
# 7      GBPJPY    0.35635
# 8      GBPUSD    0.35635
# 9      EURGBP    0.35635
# 10     USDCAD    0.25000
# 11     NZDCHF    0.25000
# 12     USDJPY    0.25000
# 13     AUDCAD    0.25000
# 14     AUDUSD    0.25000
# 15     CADJPY    0.25000
# 16     AUDCHF    0.25000
# 17     EURAUD    0.25000
# 18     EURNZD    0.16667
# 19     EURJPY    0.16667
# 20     CHFJPY    0.10206
# 21     GBPAUD    0.10206
# 22     AUDJPY    0.08909
# 23     NZDJPY    0.08909
# 24     EURCHF    0.08909
# 25     USDCHF    0.08909
# 26     NZDUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
