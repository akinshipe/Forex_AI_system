# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:14:28.481948

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPUSD    0.31253     EURUSD    0.42857     EURUSD    0.59914
# 1      AUDNZD    0.26212     GBPUSD    0.34717     USDCHF    0.45833
# 2      CHFJPY    0.25000     CHFJPY    0.30861     EURGBP    0.40825
# 3      USDCHF    0.25000     EURNZD    0.30826     CHFJPY    0.38516
# 4      EURUSD    0.23028     EURGBP    0.27890     AUDUSD    0.38516
# 5      EURJPY    0.21868     USDCHF    0.26984     GBPUSD    0.38516
# 6      AUDUSD    0.19852     AUDUSD    0.26984     AUDCHF    0.37500
# 7      NZDJPY    0.16667     AUDNZD    0.26245     EURNZD    0.37500
# 8      GBPCAD    0.16330     AUDCHF    0.25661     EURCAD    0.28721
# 9      NZDUSD    0.16330     GBPCAD    0.21822     AUDNZD    0.28721
# 10     USDJPY    0.16330     GBPJPY    0.19623     GBPCHF    0.28721
# 11     EURNZD    0.16330     NZDJPY    0.19623     NZDJPY    0.25000
# 12     AUDCAD    0.11580     AUDJPY    0.19623     GBPJPY    0.25000
# 13     AUDJPY    0.11580     NZDUSD    0.19623     AUDJPY    0.25000
# 14     AUDCHF    0.11440     EURCAD    0.17496     EURJPY    0.25000
# 15     USDCAD    0.09829     USDCAD    0.15430     NZDUSD    0.25000
# 16     GBPJPY    0.09829     EURJPY    0.15430     NZDCHF    0.16667
# 17     EURGBP    0.09829     GBPCHF    0.11664     GBPAUD    0.16667
# 18     GBPAUD    0.08333     GBPAUD    0.11664     EURAUD    0.16667
# 19     NZDCHF    0.08165     CADJPY    0.08909     NZDCAD    0.12309
# 20     GBPCHF    0.08165     CADCHF    0.08909     GBPCAD    0.12309
# 21     EURAUD    0.04903     NZDCHF    0.05939     USDCAD    0.08909
# 22     CADJPY    0.04903     EURAUD    0.05939     CADCHF    0.04280
# 23     CADCHF    0.04903     EURCHF    0.04528     CADJPY    0.04167
# 24     NZDCAD    0.03309     NZDCAD    0.04528     AUDCAD    0.04167
# 25     EURCAD    0.00000     USDJPY    0.02916     EURCHF    0.04167
# 26     EURCHF    0.00000     AUDCAD    0.00000     USDJPY    0.04167
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66667     EURNZD    0.80178  ...     EURGBP    0.20773
# 1      EURNZD    0.57735     USDCHF    0.66667  ...     GBPCAD    0.20064
# 2      USDCHF    0.49099     EURJPY    0.66667  ...     GBPCHF    0.20064
# 3      EURGBP    0.49099     EURUSD    0.66667  ...     CHFJPY    0.18021
# 4      AUDNZD    0.44444     AUDNZD    0.58333  ...     USDJPY    0.12039
# 5      AUDUSD    0.38889     AUDUSD    0.53452  ...     NZDJPY    0.09829
# 6      CHFJPY    0.38889     GBPUSD    0.53452  ...     EURUSD    0.09054
# 7      GBPUSD    0.38889     AUDJPY    0.53452  ...     GBPUSD    0.09054
# 8      GBPCHF    0.32733     USDCAD    0.53452  ...     CADCHF    0.08353
# 9      EURCAD    0.32733     GBPJPY    0.53452  ...     EURAUD    0.08353
# 10     AUDCHF    0.32733     EURGBP    0.53452  ...     AUDCHF    0.07711
# 11     NZDUSD    0.28868     CHFJPY    0.53452  ...     CADJPY    0.07711
# 12     NZDCHF    0.28868     AUDCHF    0.40825  ...     GBPAUD    0.06553
# 13     AUDJPY    0.21822     NZDUSD    0.40825  ...     EURJPY    0.06118
# 14     EURJPY    0.21822     NZDJPY    0.40825  ...     AUDJPY    0.05366
# 15     GBPCAD    0.21822     NZDCHF    0.35635  ...     GBPJPY    0.04670
# 16     NZDJPY    0.18464     EURAUD    0.35635  ...     USDCAD    0.04670
# 17     GBPAUD    0.16667     NZDCAD    0.35635  ...     NZDCHF    0.04013
# 18     EURAUD    0.16667     GBPCAD    0.25000  ...     EURCHF    0.04013
# 19     GBPJPY    0.11111     CADJPY    0.25000  ...     NZDUSD    0.04013
# 20     USDJPY    0.11111     GBPCHF    0.25000  ...     EURCAD    0.04013
# 21     AUDCAD    0.11111     EURCAD    0.16667  ...     EURNZD    0.04013
# 22     USDCAD    0.11111     USDJPY    0.16667  ...     AUDNZD    0.03382
# 23     CADJPY    0.05455     AUDCAD    0.16667  ...     AUDUSD    0.02764
# 24     EURCHF    0.05455     GBPAUD    0.16667  ...     AUDCAD    0.02764
# 25     CADCHF    0.00000     CADCHF    0.08909  ...     NZDCAD    0.02764
# 26     NZDCAD    0.00000     EURCHF    0.00000  ...     USDCHF    0.01638
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.34586     GBPUSD    0.38982     CADJPY    0.33929
# 1      EURAUD    0.27217     CADJPY    0.32824     EURCAD    0.33929
# 2      NZDCHF    0.27217     USDJPY    0.28721     GBPUSD    0.32733
# 3      EURUSD    0.21822     EURCAD    0.21212     EURUSD    0.32733
# 4      NZDCAD    0.20751     AUDNZD    0.19192     USDJPY    0.32733
# 5      NZDJPY    0.20751     NZDCAD    0.19192     AUDCAD    0.32733
# 6      NZDUSD    0.20751     EURUSD    0.17911     USDCAD    0.21822
# 7      GBPJPY    0.20751     USDCAD    0.15352     USDCHF    0.19643
# 8      EURNZD    0.20180     AUDCHF    0.12309     EURGBP    0.19643
# 9      AUDCAD    0.14142     AUDJPY    0.12309     EURCHF    0.19643
# 10     CHFJPY    0.14142     EURJPY    0.12309     NZDUSD    0.18898
# 11     CADJPY    0.13608     EURGBP    0.10050     NZDCAD    0.18898
# 12     CADCHF    0.13608     NZDCHF    0.08206     NZDCHF    0.09449
# 13     AUDNZD    0.13363     GBPJPY    0.08206     CADCHF    0.09449
# 14     GBPCHF    0.13363     GBPAUD    0.08206     EURNZD    0.09449
# 15     USDCHF    0.07274     EURCHF    0.08206     GBPCHF    0.07143
# 16     AUDUSD    0.07274     EURAUD    0.08206     AUDCHF    0.07143
# 17     AUDCHF    0.06917     EURNZD    0.08206     GBPCAD    0.07143
# 18     EURCHF    0.06917     NZDUSD    0.08206     EURJPY    0.07143
# 19     AUDJPY    0.06917     NZDJPY    0.08206     AUDJPY    0.07143
# 20     EURGBP    0.06727     AUDCAD    0.08206     AUDUSD    0.05455
# 21     GBPCAD    0.06667     USDCHF    0.08206     CHFJPY    0.05455
# 22     GBPAUD    0.00000     CADCHF    0.03161     EURAUD    0.05455
# 23     EURJPY    0.00000     CHFJPY    0.03161     GBPAUD    0.05455
# 24     EURCAD    0.00000     AUDUSD    0.03161     GBPJPY    0.05455
# 25     USDCAD    0.00000     GBPCAD    0.01010     AUDNZD    0.05455
# 26     USDJPY    0.00000     GBPCHF    0.01010     NZDJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCHF    0.40825
# 1      GBPUSD    0.35635
# 2      GBPJPY    0.35635
# 3      CADJPY    0.25000
# 4      EURCAD    0.25000
# 5      GBPCHF    0.25000
# 6      GBPCAD    0.25000
# 7      USDCHF    0.16667
# 8      AUDCAD    0.16667
# 9      EURJPY    0.16667
# 10     GBPAUD    0.16667
# 11     AUDNZD    0.16667
# 12     USDJPY    0.16667
# 13     EURUSD    0.16667
# 14     NZDUSD    0.10206
# 15     NZDJPY    0.10206
# 16     NZDCHF    0.08909
# 17     CADCHF    0.08909
# 18     CHFJPY    0.08909
# 19     AUDUSD    0.08909
# 20     USDCAD    0.08909
# 21     EURAUD    0.08909
# 22     EURNZD    0.08909
# 23     AUDJPY    0.08909
# 24     NZDCAD    0.08909
# 25     EURGBP    0.08909
# 26     AUDCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
