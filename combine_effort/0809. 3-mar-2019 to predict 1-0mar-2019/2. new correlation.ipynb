# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 22:37:38.549164

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.24878     NZDUSD    0.27217     AUDNZD    0.38982
# 1      CADCHF    0.16864     USDCHF    0.25000     AUDCHF    0.38516
# 2      EURUSD    0.16530     AUDUSD    0.21822     EURAUD    0.38516
# 3      AUDUSD    0.15505     EURCHF    0.19767     GBPCAD    0.34066
# 4      EURAUD    0.14385     AUDNZD    0.19094     USDCHF    0.31868
# 5      AUDCHF    0.13613     USDCAD    0.16667     NZDCHF    0.31449
# 6      USDCHF    0.13457     AUDCAD    0.16477     EURNZD    0.31449
# 7      NZDCAD    0.12361     AUDCHF    0.16477     NZDUSD    0.31449
# 8      NZDJPY    0.12361     GBPUSD    0.16477     AUDUSD    0.24232
# 9      GBPAUD    0.09237     GBPJPY    0.16477     NZDCAD    0.24232
# 10     AUDJPY    0.08181     GBPCHF    0.13608     EURUSD    0.24232
# 11     GBPCHF    0.07258     NZDCAD    0.13608     EURGBP    0.17911
# 12     EURJPY    0.07258     NZDJPY    0.13608     CADCHF    0.17911
# 13     CHFJPY    0.07211     NZDCHF    0.13608     EURCHF    0.17118
# 14     USDJPY    0.05046     EURJPY    0.13608     USDCAD    0.12088
# 15     EURGBP    0.04120     CADJPY    0.13608     CHFJPY    0.12088
# 16     GBPCAD    0.04120     AUDJPY    0.11111     EURCAD    0.10483
# 17     GBPUSD    0.04120     GBPCAD    0.08472     CADJPY    0.10483
# 18     NZDCHF    0.04120     EURAUD    0.08183     NZDJPY    0.10483
# 19     NZDUSD    0.04120     GBPAUD    0.08183     GBPCHF    0.10483
# 20     AUDCAD    0.03364     EURUSD    0.08183     GBPAUD    0.10483
# 21     EURCAD    0.02988     CHFJPY    0.05648     AUDJPY    0.09890
# 22     CADJPY    0.02988     EURNZD    0.05455     USDJPY    0.04280
# 23     EURCHF    0.02988     CADCHF    0.05455     GBPUSD    0.03161
# 24     USDCAD    0.02150     EURGBP    0.05455     GBPJPY    0.03161
# 25     AUDNZD    0.02150     USDJPY    0.02746     EURJPY    0.03161
# 26     EURNZD    0.00990     EURCAD    0.00000     AUDCAD    0.03161
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.57735     EURUSD    0.80178  ...     EURNZD    0.23775
# 1      EURUSD    0.47246     EURAUD    0.65465  ...     USDCAD    0.20773
# 2      EURAUD    0.47246     USDCHF    0.53452  ...     CADCHF    0.19025
# 3      GBPCAD    0.40000     AUDCHF    0.53452  ...     AUDCHF    0.15198
# 4      AUDNZD    0.40000     EURCAD    0.53452  ...     NZDCHF    0.12039
# 5      GBPCHF    0.37796     GBPCAD    0.52381  ...     NZDUSD    0.12039
# 6      AUDCHF    0.37796     CADJPY    0.42857  ...     EURGBP    0.12039
# 7      NZDUSD    0.28868     GBPCHF    0.42857  ...     CHFJPY    0.10701
# 8      EURCHF    0.28868     EURCHF    0.42857  ...     USDJPY    0.09829
# 9      NZDCHF    0.28868     CADCHF    0.42857  ...     EURCAD    0.09054
# 10     CADJPY    0.28868     NZDCAD    0.21822  ...     GBPCHF    0.08353
# 11     EURNZD    0.28868     AUDCAD    0.21822  ...     GBPAUD    0.07711
# 12     CHFJPY    0.21320     NZDJPY    0.21822  ...     EURJPY    0.07711
# 13     AUDUSD    0.18898     EURNZD    0.21822  ...     CADJPY    0.07114
# 14     NZDCAD    0.18898     AUDNZD    0.21822  ...     AUDCAD    0.06553
# 15     EURGBP    0.18898     NZDCHF    0.21822  ...     EURUSD    0.05366
# 16     GBPAUD    0.10000     NZDUSD    0.21822  ...     GBPJPY    0.05366
# 17     EURJPY    0.09449     GBPJPY    0.08909  ...     NZDCAD    0.04013
# 18     EURCAD    0.09449     AUDUSD    0.08909  ...     GBPUSD    0.04013
# 19     GBPUSD    0.09449     USDCAD    0.08909  ...     GBPCAD    0.04013
# 20     AUDCAD    0.09449     USDJPY    0.08909  ...     NZDJPY    0.04013
# 21     CADCHF    0.09449     GBPAUD    0.04762  ...     AUDNZD    0.03382
# 22     USDCAD    0.00000     EURJPY    0.04762  ...     EURAUD    0.03382
# 23     USDJPY    0.00000     GBPUSD    0.04762  ...     AUDJPY    0.02764
# 24     GBPJPY    0.00000     CHFJPY    0.04762  ...     USDCHF    0.01638
# 25     AUDJPY    0.00000     AUDJPY    0.04762  ...     EURCHF    0.00970
# 26     NZDJPY    0.00000     EURGBP    0.04762  ...     AUDUSD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.40825     USDCAD    0.66375     USDJPY    0.66667
# 1      USDJPY    0.33634     EURUSD    0.61616     USDCAD    0.66667
# 2      USDCHF    0.27217     USDJPY    0.53340     EURUSD    0.60010
# 3      EURUSD    0.26726     USDCHF    0.45303     AUDUSD    0.49099
# 4      EURNZD    0.26726     AUDUSD    0.39394     USDCHF    0.38889
# 5      EURCAD    0.20000     NZDCHF    0.30151     NZDCHF    0.38889
# 6      NZDCHF    0.20000     NZDUSD    0.30151     NZDUSD    0.38889
# 7      CADCHF    0.13363     GBPCHF    0.30151     EURNZD    0.38889
# 8      GBPAUD    0.13363     EURNZD    0.30151     GBPCHF    0.32733
# 9      AUDNZD    0.13363     EURCHF    0.28721     GBPUSD    0.32733
# 10     AUDUSD    0.13363     CHFJPY    0.24232     CADCHF    0.32733
# 11     CHFJPY    0.06917     GBPUSD    0.21212     AUDNZD    0.28868
# 12     EURCHF    0.06917     EURGBP    0.21212     NZDCAD    0.21822
# 13     GBPCAD    0.06917     AUDNZD    0.21212     EURGBP    0.21822
# 14     GBPUSD    0.06727     CADCHF    0.19192     CHFJPY    0.18464
# 15     GBPJPY    0.06727     NZDCAD    0.19192     EURCHF    0.16667
# 16     AUDCAD    0.06727     EURAUD    0.12309     CADJPY    0.16667
# 17     AUDCHF    0.06727     GBPAUD    0.10050     GBPJPY    0.11111
# 18     CADJPY    0.06667     EURCAD    0.10050     AUDJPY    0.11111
# 19     NZDCAD    0.06667     CADJPY    0.10050     NZDJPY    0.11111
# 20     NZDJPY    0.06667     NZDJPY    0.10050     AUDCHF    0.05455
# 21     NZDUSD    0.06667     AUDCHF    0.08206     EURJPY    0.05455
# 22     EURJPY    0.06667     GBPCAD    0.03161     EURCAD    0.05455
# 23     GBPCHF    0.06667     AUDJPY    0.03161     EURAUD    0.05455
# 24     AUDJPY    0.00000     GBPJPY    0.01010     AUDCAD    0.05455
# 25     EURAUD    0.00000     EURJPY    0.01010     GBPCAD    0.00000
# 26     EURGBP    0.00000     AUDCAD    0.01010     GBPAUD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCAD    0.80178
# 1      AUDUSD    0.80178
# 2      NZDCHF    0.65465
# 3      NZDUSD    0.65465
# 4      EURNZD    0.65465
# 5      USDCHF    0.53452
# 6      USDJPY    0.53452
# 7      CADJPY    0.52381
# 8      CADCHF    0.52381
# 9      GBPAUD    0.42857
# 10     GBPCAD    0.42857
# 11     EURGBP    0.42857
# 12     AUDCHF    0.35635
# 13     EURCAD    0.35635
# 14     EURUSD    0.35635
# 15     AUDNZD    0.32733
# 16     EURAUD    0.21822
# 17     NZDJPY    0.21822
# 18     AUDCAD    0.21822
# 19     NZDCAD    0.21822
# 20     GBPJPY    0.08909
# 21     GBPUSD    0.04762
# 22     CHFJPY    0.04762
# 23     EURCHF    0.04762
# 24     EURJPY    0.04762
# 25     GBPCHF    0.04762
# 26     AUDJPY    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
