# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:48:10.610525

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.40482     CADJPY    0.28868     EURUSD    0.30151
# 1      CHFJPY    0.35219     NZDCAD    0.27217     NZDCAD    0.30151
# 2      EURJPY    0.31100     EURUSD    0.25000     AUDCAD    0.30151
# 3      USDCHF    0.28824     CHFJPY    0.22591     NZDJPY    0.30151
# 4      EURCAD    0.24418     AUDCAD    0.21822     AUDUSD    0.21822
# 5      AUDNZD    0.23775     EURCAD    0.21822     GBPCAD    0.21822
# 6      NZDUSD    0.22935     EURJPY    0.20787     AUDJPY    0.20412
# 7      CADJPY    0.22935     GBPJPY    0.20787     EURCHF    0.20412
# 8      GBPJPY    0.22711     NZDUSD    0.19094     EURNZD    0.20412
# 9      AUDCAD    0.19485     GBPCHF    0.16667     USDCHF    0.20000
# 10     NZDCAD    0.19025     EURNZD    0.16477     GBPUSD    0.20000
# 11     GBPUSD    0.18684     USDCHF    0.11111     EURCAD    0.20000
# 12     EURGBP    0.13497     GBPUSD    0.10985     AUDNZD    0.20000
# 13     EURNZD    0.12721     AUDNZD    0.10985     USDCAD    0.20000
# 14     AUDUSD    0.12039     NZDCHF    0.10985     AUDCHF    0.10483
# 15     AUDJPY    0.11433     AUDCHF    0.08183     GBPAUD    0.10483
# 16     CADCHF    0.10701     USDCAD    0.08183     EURJPY    0.10483
# 17     GBPAUD    0.09829     GBPCAD    0.05939     CHFJPY    0.10483
# 18     USDJPY    0.08353     CADCHF    0.05648     NZDCHF    0.10050
# 19     EURAUD    0.08353     USDJPY    0.05648     GBPJPY    0.10050
# 20     GBPCAD    0.06019     EURCHF    0.05455     CADCHF    0.10050
# 21     NZDJPY    0.05506     GBPAUD    0.02778     CADJPY    0.10050
# 22     AUDCHF    0.04670     AUDUSD    0.02778     GBPCHF    0.10050
# 23     EURCHF    0.03382     EURGBP    0.02778     NZDUSD    0.10050
# 24     NZDCHF    0.02341     EURAUD    0.02746     USDJPY    0.10050
# 25     GBPCHF    0.02150     AUDJPY    0.00000     EURGBP    0.10050
# 26     USDCAD    0.00970     NZDJPY    0.00000     EURAUD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.60714     USDCHF    0.66667  ...     USDCHF    0.23775
# 1      NZDCAD    0.49099     EURUSD    0.66667  ...     NZDJPY    0.19910
# 2      NZDUSD    0.49099     NZDCAD    0.66667  ...     EURUSD    0.19872
# 3      USDCHF    0.46429     NZDUSD    0.66667  ...     USDJPY    0.19872
# 4      GBPUSD    0.46429     GBPUSD    0.66667  ...     EURCAD    0.19872
# 5      EURCAD    0.46429     EURCAD    0.58333  ...     CADJPY    0.19612
# 6      EURNZD    0.37796     EURNZD    0.53452  ...     GBPUSD    0.17485
# 7      CHFJPY    0.34247     CADCHF    0.40825  ...     AUDCAD    0.16386
# 8      GBPCAD    0.34247     AUDCAD    0.40825  ...     AUDJPY    0.15743
# 9      AUDCAD    0.33929     EURGBP    0.40825  ...     GBPCAD    0.13678
# 10     AUDCHF    0.26189     CHFJPY    0.35635  ...     GBPAUD    0.13074
# 11     NZDJPY    0.21822     GBPCAD    0.35635  ...     AUDNZD    0.11859
# 12     AUDNZD    0.21822     GBPJPY    0.25000  ...     NZDCHF    0.11342
# 13     CADCHF    0.21822     EURJPY    0.25000  ...     CADCHF    0.11342
# 14     GBPCHF    0.21822     AUDJPY    0.16667  ...     EURJPY    0.11342
# 15     USDJPY    0.21822     AUDUSD    0.10206  ...     AUDUSD    0.08006
# 16     GBPJPY    0.19643     GBPAUD    0.10206  ...     AUDCHF    0.07711
# 17     EURGBP    0.19643     EURAUD    0.10206  ...     EURCHF    0.07711
# 18     EURCHF    0.18898     USDJPY    0.08909  ...     EURNZD    0.07711
# 19     NZDCHF    0.07143     USDCAD    0.08909  ...     EURGBP    0.07462
# 20     USDCAD    0.07143     GBPCHF    0.08909  ...     EURAUD    0.03846
# 21     EURJPY    0.05455     AUDCHF    0.08909  ...     USDCAD    0.03548
# 22     CADJPY    0.05455     EURCHF    0.08909  ...     NZDUSD    0.03269
# 23     AUDJPY    0.05455     AUDNZD    0.08909  ...     GBPJPY    0.02746
# 24     GBPAUD    0.04029     CADJPY    0.00000  ...     CHFJPY    0.00990
# 25     EURAUD    0.04029     NZDJPY    0.00000  ...     GBPCHF    0.00990
# 26     AUDUSD    0.04029     NZDCHF    0.00000  ...     NZDCAD    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.33072     USDCHF    0.30151     NZDJPY    0.38889
# 1      USDCHF    0.32733     EURCAD    0.30151     USDCHF    0.32733
# 2      GBPCAD    0.32077     GBPCAD    0.28511     EURCAD    0.32733
# 3      GBPAUD    0.21822     EURUSD    0.21212     EURCHF    0.28868
# 4      EURCHF    0.19643     AUDCAD    0.21212     AUDCAD    0.21822
# 5      EURCAD    0.19643     NZDJPY    0.21212     EURGBP    0.21822
# 6      AUDCAD    0.19643     GBPCHF    0.21212     EURUSD    0.21822
# 7      EURUSD    0.19094     GBPJPY    0.19192     AUDJPY    0.16667
# 8      CADJPY    0.18898     GBPAUD    0.17911     GBPAUD    0.12309
# 9      GBPUSD    0.14382     GBPUSD    0.10050     EURAUD    0.12309
# 10     EURAUD    0.14382     AUDNZD    0.10050     AUDUSD    0.12309
# 11     EURNZD    0.14382     USDCAD    0.10050     CHFJPY    0.12309
# 12     AUDJPY    0.13363     EURCHF    0.08206     AUDCHF    0.12309
# 13     NZDCHF    0.12585     EURNZD    0.08206     GBPCAD    0.12309
# 14     CADCHF    0.12016     AUDJPY    0.08206     NZDCAD    0.11111
# 15     USDJPY    0.12016     AUDUSD    0.06580     USDJPY    0.11111
# 16     EURJPY    0.11664     EURAUD    0.06580     CADJPY    0.11111
# 17     GBPCHF    0.08183     AUDCHF    0.03161     NZDUSD    0.11111
# 18     AUDUSD    0.08183     CHFJPY    0.03161     EURJPY    0.11111
# 19     AUDCHF    0.07143     EURJPY    0.03161     GBPCHF    0.11111
# 20     NZDUSD    0.06250     NZDCHF    0.01010     CADCHF    0.11111
# 21     USDCAD    0.06250     CADCHF    0.01010     AUDNZD    0.11111
# 22     EURGBP    0.05455     NZDUSD    0.01010     USDCAD    0.05455
# 23     GBPJPY    0.02916     CADJPY    0.01010     GBPJPY    0.05455
# 24     CHFJPY    0.01849     USDJPY    0.01010     GBPUSD    0.05455
# 25     AUDNZD    0.00899     NZDCAD    0.01010     NZDCHF    0.05455
# 26     NZDCAD    0.00000     EURGBP    0.01010     EURNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.53452
# 1      AUDCHF    0.52381
# 2      USDCAD    0.42857
# 3      AUDJPY    0.35635
# 4      EURCAD    0.35635
# 5      AUDCAD    0.21822
# 6      NZDJPY    0.21822
# 7      CADJPY    0.21822
# 8      EURAUD    0.21822
# 9      GBPAUD    0.21822
# 10     NZDCHF    0.21822
# 11     EURGBP    0.21822
# 12     CADCHF    0.21822
# 13     AUDUSD    0.21822
# 14     GBPUSD    0.08909
# 15     GBPJPY    0.08909
# 16     EURJPY    0.08909
# 17     NZDUSD    0.08909
# 18     EURUSD    0.08909
# 19     NZDCAD    0.08909
# 20     GBPCAD    0.04762
# 21     CHFJPY    0.04762
# 22     EURCHF    0.04762
# 23     GBPCHF    0.04762
# 24     EURNZD    0.04762
# 25     USDJPY    0.04762
# 26     AUDNZD    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
