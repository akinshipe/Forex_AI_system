# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-12 08:54:50.013931

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.35897     USDJPY    0.40825     EURJPY    0.41414
# 1      EURJPY    0.35807     NZDCAD    0.33333     AUDNZD    0.32824
# 2      USDCHF    0.32450     USDCHF    0.26726     USDJPY    0.28721
# 3      USDJPY    0.31807     AUDCAD    0.26726     GBPCAD    0.28721
# 4      EURUSD    0.27885     CADJPY    0.26726     GBPUSD    0.21212
# 5      GBPUSD    0.27885     EURCAD    0.20180     GBPAUD    0.17408
# 6      CHFJPY    0.24982     GBPUSD    0.20180     CHFJPY    0.12309
# 7      AUDUSD    0.23775     EURJPY    0.20000     EURCAD    0.12309
# 8      NZDUSD    0.23775     GBPAUD    0.14142     USDCHF    0.12309
# 9      AUDCAD    0.19872     CHFJPY    0.13608     NZDUSD    0.12309
# 10     NZDJPY    0.16386     AUDJPY    0.13608     GBPCHF    0.10050
# 11     GBPJPY    0.15743     GBPCAD    0.13608     GBPJPY    0.10050
# 12     CADCHF    0.12581     CADCHF    0.13363     AUDCAD    0.10050
# 13     EURCAD    0.11859     NZDUSD    0.13363     USDCAD    0.10050
# 14     NZDCHF    0.11613     USDCAD    0.13363     EURAUD    0.10050
# 15     EURCHF    0.11440     GBPCHF    0.06917     EURNZD    0.10050
# 16     GBPCAD    0.08006     EURCHF    0.06917     CADJPY    0.10050
# 17     CADJPY    0.08006     EURGBP    0.06727     NZDJPY    0.08206
# 18     AUDCHF    0.07711     AUDUSD    0.06727     CADCHF    0.08206
# 19     GBPAUD    0.07711     AUDNZD    0.06727     AUDJPY    0.08206
# 20     EURAUD    0.04167     GBPJPY    0.06667     EURCHF    0.06580
# 21     AUDJPY    0.04167     EURAUD    0.06667     NZDCHF    0.03161
# 22     GBPCHF    0.03846     NZDCHF    0.06667     NZDCAD    0.01010
# 23     USDCAD    0.03846     AUDCHF    0.06667     EURUSD    0.01010
# 24     AUDNZD    0.03548     EURUSD    0.06667     AUDUSD    0.01010
# 25     EURGBP    0.00321     EURNZD    0.00000     AUDCHF    0.01010
# 26     EURNZD    0.00000     NZDJPY    0.00000     EURGBP    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.60010     CHFJPY    0.60000  ...     GBPCAD    0.40291
# 1      AUDCAD    0.49099     AUDUSD    0.60000  ...     GBPUSD    0.36775
# 2      EURAUD    0.49099     EURAUD    0.60000  ...     GBPCHF    0.35807
# 3      GBPAUD    0.46771     GBPUSD    0.60000  ...     EURGBP    0.33307
# 4      CHFJPY    0.46429     EURJPY    0.60000  ...     GBPJPY    0.33307
# 5      AUDUSD    0.37796     AUDCAD    0.60000  ...     AUDCHF    0.33307
# 6      AUDCHF    0.37796     NZDCAD    0.60000  ...     AUDUSD    0.33307
# 7      USDCHF    0.33929     GBPAUD    0.50000  ...     EURUSD    0.28710
# 8      GBPUSD    0.33929     NZDUSD    0.40825  ...     AUDCAD    0.28710
# 9      AUDNZD    0.32733     AUDCHF    0.40825  ...     NZDCAD    0.28710
# 10     NZDUSD    0.26189     USDJPY    0.40825  ...     EURCHF    0.23028
# 11     EURCHF    0.26189     EURNZD    0.40825  ...     EURJPY    0.21753
# 12     GBPCAD    0.21822     EURCHF    0.21822  ...     NZDCHF    0.21753
# 13     USDJPY    0.21822     EURCAD    0.21822  ...     EURAUD    0.20646
# 14     EURUSD    0.21822     NZDCHF    0.21822  ...     AUDJPY    0.19678
# 15     AUDJPY    0.19643     NZDJPY    0.20000  ...     NZDUSD    0.17138
# 16     NZDJPY    0.19643     AUDJPY    0.20000  ...     NZDJPY    0.15198
# 17     CADCHF    0.09449     USDCHF    0.20000  ...     CHFJPY    0.14368
# 18     NZDCHF    0.09449     EURGBP    0.20000  ...     EURCAD    0.12581
# 19     USDCAD    0.09449     GBPCHF    0.20000  ...     USDCAD    0.11613
# 20     NZDCAD    0.07143     USDCAD    0.20000  ...     CADCHF    0.10714
# 21     GBPCHF    0.07143     EURUSD    0.20000  ...     USDJPY    0.09054
# 22     GBPJPY    0.07143     GBPCAD    0.00000  ...     EURNZD    0.08058
# 23     EURNZD    0.07143     GBPJPY    0.00000  ...     USDCHF    0.07114
# 24     CADJPY    0.07143     CADJPY    0.00000  ...     GBPAUD    0.07114
# 25     EURCAD    0.05455     CADCHF    0.00000  ...     AUDNZD    0.05519
# 26     EURGBP    0.05455     AUDNZD    0.00000  ...     CADJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.58333     GBPCHF    0.73380     GBPCHF    0.75593
# 1      GBPCHF    0.50830     GBPCAD    0.68474     EURGBP    0.57735
# 2      AUDUSD    0.43939     EURGBP    0.60053     GBPCAD    0.57735
# 3      AUDCHF    0.40825     NZDCHF    0.53846     NZDCHF    0.50000
# 4      EURGBP    0.38446     EURCHF    0.48038     AUDCHF    0.50000
# 5      GBPUSD    0.38446     NZDCAD    0.45303     EURCHF    0.42640
# 6      AUDCAD    0.35460     AUDCHF    0.45303     EURNZD    0.37796
# 7      EURCHF    0.33887     GBPUSD    0.38982     GBPUSD    0.37796
# 8      EURCAD    0.30208     EURCAD    0.38516     CHFJPY    0.37796
# 9      EURAUD    0.27217     AUDCAD    0.31449     NZDCAD    0.37796
# 10     NZDCAD    0.27217     EURNZD    0.31449     EURCAD    0.28868
# 11     NZDCHF    0.27217     EURAUD    0.31449     AUDCAD    0.28868
# 12     GBPJPY    0.27217     GBPJPY    0.31449     USDJPY    0.28868
# 13     EURUSD    0.27217     EURUSD    0.24232     EURAUD    0.28868
# 14     CADCHF    0.19094     AUDUSD    0.24232     EURJPY    0.28868
# 15     GBPAUD    0.14434     USDCHF    0.17118     CADCHF    0.20000
# 16     EURJPY    0.13608     CHFJPY    0.17118     AUDUSD    0.20000
# 17     USDJPY    0.11111     NZDUSD    0.17118     CADJPY    0.18898
# 18     CHFJPY    0.11111     USDJPY    0.17118     USDCHF    0.18898
# 19     AUDNZD    0.10985     AUDNZD    0.17118     NZDUSD    0.10660
# 20     CADJPY    0.08183     CADJPY    0.10483     USDCAD    0.10000
# 21     USDCAD    0.08183     USDCAD    0.10483     GBPJPY    0.09449
# 22     USDCHF    0.08183     GBPAUD    0.06052     AUDJPY    0.09449
# 23     EURNZD    0.05455     CADCHF    0.04280     NZDJPY    0.09449
# 24     NZDUSD    0.05455     AUDJPY    0.04280     GBPAUD    0.00000
# 25     AUDJPY    0.02778     NZDJPY    0.04280     EURUSD    0.00000
# 26     NZDJPY    0.02778     EURJPY    0.03161     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.81650
# 1      GBPCHF    0.81650
# 2      AUDCHF    0.66667
# 3      GBPCAD    0.58333
# 4      NZDCHF    0.53452
# 5      EURCHF    0.53452
# 6      EURAUD    0.40825
# 7      EURJPY    0.40825
# 8      GBPUSD    0.40825
# 9      CHFJPY    0.40825
# 10     AUDUSD    0.40825
# 11     AUDCAD    0.40825
# 12     NZDCAD    0.40825
# 13     CADCHF    0.25000
# 14     NZDUSD    0.25000
# 15     GBPJPY    0.25000
# 16     USDJPY    0.25000
# 17     EURNZD    0.25000
# 18     CADJPY    0.16667
# 19     AUDNZD    0.16667
# 20     GBPAUD    0.10206
# 21     EURCAD    0.08909
# 22     AUDJPY    0.00000
# 23     NZDJPY    0.00000
# 24     USDCAD    0.00000
# 25     EURUSD    0.00000
# 26     USDCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
