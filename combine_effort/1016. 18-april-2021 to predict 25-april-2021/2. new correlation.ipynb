# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:56:37.536365

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CADJPY    0.27891     EURJPY    0.55405     EURJPY    0.54470
# 1      AUDNZD    0.23028     CADJPY    0.39747     CADJPY    0.43463
# 2      GBPJPY    0.22860     GBPJPY    0.36748     GBPJPY    0.27890
# 3      EURJPY    0.22860     EURNZD    0.35460     CHFJPY    0.25678
# 4      NZDJPY    0.21094     CHFJPY    0.32733     AUDCHF    0.25163
# 5      CHFJPY    0.19590     EURGBP    0.27866     EURNZD    0.24232
# 6      EURNZD    0.18831     AUDNZD    0.25882     NZDUSD    0.18157
# 7      AUDJPY    0.16116     EURUSD    0.20536     EURGBP    0.17118
# 8      EURUSD    0.13636     NZDJPY    0.19138     EURUSD    0.17118
# 9      AUDCHF    0.12928     AUDJPY    0.18898     EURAUD    0.17118
# 10     AUDUSD    0.12588     GBPCAD    0.15714     EURCHF    0.12088
# 11     NZDUSD    0.12588     AUDCHF    0.15714     GBPAUD    0.10483
# 12     EURGBP    0.11613     EURAUD    0.15714     AUDNZD    0.10483
# 13     GBPUSD    0.11289     USDCHF    0.14382     GBPUSD    0.09890
# 14     CADCHF    0.11289     USDCAD    0.12585     GBPCAD    0.09890
# 15     GBPCAD    0.10714     AUDUSD    0.12016     AUDUSD    0.09890
# 16     GBPAUD    0.08058     EURCHF    0.12016     NZDCAD    0.09890
# 17     NZDCHF    0.07722     NZDCAD    0.09449     USDCHF    0.09890
# 18     EURCHF    0.07722     GBPAUD    0.07143     GBPCHF    0.06052
# 19     GBPCHF    0.07722     USDJPY    0.06250     NZDJPY    0.06052
# 20     NZDCAD    0.07722     GBPUSD    0.04725     EURCAD    0.04280
# 21     USDCAD    0.06580     CADCHF    0.04725     USDJPY    0.04280
# 22     USDJPY    0.03548     NZDUSD    0.04029     USDCAD    0.03161
# 23     AUDCAD    0.02988     NZDCHF    0.02916     AUDCAD    0.03161
# 24     EURAUD    0.01645     GBPCHF    0.02916     NZDCHF    0.02288
# 25     USDCHF    0.00970     EURCAD    0.00899     CADCHF    0.02288
# 26     EURCAD    0.00000     AUDCAD    0.00899     AUDJPY    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.53300     NZDUSD    0.53452  ...     GBPUSD    0.24878
# 1      EURJPY    0.35355     USDCHF    0.52381  ...     EURUSD    0.18286
# 2      GBPUSD    0.28868     CADJPY    0.52381  ...     CADJPY    0.16864
# 3      USDCHF    0.21320     EURUSD    0.35635  ...     AUDNZD    0.13234
# 4      EURCHF    0.21320     USDJPY    0.35635  ...     EURAUD    0.11580
# 5      NZDJPY    0.21320     EURAUD    0.35635  ...     GBPJPY    0.11495
# 6      GBPCAD    0.20000     EURCAD    0.35635  ...     GBPCAD    0.10123
# 7      AUDCHF    0.20000     CADCHF    0.35635  ...     CHFJPY    0.08181
# 8      EURGBP    0.20000     GBPUSD    0.21822  ...     AUDCAD    0.08181
# 9      NZDUSD    0.20000     NZDCAD    0.21822  ...     USDCHF    0.05366
# 10     CHFJPY    0.18898     EURNZD    0.21822  ...     USDCAD    0.04963
# 11     GBPJPY    0.13868     EURJPY    0.21822  ...     NZDCAD    0.04728
# 12     AUDNZD    0.10660     GBPJPY    0.21822  ...     NZDCHF    0.04728
# 13     NZDCHF    0.10000     AUDNZD    0.21822  ...     EURCHF    0.04728
# 14     CADCHF    0.10000     CHFJPY    0.21822  ...     GBPCHF    0.04728
# 15     USDJPY    0.10000     GBPCHF    0.21822  ...     EURCAD    0.04052
# 16     EURUSD    0.10000     AUDUSD    0.21822  ...     GBPAUD    0.04052
# 17     AUDUSD    0.09449     NZDCHF    0.08909  ...     AUDJPY    0.03715
# 18     GBPAUD    0.09449     GBPCAD    0.08909  ...     EURJPY    0.02653
# 19     USDCAD    0.09449     GBPAUD    0.08909  ...     EURNZD    0.01959
# 20     EURNZD    0.09449     AUDJPY    0.08909  ...     NZDUSD    0.01198
# 21     AUDCAD    0.09449     AUDCAD    0.08909  ...     AUDCHF    0.01198
# 22     GBPCHF    0.00000     USDCAD    0.08909  ...     AUDUSD    0.01198
# 23     EURAUD    0.00000     AUDCHF    0.04762  ...     NZDJPY    0.01198
# 24     AUDJPY    0.00000     EURCHF    0.04762  ...     EURGBP    0.00649
# 25     NZDCAD    0.00000     NZDJPY    0.04762  ...     USDJPY    0.00649
# 26     EURCAD    0.00000     EURGBP    0.04762  ...     CADCHF    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.24456     GBPCAD    0.42366     GBPCAD    0.50000
# 1      GBPJPY    0.20751     GBPCHF    0.33333     GBPCHF    0.35355
# 2      USDCHF    0.17216     GBPJPY    0.24254     GBPUSD    0.28868
# 3      GBPAUD    0.15714     EURGBP    0.23570     GBPJPY    0.27735
# 4      EURCHF    0.14833     CHFJPY    0.23570     USDCHF    0.21320
# 5      GBPCAD    0.14833     NZDUSD    0.20000     NZDJPY    0.21320
# 6      CADJPY    0.13876     NZDJPY    0.20000     CADJPY    0.21320
# 7      AUDNZD    0.13876     EURCHF    0.18157     AUDCHF    0.20000
# 8      EURUSD    0.12016     GBPUSD    0.18157     EURGBP    0.20000
# 9      USDJPY    0.12016     USDCAD    0.17408     CHFJPY    0.18898
# 10     AUDCAD    0.10702     EURNZD    0.17408     USDCAD    0.18898
# 11     NZDCHF    0.10566     AUDJPY    0.12599     AUDCAD    0.18898
# 12     EURNZD    0.08472     CADCHF    0.12599     EURNZD    0.18898
# 13     CHFJPY    0.08472     AUDCHF    0.12599     GBPAUD    0.18898
# 14     CADCHF    0.04891     NZDCHF    0.12599     AUDNZD    0.10660
# 15     NZDCAD    0.04891     CADJPY    0.12599     EURCHF    0.10660
# 16     AUDJPY    0.04891     GBPAUD    0.11547     NZDUSD    0.10000
# 17     GBPCHF    0.04528     EURJPY    0.06667     CADCHF    0.10000
# 18     EURJPY    0.04528     NZDCAD    0.06052     NZDCHF    0.10000
# 19     EURCAD    0.03257     USDCHF    0.06052     USDJPY    0.10000
# 20     USDCAD    0.03257     AUDUSD    0.06052     EURUSD    0.10000
# 21     EURGBP    0.03257     AUDCAD    0.05803     AUDUSD    0.09449
# 22     NZDJPY    0.01043     EURAUD    0.00000     EURJPY    0.00000
# 23     NZDUSD    0.01043     EURCAD    0.00000     EURAUD    0.00000
# 24     EURAUD    0.00478     USDJPY    0.00000     AUDJPY    0.00000
# 25     AUDUSD    0.00478     EURUSD    0.00000     NZDCAD    0.00000
# 26     AUDCHF    0.00478     AUDNZD    0.00000     EURCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.53452
# 1      EURGBP    0.42857
# 2      AUDCHF    0.42857
# 3      EURCHF    0.42857
# 4      AUDCAD    0.35635
# 5      GBPCHF    0.32733
# 6      GBPJPY    0.32733
# 7      AUDNZD    0.32733
# 8      EURJPY    0.21822
# 9      NZDCAD    0.21822
# 10     AUDUSD    0.21822
# 11     GBPUSD    0.21822
# 12     EURNZD    0.21822
# 13     CHFJPY    0.21822
# 14     EURCAD    0.08909
# 15     EURUSD    0.08909
# 16     AUDJPY    0.08909
# 17     EURAUD    0.08909
# 18     NZDUSD    0.08909
# 19     GBPAUD    0.08909
# 20     USDJPY    0.08909
# 21     USDCAD    0.08909
# 22     NZDCHF    0.08909
# 23     CADCHF    0.08909
# 24     CADJPY    0.04762
# 25     NZDJPY    0.04762
# 26     USDCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
