# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 19:13:20.997887

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.36775     GBPCHF    0.36711     EURUSD    0.61237
# 1      EURJPY    0.34247     NZDCAD    0.34586     NZDCAD    0.61237
# 2      CADJPY    0.30215     AUDCAD    0.34586     NZDUSD    0.61237
# 3      GBPJPY    0.29894     AUDCHF    0.34586     AUDCAD    0.49237
# 4      NZDUSD    0.25853     EURUSD    0.29579     GBPUSD    0.49237
# 5      GBPUSD    0.21914     GBPJPY    0.28230     EURNZD    0.45833
# 6      CHFJPY    0.21914     CADJPY    0.28230     AUDCHF    0.45833
# 7      USDCHF    0.21753     NZDUSD    0.25882     GBPCHF    0.40825
# 8      AUDCAD    0.18831     GBPUSD    0.25882     USDCHF    0.32824
# 9      NZDCAD    0.18094     EURNZD    0.24661     EURCAD    0.28721
# 10     AUDNZD    0.16116     EURAUD    0.24661     NZDCHF    0.28721
# 11     AUDUSD    0.15198     EURGBP    0.17216     GBPJPY    0.28721
# 12     AUDJPY    0.14368     NZDCHF    0.17216     GBPAUD    0.25000
# 13     GBPAUD    0.13636     GBPAUD    0.15714     USDJPY    0.25000
# 14     GBPCHF    0.13613     AUDNZD    0.15714     AUDUSD    0.25000
# 15     EURCAD    0.12581     CADCHF    0.13876     EURGBP    0.20412
# 16     NZDJPY    0.12309     EURCHF    0.12016     EURAUD    0.17118
# 17     EURCHF    0.10714     AUDUSD    0.10702     CADJPY    0.16667
# 18     USDCAD    0.10714     EURCAD    0.06917     GBPCAD    0.13363
# 19     NZDCHF    0.09066     AUDJPY    0.06917     AUDJPY    0.12309
# 20     EURGBP    0.09054     CHFJPY    0.05648     EURCHF    0.12309
# 21     AUDCHF    0.07114     USDJPY    0.05648     AUDNZD    0.08909
# 22     USDJPY    0.05519     USDCHF    0.05648     EURJPY    0.08206
# 23     EURAUD    0.04516     GBPCAD    0.04891     USDCAD    0.08206
# 24     EURNZD    0.04516     EURJPY    0.04891     CADCHF    0.04280
# 25     CADCHF    0.04423     NZDJPY    0.04891     CHFJPY    0.04280
# 26     GBPCAD    0.04083     USDCAD    0.03257     NZDJPY    0.04280
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.75593     NZDCAD    0.80178  ...     AUDNZD    0.20000
# 1      NZDUSD    0.75593     NZDUSD    0.80178  ...     AUDCAD    0.16116
# 2      EURUSD    0.66144     AUDCAD    0.80178  ...     USDCHF    0.16116
# 3      GBPUSD    0.66144     EURUSD    0.65465  ...     EURUSD    0.16013
# 4      AUDCAD    0.57735     GBPUSD    0.65465  ...     EURCAD    0.16013
# 5      EURNZD    0.57735     EURGBP    0.53452  ...     NZDJPY    0.13093
# 6      USDCHF    0.50000     GBPAUD    0.53452  ...     GBPCAD    0.12666
# 7      AUDCHF    0.37796     USDJPY    0.53452  ...     GBPUSD    0.12361
# 8      GBPJPY    0.37796     AUDUSD    0.53452  ...     CADJPY    0.12361
# 9      EURGBP    0.37796     GBPCHF    0.53452  ...     AUDJPY    0.12157
# 10     EURCHF    0.37796     EURCHF    0.53452  ...     EURGBP    0.12039
# 11     GBPCHF    0.37796     CHFJPY    0.53452  ...     NZDCHF    0.08333
# 12     EURCAD    0.28868     AUDCHF    0.53452  ...     EURJPY    0.08333
# 13     USDCAD    0.28868     EURNZD    0.53452  ...     GBPAUD    0.08058
# 14     NZDCHF    0.28868     EURAUD    0.42857  ...     USDJPY    0.08058
# 15     GBPAUD    0.28868     USDCHF    0.42857  ...     EURAUD    0.08006
# 16     EURJPY    0.28868     EURCAD    0.35635  ...     EURNZD    0.08006
# 17     AUDUSD    0.28868     GBPJPY    0.21822  ...     GBPJPY    0.04364
# 18     NZDJPY    0.28868     USDCAD    0.21822  ...     CADCHF    0.04222
# 19     USDJPY    0.20000     AUDNZD    0.21822  ...     CHFJPY    0.04120
# 20     EURAUD    0.20000     EURJPY    0.08909  ...     GBPCHF    0.04120
# 21     CADJPY    0.18898     CADJPY    0.08909  ...     AUDCHF    0.04013
# 22     GBPCAD    0.10000     AUDJPY    0.08909  ...     AUDUSD    0.04013
# 23     AUDJPY    0.09449     CADCHF    0.08909  ...     USDCAD    0.00000
# 24     CADCHF    0.00000     GBPCAD    0.04762  ...     EURCHF    0.00000
# 25     CHFJPY    0.00000     NZDCHF    0.04762  ...     NZDUSD    0.00000
# 26     AUDNZD    0.00000     NZDJPY    0.04762  ...     NZDCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDCAD    0.33634     AUDCAD    0.28511     USDCAD    0.40825
# 1      GBPCAD    0.23783     EURCAD    0.28511     USDCHF    0.35355
# 2      NZDCAD    0.20180     NZDJPY    0.25163     AUDCAD    0.27217
# 3      EURCAD    0.20180     EURGBP    0.21822     EURCAD    0.27217
# 4      NZDJPY    0.19026     EURUSD    0.21822     AUDCHF    0.20045
# 5      EURJPY    0.19026     NZDCAD    0.21822     NZDCAD    0.20045
# 6      USDCHF    0.16477     NZDUSD    0.21822     AUDJPY    0.20045
# 7      EURUSD    0.14382     GBPCHF    0.21822     EURGBP    0.20045
# 8      GBPUSD    0.12585     EURJPY    0.15352     NZDUSD    0.20045
# 9      AUDNZD    0.12585     USDCHF    0.15352     AUDNZD    0.16667
# 10     NZDUSD    0.12585     USDJPY    0.08909     GBPJPY    0.13363
# 11     GBPCHF    0.10985     GBPAUD    0.08909     EURUSD    0.13363
# 12     CADJPY    0.10702     AUDCHF    0.08909     CADJPY    0.13363
# 13     AUDUSD    0.08597     AUDUSD    0.08909     EURCHF    0.13363
# 14     EURNZD    0.08597     EURNZD    0.08909     GBPUSD    0.13363
# 15     EURGBP    0.08597     CADJPY    0.08909     GBPCHF    0.13363
# 16     AUDCHF    0.06727     EURCHF    0.06580     GBPAUD    0.06804
# 17     AUDJPY    0.06727     AUDJPY    0.06580     CHFJPY    0.06804
# 18     EURAUD    0.04977     NZDCHF    0.06580     NZDCHF    0.06804
# 19     NZDCHF    0.04977     GBPUSD    0.06580     EURNZD    0.06804
# 20     USDCAD    0.04977     GBPJPY    0.06580     AUDUSD    0.06804
# 21     GBPJPY    0.03257     USDCAD    0.06580     NZDJPY    0.06804
# 22     CADCHF    0.03257     AUDNZD    0.04762     CADCHF    0.06804
# 23     CHFJPY    0.02746     GBPCAD    0.04762     EURJPY    0.06804
# 24     USDJPY    0.02746     EURAUD    0.02288     GBPCAD    0.00000
# 25     GBPAUD    0.00899     CHFJPY    0.02288     EURAUD    0.00000
# 26     EURCHF    0.00899     CADCHF    0.02288     USDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDCAD    0.40825
# 1      EURCAD    0.40825
# 2      NZDUSD    0.40825
# 3      AUDCAD    0.40825
# 4      EURUSD    0.33333
# 5      USDCAD    0.33333
# 6      GBPJPY    0.33333
# 7      GBPUSD    0.33333
# 8      EURGBP    0.27217
# 9      EURNZD    0.27217
# 10     EURJPY    0.27217
# 11     GBPAUD    0.27217
# 12     AUDCHF    0.27217
# 13     AUDJPY    0.27217
# 14     CADCHF    0.27217
# 15     CHFJPY    0.27217
# 16     EURCHF    0.27217
# 17     GBPCHF    0.27217
# 18     AUDUSD    0.27217
# 19     USDJPY    0.27217
# 20     CADJPY    0.27217
# 21     NZDJPY    0.21822
# 22     USDCHF    0.21822
# 23     EURAUD    0.21822
# 24     GBPCAD    0.21822
# 25     NZDCHF    0.21822
# 26     AUDNZD    0.11111
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
