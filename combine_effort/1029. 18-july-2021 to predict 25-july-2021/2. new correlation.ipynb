# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:51:10.621092

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.36116     CADJPY    0.36711     AUDNZD    0.28721
# 1      CHFJPY    0.35219     CHFJPY    0.30556     EURUSD    0.21212
# 2      EURJPY    0.31100     EURJPY    0.28868     NZDCAD    0.21212
# 3      GBPJPY    0.26938     EURUSD    0.25000     AUDCAD    0.21212
# 4      USDCHF    0.24418     NZDCAD    0.24716     AUDCHF    0.21212
# 5      AUDNZD    0.23282     GBPJPY    0.20787     EURNZD    0.21212
# 6      CADJPY    0.22935     AUDCAD    0.19094     GBPCHF    0.19192
# 7      EURCAD    0.20773     NZDCHF    0.16667     CADJPY    0.19192
# 8      NZDUSD    0.19025     GBPCHF    0.14434     GBPJPY    0.19192
# 9      NZDCAD    0.19025     EURNZD    0.13608     AUDUSD    0.17911
# 10     GBPUSD    0.18684     USDCHF    0.11111     EURAUD    0.12309
# 11     EURGBP    0.17138     NZDUSD    0.10985     NZDJPY    0.12309
# 12     AUDJPY    0.15198     AUDNZD    0.08472     USDCAD    0.10050
# 13     AUDCAD    0.15198     EURCAD    0.08183     EURCHF    0.10050
# 14     EURAUD    0.12721     NZDJPY    0.05939     NZDCHF    0.10050
# 15     EURNZD    0.12721     USDJPY    0.05648     GBPUSD    0.10050
# 16     AUDUSD    0.11433     EURGBP    0.05648     EURGBP    0.08206
# 17     NZDJPY    0.09996     AUDCHF    0.05455     GBPAUD    0.08206
# 18     AUDCHF    0.09054     AUDUSD    0.05455     CADCHF    0.08206
# 19     CADCHF    0.06946     AUDJPY    0.05455     CHFJPY    0.08206
# 20     GBPAUD    0.05366     GBPCAD    0.03077     USDJPY    0.08206
# 21     USDJPY    0.04670     GBPUSD    0.02778     EURJPY    0.03161
# 22     EURCHF    0.02764     GBPAUD    0.02746     GBPCAD    0.03161
# 23     NZDCHF    0.02150     EURCHF    0.02746     EURCAD    0.01010
# 24     GBPCAD    0.02150     CADCHF    0.00000     AUDJPY    0.01010
# 25     GBPCHF    0.02150     EURAUD    0.00000     NZDUSD    0.01010
# 26     USDCAD    0.00970     USDCAD    0.00000     USDCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.46429     USDCHF    0.66667  ...     USDCHF    0.23775
# 1      CHFJPY    0.37796     EURUSD    0.66667  ...     CADJPY    0.22935
# 2      AUDCAD    0.33929     NZDCAD    0.66667  ...     GBPUSD    0.22653
# 3      EURUSD    0.33929     EURCAD    0.58333  ...     EURUSD    0.20064
# 4      GBPUSD    0.33929     EURNZD    0.53452  ...     USDJPY    0.19485
# 5      EURNZD    0.32733     NZDUSD    0.53452  ...     EURCAD    0.19485
# 6      GBPCAD    0.26189     AUDCAD    0.40825  ...     NZDJPY    0.18467
# 7      EURCAD    0.21822     GBPUSD    0.40825  ...     AUDCAD    0.17138
# 8      GBPAUD    0.21822     CHFJPY    0.35635  ...     AUDJPY    0.15198
# 9      USDCHF    0.21822     NZDCHF    0.25000  ...     GBPCAD    0.14385
# 10     EURCHF    0.21822     EURJPY    0.25000  ...     EURJPY    0.14379
# 11     AUDUSD    0.21822     GBPJPY    0.25000  ...     GBPAUD    0.13497
# 12     NZDCHF    0.19643     AUDNZD    0.25000  ...     NZDCHF    0.10417
# 13     GBPCHF    0.19643     CADCHF    0.25000  ...     CADCHF    0.09996
# 14     GBPJPY    0.19643     EURCHF    0.16667  ...     EURGBP    0.07114
# 15     NZDUSD    0.19643     GBPCAD    0.10206  ...     AUDCHF    0.07114
# 16     CADJPY    0.19643     GBPAUD    0.10206  ...     USDCAD    0.07114
# 17     USDCAD    0.19643     EURAUD    0.10206  ...     AUDNZD    0.07114
# 18     AUDCHF    0.18898     AUDUSD    0.10206  ...     GBPCHF    0.06118
# 19     EURAUD    0.09449     AUDCHF    0.08909  ...     NZDCAD    0.05366
# 20     EURGBP    0.07143     AUDJPY    0.08909  ...     EURAUD    0.03382
# 21     CADCHF    0.07143     USDCAD    0.08909  ...     EURNZD    0.03382
# 22     USDJPY    0.07143     USDJPY    0.08909  ...     AUDUSD    0.03382
# 23     AUDNZD    0.07143     GBPCHF    0.00000  ...     EURCHF    0.02764
# 24     EURJPY    0.05455     CADJPY    0.00000  ...     NZDUSD    0.02764
# 25     AUDJPY    0.05455     NZDJPY    0.00000  ...     CHFJPY    0.02150
# 26     NZDJPY    0.05455     EURGBP    0.00000  ...     GBPJPY    0.01525
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.35635     GBPCAD    0.45303     AUDCAD    0.46429
# 1      GBPCAD    0.33850     USDCHF    0.39394     GBPCAD    0.34247
# 2      USDCHF    0.30556     AUDCAD    0.39394     NZDCAD    0.33929
# 3      CADJPY    0.22591     EURCAD    0.39394     GBPCHF    0.33929
# 4      AUDCAD    0.21822     NZDJPY    0.28721     USDCHF    0.32733
# 5      AUDJPY    0.19094     AUDJPY    0.21212     EURCAD    0.32733
# 6      EURCAD    0.19094     GBPCHF    0.21212     NZDJPY    0.21822
# 7      NZDCHF    0.16667     EURUSD    0.19192     EURNZD    0.21822
# 8      EURUSD    0.16667     NZDCAD    0.19192     EURJPY    0.21822
# 9      GBPAUD    0.16477     CADJPY    0.19192     GBPUSD    0.19643
# 10     GBPCHF    0.14434     EURJPY    0.17911     CADJPY    0.19643
# 11     CADCHF    0.14434     EURAUD    0.12309     AUDNZD    0.19643
# 12     EURJPY    0.14434     GBPAUD    0.12309     EURUSD    0.19643
# 13     EURAUD    0.13608     AUDNZD    0.12309     AUDCHF    0.09449
# 14     USDCAD    0.13608     GBPUSD    0.10050     CHFJPY    0.09449
# 15     EURNZD    0.13608     NZDCHF    0.10050     EURAUD    0.09449
# 16     GBPUSD    0.11111     EURCHF    0.10050     NZDCHF    0.07143
# 17     NZDUSD    0.10985     USDCAD    0.10050     GBPJPY    0.07143
# 18     EURCHF    0.10985     CADCHF    0.08206     CADCHF    0.07143
# 19     EURGBP    0.08472     CHFJPY    0.08206     NZDUSD    0.07143
# 20     USDJPY    0.08472     USDJPY    0.08206     USDCAD    0.07143
# 21     AUDUSD    0.08183     EURGBP    0.08206     USDJPY    0.07143
# 22     GBPJPY    0.05939     AUDUSD    0.03161     EURGBP    0.07143
# 23     AUDNZD    0.05648     GBPJPY    0.01010     GBPAUD    0.05455
# 24     AUDCHF    0.05455     AUDCHF    0.01010     EURCHF    0.05455
# 25     CHFJPY    0.02778     EURNZD    0.01010     AUDUSD    0.05455
# 26     NZDCAD    0.02746     NZDUSD    0.01010     AUDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.66667
# 1      EURCAD    0.58333
# 2      AUDCAD    0.40825
# 3      NZDJPY    0.40825
# 4      CADJPY    0.40825
# 5      EURGBP    0.40825
# 6      AUDCHF    0.35635
# 7      AUDJPY    0.35635
# 8      AUDNZD    0.25000
# 9      NZDCAD    0.25000
# 10     CADCHF    0.25000
# 11     EURUSD    0.25000
# 12     EURCHF    0.16667
# 13     NZDCHF    0.16667
# 14     GBPJPY    0.16667
# 15     EURJPY    0.16667
# 16     AUDUSD    0.10206
# 17     EURAUD    0.10206
# 18     GBPAUD    0.10206
# 19     GBPCAD    0.10206
# 20     EURNZD    0.08909
# 21     USDCAD    0.08909
# 22     USDJPY    0.08909
# 23     CHFJPY    0.08909
# 24     NZDUSD    0.08909
# 25     GBPCHF    0.00000
# 26     GBPUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
