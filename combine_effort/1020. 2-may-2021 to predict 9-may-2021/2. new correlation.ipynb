# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:54:32.320064

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.25992     EURJPY    0.49357     CADJPY    0.47076
# 1      GBPJPY    0.25992     CADJPY    0.39747     EURJPY    0.35722
# 2      CHFJPY    0.24878     GBPJPY    0.36748     CHFJPY    0.28721
# 3      CADJPY    0.24878     EURNZD    0.35460     GBPCHF    0.23570
# 4      AUDNZD    0.23153     CHFJPY    0.32733     GBPJPY    0.22866
# 5      EURNZD    0.22531     AUDNZD    0.25882     EURGBP    0.17118
# 6      EURGBP    0.15573     EURGBP    0.20536     GBPUSD    0.17118
# 7      EURUSD    0.14943     EURUSD    0.20536     USDCHF    0.16667
# 8      NZDJPY    0.14941     AUDJPY    0.18898     EURCHF    0.13363
# 9      GBPUSD    0.13170     EURAUD    0.15714     NZDCHF    0.13363
# 10     AUDJPY    0.13170     GBPCHF    0.12016     USDCAD    0.12309
# 11     AUDCHF    0.12157     EURCHF    0.12016     EURNZD    0.12309
# 12     NZDUSD    0.09752     AUDUSD    0.12016     GBPCAD    0.08909
# 13     AUDUSD    0.09752     NZDJPY    0.11585     NZDUSD    0.08909
# 14     EURCHF    0.09752     NZDCAD    0.09449     AUDCAD    0.08206
# 15     GBPCAD    0.09688     AUDCHF    0.08183     EURCAD    0.08206
# 16     GBPCHF    0.08181     GBPCAD    0.08183     CADCHF    0.04280
# 17     CADCHF    0.08181     USDCHF    0.07143     AUDCHF    0.04280
# 18     GBPAUD    0.07462     GBPAUD    0.07143     NZDCAD    0.04280
# 19     EURAUD    0.04963     USDJPY    0.06250     AUDJPY    0.04280
# 20     NZDCHF    0.04728     USDCAD    0.05455     EURUSD    0.04167
# 21     NZDCAD    0.04728     GBPUSD    0.04725     USDJPY    0.04167
# 22     EURCAD    0.04052     CADCHF    0.04725     EURAUD    0.04167
# 23     USDCHF    0.01478     NZDUSD    0.04029     AUDUSD    0.04167
# 24     USDJPY    0.00649     NZDCHF    0.02916     NZDJPY    0.00000
# 25     AUDCAD    0.00167     EURCAD    0.00899     GBPAUD    0.00000
# 26     USDCAD    0.00167     AUDCAD    0.00899     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.44444     USDCHF    0.81650  ...     GBPUSD    0.27217
# 1      GBPCHF    0.43082     NZDUSD    0.60000  ...     EURUSD    0.19852
# 2      CADJPY    0.43082     EURUSD    0.40825  ...     EURAUD    0.16667
# 3      USDCAD    0.38889     USDJPY    0.40825  ...     GBPJPY    0.14548
# 4      NZDUSD    0.28868     USDCAD    0.40825  ...     AUDCAD    0.13457
# 5      GBPJPY    0.27217     AUDUSD    0.40825  ...     GBPCHF    0.13457
# 6      AUDUSD    0.21822     GBPCHF    0.40825  ...     AUDNZD    0.13234
# 7      EURNZD    0.21822     CHFJPY    0.40825  ...     CADJPY    0.11775
# 8      GBPAUD    0.21822     CADCHF    0.40825  ...     GBPCAD    0.11580
# 9      EURUSD    0.16667     CADJPY    0.40825  ...     NZDCAD    0.10206
# 10     USDJPY    0.16667     GBPUSD    0.40825  ...     AUDCHF    0.10206
# 11     CADCHF    0.16667     EURCAD    0.40825  ...     NZDCHF    0.10206
# 12     EURCHF    0.12309     EURJPY    0.33333  ...     AUDUSD    0.06895
# 13     AUDJPY    0.11111     AUDCAD    0.21822  ...     NZDUSD    0.06895
# 14     GBPUSD    0.11111     NZDJPY    0.21822  ...     EURCHF    0.06895
# 15     NZDCAD    0.11111     AUDNZD    0.21822  ...     EURNZD    0.06580
# 16     EURJPY    0.08006     GBPJPY    0.21822  ...     CADCHF    0.05046
# 17     NZDJPY    0.06804     EURCHF    0.21822  ...     CHFJPY    0.05046
# 18     AUDCAD    0.05455     GBPAUD    0.20000  ...     EURGBP    0.04903
# 19     EURCAD    0.05455     GBPCAD    0.20000  ...     GBPAUD    0.04903
# 20     EURAUD    0.05455     EURAUD    0.20000  ...     EURJPY    0.03637
# 21     CHFJPY    0.05455     EURNZD    0.20000  ...     NZDJPY    0.03501
# 22     AUDCHF    0.05455     AUDJPY    0.20000  ...     USDCAD    0.03364
# 23     EURGBP    0.00000     AUDCHF    0.20000  ...     USDCHF    0.03309
# 24     GBPCAD    0.00000     NZDCAD    0.20000  ...     USDJPY    0.03269
# 25     NZDCHF    0.00000     NZDCHF    0.00000  ...     AUDJPY    0.01701
# 26     AUDNZD    0.00000     EURGBP    0.00000  ...     EURCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.24456     GBPCAD    0.37796     GBPCAD    0.42640
# 1      GBPJPY    0.20751     GBPCHF    0.33333     GBPCHF    0.36364
# 2      GBPCAD    0.19767     GBPJPY    0.24254     EURCHF    0.36364
# 3      GBPAUD    0.15714     NZDJPY    0.20000     AUDCAD    0.34247
# 4      EURCHF    0.14833     EURGBP    0.18157     GBPJPY    0.30151
# 5      GBPCHF    0.14833     AUDCHF    0.18157     AUDUSD    0.26189
# 6      AUDNZD    0.13876     GBPUSD    0.18157     AUDCHF    0.26189
# 7      CADJPY    0.13876     EURNZD    0.17408     EURJPY    0.23652
# 8      USDCHF    0.12016     USDCAD    0.17408     NZDCAD    0.18464
# 9      EURUSD    0.12016     CHFJPY    0.17408     AUDJPY    0.18464
# 10     USDJPY    0.12016     NZDUSD    0.12599     GBPUSD    0.18464
# 11     AUDCAD    0.10702     EURCHF    0.12599     USDCHF    0.12309
# 12     NZDCHF    0.10566     NZDCHF    0.12599     EURUSD    0.12309
# 13     CHFJPY    0.08472     GBPAUD    0.11547     USDJPY    0.12309
# 14     USDCAD    0.08472     AUDNZD    0.06667     USDCAD    0.12309
# 15     EURNZD    0.08472     CADCHF    0.06052     CADCHF    0.12309
# 16     NZDJPY    0.07087     CADJPY    0.06052     EURGBP    0.10660
# 17     AUDCHF    0.05648     AUDJPY    0.06052     NZDCHF    0.10660
# 18     NZDCAD    0.04891     NZDCAD    0.06052     NZDUSD    0.10660
# 19     CADCHF    0.04891     EURCAD    0.05803     AUDNZD    0.10660
# 20     AUDJPY    0.04891     AUDCAD    0.05803     NZDJPY    0.07538
# 21     EURCAD    0.03257     AUDUSD    0.00000     GBPAUD    0.04029
# 22     EURGBP    0.01849     EURJPY    0.00000     EURCAD    0.04029
# 23     EURJPY    0.01043     EURAUD    0.00000     EURAUD    0.04029
# 24     NZDUSD    0.01043     USDJPY    0.00000     EURNZD    0.04029
# 25     EURAUD    0.00478     EURUSD    0.00000     CHFJPY    0.04029
# 26     AUDUSD    0.00478     USDCHF    0.00000     CADJPY    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.50000
# 1      AUDCHF    0.50000
# 2      EURGBP    0.40825
# 3      GBPCHF    0.40825
# 4      CHFJPY    0.40825
# 5      GBPJPY    0.32733
# 6      EURCHF    0.32733
# 7      AUDNZD    0.32733
# 8      AUDCAD    0.21822
# 9      NZDJPY    0.21822
# 10     EURJPY    0.16667
# 11     EURUSD    0.10206
# 12     CADJPY    0.10206
# 13     EURCAD    0.10206
# 14     AUDUSD    0.10206
# 15     USDCHF    0.10206
# 16     USDJPY    0.10206
# 17     GBPUSD    0.10206
# 18     NZDCHF    0.10206
# 19     USDCAD    0.10206
# 20     CADCHF    0.10206
# 21     GBPAUD    0.00000
# 22     EURAUD    0.00000
# 23     EURNZD    0.00000
# 24     AUDJPY    0.00000
# 25     NZDCAD    0.00000
# 26     NZDUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
