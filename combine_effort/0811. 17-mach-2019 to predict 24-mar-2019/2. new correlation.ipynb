# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-16 08:48:49.277220

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.26449     USDCHF    0.22172     AUDNZD    0.50252
# 1      NZDCAD    0.16871     NZDUSD    0.20180     AUDCHF    0.45303
# 2      EURUSD    0.14943     AUDNZD    0.20180     EURAUD    0.41414
# 3      EURAUD    0.13497     AUDCHF    0.16477     NZDCHF    0.41414
# 4      NZDJPY    0.12157     NZDCHF    0.14382     GBPCAD    0.38982
# 5      AUDUSD    0.12157     AUDUSD    0.14382     NZDCAD    0.32824
# 6      USDCHF    0.11580     EURUSD    0.14382     USDCHF    0.32824
# 7      AUDNZD    0.10895     NZDCAD    0.14382     EURUSD    0.30151
# 8      CADCHF    0.09688     USDCAD    0.10985     NZDUSD    0.30151
# 9      AUDCHF    0.09688     EURCHF    0.10702     EURNZD    0.30151
# 10     NZDCHF    0.08760     GBPCAD    0.09513     CHFJPY    0.28511
# 11     GBPAUD    0.08760     GBPUSD    0.08597     AUDUSD    0.21212
# 12     EURJPY    0.07462     GBPJPY    0.08597     EURGBP    0.19192
# 13     GBPCHF    0.07462     GBPAUD    0.08597     GBPAUD    0.19192
# 14     NZDUSD    0.07462     EURAUD    0.08597     AUDCAD    0.12309
# 15     AUDJPY    0.06732     CADJPY    0.06727     EURCHF    0.12309
# 16     AUDCAD    0.06204     AUDCAD    0.06727     EURCAD    0.10050
# 17     CADJPY    0.05366     GBPCHF    0.06727     NZDJPY    0.10050
# 18     EURCAD    0.05366     EURJPY    0.06727     GBPCHF    0.10050
# 19     CHFJPY    0.04728     NZDJPY    0.06727     GBPUSD    0.10050
# 20     EURGBP    0.04052     USDJPY    0.04977     USDJPY    0.08206
# 21     GBPUSD    0.04052     CADCHF    0.04977     USDCAD    0.08206
# 22     USDJPY    0.03309     EURGBP    0.04977     AUDJPY    0.03161
# 23     USDCAD    0.02764     CHFJPY    0.03257     CADJPY    0.01010
# 24     EURCHF    0.01959     AUDJPY    0.02746     GBPJPY    0.01010
# 25     EURNZD    0.00649     EURNZD    0.00899     CADCHF    0.01010
# 26     GBPCAD    0.00649     EURCAD    0.00899     EURJPY    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.44444     AUDNZD    0.58333  ...     EURNZD    0.23775
# 1      EURUSD    0.44444     EURUSD    0.58333  ...     USDCAD    0.20773
# 2      GBPCHF    0.38889     AUDCHF    0.53452  ...     CADCHF    0.19025
# 3      AUDCHF    0.38889     CADCHF    0.40825  ...     AUDCAD    0.15198
# 4      USDCHF    0.38889     EURAUD    0.40825  ...     EURGBP    0.12039
# 5      NZDCHF    0.32733     GBPCAD    0.35635  ...     CADJPY    0.11433
# 6      EURAUD    0.32733     EURGBP    0.35635  ...     AUDCHF    0.10895
# 7      EURCHF    0.28868     USDCHF    0.25000  ...     CHFJPY    0.10701
# 8      CHFJPY    0.28868     EURCAD    0.25000  ...     USDJPY    0.09829
# 9      CADCHF    0.28868     NZDCAD    0.25000  ...     NZDCAD    0.08353
# 10     GBPCAD    0.28868     AUDCAD    0.25000  ...     GBPCHF    0.08353
# 11     NZDCAD    0.21822     NZDCHF    0.25000  ...     GBPCAD    0.08353
# 12     EURCAD    0.21822     NZDJPY    0.16667  ...     NZDUSD    0.07711
# 13     NZDUSD    0.16667     GBPUSD    0.16667  ...     GBPAUD    0.07711
# 14     AUDJPY    0.16667     USDCAD    0.16667  ...     EURJPY    0.07711
# 15     EURNZD    0.16667     GBPAUD    0.16667  ...     NZDCHF    0.07711
# 16     CADJPY    0.11111     AUDJPY    0.10206  ...     EURUSD    0.05366
# 17     GBPUSD    0.11111     EURJPY    0.10206  ...     EURCAD    0.04670
# 18     NZDJPY    0.11111     EURCHF    0.08909  ...     GBPUSD    0.04013
# 19     AUDUSD    0.05455     USDJPY    0.08909  ...     AUDUSD    0.04013
# 20     AUDCAD    0.05455     CADJPY    0.08909  ...     NZDJPY    0.04013
# 21     EURGBP    0.05455     GBPJPY    0.08909  ...     AUDNZD    0.03382
# 22     EURJPY    0.05455     CHFJPY    0.08909  ...     EURAUD    0.03382
# 23     GBPJPY    0.05455     GBPCHF    0.08909  ...     AUDJPY    0.02764
# 24     USDJPY    0.05455     EURNZD    0.00000  ...     USDCHF    0.01638
# 25     USDCAD    0.05455     AUDUSD    0.00000  ...     GBPJPY    0.00970
# 26     GBPAUD    0.00000     NZDUSD    0.00000  ...     EURCHF    0.00970
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.40825     USDJPY    0.61237     USDJPY    0.49099
# 1      USDJPY    0.33634     USDCAD    0.61237     USDCAD    0.49099
# 2      EURUSD    0.26726     EURUSD    0.60000     AUDUSD    0.49099
# 3      EURNZD    0.26726     USDCHF    0.40825     EURUSD    0.44444
# 4      USDCHF    0.20180     AUDUSD    0.30151     USDCHF    0.38889
# 5      GBPCAD    0.14142     EURGBP    0.30151     NZDUSD    0.38889
# 6      AUDUSD    0.13363     CHFJPY    0.21822     EURNZD    0.38889
# 7      EURCAD    0.13363     EURCHF    0.20412     NZDCHF    0.21822
# 8      NZDCHF    0.13363     AUDCAD    0.20412     AUDCAD    0.21822
# 9      EURCHF    0.06917     NZDUSD    0.20000     EURGBP    0.21822
# 10     CHFJPY    0.06917     GBPUSD    0.20000     GBPUSD    0.16667
# 11     GBPJPY    0.06727     GBPCHF    0.20000     GBPCHF    0.16667
# 12     EURAUD    0.06727     EURNZD    0.20000     CADJPY    0.16667
# 13     GBPAUD    0.06727     AUDCHF    0.10483     AUDNZD    0.11111
# 14     EURGBP    0.06727     AUDJPY    0.10483     NZDJPY    0.11111
# 15     GBPUSD    0.06727     GBPCAD    0.10483     AUDJPY    0.11111
# 16     CADCHF    0.06727     EURAUD    0.10050     AUDCHF    0.11111
# 17     EURJPY    0.06667     CADJPY    0.10050     EURAUD    0.05455
# 18     GBPCHF    0.06667     GBPAUD    0.10050     NZDCAD    0.05455
# 19     NZDUSD    0.06667     EURJPY    0.10050     EURCAD    0.05455
# 20     CADJPY    0.06667     GBPJPY    0.10050     EURJPY    0.05455
# 21     NZDJPY    0.06667     NZDCHF    0.10050     GBPJPY    0.05455
# 22     AUDCAD    0.06667     CADCHF    0.10050     EURCHF    0.00000
# 23     AUDNZD    0.06667     EURCAD    0.00000     GBPAUD    0.00000
# 24     AUDCHF    0.00000     NZDJPY    0.00000     GBPCAD    0.00000
# 25     AUDJPY    0.00000     NZDCAD    0.00000     CHFJPY    0.00000
# 26     NZDCAD    0.00000     AUDNZD    0.00000     CADCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCAD    0.81650
# 1      CADJPY    0.65465
# 2      AUDUSD    0.60000
# 3      NZDUSD    0.60000
# 4      EURNZD    0.60000
# 5      AUDJPY    0.50000
# 6      CADCHF    0.50000
# 7      EURJPY    0.50000
# 8      USDCHF    0.40825
# 9      EURUSD    0.40825
# 10     NZDJPY    0.40825
# 11     EURCAD    0.40825
# 12     NZDCHF    0.40825
# 13     GBPAUD    0.40825
# 14     GBPCAD    0.21822
# 15     EURGBP    0.21822
# 16     GBPJPY    0.21822
# 17     AUDCHF    0.21822
# 18     CHFJPY    0.21822
# 19     EURCHF    0.21822
# 20     GBPCHF    0.21822
# 21     USDJPY    0.21822
# 22     EURAUD    0.20000
# 23     GBPUSD    0.00000
# 24     AUDCAD    0.00000
# 25     NZDCAD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
