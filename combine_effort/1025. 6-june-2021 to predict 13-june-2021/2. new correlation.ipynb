# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 23:03:43.790932

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.27421     EURJPY    0.43179     CADJPY    0.47140
# 1      CADJPY    0.27421     CADJPY    0.40825     GBPCHF    0.47140
# 2      EURJPY    0.27263     GBPJPY    0.29881     GBPJPY    0.35722
# 3      GBPJPY    0.27263     GBPCHF    0.26245     CADCHF    0.25678
# 4      EURUSD    0.21627     CHFJPY    0.25882     USDCAD    0.25000
# 5      EURGBP    0.19025     EURAUD    0.21822     EURJPY    0.22866
# 6      AUDNZD    0.18021     EURUSD    0.20536     AUDUSD    0.20412
# 7      GBPUSD    0.15418     AUDNZD    0.18898     GBPAUD    0.20412
# 8      EURNZD    0.15198     EURGBP    0.15714     USDCHF    0.16667
# 9      CADCHF    0.14385     AUDCAD    0.14382     CHFJPY    0.16667
# 10     NZDJPY    0.11699     EURNZD    0.14382     NZDCHF    0.16667
# 11     GBPCHF    0.10701     AUDCHF    0.09449     GBPCAD    0.13363
# 12     AUDJPY    0.10701     AUDUSD    0.08183     EURUSD    0.12309
# 13     NZDUSD    0.10701     USDCAD    0.08183     EURCAD    0.12309
# 14     AUDCHF    0.10417     GBPAUD    0.06250     EURGBP    0.08909
# 15     NZDCAD    0.09829     NZDCHF    0.04725     AUDCHF    0.08206
# 16     EURCAD    0.07711     GBPCAD    0.04725     USDJPY    0.08206
# 17     GBPAUD    0.07114     AUDJPY    0.04725     AUDCAD    0.08206
# 18     EURAUD    0.07114     NZDJPY    0.04213     NZDCAD    0.08206
# 19     AUDCAD    0.06553     CADCHF    0.04029     GBPUSD    0.04280
# 20     NZDCHF    0.06118     GBPUSD    0.02916     EURCHF    0.04280
# 21     USDCHF    0.04670     NZDUSD    0.02916     AUDNZD    0.04280
# 22     USDJPY    0.04013     EURCHF    0.01849     NZDUSD    0.04167
# 23     EURCHF    0.02341     NZDCAD    0.01849     AUDJPY    0.04167
# 24     AUDUSD    0.02341     EURCAD    0.00899     EURAUD    0.00000
# 25     GBPCAD    0.02150     USDJPY    0.00899     EURNZD    0.00000
# 26     USDCAD    0.01638     USDCHF    0.00899     NZDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPCHF    0.47246     CADCHF    0.53452  ...     GBPUSD    0.24131
# 1      CADJPY    0.47246     GBPCHF    0.53452  ...     EURUSD    0.19852
# 2      CADCHF    0.47246     CADJPY    0.53452  ...     USDCHF    0.18021
# 3      GBPJPY    0.34247     EURUSD    0.53452  ...     USDJPY    0.16330
# 4      USDCHF    0.32733     GBPUSD    0.42857  ...     CADJPY    0.15309
# 5      AUDUSD    0.32733     CHFJPY    0.42857  ...     EURAUD    0.14804
# 6      USDCAD    0.21822     GBPCAD    0.42857  ...     GBPCAD    0.13457
# 7      USDJPY    0.19643     GBPJPY    0.42857  ...     GBPJPY    0.11169
# 8      NZDUSD    0.19643     NZDCAD    0.21822  ...     GBPCHF    0.10206
# 9      GBPAUD    0.19643     EURCAD    0.21822  ...     NZDCAD    0.08333
# 10     AUDCHF    0.19643     EURJPY    0.21822  ...     AUDCAD    0.08333
# 11     NZDCHF    0.19643     GBPAUD    0.21822  ...     AUDNZD    0.08333
# 12     AUDCAD    0.18898     AUDCHF    0.21822  ...     EURJPY    0.07446
# 13     AUDNZD    0.18898     NZDCHF    0.21822  ...     EURCHF    0.06804
# 14     NZDJPY    0.09449     EURNZD    0.21822  ...     AUDJPY    0.06804
# 15     EURGBP    0.09449     EURCHF    0.21822  ...     GBPAUD    0.06580
# 16     GBPUSD    0.07143     AUDUSD    0.21822  ...     EURNZD    0.06580
# 17     CHFJPY    0.07143     AUDCAD    0.08909  ...     NZDJPY    0.05251
# 18     EURAUD    0.07143     AUDJPY    0.08909  ...     NZDCHF    0.05046
# 19     EURNZD    0.07143     USDCHF    0.08909  ...     AUDCHF    0.05046
# 20     AUDJPY    0.07143     AUDNZD    0.08909  ...     CADCHF    0.05046
# 21     EURUSD    0.07143     EURAUD    0.08909  ...     EURGBP    0.04963
# 22     NZDCAD    0.07143     NZDUSD    0.08909  ...     EURCAD    0.03269
# 23     GBPCAD    0.05455     USDJPY    0.08909  ...     CHFJPY    0.01701
# 24     EURCAD    0.05455     NZDJPY    0.04762  ...     NZDUSD    0.01701
# 25     EURCHF    0.05455     USDCAD    0.04762  ...     AUDUSD    0.01701
# 26     EURJPY    0.02621     EURGBP    0.04762  ...     USDCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.46291     GBPCAD    0.42857     GBPCAD    0.49237
# 1      GBPCHF    0.42857     GBPCHF    0.37796     USDCHF    0.43082
# 2      GBPJPY    0.29277     USDCHF    0.35635     GBPCHF    0.42640
# 3      GBPUSD    0.26984     GBPJPY    0.32733     AUDNZD    0.42640
# 4      EURGBP    0.19623     EURUSD    0.28511     GBPJPY    0.36364
# 5      GBPAUD    0.17496     USDJPY    0.28511     EURUSD    0.34247
# 6      USDCHF    0.16147     AUDCAD    0.28511     USDJPY    0.34247
# 7      USDJPY    0.16147     EURJPY    0.27501     GBPUSD    0.26189
# 8      NZDJPY    0.15478     GBPUSD    0.25163     AUDCHF    0.26189
# 9      AUDJPY    0.15430     AUDNZD    0.25163     EURJPY    0.23652
# 10     AUDCHF    0.15430     AUDUSD    0.21822     AUDCAD    0.21320
# 11     AUDCAD    0.13211     NZDCAD    0.15352     NZDJPY    0.21320
# 12     EURUSD    0.11664     AUDCHF    0.15352     USDCAD    0.18464
# 13     CHFJPY    0.10566     CADJPY    0.12599     AUDUSD    0.12309
# 14     EURAUD    0.08909     NZDJPY    0.12599     EURCAD    0.12309
# 15     CADCHF    0.06580     NZDCHF    0.08909     EURCHF    0.12309
# 16     AUDUSD    0.05939     CHFJPY    0.08909     CADCHF    0.10660
# 17     USDCAD    0.05939     NZDUSD    0.08909     CADJPY    0.10660
# 18     NZDUSD    0.04762     USDCAD    0.08909     EURGBP    0.10660
# 19     CADJPY    0.04762     AUDJPY    0.08909     NZDCHF    0.04029
# 20     NZDCAD    0.04528     EURCAD    0.06580     GBPAUD    0.04029
# 21     EURCHF    0.04528     EURGBP    0.04762     CHFJPY    0.04029
# 22     EURJPY    0.01720     EURCHF    0.02288     EURAUD    0.04029
# 23     EURNZD    0.01468     CADCHF    0.02288     EURNZD    0.04029
# 24     EURCAD    0.01468     EURNZD    0.00000     AUDJPY    0.04029
# 25     NZDCHF    0.00000     EURAUD    0.00000     NZDUSD    0.04029
# 26     AUDNZD    0.00000     GBPAUD    0.00000     NZDCAD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.53452
# 1      USDJPY    0.53452
# 2      GBPCHF    0.53452
# 3      AUDNZD    0.53452
# 4      EURUSD    0.53452
# 5      USDCAD    0.42857
# 6      GBPUSD    0.42857
# 7      GBPJPY    0.42857
# 8      GBPCAD    0.42857
# 9      AUDCAD    0.35635
# 10     EURAUD    0.35635
# 11     EURCAD    0.21822
# 12     AUDCHF    0.21822
# 13     NZDCHF    0.21822
# 14     EURCHF    0.21822
# 15     AUDUSD    0.21822
# 16     GBPAUD    0.21822
# 17     EURJPY    0.21822
# 18     EURNZD    0.21822
# 19     NZDCAD    0.21822
# 20     NZDUSD    0.08909
# 21     CADCHF    0.08909
# 22     CADJPY    0.08909
# 23     AUDJPY    0.08909
# 24     CHFJPY    0.04762
# 25     NZDJPY    0.04762
# 26     EURGBP    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
