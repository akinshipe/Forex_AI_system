# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:53:43.606543

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.34300     EURJPY    0.45505     CADJPY    0.38982
# 1      CHFJPY    0.33333     GBPJPY    0.38536     GBPCHF    0.38982
# 2      EURUSD    0.32026     CADJPY    0.38052     GBPJPY    0.38982
# 3      GBPJPY    0.30551     CHFJPY    0.31175     AUDCHF    0.30151
# 4      CADJPY    0.25000     GBPCHF    0.30826     AUDNZD    0.28721
# 5      AUDNZD    0.20261     EURUSD    0.30208     CADCHF    0.28511
# 6      USDCHF    0.20000     NZDCAD    0.18552     NZDCAD    0.21212
# 7      GBPUSD    0.16667     NZDCHF    0.17216     EURNZD    0.21212
# 8      NZDUSD    0.16330     USDCHF    0.16477     EURAUD    0.21212
# 9      AUDJPY    0.16330     AUDCAD    0.12585     NZDCHF    0.19192
# 10     EURGBP    0.16116     AUDJPY    0.10985     USDJPY    0.17911
# 11     NZDCAD    0.16116     NZDUSD    0.10985     EURJPY    0.17408
# 12     NZDJPY    0.12666     EURCHF    0.10985     AUDCAD    0.12309
# 13     GBPAUD    0.12157     AUDCHF    0.10985     EURUSD    0.12309
# 14     AUDUSD    0.12157     GBPUSD    0.10985     AUDJPY    0.10050
# 15     EURCAD    0.12039     AUDNZD    0.09513     GBPUSD    0.10050
# 16     GBPCHF    0.08333     EURCAD    0.08597     EURCAD    0.08206
# 17     NZDCHF    0.08165     EURNZD    0.06727     USDCHF    0.08206
# 18     AUDCAD    0.08058     USDJPY    0.02746     CHFJPY    0.08206
# 19     EURNZD    0.08006     EURGBP    0.02746     EURCHF    0.08206
# 20     CADCHF    0.04222     GBPCAD    0.01468     AUDUSD    0.08206
# 21     EURCHF    0.04120     CADCHF    0.01468     EURGBP    0.08206
# 22     GBPCAD    0.04120     NZDJPY    0.01468     GBPCAD    0.03161
# 23     AUDCHF    0.04052     GBPAUD    0.00899     NZDJPY    0.03161
# 24     EURAUD    0.04013     EURAUD    0.00899     GBPAUD    0.01010
# 25     USDJPY    0.00000     AUDUSD    0.00899     NZDUSD    0.01010
# 26     USDCAD    0.00000     USDCAD    0.00899     USDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.38889     EURUSD    0.81650  ...     GBPUSD    0.21612
# 1      GBPJPY    0.38889     NZDUSD    0.65465  ...     CADJPY    0.20599
# 2      GBPCHF    0.38889     NZDCAD    0.65465  ...     USDCHF    0.20261
# 3      EURUSD    0.32733     USDCHF    0.60000  ...     EURUSD    0.16871
# 4      AUDCHF    0.32733     GBPUSD    0.60000  ...     NZDJPY    0.15911
# 5      CHFJPY    0.28868     CHFJPY    0.50000  ...     USDJPY    0.15573
# 6      CADCHF    0.28868     GBPCHF    0.40825  ...     AUDJPY    0.13234
# 7      USDCHF    0.21822     AUDCAD    0.40825  ...     GBPCHF    0.13170
# 8      GBPUSD    0.21822     EURNZD    0.40825  ...     EURJPY    0.11119
# 9      AUDNZD    0.21822     AUDCHF    0.40825  ...     EURCAD    0.10895
# 10     GBPCAD    0.18464     NZDCHF    0.40825  ...     AUDCAD    0.10123
# 11     EURJPY    0.18464     GBPJPY    0.40825  ...     AUDNZD    0.09688
# 12     NZDCAD    0.16667     EURJPY    0.40825  ...     GBPCAD    0.08181
# 13     AUDCAD    0.16667     EURCAD    0.40825  ...     GBPAUD    0.06732
# 14     NZDJPY    0.16667     AUDUSD    0.21822  ...     EURGBP    0.06204
# 15     EURNZD    0.16667     USDJPY    0.21822  ...     EURAUD    0.05366
# 16     EURGBP    0.11111     GBPCAD    0.21822  ...     NZDCHF    0.04963
# 17     USDJPY    0.11111     CADJPY    0.21822  ...     NZDUSD    0.04963
# 18     AUDUSD    0.11111     AUDJPY    0.20000  ...     USDCAD    0.04963
# 19     GBPAUD    0.11111     AUDNZD    0.20000  ...     CHFJPY    0.03715
# 20     AUDJPY    0.05455     USDCAD    0.20000  ...     GBPJPY    0.02653
# 21     EURCHF    0.05455     EURAUD    0.00000  ...     NZDCAD    0.01959
# 22     NZDUSD    0.05455     GBPAUD    0.00000  ...     AUDCHF    0.01478
# 23     USDCAD    0.05455     CADCHF    0.00000  ...     AUDUSD    0.01478
# 24     NZDCHF    0.05455     NZDJPY    0.00000  ...     CADCHF    0.01198
# 25     EURCAD    0.05455     EURCHF    0.00000  ...     EURNZD    0.00649
# 26     EURAUD    0.00000     EURGBP    0.00000  ...     EURCHF    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.30861     GBPCHF    0.38516     GBPCHF    0.49099
# 1      GBPCHF    0.30861     GBPCAD    0.38516     USDCHF    0.33929
# 2      GBPCAD    0.30861     USDCHF    0.37500     AUDNZD    0.33929
# 3      USDCHF    0.28868     AUDCAD    0.37500     NZDJPY    0.32733
# 4      NZDCHF    0.19565     NZDJPY    0.25678     AUDCAD    0.32733
# 5      EURUSD    0.14434     AUDNZD    0.25000     GBPCAD    0.26189
# 6      NZDUSD    0.14434     AUDCHF    0.20412     GBPJPY    0.21822
# 7      AUDJPY    0.14434     GBPUSD    0.20412     EURCAD    0.19643
# 8      GBPUSD    0.14434     GBPJPY    0.17118     EURUSD    0.19643
# 9      EURNZD    0.14142     EURCAD    0.16667     AUDCHF    0.19643
# 10     GBPJPY    0.10660     EURUSD    0.16667     EURAUD    0.18898
# 11     CADJPY    0.10000     AUDUSD    0.16667     CHFJPY    0.18898
# 12     NZDCAD    0.09513     USDCAD    0.12309     CADCHF    0.09449
# 13     EURCAD    0.09513     CADCHF    0.08909     USDCAD    0.07143
# 14     GBPAUD    0.09449     NZDUSD    0.08206     NZDCHF    0.07143
# 15     AUDCAD    0.09449     NZDCAD    0.08206     GBPUSD    0.07143
# 16     AUDNZD    0.05000     EURNZD    0.08206     EURCHF    0.07143
# 17     CHFJPY    0.04891     EURAUD    0.08206     NZDUSD    0.07143
# 18     EURAUD    0.04725     GBPAUD    0.08206     AUDJPY    0.07143
# 19     AUDUSD    0.04725     NZDCHF    0.08206     CADJPY    0.05455
# 20     USDCAD    0.04725     CADJPY    0.04280     NZDCAD    0.05455
# 21     EURJPY    0.00000     USDJPY    0.04280     USDJPY    0.05455
# 22     AUDCHF    0.00000     CHFJPY    0.04167     EURNZD    0.05455
# 23     CADCHF    0.00000     EURCHF    0.04167     GBPAUD    0.05455
# 24     EURCHF    0.00000     EURGBP    0.04167     AUDUSD    0.05455
# 25     USDJPY    0.00000     EURJPY    0.00000     EURGBP    0.05455
# 26     EURGBP    0.00000     AUDJPY    0.00000     EURJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.60000
# 1      GBPCHF    0.40825
# 2      AUDCAD    0.40825
# 3      NZDJPY    0.40825
# 4      EURCAD    0.40825
# 5      EURGBP    0.40825
# 6      EURUSD    0.40825
# 7      NZDUSD    0.21822
# 8      GBPCAD    0.21822
# 9      NZDCAD    0.21822
# 10     USDJPY    0.21822
# 11     CADJPY    0.21822
# 12     AUDUSD    0.21822
# 13     AUDJPY    0.20000
# 14     USDCAD    0.20000
# 15     AUDNZD    0.20000
# 16     GBPUSD    0.20000
# 17     GBPJPY    0.00000
# 18     EURJPY    0.00000
# 19     EURAUD    0.00000
# 20     EURNZD    0.00000
# 21     NZDCHF    0.00000
# 22     AUDCHF    0.00000
# 23     CADCHF    0.00000
# 24     CHFJPY    0.00000
# 25     EURCHF    0.00000
# 26     GBPAUD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
