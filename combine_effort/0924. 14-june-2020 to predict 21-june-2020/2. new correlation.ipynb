# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 14:41:36.895116

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.35286     USDJPY    0.38446     USDJPY    0.40825
# 1      USDCHF    0.32450     AUDNZD    0.27866     AUDCAD    0.40825
# 2      NZDCAD    0.32450     GBPCAD    0.26068     EURJPY    0.40825
# 3      AUDCAD    0.24418     AUDCAD    0.22172     GBPUSD    0.40000
# 4      GBPUSD    0.24418     EURJPY    0.22172     AUDUSD    0.30151
# 5      EURJPY    0.23775     GBPUSD    0.14382     NZDUSD    0.30151
# 6      EURUSD    0.23775     USDCHF    0.14382     CHFJPY    0.30151
# 7      NZDUSD    0.23775     GBPAUD    0.10985     EURAUD    0.30151
# 8      CHFJPY    0.21627     AUDJPY    0.10985     EURGBP    0.20412
# 9      CADCHF    0.20064     NZDCAD    0.08597     NZDCAD    0.20412
# 10     AUDUSD    0.19485     USDCAD    0.06727     NZDJPY    0.20412
# 11     CADJPY    0.15743     CADJPY    0.06727     EURNZD    0.20412
# 12     EURCAD    0.12039     EURNZD    0.06727     AUDNZD    0.20412
# 13     NZDJPY    0.09829     EURAUD    0.06727     AUDCHF    0.20000
# 14     USDCAD    0.08353     EURCAD    0.06727     GBPCHF    0.20000
# 15     GBPJPY    0.07711     AUDUSD    0.06727     EURUSD    0.20000
# 16     AUDNZD    0.05366     GBPJPY    0.06727     USDCHF    0.20000
# 17     EURNZD    0.04013     NZDUSD    0.06727     NZDCHF    0.10050
# 18     NZDCHF    0.04013     AUDCHF    0.06727     GBPJPY    0.10050
# 19     EURGBP    0.04013     CADCHF    0.06727     GBPAUD    0.10050
# 20     GBPAUD    0.03382     EURCHF    0.04977     EURCHF    0.10050
# 21     GBPCAD    0.03382     NZDJPY    0.03257     CADJPY    0.10050
# 22     EURAUD    0.03382     CHFJPY    0.02746     AUDJPY    0.10050
# 23     AUDJPY    0.02764     EURUSD    0.00899     USDCAD    0.10050
# 24     GBPCHF    0.01638     GBPCHF    0.00899     GBPCAD    0.00000
# 25     EURCHF    0.00970     NZDCHF    0.00899     EURCAD    0.00000
# 26     AUDCHF    0.00321     EURGBP    0.00899     CADCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDJPY    0.49099     AUDCAD    0.50000  ...     GBPCAD    0.43417
# 1      AUDUSD    0.47246     AUDUSD    0.50000  ...     GBPUSD    0.31795
# 2      AUDCAD    0.47246     EURGBP    0.40825  ...     GBPCHF    0.29778
# 3      NZDUSD    0.46429     GBPCHF    0.40825  ...     AUDUSD    0.29758
# 4      GBPUSD    0.46429     EURCAD    0.40825  ...     EURGBP    0.28365
# 5      NZDCAD    0.34247     GBPUSD    0.40825  ...     CADCHF    0.28365
# 6      USDCHF    0.33929     AUDNZD    0.40825  ...     GBPJPY    0.24982
# 7      EURUSD    0.33929     NZDUSD    0.40825  ...     EURUSD    0.24982
# 8      USDCAD    0.33929     USDJPY    0.40825  ...     NZDCAD    0.23684
# 9      EURJPY    0.32733     NZDCAD    0.33333  ...     AUDCAD    0.23684
# 10     CHFJPY    0.32733     GBPAUD    0.21822  ...     AUDCHF    0.23684
# 11     NZDJPY    0.32733     AUDCHF    0.21822  ...     USDJPY    0.23153
# 12     EURAUD    0.32733     NZDJPY    0.21822  ...     EURCAD    0.20261
# 13     CADJPY    0.21822     EURAUD    0.21822  ...     GBPAUD    0.19025
# 14     EURNZD    0.21822     EURUSD    0.20000  ...     USDCHF    0.15573
# 15     EURGBP    0.21822     CADJPY    0.20000  ...     USDCAD    0.15573
# 16     GBPJPY    0.21822     USDCHF    0.20000  ...     EURAUD    0.10895
# 17     AUDCHF    0.19643     GBPJPY    0.20000  ...     EURCHF    0.10123
# 18     AUDJPY    0.19643     USDCAD    0.20000  ...     EURJPY    0.08760
# 19     GBPCHF    0.19643     EURCHF    0.00000  ...     CADJPY    0.08760
# 20     AUDNZD    0.19643     GBPCAD    0.00000  ...     NZDUSD    0.08760
# 21     GBPAUD    0.07143     EURNZD    0.00000  ...     AUDNZD    0.06732
# 22     GBPCAD    0.07143     AUDJPY    0.00000  ...     NZDJPY    0.04963
# 23     EURCAD    0.07143     NZDCHF    0.00000  ...     NZDCHF    0.04052
# 24     NZDCHF    0.07143     CADCHF    0.00000  ...     EURNZD    0.04052
# 25     CADCHF    0.07143     CHFJPY    0.00000  ...     CHFJPY    0.01478
# 26     EURCHF    0.07143     EURJPY    0.00000  ...     AUDJPY    0.01478
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.53035     EURGBP    0.45833     EURGBP    0.49099
# 1      EURGBP    0.41349     USDJPY    0.45833     USDJPY    0.49099
# 2      GBPCHF    0.39551     GBPCAD    0.40825     GBPCHF    0.46429
# 3      NZDCAD    0.32127     GBPCHF    0.40825     NZDCAD    0.34247
# 4      USDJPY    0.30208     CHFJPY    0.32824     GBPAUD    0.33929
# 5      GBPUSD    0.26068     GBPAUD    0.28721     GBPCAD    0.33929
# 6      GBPAUD    0.24716     EURNZD    0.25000     USDCHF    0.33929
# 7      AUDUSD    0.20180     EURJPY    0.25000     EURJPY    0.21822
# 8      EURNZD    0.20180     AUDCHF    0.20412     CHFJPY    0.21822
# 9      EURAUD    0.20180     GBPUSD    0.20412     EURNZD    0.21822
# 10     CADCHF    0.20180     USDCHF    0.20412     GBPJPY    0.21822
# 11     AUDCHF    0.20180     AUDCAD    0.16667     GBPUSD    0.19643
# 12     EURCAD    0.20180     NZDCAD    0.16667     NZDUSD    0.19643
# 13     GBPJPY    0.20180     NZDCHF    0.12309     AUDCHF    0.19643
# 14     AUDCAD    0.18552     EURCHF    0.12309     AUDUSD    0.18898
# 15     CHFJPY    0.16477     GBPJPY    0.12309     AUDCAD    0.18898
# 16     AUDNZD    0.14382     NZDUSD    0.12309     NZDCHF    0.07143
# 17     NZDCHF    0.14382     AUDJPY    0.12309     USDCAD    0.07143
# 18     EURUSD    0.14382     AUDUSD    0.08206     EURCHF    0.07143
# 19     USDCHF    0.12585     USDCAD    0.08206     EURCAD    0.07143
# 20     EURJPY    0.08597     EURAUD    0.08206     CADCHF    0.07143
# 21     EURCHF    0.08597     CADJPY    0.08206     AUDJPY    0.07143
# 22     NZDUSD    0.06727     NZDJPY    0.04167     EURUSD    0.07143
# 23     CADJPY    0.06727     AUDNZD    0.04167     AUDNZD    0.07143
# 24     USDCAD    0.06727     CADCHF    0.00000     EURAUD    0.05455
# 25     NZDJPY    0.03257     EURCAD    0.00000     CADJPY    0.05455
# 26     AUDJPY    0.02746     EURUSD    0.00000     NZDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.66667
# 1      GBPAUD    0.53452
# 2      USDCHF    0.40825
# 3      NZDCAD    0.40825
# 4      NZDCHF    0.25000
# 5      AUDJPY    0.25000
# 6      EURNZD    0.25000
# 7      EURCAD    0.25000
# 8      EURJPY    0.25000
# 9      GBPCAD    0.25000
# 10     EURGBP    0.25000
# 11     CADCHF    0.25000
# 12     CHFJPY    0.25000
# 13     EURCHF    0.25000
# 14     AUDNZD    0.25000
# 15     GBPUSD    0.16667
# 16     GBPCHF    0.16667
# 17     NZDUSD    0.16667
# 18     AUDUSD    0.10206
# 19     AUDCAD    0.10206
# 20     AUDCHF    0.08909
# 21     EURAUD    0.08909
# 22     NZDJPY    0.08909
# 23     GBPJPY    0.00000
# 24     CADJPY    0.00000
# 25     USDCAD    0.00000
# 26     EURUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
