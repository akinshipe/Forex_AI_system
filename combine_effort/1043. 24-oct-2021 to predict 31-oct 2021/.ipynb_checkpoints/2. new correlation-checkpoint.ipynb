# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:48:52.705824

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.27146     NZDCAD    0.40089     NZDCAD    0.50252
# 1      EURJPY    0.26952     AUDCAD    0.33929     AUDCAD    0.49237
# 2      EURUSD    0.25223     EURUSD    0.33036     EURUSD    0.32824
# 3      CADJPY    0.22740     GBPJPY    0.27866     NZDUSD    0.30151
# 4      NZDCAD    0.19025     EURCAD    0.26726     EURCAD    0.30151
# 5      GBPCHF    0.18684     NZDUSD    0.20536     GBPJPY    0.30151
# 6      EURAUD    0.12721     GBPCHF    0.20536     USDJPY    0.29013
# 7      EURCAD    0.12721     GBPUSD    0.20536     EURNZD    0.24232
# 8      AUDCAD    0.10895     EURNZD    0.19094     EURCHF    0.24232
# 9      USDJPY    0.10701     CADJPY    0.14382     CADCHF    0.24232
# 10     NZDUSD    0.10417     NZDCHF    0.14382     USDCHF    0.21212
# 11     CHFJPY    0.10417     USDCHF    0.13363     GBPUSD    0.21212
# 12     USDCHF    0.09054     USDJPY    0.12016     EURGBP    0.21212
# 13     CADCHF    0.07881     GBPCAD    0.09449     USDCAD    0.21212
# 14     AUDNZD    0.07711     AUDNZD    0.08183     EURJPY    0.12309
# 15     EURCHF    0.07711     AUDUSD    0.07143     CHFJPY    0.12309
# 16     GBPUSD    0.06553     USDCAD    0.07143     GBPAUD    0.10050
# 17     NZDCHF    0.06019     EURGBP    0.07143     GBPCHF    0.10050
# 18     AUDCHF    0.05366     AUDCHF    0.06250     AUDJPY    0.10050
# 19     AUDUSD    0.04670     AUDJPY    0.06250     NZDCHF    0.08206
# 20     USDCAD    0.03382     EURCHF    0.05455     NZDJPY    0.08206
# 21     AUDJPY    0.01638     CADCHF    0.01849     AUDNZD    0.06580
# 22     GBPCAD    0.01525     CHFJPY    0.01849     GBPCAD    0.03161
# 23     EURGBP    0.00970     NZDJPY    0.01849     AUDCHF    0.01010
# 24     NZDJPY    0.00876     EURJPY    0.00899     EURAUD    0.01010
# 25     GBPAUD    0.00321     EURAUD    0.00899     CADJPY    0.01010
# 26     EURNZD    0.00321     GBPAUD    0.00000     AUDUSD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.46429     GBPJPY    0.66667  ...     GBPCAD    0.23889
# 1      EURCHF    0.37796     USDCAD    0.40825  ...     AUDNZD    0.23775
# 2      AUDNZD    0.34247     NZDCAD    0.40825  ...     GBPCHF    0.22653
# 3      EURCAD    0.33929     EURJPY    0.40825  ...     GBPUSD    0.18021
# 4      CHFJPY    0.33929     EURCHF    0.35635  ...     USDCHF    0.15198
# 5      NZDUSD    0.32733     AUDNZD    0.25000  ...     EURUSD    0.15198
# 6      AUDCAD    0.32733     CADJPY    0.25000  ...     AUDJPY    0.14744
# 7      GBPJPY    0.32733     GBPCHF    0.25000  ...     AUDCAD    0.13497
# 8      USDJPY    0.26189     NZDJPY    0.25000  ...     EURCAD    0.11433
# 9      EURUSD    0.21822     NZDCHF    0.25000  ...     NZDJPY    0.09632
# 10     AUDJPY    0.21822     AUDCAD    0.25000  ...     EURGBP    0.09054
# 11     EURNZD    0.21822     EURNZD    0.16667  ...     GBPAUD    0.08353
# 12     USDCAD    0.19643     EURCAD    0.16667  ...     GBPJPY    0.07881
# 13     GBPCHF    0.19643     GBPCAD    0.16667  ...     NZDUSD    0.06118
# 14     NZDCHF    0.18898     AUDCHF    0.16667  ...     NZDCHF    0.06019
# 15     NZDJPY    0.18898     CHFJPY    0.16667  ...     USDJPY    0.06019
# 16     CADCHF    0.09449     AUDUSD    0.16667  ...     CADJPY    0.06019
# 17     EURAUD    0.07143     EURUSD    0.16667  ...     AUDCHF    0.05366
# 18     EURGBP    0.07143     USDJPY    0.10206  ...     NZDCAD    0.05366
# 19     EURJPY    0.07143     CADCHF    0.08909  ...     USDCAD    0.04670
# 20     GBPUSD    0.07143     GBPAUD    0.08909  ...     EURAUD    0.03382
# 21     AUDCHF    0.07143     EURAUD    0.08909  ...     AUDUSD    0.03382
# 22     AUDUSD    0.07143     AUDJPY    0.08909  ...     EURJPY    0.02150
# 23     GBPAUD    0.05455     USDCHF    0.00000  ...     CHFJPY    0.02150
# 24     CADJPY    0.05455     GBPUSD    0.00000  ...     CADCHF    0.00876
# 25     GBPCAD    0.05455     NZDUSD    0.00000  ...     EURNZD    0.00321
# 26     USDCHF    0.05455     EURGBP    0.00000  ...     EURCHF    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      EURUSD    0.27866     NZDUSD    0.43644     NZDUSD    0.57735
# 1      GBPUSD    0.26068     GBPUSD    0.37284     AUDNZD    0.53300
# 2      USDCAD    0.26068     USDCAD    0.37284     USDCAD    0.47246
# 3      NZDUSD    0.26068     EURUSD    0.31180     NZDJPY    0.40000
# 4      GBPCHF    0.26068     EURJPY    0.31180     EURJPY    0.37796
# 5      AUDCAD    0.26068     AUDNZD    0.28571     GBPUSD    0.37796
# 6      USDCHF    0.20180     EURNZD    0.25163     EURNZD    0.28868
# 7      NZDCAD    0.20180     EURCHF    0.25163     GBPJPY    0.28868
# 8      EURCAD    0.20180     NZDCAD    0.21822     CADJPY    0.28868
# 9      GBPJPY    0.18552     GBPCHF    0.21822     EURUSD    0.28868
# 10     EURNZD    0.16477     EURCAD    0.21822     EURCHF    0.20000
# 11     AUDUSD    0.14382     GBPJPY    0.21822     AUDCHF    0.18898
# 12     AUDCHF    0.14382     USDCHF    0.15352     GBPCHF    0.18898
# 13     AUDNZD    0.10985     AUDCHF    0.15352     AUDUSD    0.18898
# 14     USDJPY    0.10702     AUDUSD    0.15352     NZDCAD    0.18898
# 15     GBPCAD    0.09513     EURGBP    0.15352     CHFJPY    0.18898
# 16     EURAUD    0.08597     CHFJPY    0.13363     USDJPY    0.10660
# 17     GBPAUD    0.06727     NZDJPY    0.13363     CADCHF    0.10000
# 18     NZDCHF    0.04977     AUDCAD    0.13363     NZDCHF    0.10000
# 19     EURJPY    0.04977     USDJPY    0.12599     EURGBP    0.09449
# 20     CADJPY    0.04977     NZDCHF    0.08909     EURAUD    0.09449
# 21     CADCHF    0.03257     EURAUD    0.06580     EURCAD    0.09449
# 22     CHFJPY    0.03257     CADJPY    0.06580     AUDJPY    0.00000
# 23     NZDJPY    0.03257     GBPCAD    0.02288     GBPAUD    0.00000
# 24     EURCHF    0.02746     CADCHF    0.02288     AUDCAD    0.00000
# 25     AUDJPY    0.00899     GBPAUD    0.00000     GBPCAD    0.00000
# 26     EURGBP    0.00899     AUDJPY    0.00000     USDCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCAD    0.60000
# 1      NZDUSD    0.60000
# 2      EURJPY    0.60000
# 3      GBPUSD    0.60000
# 4      AUDNZD    0.40825
# 5      EURUSD    0.40825
# 6      CADJPY    0.40825
# 7      AUDUSD    0.40825
# 8      GBPCHF    0.40825
# 9      CHFJPY    0.40825
# 10     EURNZD    0.40825
# 11     AUDCHF    0.40825
# 12     NZDJPY    0.40825
# 13     GBPJPY    0.40825
# 14     GBPAUD    0.21822
# 15     CADCHF    0.21822
# 16     AUDJPY    0.21822
# 17     EURCHF    0.21822
# 18     EURAUD    0.21822
# 19     NZDCAD    0.20000
# 20     USDCHF    0.20000
# 21     EURGBP    0.20000
# 22     EURCAD    0.00000
# 23     GBPCAD    0.00000
# 24     NZDCHF    0.00000
# 25     AUDCAD    0.00000
# 26     USDJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
