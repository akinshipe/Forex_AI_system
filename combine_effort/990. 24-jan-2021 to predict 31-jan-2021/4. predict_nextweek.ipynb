# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:35:06.198817
# 2021-12-06 23:35:06.234565
# 2021-12-06 23:36:06.250825
# 2021-12-06 23:37:06.255147
# 2021-12-06 23:38:06.273288
# 2021-12-06 23:39:06.282396
# 2021-12-06 23:40:06.292790
# 2021-12-06 23:41:06.297714
# 2021-12-06 23:42:06.308338
# 2021-12-06 23:43:06.316429
# 2021-12-06 23:44:06.330654
# 2021-12-06 23:45:06.330953
# 2021-12-06 23:46:06.332902
# 2021-12-06 23:47:06.348217
# 2021-12-06 23:48:06.363021
# 2021-12-06 23:49:06.378499
# 2021-12-06 23:50:06.381910
# 2021-12-06 23:51:06.390212
# 2021-12-06 23:52:06.407225
# 2021-12-06 23:53:06.429195
# 2021-12-06 23:54:06.440102
# 2021-12-06 23:55:06.457982
# 2021-12-06 23:56:06.466596
# 2021-12-06 23:57:06.484809
# 2021-12-06 23:58:06.495922
# 2021-12-06 23:59:06.502046
# 2021-12-07 00:00:06.512116
# 2021-12-07 00:01:06.533672
# 2021-12-07 00:02:06.538923
# 2021-12-07 00:03:06.558018
# 2021-12-07 00:04:06.570164
# 2021-12-07 00:05:06.576408
# 2021-12-07 00:06:06.579666
# 2021-12-07 00:07:06.585459
# 2021-12-07 00:08:06.590213
# 2021-12-07 00:09:06.611784
# 2021-12-07 00:10:06.617671
# 2021-12-07 00:11:06.625954
# 2021-12-07 00:12:06.643591
# 2021-12-07 00:13:06.653341
# 2021-12-07 00:14:06.664730
# 2021-12-07 00:15:06.679535
# 2021-12-07 00:16:06.695483
# 2021-12-07 00:17:06.708257
# 2021-12-07 00:18:06.717469
# 2021-12-07 00:19:06.725509
# 2021-12-07 00:20:06.732218
# 2021-12-07 00:21:06.745811
# 2021-12-07 04:19:09.496516
# 2021-12-07 04:20:09.505495
# 2021-12-07 04:21:09.519598
# 2021-12-07 04:22:09.526083
# 2021-12-07 04:23:09.533128
# 2021-12-07 04:24:09.549705

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 20 [-0.54155917]
# GBPUSD 20 [0.99996]
# EURUSD 15 [0.142365]
# USDJPY 15 [-0.99789306]
# USDCAD 20 [-0.55923663]
# NZDUSD 10 [1.]
# GBPCHF 10 [0.9997]
# EURCHF 10 [-0.59342754]
# CADCHF 20 [0.72512005]
# NZDCHF 20 [0.83392951]
# EURGBP 10 [-0.33576325]
# GBPJPY 10 [0.3247]
# GBPCAD 10 [0.9998]
# GBPAUD 15 [-0.33262062]
# EURCAD 20 [-0.68532003]
# EURNZD 15 [-0.71107734]
# CADJPY 10 [0.74845067]
# NZDJPY 20 [1.]
# AUDCAD 20 [0.54574337]
# AUDNZD 10 [-0.80781]
# ['S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
