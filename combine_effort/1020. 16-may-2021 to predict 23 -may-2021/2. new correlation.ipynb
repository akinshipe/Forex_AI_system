# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:52:08.832463

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.25992     EURJPY    0.43179     CADJPY    0.47140
# 1      GBPJPY    0.25992     CADJPY    0.33072     NZDCHF    0.25678
# 2      CHFJPY    0.24878     GBPJPY    0.29881     GBPCHF    0.23570
# 3      CADJPY    0.24878     AUDNZD    0.25882     GBPJPY    0.22866
# 4      AUDNZD    0.23153     CHFJPY    0.25882     EURJPY    0.22866
# 5      EURUSD    0.18286     EURNZD    0.21822     AUDCAD    0.20412
# 6      AUDJPY    0.16530     EURGBP    0.21822     USDCAD    0.17118
# 7      NZDJPY    0.14941     EURUSD    0.20536     GBPUSD    0.17118
# 8      EURNZD    0.14368     AUDJPY    0.18898     USDCHF    0.16667
# 9      EURGBP    0.14368     EURAUD    0.15714     NZDCAD    0.16667
# 10     GBPUSD    0.13170     AUDUSD    0.12016     AUDJPY    0.16667
# 11     NZDUSD    0.13170     GBPCHF    0.11664     EURAUD    0.16667
# 12     AUDUSD    0.13170     GBPCAD    0.09449     CHFJPY    0.16667
# 13     GBPAUD    0.10895     USDJPY    0.07143     AUDCHF    0.16667
# 14     GBPCAD    0.08515     GBPAUD    0.07143     AUDNZD    0.13363
# 15     AUDCHF    0.08515     USDCHF    0.07143     CADCHF    0.13363
# 16     CADCHF    0.08181     AUDCAD    0.05455     NZDJPY    0.10206
# 17     NZDCHF    0.08181     EURCHF    0.04725     GBPCAD    0.08909
# 18     GBPCHF    0.08181     NZDCHF    0.04029     EURGBP    0.08909
# 19     NZDCAD    0.08181     NZDUSD    0.04029     GBPAUD    0.08206
# 20     EURCHF    0.04728     NZDJPY    0.03341     EURNZD    0.08206
# 21     USDJPY    0.04052     GBPUSD    0.02916     AUDUSD    0.08206
# 22     AUDCAD    0.03309     CADCHF    0.02916     EURCAD    0.04280
# 23     EURCAD    0.02764     NZDCAD    0.02916     EURCHF    0.04280
# 24     USDCHF    0.01959     AUDCHF    0.01849     NZDUSD    0.04280
# 25     EURAUD    0.01478     USDCAD    0.01849     USDJPY    0.04167
# 26     USDCAD    0.00167     EURCAD    0.00899     EURUSD    0.04167
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.34247     AUDNZD    0.53452  ...     GBPUSD    0.27217
# 1      GBPCHF    0.34247     EURCAD    0.53452  ...     EURUSD    0.23028
# 2      CADJPY    0.34247     AUDCHF    0.40825  ...     EURAUD    0.19852
# 3      EURAUD    0.32733     EURAUD    0.40825  ...     AUDCAD    0.16667
# 4      AUDCHF    0.32733     EURJPY    0.40825  ...     EURNZD    0.14804
# 5      USDCHF    0.32733     USDCHF    0.40825  ...     GBPJPY    0.14548
# 6      USDCAD    0.26189     USDCAD    0.35635  ...     NZDCAD    0.13457
# 7      NZDUSD    0.21822     NZDJPY    0.35635  ...     GBPCHF    0.13457
# 8      GBPUSD    0.21822     CADCHF    0.25000  ...     AUDCHF    0.13457
# 9      GBPJPY    0.20045     CADJPY    0.25000  ...     NZDCHF    0.13457
# 10     CADCHF    0.18898     GBPCHF    0.25000  ...     GBPCAD    0.13457
# 11     EURCAD    0.18898     NZDUSD    0.16667  ...     AUDNZD    0.13234
# 12     NZDJPY    0.13363     EURCHF    0.16667  ...     CADJPY    0.11775
# 13     EURCHF    0.09449     CHFJPY    0.16667  ...     AUDUSD    0.10206
# 14     GBPCAD    0.09449     AUDCAD    0.16667  ...     NZDUSD    0.10206
# 15     CHFJPY    0.07143     GBPUSD    0.16667  ...     USDJPY    0.08165
# 16     NZDCAD    0.07143     GBPCAD    0.16667  ...     USDCHF    0.06580
# 17     AUDUSD    0.07143     EURGBP    0.08909  ...     EURGBP    0.06580
# 18     AUDCAD    0.07143     GBPJPY    0.08909  ...     CADCHF    0.05046
# 19     EURNZD    0.07143     USDJPY    0.00000  ...     CHFJPY    0.05046
# 20     AUDJPY    0.05455     EURUSD    0.00000  ...     AUDJPY    0.05046
# 21     GBPAUD    0.05455     EURNZD    0.00000  ...     EURJPY    0.03637
# 22     EURUSD    0.05455     AUDJPY    0.00000  ...     NZDJPY    0.03501
# 23     USDJPY    0.05455     NZDCHF    0.00000  ...     USDCAD    0.03364
# 24     NZDCHF    0.05455     AUDUSD    0.00000  ...     EURCHF    0.01701
# 25     EURGBP    0.04029     NZDCAD    0.00000  ...     EURCAD    0.01638
# 26     EURJPY    0.02621     GBPAUD    0.00000  ...     GBPAUD    0.01638
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.35000     GBPCAD    0.42857     AUDCHF    0.49237
# 1      GBPJPY    0.31623     GBPCHF    0.37796     GBPCAD    0.42640
# 2      GBPCHF    0.30861     AUDCHF    0.31180     EURGBP    0.36364
# 3      GBPUSD    0.30861     GBPJPY    0.27501     GBPCHF    0.36364
# 4      AUDCAD    0.28868     GBPUSD    0.25163     AUDNZD    0.36364
# 5      AUDCHF    0.24456     AUDCAD    0.21822     AUDCAD    0.34247
# 6      EURCHF    0.20000     NZDJPY    0.21822     GBPJPY    0.30151
# 7      USDCHF    0.18898     USDCAD    0.20588     AUDUSD    0.26189
# 8      EURUSD    0.18898     EURGBP    0.19048     NZDCAD    0.26189
# 9      USDJPY    0.18898     AUDNZD    0.19048     EURNZD    0.26189
# 10     NZDCAD    0.15430     AUDUSD    0.15352     EURJPY    0.23652
# 11     EURGBP    0.14434     USDCHF    0.13363     AUDJPY    0.18464
# 12     NZDCHF    0.10660     EURUSD    0.13363     EURAUD    0.18464
# 13     NZDUSD    0.10660     USDJPY    0.13363     NZDUSD    0.18464
# 14     CADJPY    0.10000     CHFJPY    0.13363     GBPAUD    0.18464
# 15     EURAUD    0.09782     CADJPY    0.12599     GBPUSD    0.18464
# 16     AUDUSD    0.09782     NZDCAD    0.08909     NZDCHF    0.18464
# 17     EURCAD    0.09513     AUDJPY    0.08909     EURUSD    0.12309
# 18     GBPAUD    0.09449     EURAUD    0.08909     USDJPY    0.12309
# 19     EURJPY    0.05573     GBPAUD    0.06580     USDCHF    0.12309
# 20     AUDJPY    0.05000     EURNZD    0.06580     EURCAD    0.10660
# 21     CHFJPY    0.04891     CADCHF    0.04762     CADCHF    0.10660
# 22     USDCAD    0.04891     EURJPY    0.03056     EURCHF    0.10660
# 23     AUDNZD    0.04891     NZDUSD    0.02288     NZDJPY    0.07538
# 24     CADCHF    0.00000     EURCHF    0.02288     CHFJPY    0.04029
# 25     EURNZD    0.00000     NZDCHF    0.02288     CADJPY    0.02273
# 26     NZDJPY    0.00000     EURCAD    0.02288     USDCAD    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDCHF    0.65465
# 1      GBPCHF    0.53452
# 2      GBPCAD    0.53452
# 3      EURGBP    0.42857
# 4      GBPJPY    0.42857
# 5      AUDNZD    0.42857
# 6      CHFJPY    0.35635
# 7      AUDCAD    0.35635
# 8      GBPAUD    0.21822
# 9      AUDUSD    0.21822
# 10     NZDCAD    0.21822
# 11     AUDJPY    0.21822
# 12     EURNZD    0.21822
# 13     EURAUD    0.21822
# 14     EURJPY    0.21822
# 15     USDCHF    0.21822
# 16     EURUSD    0.21822
# 17     USDJPY    0.21822
# 18     NZDCHF    0.21822
# 19     GBPUSD    0.08909
# 20     CADJPY    0.08909
# 21     CADCHF    0.08909
# 22     EURCHF    0.08909
# 23     NZDUSD    0.08909
# 24     EURCAD    0.04762
# 25     USDCAD    0.04762
# 26     NZDJPY    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
