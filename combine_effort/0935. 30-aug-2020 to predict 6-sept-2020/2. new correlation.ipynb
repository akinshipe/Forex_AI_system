# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:22:08.845354

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.26318     GBPUSD    0.29579     AUDUSD    0.32733
# 1      NZDCAD    0.26212     NZDCAD    0.24661     GBPUSD    0.31180
# 2      GBPUSD    0.23028     EURAUD    0.24661     NZDCAD    0.25163
# 3      NZDUSD    0.18021     NZDJPY    0.24661     USDJPY    0.21822
# 4      USDCHF    0.16667     AUDCAD    0.24456     GBPCHF    0.21822
# 5      AUDCAD    0.14804     AUDUSD    0.24456     GBPJPY    0.15352
# 6      CHFJPY    0.13457     EURJPY    0.24456     NZDUSD    0.15352
# 7      EURJPY    0.11580     NZDUSD    0.20751     NZDJPY    0.15352
# 8      NZDJPY    0.11580     CHFJPY    0.19767     CADJPY    0.15352
# 9      AUDCHF    0.09869     USDJPY    0.17216     EURGBP    0.13363
# 10     CADCHF    0.08165     EURNZD    0.17216     EURCAD    0.13363
# 11     NZDCHF    0.08165     CADJPY    0.15714     AUDCAD    0.12599
# 12     EURCAD    0.08165     AUDJPY    0.14833     EURNZD    0.08909
# 13     GBPCHF    0.06580     NZDCHF    0.12016     EURAUD    0.08909
# 14     AUDUSD    0.06580     GBPAUD    0.12016     AUDNZD    0.08909
# 15     EURUSD    0.06580     GBPCHF    0.12016     USDCAD    0.08909
# 16     GBPCAD    0.06553     EURCHF    0.10702     GBPAUD    0.06580
# 17     CADJPY    0.06553     USDCAD    0.10702     EURJPY    0.04762
# 18     GBPAUD    0.04963     EURGBP    0.08472     AUDCHF    0.04762
# 19     USDCAD    0.04963     GBPJPY    0.06917     USDCHF    0.04762
# 20     EURCHF    0.04903     GBPCAD    0.06917     CHFJPY    0.02288
# 21     GBPJPY    0.04903     CADCHF    0.06917     AUDJPY    0.02288
# 22     AUDJPY    0.03364     EURCAD    0.06917     EURCHF    0.02288
# 23     AUDNZD    0.03309     AUDNZD    0.05648     EURUSD    0.02288
# 24     EURNZD    0.03269     AUDCHF    0.05648     GBPCAD    0.00000
# 25     EURAUD    0.03269     EURUSD    0.05648     NZDCHF    0.00000
# 26     EURGBP    0.00000     USDCHF    0.00478     CADCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.35355     AUDCAD    0.37500  ...     GBPCAD    0.39451
# 1      GBPUSD    0.35355     USDCAD    0.32733  ...     AUDUSD    0.26948
# 2      GBPJPY    0.35355     CADJPY    0.32733  ...     GBPCHF    0.26948
# 3      USDCAD    0.30151     GBPUSD    0.32733  ...     AUDCAD    0.26948
# 4      AUDJPY    0.30151     GBPJPY    0.32733  ...     EURCAD    0.24175
# 5      EURCHF    0.30151     AUDJPY    0.25000  ...     CADCHF    0.24175
# 6      CHFJPY    0.30151     EURCHF    0.25000  ...     USDJPY    0.21753
# 7      EURUSD    0.25000     CHFJPY    0.25000  ...     EURCHF    0.20646
# 8      AUDUSD    0.25000     AUDCHF    0.21822  ...     AUDCHF    0.18831
# 9      EURJPY    0.25000     USDCHF    0.16667  ...     EURUSD    0.18831
# 10     GBPCAD    0.20045     EURUSD    0.16667  ...     GBPUSD    0.18831
# 11     USDCHF    0.19612     AUDUSD    0.16667  ...     EURGBP    0.16116
# 12     NZDJPY    0.13363     EURJPY    0.16667  ...     NZDCAD    0.15198
# 13     EURNZD    0.13363     GBPAUD    0.10206  ...     GBPAUD    0.14368
# 14     GBPAUD    0.13363     EURCAD    0.10206  ...     GBPJPY    0.11613
# 15     AUDNZD    0.13363     AUDNZD    0.10206  ...     CHFJPY    0.11289
# 16     NZDCHF    0.13363     GBPCAD    0.10206  ...     USDCAD    0.10123
# 17     CADCHF    0.13363     CADCHF    0.10206  ...     USDCHF    0.09869
# 18     GBPCHF    0.13363     NZDUSD    0.10206  ...     NZDUSD    0.07114
# 19     USDJPY    0.13363     NZDCHF    0.00000  ...     EURJPY    0.06204
# 20     AUDCHF    0.07538     EURAUD    0.00000  ...     AUDNZD    0.06204
# 21     AUDCAD    0.07538     EURNZD    0.00000  ...     EURAUD    0.03548
# 22     EURCAD    0.06804     GBPCHF    0.00000  ...     EURNZD    0.03548
# 23     EURAUD    0.06804     NZDJPY    0.00000  ...     AUDJPY    0.02988
# 24     NZDUSD    0.06804     USDJPY    0.00000  ...     NZDJPY    0.01959
# 25     NZDCAD    0.06804     NZDCAD    0.00000  ...     CADJPY    0.00970
# 26     EURGBP    0.06804     EURGBP    0.00000  ...     NZDCHF    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.35747     NZDCHF    0.50252     NZDCHF    0.60714
# 1      CHFJPY    0.30208     USDJPY    0.50252     EURAUD    0.49099
# 2      AUDCAD    0.23783     EURAUD    0.32824     EURNZD    0.46429
# 3      GBPCAD    0.20180     CADCHF    0.30151     USDCHF    0.41931
# 4      EURJPY    0.19026     EURNZD    0.28721     GBPJPY    0.37796
# 5      EURCHF    0.18552     USDCHF    0.28511     GBPUSD    0.37796
# 6      USDCHF    0.17216     CHFJPY    0.24232     NZDJPY    0.33929
# 7      EURGBP    0.16477     AUDJPY    0.24232     USDJPY    0.33929
# 8      GBPCHF    0.14382     NZDJPY    0.21212     GBPCHF    0.33929
# 9      NZDCHF    0.12585     GBPJPY    0.21212     CADCHF    0.33929
# 10     GBPAUD    0.12585     GBPAUD    0.21212     EURCAD    0.32733
# 11     AUDNZD    0.10985     AUDCAD    0.17408     EURGBP    0.32733
# 12     AUDCHF    0.10985     AUDCHF    0.15352     AUDCHF    0.26189
# 13     AUDJPY    0.10702     EURJPY    0.15352     CHFJPY    0.26189
# 14     AUDUSD    0.09513     USDCAD    0.12309     USDCAD    0.26189
# 15     EURAUD    0.08597     GBPUSD    0.12309     AUDJPY    0.26189
# 16     NZDJPY    0.08597     GBPCHF    0.10050     NZDUSD    0.21822
# 17     USDCAD    0.08597     GBPCAD    0.10050     NZDCAD    0.21822
# 18     GBPJPY    0.06727     EURGBP    0.08206     AUDNZD    0.19643
# 19     CADCHF    0.06727     EURCAD    0.08206     EURJPY    0.13363
# 20     NZDUSD    0.06727     AUDNZD    0.08206     AUDUSD    0.13363
# 21     EURCAD    0.06727     AUDUSD    0.05025     EURUSD    0.13363
# 22     EURNZD    0.04977     EURCHF    0.03161     CADJPY    0.09449
# 23     NZDCAD    0.04977     EURUSD    0.03161     GBPCAD    0.07143
# 24     EURUSD    0.02746     NZDCAD    0.03161     GBPAUD    0.07143
# 25     GBPUSD    0.00899     CADJPY    0.01010     EURCHF    0.04029
# 26     CADJPY    0.00899     NZDUSD    0.01010     AUDCAD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURNZD    0.60000
# 1      EURAUD    0.60000
# 2      NZDCHF    0.60000
# 3      AUDCAD    0.50000
# 4      EURCHF    0.50000
# 5      AUDNZD    0.40825
# 6      CADCHF    0.40825
# 7      EURCAD    0.40825
# 8      EURJPY    0.33333
# 9      USDCHF    0.33333
# 10     AUDUSD    0.33333
# 11     EURUSD    0.33333
# 12     GBPUSD    0.21822
# 13     GBPJPY    0.21822
# 14     CADJPY    0.21822
# 15     AUDCHF    0.21822
# 16     USDCAD    0.21822
# 17     USDJPY    0.20000
# 18     NZDCAD    0.20000
# 19     NZDJPY    0.20000
# 20     EURGBP    0.20000
# 21     GBPCHF    0.20000
# 22     NZDUSD    0.00000
# 23     AUDJPY    0.00000
# 24     GBPAUD    0.00000
# 25     GBPCAD    0.00000
# 26     CHFJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
