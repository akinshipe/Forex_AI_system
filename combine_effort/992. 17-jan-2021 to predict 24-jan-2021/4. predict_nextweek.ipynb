# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:34:51.258343
# 2021-12-06 23:34:51.262623
# 2021-12-06 23:35:51.275457
# 2021-12-06 23:36:51.292487
# 2021-12-06 23:37:51.312229
# 2021-12-06 23:38:51.325727
# 2021-12-06 23:39:51.340458
# 2021-12-06 23:40:51.352032
# 2021-12-06 23:41:51.363845
# 2021-12-06 23:42:51.369913
# 2021-12-06 23:43:51.373591
# 2021-12-06 23:44:51.374947
# 2021-12-06 23:45:51.381809
# 2021-12-06 23:46:51.387082
# 2021-12-06 23:47:51.391523
# 2021-12-06 23:48:51.398110
# 2021-12-06 23:49:51.420284
# 2021-12-06 23:50:51.446094
# 2021-12-06 23:51:51.452426
# 2021-12-06 23:52:51.454996
# 2021-12-06 23:53:51.461808
# 2021-12-06 23:54:51.465941
# 2021-12-06 23:55:51.483099
# 2021-12-06 23:56:51.504269
# 2021-12-06 23:57:51.517366
# 2021-12-06 23:58:51.526147
# 2021-12-06 23:59:51.533233
# 2021-12-07 00:00:51.552169
# 2021-12-07 00:01:51.570614
# 2021-12-07 00:02:51.575469
# 2021-12-07 00:03:51.598131
# 2021-12-07 00:04:51.603419
# 2021-12-07 00:05:51.617176
# 2021-12-07 00:06:51.626079
# 2021-12-07 00:07:51.641976
# 2021-12-07 00:08:51.648976
# 2021-12-07 00:09:51.669552
# 2021-12-07 00:10:51.688978
# 2021-12-07 00:11:51.704346
# 2021-12-07 00:12:51.713203
# 2021-12-07 00:13:51.734968
# 2021-12-07 00:14:51.737105
# 2021-12-07 00:15:51.759349
# 2021-12-07 00:16:51.767117
# 2021-12-07 00:17:51.777820
# 2021-12-07 00:18:51.787008
# 2021-12-07 00:19:51.792998
# 2021-12-07 00:20:51.796294
# 2021-12-07 00:21:51.816183
# 2021-12-07 04:22:54.764915
# 2021-12-07 04:23:54.774673
# 2021-12-07 04:24:54.781879
# 2021-12-07 04:25:54.790515
# 2021-12-07 04:26:54.805362

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 10 [0.32835647]
# GBPUSD 10 [-0.37791]
# EURUSD 10 [-0.33377468]
# USDJPY 20 [-0.469]
# AUDUSD 10 [1.]
# NZDUSD 10 [1.]
# GBPCHF 10 [0.3312]
# EURCHF 10 [0.99245]
# CADCHF 15 [0.77646512]
# AUDCHF 15 [0.59809731]
# NZDCHF 15 [1.]
# EURGBP 10 [-0.3328444]
# GBPJPY 10 [0.0399]
# GBPCAD 30 [0.60093417]
# GBPAUD 15 [0.77847732]
# EURJPY 10 [-0.33177615]
# EURCAD 50 [-0.43126422]
# EURAUD 15 [-0.63692005]
# EURNZD 15 [-0.63993245]
# NZDJPY 50 [0.59854084]
# AUDCAD 15 [1.]
# NZDCAD 15 [1.]
# AUDNZD 10 [1.]
# ['B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
