# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:36:57.558421

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.36775     GBPCHF    0.30556     EURUSD    0.50252
# 1      EURJPY    0.30215     EURUSD    0.30208     NZDCAD    0.50252
# 2      CADJPY    0.26318     NZDCAD    0.27217     NZDUSD    0.50252
# 3      NZDUSD    0.25853     AUDCAD    0.27217     GBPUSD    0.39394
# 4      GBPJPY    0.25567     AUDCHF    0.27217     AUDCAD    0.39394
# 5      GBPUSD    0.21914     CADJPY    0.22591     EURNZD    0.32824
# 6      CHFJPY    0.21914     GBPJPY    0.22591     AUDCHF    0.32824
# 7      USDCHF    0.21753     GBPUSD    0.19094     USDCHF    0.30151
# 8      AUDCAD    0.18831     NZDUSD    0.19094     GBPCHF    0.30151
# 9      NZDCAD    0.18094     EURGBP    0.16667     CADJPY    0.19192
# 10     AUDNZD    0.16116     EURNZD    0.16477     EURCAD    0.19192
# 11     AUDUSD    0.15198     EURAUD    0.16477     GBPJPY    0.19192
# 12     GBPCHF    0.13613     AUDNZD    0.13608     EURGBP    0.19192
# 13     EURCAD    0.12581     USDCHF    0.11111     NZDCHF    0.19192
# 14     NZDJPY    0.12309     NZDCHF    0.10985     CHFJPY    0.17911
# 15     EURCHF    0.10714     CADCHF    0.08472     GBPAUD    0.12309
# 16     AUDJPY    0.10714     EURJPY    0.08472     AUDUSD    0.12309
# 17     GBPAUD    0.10123     GBPAUD    0.08183     USDJPY    0.12309
# 18     NZDCHF    0.09066     EURCAD    0.08183     CADCHF    0.08206
# 19     AUDCHF    0.07114     USDJPY    0.05648     GBPCAD    0.06580
# 20     USDCAD    0.07114     EURCHF    0.05455     EURAUD    0.03161
# 21     USDJPY    0.05519     CHFJPY    0.02778     NZDJPY    0.03161
# 22     EURGBP    0.05519     AUDUSD    0.02746     AUDNZD    0.03161
# 23     EURAUD    0.04516     USDCAD    0.02746     EURJPY    0.01010
# 24     EURNZD    0.04516     GBPCAD    0.00000     EURCHF    0.01010
# 25     CADCHF    0.04423     AUDJPY    0.00000     AUDJPY    0.01010
# 26     GBPCAD    0.04083     NZDJPY    0.00000     USDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPUSD    0.66144     NZDCAD    0.80178  ...     AUDNZD    0.20000
# 1      EURUSD    0.66144     AUDCAD    0.80178  ...     CADJPY    0.16330
# 2      NZDCAD    0.66144     NZDUSD    0.80178  ...     AUDCAD    0.16116
# 3      NZDUSD    0.66144     EURUSD    0.65465  ...     AUDJPY    0.16116
# 4      USDCHF    0.57735     GBPUSD    0.65465  ...     USDCHF    0.16116
# 5      EURNZD    0.50000     USDCHF    0.53452  ...     EURUSD    0.16013
# 6      AUDCAD    0.47246     AUDCHF    0.53452  ...     EURCAD    0.16013
# 7      GBPJPY    0.37796     EURNZD    0.53452  ...     NZDJPY    0.13093
# 8      EURGBP    0.37796     GBPAUD    0.53452  ...     GBPCAD    0.12666
# 9      GBPCHF    0.37796     EURGBP    0.53452  ...     EURJPY    0.12361
# 10     EURCAD    0.28868     EURCHF    0.53452  ...     GBPUSD    0.12361
# 11     AUDCHF    0.28868     AUDUSD    0.53452  ...     GBPAUD    0.12157
# 12     EURCHF    0.28868     GBPCHF    0.53452  ...     NZDCHF    0.08333
# 13     EURJPY    0.28868     CHFJPY    0.42857  ...     USDJPY    0.08058
# 14     USDCAD    0.28868     USDJPY    0.42857  ...     EURGBP    0.08058
# 15     USDJPY    0.20000     EURAUD    0.42857  ...     EURAUD    0.08006
# 16     GBPAUD    0.20000     EURCAD    0.21822  ...     EURNZD    0.08006
# 17     AUDUSD    0.20000     USDCAD    0.21822  ...     CADCHF    0.04222
# 18     CADJPY    0.18898     AUDNZD    0.21822  ...     CHFJPY    0.04120
# 19     NZDCHF    0.18898     GBPJPY    0.21822  ...     GBPCHF    0.04120
# 20     NZDJPY    0.18898     EURJPY    0.08909  ...     AUDCHF    0.04013
# 21     AUDNZD    0.10660     GBPCAD    0.08909  ...     USDCAD    0.04013
# 22     EURAUD    0.10660     CADJPY    0.08909  ...     AUDUSD    0.04013
# 23     GBPCAD    0.10000     AUDJPY    0.08909  ...     GBPJPY    0.00000
# 24     CHFJPY    0.10000     CADCHF    0.08909  ...     NZDUSD    0.00000
# 25     AUDJPY    0.00000     NZDJPY    0.04762  ...     EURCHF    0.00000
# 26     CADCHF    0.00000     NZDCHF    0.04762  ...     NZDCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDCAD    0.26726     AUDCAD    0.28511     USDCHF    0.40825
# 1      NZDJPY    0.23623     EURCAD    0.28511     USDCAD    0.40825
# 2      USDCHF    0.21822     NZDJPY    0.25163     AUDCHF    0.27217
# 3      EURCAD    0.20536     USDCHF    0.21822     AUDJPY    0.27217
# 4      GBPCAD    0.18898     EURUSD    0.21822     EURCAD    0.27217
# 5      CADJPY    0.15714     NZDCAD    0.21822     AUDCAD    0.20045
# 6      EURJPY    0.15714     NZDUSD    0.21822     EURGBP    0.20045
# 7      EURUSD    0.14382     GBPCHF    0.21822     GBPCHF    0.13363
# 8      NZDCAD    0.13363     EURJPY    0.15352     NZDCAD    0.13363
# 9      AUDJPY    0.13363     CADJPY    0.15352     EURUSD    0.13363
# 10     AUDNZD    0.13363     EURGBP    0.15352     NZDUSD    0.13363
# 11     EURAUD    0.12585     AUDCHF    0.08909     NZDCHF    0.13363
# 12     EURGBP    0.08183     GBPAUD    0.08909     GBPUSD    0.13363
# 13     EURCHF    0.07143     CADCHF    0.08909     GBPJPY    0.13363
# 14     GBPUSD    0.06250     EURNZD    0.08909     NZDJPY    0.13363
# 15     GBPAUD    0.06250     AUDUSD    0.08909     CADJPY    0.13363
# 16     NZDUSD    0.06250     USDJPY    0.08909     EURAUD    0.07538
# 17     CHFJPY    0.05455     NZDCHF    0.06580     AUDNZD    0.07538
# 18     GBPCHF    0.05455     GBPUSD    0.06580     EURCHF    0.06804
# 19     GBPJPY    0.01849     GBPJPY    0.06580     CADCHF    0.06804
# 20     CADCHF    0.01849     EURCHF    0.06580     EURJPY    0.06804
# 21     USDJPY    0.01849     AUDJPY    0.06580     AUDUSD    0.00000
# 22     NZDCHF    0.00899     USDCAD    0.06580     EURNZD    0.00000
# 23     EURNZD    0.00899     GBPCAD    0.04762     GBPAUD    0.00000
# 24     AUDUSD    0.00899     CHFJPY    0.02288     USDJPY    0.00000
# 25     USDCAD    0.00899     EURAUD    0.02288     GBPCAD    0.00000
# 26     AUDCHF    0.00000     AUDNZD    0.02288     CHFJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDCAD    0.40825
# 1      AUDCAD    0.40825
# 2      NZDUSD    0.40825
# 3      EURUSD    0.33333
# 4      USDCAD    0.33333
# 5      EURCAD    0.33333
# 6      GBPUSD    0.33333
# 7      GBPJPY    0.33333
# 8      USDCHF    0.27217
# 9      GBPCAD    0.27217
# 10     AUDJPY    0.27217
# 11     CADJPY    0.27217
# 12     EURNZD    0.27217
# 13     EURJPY    0.27217
# 14     GBPAUD    0.27217
# 15     EURGBP    0.27217
# 16     AUDCHF    0.27217
# 17     CADCHF    0.27217
# 18     EURCHF    0.27217
# 19     GBPCHF    0.27217
# 20     AUDUSD    0.27217
# 21     NZDCHF    0.21822
# 22     EURAUD    0.21822
# 23     CHFJPY    0.21822
# 24     NZDJPY    0.21822
# 25     USDJPY    0.21822
# 26     AUDNZD    0.11111
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
