# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:02:10.826598

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.32360     EURJPY    0.59093     EURJPY    0.80178
# 1      CHFJPY    0.30920     CHFJPY    0.52177     EURAUD    0.53452
# 2      NZDJPY    0.28904     EURUSD    0.47087     CHFJPY    0.47076
# 3      GBPJPY    0.28904     USDCHF    0.41349     GBPJPY    0.40825
# 4      GBPUSD    0.27421     EURNZD    0.38620     EURNZD    0.38516
# 5      NZDUSD    0.27421     EURGBP    0.35747     CADJPY    0.35635
# 6      AUDUSD    0.25395     GBPJPY    0.31278     USDCHF    0.32824
# 7      EURUSD    0.25223     AUDJPY    0.31175     EURGBP    0.32824
# 8      CADJPY    0.21627     AUDUSD    0.31175     EURUSD    0.32824
# 9      NZDCAD    0.20302     CADJPY    0.31175     AUDCHF    0.31180
# 10     AUDJPY    0.19061     EURCAD    0.27866     CADCHF    0.23570
# 11     USDCHF    0.17138     AUDNZD    0.26068     AUDJPY    0.23570
# 12     USDJPY    0.15743     AUDCHF    0.24661     NZDJPY    0.22866
# 13     AUDNZD    0.13497     EURAUD    0.24661     EURCAD    0.20412
# 14     USDCAD    0.13497     NZDUSD    0.23783     AUDNZD    0.16667
# 15     AUDCAD    0.11699     NZDJPY    0.23324     USDCAD    0.16667
# 16     EURNZD    0.11433     GBPAUD    0.22172     NZDCAD    0.15309
# 17     NZDCHF    0.10701     EURCHF    0.17216     EURCHF    0.13363
# 18     EURCHF    0.10701     GBPUSD    0.16147     AUDUSD    0.13363
# 19     GBPCHF    0.10701     GBPCHF    0.13211     GBPAUD    0.12309
# 20     AUDCHF    0.09996     CADCHF    0.13211     USDJPY    0.12309
# 21     EURCAD    0.08353     USDCAD    0.10985     NZDUSD    0.10206
# 22     GBPAUD    0.07711     AUDCAD    0.10985     GBPCAD    0.08909
# 23     EURGBP    0.07711     NZDCAD    0.09513     AUDCAD    0.08909
# 24     GBPCAD    0.02764     NZDCHF    0.07099     NZDCHF    0.05717
# 25     EURAUD    0.02150     USDJPY    0.06727     GBPCHF    0.00000
# 26     CADCHF    0.02150     GBPCAD    0.02746     GBPUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.85280     EURJPY    1.00000  ...     GBPUSD    0.18711
# 1      EURAUD    0.50000     NZDJPY    0.66667  ...     EURUSD    0.14804
# 2      AUDCHF    0.42640     CADJPY    0.66667  ...     CHFJPY    0.13457
# 3      CHFJPY    0.40000     CHFJPY    0.61237  ...     EURAUD    0.13457
# 4      GBPJPY    0.37796     EURCAD    0.40825  ...     AUDNZD    0.13234
# 5      CADJPY    0.35355     NZDCHF    0.37500  ...     CADJPY    0.13234
# 6      CADCHF    0.35355     USDCHF    0.32733  ...     EURGBP    0.11440
# 7      USDCHF    0.28868     AUDCHF    0.32733  ...     NZDCHF    0.10206
# 8      EURUSD    0.28868     EURAUD    0.32733  ...     GBPCHF    0.06804
# 9      EURNZD    0.28868     GBPUSD    0.32733  ...     CADCHF    0.05046
# 10     GBPCHF    0.21320     EURGBP    0.32733  ...     USDCAD    0.04963
# 11     USDJPY    0.20000     USDJPY    0.32733  ...     GBPCAD    0.04963
# 12     AUDCAD    0.20000     EURUSD    0.32733  ...     USDJPY    0.04903
# 13     NZDJPY    0.13868     AUDNZD    0.32733  ...     EURCAD    0.04903
# 14     NZDCAD    0.10660     CADCHF    0.25000  ...     NZDCAD    0.03501
# 15     AUDNZD    0.10660     GBPCAD    0.25000  ...     AUDCAD    0.03501
# 16     GBPUSD    0.10660     EURCHF    0.21822  ...     NZDJPY    0.03501
# 17     AUDUSD    0.10660     NZDUSD    0.21822  ...     GBPJPY    0.03501
# 18     GBPCAD    0.10000     AUDJPY    0.21822  ...     GBPAUD    0.03269
# 19     EURCHF    0.10000     NZDCAD    0.21822  ...     EURJPY    0.01724
# 20     GBPAUD    0.09449     GBPCHF    0.16667  ...     AUDCHF    0.01724
# 21     EURCAD    0.09449     GBPAUD    0.10206  ...     EURCHF    0.01701
# 22     EURGBP    0.09449     AUDUSD    0.10206  ...     AUDJPY    0.01701
# 23     NZDCHF    0.00000     USDCAD    0.10206  ...     NZDUSD    0.01701
# 24     AUDJPY    0.00000     EURNZD    0.10206  ...     USDCHF    0.01645
# 25     NZDUSD    0.00000     AUDCAD    0.10206  ...     EURNZD    0.01638
# 26     USDCAD    0.00000     GBPJPY    0.00000  ...     AUDUSD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.32077     GBPUSD    0.42366     GBPCAD    0.35355
# 1      EURUSD    0.26726     AUDNZD    0.25678     GBPUSD    0.30151
# 2      USDJPY    0.26726     AUDCAD    0.25163     GBPCHF    0.30151
# 3      CADJPY    0.25882     GBPCAD    0.25163     NZDJPY    0.29417
# 4      USDCHF    0.19643     EURCHF    0.25163     EURNZD    0.27217
# 5      AUDNZD    0.19643     GBPJPY    0.24460     USDCAD    0.27217
# 6      NZDCHF    0.19138     GBPAUD    0.24232     GBPAUD    0.20045
# 7      NZDJPY    0.19138     CADJPY    0.20588     NZDCHF    0.16667
# 8      GBPAUD    0.14382     GBPCHF    0.18157     CADCHF    0.16667
# 9      EURGBP    0.12585     USDCHF    0.17911     CADJPY    0.16667
# 10     EURNZD    0.12016     EURUSD    0.17911     NZDUSD    0.16667
# 11     AUDJPY    0.12016     USDJPY    0.17911     AUDJPY    0.16667
# 12     EURJPY    0.12016     EURNZD    0.12088     EURCAD    0.13363
# 13     AUDCHF    0.12016     EURCAD    0.10483     GBPJPY    0.13363
# 14     CADCHF    0.11664     NZDCAD    0.10483     EURGBP    0.13363
# 15     GBPCHF    0.11664     NZDUSD    0.10483     EURJPY    0.07538
# 16     GBPJPY    0.11585     CHFJPY    0.09890     NZDCAD    0.07538
# 17     CHFJPY    0.08183     AUDJPY    0.06052     AUDNZD    0.07538
# 18     AUDCAD    0.08183     CADCHF    0.06052     AUDCHF    0.07538
# 19     EURCAD    0.06250     USDCAD    0.04280     AUDUSD    0.07538
# 20     USDCAD    0.05455     EURGBP    0.03161     EURUSD    0.06804
# 21     GBPCAD    0.05455     EURAUD    0.02288     USDCHF    0.06804
# 22     NZDCAD    0.04725     AUDCHF    0.02288     EURAUD    0.00000
# 23     NZDUSD    0.04725     EURJPY    0.02288     CHFJPY    0.00000
# 24     EURAUD    0.01849     AUDUSD    0.02288     EURCHF    0.00000
# 25     EURCHF    0.01849     NZDJPY    0.01468     USDJPY    0.00000
# 26     AUDUSD    0.01849     NZDCHF    0.01468     AUDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDJPY    0.50918
# 1      CADJPY    0.50918
# 2      GBPUSD    0.42857
# 3      GBPAUD    0.35635
# 4      USDCAD    0.35635
# 5      EURNZD    0.35635
# 6      GBPCAD    0.32733
# 7      NZDCHF    0.21822
# 8      EURJPY    0.21822
# 9      GBPCHF    0.21822
# 10     CADCHF    0.21822
# 11     CHFJPY    0.08909
# 12     EURCAD    0.08909
# 13     AUDUSD    0.08909
# 14     AUDCAD    0.08909
# 15     AUDJPY    0.04762
# 16     NZDCAD    0.04762
# 17     USDCHF    0.04762
# 18     EURGBP    0.04762
# 19     EURAUD    0.04762
# 20     AUDCHF    0.04762
# 21     EURCHF    0.04762
# 22     NZDUSD    0.04762
# 23     USDJPY    0.04762
# 24     EURUSD    0.04762
# 25     AUDNZD    0.04762
# 26     GBPJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
