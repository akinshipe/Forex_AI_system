# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:25:52.395872

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CADCHF    0.21914     USDCHF    0.30208     USDCHF    0.32824
# 1      AUDCHF    0.21914     EURCHF    0.25000     AUDCAD    0.20412
# 2      GBPJPY    0.19590     EURJPY    0.24716     GBPAUD    0.20412
# 3      GBPAUD    0.17485     GBPJPY    0.21822     CADCHF    0.16667
# 4      USDCHF    0.13457     GBPUSD    0.21822     CHFJPY    0.16667
# 5      EURUSD    0.13457     EURNZD    0.19094     GBPCHF    0.12309
# 6      NZDJPY    0.10417     AUDJPY    0.16477     GBPUSD    0.12309
# 7      AUDJPY    0.09237     GBPCHF    0.13608     EURGBP    0.12309
# 8      GBPCAD    0.09237     NZDJPY    0.13608     EURUSD    0.12309
# 9      GBPUSD    0.09237     USDJPY    0.13608     NZDUSD    0.12309
# 10     EURGBP    0.09237     GBPAUD    0.13608     EURCHF    0.08909
# 11     EURCHF    0.08515     CADCHF    0.10985     AUDCHF    0.08909
# 12     EURJPY    0.08515     NZDUSD    0.08183     EURAUD    0.08909
# 13     CHFJPY    0.08181     AUDUSD    0.08183     USDJPY    0.08206
# 14     AUDUSD    0.07258     NZDCHF    0.08183     NZDCAD    0.08206
# 15     EURNZD    0.07258     CADJPY    0.08183     EURNZD    0.08206
# 16     EURAUD    0.06118     EURCAD    0.08183     EURJPY    0.08206
# 17     NZDCAD    0.06118     AUDCHF    0.05648     GBPCAD    0.04280
# 18     NZDCHF    0.04120     AUDCAD    0.05648     USDCAD    0.04280
# 19     GBPCHF    0.04120     AUDNZD    0.05455     AUDJPY    0.04167
# 20     NZDUSD    0.04120     EURAUD    0.02746     NZDCHF    0.04167
# 21     AUDNZD    0.04120     GBPCAD    0.02746     AUDUSD    0.04167
# 22     USDCAD    0.02988     USDCAD    0.02746     EURCAD    0.00000
# 23     USDJPY    0.02988     EURUSD    0.02746     GBPJPY    0.00000
# 24     EURCAD    0.02150     CHFJPY    0.00000     CADJPY    0.00000
# 25     CADJPY    0.00990     NZDCAD    0.00000     NZDJPY    0.00000
# 26     AUDCAD    0.00167     EURGBP    0.00000     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.38889     USDCHF    0.81650  ...     EURCAD    0.24418
# 1      CADCHF    0.32733     CHFJPY    0.61237  ...     EURNZD    0.19872
# 2      CHFJPY    0.28868     EURUSD    0.40825  ...     NZDUSD    0.16013
# 3      EURAUD    0.28868     EURAUD    0.40825  ...     EURJPY    0.15573
# 4      GBPCAD    0.28868     GBPCHF    0.40825  ...     EURUSD    0.13074
# 5      AUDCHF    0.28868     GBPCAD    0.35635  ...     USDJPY    0.12581
# 6      EURNZD    0.21822     GBPUSD    0.25000  ...     USDCAD    0.12581
# 7      EURCAD    0.21822     AUDCAD    0.25000  ...     GBPJPY    0.12581
# 8      NZDCHF    0.21822     CADJPY    0.25000  ...     EURGBP    0.11859
# 9      AUDNZD    0.21822     EURCHF    0.25000  ...     GBPAUD    0.11859
# 10     NZDUSD    0.21822     AUDCHF    0.25000  ...     CHFJPY    0.08760
# 11     USDCAD    0.12309     EURNZD    0.16667  ...     EURAUD    0.08353
# 12     EURUSD    0.11111     EURJPY    0.16667  ...     NZDCHF    0.08006
# 13     NZDCAD    0.11111     AUDNZD    0.16667  ...     NZDJPY    0.07711
# 14     AUDJPY    0.11111     NZDCHF    0.16667  ...     AUDCAD    0.07462
# 15     EURCHF    0.11111     NZDUSD    0.16667  ...     USDCHF    0.04903
# 16     AUDUSD    0.11111     GBPJPY    0.08909  ...     CADJPY    0.04167
# 17     GBPJPY    0.11111     GBPAUD    0.08909  ...     AUDJPY    0.04167
# 18     GBPAUD    0.05455     USDCAD    0.08909  ...     GBPCAD    0.03846
# 19     EURJPY    0.05455     NZDJPY    0.08909  ...     GBPUSD    0.03846
# 20     GBPCHF    0.05455     CADCHF    0.00000  ...     AUDUSD    0.03846
# 21     USDJPY    0.05455     EURCAD    0.00000  ...     AUDCHF    0.03548
# 22     CADJPY    0.05455     AUDUSD    0.00000  ...     CADCHF    0.03548
# 23     NZDJPY    0.05455     AUDJPY    0.00000  ...     EURCHF    0.00649
# 24     AUDCAD    0.05455     USDJPY    0.00000  ...     NZDCAD    0.00321
# 25     GBPUSD    0.05455     NZDCAD    0.00000  ...     GBPCHF    0.00000
# 26     EURGBP    0.05455     EURGBP    0.00000  ...     AUDNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.33634     USDCAD    0.52414     EURUSD    0.76376
# 1      GBPAUD    0.33333     EURUSD    0.50252     USDJPY    0.60714
# 2      USDJPY    0.33333     EURCAD    0.40000     USDCAD    0.56408
# 3      EURNZD    0.26726     USDCHF    0.30151     USDCHF    0.49099
# 4      EURCAD    0.26726     USDJPY    0.30151     EURCAD    0.46429
# 5      USDCHF    0.20180     NZDCAD    0.30151     CHFJPY    0.37796
# 6      EURUSD    0.20180     EURNZD    0.30151     EURAUD    0.37796
# 7      EURJPY    0.20180     EURCHF    0.21822     GBPUSD    0.33929
# 8      EURGBP    0.20000     EURAUD    0.21822     GBPAUD    0.33929
# 9      CHFJPY    0.14142     AUDUSD    0.20412     GBPCHF    0.33929
# 10     NZDCHF    0.13363     CHFJPY    0.20412     NZDCAD    0.32733
# 11     GBPUSD    0.13363     NZDCHF    0.20412     AUDUSD    0.32733
# 12     AUDNZD    0.13363     GBPAUD    0.20000     EURCHF    0.32733
# 13     AUDCHF    0.06917     NZDJPY    0.20000     AUDJPY    0.21822
# 14     AUDCAD    0.06917     AUDNZD    0.20000     EURJPY    0.19643
# 15     GBPCAD    0.06727     GBPCAD    0.10483     CADJPY    0.19643
# 16     CADCHF    0.06727     EURJPY    0.10050     EURNZD    0.19643
# 17     EURAUD    0.06727     GBPUSD    0.10050     AUDNZD    0.19643
# 18     AUDJPY    0.06727     GBPCHF    0.10050     NZDCHF    0.19643
# 19     GBPCHF    0.06667     NZDUSD    0.10050     NZDUSD    0.19643
# 20     NZDJPY    0.06667     EURGBP    0.10050     GBPCAD    0.18898
# 21     NZDCAD    0.06667     GBPJPY    0.00000     AUDCHF    0.09449
# 22     GBPJPY    0.00000     AUDCHF    0.00000     CADCHF    0.07143
# 23     EURCHF    0.00000     CADCHF    0.00000     NZDJPY    0.07143
# 24     AUDUSD    0.00000     CADJPY    0.00000     AUDCAD    0.07143
# 25     CADJPY    0.00000     AUDJPY    0.00000     EURGBP    0.07143
# 26     NZDUSD    0.00000     AUDCAD    0.00000     GBPJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      EURUSD    0.81650
# 1      USDJPY    0.81650
# 2      GBPUSD    0.58333
# 3      USDCAD    0.53452
# 4      USDCHF    0.40825
# 5      AUDUSD    0.40825
# 6      NZDCAD    0.40825
# 7      GBPCHF    0.40825
# 8      AUDJPY    0.40825
# 9      CHFJPY    0.40825
# 10     EURAUD    0.40825
# 11     EURCAD    0.40825
# 12     GBPAUD    0.35635
# 13     GBPCAD    0.35635
# 14     CADJPY    0.25000
# 15     EURNZD    0.25000
# 16     AUDNZD    0.25000
# 17     NZDCHF    0.25000
# 18     AUDCHF    0.25000
# 19     NZDUSD    0.25000
# 20     EURJPY    0.16667
# 21     EURCHF    0.16667
# 22     AUDCAD    0.16667
# 23     GBPJPY    0.08909
# 24     NZDJPY    0.08909
# 25     CADCHF    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
