# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 15:08:51.697134

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.23753     GBPUSD    0.38620     EURUSD    0.42857
# 1      GBPUSD    0.22653     AUDUSD    0.34717     GBPUSD    0.37284
# 2      GBPCAD    0.18684     NZDUSD    0.29579     CHFJPY    0.31180
# 3      AUDNZD    0.17485     EURUSD    0.29187     AUDCHF    0.28511
# 4      AUDCAD    0.16530     NZDCAD    0.29187     AUDUSD    0.25163
# 5      NZDCAD    0.14385     NZDJPY    0.24661     EURGBP    0.21822
# 6      CHFJPY    0.13457     AUDCAD    0.24456     NZDCAD    0.21822
# 7      EURJPY    0.13457     CHFJPY    0.19767     NZDJPY    0.21822
# 8      USDCHF    0.13457     AUDNZD    0.15714     NZDUSD    0.21822
# 9      EURNZD    0.12361     USDJPY    0.15714     GBPCHF    0.21822
# 10     NZDUSD    0.12361     EURNZD    0.15714     EURNZD    0.21822
# 11     GBPAUD    0.11775     GBPJPY    0.15714     EURCAD    0.21822
# 12     EURUSD    0.11289     USDCHF    0.14833     USDCHF    0.19048
# 13     AUDUSD    0.11289     EURAUD    0.10702     GBPJPY    0.15352
# 14     EURGBP    0.09237     AUDJPY    0.10702     AUDJPY    0.15352
# 15     NZDJPY    0.08181     USDCAD    0.10702     GBPAUD    0.13363
# 16     AUDCHF    0.07258     AUDCHF    0.08472     EURCHF    0.08909
# 17     GBPCHF    0.07258     GBPCAD    0.06917     USDCAD    0.08909
# 18     CADCHF    0.07258     GBPAUD    0.06917     AUDCAD    0.08909
# 19     CADJPY    0.04120     CADCHF    0.06917     USDJPY    0.08909
# 20     EURCHF    0.04120     CADJPY    0.06917     GBPCAD    0.06580
# 21     EURAUD    0.04120     EURCHF    0.05648     CADCHF    0.06580
# 22     EURCAD    0.04120     NZDCHF    0.01849     EURJPY    0.02288
# 23     USDCAD    0.02150     EURCAD    0.01849     NZDCHF    0.00000
# 24     GBPJPY    0.00990     GBPCHF    0.01849     EURAUD    0.00000
# 25     NZDCHF    0.00990     EURGBP    0.01849     CADJPY    0.00000
# 26     AUDJPY    0.00167     EURJPY    0.00478     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.57735     EURUSD    0.81650  ...     GBPCAD    0.35588
# 1      USDCHF    0.38889     USDCHF    0.60000  ...     EURGBP    0.32450
# 2      CHFJPY    0.38889     GBPUSD    0.60000  ...     GBPCHF    0.31807
# 3      AUDUSD    0.38889     AUDCAD    0.60000  ...     CHFJPY    0.18021
# 4      GBPUSD    0.38889     AUDUSD    0.60000  ...     USDJPY    0.16386
# 5      NZDCAD    0.32733     NZDUSD    0.60000  ...     CADCHF    0.15743
# 6      NZDJPY    0.32733     CHFJPY    0.60000  ...     AUDCHF    0.15743
# 7      EURCAD    0.32733     EURCAD    0.60000  ...     GBPAUD    0.14744
# 8      EURGBP    0.32733     NZDCAD    0.40825  ...     EURCAD    0.12039
# 9      NZDUSD    0.32733     NZDJPY    0.40825  ...     EURCHF    0.12039
# 10     GBPCHF    0.32733     AUDJPY    0.40825  ...     NZDCAD    0.11433
# 11     GBPAUD    0.28868     EURNZD    0.40825  ...     AUDCAD    0.10895
# 12     EURNZD    0.21822     GBPAUD    0.40825  ...     GBPJPY    0.07711
# 13     AUDCHF    0.21822     EURGBP    0.40825  ...     AUDUSD    0.07114
# 14     AUDCAD    0.21822     GBPCHF    0.40825  ...     USDCHF    0.06553
# 15     GBPJPY    0.21822     USDJPY    0.21822  ...     AUDJPY    0.05366
# 16     AUDJPY    0.21822     AUDNZD    0.21822  ...     NZDJPY    0.05366
# 17     EURCHF    0.11111     GBPJPY    0.20000  ...     USDCAD    0.04670
# 18     EURJPY    0.11111     EURJPY    0.20000  ...     NZDUSD    0.04013
# 19     CADCHF    0.05455     EURAUD    0.20000  ...     EURAUD    0.04013
# 20     EURAUD    0.05455     EURCHF    0.20000  ...     EURNZD    0.04013
# 21     CADJPY    0.05455     USDCAD    0.20000  ...     CADJPY    0.04013
# 22     GBPCAD    0.05455     GBPCAD    0.00000  ...     GBPUSD    0.03382
# 23     NZDCHF    0.05455     NZDCHF    0.00000  ...     EURJPY    0.01638
# 24     AUDNZD    0.05455     AUDCHF    0.00000  ...     EURUSD    0.00970
# 25     USDCAD    0.00000     CADCHF    0.00000  ...     NZDCHF    0.00321
# 26     USDJPY    0.00000     CADJPY    0.00000  ...     AUDNZD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      CHFJPY    0.21822     GBPUSD    0.30151     EURGBP    0.33929
# 1      EURGBP    0.20536     EURUSD    0.21822     CADJPY    0.33929
# 2      NZDCHF    0.20536     EURCHF    0.20412     GBPCAD    0.33929
# 3      USDJPY    0.19643     CHFJPY    0.20412     GBPCHF    0.33929
# 4      GBPCHF    0.19643     EURGBP    0.20000     GBPUSD    0.32733
# 5      EURUSD    0.15714     NZDCHF    0.20000     EURCHF    0.21822
# 6      NZDJPY    0.14382     NZDCAD    0.20000     EURJPY    0.21822
# 7      AUDJPY    0.14382     NZDJPY    0.20000     AUDCHF    0.19643
# 8      EURAUD    0.14382     CADJPY    0.20000     AUDNZD    0.19643
# 9      GBPUSD    0.14382     EURNZD    0.20000     USDJPY    0.18898
# 10     GBPCAD    0.13363     EURAUD    0.20000     EURUSD    0.18898
# 11     CADJPY    0.13363     AUDNZD    0.20000     USDCAD    0.09449
# 12     CADCHF    0.13363     GBPCHF    0.20000     GBPAUD    0.09449
# 13     GBPAUD    0.13363     NZDUSD    0.20000     EURCAD    0.07143
# 14     USDCHF    0.12016     EURJPY    0.10483     AUDCAD    0.07143
# 15     GBPJPY    0.07143     AUDUSD    0.10483     NZDUSD    0.07143
# 16     EURCAD    0.07143     AUDCHF    0.10050     NZDCHF    0.07143
# 17     NZDUSD    0.07143     CADCHF    0.10050     NZDCAD    0.07143
# 18     EURNZD    0.06250     GBPJPY    0.10050     GBPJPY    0.07143
# 19     AUDNZD    0.06250     GBPCAD    0.10050     CADCHF    0.07143
# 20     AUDCHF    0.05455     AUDJPY    0.10050     EURAUD    0.07143
# 21     EURCHF    0.05455     GBPAUD    0.00000     EURNZD    0.07143
# 22     AUDCAD    0.04725     EURCAD    0.00000     AUDJPY    0.07143
# 23     AUDUSD    0.02916     USDCAD    0.00000     NZDJPY    0.07143
# 24     EURJPY    0.01849     AUDCAD    0.00000     CHFJPY    0.05455
# 25     NZDCAD    0.01849     USDJPY    0.00000     AUDUSD    0.05455
# 26     USDCAD    0.00899     USDCHF    0.00000     USDCHF    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.66667
# 1      GBPCHF    0.66667
# 2      EURUSD    0.58333
# 3      AUDCAD    0.40825
# 4      EURCAD    0.40825
# 5      GBPUSD    0.40825
# 6      CHFJPY    0.40825
# 7      USDCHF    0.40825
# 8      AUDUSD    0.40825
# 9      NZDUSD    0.40825
# 10     USDJPY    0.35635
# 11     AUDJPY    0.25000
# 12     NZDCHF    0.25000
# 13     GBPCAD    0.25000
# 14     GBPAUD    0.25000
# 15     EURNZD    0.25000
# 16     CADCHF    0.16667
# 17     AUDCHF    0.16667
# 18     NZDCAD    0.16667
# 19     NZDJPY    0.16667
# 20     CADJPY    0.16667
# 21     AUDNZD    0.08909
# 22     EURCHF    0.00000
# 23     EURAUD    0.00000
# 24     USDCAD    0.00000
# 25     GBPJPY    0.00000
# 26     EURJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
