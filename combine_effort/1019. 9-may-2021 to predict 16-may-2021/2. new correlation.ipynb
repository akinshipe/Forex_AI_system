# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:53:16.823216

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.28356     EURJPY    0.49357     CADJPY    0.57907
# 1      GBPJPY    0.28356     CADJPY    0.39747     EURJPY    0.35722
# 2      CADJPY    0.27891     GBPJPY    0.36748     CHFJPY    0.28721
# 3      CHFJPY    0.27891     CHFJPY    0.32733     GBPCHF    0.23570
# 4      AUDNZD    0.23028     EURNZD    0.29579     GBPJPY    0.22866
# 5      EURNZD    0.18831     AUDNZD    0.25882     GBPUSD    0.17118
# 6      EURUSD    0.18286     EURUSD    0.20536     USDCHF    0.16667
# 7      NZDJPY    0.17620     AUDJPY    0.18898     EURCAD    0.16667
# 8      GBPUSD    0.16116     GBPCHF    0.18898     NZDCHF    0.13363
# 9      AUDJPY    0.16116     EURAUD    0.15714     CADCHF    0.13363
# 10     EURGBP    0.15198     EURGBP    0.14382     NZDJPY    0.10206
# 11     NZDUSD    0.12588     EURCHF    0.12016     GBPCAD    0.08909
# 12     AUDUSD    0.12588     AUDUSD    0.12016     EURGBP    0.08909
# 13     GBPAUD    0.11613     NZDJPY    0.11585     NZDUSD    0.08909
# 14     CADCHF    0.11289     GBPAUD    0.07143     GBPAUD    0.08206
# 15     GBPCHF    0.11289     USDCHF    0.07143     AUDCAD    0.08206
# 16     GBPCAD    0.09869     USDCAD    0.05455     AUDCHF    0.04280
# 17     AUDCHF    0.09066     AUDCAD    0.05455     EURCHF    0.04280
# 18     NZDCHF    0.07722     GBPUSD    0.04725     EURAUD    0.04280
# 19     EURCHF    0.07722     CADCHF    0.04725     AUDJPY    0.04280
# 20     NZDCAD    0.07722     NZDCHF    0.04029     NZDCAD    0.04280
# 21     EURCAD    0.03548     NZDUSD    0.04029     AUDUSD    0.04167
# 22     USDCAD    0.02988     NZDCAD    0.02916     USDCAD    0.04167
# 23     AUDCAD    0.02988     AUDCHF    0.01849     EURNZD    0.04167
# 24     USDCHF    0.01959     GBPCAD    0.01849     USDJPY    0.04167
# 25     EURAUD    0.01645     EURCAD    0.00899     EURUSD    0.04167
# 26     USDJPY    0.00000     USDJPY    0.00000     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.44444     EURCAD    0.65465  ...     GBPUSD    0.30054
# 1      GBPCHF    0.43082     USDCHF    0.60000  ...     EURUSD    0.23153
# 2      CADJPY    0.43082     AUDNZD    0.50000  ...     EURAUD    0.19852
# 3      USDCAD    0.28868     NZDUSD    0.40825  ...     GBPJPY    0.16967
# 4      NZDUSD    0.28868     GBPCHF    0.40825  ...     AUDCAD    0.16530
# 5      CADCHF    0.28868     CADJPY    0.40825  ...     GBPCHF    0.16530
# 6      GBPJPY    0.27217     CADCHF    0.40825  ...     AUDNZD    0.13234
# 7      AUDUSD    0.21822     AUDCHF    0.40825  ...     AUDCHF    0.13170
# 8      EURUSD    0.16667     EURAUD    0.40825  ...     NZDCAD    0.13170
# 9      USDJPY    0.16667     EURJPY    0.33333  ...     NZDCHF    0.13170
# 10     EURAUD    0.16667     EURGBP    0.21822  ...     GBPCAD    0.11580
# 11     AUDCHF    0.16667     NZDJPY    0.21822  ...     EURNZD    0.10123
# 12     EURCAD    0.16667     GBPJPY    0.21822  ...     NZDUSD    0.09752
# 13     EURGBP    0.12309     USDCAD    0.21822  ...     AUDUSD    0.09752
# 14     AUDNZD    0.12309     NZDCAD    0.20000  ...     CADJPY    0.08515
# 15     GBPUSD    0.11111     EURUSD    0.20000  ...     CADCHF    0.08181
# 16     GBPAUD    0.11111     USDJPY    0.20000  ...     CHFJPY    0.08181
# 17     EURNZD    0.11111     GBPUSD    0.20000  ...     USDCHF    0.06732
# 18     AUDJPY    0.11111     CHFJPY    0.20000  ...     NZDJPY    0.06255
# 19     NZDCAD    0.11111     AUDUSD    0.20000  ...     EURGBP    0.05366
# 20     EURJPY    0.08006     GBPCAD    0.20000  ...     EURCHF    0.04728
# 21     NZDJPY    0.06804     GBPAUD    0.00000  ...     AUDJPY    0.04728
# 22     CHFJPY    0.05455     NZDCHF    0.00000  ...     USDJPY    0.04052
# 23     AUDCAD    0.05455     EURNZD    0.00000  ...     EURJPY    0.01083
# 24     GBPCAD    0.00000     AUDJPY    0.00000  ...     EURCAD    0.00649
# 25     NZDCHF    0.00000     EURCHF    0.00000  ...     GBPAUD    0.00649
# 26     EURCHF    0.00000     AUDCAD    0.00000  ...     USDCAD    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.29187     GBPCAD    0.42857     AUDCHF    0.49237
# 1      GBPCHF    0.24456     GBPCHF    0.37796     GBPCAD    0.42640
# 2      GBPUSD    0.24456     GBPJPY    0.27501     EURGBP    0.36364
# 3      USDJPY    0.20751     AUDCHF    0.25163     GBPCHF    0.36364
# 4      GBPJPY    0.20751     GBPUSD    0.25163     AUDNZD    0.36364
# 5      AUDCAD    0.19767     NZDJPY    0.21822     AUDCAD    0.34247
# 6      GBPAUD    0.15714     EURGBP    0.19048     GBPJPY    0.30151
# 7      AUDCHF    0.14833     AUDCAD    0.15352     AUDUSD    0.26189
# 8      EURCHF    0.14833     EURNZD    0.13363     EURJPY    0.23652
# 9      AUDNZD    0.13876     USDCHF    0.13363     NZDCAD    0.18464
# 10     CADJPY    0.13876     EURUSD    0.13363     AUDJPY    0.18464
# 11     USDCHF    0.12016     USDJPY    0.13363     EURNZD    0.18464
# 12     EURUSD    0.12016     USDCAD    0.13363     EURAUD    0.18464
# 13     EURGBP    0.10702     AUDNZD    0.12599     EURCAD    0.18464
# 14     CHFJPY    0.08472     AUDUSD    0.08909     GBPAUD    0.18464
# 15     USDCAD    0.08472     EURCAD    0.08909     GBPUSD    0.18464
# 16     NZDJPY    0.07087     GBPAUD    0.06580     EURUSD    0.12309
# 17     CADCHF    0.04891     CHFJPY    0.06580     USDJPY    0.12309
# 18     AUDJPY    0.04891     EURJPY    0.05455     USDCHF    0.12309
# 19     NZDCAD    0.04528     NZDUSD    0.04762     NZDUSD    0.10660
# 20     EURCAD    0.03257     CADJPY    0.04762     NZDCHF    0.10660
# 21     NZDCHF    0.01043     NZDCHF    0.04762     CADCHF    0.10660
# 22     NZDUSD    0.01043     CADCHF    0.04762     EURCHF    0.10660
# 23     EURJPY    0.01043     EURAUD    0.02288     USDCAD    0.10660
# 24     AUDUSD    0.00478     AUDJPY    0.02288     NZDJPY    0.07538
# 25     EURAUD    0.00478     EURCHF    0.02288     CHFJPY    0.04029
# 26     EURNZD    0.00478     NZDCAD    0.02288     CADJPY    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.65465
# 1      GBPCHF    0.53452
# 2      AUDCHF    0.53452
# 3      EURGBP    0.42857
# 4      GBPJPY    0.42857
# 5      AUDCAD    0.35635
# 6      AUDNZD    0.32733
# 7      EURJPY    0.21822
# 8      GBPUSD    0.21822
# 9      NZDCAD    0.21822
# 10     EURUSD    0.21822
# 11     USDJPY    0.21822
# 12     USDCHF    0.21822
# 13     AUDUSD    0.21822
# 14     CHFJPY    0.21822
# 15     NZDCHF    0.08909
# 16     GBPAUD    0.08909
# 17     EURCHF    0.08909
# 18     EURAUD    0.08909
# 19     EURNZD    0.08909
# 20     CADJPY    0.08909
# 21     AUDJPY    0.08909
# 22     CADCHF    0.08909
# 23     NZDUSD    0.08909
# 24     USDCAD    0.04762
# 25     EURCAD    0.04762
# 26     NZDJPY    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
