# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 19:21:49.546234

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.33333     CADJPY    0.43301     CADJPY    0.47076
# 1      EURJPY    0.30551     EURJPY    0.43082     GBPCHF    0.35635
# 2      GBPJPY    0.30551     CHFJPY    0.36711     GBPJPY    0.35635
# 3      EURUSD    0.28090     GBPJPY    0.35392     AUDCHF    0.28721
# 4      CADJPY    0.25000     EURUSD    0.30208     CADCHF    0.25678
# 5      GBPUSD    0.16667     GBPCHF    0.20787     AUDNZD    0.25678
# 6      NZDJPY    0.16667     NZDCHF    0.16667     NZDCHF    0.20412
# 7      AUDNZD    0.16330     USDCHF    0.16477     EURAUD    0.20412
# 8      NZDUSD    0.16330     EURGBP    0.11111     CHFJPY    0.16667
# 9      NZDCAD    0.16116     NZDCAD    0.10985     USDJPY    0.16667
# 10     EURGBP    0.16116     NZDUSD    0.08472     AUDCAD    0.12309
# 11     USDCHF    0.16013     GBPUSD    0.08472     NZDCAD    0.12309
# 12     AUDJPY    0.12361     AUDJPY    0.08472     EURNZD    0.12309
# 13     NZDCHF    0.12157     EURAUD    0.08183     EURUSD    0.12309
# 14     CADCHF    0.08333     AUDNZD    0.05939     EURJPY    0.10206
# 15     GBPCHF    0.08333     NZDJPY    0.05939     AUDJPY    0.08206
# 16     AUDCHF    0.08165     CADCHF    0.05939     EURCAD    0.08206
# 17     AUDUSD    0.08165     AUDCAD    0.05455     USDCHF    0.08206
# 18     GBPAUD    0.08058     GBPAUD    0.05455     GBPUSD    0.08206
# 19     EURCAD    0.08006     USDJPY    0.02778     AUDUSD    0.08206
# 20     EURNZD    0.08006     EURCHF    0.02778     GBPCAD    0.04280
# 21     AUDCAD    0.04052     AUDCHF    0.02778     NZDJPY    0.04280
# 22     EURAUD    0.04013     USDCAD    0.02746     EURGBP    0.04280
# 23     EURCHF    0.00000     AUDUSD    0.02746     EURCHF    0.04167
# 24     GBPCAD    0.00000     EURCAD    0.02746     USDCAD    0.04167
# 25     USDCAD    0.00000     EURNZD    0.00000     GBPAUD    0.00000
# 26     USDJPY    0.00000     GBPCAD    0.00000     NZDUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.33929     CHFJPY    0.65465  ...     GBPUSD    0.21612
# 1      AUDNZD    0.21822     EURUSD    0.60000  ...     CADJPY    0.20599
# 2      GBPCHF    0.21822     CADJPY    0.40825  ...     USDCHF    0.16871
# 3      GBPJPY    0.21822     EURNZD    0.40825  ...     AUDJPY    0.16864
# 4      CADCHF    0.21822     GBPJPY    0.40825  ...     USDJPY    0.15573
# 5      CHFJPY    0.21822     GBPUSD    0.40825  ...     EURJPY    0.15032
# 6      AUDUSD    0.21822     NZDCHF    0.40825  ...     EURUSD    0.13497
# 7      AUDCAD    0.19643     AUDCHF    0.40825  ...     AUDNZD    0.13234
# 8      EURCHF    0.19643     USDCHF    0.40825  ...     GBPCHF    0.13170
# 9      USDCAD    0.19643     GBPCHF    0.40825  ...     NZDJPY    0.12157
# 10     AUDCHF    0.19643     NZDUSD    0.40825  ...     GBPCAD    0.11580
# 11     NZDJPY    0.19643     NZDCAD    0.40825  ...     GBPAUD    0.10123
# 12     NZDCAD    0.19643     CADCHF    0.21822  ...     EURCAD    0.07462
# 13     EURUSD    0.19643     GBPCAD    0.21822  ...     AUDCAD    0.06732
# 14     EURNZD    0.19643     EURJPY    0.21822  ...     EURGBP    0.06204
# 15     GBPCAD    0.09449     EURCAD    0.20000  ...     EURAUD    0.05366
# 16     EURCAD    0.07143     AUDJPY    0.20000  ...     USDCAD    0.04963
# 17     AUDJPY    0.07143     AUDCAD    0.20000  ...     AUDUSD    0.04963
# 18     USDCHF    0.07143     AUDNZD    0.20000  ...     NZDUSD    0.04963
# 19     GBPAUD    0.07143     EURCHF    0.20000  ...     AUDCHF    0.04963
# 20     GBPUSD    0.07143     EURAUD    0.00000  ...     CADCHF    0.04728
# 21     NZDUSD    0.07143     GBPAUD    0.00000  ...     CHFJPY    0.03715
# 22     USDJPY    0.07143     AUDUSD    0.00000  ...     EURCHF    0.03715
# 23     EURAUD    0.05455     NZDJPY    0.00000  ...     GBPJPY    0.02653
# 24     NZDCHF    0.05455     USDCAD    0.00000  ...     NZDCAD    0.01959
# 25     EURGBP    0.05455     USDJPY    0.00000  ...     NZDCHF    0.01478
# 26     EURJPY    0.04029     EURGBP    0.00000  ...     EURNZD    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.35000     GBPCAD    0.38516     GBPCHF    0.49099
# 1      NZDJPY    0.30861     GBPCHF    0.31180     GBPCAD    0.37796
# 2      GBPCHF    0.30861     USDCHF    0.28721     USDCHF    0.33929
# 3      USDCHF    0.23783     AUDCAD    0.28721     GBPJPY    0.21822
# 4      AUDJPY    0.19565     NZDJPY    0.25678     CADCHF    0.21822
# 5      NZDUSD    0.19565     CADCHF    0.17118     AUDNZD    0.21822
# 6      NZDCHF    0.14434     AUDNZD    0.17118     EURCAD    0.19643
# 7      EURNZD    0.14142     AUDCHF    0.12309     AUDCAD    0.19643
# 8      CADJPY    0.10000     GBPUSD    0.12309     NZDJPY    0.19643
# 9      GBPUSD    0.09782     EURJPY    0.10206     AUDCHF    0.19643
# 10     NZDCAD    0.09513     GBPJPY    0.08909     EURUSD    0.19643
# 11     AUDUSD    0.09513     EURCAD    0.08206     NZDUSD    0.07143
# 12     EURUSD    0.09513     NZDCAD    0.08206     NZDCAD    0.07143
# 13     EURCAD    0.09513     AUDUSD    0.08206     AUDJPY    0.07143
# 14     USDCAD    0.09513     EURUSD    0.08206     CADJPY    0.07143
# 15     AUDCAD    0.09449     AUDJPY    0.08206     EURNZD    0.07143
# 16     GBPAUD    0.09449     EURNZD    0.08206     GBPAUD    0.07143
# 17     GBPJPY    0.05573     CADJPY    0.04280     USDJPY    0.07143
# 18     EURJPY    0.05330     EURGBP    0.04280     GBPUSD    0.07143
# 19     CHFJPY    0.04891     EURCHF    0.04167     USDCAD    0.07143
# 20     EURAUD    0.04725     USDCAD    0.04167     EURCHF    0.07143
# 21     EURGBP    0.00000     USDJPY    0.04167     AUDUSD    0.05455
# 22     AUDCHF    0.00000     CHFJPY    0.04167     EURAUD    0.05455
# 23     CADCHF    0.00000     EURAUD    0.00000     NZDCHF    0.05455
# 24     EURCHF    0.00000     GBPAUD    0.00000     CHFJPY    0.05455
# 25     USDJPY    0.00000     NZDCHF    0.00000     EURGBP    0.05455
# 26     AUDNZD    0.00000     NZDUSD    0.00000     EURJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.40825
# 1      GBPCHF    0.40825
# 2      NZDJPY    0.40825
# 3      EURGBP    0.40825
# 4      GBPCAD    0.21822
# 5      EURJPY    0.21822
# 6      CHFJPY    0.21822
# 7      CADCHF    0.21822
# 8      AUDCAD    0.20000
# 9      EURUSD    0.20000
# 10     AUDJPY    0.20000
# 11     EURCAD    0.20000
# 12     AUDNZD    0.20000
# 13     EURCHF    0.20000
# 14     GBPUSD    0.00000
# 15     GBPJPY    0.00000
# 16     AUDUSD    0.00000
# 17     GBPAUD    0.00000
# 18     NZDCHF    0.00000
# 19     AUDCHF    0.00000
# 20     EURAUD    0.00000
# 21     EURNZD    0.00000
# 22     CADJPY    0.00000
# 23     USDJPY    0.00000
# 24     NZDUSD    0.00000
# 25     NZDCAD    0.00000
# 26     USDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
