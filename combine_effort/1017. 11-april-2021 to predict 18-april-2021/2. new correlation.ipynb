# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:57:35.370263

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.25395     EURJPY    0.52322     EURJPY    0.54470
# 1      GBPJPY    0.25395     GBPJPY    0.31278     CADJPY    0.30261
# 2      NZDJPY    0.23889     CADJPY    0.31175     GBPJPY    0.27890
# 3      CADJPY    0.22653     EURNZD    0.30208     AUDCHF    0.25163
# 4      AUDNZD    0.21627     EURUSD    0.27866     EURNZD    0.24232
# 5      EURNZD    0.19485     AUDNZD    0.24716     GBPCHF    0.20588
# 6      CHFJPY    0.19061     CHFJPY    0.24716     CADCHF    0.18157
# 7      EURUSD    0.17138     NZDJPY    0.23324     NZDUSD    0.18157
# 8      AUDUSD    0.15418     EURGBP    0.22172     EURUSD    0.17118
# 9      NZDUSD    0.15418     EURCHF    0.17216     EURAUD    0.17118
# 10     GBPUSD    0.14385     AUDUSD    0.17216     CHFJPY    0.12088
# 11     AUDJPY    0.14385     AUDJPY    0.17216     EURCHF    0.12088
# 12     AUDCHF    0.14379     USDCHF    0.16477     GBPAUD    0.10483
# 13     EURGBP    0.12039     USDCAD    0.12585     GBPUSD    0.09890
# 14     EURCHF    0.10701     GBPCAD    0.10702     AUDUSD    0.09890
# 15     NZDCAD    0.10701     EURAUD    0.10702     NZDCAD    0.09890
# 16     GBPAUD    0.07711     AUDCHF    0.10702     USDJPY    0.09890
# 17     USDJPY    0.07711     GBPUSD    0.09513     USDCHF    0.09890
# 18     GBPCAD    0.07114     GBPAUD    0.08597     NZDJPY    0.06052
# 19     NZDCHF    0.06118     EURCAD    0.08597     AUDNZD    0.06052
# 20     CADCHF    0.06118     NZDUSD    0.08113     EURCAD    0.04280
# 21     GBPCHF    0.06118     AUDCAD    0.04977     GBPCAD    0.04280
# 22     AUDCAD    0.06118     NZDCAD    0.04757     AUDCAD    0.03161
# 23     USDCAD    0.05366     GBPCHF    0.01468     USDCAD    0.03161
# 24     USDCHF    0.04670     CADCHF    0.01468     EURGBP    0.03161
# 25     EURCAD    0.04013     NZDCHF    0.01468     AUDJPY    0.02288
# 26     EURAUD    0.02764     USDJPY    0.00899     NZDCHF    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.45227     NZDUSD    0.53452  ...     GBPUSD    0.21868
# 1      EURJPY    0.45227     EURAUD    0.35635  ...     EURUSD    0.14804
# 2      NZDJPY    0.31818     USDCHF    0.21822  ...     AUDNZD    0.13234
# 3      AUDCAD    0.26189     GBPUSD    0.21822  ...     CADJPY    0.11775
# 4      EURCHF    0.21320     NZDCAD    0.21822  ...     EURAUD    0.11580
# 5      NZDCHF    0.21320     CADJPY    0.21822  ...     CHFJPY    0.10206
# 6      GBPJPY    0.20696     EURNZD    0.21822  ...     GBPJPY    0.08909
# 7      GBPUSD    0.18464     EURJPY    0.21822  ...     GBPCAD    0.06580
# 8      AUDJPY    0.12309     GBPJPY    0.21822  ...     GBPCHF    0.05046
# 9      CHFJPY    0.12309     AUDNZD    0.21822  ...     AUDCAD    0.05046
# 10     NZDCAD    0.12309     CHFJPY    0.21822  ...     CADCHF    0.05046
# 11     EURAUD    0.12309     GBPCHF    0.21822  ...     NZDCHF    0.05046
# 12     NZDUSD    0.10660     AUDUSD    0.21822  ...     USDCAD    0.04963
# 13     USDJPY    0.10660     AUDJPY    0.08909  ...     GBPAUD    0.04903
# 14     EURUSD    0.10660     NZDCHF    0.08909  ...     USDJPY    0.04903
# 15     EURCAD    0.10660     GBPCAD    0.08909  ...     AUDJPY    0.03364
# 16     GBPCAD    0.10660     GBPAUD    0.08909  ...     AUDUSD    0.01724
# 17     AUDCHF    0.10660     AUDCAD    0.08909  ...     NZDUSD    0.01724
# 18     EURGBP    0.10660     USDCAD    0.08909  ...     NZDJPY    0.01724
# 19     GBPCHF    0.07538     CADCHF    0.04762  ...     NZDCAD    0.01701
# 20     GBPAUD    0.04029     EURUSD    0.04762  ...     EURCHF    0.01701
# 21     USDCAD    0.04029     NZDJPY    0.04762  ...     AUDCHF    0.01701
# 22     EURNZD    0.04029     EURCAD    0.04762  ...     USDCHF    0.01638
# 23     AUDUSD    0.04029     USDJPY    0.04762  ...     EURNZD    0.01638
# 24     USDCHF    0.02273     AUDCHF    0.04762  ...     EURCAD    0.00000
# 25     CADCHF    0.02273     EURCHF    0.04762  ...     EURJPY    0.00000
# 26     AUDNZD    0.02273     EURGBP    0.04762  ...     EURGBP    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPAUD    0.24661     GBPCAD    0.40825     GBPCAD    0.42640
# 1      GBPUSD    0.24456     GBPCHF    0.32733     EURNZD    0.34247
# 2      AUDNZD    0.22591     USDCAD    0.30151     GBPAUD    0.34247
# 3      EURCHF    0.14833     EURNZD    0.30151     USDCAD    0.34247
# 4      GBPCAD    0.14833     NZDUSD    0.28868     NZDJPY    0.31818
# 5      AUDJPY    0.13876     NZDJPY    0.28868     GBPCHF    0.30151
# 6      CADJPY    0.13876     GBPAUD    0.25000     GBPJPY    0.23652
# 7      EURUSD    0.12016     AUDJPY    0.21822     NZDCHF    0.21320
# 8      USDJPY    0.12016     NZDCHF    0.21822     NZDUSD    0.21320
# 9      USDCAD    0.12016     GBPJPY    0.21004     GBPUSD    0.18464
# 10     AUDCAD    0.10702     EURGBP    0.20101     CHFJPY    0.12309
# 11     NZDCHF    0.10566     NZDCAD    0.15724     NZDCAD    0.12309
# 12     GBPJPY    0.09268     AUDUSD    0.15724     EURAUD    0.12309
# 13     EURNZD    0.08472     CHFJPY    0.15724     AUDJPY    0.12309
# 14     USDCHF    0.08472     EURUSD    0.15309     EURCHF    0.10660
# 15     CHFJPY    0.08472     EURCAD    0.15309     AUDCHF    0.10660
# 16     EURJPY    0.04891     USDCHF    0.10483     USDJPY    0.10660
# 17     NZDCAD    0.04891     GBPUSD    0.10483     EURCAD    0.10660
# 18     CADCHF    0.04528     EURCHF    0.10483     EURUSD    0.10660
# 19     GBPCHF    0.04528     USDJPY    0.10483     EURGBP    0.10660
# 20     EURCAD    0.03257     EURAUD    0.10206     EURJPY    0.07538
# 21     EURGBP    0.03257     AUDCHF    0.05455     CADJPY    0.07538
# 22     NZDUSD    0.01043     AUDCAD    0.05025     AUDCAD    0.04029
# 23     NZDJPY    0.01043     EURJPY    0.00000     AUDUSD    0.04029
# 24     AUDCHF    0.00478     CADJPY    0.00000     USDCHF    0.02273
# 25     EURAUD    0.00478     CADCHF    0.00000     CADCHF    0.02273
# 26     AUDUSD    0.00478     AUDNZD    0.00000     AUDNZD    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.40825
# 1      EURGBP    0.32733
# 2      AUDCHF    0.32733
# 3      EURUSD    0.32733
# 4      USDJPY    0.32733
# 5      EURCAD    0.32733
# 6      EURCHF    0.32733
# 7      CADCHF    0.32733
# 8      CADJPY    0.25000
# 9      EURJPY    0.25000
# 10     GBPJPY    0.25000
# 11     USDCHF    0.25000
# 12     GBPCHF    0.25000
# 13     AUDNZD    0.25000
# 14     NZDJPY    0.21822
# 15     NZDCHF    0.10206
# 16     GBPAUD    0.10206
# 17     NZDUSD    0.10206
# 18     EURAUD    0.10206
# 19     USDCAD    0.10206
# 20     AUDJPY    0.10206
# 21     AUDCAD    0.10206
# 22     GBPUSD    0.00000
# 23     CHFJPY    0.00000
# 24     AUDUSD    0.00000
# 25     EURNZD    0.00000
# 26     NZDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
