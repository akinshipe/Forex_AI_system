# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 10:51:08.741725

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.40032     USDJPY    0.53035     USDJPY    0.40825
# 1      USDJPY    0.39906     USDCHF    0.20536     EURJPY    0.40825
# 2      USDCHF    0.32026     GBPUSD    0.20536     AUDCAD    0.40000
# 3      EURJPY    0.27885     NZDCAD    0.20536     NZDUSD    0.31449
# 4      NZDUSD    0.27885     AUDCAD    0.20536     USDCHF    0.30151
# 5      CHFJPY    0.24982     CADJPY    0.20536     AUDUSD    0.30151
# 6      AUDCAD    0.24019     EURJPY    0.20536     EURAUD    0.30151
# 7      GBPUSD    0.24019     AUDJPY    0.19094     CHFJPY    0.30151
# 8      EURUSD    0.23775     AUDNZD    0.14382     GBPUSD    0.30151
# 9      AUDUSD    0.23775     NZDUSD    0.13363     AUDCHF    0.20412
# 10     CADCHF    0.20192     CHFJPY    0.08183     NZDJPY    0.20412
# 11     NZDJPY    0.13074     CADCHF    0.07143     AUDNZD    0.20412
# 12     CADJPY    0.11859     USDCAD    0.07143     EURUSD    0.20412
# 13     GBPJPY    0.11859     EURNZD    0.07143     EURCAD    0.20000
# 14     EURCAD    0.08006     EURGBP    0.07143     EURGBP    0.20000
# 15     AUDNZD    0.07462     GBPCAD    0.06250     GBPAUD    0.10483
# 16     USDCAD    0.04167     NZDCHF    0.06250     EURCHF    0.10483
# 17     GBPCAD    0.03846     AUDUSD    0.06250     USDCAD    0.10483
# 18     NZDCHF    0.03846     EURUSD    0.06250     GBPJPY    0.10050
# 19     EURAUD    0.03846     GBPAUD    0.05455     EURNZD    0.10050
# 20     EURGBP    0.03846     EURCHF    0.01849     CADJPY    0.10050
# 21     GBPAUD    0.03548     NZDJPY    0.01849     AUDJPY    0.10050
# 22     AUDJPY    0.03548     GBPCHF    0.00899     NZDCAD    0.10050
# 23     GBPCHF    0.03548     GBPJPY    0.00000     NZDCHF    0.00000
# 24     EURCHF    0.00649     EURAUD    0.00000     CADCHF    0.00000
# 25     EURNZD    0.00000     AUDCHF    0.00000     GBPCAD    0.00000
# 26     AUDCHF    0.00000     EURCAD    0.00000     GBPCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDJPY    0.60010     USDJPY    0.81650  ...     GBPCAD    0.39906
# 1      NZDCAD    0.49099     NZDCAD    0.65465  ...     GBPCHF    0.38858
# 2      AUDCAD    0.49099     AUDCAD    0.65465  ...     AUDUSD    0.37888
# 3      AUDUSD    0.49099     AUDUSD    0.65465  ...     AUDCHF    0.36470
# 4      GBPUSD    0.46429     EURGBP    0.60000  ...     GBPUSD    0.36470
# 5      NZDUSD    0.46429     GBPUSD    0.60000  ...     AUDCAD    0.36470
# 6      CHFJPY    0.33929     NZDUSD    0.60000  ...     EURGBP    0.33092
# 7      EURAUD    0.33929     NZDJPY    0.40825  ...     GBPJPY    0.33092
# 8      EURJPY    0.33929     EURNZD    0.40825  ...     EURUSD    0.29758
# 9      EURGBP    0.32733     EURAUD    0.40825  ...     NZDCAD    0.28365
# 10     EURNZD    0.32733     GBPCAD    0.40825  ...     EURAUD    0.23684
# 11     NZDJPY    0.21822     GBPJPY    0.40825  ...     EURCHF    0.23153
# 12     GBPCAD    0.19643     USDCHF    0.40825  ...     NZDCHF    0.16871
# 13     USDCHF    0.19643     AUDCHF    0.40825  ...     NZDUSD    0.16871
# 14     AUDCHF    0.19643     GBPCHF    0.40825  ...     EURJPY    0.16871
# 15     GBPCHF    0.19643     USDCAD    0.40825  ...     CADCHF    0.15573
# 16     USDCAD    0.19643     EURUSD    0.40825  ...     USDJPY    0.14943
# 17     EURUSD    0.19643     CADJPY    0.21822  ...     AUDJPY    0.14368
# 18     EURCAD    0.07143     NZDCHF    0.20000  ...     NZDJPY    0.13234
# 19     CADCHF    0.07143     CADCHF    0.20000  ...     EURNZD    0.12157
# 20     AUDJPY    0.07143     GBPAUD    0.20000  ...     USDCHF    0.12157
# 21     GBPJPY    0.05455     EURJPY    0.20000  ...     EURCAD    0.12157
# 22     NZDCHF    0.05455     EURCAD    0.20000  ...     CHFJPY    0.09688
# 23     GBPAUD    0.05455     CHFJPY    0.20000  ...     USDCAD    0.07462
# 24     EURCHF    0.05455     EURCHF    0.20000  ...     AUDNZD    0.06732
# 25     CADJPY    0.05455     AUDJPY    0.20000  ...     GBPAUD    0.06204
# 26     AUDNZD    0.05455     AUDNZD    0.00000  ...     CADJPY    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.53035     GBPCHF    0.73380     GBPCHF    0.76376
# 1      GBPCHF    0.45701     EURGBP    0.52414     EURGBP    0.66667
# 2      AUDUSD    0.41349     GBPCAD    0.52414     NZDUSD    0.49099
# 3      EURGBP    0.39551     EURNZD    0.45303     AUDCHF    0.49099
# 4      GBPUSD    0.39551     GBPUSD    0.45303     GBPUSD    0.49099
# 5      AUDCAD    0.39551     NZDCAD    0.38982     GBPCAD    0.49099
# 6      NZDCAD    0.39551     USDJPY    0.38516     NZDCAD    0.44444
# 7      AUDCHF    0.33634     NZDCHF    0.38516     AUDCAD    0.44444
# 8      GBPJPY    0.33634     AUDCHF    0.38516     AUDUSD    0.44444
# 9      EURAUD    0.33634     EURCHF    0.31868     USDJPY    0.38889
# 10     NZDCHF    0.27866     NZDUSD    0.31868     EURCHF    0.38889
# 11     EURUSD    0.27866     AUDCAD    0.31449     EURNZD    0.38889
# 12     EURNZD    0.26068     CHFJPY    0.24232     NZDCHF    0.38889
# 13     EURCHF    0.24661     AUDUSD    0.24232     GBPJPY    0.38889
# 14     USDJPY    0.22172     GBPJPY    0.24232     EURAUD    0.32733
# 15     NZDUSD    0.20180     EURAUD    0.24232     EURJPY    0.21822
# 16     EURCAD    0.20180     EURJPY    0.17118     USDCHF    0.21822
# 17     NZDJPY    0.17216     AUDNZD    0.17118     CADCHF    0.21822
# 18     USDCHF    0.12585     CADCHF    0.17118     CHFJPY    0.21822
# 19     EURJPY    0.12585     EURUSD    0.17118     USDCAD    0.21822
# 20     CADCHF    0.12585     GBPAUD    0.12088     EURUSD    0.21822
# 21     GBPAUD    0.10985     EURCAD    0.10483     GBPAUD    0.16667
# 22     AUDJPY    0.10985     USDCAD    0.09890     NZDJPY    0.16667
# 23     AUDNZD    0.08597     NZDJPY    0.04280     CADJPY    0.11111
# 24     CHFJPY    0.02746     CADJPY    0.03161     AUDNZD    0.11111
# 25     CADJPY    0.00899     AUDJPY    0.03161     EURCAD    0.05455
# 26     USDCAD    0.00899     USDCHF    0.03161     AUDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCHF    0.80178
# 1      EURGBP    0.65465
# 2      GBPUSD    0.65465
# 3      NZDUSD    0.65465
# 4      EURNZD    0.53452
# 5      GBPCAD    0.53452
# 6      GBPJPY    0.53452
# 7      USDCHF    0.53452
# 8      EURUSD    0.53452
# 9      USDCAD    0.53452
# 10     USDJPY    0.53452
# 11     NZDCAD    0.52381
# 12     AUDCAD    0.52381
# 13     AUDUSD    0.52381
# 14     CADJPY    0.42857
# 15     AUDCHF    0.35635
# 16     NZDJPY    0.35635
# 17     EURAUD    0.35635
# 18     EURCHF    0.21822
# 19     AUDJPY    0.21822
# 20     EURJPY    0.21822
# 21     EURCAD    0.21822
# 22     CHFJPY    0.21822
# 23     GBPAUD    0.21822
# 24     NZDCHF    0.21822
# 25     CADCHF    0.21822
# 26     AUDNZD    0.08909
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
