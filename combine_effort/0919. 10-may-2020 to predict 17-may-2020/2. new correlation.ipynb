# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-12 18:56:08.179774

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.40032     USDJPY    0.47087     USDJPY    0.41414
# 1      USDJPY    0.36116     EURJPY    0.33333     EURJPY    0.39394
# 2      EURJPY    0.36116     USDCHF    0.26726     USDCHF    0.30151
# 3      CHFJPY    0.32233     GBPUSD    0.26726     CHFJPY    0.30151
# 4      USDCHF    0.32026     NZDCAD    0.26726     AUDCAD    0.30151
# 5      NZDUSD    0.32026     AUDCAD    0.26726     GBPUSD    0.30151
# 6      EURUSD    0.28090     CHFJPY    0.20180     AUDNZD    0.28721
# 7      GBPUSD    0.28000     NZDUSD    0.20000     NZDUSD    0.24232
# 8      AUDUSD    0.24019     CADJPY    0.20000     AUDUSD    0.21212
# 9      AUDCAD    0.20000     AUDJPY    0.13608     EURAUD    0.21212
# 10     NZDJPY    0.16330     AUDNZD    0.13608     GBPCAD    0.21212
# 11     CADCHF    0.16013     CADCHF    0.13363     EURCAD    0.19192
# 12     GBPJPY    0.16013     EURCAD    0.13363     GBPAUD    0.15352
# 13     AUDNZD    0.12157     AUDUSD    0.13363     USDCAD    0.12309
# 14     GBPAUD    0.08058     EURUSD    0.13363     CADCHF    0.12309
# 15     NZDCHF    0.08006     GBPAUD    0.06917     AUDCHF    0.12309
# 16     GBPCAD    0.08006     EURCHF    0.06917     EURUSD    0.12309
# 17     EURCAD    0.08006     NZDJPY    0.06917     EURGBP    0.10050
# 18     EURAUD    0.08006     GBPCAD    0.06727     NZDJPY    0.08206
# 19     CADJPY    0.08006     EURGBP    0.06727     NZDCHF    0.08206
# 20     EURCHF    0.04052     AUDCHF    0.06667     EURCHF    0.03161
# 21     GBPCHF    0.04013     GBPJPY    0.06667     GBPJPY    0.01010
# 22     AUDCHF    0.00000     EURAUD    0.06667     EURNZD    0.01010
# 23     EURNZD    0.00000     USDCAD    0.06667     CADJPY    0.01010
# 24     AUDJPY    0.00000     NZDCHF    0.00000     AUDJPY    0.01010
# 25     USDCAD    0.00000     EURNZD    0.00000     NZDCAD    0.01010
# 26     EURGBP    0.00000     GBPCHF    0.00000     GBPCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.60010     CHFJPY    0.65465  ...     GBPCAD    0.39906
# 1      GBPUSD    0.49099     USDJPY    0.65465  ...     GBPUSD    0.36470
# 2      USDJPY    0.49099     NZDUSD    0.65465  ...     GBPCHF    0.35286
# 3      CHFJPY    0.49099     GBPUSD    0.65465  ...     EURGBP    0.33092
# 4      AUDCAD    0.44444     EURJPY    0.65465  ...     AUDUSD    0.33092
# 5      NZDUSD    0.38889     USDCHF    0.53452  ...     AUDCHF    0.33092
# 6      EURNZD    0.38889     EURUSD    0.53452  ...     GBPJPY    0.33092
# 7      NZDCAD    0.32733     USDCAD    0.53452  ...     EURUSD    0.29758
# 8      AUDUSD    0.32733     EURNZD    0.53452  ...     AUDCAD    0.28365
# 9      EURAUD    0.32733     AUDCAD    0.52381  ...     NZDCAD    0.23684
# 10     GBPAUD    0.28868     NZDCAD    0.52381  ...     EURCHF    0.23153
# 11     USDCHF    0.21822     AUDUSD    0.52381  ...     EURJPY    0.21627
# 12     EURGBP    0.21822     CADJPY    0.42857  ...     NZDUSD    0.16871
# 13     AUDCHF    0.21822     GBPJPY    0.42857  ...     NZDCHF    0.16871
# 14     GBPCHF    0.21822     NZDJPY    0.35635  ...     EURAUD    0.15573
# 15     EURUSD    0.21822     EURAUD    0.35635  ...     CADCHF    0.15573
# 16     NZDJPY    0.16667     AUDJPY    0.21822  ...     AUDJPY    0.14368
# 17     NZDCHF    0.11111     EURGBP    0.21822  ...     CHFJPY    0.14368
# 18     GBPJPY    0.11111     GBPCAD    0.21822  ...     USDJPY    0.13497
# 19     EURCAD    0.11111     AUDCHF    0.21822  ...     NZDJPY    0.13234
# 20     EURCHF    0.11111     CADCHF    0.21822  ...     EURCAD    0.08760
# 21     CADJPY    0.11111     GBPCHF    0.21822  ...     USDCHF    0.07462
# 22     USDCAD    0.11111     EURCAD    0.08909  ...     EURNZD    0.07462
# 23     GBPCAD    0.05455     GBPAUD    0.08909  ...     USDCAD    0.07462
# 24     CADCHF    0.05455     NZDCHF    0.08909  ...     AUDNZD    0.06732
# 25     AUDJPY    0.05455     EURCHF    0.08909  ...     GBPAUD    0.06204
# 26     AUDNZD    0.00000     AUDNZD    0.08909  ...     CADJPY    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.52177     GBPCHF    0.66375     EURGBP    0.66144
# 1      GBPCHF    0.44444     GBPCAD    0.60053     GBPCHF    0.66144
# 2      EURGBP    0.38446     EURGBP    0.52414     GBPCAD    0.47246
# 3      AUDUSD    0.35460     EURNZD    0.45303     USDJPY    0.37796
# 4      NZDCAD    0.32733     NZDCAD    0.38982     AUDCHF    0.37796
# 5      AUDCAD    0.32733     AUDCHF    0.38516     GBPUSD    0.37796
# 6      GBPUSD    0.32733     NZDCHF    0.38516     AUDCAD    0.28868
# 7      GBPJPY    0.27217     NZDUSD    0.31868     NZDUSD    0.28868
# 8      EURAUD    0.27217     EURCHF    0.31868     EURCHF    0.28868
# 9      AUDCHF    0.27217     AUDCAD    0.31449     EURNZD    0.28868
# 10     EURUSD    0.21822     GBPUSD    0.31449     NZDCHF    0.28868
# 11     EURCAD    0.21822     EURCAD    0.24232     GBPJPY    0.28868
# 12     NZDCHF    0.21822     USDJPY    0.24232     EURAUD    0.18898
# 13     EURCHF    0.19767     AUDUSD    0.24232     NZDCAD    0.18898
# 14     CADCHF    0.19094     EURAUD    0.24232     AUDUSD    0.18898
# 15     EURNZD    0.19094     GBPJPY    0.24232     CHFJPY    0.18898
# 16     USDJPY    0.16477     AUDNZD    0.17118     AUDNZD    0.10000
# 17     EURJPY    0.13608     EURUSD    0.17118     GBPAUD    0.10000
# 18     NZDUSD    0.13608     CHFJPY    0.10483     EURJPY    0.09449
# 19     NZDJPY    0.08472     USDCHF    0.10483     CADCHF    0.09449
# 20     GBPAUD    0.08472     CADCHF    0.04280     AUDJPY    0.09449
# 21     USDCHF    0.05455     NZDJPY    0.04280     EURUSD    0.09449
# 22     AUDJPY    0.02778     USDCAD    0.04280     USDCHF    0.09449
# 23     AUDNZD    0.02778     EURJPY    0.03161     EURCAD    0.00000
# 24     CHFJPY    0.02746     CADJPY    0.03161     CADJPY    0.00000
# 25     CADJPY    0.00000     AUDJPY    0.03161     NZDJPY    0.00000
# 26     USDCAD    0.00000     GBPAUD    0.02288     USDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.81650
# 1      GBPCHF    0.81650
# 2      GBPJPY    0.53452
# 3      GBPUSD    0.40825
# 4      USDJPY    0.40825
# 5      NZDUSD    0.40825
# 6      GBPCAD    0.40825
# 7      AUDCHF    0.40825
# 8      NZDCAD    0.35635
# 9      AUDCAD    0.35635
# 10     AUDUSD    0.35635
# 11     EURNZD    0.25000
# 12     USDCHF    0.25000
# 13     NZDCHF    0.25000
# 14     EURCHF    0.25000
# 15     USDCAD    0.25000
# 16     EURUSD    0.25000
# 17     GBPAUD    0.16667
# 18     EURCAD    0.16667
# 19     EURAUD    0.16667
# 20     NZDJPY    0.16667
# 21     AUDNZD    0.16667
# 22     CADJPY    0.08909
# 23     CADCHF    0.00000
# 24     CHFJPY    0.00000
# 25     EURJPY    0.00000
# 26     AUDJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
