# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 11:44:28.879150

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.37888     NZDCAD    0.40825     NZDCAD    0.73380
# 1      EURJPY    0.33561     AUDCAD    0.35460     EURUSD    0.66375
# 2      GBPJPY    0.32718     GBPCHF    0.30556     NZDUSD    0.66375
# 3      CADJPY    0.29778     GBPJPY    0.30556     AUDCAD    0.60053
# 4      NZDUSD    0.25212     EURUSD    0.30208     USDCHF    0.53846
# 5      USDCHF    0.23153     EURNZD    0.25000     EURNZD    0.53846
# 6      AUDCAD    0.22531     CADJPY    0.24716     GBPUSD    0.52414
# 7      NZDCAD    0.21506     AUDCHF    0.21822     EURCAD    0.38982
# 8      CHFJPY    0.21506     NZDUSD    0.21822     GBPJPY    0.38982
# 9      GBPUSD    0.21506     GBPUSD    0.21822     USDJPY    0.31868
# 10     EURCAD    0.16871     EURAUD    0.19767     AUDUSD    0.31868
# 11     GBPCHF    0.16864     EURGBP    0.19094     GBPAUD    0.31868
# 12     AUDUSD    0.15573     NZDCHF    0.16667     EURGBP    0.31449
# 13     GBPAUD    0.14943     EURCAD    0.13608     NZDCHF    0.25678
# 14     AUDJPY    0.14368     GBPAUD    0.11111     GBPCHF    0.25678
# 15     AUDNZD    0.12157     CADCHF    0.08472     EURAUD    0.25163
# 16     NZDJPY    0.11119     CHFJPY    0.08183     AUDCHF    0.24232
# 17     USDCAD    0.10895     USDCHF    0.05648     EURJPY    0.24232
# 18     NZDCHF    0.07357     AUDUSD    0.05648     USDCAD    0.24232
# 19     USDJPY    0.06732     USDJPY    0.05648     CADJPY    0.17911
# 20     EURCHF    0.06204     EURCHF    0.05455     NZDJPY    0.17911
# 21     EURAUD    0.04052     EURJPY    0.02778     AUDJPY    0.17118
# 22     EURNZD    0.04052     NZDJPY    0.02778     CADCHF    0.09890
# 23     AUDCHF    0.02764     AUDJPY    0.02746     GBPCAD    0.06052
# 24     GBPCAD    0.01198     AUDNZD    0.02746     CHFJPY    0.04280
# 25     CADCHF    0.01198     GBPCAD    0.00000     EURCHF    0.03161
# 26     EURGBP    0.00649     USDCAD    0.00000     AUDNZD    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDCAD    0.86603     NZDCAD    0.80178  ...     USDCHF    0.20261
# 1      NZDCAD    0.75593     AUDCAD    0.80178  ...     EURUSD    0.20064
# 2      NZDUSD    0.66144     NZDUSD    0.80178  ...     AUDNZD    0.20000
# 3      EURGBP    0.57735     EURGBP    0.53452  ...     GBPUSD    0.16330
# 4      GBPUSD    0.57735     GBPUSD    0.53452  ...     AUDCAD    0.16116
# 5      EURUSD    0.57735     EURUSD    0.53452  ...     EURCAD    0.16013
# 6      EURNZD    0.50000     AUDUSD    0.53452  ...     GBPCAD    0.12666
# 7      GBPAUD    0.50000     EURNZD    0.53452  ...     NZDCHF    0.12666
# 8      USDCHF    0.50000     GBPAUD    0.53452  ...     USDJPY    0.12157
# 9      AUDUSD    0.50000     AUDNZD    0.50918  ...     NZDJPY    0.08575
# 10     USDJPY    0.42640     EURAUD    0.42857  ...     CADJPY    0.08165
# 11     EURAUD    0.42640     USDJPY    0.42857  ...     AUDJPY    0.08058
# 12     GBPJPY    0.37796     EURCAD    0.35635  ...     EURGBP    0.08006
# 13     EURCAD    0.28868     CHFJPY    0.35635  ...     GBPJPY    0.04364
# 14     AUDCHF    0.28868     GBPJPY    0.35635  ...     CADCHF    0.04222
# 15     CADCHF    0.28868     NZDJPY    0.35635  ...     EURJPY    0.04120
# 16     USDCAD    0.28868     GBPCHF    0.35635  ...     NZDUSD    0.04120
# 17     EURJPY    0.20000     USDCHF    0.32733  ...     GBPCHF    0.04120
# 18     AUDJPY    0.20000     AUDCHF    0.21822  ...     GBPAUD    0.04052
# 19     NZDJPY    0.18898     EURCHF    0.21822  ...     USDCAD    0.04013
# 20     GBPCHF    0.18898     CADJPY    0.21822  ...     AUDCHF    0.04013
# 21     GBPCAD    0.10660     USDCAD    0.21822  ...     EURAUD    0.04000
# 22     NZDCHF    0.10000     NZDCHF    0.21822  ...     EURNZD    0.04000
# 23     CHFJPY    0.09449     EURJPY    0.08909  ...     EURCHF    0.00000
# 24     CADJPY    0.09449     AUDJPY    0.08909  ...     AUDUSD    0.00000
# 25     EURCHF    0.09449     CADCHF    0.08909  ...     NZDCAD    0.00000
# 26     AUDNZD    0.00000     GBPCAD    0.04762  ...     CHFJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDCAD    0.33929     USDCHF    0.48038     NZDUSD    0.46771
# 1      USDCHF    0.29579     EURUSD    0.37284     EURUSD    0.40825
# 2      EURUSD    0.27866     USDCAD    0.37284     USDCAD    0.40825
# 3      EURCAD    0.26726     NZDUSD    0.37284     GBPUSD    0.40825
# 4      GBPUSD    0.20536     AUDCAD    0.28511     USDCHF    0.35355
# 5      NZDUSD    0.20536     EURCAD    0.28511     EURNZD    0.35355
# 6      GBPCAD    0.18898     USDJPY    0.25163     AUDUSD    0.35355
# 7      USDJPY    0.15714     AUDUSD    0.25163     EURJPY    0.35355
# 8      AUDUSD    0.15714     EURNZD    0.25163     GBPAUD    0.35355
# 9      USDCAD    0.13363     GBPAUD    0.25163     AUDJPY    0.35355
# 10     NZDCAD    0.13363     GBPUSD    0.21822     NZDCHF    0.35355
# 11     AUDNZD    0.12585     NZDCAD    0.21822     USDJPY    0.30151
# 12     NZDCHF    0.08183     EURGBP    0.21822     EURAUD    0.30151
# 13     GBPAUD    0.08183     EURAUD    0.19048     GBPCAD    0.30151
# 14     EURJPY    0.08183     EURJPY    0.15352     EURCAD    0.27217
# 15     EURNZD    0.08183     CHFJPY    0.13363     AUDCAD    0.27217
# 16     NZDJPY    0.08183     GBPCAD    0.12599     NZDJPY    0.20045
# 17     AUDCHF    0.07143     NZDCHF    0.08909     NZDCAD    0.20045
# 18     EURCHF    0.07143     AUDJPY    0.08909     CHFJPY    0.20045
# 19     EURGBP    0.07143     GBPCHF    0.08909     AUDNZD    0.16667
# 20     CHFJPY    0.06250     GBPJPY    0.06580     GBPJPY    0.13363
# 21     GBPJPY    0.05455     AUDCHF    0.06580     CADJPY    0.13363
# 22     GBPCHF    0.05455     CADJPY    0.06580     EURCHF    0.13363
# 23     CADCHF    0.01849     NZDJPY    0.06580     GBPCHF    0.13363
# 24     EURAUD    0.01849     EURCHF    0.06580     AUDCHF    0.06804
# 25     CADJPY    0.00899     AUDNZD    0.04762     CADCHF    0.06804
# 26     AUDJPY    0.00899     CADCHF    0.02288     EURGBP    0.06804
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDNZD    0.66667
# 1      NZDUSD    0.61237
# 2      NZDJPY    0.61237
# 3      USDCAD    0.50000
# 4      CADJPY    0.50000
# 5      AUDUSD    0.40825
# 6      EURUSD    0.40825
# 7      GBPCHF    0.40825
# 8      EURJPY    0.40825
# 9      CHFJPY    0.40825
# 10     AUDJPY    0.40825
# 11     EURNZD    0.40825
# 12     GBPUSD    0.40825
# 13     GBPAUD    0.40825
# 14     USDJPY    0.32733
# 15     EURAUD    0.32733
# 16     GBPCAD    0.32733
# 17     USDCHF    0.25000
# 18     NZDCHF    0.25000
# 19     EURCAD    0.10206
# 20     GBPJPY    0.10206
# 21     CADCHF    0.10206
# 22     AUDCAD    0.10206
# 23     NZDCAD    0.10206
# 24     EURGBP    0.10206
# 25     AUDCHF    0.00000
# 26     EURCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
