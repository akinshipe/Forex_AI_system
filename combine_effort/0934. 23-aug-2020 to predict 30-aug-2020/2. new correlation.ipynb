# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:16:34.262576

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.26212     GBPUSD    0.29579     AUDUSD    0.32733
# 1      GBPUSD    0.23028     EURJPY    0.24456     GBPUSD    0.31180
# 2      USDJPY    0.21506     CHFJPY    0.19767     EURCAD    0.28511
# 3      AUDCAD    0.14804     USDJPY    0.17216     AUDNZD    0.25163
# 4      CHFJPY    0.13457     NZDCAD    0.15714     NZDCAD    0.25163
# 5      NZDUSD    0.13074     NZDJPY    0.15714     GBPCHF    0.21822
# 6      USDCHF    0.11580     EURAUD    0.15714     NZDJPY    0.15352
# 7      NZDJPY    0.11580     AUDNZD    0.14833     CADJPY    0.15352
# 8      EURJPY    0.11580     AUDCAD    0.14833     NZDUSD    0.15352
# 9      AUDCHF    0.09869     AUDUSD    0.14833     GBPCAD    0.15352
# 10     USDCAD    0.09869     NZDUSD    0.12016     CADCHF    0.15352
# 11     AUDNZD    0.08333     GBPCHF    0.12016     GBPJPY    0.15352
# 12     CADCHF    0.08165     EURNZD    0.08472     EURGBP    0.13363
# 13     EURCAD    0.08165     EURGBP    0.08472     AUDCAD    0.12599
# 14     GBPCHF    0.06580     GBPJPY    0.06917     EURAUD    0.08909
# 15     AUDUSD    0.06580     GBPCAD    0.06917     EURNZD    0.08909
# 16     EURUSD    0.06580     EURCAD    0.06917     USDCAD    0.08909
# 17     GBPCAD    0.06553     CADCHF    0.06917     GBPAUD    0.06580
# 18     CADJPY    0.06553     CADJPY    0.06917     USDJPY    0.06580
# 19     GBPJPY    0.04903     AUDJPY    0.05648     AUDCHF    0.04762
# 20     EURCHF    0.04903     EURUSD    0.05648     EURJPY    0.04762
# 21     AUDJPY    0.03364     GBPAUD    0.03257     USDCHF    0.04762
# 22     NZDCHF    0.03269     NZDCHF    0.03257     CHFJPY    0.02288
# 23     EURAUD    0.03269     AUDCHF    0.03257     EURCHF    0.02288
# 24     EURNZD    0.01638     EURCHF    0.01849     AUDJPY    0.02288
# 25     GBPAUD    0.00000     USDCAD    0.01849     EURUSD    0.02288
# 26     EURGBP    0.00000     USDCHF    0.00478     NZDCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADCHF    0.36690     AUDCAD    0.50918  ...     GBPCAD    0.43417
# 1      GBPCAD    0.36690     AUDCHF    0.50918  ...     AUDUSD    0.30694
# 2      AUDNZD    0.32026     EURCAD    0.33333  ...     GBPCHF    0.30694
# 3      USDJPY    0.32026     USDJPY    0.33333  ...     AUDCAD    0.30694
# 4      CADJPY    0.32026     NZDUSD    0.33333  ...     EURCAD    0.28365
# 5      EURNZD    0.32026     GBPCAD    0.33333  ...     CADCHF    0.28365
# 6      GBPJPY    0.32026     EURAUD    0.33333  ...     EURCHF    0.24982
# 7      GBPUSD    0.32026     CADCHF    0.33333  ...     USDJPY    0.23153
# 8      AUDJPY    0.27735     GBPUSD    0.27217  ...     AUDCHF    0.22531
# 9      EURGBP    0.27735     EURNZD    0.27217  ...     EURUSD    0.22531
# 10     EURCHF    0.27735     GBPAUD    0.27217  ...     GBPUSD    0.22531
# 11     USDCAD    0.27735     GBPJPY    0.27217  ...     EURGBP    0.20261
# 12     CHFJPY    0.23652     EURGBP    0.27217  ...     NZDCAD    0.19025
# 13     EURUSD    0.23652     NZDCHF    0.27217  ...     GBPJPY    0.15573
# 14     AUDUSD    0.23652     GBPCHF    0.27217  ...     GBPAUD    0.13234
# 15     EURJPY    0.19612     NZDJPY    0.27217  ...     USDCAD    0.10123
# 16     USDCHF    0.19612     NZDCAD    0.27217  ...     EURJPY    0.09688
# 17     AUDCHF    0.13868     CADJPY    0.27217  ...     USDCHF    0.09688
# 18     AUDCAD    0.13868     AUDJPY    0.21822  ...     CHFJPY    0.08181
# 19     EURCAD    0.08006     AUDNZD    0.21822  ...     EURAUD    0.07462
# 20     GBPAUD    0.02621     CHFJPY    0.21822  ...     NZDUSD    0.07462
# 21     EURAUD    0.02621     EURCHF    0.21822  ...     AUDNZD    0.04963
# 22     NZDUSD    0.02621     USDCAD    0.21822  ...     EURNZD    0.02764
# 23     GBPCHF    0.02621     EURJPY    0.16667  ...     CADJPY    0.02764
# 24     NZDCHF    0.02621     AUDUSD    0.16667  ...     NZDJPY    0.01478
# 25     NZDJPY    0.02621     EURUSD    0.16667  ...     NZDCHF    0.00649
# 26     NZDCAD    0.02621     USDCHF    0.11111  ...     AUDJPY    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.43939     USDJPY    0.53340     USDCHF    0.53452
# 1      GBPCAD    0.27217     NZDCHF    0.40825     USDJPY    0.49099
# 2      EURGBP    0.25000     USDCHF    0.35635     NZDCHF    0.46429
# 3      CHFJPY    0.25000     CADCHF    0.32824     EURAUD    0.33929
# 4      AUDCAD    0.22591     EURAUD    0.25000     CADCHF    0.33929
# 5      USDCHF    0.22591     AUDCAD    0.23570     EURNZD    0.32733
# 6      GBPCHF    0.21822     AUDJPY    0.17118     EURCAD    0.32733
# 7      EURCHF    0.19094     CHFJPY    0.17118     CHFJPY    0.26189
# 8      EURJPY    0.14434     EURNZD    0.16667     GBPUSD    0.21822
# 9      CADCHF    0.13608     NZDJPY    0.12309     GBPJPY    0.21822
# 10     EURCAD    0.13608     GBPJPY    0.12309     NZDJPY    0.19643
# 11     AUDJPY    0.11111     GBPCAD    0.12309     GBPCHF    0.19643
# 12     GBPAUD    0.10985     GBPAUD    0.12309     AUDCAD    0.18898
# 13     AUDCHF    0.10985     AUDUSD    0.10206     EURGBP    0.18898
# 14     NZDCHF    0.10985     AUDCHF    0.08909     EURCHF    0.18898
# 15     AUDNZD    0.08472     EURJPY    0.08909     EURJPY    0.13363
# 16     AUDUSD    0.08472     NZDUSD    0.08206     AUDCHF    0.09449
# 17     USDCAD    0.08183     CADJPY    0.08206     AUDJPY    0.09449
# 18     EURAUD    0.08183     EURCAD    0.08206     USDCAD    0.09449
# 19     NZDJPY    0.08183     NZDCAD    0.04280     GBPCAD    0.07143
# 20     NZDUSD    0.08183     AUDNZD    0.04280     GBPAUD    0.07143
# 21     GBPUSD    0.05455     EURCHF    0.04280     NZDUSD    0.07143
# 22     NZDCAD    0.05455     EURUSD    0.04280     NZDCAD    0.07143
# 23     EURNZD    0.02778     GBPUSD    0.04167     CADJPY    0.05455
# 24     EURUSD    0.02778     USDCAD    0.04167     AUDNZD    0.05455
# 25     GBPJPY    0.00000     EURGBP    0.04167     AUDUSD    0.04029
# 26     CADJPY    0.00000     GBPCHF    0.00000     EURUSD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURNZD    0.58333
# 1      NZDCHF    0.58333
# 2      USDCHF    0.40825
# 3      CADCHF    0.40825
# 4      USDJPY    0.40825
# 5      EURAUD    0.40825
# 6      EURCAD    0.40825
# 7      AUDCAD    0.35635
# 8      AUDNZD    0.35635
# 9      EURCHF    0.35635
# 10     GBPUSD    0.25000
# 11     GBPJPY    0.25000
# 12     GBPAUD    0.25000
# 13     EURGBP    0.16667
# 14     NZDCAD    0.16667
# 15     GBPCHF    0.16667
# 16     NZDJPY    0.16667
# 17     CADJPY    0.16667
# 18     EURUSD    0.10206
# 19     EURJPY    0.10206
# 20     AUDUSD    0.10206
# 21     AUDJPY    0.08909
# 22     CHFJPY    0.08909
# 23     USDCAD    0.08909
# 24     AUDCHF    0.08909
# 25     GBPCAD    0.00000
# 26     NZDUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
