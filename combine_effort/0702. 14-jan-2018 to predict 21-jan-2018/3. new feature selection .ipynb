# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['corelation'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 02:18:46.308663

# %%
print('---------------- Script Has Started Execution-----------------------')

currency_pairs = [
                    'USDCHF10080',
                 'GBPUSD10080',
                  'EURUSD10080', 
    'USDJPY10080',
    'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]


# load the corelation data from CSV
correlation_dataframe = pd.read_csv('files/auto-correlation2.csv'  ) 

# declair the variable that will hold all testable units, the week and the needed feature
currency_pair_detail = []
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# loop through all currency pairs
for a in currency_pairs:
    
    current_currency = a.replace('10080','')
    
    
    weeks = [    {'week_name' : 10, 'correlation_cutoff' : 0.632},
                 {'week_name' : 15, 'correlation_cutoff' : 0.514},
                 {'week_name' : 20, 'correlation_cutoff' : 0.444},
                 {'week_name' : 30, 'correlation_cutoff' : 0.361},
                 {'week_name' : 50, 'correlation_cutoff' : 0.279},
            ]
    
   
    #loop throuh all available weeks
    for b in weeks:
        
        needed_column_list = []
        
        #check if the current currency in the current week has any currency above the correlation score of the week
        #this is to avoid running analysis for weeks with no correlation
        if  correlation_dataframe[current_currency + '_' + str(b['week_name'])][0] > b['correlation_cutoff']:
            
            #loop though weeks to get all the currency pairs in the weeks lesser than current week according to my strategy
            for c in weeks:

                if c['week_name'] <= b['week_name']:

                    #gets the needed two needed columns
                    current_needed_columns = correlation_dataframe[[current_currency + '__' + str(c['week_name']), current_currency + '_' + str(c['week_name'])]] 
                    
                    #get the rows that has corelation
                    current_needed_columns = current_needed_columns.loc[ (current_needed_columns[current_currency + '_' + str(c['week_name'])] >= c['correlation_cutoff'])]
                    
                    #converts the currency pairs that passes to list
                    current_needed_columns = current_needed_columns[current_currency + '__' + str(c['week_name'])].values.tolist()
                    
                    #loop through all the currency pairs that passes and append each currency pair to the list if it is not there already
                    for d in current_needed_columns :
                        if d not in needed_column_list:
                            needed_column_list.append(d) 


        #creates a dictionary with the needed info for the currency and week
        current_currency_detail = {'currency_name': current_currency, 'week': b['week_name'], 'needed_features':needed_column_list }
        
        #appends all non empty currency detail to the global list
        if len(current_currency_detail['needed_features']) > 0:
            currency_pair_detail.append(current_currency_detail)
        
       
    
        




print(currency_pair_detail)
# Out:
# [{'currency_name': 'USDCHF', 'week': 10, 'needed_features': ['EURCHF']}, {'currency_name': 'USDCHF', 'week': 15, 'needed_features': ['EURCHF', 'CADCHF']}, {'currency_name': 'USDCHF', 'week': 20, 'needed_features': ['EURCHF', 'CADCHF']}, {'currency_name': 'USDCHF', 'week': 30, 'needed_features': ['EURCHF', 'CADCHF']}, {'currency_name': 'USDCHF', 'week': 50, 'needed_features': ['EURCHF', 'CADCHF', 'USDCHF']}, {'currency_name': 'GBPUSD', 'week': 10, 'needed_features': ['EURUSD', 'AUDUSD']}, {'currency_name': 'GBPUSD', 'week': 15, 'needed_features': ['EURUSD', 'AUDUSD', 'EURGBP']}, {'currency_name': 'GBPUSD', 'week': 20, 'needed_features': ['EURUSD', 'AUDUSD', 'EURGBP', 'GBPCAD']}, {'currency_name': 'GBPUSD', 'week': 30, 'needed_features': ['EURUSD', 'AUDUSD', 'EURGBP', 'GBPCAD']}, {'currency_name': 'GBPUSD', 'week': 50, 'needed_features': ['EURUSD', 'AUDUSD', 'EURGBP', 'GBPCAD', 'GBPJPY']}, {'currency_name': 'EURUSD', 'week': 15, 'needed_features': ['GBPJPY', 'AUDCAD']}, {'currency_name': 'EURUSD', 'week': 20, 'needed_features': ['GBPJPY', 'AUDCAD', 'GBPCAD']}, {'currency_name': 'EURUSD', 'week': 30, 'needed_features': ['GBPJPY', 'AUDCAD', 'GBPCAD', 'GBPAUD']}, {'currency_name': 'USDJPY', 'week': 10, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF']}, {'currency_name': 'USDJPY', 'week': 15, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF', 'EURAUD']}, {'currency_name': 'USDJPY', 'week': 20, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF', 'EURAUD', 'AUDNZD']}, {'currency_name': 'USDJPY', 'week': 30, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF', 'EURAUD', 'AUDNZD']}, {'currency_name': 'USDJPY', 'week': 50, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF', 'EURAUD', 'AUDNZD']}, {'currency_name': 'USDCAD', 'week': 10, 'needed_features': ['EURGBP', 'GBPCHF']}, {'currency_name': 'USDCAD', 'week': 15, 'needed_features': ['EURGBP', 'GBPCHF']}, {'currency_name': 'USDCAD', 'week': 20, 'needed_features': ['EURGBP', 'GBPCHF', 'GBPCAD']}, {'currency_name': 'USDCAD', 'week': 30, 'needed_features': ['EURGBP', 'GBPCHF', 'GBPCAD']}, {'currency_name': 'USDCAD', 'week': 50, 'needed_features': ['EURGBP', 'GBPCHF', 'GBPCAD', 'AUDCAD', 'GBPJPY']}, {'currency_name': 'AUDUSD', 'week': 20, 'needed_features': ['GBPCAD', 'AUDNZD']}, {'currency_name': 'AUDUSD', 'week': 30, 'needed_features': ['GBPCAD', 'AUDNZD', 'EURGBP']}, {'currency_name': 'AUDUSD', 'week': 50, 'needed_features': ['GBPCAD', 'AUDNZD', 'EURGBP']}, {'currency_name': 'NZDUSD', 'week': 50, 'needed_features': ['EURNZD']}, {'currency_name': 'GBPCHF', 'week': 10, 'needed_features': ['EURAUD']}, {'currency_name': 'GBPCHF', 'week': 20, 'needed_features': ['EURAUD']}, {'currency_name': 'GBPCHF', 'week': 30, 'needed_features': ['EURAUD', 'CHFJPY']}, {'currency_name': 'EURCHF', 'week': 10, 'needed_features': ['EURAUD']}, {'currency_name': 'EURCHF', 'week': 15, 'needed_features': ['EURAUD', 'AUDCAD']}, {'currency_name': 'EURCHF', 'week': 20, 'needed_features': ['EURAUD', 'AUDCAD', 'EURCHF']}, {'currency_name': 'EURCHF', 'week': 30, 'needed_features': ['EURAUD', 'AUDCAD', 'EURCHF']}, {'currency_name': 'CHFJPY', 'week': 10, 'needed_features': ['EURGBP', 'GBPCHF']}, {'currency_name': 'CHFJPY', 'week': 15, 'needed_features': ['EURGBP', 'GBPCHF', 'USDJPY', 'USDCHF', 'CADCHF']}, {'currency_name': 'CHFJPY', 'week': 20, 'needed_features': ['EURGBP', 'GBPCHF', 'USDJPY', 'USDCHF', 'CADCHF', 'EURUSD']}, {'currency_name': 'CHFJPY', 'week': 30, 'needed_features': ['EURGBP', 'GBPCHF', 'USDJPY', 'USDCHF', 'CADCHF', 'EURUSD', 'AUDUSD']}, {'currency_name': 'CADCHF', 'week': 10, 'needed_features': ['EURCHF', 'EURAUD']}, {'currency_name': 'CADCHF', 'week': 15, 'needed_features': ['EURCHF', 'EURAUD']}, {'currency_name': 'CADCHF', 'week': 20, 'needed_features': ['EURCHF', 'EURAUD']}, {'currency_name': 'CADCHF', 'week': 30, 'needed_features': ['EURCHF', 'EURAUD', 'AUDCAD', 'AUDCHF', 'CHFJPY']}, {'currency_name': 'CADCHF', 'week': 50, 'needed_features': ['EURCHF', 'EURAUD', 'AUDCAD', 'AUDCHF', 'CHFJPY', 'GBPCHF', 'USDC ...

# %%
for e in currency_pair_detail:
    
    print (e['currency_name'])
    current_currency = e['currency_name']

    raw_data = pd.read_csv('files/' + e['currency_name'] + '.csv'  ) 
    weeks = e['week']

    number_of_accurate_prediction = 0
    number_of_trades = 0


    step_down = 5
    cut_off = 0
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None



    for v in range(step_down):

      


        data = raw_data.copy()
        data = data[v:v+weeks]
        #print(data['date'])


        y = data['nextweek_'+ current_currency]
        
        
        X = data.loc[:, e['needed_features'] ]

       




        X_train = X[1:]
        y_train = y[1:]
        X_test = X[:1]
        y_test = y[:1]




        clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                     max_features=max_features, max_samples = max_samples)

        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)


        y_test = y_test.values




        if y_pred[0] > cut_off  or y_pred[0] < (-1*cut_off) :
            number_of_trades = number_of_trades + 1
            #print(y_pred[0], y_test[0])


            if (y_pred[0] > 0 and y_test[0] == 1) or (y_pred[0] < 0 and y_test[0]) == -1:
                number_of_accurate_prediction = number_of_accurate_prediction +1
                


    e['accuracy_score'] =  100*number_of_accurate_prediction/number_of_trades
    print(e['accuracy_score'])
# Out:
# USDCHF
# 80.0
# USDCHF
# 60.0
# USDCHF
# 80.0
# USDCHF
# 80.0
# USDCHF
# 60.0
# GBPUSD
# 80.0
# GBPUSD
# 80.0
# GBPUSD
# 100.0
# GBPUSD
# 80.0
# GBPUSD
# 80.0
# EURUSD
# 80.0
# EURUSD
# 80.0
# EURUSD
# 80.0
# USDJPY
# 100.0
# USDJPY
# 80.0
# USDJPY
# 80.0
# USDJPY
# 60.0
# USDJPY
# 80.0
# USDCAD
# 80.0
# USDCAD
# 60.0
# USDCAD
# 80.0
# USDCAD
# 80.0
# USDCAD
# 60.0
# AUDUSD
# 80.0
# AUDUSD
# 80.0
# AUDUSD
# 80.0
# NZDUSD
# 40.0
# GBPCHF
# 60.0
# GBPCHF
# 80.0
# GBPCHF
# 40.0
# EURCHF
# 80.0
# EURCHF
# 80.0
# EURCHF
# 60.0
# EURCHF
# 60.0
# CHFJPY
# 80.0
# CHFJPY
# 80.0
# CHFJPY
# 80.0
# CHFJPY
# 100.0
# CADCHF
# 80.0
# CADCHF
# 100.0
# CADCHF
# 100.0
# CADCHF
# 60.0
# CADCHF
# 60.0
# AUDCHF
# 80.0
# AUDCHF
# 80.0
# AUDCHF
# 100.0
# AUDCHF
# 80.0
# NZDCHF
# 60.0
# NZDCHF
# 60.0
# NZDCHF
# 80.0
# NZDCHF
# 60.0
# NZDCHF
# 40.0
# EURGBP
# 100.0
# EURGBP
# 100.0
# EURGBP
# 100.0
# EURGBP
# 40.0
# EURGBP
# 60.0
# GBPJPY
# 100.0
# GBPJPY
# 100.0
# GBPJPY
# 60.0
# GBPJPY
# 40.0
# GBPCAD
# 40.0
# GBPCAD
# 80.0
# EURJPY
# 80.0
# EURJPY
# 60.0
# EURJPY
# 60.0
# EURCAD
# 80.0
# EURCAD
# 40.0
# EURCAD
# 60.0
# EURCAD
# 80.0
# EURAUD
# 100.0
# EURAUD
# 80.0
# EURAUD
# 40.0
# EURNZD
# 60.0
# EURNZD
# 40.0
# EURNZD
# 60.0
# CADJPY
# 100.0
# CADJPY
# 60.0
# CADJPY
# 80.0
# CADJPY
# 80.0
# AUDJPY
# 60.0
# AUDJPY
# 80.0
# AUDJPY
# 60.0
# AUDJPY
# 80.0
# AUDJPY
# 80.0
# NZDJPY
# 80.0
# NZDJPY
# 60.0
# NZDJPY
# 80.0
# AUDCAD
# 60.0
# NZDCAD
# 60.0
# AUDNZD
# 80.0
# AUDNZD
# 60.0
# AUDNZD
# 100.0
# AUDNZD
# 80.0
# AUDNZD
# 60.0

# %%
next_week_trades =[]

for f in currency_pairs:
    
    current_currency = f.replace('10080','')
    current_currency_list =[]
    current_currency_best_trade = None
    
    for g in currency_pair_detail:
        
        
        
        if g['currency_name'] == current_currency:
            
            current_currency_list.append(g)
            
    
    current_currency_list.sort(key=lambda x: x['week'], reverse=False)
    
    for h in current_currency_list:
        
        if h['accuracy_score'] > 99.9:
            
            current_currency_best_trade = h
            
            break
            

    if current_currency_best_trade == None:
       
        for i in current_currency_list:

            if i['accuracy_score'] > 79.9:
                
                current_currency_best_trade = i
                
                break
    
    
    if current_currency_best_trade != None:
        
        next_week_trades.append(current_currency_best_trade)
    
    
        
            
print(next_week_trades)
# Out:
# [{'currency_name': 'USDCHF', 'week': 10, 'needed_features': ['EURCHF'], 'accuracy_score': 80.0}, {'currency_name': 'GBPUSD', 'week': 20, 'needed_features': ['EURUSD', 'AUDUSD', 'EURGBP', 'GBPCAD'], 'accuracy_score': 100.0}, {'currency_name': 'EURUSD', 'week': 15, 'needed_features': ['GBPJPY', 'AUDCAD'], 'accuracy_score': 80.0}, {'currency_name': 'USDJPY', 'week': 10, 'needed_features': ['EURCHF', 'AUDJPY', 'CADCHF'], 'accuracy_score': 100.0}, {'currency_name': 'USDCAD', 'week': 10, 'needed_features': ['EURGBP', 'GBPCHF'], 'accuracy_score': 80.0}, {'currency_name': 'AUDUSD', 'week': 20, 'needed_features': ['GBPCAD', 'AUDNZD'], 'accuracy_score': 80.0}, {'currency_name': 'GBPCHF', 'week': 20, 'needed_features': ['EURAUD'], 'accuracy_score': 80.0}, {'currency_name': 'EURCHF', 'week': 10, 'needed_features': ['EURAUD'], 'accuracy_score': 80.0}, {'currency_name': 'CHFJPY', 'week': 30, 'needed_features': ['EURGBP', 'GBPCHF', 'USDJPY', 'USDCHF', 'CADCHF', 'EURUSD', 'AUDUSD'], 'accuracy_score': 100.0}, {'currency_name': 'CADCHF', 'week': 15, 'needed_features': ['EURCHF', 'EURAUD'], 'accuracy_score': 100.0}, {'currency_name': 'AUDCHF', 'week': 30, 'needed_features': ['NZDCAD', 'EURJPY', 'GBPCHF'], 'accuracy_score': 100.0}, {'currency_name': 'NZDCHF', 'week': 20, 'needed_features': ['EURUSD', 'EURCHF', 'USDCAD'], 'accuracy_score': 80.0}, {'currency_name': 'EURGBP', 'week': 10, 'needed_features': ['CADCHF', 'NZDCHF'], 'accuracy_score': 100.0}, {'currency_name': 'GBPJPY', 'week': 10, 'needed_features': ['EURGBP', 'CADCHF', 'USDCHF'], 'accuracy_score': 100.0}, {'currency_name': 'GBPCAD', 'week': 50, 'needed_features': ['NZDCHF', 'AUDJPY'], 'accuracy_score': 80.0}, {'currency_name': 'EURJPY', 'week': 10, 'needed_features': ['EURGBP', 'GBPCHF'], 'accuracy_score': 80.0}, {'currency_name': 'EURCAD', 'week': 10, 'needed_features': ['EURGBP', 'AUDJPY'], 'accuracy_score': 80.0}, {'currency_name': 'EURAUD', 'week': 20, 'needed_features': ['EURNZD'], 'accuracy_score': 100.0}, {'currency_name': 'CADJPY', 'week': 10, 'needed_features': ['EURGBP', 'AUDJPY'], 'accuracy_score': 100.0}, {'currency_name': 'AUDJPY', 'week': 15, 'needed_features': ['EURGBP', 'CADJPY', 'EURCAD', 'GBPCHF', 'NZDCAD'], 'accuracy_score': 80.0}, {'currency_name': 'NZDJPY', 'week': 15, 'needed_features': ['GBPCHF'], 'accuracy_score': 80.0}, {'currency_name': 'AUDNZD', 'week': 20, 'needed_features': ['AUDUSD', 'USDCHF', 'NZDUSD'], 'accuracy_score': 100.0}]

# %%
# creating a dataframe for nextweek trades and saving it in csv

name =[]
week = []
needed_features = []
accuracy =[]

for j in next_week_trades:
    
    name.append(j['currency_name'])
    week.append(j['week'])
    needed_features.append(j['needed_features'])
    accuracy.append(j['accuracy_score'])
    
    
next_week_trades_dataframe = pd.DataFrame()
next_week_trades_dataframe['names']=name
next_week_trades_dataframe['week'] =week
next_week_trades_dataframe['needed_features'] = needed_features
next_week_trades_dataframe['accuracy']=accuracy


print(next_week_trades_dataframe)

next_week_trades_dataframe.to_csv("files/next_week_trades.csv")
# Out:
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                           [EURCHF]      80.0
# 1   GBPUSD    20                   [EURUSD, AUDUSD, EURGBP, GBPCAD]     100.0
# 2   EURUSD    15                                   [GBPJPY, AUDCAD]      80.0
# 3   USDJPY    10                           [EURCHF, AUDJPY, CADCHF]     100.0
# 4   USDCAD    10                                   [EURGBP, GBPCHF]      80.0
# 5   AUDUSD    20                                   [GBPCAD, AUDNZD]      80.0
# 6   GBPCHF    20                                           [EURAUD]      80.0
# 7   EURCHF    10                                           [EURAUD]      80.0
# 8   CHFJPY    30  [EURGBP, GBPCHF, USDJPY, USDCHF, CADCHF, EURUS...     100.0
# 9   CADCHF    15                                   [EURCHF, EURAUD]     100.0
# 10  AUDCHF    30                           [NZDCAD, EURJPY, GBPCHF]     100.0
# 11  NZDCHF    20                           [EURUSD, EURCHF, USDCAD]      80.0
# 12  EURGBP    10                                   [CADCHF, NZDCHF]     100.0
# 13  GBPJPY    10                           [EURGBP, CADCHF, USDCHF]     100.0
# 14  GBPCAD    50                                   [NZDCHF, AUDJPY]      80.0
# 15  EURJPY    10                                   [EURGBP, GBPCHF]      80.0
# 16  EURCAD    10                                   [EURGBP, AUDJPY]      80.0
# 17  EURAUD    20                                           [EURNZD]     100.0
# 18  CADJPY    10                                   [EURGBP, AUDJPY]     100.0
# 19  AUDJPY    15           [EURGBP, CADJPY, EURCAD, GBPCHF, NZDCAD]      80.0
# 20  NZDJPY    15                                           [GBPCHF]      80.0
# 21  AUDNZD    20                           [AUDUSD, USDCHF, NZDUSD]     100.0

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['feature'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        0           0
