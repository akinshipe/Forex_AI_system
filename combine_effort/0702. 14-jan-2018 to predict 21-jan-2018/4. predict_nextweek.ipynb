# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 03:11:44.995123
# 2021-12-10 03:11:45.002097
# 2021-12-10 03:12:45.014212
# 2021-12-10 03:13:45.022041
# 2021-12-10 03:14:45.029664
# 2021-12-10 03:15:45.054655
# 2021-12-10 03:16:45.059888
# 2021-12-10 03:17:45.086499
# 2021-12-10 03:18:45.111158
# 2021-12-10 03:19:45.119519
# 2021-12-10 03:20:45.127283
# 2021-12-10 03:21:45.149065
# 2021-12-10 03:22:45.166529
# 2021-12-10 03:23:45.178176
# 2021-12-10 03:24:45.203306
# 2021-12-10 03:25:45.220714
# 2021-12-10 03:26:45.230983
# 2021-12-10 03:27:45.256419
# 2021-12-10 03:28:45.262575
# 2021-12-10 03:29:45.281060
# 2021-12-10 03:30:45.294813
# 2021-12-10 03:31:45.320633
# 2021-12-10 03:32:45.323948
# 2021-12-10 03:33:45.328364
# 2021-12-10 03:34:45.336690
# 2021-12-10 03:35:45.348725
# 2021-12-10 03:36:45.371263
# 2021-12-10 03:37:45.397416
# 2021-12-10 03:38:45.405638
# 2021-12-10 03:39:45.412842
# 2021-12-10 03:40:45.430604
# 2021-12-10 03:41:45.458508
# 2021-12-10 03:42:45.473076
# 2021-12-10 03:43:45.484576
# 2021-12-10 03:44:45.500546
# 2021-12-10 03:45:45.521233
# 2021-12-10 03:46:45.524453
# 2021-12-10 03:47:45.537920
# 2021-12-10 03:48:45.544580
# 2021-12-10 03:49:45.567040
# 2021-12-10 03:50:45.585957
# 2021-12-10 03:51:45.602788
# 2021-12-10 03:52:45.611645
# 2021-12-10 03:53:45.619690
# 2021-12-10 03:54:45.641757
# 2021-12-10 03:55:45.661913
# 2021-12-10 03:56:45.668909
# 2021-12-10 03:57:45.682421
# 2021-12-10 03:58:45.698766
# 2021-12-10 03:59:45.712826
# 2021-12-10 04:00:45.728541
# 2021-12-10 04:01:45.745004
# 2021-12-10 04:02:45.748041
# 2021-12-10 04:03:45.774624
# 2021-12-10 04:04:45.801998
# 2021-12-10 04:05:45.814369
# 2021-12-10 04:06:45.839320
# 2021-12-10 04:07:45.842228
# 2021-12-10 04:08:45.863879
# 2021-12-10 04:09:45.892499
# 2021-12-10 04:10:45.919352
# 2021-12-10 04:11:45.943878
# 2021-12-10 05:45:47.290873
# 2021-12-10 05:46:47.305980
# 2021-12-10 05:47:47.330756
# 2021-12-10 05:48:47.352019
# 2021-12-10 05:49:47.371314
# 2021-12-10 05:50:47.393874
# 2021-12-10 05:51:47.401972
# 2021-12-10 05:52:47.420322
# 2021-12-10 05:53:47.423861
# 2021-12-10 05:54:47.435492
# 2021-12-10 05:55:47.451384
# 2021-12-10 05:56:47.466979
# 2021-12-10 05:57:47.479009
# 2021-12-10 05:58:47.486738
# 2021-12-10 05:59:47.510483
# 2021-12-10 06:00:47.528582
# 2021-12-10 06:01:47.534017
# 2021-12-10 06:02:47.541676
# 2021-12-10 06:03:47.563979

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 10 [0.29971603]
# GBPUSD 20 [0.35160821]
# EURUSD 15 [-0.98315627]
# USDJPY 10 [0.9888]
# USDCAD 10 [0.99369952]
# AUDUSD 20 [0.43584418]
# GBPCHF 20 [0.99975]
# EURCHF 10 [0.99193]
# CHFJPY 30 [0.77872679]
# CADCHF 15 [0.98175333]
# AUDCHF 30 [0.89997073]
# NZDCHF 20 [0.47752072]
# EURGBP 10 [0.52252187]
# GBPJPY 10 [0.4984]
# GBPCAD 50 [-0.28660455]
# EURJPY 10 [-0.99476357]
# EURCAD 10 [0.7883]
# EURAUD 20 [0.79694053]
# CADJPY 10 [-0.7991]
# AUDJPY 15 [0.8443]
# NZDJPY 15 [-0.19782746]
# AUDNZD 20 [0.49777886]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'B']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
