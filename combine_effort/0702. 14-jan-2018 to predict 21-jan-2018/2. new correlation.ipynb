# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:11:42.084384

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDCHF    0.36876     EURCHF    0.38052     EURCHF    0.57907
# 1      EURCHF    0.35588     EURGBP    0.32127     EURGBP    0.40825
# 2      CADCHF    0.32450     CADCHF    0.27866     CADCHF    0.32824
# 3      NZDCHF    0.25223     GBPAUD    0.22172     EURUSD    0.28721
# 4      USDJPY    0.23282     NZDCHF    0.22172     EURAUD    0.25678
# 5      EURUSD    0.20773     USDCHF    0.22172     GBPAUD    0.25000
# 6      GBPAUD    0.20773     CHFJPY    0.20180     GBPCAD    0.25000
# 7      EURCAD    0.19485     USDJPY    0.18552     AUDUSD    0.20412
# 8      EURNZD    0.17138     GBPJPY    0.16477     CADJPY    0.20412
# 9      GBPCAD    0.16386     GBPUSD    0.14382     EURNZD    0.20412
# 10     GBPCHF    0.15743     CADJPY    0.14382     CHFJPY    0.20412
# 11     CHFJPY    0.15743     GBPCAD    0.12585     GBPJPY    0.17118
# 12     AUDCHF    0.13497     NZDCAD    0.10702     NZDCAD    0.17118
# 13     GBPUSD    0.12721     AUDCAD    0.10702     AUDCAD    0.17118
# 14     GBPJPY    0.12721     EURJPY    0.10702     AUDNZD    0.17118
# 15     NZDUSD    0.09054     EURAUD    0.09513     NZDCHF    0.12309
# 16     EURJPY    0.05366     AUDJPY    0.08597     AUDCHF    0.12309
# 17     AUDNZD    0.04013     USDCAD    0.08597     AUDJPY    0.12309
# 18     CADJPY    0.03382     AUDCHF    0.08597     USDCHF    0.12309
# 19     EURGBP    0.03382     GBPCHF    0.08597     GBPCHF    0.08909
# 20     NZDCAD    0.02150     EURNZD    0.08597     NZDJPY    0.08206
# 21     EURAUD    0.01638     EURCAD    0.06727     USDJPY    0.08206
# 22     AUDCAD    0.01638     NZDJPY    0.04977     NZDUSD    0.04280
# 23     AUDUSD    0.00970     NZDUSD    0.02746     GBPUSD    0.04167
# 24     USDCAD    0.00321     EURUSD    0.02746     EURJPY    0.04167
# 25     AUDJPY    0.00321     AUDUSD    0.00899     EURCAD    0.00000
# 26     NZDJPY    0.00321     AUDNZD    0.00899     USDCAD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADCHF    0.57735     EURCHF    0.76376  ...     GBPCHF    0.36218
# 1      EURCHF    0.53300     EURAUD    0.61237  ...     USDCHF    0.31807
# 2      EURAUD    0.40000     EURCAD    0.50000  ...     EURNZD    0.27743
# 3      AUDJPY    0.37796     CADJPY    0.50000  ...     NZDCAD    0.25732
# 4      EURGBP    0.28868     CHFJPY    0.50000  ...     EURCHF    0.24418
# 5      EURUSD    0.28868     EURJPY    0.40825  ...     EURGBP    0.23775
# 6      EURJPY    0.28868     AUDJPY    0.40825  ...     USDJPY    0.20646
# 7      GBPJPY    0.28868     NZDCHF    0.40825  ...     CADCHF    0.19872
# 8      NZDCAD    0.20000     CADCHF    0.40825  ...     EURCAD    0.16386
# 9      GBPCHF    0.20000     AUDCAD    0.40825  ...     AUDNZD    0.16013
# 10     CHFJPY    0.18898     USDCAD    0.40825  ...     EURUSD    0.15743
# 11     AUDUSD    0.18898     NZDCAD    0.40825  ...     AUDCHF    0.15573
# 12     EURNZD    0.18898     AUDCHF    0.32733  ...     AUDCAD    0.13074
# 13     CADJPY    0.18898     GBPJPY    0.32733  ...     AUDUSD    0.12581
# 14     NZDUSD    0.10000     NZDJPY    0.32733  ...     NZDJPY    0.12179
# 15     NZDCHF    0.09449     NZDUSD    0.25000  ...     GBPCAD    0.11859
# 16     GBPCAD    0.09449     GBPUSD    0.25000  ...     NZDCHF    0.11613
# 17     USDCAD    0.09449     USDCHF    0.25000  ...     EURAUD    0.11440
# 18     EURCAD    0.09449     AUDUSD    0.21822  ...     GBPJPY    0.08353
# 19     USDJPY    0.09449     EURUSD    0.21822  ...     GBPUSD    0.08353
# 20     AUDCAD    0.00000     EURGBP    0.10206  ...     CADJPY    0.07711
# 21     NZDJPY    0.00000     EURNZD    0.10206  ...     USDCAD    0.04167
# 22     USDCHF    0.00000     GBPAUD    0.10206  ...     AUDJPY    0.04167
# 23     GBPAUD    0.00000     GBPCAD    0.10206  ...     CHFJPY    0.03846
# 24     GBPUSD    0.00000     GBPCHF    0.10206  ...     NZDUSD    0.03548
# 25     AUDCHF    0.00000     USDJPY    0.10206  ...     EURJPY    0.00649
# 26     AUDNZD    0.00000     AUDNZD    0.10206  ...     GBPAUD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.47087     USDCHF    0.66375     AUDUSD    0.76376
# 1      USDCHF    0.33634     AUDUSD    0.52414     USDCHF    0.66667
# 2      EURNZD    0.33634     USDJPY    0.38982     NZDUSD    0.57735
# 3      EURGBP    0.33634     NZDUSD    0.31868     USDJPY    0.49099
# 4      EURCHF    0.28284     EURNZD    0.31449     GBPAUD    0.44444
# 5      GBPJPY    0.27217     GBPAUD    0.25678     EURUSD    0.38889
# 6      CADCHF    0.26726     CADCHF    0.24232     GBPUSD    0.38889
# 7      AUDUSD    0.26726     EURUSD    0.24232     NZDCAD    0.28868
# 8      NZDCAD    0.20751     GBPCHF    0.20588     EURAUD    0.28868
# 9      USDJPY    0.20180     EURCHF    0.20588     USDCAD    0.21822
# 10     AUDCHF    0.20180     GBPUSD    0.17118     CHFJPY    0.21822
# 11     GBPAUD    0.20180     NZDCAD    0.12088     AUDJPY    0.21822
# 12     EURCAD    0.20000     AUDCAD    0.12088     EURNZD    0.21822
# 13     EURUSD    0.13608     GBPJPY    0.12088     AUDCAD    0.16667
# 14     GBPCAD    0.13363     EURAUD    0.12088     AUDCHF    0.16667
# 15     GBPUSD    0.13363     EURCAD    0.10483     EURCHF    0.12309
# 16     CADJPY    0.13363     CADJPY    0.10483     NZDJPY    0.11111
# 17     EURJPY    0.06917     EURGBP    0.10483     EURGBP    0.11111
# 18     AUDCAD    0.06917     CHFJPY    0.10483     EURJPY    0.11111
# 19     AUDJPY    0.06727     USDCAD    0.10483     GBPJPY    0.11111
# 20     NZDJPY    0.06727     AUDNZD    0.09890     CADCHF    0.11111
# 21     USDCAD    0.06727     EURJPY    0.04280     AUDNZD    0.11111
# 22     NZDCHF    0.06727     GBPCAD    0.04280     EURCAD    0.05455
# 23     CHFJPY    0.06667     NZDCHF    0.03161     GBPCAD    0.05455
# 24     EURAUD    0.00000     AUDCHF    0.03161     CADJPY    0.05455
# 25     NZDUSD    0.00000     AUDJPY    0.03161     NZDCHF    0.05455
# 26     AUDNZD    0.00000     NZDJPY    0.03161     GBPCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDUSD    0.65465
# 1      USDCHF    0.50000
# 2      NZDUSD    0.50000
# 3      EURNZD    0.40825
# 4      GBPAUD    0.40825
# 5      GBPCAD    0.40825
# 6      EURGBP    0.40825
# 7      USDJPY    0.40825
# 8      EURUSD    0.21822
# 9      AUDCHF    0.21822
# 10     NZDJPY    0.21822
# 11     GBPJPY    0.21822
# 12     EURCHF    0.21822
# 13     CHFJPY    0.20000
# 14     EURCAD    0.20000
# 15     CADJPY    0.20000
# 16     GBPCHF    0.00000
# 17     NZDCAD    0.00000
# 18     AUDCAD    0.00000
# 19     AUDJPY    0.00000
# 20     EURJPY    0.00000
# 21     EURAUD    0.00000
# 22     USDCAD    0.00000
# 23     GBPUSD    0.00000
# 24     NZDCHF    0.00000
# 25     CADCHF    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
