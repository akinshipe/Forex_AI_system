# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 19:15:11.886249

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.23028     NZDUSD    0.27217     USDCHF    0.38516
# 1      CADCHF    0.21506     USDCHF    0.25000     GBPCAD    0.34066
# 2      AUDCHF    0.18094     EURCHF    0.25000     AUDCHF    0.31868
# 3      USDCHF    0.16667     GBPUSD    0.21822     EURAUD    0.31868
# 4      EURUSD    0.16667     AUDUSD    0.21822     AUDNZD    0.31449
# 5      NZDCAD    0.16330     GBPJPY    0.21822     NZDCAD    0.24232
# 6      GBPAUD    0.13074     NZDCAD    0.19094     NZDCHF    0.24232
# 7      AUDUSD    0.11440     NZDJPY    0.19094     EURNZD    0.24232
# 8      NZDJPY    0.11440     EURJPY    0.19094     NZDUSD    0.24232
# 9      GBPCHF    0.11440     AUDNZD    0.19094     EURUSD    0.24232
# 10     EURAUD    0.09829     GBPCHF    0.19094     NZDJPY    0.17911
# 11     AUDCAD    0.08333     NZDCHF    0.13608     CADCHF    0.17911
# 12     GBPCAD    0.08165     GBPAUD    0.13608     AUDUSD    0.17118
# 13     EURGBP    0.08165     AUDCAD    0.11111     EURCHF    0.17118
# 14     GBPUSD    0.08165     AUDCHF    0.11111     AUDJPY    0.17118
# 15     AUDJPY    0.06580     AUDJPY    0.11111     USDCAD    0.12088
# 16     EURJPY    0.06553     CADCHF    0.10985     EURCAD    0.10483
# 17     CHFJPY    0.05046     USDCAD    0.10985     CADJPY    0.10483
# 18     USDJPY    0.03309     CADJPY    0.08183     EURGBP    0.10483
# 19     EURNZD    0.03269     CHFJPY    0.05648     EURJPY    0.10483
# 20     AUDNZD    0.03269     EURCAD    0.05455     GBPCHF    0.10483
# 21     EURCAD    0.01645     GBPCAD    0.02778     GBPJPY    0.04280
# 22     CADJPY    0.01645     EURAUD    0.02746     CHFJPY    0.04280
# 23     EURCHF    0.01638     USDJPY    0.02746     USDJPY    0.03161
# 24     USDCAD    0.01638     EURUSD    0.02746     GBPUSD    0.03161
# 25     NZDCHF    0.00000     EURNZD    0.00000     AUDCAD    0.03161
# 26     NZDUSD    0.00000     EURGBP    0.00000     GBPAUD    0.03161
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.49099     USDCHF    0.66667  ...     EURNZD    0.23775
# 1      EURAUD    0.49099     EURUSD    0.58333  ...     USDCAD    0.20773
# 2      GBPCAD    0.44444     GBPCHF    0.53452  ...     CADCHF    0.19025
# 3      AUDNZD    0.44444     EURCHF    0.53452  ...     AUDCHF    0.15198
# 4      EURCHF    0.38889     EURAUD    0.40825  ...     EURGBP    0.12039
# 5      AUDCHF    0.38889     GBPCAD    0.35635  ...     NZDUSD    0.12039
# 6      EURNZD    0.32733     AUDNZD    0.35635  ...     NZDCHF    0.12039
# 7      NZDUSD    0.32733     AUDCAD    0.25000  ...     EURUSD    0.09829
# 8      GBPCHF    0.32733     NZDJPY    0.25000  ...     EURCAD    0.09054
# 9      NZDCAD    0.32733     AUDCHF    0.25000  ...     GBPCHF    0.08353
# 10     NZDCHF    0.32733     EURCAD    0.25000  ...     GBPAUD    0.07711
# 11     EURUSD    0.32733     EURJPY    0.16667  ...     AUDNZD    0.07711
# 12     CHFJPY    0.28868     USDCAD    0.16667  ...     CADJPY    0.07114
# 13     EURGBP    0.21822     AUDJPY    0.16667  ...     AUDJPY    0.07114
# 14     AUDUSD    0.21822     AUDUSD    0.16667  ...     AUDCAD    0.06553
# 15     NZDJPY    0.16667     EURGBP    0.16667  ...     CHFJPY    0.06118
# 16     GBPAUD    0.16667     CHFJPY    0.16667  ...     USDJPY    0.05366
# 17     AUDJPY    0.11111     GBPAUD    0.08909  ...     GBPUSD    0.04013
# 18     CADJPY    0.11111     GBPUSD    0.08909  ...     GBPCAD    0.04013
# 19     AUDCAD    0.05455     CADJPY    0.08909  ...     NZDCAD    0.04013
# 20     USDCAD    0.05455     CADCHF    0.08909  ...     EURCHF    0.03382
# 21     EURCAD    0.05455     GBPJPY    0.00000  ...     EURJPY    0.03382
# 22     EURJPY    0.05455     USDJPY    0.00000  ...     EURAUD    0.03382
# 23     GBPUSD    0.05455     EURNZD    0.00000  ...     USDCHF    0.01638
# 24     CADCHF    0.05455     NZDCHF    0.00000  ...     GBPJPY    0.00970
# 25     USDJPY    0.05455     NZDCAD    0.00000  ...     AUDUSD    0.00321
# 26     GBPJPY    0.00000     NZDUSD    0.00000  ...     NZDJPY    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.41349     USDCAD    0.66375     EURUSD    0.75593
# 1      EURUSD    0.27866     EURUSD    0.61616     USDJPY    0.66144
# 2      USDJPY    0.27866     USDJPY    0.41414     USDCAD    0.66144
# 3      EURNZD    0.26726     USDCHF    0.32824     AUDUSD    0.47246
# 4      USDCHF    0.21822     GBPCHF    0.30151     USDCHF    0.37796
# 5      EURCAD    0.20536     AUDUSD    0.28721     NZDCHF    0.37796
# 6      GBPAUD    0.13363     EURCHF    0.28721     NZDUSD    0.37796
# 7      NZDCHF    0.13363     EURAUD    0.24232     GBPCHF    0.37796
# 8      CADCHF    0.12585     GBPAUD    0.21212     NZDCAD    0.37796
# 9      GBPCAD    0.08183     NZDJPY    0.21212     EURNZD    0.37796
# 10     AUDCAD    0.08183     GBPUSD    0.21212     GBPUSD    0.37796
# 11     NZDCAD    0.07143     NZDCHF    0.19192     NZDJPY    0.28868
# 12     NZDJPY    0.07143     EURNZD    0.19192     AUDNZD    0.28868
# 13     AUDNZD    0.07143     NZDCAD    0.19192     EURCHF    0.28868
# 14     GBPCHF    0.07143     CADCHF    0.19192     GBPJPY    0.20000
# 15     GBPJPY    0.06250     NZDUSD    0.19192     CHFJPY    0.20000
# 16     GBPUSD    0.06250     GBPJPY    0.12309     CADCHF    0.18898
# 17     EURJPY    0.06250     CHFJPY    0.12309     EURGBP    0.18898
# 18     CADJPY    0.06250     CADJPY    0.10050     EURJPY    0.09449
# 19     AUDUSD    0.06250     EURGBP    0.10050     EURCAD    0.09449
# 20     AUDCHF    0.05455     EURCAD    0.10050     EURAUD    0.09449
# 21     EURCHF    0.05455     EURJPY    0.10050     AUDCAD    0.09449
# 22     AUDJPY    0.05455     AUDNZD    0.10050     AUDCHF    0.00000
# 23     CHFJPY    0.01849     AUDJPY    0.08206     GBPCAD    0.00000
# 24     EURAUD    0.00899     GBPCAD    0.03161     GBPAUD    0.00000
# 25     NZDUSD    0.00000     AUDCHF    0.03161     CADJPY    0.00000
# 26     EURGBP    0.00000     AUDCAD    0.01010     AUDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURUSD    0.61237
# 1      USDCAD    0.61237
# 2      AUDUSD    0.61237
# 3      NZDCHF    0.50000
# 4      USDJPY    0.50000
# 5      NZDUSD    0.50000
# 6      NZDCAD    0.50000
# 7      EURNZD    0.50000
# 8      USDCHF    0.40825
# 9      AUDCAD    0.40825
# 10     NZDJPY    0.40825
# 11     EURGBP    0.40825
# 12     GBPCAD    0.32733
# 13     GBPAUD    0.32733
# 14     AUDNZD    0.32733
# 15     GBPUSD    0.21822
# 16     CADCHF    0.21822
# 17     CADJPY    0.21822
# 18     EURCHF    0.21822
# 19     GBPCHF    0.21822
# 20     AUDCHF    0.10206
# 21     EURJPY    0.10206
# 22     EURCAD    0.10206
# 23     AUDJPY    0.10206
# 24     CHFJPY    0.10206
# 25     GBPJPY    0.00000
# 26     EURAUD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
