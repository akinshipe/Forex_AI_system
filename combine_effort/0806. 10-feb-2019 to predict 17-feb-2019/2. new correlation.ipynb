# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 13:49:00.204088

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.22653     GBPUSD    0.34586     USDCHF    0.31868
# 1      CADCHF    0.21914     GBPJPY    0.25882     CADCHF    0.17911
# 2      AUDCHF    0.21914     EURCHF    0.24661     GBPUSD    0.17911
# 3      GBPAUD    0.20602     EURJPY    0.22591     AUDNZD    0.17911
# 4      EURUSD    0.13457     GBPAUD    0.20751     EURUSD    0.17118
# 5      EURGBP    0.12361     USDCHF    0.19767     GBPCAD    0.12088
# 6      GBPCAD    0.12361     GBPCHF    0.17216     USDJPY    0.10483
# 7      GBPUSD    0.12361     NZDUSD    0.15714     EURCAD    0.10483
# 8      GBPCHF    0.10417     AUDUSD    0.15714     GBPAUD    0.10483
# 9      USDCHF    0.10357     AUDJPY    0.15714     AUDCAD    0.10483
# 10     NZDCAD    0.09237     AUDCAD    0.14833     NZDCAD    0.10483
# 11     CHFJPY    0.08181     CADCHF    0.12016     CHFJPY    0.10483
# 12     NZDJPY    0.07258     EURNZD    0.12016     GBPCHF    0.10483
# 13     AUDUSD    0.07258     NZDJPY    0.12016     NZDUSD    0.10483
# 14     EURNZD    0.07258     NZDCAD    0.12016     AUDCHF    0.09890
# 15     EURAUD    0.06118     GBPCAD    0.10702     EURCHF    0.09890
# 16     AUDJPY    0.06118     EURCAD    0.06917     EURAUD    0.09890
# 17     EURJPY    0.05313     CADJPY    0.06917     GBPJPY    0.04280
# 18     EURCHF    0.05313     EURGBP    0.06917     EURJPY    0.04280
# 19     NZDCHF    0.04120     NZDCHF    0.06917     AUDJPY    0.03161
# 20     NZDUSD    0.04120     USDJPY    0.06917     NZDJPY    0.03161
# 21     USDCAD    0.02988     AUDNZD    0.06917     EURGBP    0.03161
# 22     USDJPY    0.02988     AUDCHF    0.05648     CADJPY    0.03161
# 23     EURCAD    0.02150     CHFJPY    0.05648     EURNZD    0.03161
# 24     CADJPY    0.02150     EURAUD    0.03257     AUDUSD    0.03161
# 25     AUDNZD    0.00990     USDCAD    0.03257     NZDCHF    0.03161
# 26     AUDCAD    0.00167     EURUSD    0.03257     USDCAD    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.38889     GBPCHF    0.65465  ...     EURNZD    0.19872
# 1      EURAUD    0.38889     USDCHF    0.53452  ...     EURCAD    0.16386
# 2      AUDNZD    0.32733     GBPUSD    0.53452  ...     NZDUSD    0.16013
# 3      GBPCAD    0.28868     AUDCAD    0.53452  ...     EURUSD    0.13074
# 4      CHFJPY    0.28868     NZDJPY    0.42857  ...     USDJPY    0.12581
# 5      AUDCHF    0.28868     EURCHF    0.42857  ...     USDCAD    0.12581
# 6      NZDUSD    0.21822     GBPAUD    0.42857  ...     EURJPY    0.11613
# 7      CADCHF    0.21822     EURUSD    0.35635  ...     CADCHF    0.11613
# 8      EURNZD    0.21822     CHFJPY    0.35635  ...     AUDCHF    0.11613
# 9      NZDCHF    0.21822     AUDJPY    0.21822  ...     CHFJPY    0.08760
# 10     NZDCAD    0.21822     EURAUD    0.21822  ...     GBPJPY    0.08353
# 11     EURCAD    0.21822     EURCAD    0.21822  ...     EURGBP    0.08006
# 12     EURUSD    0.21822     EURGBP    0.21822  ...     GBPAUD    0.08006
# 13     GBPCHF    0.16667     AUDUSD    0.21822  ...     NZDCHF    0.08006
# 14     EURCHF    0.11111     NZDCHF    0.08909  ...     AUDCAD    0.07462
# 15     AUDUSD    0.11111     AUDCHF    0.08909  ...     NZDCAD    0.04167
# 16     AUDJPY    0.11111     EURJPY    0.08909  ...     NZDJPY    0.03846
# 17     AUDCAD    0.05455     CADCHF    0.08909  ...     AUDNZD    0.03846
# 18     NZDJPY    0.05455     NZDUSD    0.08909  ...     AUDUSD    0.03846
# 19     CADJPY    0.05455     EURNZD    0.08909  ...     EURCHF    0.03548
# 20     USDJPY    0.05455     CADJPY    0.08909  ...     USDCHF    0.00990
# 21     EURJPY    0.05455     USDCAD    0.08909  ...     EURAUD    0.00321
# 22     GBPAUD    0.05455     USDJPY    0.08909  ...     CADJPY    0.00321
# 23     GBPUSD    0.05455     NZDCAD    0.08909  ...     AUDJPY    0.00321
# 24     EURGBP    0.05455     GBPJPY    0.04762  ...     GBPCHF    0.00321
# 25     USDCAD    0.00000     GBPCAD    0.04762  ...     GBPCAD    0.00000
# 26     GBPJPY    0.00000     AUDNZD    0.04762  ...     GBPUSD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.33634     USDCAD    0.65465     EURUSD    0.87500
# 1      USDJPY    0.33333     EURUSD    0.61237     USDJPY    0.87500
# 2      EURNZD    0.26726     USDJPY    0.40000     USDCAD    0.66144
# 3      EURUSD    0.20180     USDCHF    0.31449     USDCHF    0.49099
# 4      EURCAD    0.20000     EURCHF    0.31449     CHFJPY    0.37796
# 5      GBPAUD    0.20000     NZDCHF    0.30151     GBPUSD    0.33929
# 6      NZDCHF    0.20000     AUDUSD    0.30151     EURGBP    0.33929
# 7      USDCHF    0.13608     NZDJPY    0.30151     AUDUSD    0.32733
# 8      AUDCHF    0.13608     EURNZD    0.30151     EURCHF    0.32733
# 9      CHFJPY    0.13608     EURCAD    0.20000     GBPCHF    0.21822
# 10     EURJPY    0.13608     GBPAUD    0.20000     AUDJPY    0.21822
# 11     CADCHF    0.13363     NZDCAD    0.20000     EURAUD    0.21822
# 12     AUDCAD    0.06917     CHFJPY    0.20000     GBPAUD    0.19643
# 13     EURCHF    0.06727     GBPCHF    0.20000     NZDCAD    0.19643
# 14     GBPCHF    0.06727     NZDUSD    0.20000     EURNZD    0.19643
# 15     EURAUD    0.06727     AUDCHF    0.10483     EURCAD    0.19643
# 16     GBPCAD    0.06727     GBPCAD    0.10483     EURJPY    0.19643
# 17     CADJPY    0.06667     EURAUD    0.10483     NZDCHF    0.19643
# 18     EURGBP    0.06667     AUDJPY    0.10050     NZDUSD    0.19643
# 19     GBPUSD    0.06667     CADJPY    0.10050     GBPJPY    0.18898
# 20     AUDNZD    0.06667     EURGBP    0.10050     GBPCAD    0.09449
# 21     GBPJPY    0.00000     GBPUSD    0.10050     AUDCHF    0.09449
# 22     NZDUSD    0.00000     CADCHF    0.10050     CADJPY    0.07143
# 23     AUDJPY    0.00000     AUDNZD    0.10050     CADCHF    0.07143
# 24     NZDJPY    0.00000     EURJPY    0.00000     NZDJPY    0.07143
# 25     AUDUSD    0.00000     GBPJPY    0.00000     AUDCAD    0.07143
# 26     NZDCAD    0.00000     AUDCAD    0.00000     AUDNZD    0.07143
#
#    AUDNZD__10  AUDNZD_10
# 0      EURUSD    0.80178
# 1      USDJPY    0.80178
# 2      AUDUSD    0.65465
# 3      USDCHF    0.53452
# 4      NZDCHF    0.53452
# 5      USDCAD    0.53452
# 6      NZDUSD    0.53452
# 7      NZDCAD    0.53452
# 8      EURNZD    0.53452
# 9      NZDJPY    0.42857
# 10     AUDNZD    0.42857
# 11     GBPUSD    0.35635
# 12     EURCAD    0.21822
# 13     EURAUD    0.21822
# 14     AUDJPY    0.21822
# 15     GBPCHF    0.21822
# 16     EURGBP    0.21822
# 17     AUDCHF    0.08909
# 18     CADCHF    0.08909
# 19     EURJPY    0.08909
# 20     CHFJPY    0.08909
# 21     CADJPY    0.08909
# 22     AUDCAD    0.08909
# 23     GBPJPY    0.04762
# 24     GBPCAD    0.04762
# 25     GBPAUD    0.04762
# 26     EURCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
