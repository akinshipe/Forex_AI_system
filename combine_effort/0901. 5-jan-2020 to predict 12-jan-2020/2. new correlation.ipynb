# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:37:29.035747

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.24418     NZDCAD    0.59821     NZDCAD    0.60000
# 1      EURUSD    0.24019     USDJPY    0.39551     EURCAD    0.50252
# 2      NZDCAD    0.24019     USDCHF    0.33929     USDJPY    0.40825
# 3      USDJPY    0.20192     CADCHF    0.33036     CADJPY    0.40825
# 4      EURCAD    0.19872     NZDUSD    0.27866     EURAUD    0.40825
# 5      GBPUSD    0.16386     EURUSD    0.26726     CADCHF    0.40825
# 6      USDCHF    0.16013     EURCAD    0.26726     GBPUSD    0.31449
# 7      EURAUD    0.16013     CADJPY    0.26068     USDCAD    0.31449
# 8      NZDUSD    0.16013     EURAUD    0.26068     AUDJPY    0.31449
# 9      CHFJPY    0.15573     AUDNZD    0.26068     AUDCHF    0.31449
# 10     CADCHF    0.12581     CHFJPY    0.21822     USDCHF    0.30151
# 11     GBPJPY    0.12179     GBPUSD    0.20536     GBPCAD    0.20412
# 12     AUDUSD    0.12179     AUDUSD    0.19643     AUDNZD    0.20412
# 13     EURNZD    0.11859     EURJPY    0.19094     EURUSD    0.20412
# 14     NZDJPY    0.08006     GBPJPY    0.13363     GBPCHF    0.11547
# 15     EURCHF    0.08006     AUDCAD    0.13363     NZDUSD    0.10483
# 16     AUDCAD    0.07711     USDCAD    0.12585     NZDJPY    0.10483
# 17     AUDJPY    0.07711     AUDCHF    0.12585     EURGBP    0.10483
# 18     GBPCHF    0.04516     AUDJPY    0.12585     GBPAUD    0.10050
# 19     CADJPY    0.04167     NZDJPY    0.08183     EURCHF    0.10050
# 20     GBPCAD    0.04167     EURCHF    0.07143     EURNZD    0.10050
# 21     EURGBP    0.03548     NZDCHF    0.07143     AUDCAD    0.10050
# 22     AUDNZD    0.03548     EURGBP    0.07143     NZDCHF    0.00000
# 23     GBPAUD    0.00321     EURNZD    0.06250     GBPJPY    0.00000
# 24     AUDCHF    0.00321     GBPCAD    0.06250     CHFJPY    0.00000
# 25     USDCAD    0.00321     GBPCHF    0.05455     EURJPY    0.00000
# 26     NZDCHF    0.00000     GBPAUD    0.00000     AUDUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.60714     USDJPY    0.81650  ...     EURJPY    0.41391
# 1      USDJPY    0.60010     CADJPY    0.81650  ...     AUDUSD    0.36775
# 2      CADJPY    0.60010     AUDJPY    0.80178  ...     GBPJPY    0.36775
# 3      EURAUD    0.60010     EURAUD    0.58333  ...     EURUSD    0.32233
# 4      AUDJPY    0.47246     AUDUSD    0.40825  ...     AUDJPY    0.31366
# 5      AUDCHF    0.47246     EURCAD    0.40825  ...     CHFJPY    0.30694
# 6      EURCAD    0.46429     NZDCAD    0.40825  ...     GBPUSD    0.25223
# 7      USDCAD    0.34247     USDCAD    0.35635  ...     NZDUSD    0.24175
# 8      EURCHF    0.33929     CHFJPY    0.35635  ...     AUDCHF    0.23282
# 9      CADCHF    0.32733     AUDCHF    0.35635  ...     GBPCAD    0.20646
# 10     USDCHF    0.21822     NZDJPY    0.35635  ...     CADJPY    0.19678
# 11     EURJPY    0.21822     EURCHF    0.25000  ...     GBPCHF    0.18831
# 12     GBPJPY    0.19643     NZDCHF    0.25000  ...     EURCHF    0.16116
# 13     EURGBP    0.19643     EURJPY    0.25000  ...     EURAUD    0.16116
# 14     AUDUSD    0.19643     GBPCAD    0.16667  ...     NZDJPY    0.16116
# 15     AUDNZD    0.19643     EURGBP    0.16667  ...     NZDCAD    0.16116
# 16     CHFJPY    0.18898     GBPJPY    0.16667  ...     USDCHF    0.16116
# 17     NZDJPY    0.18898     AUDCAD    0.16667  ...     AUDCAD    0.15198
# 18     NZDUSD    0.13363     EURUSD    0.16667  ...     EURGBP    0.13636
# 19     GBPUSD    0.09449     CADCHF    0.16667  ...     NZDCHF    0.08058
# 20     NZDCHF    0.09449     NZDUSD    0.10206  ...     USDCAD    0.07114
# 21     GBPAUD    0.07143     USDCHF    0.08909  ...     CADCHF    0.05519
# 22     AUDCAD    0.07143     EURNZD    0.08909  ...     AUDNZD    0.05519
# 23     GBPCAD    0.05455     GBPUSD    0.08909  ...     EURNZD    0.04516
# 24     EURNZD    0.05455     GBPCHF    0.08909  ...     USDJPY    0.04516
# 25     EURUSD    0.05455     GBPAUD    0.00000  ...     EURCAD    0.03548
# 26     GBPCHF    0.04029     AUDNZD    0.00000  ...     GBPAUD    0.00970
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDUSD    0.47321     AUDUSD    0.70353     AUDUSD    0.73214
# 1      EURUSD    0.40089     EURUSD    0.69752     EURUSD    0.60010
# 2      AUDCAD    0.40089     GBPCAD    0.69752     GBPCAD    0.60010
# 3      GBPJPY    0.40089     GBPUSD    0.60053     EURJPY    0.49099
# 4      AUDCHF    0.39551     CADCHF    0.53340     CADCHF    0.49099
# 5      EURJPY    0.35460     EURJPY    0.53340     AUDCHF    0.47246
# 6      CADCHF    0.33929     GBPJPY    0.49237     GBPUSD    0.47246
# 7      GBPCAD    0.33036     EURCAD    0.41414     AUDCAD    0.46429
# 8      GBPUSD    0.33036     GBPCHF    0.40618     GBPJPY    0.46429
# 9      CHFJPY    0.32733     AUDCAD    0.39394     GBPCHF    0.34247
# 10     AUDJPY    0.26068     EURCHF    0.39394     EURCHF    0.33929
# 11     EURAUD    0.26068     AUDCHF    0.38982     EURCAD    0.33929
# 12     EURGBP    0.20536     NZDCAD    0.30151     EURAUD    0.32733
# 13     NZDCAD    0.20536     EURAUD    0.28721     EURNZD    0.21822
# 14     EURCHF    0.20536     CHFJPY    0.28721     NZDUSD    0.20045
# 15     USDCHF    0.19643     EURNZD    0.21212     NZDCAD    0.19643
# 16     GBPCHF    0.19094     GBPAUD    0.19192     EURGBP    0.19643
# 17     NZDJPY    0.19094     USDCHF    0.19192     AUDNZD    0.19643
# 18     USDCAD    0.14382     AUDJPY    0.17911     GBPAUD    0.19643
# 19     EURCAD    0.13363     NZDJPY    0.17911     NZDCHF    0.18898
# 20     NZDUSD    0.12585     EURGBP    0.17911     CHFJPY    0.18898
# 21     EURNZD    0.07143     NZDUSD    0.17911     AUDJPY    0.18898
# 22     NZDCHF    0.06250     CADJPY    0.08206     NZDJPY    0.18898
# 23     CADJPY    0.00899     NZDCHF    0.08206     CADJPY    0.05455
# 24     USDJPY    0.00899     USDJPY    0.08206     USDJPY    0.05455
# 25     AUDNZD    0.00899     AUDNZD    0.08206     USDCHF    0.05455
# 26     GBPAUD    0.00000     USDCAD    0.03161     USDCAD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDUSD    0.81650
# 1      EURUSD    0.66667
# 2      GBPCAD    0.66667
# 3      AUDCAD    0.66667
# 4      GBPJPY    0.66667
# 5      EURAUD    0.66667
# 6      EURJPY    0.58333
# 7      CADCHF    0.58333
# 8      USDCHF    0.53452
# 9      AUDCHF    0.53452
# 10     GBPUSD    0.53452
# 11     AUDJPY    0.53452
# 12     CHFJPY    0.53452
# 13     NZDJPY    0.53452
# 14     NZDUSD    0.40825
# 15     NZDCAD    0.40825
# 16     EURCAD    0.40825
# 17     EURGBP    0.25000
# 18     NZDCHF    0.25000
# 19     EURCHF    0.16667
# 20     EURNZD    0.08909
# 21     GBPCHF    0.08909
# 22     USDCAD    0.08909
# 23     GBPAUD    0.00000
# 24     CADJPY    0.00000
# 25     USDJPY    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
