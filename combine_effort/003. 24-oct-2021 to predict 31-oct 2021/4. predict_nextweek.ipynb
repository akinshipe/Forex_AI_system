# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:49:50.803470
# 2021-12-06 23:49:50.812773
# 2021-12-06 23:50:50.832246
# 2021-12-06 23:51:50.848158
# 2021-12-06 23:52:50.869247
# 2021-12-06 23:53:50.873552
# 2021-12-06 23:54:50.879826
# 2021-12-06 23:55:50.903786
# 2021-12-06 23:56:50.909268
# 2021-12-06 23:57:50.912255
# 2021-12-06 23:58:50.929290
# 2021-12-06 23:59:50.940833
# 2021-12-07 00:00:50.961723
# 2021-12-07 00:01:50.984085
# 2021-12-07 00:02:50.987131
# 2021-12-07 00:03:50.991075
# 2021-12-07 00:04:50.997886
# 2021-12-07 00:05:51.009104
# 2021-12-07 00:06:51.029587
# 2021-12-07 00:07:51.048232
# 2021-12-07 00:08:51.051737
# 2021-12-07 00:09:51.073270
# 2021-12-07 00:10:51.083199
# 2021-12-07 00:11:51.098674
# 2021-12-07 00:12:51.107076
# 2021-12-07 00:13:51.130058
# 2021-12-07 00:14:51.134599
# 2021-12-07 00:15:51.140387
# 2021-12-07 00:16:51.160095
# 2021-12-07 00:17:51.185188
# 2021-12-07 00:18:51.188061
# 2021-12-07 00:19:51.197393
# 2021-12-07 00:20:51.220335
# 2021-12-07 00:21:51.227608
# 2021-12-07 00:22:51.240331
# 2021-12-07 00:23:51.247666
# 2021-12-07 00:24:51.262666
# 2021-12-07 00:25:51.267150
# 2021-12-07 00:26:51.277560
# 2021-12-07 00:27:51.284470
# 2021-12-07 00:28:51.288116
# 2021-12-07 00:29:51.296160
# 2021-12-07 00:30:51.315535
# 2021-12-07 00:31:51.338169
# 2021-12-07 00:32:51.346373
# 2021-12-07 00:33:51.367830
# 2021-12-07 00:34:51.377683
# 2021-12-07 04:26:54.379706
# 2021-12-07 04:27:54.388522
# 2021-12-07 04:28:54.398848
# 2021-12-07 04:29:54.418923
# 2021-12-07 04:30:54.422884

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# GBPUSD 15 [0.50226615]
# EURUSD 20 [0.33252793]
# USDJPY 20 [-0.66445164]
# AUDUSD 15 [0.96540452]
# GBPCHF 15 [0.71295581]
# EURCHF 20 [-0.66570158]
# CADCHF 10 [0.42514619]
# AUDCHF 15 [-0.19964797]
# NZDCHF 10 [-0.122]
# EURGBP 10 [-0.5337921]
# GBPCAD 10 [-0.4006]
# EURCAD 15 [-0.7978]
# EURAUD 15 [-0.93321572]
# EURNZD 20 [0.8034094]
# CADJPY 15 [0.81437936]
# AUDJPY 50 [0.20031655]
# NZDJPY 50 [0.81929134]
# AUDCAD 10 [0.8283]
# NZDCAD 50 [-0.00112202]
# ['B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
