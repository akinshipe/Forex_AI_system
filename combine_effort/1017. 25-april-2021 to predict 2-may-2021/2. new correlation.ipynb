# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:55:40.485351

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.29181     EURJPY    0.49357     EURJPY    0.47140
# 1      CADJPY    0.28123     CADJPY    0.39747     CADJPY    0.47076
# 2      EURJPY    0.25992     GBPJPY    0.36748     GBPJPY    0.35722
# 3      CHFJPY    0.24878     EURNZD    0.35460     CHFJPY    0.28721
# 4      AUDNZD    0.23153     CHFJPY    0.32733     NZDUSD    0.23570
# 5      EURNZD    0.19025     AUDNZD    0.25882     GBPCHF    0.23570
# 6      NZDJPY    0.18306     EURGBP    0.20536     AUDUSD    0.17118
# 7      AUDJPY    0.16530     AUDJPY    0.18898     GBPUSD    0.17118
# 8      EURUSD    0.14943     NZDCAD    0.17496     EURCHF    0.13363
# 9      GBPUSD    0.13170     AUDCHF    0.15714     USDCAD    0.12309
# 10     AUDCHF    0.12157     GBPCAD    0.15714     EURNZD    0.12309
# 11     EURGBP    0.12157     EURAUD    0.15714     NZDCAD    0.08909
# 12     CADCHF    0.11580     USDJPY    0.13363     AUDCHF    0.08909
# 13     EURCHF    0.09752     EURUSD    0.13363     GBPCAD    0.08909
# 14     NZDUSD    0.09752     CADCHF    0.12016     USDJPY    0.08206
# 15     AUDUSD    0.09752     EURCHF    0.12016     EURCAD    0.08206
# 16     GBPCAD    0.09688     NZDJPY    0.11585     USDCHF    0.04280
# 17     GBPCHF    0.08181     NZDCHF    0.11080     AUDJPY    0.04280
# 18     GBPAUD    0.07462     AUDCAD    0.08183     CADCHF    0.04280
# 19     NZDCHF    0.04728     USDCHF    0.07143     AUDCAD    0.04167
# 20     NZDCAD    0.04728     GBPAUD    0.07143     EURGBP    0.04167
# 21     USDCAD    0.03309     EURCAD    0.06250     EURAUD    0.04167
# 22     USDCHF    0.01959     USDCAD    0.05455     EURUSD    0.04167
# 23     EURAUD    0.01478     AUDUSD    0.04725     GBPAUD    0.00000
# 24     EURCAD    0.00649     GBPCHF    0.04725     NZDJPY    0.00000
# 25     USDJPY    0.00649     NZDUSD    0.04213     NZDCHF    0.00000
# 26     AUDCAD    0.00167     GBPUSD    0.02916     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADJPY    0.57735     USDCHF    0.80178  ...     GBPUSD    0.21612
# 1      USDCHF    0.28868     NZDUSD    0.66667  ...     EURUSD    0.14943
# 2      NZDUSD    0.28868     EURUSD    0.58333  ...     EURAUD    0.14943
# 3      GBPUSD    0.28868     USDJPY    0.58333  ...     CADJPY    0.13234
# 4      GBPJPY    0.27217     CADJPY    0.58333  ...     GBPJPY    0.11495
# 5      GBPCHF    0.27217     EURCAD    0.58333  ...     AUDNZD    0.09688
# 6      EURJPY    0.27217     CADCHF    0.58333  ...     AUDCAD    0.08181
# 7      USDCAD    0.21822     GBPUSD    0.40825  ...     GBPCHF    0.08181
# 8      AUDUSD    0.21822     AUDUSD    0.40825  ...     CHFJPY    0.08181
# 9      CHFJPY    0.21822     EURAUD    0.40825  ...     GBPCAD    0.06732
# 10     GBPCAD    0.18464     GBPJPY    0.35635  ...     EURNZD    0.05366
# 11     EURUSD    0.16667     AUDNZD    0.35635  ...     USDCAD    0.04963
# 12     USDJPY    0.16667     GBPCHF    0.35635  ...     NZDCAD    0.04728
# 13     CADCHF    0.16667     EURJPY    0.27217  ...     AUDCHF    0.04728
# 14     NZDJPY    0.12309     GBPCAD    0.25000  ...     NZDCHF    0.04728
# 15     EURCHF    0.12309     USDCAD    0.25000  ...     EURGBP    0.04052
# 16     AUDCHF    0.11111     NZDCAD    0.25000  ...     CADCHF    0.03309
# 17     NZDCAD    0.11111     AUDCHF    0.16667  ...     USDCHF    0.01959
# 18     AUDCAD    0.05455     CHFJPY    0.16667  ...     EURCHF    0.01198
# 19     GBPAUD    0.05455     AUDCAD    0.16667  ...     NZDUSD    0.01198
# 20     EURCAD    0.05455     EURGBP    0.16667  ...     NZDJPY    0.01198
# 21     EURAUD    0.05455     EURCHF    0.10206  ...     AUDUSD    0.01198
# 22     EURNZD    0.05455     NZDCHF    0.08909  ...     EURJPY    0.01083
# 23     AUDJPY    0.05455     NZDJPY    0.08909  ...     GBPAUD    0.00649
# 24     EURGBP    0.00000     GBPAUD    0.00000  ...     EURCAD    0.00649
# 25     NZDCHF    0.00000     EURNZD    0.00000  ...     USDJPY    0.00649
# 26     AUDNZD    0.00000     AUDJPY    0.00000  ...     AUDJPY    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPJPY    0.20751     GBPCAD    0.37796     GBPCAD    0.42640
# 1      GBPUSD    0.19623     GBPCHF    0.33333     GBPCHF    0.35355
# 2      NZDCHF    0.16685     GBPJPY    0.28868     GBPJPY    0.35355
# 3      GBPAUD    0.15714     EURGBP    0.23570     AUDCHF    0.28868
# 4      EURCHF    0.14833     NZDJPY    0.20000     NZDJPY    0.21320
# 5      GBPCAD    0.14833     NZDUSD    0.20000     EURGBP    0.20000
# 6      AUDNZD    0.13876     NZDCHF    0.20000     GBPUSD    0.20000
# 7      CADJPY    0.13876     GBPUSD    0.18157     AUDNZD    0.20000
# 8      USDCHF    0.12016     USDCAD    0.17408     USDCAD    0.18898
# 9      NZDCAD    0.10566     EURNZD    0.17408     AUDCAD    0.18898
# 10     GBPCHF    0.09782     CHFJPY    0.17408     EURCHF    0.10660
# 11     CHFJPY    0.08472     NZDCAD    0.12599     CADJPY    0.10000
# 12     USDCAD    0.08472     EURCHF    0.12599     USDCHF    0.10000
# 13     EURNZD    0.08472     AUDCHF    0.12599     NZDCHF    0.10000
# 14     NZDUSD    0.07087     GBPAUD    0.11547     NZDUSD    0.10000
# 15     NZDJPY    0.07087     EURJPY    0.06667     AUDUSD    0.09449
# 16     EURUSD    0.06917     AUDNZD    0.06667     GBPAUD    0.09449
# 17     USDJPY    0.06917     CADCHF    0.06052     CHFJPY    0.09449
# 18     AUDCAD    0.05648     AUDUSD    0.06052     EURCAD    0.09449
# 19     AUDUSD    0.04891     CADJPY    0.06052     EURAUD    0.09449
# 20     AUDJPY    0.04891     AUDJPY    0.06052     EURNZD    0.09449
# 21     EURCAD    0.01849     USDCHF    0.06052     AUDJPY    0.09449
# 22     EURGBP    0.01849     EURCAD    0.05803     USDJPY    0.00000
# 23     EURJPY    0.01043     USDJPY    0.05803     EURUSD    0.00000
# 24     EURAUD    0.00478     EURAUD    0.00000     CADCHF    0.00000
# 25     CADCHF    0.00478     AUDCAD    0.00000     NZDCAD    0.00000
# 26     AUDCHF    0.00478     EURUSD    0.00000     EURJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.53452
# 1      GBPCAD    0.53452
# 2      AUDCHF    0.53452
# 3      GBPCHF    0.42857
# 4      GBPJPY    0.42857
# 5      AUDNZD    0.42857
# 6      AUDCAD    0.35635
# 7      EURCHF    0.32733
# 8      GBPAUD    0.21822
# 9      AUDJPY    0.21822
# 10     GBPUSD    0.21822
# 11     EURNZD    0.21822
# 12     EURAUD    0.21822
# 13     AUDUSD    0.21822
# 14     EURJPY    0.21822
# 15     EURCAD    0.08909
# 16     NZDCAD    0.08909
# 17     CADJPY    0.08909
# 18     NZDUSD    0.08909
# 19     EURUSD    0.08909
# 20     USDJPY    0.08909
# 21     USDCAD    0.08909
# 22     CADCHF    0.08909
# 23     CHFJPY    0.08909
# 24     NZDCHF    0.04762
# 25     NZDJPY    0.04762
# 26     USDCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
