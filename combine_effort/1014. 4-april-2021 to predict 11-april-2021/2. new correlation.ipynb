# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:58:33.313065

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.28904     EURJPY    0.50830     EURJPY    0.66339
# 1      GBPJPY    0.25395     EURNZD    0.38889     AUDCHF    0.42366
# 2      CADJPY    0.22653     EURUSD    0.35460     EURNZD    0.38516
# 3      CHFJPY    0.22653     AUDNZD    0.30556     CADCHF    0.36690
# 4      AUDNZD    0.21627     CHFJPY    0.30556     EURAUD    0.31868
# 5      EURUSD    0.20773     EURGBP    0.30208     CADJPY    0.30261
# 6      NZDJPY    0.20302     USDCHF    0.25000     CHFJPY    0.25678
# 7      EURNZD    0.19485     CADJPY    0.22591     GBPUSD    0.25163
# 8      NZDUSD    0.19061     EURAUD    0.19767     NZDCAD    0.25163
# 9      AUDCHF    0.18467     AUDCHF    0.19767     AUDNZD    0.20588
# 10     AUDUSD    0.15418     GBPCAD    0.19767     NZDUSD    0.18157
# 11     GBPUSD    0.14385     GBPJPY    0.19305     NZDCHF    0.18157
# 12     EURGBP    0.12039     AUDUSD    0.16667     AUDCAD    0.17118
# 13     USDJPY    0.11433     EURCAD    0.16477     EURGBP    0.17118
# 14     AUDJPY    0.10701     GBPAUD    0.16477     EURUSD    0.17118
# 15     USDCAD    0.09054     USDCAD    0.13608     GBPJPY    0.10483
# 16     USDCHF    0.08353     NZDJPY    0.12309     NZDJPY    0.10483
# 17     GBPAUD    0.07711     GBPCHF    0.08909     GBPCAD    0.09890
# 18     GBPCAD    0.07114     NZDCHF    0.08909     EURCAD    0.09890
# 19     EURCHF    0.06946     CADCHF    0.08909     AUDUSD    0.09890
# 20     NZDCAD    0.06946     NZDCAD    0.08909     USDJPY    0.09890
# 21     EURAUD    0.06553     EURCHF    0.08472     USDCHF    0.09890
# 22     GBPCHF    0.06118     AUDJPY    0.08472     GBPCHF    0.06052
# 23     EURCAD    0.04013     USDJPY    0.08183     GBPAUD    0.03161
# 24     NZDCHF    0.02341     NZDUSD    0.05939     USDCAD    0.03161
# 25     CADCHF    0.02341     AUDCAD    0.02778     EURCHF    0.02288
# 26     AUDCAD    0.02341     GBPUSD    0.00000     AUDJPY    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.65909     NZDCAD    0.40825  ...     CADJPY    0.16864
# 1      CADJPY    0.45227     NZDUSD    0.40825  ...     GBPUSD    0.16530
# 2      GBPUSD    0.42640     AUDJPY    0.40825  ...     EURUSD    0.13497
# 3      EURGBP    0.36364     EURNZD    0.40825  ...     EURAUD    0.11580
# 4      EURUSD    0.36364     GBPUSD    0.40825  ...     AUDNZD    0.09688
# 5      USDJPY    0.36364     EURJPY    0.37500  ...     CHFJPY    0.08181
# 6      GBPCAD    0.36364     AUDCHF    0.32733  ...     USDCAD    0.06204
# 7      AUDCHF    0.36364     NZDCHF    0.32733  ...     USDJPY    0.05366
# 8      CHFJPY    0.34247     EURCAD    0.32733  ...     NZDCHF    0.04728
# 9      CADCHF    0.30151     GBPCAD    0.32733  ...     AUDCAD    0.04728
# 10     USDCHF    0.30151     EURGBP    0.25000  ...     CADCHF    0.04728
# 11     GBPAUD    0.26189     EURUSD    0.25000  ...     EURCAD    0.04052
# 12     USDCAD    0.26189     USDJPY    0.25000  ...     EURGBP    0.04052
# 13     GBPCHF    0.23652     NZDJPY    0.25000  ...     NZDUSD    0.03715
# 14     EURNZD    0.18464     EURCHF    0.25000  ...     AUDJPY    0.03715
# 15     GBPJPY    0.16116     CADCHF    0.25000  ...     EURNZD    0.02764
# 16     NZDUSD    0.10660     AUDNZD    0.21822  ...     GBPJPY    0.02653
# 17     EURCAD    0.10660     GBPJPY    0.16667  ...     EURJPY    0.02432
# 18     EURAUD    0.10660     CADJPY    0.16667  ...     NZDJPY    0.02432
# 19     AUDJPY    0.10660     GBPCHF    0.16667  ...     GBPCAD    0.01959
# 20     NZDCAD    0.10660     USDCHF    0.16667  ...     AUDCHF    0.01198
# 21     NZDJPY    0.07538     EURAUD    0.10206  ...     EURCHF    0.01198
# 22     AUDUSD    0.04029     AUDUSD    0.10206  ...     AUDUSD    0.01198
# 23     AUDCAD    0.04029     AUDCAD    0.10206  ...     NZDCAD    0.01198
# 24     EURCHF    0.02273     GBPAUD    0.00000  ...     GBPAUD    0.00649
# 25     NZDCHF    0.02273     CHFJPY    0.00000  ...     USDCHF    0.00649
# 26     AUDNZD    0.02273     USDCAD    0.00000  ...     GBPCHF    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDJPY    0.22591     GBPCAD    0.42366     NZDJPY    0.45227
# 1      CADJPY    0.22591     AUDJPY    0.37796     EURNZD    0.43082
# 2      NZDCHF    0.20787     GBPCHF    0.33333     GBPCAD    0.36364
# 3      EURUSD    0.19094     GBPAUD    0.29013     NZDCHF    0.31818
# 4      USDJPY    0.19094     NZDJPY    0.28868     USDCAD    0.26189
# 5      USDCHF    0.16667     EURGBP    0.23570     GBPAUD    0.26189
# 6      EURNZD    0.16667     CHFJPY    0.23570     GBPCHF    0.23652
# 7      AUDNZD    0.16667     EURNZD    0.23570     EURAUD    0.21320
# 8      GBPAUD    0.16477     NZDUSD    0.20000     NZDCAD    0.21320
# 9      GBPUSD    0.14434     CADJPY    0.20000     NZDUSD    0.21320
# 10     USDCAD    0.13608     NZDCHF    0.20000     AUDJPY    0.21320
# 11     NZDJPY    0.12309     GBPJPY    0.19245     GBPJPY    0.16116
# 12     AUDCAD    0.11111     EURCAD    0.18157     EURCAD    0.10660
# 13     EURGBP    0.10985     USDCAD    0.17408     GBPUSD    0.10660
# 14     EURCAD    0.10985     NZDCAD    0.12599     CADJPY    0.07538
# 15     EURAUD    0.08472     EURJPY    0.12599     USDCHF    0.07538
# 16     EURJPY    0.08472     AUDNZD    0.12599     CADCHF    0.07538
# 17     AUDCHF    0.08472     GBPUSD    0.12599     CHFJPY    0.04029
# 18     NZDUSD    0.05939     EURCHF    0.12599     AUDUSD    0.04029
# 19     GBPCHF    0.05939     AUDCHF    0.06667     AUDCAD    0.04029
# 20     CADCHF    0.05939     EURAUD    0.06052     EURGBP    0.02273
# 21     NZDCAD    0.05939     AUDUSD    0.06052     EURJPY    0.02273
# 22     GBPCAD    0.05648     USDJPY    0.06052     AUDCHF    0.02273
# 23     EURCHF    0.05648     USDCHF    0.06052     EURCHF    0.02273
# 24     GBPJPY    0.03217     CADCHF    0.00000     USDJPY    0.02273
# 25     CHFJPY    0.02778     AUDCAD    0.00000     EURUSD    0.02273
# 26     AUDUSD    0.02778     EURUSD    0.00000     AUDNZD    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDJPY    0.37500
# 1      AUDNZD    0.32733
# 2      EURCAD    0.32733
# 3      GBPCAD    0.32733
# 4      AUDCHF    0.32733
# 5      EURCHF    0.25000
# 6      EURJPY    0.25000
# 7      CADCHF    0.25000
# 8      EURGBP    0.25000
# 9      USDJPY    0.25000
# 10     EURUSD    0.25000
# 11     NZDCHF    0.21822
# 12     GBPCHF    0.16667
# 13     CADJPY    0.16667
# 14     USDCHF    0.16667
# 15     GBPJPY    0.16667
# 16     AUDUSD    0.10206
# 17     EURAUD    0.10206
# 18     EURNZD    0.10206
# 19     GBPUSD    0.10206
# 20     AUDJPY    0.10206
# 21     NZDUSD    0.10206
# 22     AUDCAD    0.10206
# 23     NZDCAD    0.10206
# 24     GBPAUD    0.00000
# 25     USDCAD    0.00000
# 26     CHFJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
