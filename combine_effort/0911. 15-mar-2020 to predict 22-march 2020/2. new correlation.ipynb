# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-11 11:58:36.982153

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.31807     USDJPY    0.27217     USDJPY    0.39394
# 1      CHFJPY    0.24982     CADJPY    0.27217     CADJPY    0.39394
# 2      NZDCAD    0.23775     USDCHF    0.26726     AUDJPY    0.38982
# 3      USDCHF    0.20192     NZDCAD    0.26726     USDCAD    0.30151
# 4      EURUSD    0.19872     USDCAD    0.26726     GBPCAD    0.28721
# 5      USDJPY    0.19872     EURCAD    0.26726     AUDUSD    0.24232
# 6      AUDCAD    0.19872     AUDJPY    0.20751     AUDNZD    0.21212
# 7      NZDUSD    0.19678     GBPUSD    0.20180     AUDCHF    0.21212
# 8      GBPUSD    0.15743     EURAUD    0.20000     EURAUD    0.21212
# 9      AUDUSD    0.15573     EURJPY    0.20000     EURJPY    0.21212
# 10     EURGBP    0.12581     CADCHF    0.20000     GBPJPY    0.19192
# 11     GBPCAD    0.12179     AUDCHF    0.20000     EURGBP    0.19192
# 12     EURCAD    0.12179     EURGBP    0.13608     GBPCHF    0.19192
# 13     EURNZD    0.12179     CHFJPY    0.13608     GBPAUD    0.17911
# 14     NZDJPY    0.12179     EURNZD    0.13363     NZDJPY    0.17911
# 15     GBPJPY    0.11859     AUDCAD    0.13363     EURCHF    0.15352
# 16     GBPAUD    0.11859     EURUSD    0.13363     USDCHF    0.12309
# 17     EURCHF    0.11613     GBPAUD    0.06917     EURCAD    0.10050
# 18     EURAUD    0.08353     GBPCHF    0.06917     NZDUSD    0.10050
# 19     AUDCHF    0.07711     NZDJPY    0.06917     EURUSD    0.10050
# 20     NZDCHF    0.07711     GBPJPY    0.06727     EURNZD    0.08206
# 21     GBPCHF    0.07711     EURCHF    0.06727     CHFJPY    0.03161
# 22     CADCHF    0.04167     NZDCHF    0.06667     NZDCHF    0.01010
# 23     AUDJPY    0.04167     NZDUSD    0.06667     GBPUSD    0.01010
# 24     USDCAD    0.04167     GBPCAD    0.00000     CADCHF    0.01010
# 25     CADJPY    0.03846     AUDUSD    0.00000     AUDCAD    0.01010
# 26     AUDNZD    0.00649     AUDNZD    0.00000     NZDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPCAD    0.44444     EURJPY    0.65465  ...     GBPCAD    0.36775
# 1      AUDNZD    0.38889     GBPAUD    0.50000  ...     GBPJPY    0.36775
# 2      NZDCAD    0.38889     AUDNZD    0.40825  ...     GBPUSD    0.33307
# 3      AUDUSD    0.38889     GBPCAD    0.40825  ...     GBPCHF    0.31366
# 4      NZDUSD    0.38889     NZDCAD    0.40825  ...     EURGBP    0.29870
# 5      GBPCHF    0.38889     GBPCHF    0.40825  ...     EURUSD    0.28710
# 6      EURJPY    0.38889     CHFJPY    0.40825  ...     AUDUSD    0.26449
# 7      AUDCHF    0.38889     AUDCAD    0.21822  ...     AUDCHF    0.25223
# 8      USDCAD    0.32733     USDCAD    0.21822  ...     NZDCAD    0.25223
# 9      GBPJPY    0.32733     EURAUD    0.21822  ...     EURJPY    0.25223
# 10     EURNZD    0.32733     CADCHF    0.21822  ...     EURCHF    0.21753
# 11     NZDCHF    0.28868     NZDCHF    0.21822  ...     AUDCAD    0.20646
# 12     NZDJPY    0.28868     EURNZD    0.20000  ...     AUDJPY    0.19678
# 13     AUDJPY    0.28868     EURCAD    0.20000  ...     EURCAD    0.19678
# 14     EURAUD    0.21822     USDCHF    0.20000  ...     NZDCHF    0.17138
# 15     AUDCAD    0.21822     GBPJPY    0.20000  ...     CHFJPY    0.14368
# 16     EURCAD    0.21822     EURGBP    0.20000  ...     NZDUSD    0.13636
# 17     EURGBP    0.21822     GBPUSD    0.00000  ...     CADCHF    0.11613
# 18     EURUSD    0.21822     AUDCHF    0.00000  ...     GBPAUD    0.11613
# 19     EURCHF    0.18464     EURCHF    0.00000  ...     USDCAD    0.11613
# 20     CADCHF    0.16667     NZDUSD    0.00000  ...     NZDJPY    0.11613
# 21     CADJPY    0.16667     AUDUSD    0.00000  ...     AUDNZD    0.10123
# 22     USDJPY    0.16667     CADJPY    0.00000  ...     EURAUD    0.09054
# 23     GBPAUD    0.12309     AUDJPY    0.00000  ...     EURNZD    0.04516
# 24     GBPUSD    0.05455     NZDJPY    0.00000  ...     USDJPY    0.04516
# 25     CHFJPY    0.00000     USDJPY    0.00000  ...     CADJPY    0.03548
# 26     USDCHF    0.00000     EURUSD    0.00000  ...     USDCHF    0.03548
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.65908     GBPCAD    0.61237     GBPCAD    0.72222
# 1      GBPUSD    0.45701     EURCAD    0.40000     GBPCHF    0.66667
# 2      GBPCHF    0.45134     AUDUSD    0.31449     NZDCHF    0.57735
# 3      AUDUSD    0.43939     EURGBP    0.30151     EURCHF    0.49237
# 4      EURCAD    0.41349     AUDCHF    0.30151     EURGBP    0.49099
# 5      EURUSD    0.39551     EURAUD    0.30151     EURCAD    0.49099
# 6      EURCHF    0.35747     GBPJPY    0.30151     NZDCAD    0.38889
# 7      CADCHF    0.33634     GBPUSD    0.30151     AUDCHF    0.38889
# 8      AUDCHF    0.33634     NZDCHF    0.30151     AUDNZD    0.38889
# 9      GBPJPY    0.32127     CADCHF    0.30151     GBPUSD    0.32733
# 10     NZDCAD    0.27866     GBPCHF    0.30151     EURNZD    0.32733
# 11     AUDCAD    0.27866     AUDCAD    0.30151     GBPJPY    0.32733
# 12     EURGBP    0.24716     NZDCAD    0.30151     CHFJPY    0.28868
# 13     NZDCHF    0.20180     EURCHF    0.21822     USDCHF    0.28868
# 14     EURJPY    0.20180     EURNZD    0.20412     USDCAD    0.21822
# 15     EURAUD    0.20180     USDCAD    0.20000     EURAUD    0.21822
# 16     GBPAUD    0.17216     EURUSD    0.20000     AUDCAD    0.21822
# 17     USDCAD    0.14382     AUDJPY    0.10483     EURUSD    0.21822
# 18     NZDUSD    0.06727     CHFJPY    0.10483     CADCHF    0.16667
# 19     AUDJPY    0.03257     GBPAUD    0.10483     GBPAUD    0.12309
# 20     NZDJPY    0.03257     NZDJPY    0.10483     AUDUSD    0.11111
# 21     AUDNZD    0.02746     AUDNZD    0.10050     EURJPY    0.11111
# 22     CADJPY    0.02746     CADJPY    0.10050     NZDUSD    0.11111
# 23     CHFJPY    0.02746     EURJPY    0.10050     CADJPY    0.11111
# 24     USDJPY    0.02746     USDJPY    0.10050     USDJPY    0.11111
# 25     EURNZD    0.00899     NZDUSD    0.00000     AUDJPY    0.00000
# 26     USDCHF    0.00899     USDCHF    0.00000     NZDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      CHFJPY    0.66667
# 1      GBPCHF    0.66667
# 2      GBPCAD    0.58333
# 3      EURJPY    0.53452
# 4      NZDCHF    0.53452
# 5      USDCHF    0.40825
# 6      EURNZD    0.40825
# 7      EURCAD    0.40825
# 8      AUDCHF    0.40825
# 9      EURGBP    0.40825
# 10     EURCHF    0.40825
# 11     USDCAD    0.35635
# 12     USDJPY    0.25000
# 13     NZDCAD    0.25000
# 14     NZDJPY    0.25000
# 15     AUDJPY    0.25000
# 16     CADJPY    0.25000
# 17     AUDNZD    0.25000
# 18     GBPUSD    0.25000
# 19     EURUSD    0.16667
# 20     GBPAUD    0.10206
# 21     AUDUSD    0.10206
# 22     NZDUSD    0.10206
# 23     EURAUD    0.08909
# 24     AUDCAD    0.08909
# 25     CADCHF    0.08909
# 26     GBPJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
