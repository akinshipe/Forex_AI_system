# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:56:30.272392

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.30358     EURJPY    0.38536     CADJPY    0.35635
# 1      EURJPY    0.24251     CADJPY    0.38052     GBPCHF    0.35635
# 2      GBPJPY    0.24251     CHFJPY    0.31175     AUDUSD    0.28721
# 3      CADJPY    0.22018     GBPCHF    0.23783     CADCHF    0.25678
# 4      AUDNZD    0.21246     GBPJPY    0.23544     USDCAD    0.25000
# 5      EURUSD    0.20646     EURAUD    0.22172     GBPJPY    0.23570
# 6      EURGBP    0.19612     USDCAD    0.16477     GBPAUD    0.20412
# 7      EURNZD    0.15743     AUDUSD    0.16477     USDCHF    0.16667
# 8      EURCAD    0.11859     AUDNZD    0.16147     USDJPY    0.16667
# 9      AUDCHF    0.11440     EURUSD    0.14382     CHFJPY    0.16667
# 10     GBPUSD    0.09803     EURNZD    0.14382     GBPCAD    0.13363
# 11     NZDJPY    0.09803     GBPAUD    0.12585     AUDNZD    0.13363
# 12     NZDUSD    0.09237     EURGBP    0.10702     NZDUSD    0.12309
# 13     CADCHF    0.09237     AUDCHF    0.10702     EURCAD    0.12309
# 14     AUDJPY    0.09237     GBPCAD    0.09513     AUDJPY    0.12309
# 15     NZDCAD    0.08760     EURCAD    0.08597     EURJPY    0.10206
# 16     USDCHF    0.08353     AUDCAD    0.08597     NZDJPY    0.08909
# 17     EURAUD    0.07711     NZDJPY    0.07099     NZDCHF    0.08206
# 18     GBPAUD    0.07462     USDJPY    0.04977     AUDCHF    0.08206
# 19     GBPCHF    0.05338     GBPUSD    0.04757     AUDCAD    0.08206
# 20     NZDCHF    0.04903     NZDUSD    0.04757     GBPUSD    0.04167
# 21     AUDCAD    0.03269     NZDCHF    0.03257     EURCHF    0.04167
# 22     USDCAD    0.03269     AUDJPY    0.03257     EURUSD    0.04167
# 23     EURCHF    0.00990     EURCHF    0.02746     EURAUD    0.00000
# 24     GBPCAD    0.00990     NZDCAD    0.02746     EURNZD    0.00000
# 25     AUDUSD    0.00990     CADCHF    0.01468     NZDCAD    0.00000
# 26     USDJPY    0.00000     USDCHF    0.00899     EURGBP    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.34247     GBPCAD    0.53452  ...     GBPUSD    0.24131
# 1      CADCHF    0.32733     CHFJPY    0.53452  ...     USDCHF    0.18021
# 2      CADJPY    0.32733     CADJPY    0.40825  ...     USDJPY    0.16330
# 3      AUDUSD    0.32733     AUDUSD    0.40825  ...     CADJPY    0.15309
# 4      GBPCHF    0.32733     GBPCHF    0.40825  ...     EURUSD    0.14804
# 5      NZDJPY    0.21822     CADCHF    0.40825  ...     GBPCAD    0.13457
# 6      USDCAD    0.21822     GBPAUD    0.40825  ...     EURJPY    0.12729
# 7      GBPAUD    0.19643     USDCAD    0.35635  ...     AUDJPY    0.11775
# 8      AUDCHF    0.19643     EURUSD    0.25000  ...     EURCHF    0.11775
# 9      USDCHF    0.19643     EURAUD    0.25000  ...     GBPAUD    0.11580
# 10     NZDUSD    0.19643     EURCHF    0.25000  ...     NZDJPY    0.10342
# 11     USDJPY    0.19643     EURCAD    0.25000  ...     GBPCHF    0.10206
# 12     GBPJPY    0.18898     GBPUSD    0.25000  ...     EURAUD    0.09829
# 13     EURJPY    0.13363     GBPJPY    0.25000  ...     AUDCAD    0.08333
# 14     NZDCHF    0.07143     EURNZD    0.16667  ...     AUDNZD    0.08333
# 15     GBPUSD    0.07143     AUDCHF    0.16667  ...     GBPJPY    0.05455
# 16     EURCHF    0.07143     NZDCHF    0.16667  ...     CADCHF    0.05046
# 17     EURAUD    0.07143     NZDJPY    0.16667  ...     NZDUSD    0.03364
# 18     EURNZD    0.07143     NZDCAD    0.16667  ...     AUDUSD    0.03364
# 19     AUDJPY    0.07143     USDJPY    0.16667  ...     NZDCAD    0.03309
# 20     EURUSD    0.07143     EURJPY    0.10206  ...     EURCAD    0.03269
# 21     CHFJPY    0.05455     USDCHF    0.08909  ...     CHFJPY    0.01701
# 22     AUDCAD    0.05455     EURGBP    0.08909  ...     EURNZD    0.01638
# 23     NZDCAD    0.05455     AUDNZD    0.08909  ...     NZDCHF    0.00000
# 24     EURCAD    0.05455     AUDJPY    0.00000  ...     AUDCHF    0.00000
# 25     GBPCAD    0.05455     AUDCAD    0.00000  ...     USDCAD    0.00000
# 26     EURGBP    0.04029     NZDUSD    0.00000  ...     EURGBP    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.46291     AUDNZD    0.42857     GBPCAD    0.57735
# 1      GBPCHF    0.30861     GBPCAD    0.42857     USDCHF    0.47246
# 2      NZDJPY    0.26318     USDCHF    0.35635     AUDNZD    0.42640
# 3      USDCHF    0.26245     NZDJPY    0.28571     AUDCAD    0.28868
# 4      AUDJPY    0.25661     AUDCAD    0.28511     NZDJPY    0.28868
# 5      EURGBP    0.19623     GBPCHF    0.19048     GBPCHF    0.28868
# 6      GBPAUD    0.17496     AUDCHF    0.15352     EURCAD    0.28868
# 7      USDJPY    0.16147     USDJPY    0.13363     GBPJPY    0.20000
# 8      GBPUSD    0.15430     EURUSD    0.13363     USDJPY    0.18898
# 9      CADJPY    0.15430     EURCHF    0.13363     AUDJPY    0.18898
# 10     NZDUSD    0.15430     EURGBP    0.12599     EURUSD    0.18898
# 11     GBPJPY    0.14548     GBPJPY    0.12599     EURCHF    0.18898
# 12     AUDCAD    0.13211     USDCAD    0.08909     EURGBP    0.10660
# 13     EURNZD    0.11664     CHFJPY    0.08909     AUDCHF    0.09449
# 14     EURUSD    0.11664     GBPUSD    0.08909     NZDCHF    0.09449
# 15     AUDNZD    0.11111     NZDCHF    0.06580     GBPUSD    0.09449
# 16     NZDCHF    0.10566     AUDJPY    0.06580     GBPAUD    0.09449
# 17     CHFJPY    0.10566     NZDUSD    0.06580     EURAUD    0.09449
# 18     EURJPY    0.09869     AUDUSD    0.06580     EURNZD    0.09449
# 19     USDCAD    0.05939     EURCAD    0.06580     NZDUSD    0.09449
# 20     AUDUSD    0.05939     EURJPY    0.05455     CADCHF    0.00000
# 21     EURCHF    0.05939     CADJPY    0.04762     USDCAD    0.00000
# 22     NZDCAD    0.05939     CADCHF    0.02288     EURJPY    0.00000
# 23     CADCHF    0.04762     GBPAUD    0.00000     CHFJPY    0.00000
# 24     AUDCHF    0.04528     EURAUD    0.00000     CADJPY    0.00000
# 25     EURCAD    0.01468     EURNZD    0.00000     AUDUSD    0.00000
# 26     EURAUD    0.01468     NZDCAD    0.00000     NZDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.53452
# 1      GBPCAD    0.53452
# 2      AUDNZD    0.53452
# 3      AUDCAD    0.40825
# 4      GBPCHF    0.40825
# 5      USDJPY    0.25000
# 6      GBPUSD    0.25000
# 7      EURCAD    0.25000
# 8      GBPJPY    0.25000
# 9      EURUSD    0.25000
# 10     EURCHF    0.25000
# 11     NZDJPY    0.16667
# 12     NZDCHF    0.16667
# 13     NZDCAD    0.16667
# 14     AUDCHF    0.16667
# 15     EURAUD    0.16667
# 16     EURNZD    0.16667
# 17     EURJPY    0.10206
# 18     EURGBP    0.08909
# 19     CHFJPY    0.08909
# 20     USDCAD    0.08909
# 21     AUDUSD    0.00000
# 22     CADCHF    0.00000
# 23     AUDJPY    0.00000
# 24     CADJPY    0.00000
# 25     GBPAUD    0.00000
# 26     NZDUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
