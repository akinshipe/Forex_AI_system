# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:49:53.335306

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.40482     NZDCAD    0.32733     AUDNZD    0.30151
# 1      CHFJPY    0.35219     CADJPY    0.28868     EURUSD    0.30151
# 2      EURJPY    0.31100     AUDCAD    0.27217     NZDCAD    0.30151
# 3      USDCHF    0.28824     EURUSD    0.25000     AUDCAD    0.30151
# 4      AUDNZD    0.27536     GBPCHF    0.22591     NZDJPY    0.20412
# 5      CADJPY    0.22935     CHFJPY    0.22591     EURNZD    0.20412
# 6      GBPJPY    0.22711     EURNZD    0.21822     AUDCHF    0.20412
# 7      EURCAD    0.20773     GBPJPY    0.20787     GBPUSD    0.20000
# 8      AUDCAD    0.19485     EURJPY    0.20787     USDCAD    0.20000
# 9      NZDCAD    0.19025     NZDUSD    0.19094     GBPCHF    0.20000
# 10     NZDUSD    0.19025     AUDNZD    0.16667     GBPAUD    0.10483
# 11     GBPUSD    0.18684     NZDCHF    0.16667     GBPCAD    0.10483
# 12     EURGBP    0.17138     EURCAD    0.16477     CHFJPY    0.10483
# 13     AUDUSD    0.15743     AUDCHF    0.13608     EURAUD    0.10483
# 14     AUDJPY    0.15198     USDCHF    0.11111     AUDUSD    0.10483
# 15     EURNZD    0.12721     GBPUSD    0.10985     EURJPY    0.10483
# 16     GBPAUD    0.09829     EURAUD    0.08183     CADJPY    0.10050
# 17     EURAUD    0.08353     USDCAD    0.08183     AUDJPY    0.10050
# 18     EURCHF    0.07114     GBPCAD    0.05939     USDCHF    0.10050
# 19     CADCHF    0.06946     NZDJPY    0.05939     EURCAD    0.10050
# 20     NZDJPY    0.05506     USDJPY    0.05648     GBPJPY    0.10050
# 21     AUDCHF    0.04670     EURCHF    0.05455     EURCHF    0.10050
# 22     USDJPY    0.04670     AUDJPY    0.05455     NZDUSD    0.10050
# 23     NZDCHF    0.02341     EURGBP    0.02778     EURGBP    0.10050
# 24     GBPCAD    0.02150     GBPAUD    0.02746     NZDCHF    0.00000
# 25     GBPCHF    0.02150     AUDUSD    0.02746     CADCHF    0.00000
# 26     USDCAD    0.00970     CADCHF    0.00000     USDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.46429     USDCHF    0.66667  ...     USDCHF    0.23775
# 1      NZDCAD    0.46429     GBPUSD    0.66667  ...     NZDJPY    0.19910
# 2      CHFJPY    0.37796     EURUSD    0.66667  ...     EURUSD    0.19872
# 3      USDCHF    0.33929     NZDCAD    0.66667  ...     CADJPY    0.19612
# 4      GBPUSD    0.33929     EURCAD    0.58333  ...     GBPUSD    0.17485
# 5      AUDCAD    0.33929     EURNZD    0.53452  ...     AUDCAD    0.16386
# 6      EURCAD    0.33929     NZDUSD    0.53452  ...     USDJPY    0.15743
# 7      EURNZD    0.32733     AUDCAD    0.40825  ...     EURCAD    0.15743
# 8      NZDUSD    0.32733     CHFJPY    0.35635  ...     GBPAUD    0.13074
# 9      GBPCAD    0.26189     GBPCAD    0.35635  ...     AUDJPY    0.11613
# 10     EURCHF    0.21822     EURJPY    0.25000  ...     EURGBP    0.11613
# 11     AUDNZD    0.19643     GBPJPY    0.25000  ...     NZDCHF    0.11342
# 12     GBPCHF    0.19643     EURGBP    0.25000  ...     EURJPY    0.11342
# 13     USDCAD    0.19643     CADCHF    0.25000  ...     GBPCAD    0.09237
# 14     AUDCHF    0.18898     GBPCHF    0.25000  ...     AUDCHF    0.07711
# 15     NZDJPY    0.18898     AUDNZD    0.25000  ...     EURNZD    0.07711
# 16     GBPAUD    0.09449     AUDJPY    0.16667  ...     AUDNZD    0.07711
# 17     EURAUD    0.09449     GBPAUD    0.10206  ...     NZDUSD    0.07462
# 18     AUDUSD    0.09449     EURAUD    0.10206  ...     CADCHF    0.07099
# 19     NZDCHF    0.07143     AUDUSD    0.10206  ...     EURAUD    0.03846
# 20     GBPJPY    0.07143     AUDCHF    0.08909  ...     AUDUSD    0.03846
# 21     CADJPY    0.07143     EURCHF    0.08909  ...     EURCHF    0.03548
# 22     AUDJPY    0.07143     USDCAD    0.08909  ...     USDCAD    0.03548
# 23     EURGBP    0.07143     USDJPY    0.08909  ...     GBPJPY    0.02746
# 24     CADCHF    0.05455     NZDCHF    0.00000  ...     CHFJPY    0.00990
# 25     EURJPY    0.05455     CADJPY    0.00000  ...     GBPCHF    0.00990
# 26     USDJPY    0.05455     NZDJPY    0.00000  ...     NZDCAD    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.30826     GBPCAD    0.31449     USDCHF    0.32733
# 1      GBPCAD    0.27890     USDCHF    0.30151     AUDCAD    0.32733
# 2      USDCHF    0.24716     AUDCAD    0.30151     EURCAD    0.32733
# 3      CADJPY    0.23783     EURCAD    0.30151     NZDJPY    0.28868
# 4      GBPAUD    0.22172     NZDJPY    0.20412     GBPCHF    0.21822
# 5      AUDCAD    0.20180     GBPCHF    0.20000     NZDCAD    0.21822
# 6      EURCAD    0.18552     AUDUSD    0.10483     CADJPY    0.21822
# 7      EURJPY    0.16147     CHFJPY    0.10483     EURGBP    0.21822
# 8      EURNZD    0.14382     EURAUD    0.10483     AUDNZD    0.21822
# 9      EURAUD    0.14382     EURJPY    0.10483     EURUSD    0.21822
# 10     USDCAD    0.12585     GBPAUD    0.10483     EURCHF    0.16667
# 11     AUDJPY    0.12585     NZDCAD    0.10050     GBPCAD    0.12309
# 12     NZDUSD    0.12585     AUDJPY    0.10050     NZDUSD    0.11111
# 13     EURCHF    0.12585     CADJPY    0.10050     EURNZD    0.11111
# 14     EURGBP    0.10985     EURGBP    0.10050     USDJPY    0.11111
# 15     NZDCHF    0.10985     GBPJPY    0.10050     CADCHF    0.11111
# 16     EURUSD    0.10985     EURCHF    0.10050     EURJPY    0.11111
# 17     GBPCHF    0.10702     NZDUSD    0.10050     NZDCHF    0.05455
# 18     CADCHF    0.09513     EURUSD    0.10050     GBPUSD    0.05455
# 19     GBPUSD    0.08597     AUDNZD    0.10050     GBPJPY    0.05455
# 20     AUDUSD    0.08597     GBPUSD    0.00000     AUDJPY    0.05455
# 21     AUDCHF    0.06727     NZDCHF    0.00000     USDCAD    0.05455
# 22     CHFJPY    0.03257     AUDCHF    0.00000     AUDCHF    0.00000
# 23     USDJPY    0.03257     CADCHF    0.00000     GBPAUD    0.00000
# 24     AUDNZD    0.02746     EURNZD    0.00000     CHFJPY    0.00000
# 25     GBPJPY    0.01468     USDCAD    0.00000     EURAUD    0.00000
# 26     NZDCAD    0.00899     USDJPY    0.00000     AUDUSD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.53452
# 1      AUDCHF    0.52381
# 2      USDCAD    0.42857
# 3      AUDJPY    0.35635
# 4      EURCAD    0.35635
# 5      EURGBP    0.35635
# 6      GBPAUD    0.21822
# 7      AUDCAD    0.21822
# 8      NZDJPY    0.21822
# 9      AUDUSD    0.21822
# 10     NZDCHF    0.21822
# 11     CADJPY    0.21822
# 12     EURAUD    0.21822
# 13     EURJPY    0.08909
# 14     NZDCAD    0.08909
# 15     EURUSD    0.08909
# 16     AUDNZD    0.08909
# 17     GBPCHF    0.08909
# 18     GBPJPY    0.08909
# 19     GBPUSD    0.08909
# 20     CADCHF    0.08909
# 21     USDJPY    0.04762
# 22     GBPCAD    0.04762
# 23     EURNZD    0.04762
# 24     CHFJPY    0.04762
# 25     EURCHF    0.04762
# 26     NZDUSD    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
