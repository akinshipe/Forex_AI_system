# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 18:30:24.694207

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.30694     USDJPY    0.30556     GBPUSD    0.40825
# 1      GBPUSD    0.25223     AUDNZD    0.30208     AUDUSD    0.38516
# 2      NZDCAD    0.25223     GBPUSD    0.27217     AUDCAD    0.38516
# 3      USDCHF    0.21753     EURJPY    0.25000     NZDUSD    0.32824
# 4      EURUSD    0.20646     GBPCAD    0.19094     CHFJPY    0.32824
# 5      EURJPY    0.20646     CHFJPY    0.16477     NZDCAD    0.31180
# 6      CHFJPY    0.18286     AUDCAD    0.16477     USDJPY    0.28721
# 7      AUDCAD    0.17138     EURNZD    0.13608     USDCAD    0.28721
# 8      NZDUSD    0.16116     EURCAD    0.13608     CADJPY    0.25678
# 9      EURCAD    0.16116     USDCHF    0.11111     EURJPY    0.25000
# 10     CADCHF    0.16116     EURGBP    0.10985     NZDJPY    0.25000
# 11     AUDUSD    0.11613     EURAUD    0.08183     EURAUD    0.25000
# 12     AUDNZD    0.10123     AUDUSD    0.08183     AUDNZD    0.20412
# 13     EURNZD    0.08058     NZDCHF    0.08183     GBPCHF    0.20412
# 14     CADJPY    0.08058     NZDJPY    0.05648     AUDJPY    0.20412
# 15     AUDCHF    0.07114     GBPCHF    0.05455     EURGBP    0.16667
# 16     EURAUD    0.07114     NZDUSD    0.05455     AUDCHF    0.12309
# 17     GBPCHF    0.06580     USDCAD    0.05455     EURUSD    0.12309
# 18     AUDJPY    0.06204     CADJPY    0.05455     GBPCAD    0.08206
# 19     USDCAD    0.04516     EURUSD    0.05455     EURCAD    0.08206
# 20     NZDJPY    0.02988     CADCHF    0.05455     GBPJPY    0.08206
# 21     GBPCAD    0.02597     EURCHF    0.02778     EURNZD    0.08206
# 22     GBPAUD    0.02597     NZDCAD    0.02778     USDCHF    0.04167
# 23     EURCHF    0.02597     GBPAUD    0.02746     GBPAUD    0.00000
# 24     GBPJPY    0.00970     AUDJPY    0.02746     NZDCHF    0.00000
# 25     EURGBP    0.00970     GBPJPY    0.00000     CADCHF    0.00000
# 26     NZDCHF    0.00000     AUDCHF    0.00000     EURCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDCAD    0.42640     AUDNZD    0.50000  ...     GBPCAD    0.42767
# 1      AUDUSD    0.42640     GBPCAD    0.50000  ...     GBPCHF    0.33333
# 2      GBPUSD    0.37796     CADJPY    0.50000  ...     GBPUSD    0.31127
# 3      NZDCAD    0.35355     CADCHF    0.40825  ...     USDJPY    0.28123
# 4      AUDNZD    0.28868     USDCAD    0.40825  ...     EURCAD    0.24495
# 5      USDJPY    0.28868     GBPCHF    0.40825  ...     CADCHF    0.24495
# 6      NZDUSD    0.28868     AUDJPY    0.40825  ...     EURGBP    0.22935
# 7      GBPCHF    0.28868     EURAUD    0.32733  ...     AUDUSD    0.21246
# 8      CADJPY    0.28868     NZDCHF    0.32733  ...     EURUSD    0.19612
# 9      NZDJPY    0.20000     AUDCHF    0.32733  ...     GBPAUD    0.18094
# 10     EURAUD    0.20000     NZDJPY    0.32733  ...     EURCHF    0.14804
# 11     AUDCHF    0.20000     NZDUSD    0.32733  ...     NZDCAD    0.14744
# 12     GBPCAD    0.18898     AUDUSD    0.32733  ...     AUDCHF    0.14744
# 13     EURCAD    0.18898     AUDCAD    0.32733  ...     AUDCAD    0.14744
# 14     EURGBP    0.18898     GBPAUD    0.32733  ...     GBPJPY    0.14744
# 15     USDCAD    0.18898     NZDCAD    0.25000  ...     CHFJPY    0.11580
# 16     GBPJPY    0.09449     EURJPY    0.21822  ...     AUDJPY    0.11580
# 17     EURNZD    0.09449     USDCHF    0.21822  ...     USDCAD    0.11440
# 18     CHFJPY    0.09449     EURCAD    0.10206  ...     USDCHF    0.09869
# 19     AUDJPY    0.09449     GBPJPY    0.10206  ...     CADJPY    0.08165
# 20     EURCHF    0.09449     EURNZD    0.10206  ...     EURAUD    0.06553
# 21     EURUSD    0.09449     CHFJPY    0.10206  ...     NZDJPY    0.05046
# 22     GBPAUD    0.00000     USDJPY    0.10206  ...     AUDNZD    0.03309
# 23     EURJPY    0.00000     EURUSD    0.10206  ...     EURJPY    0.03269
# 24     NZDCHF    0.00000     EURGBP    0.10206  ...     EURNZD    0.00000
# 25     CADCHF    0.00000     GBPUSD    0.00000  ...     NZDCHF    0.00000
# 26     USDCHF    0.00000     EURCHF    0.00000  ...     NZDUSD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.43939     USDJPY    0.61616     USDJPY    0.66667
# 1      GBPCHF    0.41349     CHFJPY    0.41414     AUDJPY    0.49099
# 2      GBPCAD    0.39551     EURGBP    0.32824     CHFJPY    0.49099
# 3      EURGBP    0.35747     EURJPY    0.32824     GBPAUD    0.38889
# 4      CHFJPY    0.35747     GBPCHF    0.30151     EURJPY    0.38889
# 5      NZDCAD    0.24716     AUDJPY    0.30151     NZDCHF    0.38889
# 6      AUDJPY    0.22172     GBPAUD    0.30151     AUDCHF    0.28868
# 7      AUDNZD    0.22172     USDCHF    0.28721     EURAUD    0.28868
# 8      GBPUSD    0.20180     GBPCAD    0.19192     NZDJPY    0.28868
# 9      EURNZD    0.20180     CADJPY    0.17911     EURCAD    0.21822
# 10     EURCAD    0.20180     NZDJPY    0.12309     GBPJPY    0.21822
# 11     GBPAUD    0.18552     EURAUD    0.12309     EURGBP    0.21822
# 12     EURCHF    0.16477     EURCHF    0.10050     EURUSD    0.21822
# 13     EURJPY    0.16477     AUDNZD    0.10050     EURCHF    0.21822
# 14     NZDCHF    0.14382     GBPUSD    0.10050     AUDUSD    0.18464
# 15     CADCHF    0.12585     NZDCHF    0.10050     AUDCAD    0.18464
# 16     CADJPY    0.12585     CADCHF    0.10050     CADJPY    0.16667
# 17     USDCAD    0.12585     NZDCAD    0.06580     USDCHF    0.16667
# 18     NZDJPY    0.10702     AUDUSD    0.03161     GBPCHF    0.16667
# 19     GBPJPY    0.06727     AUDCAD    0.03161     CADCHF    0.11111
# 20     AUDCHF    0.06727     GBPJPY    0.01010     NZDUSD    0.11111
# 21     AUDCAD    0.04977     NZDUSD    0.01010     AUDNZD    0.11111
# 22     USDCHF    0.02746     EURCAD    0.01010     NZDCAD    0.06804
# 23     AUDUSD    0.00899     EURNZD    0.01010     GBPCAD    0.05455
# 24     NZDUSD    0.00899     AUDCHF    0.01010     GBPUSD    0.05455
# 25     EURAUD    0.00899     EURUSD    0.01010     EURNZD    0.05455
# 26     EURUSD    0.00899     USDCAD    0.01010     USDCAD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.81650
# 1      CHFJPY    0.81650
# 2      EURJPY    0.65465
# 3      EURUSD    0.40825
# 4      AUDJPY    0.40825
# 5      GBPJPY    0.40825
# 6      USDCHF    0.21822
# 7      GBPAUD    0.21822
# 8      AUDCAD    0.21822
# 9      AUDUSD    0.21822
# 10     NZDUSD    0.21822
# 11     NZDJPY    0.21822
# 12     AUDCHF    0.21822
# 13     NZDCHF    0.21822
# 14     EURAUD    0.21822
# 15     CADJPY    0.20000
# 16     AUDNZD    0.20000
# 17     GBPCAD    0.20000
# 18     GBPUSD    0.20000
# 19     EURCHF    0.20000
# 20     EURCAD    0.00000
# 21     EURNZD    0.00000
# 22     CADCHF    0.00000
# 23     GBPCHF    0.00000
# 24     USDCAD    0.00000
# 25     NZDCAD    0.00000
# 26     EURGBP    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           1
