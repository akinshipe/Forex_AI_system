# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:23:16.953135

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CADCHF    0.23753     EURJPY    0.30556     USDCHF    0.32824
# 1      AUDCHF    0.23753     USDCHF    0.30208     AUDCAD    0.20412
# 2      GBPJPY    0.14385     EURCHF    0.30208     USDJPY    0.20412
# 3      EURCHF    0.13613     GBPJPY    0.27217     NZDUSD    0.20412
# 4      USDCHF    0.13457     AUDJPY    0.21822     GBPAUD    0.20412
# 5      EURUSD    0.13457     NZDJPY    0.19094     CADCHF    0.20412
# 6      GBPAUD    0.12361     NZDUSD    0.13608     CHFJPY    0.16667
# 7      NZDCAD    0.11289     NZDCHF    0.13608     USDCAD    0.13363
# 8      NZDJPY    0.10417     GBPUSD    0.13608     NZDCHF    0.12309
# 9      AUDUSD    0.10417     USDJPY    0.13608     EURCAD    0.12309
# 10     GBPUSD    0.07258     GBPAUD    0.13608     GBPUSD    0.12309
# 11     AUDJPY    0.07258     EURNZD    0.13608     EURGBP    0.12309
# 12     EURGBP    0.07258     CADJPY    0.13608     AUDUSD    0.12309
# 13     EURAUD    0.06118     AUDCAD    0.11111     GBPCHF    0.08206
# 14     USDJPY    0.05313     GBPCHF    0.10985     NZDJPY    0.08206
# 15     NZDCHF    0.04120     USDCAD    0.10985     GBPCAD    0.04280
# 16     GBPCAD    0.04120     AUDUSD    0.08183     EURJPY    0.04280
# 17     CADJPY    0.04120     EURCAD    0.08183     EURAUD    0.04280
# 18     EURJPY    0.03364     CADCHF    0.05455     AUDCHF    0.04167
# 19     CHFJPY    0.02988     GBPCAD    0.05455     EURCHF    0.04167
# 20     GBPCHF    0.02150     EURUSD    0.05455     CADJPY    0.04167
# 21     EURCAD    0.02150     EURAUD    0.05455     EURUSD    0.04167
# 22     EURNZD    0.00990     EURGBP    0.02746     GBPJPY    0.00000
# 23     NZDUSD    0.00990     AUDCHF    0.02746     EURNZD    0.00000
# 24     AUDNZD    0.00990     CHFJPY    0.00000     AUDJPY    0.00000
# 25     USDCAD    0.00167     NZDCAD    0.00000     NZDCAD    0.00000
# 26     AUDCAD    0.00167     AUDNZD    0.00000     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.38889     CHFJPY    0.65465  ...     EURCAD    0.20064
# 1      CHFJPY    0.32733     USDCHF    0.60000  ...     EURJPY    0.16330
# 2      GBPCAD    0.28868     NZDUSD    0.60000  ...     EURGBP    0.16013
# 3      USDCAD    0.27217     EURNZD    0.60000  ...     NZDUSD    0.16013
# 4      EURNZD    0.21822     NZDCHF    0.60000  ...     EURNZD    0.16013
# 5      EURCAD    0.21822     AUDNZD    0.60000  ...     USDCAD    0.12157
# 6      NZDCHF    0.21822     AUDUSD    0.40825  ...     GBPJPY    0.12039
# 7      CADCHF    0.21822     EURAUD    0.40825  ...     NZDJPY    0.12039
# 8      AUDNZD    0.21822     NZDCAD    0.40825  ...     GBPAUD    0.12000
# 9      USDJPY    0.21822     AUDCHF    0.40825  ...     EURUSD    0.08165
# 10     NZDUSD    0.21822     NZDJPY    0.40825  ...     USDJPY    0.08058
# 11     GBPAUD    0.16667     GBPCAD    0.40825  ...     NZDCAD    0.08058
# 12     AUDCAD    0.16667     EURCAD    0.40825  ...     CHFJPY    0.08058
# 13     NZDJPY    0.16667     USDCAD    0.21822  ...     AUDNZD    0.08006
# 14     NZDCAD    0.11111     CADCHF    0.21822  ...     GBPUSD    0.08006
# 15     EURUSD    0.11111     GBPCHF    0.21822  ...     AUDCHF    0.08006
# 16     EURCHF    0.11111     EURJPY    0.21822  ...     CADCHF    0.08006
# 17     AUDUSD    0.11111     AUDJPY    0.20000  ...     AUDCAD    0.04052
# 18     AUDCHF    0.11111     EURUSD    0.20000  ...     EURAUD    0.04013
# 19     GBPCHF    0.05455     GBPAUD    0.20000  ...     GBPCHF    0.04013
# 20     AUDJPY    0.05455     USDJPY    0.20000  ...     AUDUSD    0.04013
# 21     GBPUSD    0.05455     EURCHF    0.20000  ...     GBPCAD    0.04000
# 22     EURGBP    0.05455     GBPJPY    0.00000  ...     NZDCHF    0.04000
# 23     EURJPY    0.00000     CADJPY    0.00000  ...     CADJPY    0.04000
# 24     EURAUD    0.00000     GBPUSD    0.00000  ...     EURCHF    0.00000
# 25     CADJPY    0.00000     AUDCAD    0.00000  ...     AUDJPY    0.00000
# 26     GBPJPY    0.00000     EURGBP    0.00000  ...     USDCHF    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPAUD    0.33333     EURCAD    0.39394     EURUSD    0.60010
# 1      USDJPY    0.33333     USDCAD    0.37284     USDCAD    0.53452
# 2      EURJPY    0.27217     EURUSD    0.32824     EURCAD    0.33929
# 3      EURCAD    0.26726     GBPAUD    0.30151     USDJPY    0.33929
# 4      USDCHF    0.20180     USDJPY    0.30151     GBPAUD    0.32733
# 5      EURGBP    0.20180     EURAUD    0.24232     USDCHF    0.32733
# 6      USDCAD    0.20180     USDCHF    0.21212     NZDCAD    0.21822
# 7      EURNZD    0.20000     GBPUSD    0.19192     EURCHF    0.21822
# 8      GBPUSD    0.20000     EURJPY    0.17911     AUDUSD    0.21822
# 9      CHFJPY    0.14142     CHFJPY    0.12309     GBPCHF    0.19643
# 10     NZDJPY    0.13363     AUDCHF    0.12309     GBPUSD    0.19643
# 11     AUDJPY    0.13363     NZDCAD    0.10050     CHFJPY    0.19643
# 12     GBPCAD    0.13363     AUDCAD    0.10050     EURAUD    0.18898
# 13     EURUSD    0.13363     AUDJPY    0.10050     CADJPY    0.09449
# 14     EURCHF    0.06727     EURNZD    0.10050     GBPJPY    0.09449
# 15     AUDCHF    0.06727     AUDNZD    0.10050     GBPCAD    0.09449
# 16     GBPCHF    0.06727     GBPJPY    0.10050     EURJPY    0.09449
# 17     NZDUSD    0.06667     CADCHF    0.10050     AUDJPY    0.07143
# 18     NZDCAD    0.06667     NZDUSD    0.10050     EURNZD    0.07143
# 19     CADJPY    0.06667     EURCHF    0.08206     EURGBP    0.07143
# 20     AUDNZD    0.06667     CADJPY    0.08206     NZDCHF    0.07143
# 21     GBPJPY    0.06667     GBPCAD    0.03161     CADCHF    0.07143
# 22     NZDCHF    0.06667     NZDCHF    0.01010     NZDUSD    0.07143
# 23     EURAUD    0.00000     GBPCHF    0.01010     AUDNZD    0.07143
# 24     AUDCAD    0.00000     NZDJPY    0.01010     AUDCHF    0.05455
# 25     CADCHF    0.00000     AUDUSD    0.01010     NZDJPY    0.05455
# 26     AUDUSD    0.00000     EURGBP    0.01010     AUDCAD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      EURUSD    0.81650
# 1      USDJPY    0.81650
# 2      GBPUSD    0.66667
# 3      CHFJPY    0.53452
# 4      USDCAD    0.53452
# 5      GBPCHF    0.53452
# 6      AUDJPY    0.40825
# 7      GBPAUD    0.40825
# 8      USDCHF    0.40825
# 9      EURCHF    0.40825
# 10     EURJPY    0.35635
# 11     AUDCHF    0.25000
# 12     AUDCAD    0.25000
# 13     EURAUD    0.25000
# 14     EURCAD    0.16667
# 15     NZDJPY    0.16667
# 16     CADJPY    0.16667
# 17     NZDCAD    0.16667
# 18     EURGBP    0.16667
# 19     GBPCAD    0.16667
# 20     AUDUSD    0.16667
# 21     GBPJPY    0.10206
# 22     CADCHF    0.08909
# 23     EURNZD    0.00000
# 24     NZDCHF    0.00000
# 25     NZDUSD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
