# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 11:42:20.105040

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.34613     NZDCAD    0.35460     NZDCAD    0.66375
# 1      EURJPY    0.33561     AUDCAD    0.35460     EURUSD    0.59914
# 2      GBPJPY    0.32718     GBPJPY    0.30556     NZDUSD    0.59914
# 3      CADJPY    0.29778     EURUSD    0.30208     USDCHF    0.53846
# 4      USDCHF    0.23153     EURNZD    0.25000     AUDCAD    0.52414
# 5      AUDCAD    0.22531     EURAUD    0.25000     EURNZD    0.48038
# 6      NZDCAD    0.21506     CADJPY    0.24716     GBPUSD    0.45303
# 7      NZDUSD    0.21506     GBPCHF    0.24716     GBPJPY    0.38982
# 8      CHFJPY    0.21506     GBPUSD    0.21822     EURCAD    0.38982
# 9      GBPUSD    0.17898     NZDUSD    0.21822     GBPAUD    0.31868
# 10     EURCAD    0.16871     AUDCHF    0.21822     USDJPY    0.25163
# 11     GBPCHF    0.16864     EURGBP    0.19094     AUDUSD    0.25163
# 12     GBPAUD    0.14943     GBPAUD    0.16477     EURAUD    0.25163
# 13     AUDJPY    0.14368     USDCHF    0.11111     EURJPY    0.24232
# 14     AUDNZD    0.12157     NZDCHF    0.10985     EURGBP    0.24232
# 15     AUDUSD    0.12157     CADCHF    0.08472     USDCAD    0.24232
# 16     NZDJPY    0.11119     EURCAD    0.08183     NZDCHF    0.17911
# 17     USDCAD    0.10895     AUDJPY    0.08183     CADJPY    0.17911
# 18     NZDCHF    0.07357     AUDNZD    0.08183     NZDJPY    0.17911
# 19     USDJPY    0.06732     GBPCAD    0.05648     GBPCHF    0.17911
# 20     EURCHF    0.06204     AUDUSD    0.05648     AUDCHF    0.17118
# 21     EURAUD    0.04052     USDJPY    0.05648     AUDJPY    0.17118
# 22     EURNZD    0.04052     USDCAD    0.05455     CADCHF    0.09890
# 23     AUDCHF    0.02764     EURJPY    0.02778     CHFJPY    0.04280
# 24     GBPCAD    0.01198     NZDJPY    0.02778     EURCHF    0.03161
# 25     CADCHF    0.01198     CHFJPY    0.02746     GBPCAD    0.02288
# 26     EURGBP    0.00649     EURCHF    0.00000     AUDNZD    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.75593     NZDCAD    0.65465  ...     AUDNZD    0.24019
# 1      AUDCAD    0.75593     AUDCAD    0.65465  ...     AUDCAD    0.20646
# 2      NZDUSD    0.66144     NZDUSD    0.65465  ...     EURCAD    0.19872
# 3      GBPUSD    0.57735     GBPAUD    0.65465  ...     EURUSD    0.19678
# 4      EURUSD    0.57735     EURGBP    0.53452  ...     GBPCAD    0.18254
# 5      GBPAUD    0.57735     GBPUSD    0.53452  ...     GBPUSD    0.16871
# 6      USDCHF    0.50000     EURUSD    0.53452  ...     USDCHF    0.15573
# 7      EURNZD    0.50000     AUDUSD    0.53452  ...     USDJPY    0.15573
# 8      EURAUD    0.50000     EURAUD    0.53452  ...     AUDJPY    0.11613
# 9      EURGBP    0.50000     GBPJPY    0.52381  ...     CADJPY    0.11440
# 10     AUDUSD    0.50000     EURNZD    0.42857  ...     NZDJPY    0.11328
# 11     GBPJPY    0.47246     USDCHF    0.42857  ...     GBPCHF    0.09237
# 12     USDJPY    0.42640     USDJPY    0.42857  ...     GBPAUD    0.08760
# 13     USDCAD    0.37796     GBPCHF    0.35635  ...     EURAUD    0.08006
# 14     NZDJPY    0.28868     CADJPY    0.35635  ...     EURJPY    0.07258
# 15     EURJPY    0.28868     NZDJPY    0.35635  ...     NZDCHF    0.07099
# 16     AUDCHF    0.28868     USDCAD    0.35635  ...     CADCHF    0.07099
# 17     AUDJPY    0.28868     AUDCHF    0.21822  ...     NZDUSD    0.04903
# 18     CADCHF    0.20000     CHFJPY    0.21822  ...     NZDCAD    0.04903
# 19     GBPCAD    0.20000     EURJPY    0.21822  ...     EURCHF    0.04516
# 20     CADJPY    0.18898     EURCAD    0.21822  ...     EURGBP    0.03846
# 21     EURCAD    0.18898     EURCHF    0.21822  ...     CHFJPY    0.03269
# 22     GBPCHF    0.18898     AUDJPY    0.21822  ...     GBPJPY    0.01747
# 23     NZDCHF    0.10000     AUDNZD    0.21822  ...     USDCAD    0.00321
# 24     EURCHF    0.09449     GBPCAD    0.08909  ...     AUDCHF    0.00321
# 25     CHFJPY    0.09449     NZDCHF    0.04762  ...     AUDUSD    0.00000
# 26     AUDNZD    0.00000     CADCHF    0.04762  ...     EURNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDCAD    0.33929     EURCAD    0.38982     NZDUSD    0.56408
# 1      EURCAD    0.33929     EURUSD    0.38516     EURUSD    0.49237
# 2      EURUSD    0.27866     NZDUSD    0.38516     GBPUSD    0.49237
# 3      GBPCAD    0.25882     USDCHF    0.31868     AUDNZD    0.45227
# 4      USDCHF    0.21822     AUDCAD    0.31449     EURNZD    0.42640
# 5      GBPUSD    0.20536     USDJPY    0.25163     AUDUSD    0.42640
# 6      NZDCAD    0.20536     AUDUSD    0.25163     USDJPY    0.36364
# 7      NZDUSD    0.20536     EURNZD    0.25163     EURCAD    0.34247
# 8      AUDNZD    0.19643     GBPUSD    0.24232     AUDCAD    0.34247
# 9      AUDUSD    0.15714     USDCAD    0.24232     NZDCAD    0.34247
# 10     USDJPY    0.15714     NZDCAD    0.24232     EURCHF    0.26189
# 11     GBPCHF    0.12585     AUDNZD    0.20588     USDCAD    0.26189
# 12     NZDJPY    0.08183     EURGBP    0.17911     AUDCHF    0.18464
# 13     EURNZD    0.08183     GBPAUD    0.09890     AUDJPY    0.18464
# 14     EURJPY    0.08183     CADCHF    0.09890     GBPAUD    0.18464
# 15     EURGBP    0.07143     AUDCHF    0.04280     EURJPY    0.18464
# 16     AUDCHF    0.07143     CHFJPY    0.04280     NZDJPY    0.12309
# 17     AUDJPY    0.06250     AUDJPY    0.04280     EURAUD    0.10660
# 18     USDCAD    0.06250     NZDCHF    0.03161     USDCHF    0.10660
# 19     GBPJPY    0.05455     GBPJPY    0.03161     GBPCAD    0.10660
# 20     EURAUD    0.05455     EURJPY    0.03161     NZDCHF    0.10660
# 21     CADCHF    0.01849     CADJPY    0.03161     CADCHF    0.10660
# 22     GBPAUD    0.00899     NZDJPY    0.03161     EURGBP    0.10660
# 23     CADJPY    0.00899     EURCHF    0.03161     GBPJPY    0.04029
# 24     NZDCHF    0.00899     GBPCHF    0.03161     CADJPY    0.04029
# 25     CHFJPY    0.00899     GBPCAD    0.02288     CHFJPY    0.04029
# 26     EURCHF    0.00000     EURAUD    0.02288     GBPCHF    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDNZD    0.76376
# 1      NZDUSD    0.65465
# 2      GBPUSD    0.53452
# 3      EURUSD    0.53452
# 4      AUDUSD    0.53452
# 5      USDJPY    0.42857
# 6      EURNZD    0.42857
# 7      USDCAD    0.35635
# 8      CADJPY    0.35635
# 9      NZDJPY    0.35635
# 10     EURJPY    0.21822
# 11     GBPAUD    0.21822
# 12     AUDJPY    0.21822
# 13     CHFJPY    0.21822
# 14     AUDCHF    0.21822
# 15     AUDCAD    0.21822
# 16     EURCHF    0.21822
# 17     NZDCAD    0.21822
# 18     EURCAD    0.21822
# 19     EURGBP    0.08909
# 20     EURAUD    0.08909
# 21     GBPCAD    0.08909
# 22     GBPCHF    0.08909
# 23     GBPJPY    0.04762
# 24     NZDCHF    0.04762
# 25     CADCHF    0.04762
# 26     USDCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
