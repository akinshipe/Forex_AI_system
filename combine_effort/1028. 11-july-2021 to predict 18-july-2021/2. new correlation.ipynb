# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 22:52:31.829767

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.36362     CADJPY    0.36711     AUDNZD    0.28721
# 1      EURUSD    0.35897     CHFJPY    0.36711     GBPCHF    0.28721
# 2      EURJPY    0.32451     EURJPY    0.35635     CADJPY    0.28721
# 3      GBPJPY    0.28492     EURUSD    0.30208     GBPJPY    0.28721
# 4      USDCHF    0.24019     GBPJPY    0.27696     EURUSD    0.21212
# 5      CADJPY    0.23753     NZDCAD    0.24716     NZDCAD    0.21212
# 6      AUDNZD    0.23684     GBPCHF    0.20787     AUDCHF    0.21212
# 7      GBPUSD    0.19682     AUDCAD    0.19094     AUDUSD    0.17911
# 8      NZDCAD    0.19678     NZDCHF    0.16667     CADCHF    0.17911
# 9      EURGBP    0.16871     USDCHF    0.16477     EURAUD    0.12309
# 10     EURCAD    0.16386     AUDNZD    0.14434     AUDCAD    0.12309
# 11     NZDUSD    0.15573     USDJPY    0.11111     NZDJPY    0.12309
# 12     AUDJPY    0.15573     AUDCHF    0.10985     EURNZD    0.12309
# 13     EURNZD    0.12179     NZDUSD    0.10985     USDCAD    0.10050
# 14     AUDUSD    0.11613     AUDJPY    0.10985     NZDCHF    0.10050
# 15     AUDCAD    0.11613     GBPUSD    0.08472     GBPUSD    0.10050
# 16     NZDJPY    0.11342     EURCAD    0.08183     EURGBP    0.08206
# 17     AUDCHF    0.08760     EURNZD    0.08183     GBPAUD    0.08206
# 18     GBPAUD    0.08760     EURGBP    0.05648     CHFJPY    0.08206
# 19     EURAUD    0.08353     GBPCAD    0.03077     NZDUSD    0.08206
# 20     USDJPY    0.04167     EURCHF    0.02778     USDJPY    0.08206
# 21     NZDCHF    0.03269     GBPAUD    0.02746     EURJPY    0.06580
# 22     EURCHF    0.03269     CADCHF    0.00000     GBPCAD    0.03161
# 23     GBPCHF    0.03002     EURAUD    0.00000     EURCAD    0.01010
# 24     CADCHF    0.01352     AUDUSD    0.00000     AUDJPY    0.01010
# 25     GBPCAD    0.00990     NZDJPY    0.00000     EURCHF    0.01010
# 26     USDCAD    0.00649     USDCAD    0.00000     USDCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CHFJPY    0.49237     USDCHF    0.81650  ...     GBPUSD    0.24510
# 1      EURUSD    0.49099     EURUSD    0.81650  ...     USDCHF    0.24175
# 2      USDCHF    0.38889     NZDCAD    0.66667  ...     CADJPY    0.21914
# 3      GBPUSD    0.38889     CHFJPY    0.61237  ...     EURUSD    0.20646
# 4      NZDCAD    0.32733     GBPUSD    0.58333  ...     USDJPY    0.19678
# 5      AUDCAD    0.32733     EURNZD    0.53452  ...     NZDJPY    0.17459
# 6      CADJPY    0.21822     NZDUSD    0.53452  ...     EURCAD    0.15198
# 7      EURCAD    0.21822     AUDCAD    0.40825  ...     AUDJPY    0.14368
# 8      GBPJPY    0.21822     EURCAD    0.40825  ...     AUDCAD    0.13636
# 9      AUDNZD    0.21822     EURJPY    0.40825  ...     EURJPY    0.12928
# 10     EURCHF    0.21822     GBPJPY    0.40825  ...     GBPCAD    0.11289
# 11     GBPCHF    0.21822     AUDNZD    0.40825  ...     GBPAUD    0.10123
# 12     GBPCAD    0.18464     NZDCHF    0.25000  ...     NZDCHF    0.09869
# 13     AUDCHF    0.16667     AUDCHF    0.25000  ...     GBPCHF    0.07722
# 14     NZDJPY    0.16667     AUDJPY    0.25000  ...     EURGBP    0.06204
# 15     EURNZD    0.16667     USDCAD    0.25000  ...     AUDCHF    0.06204
# 16     CADCHF    0.11111     USDJPY    0.25000  ...     NZDUSD    0.06204
# 17     AUDUSD    0.11111     EURCHF    0.16667  ...     USDCAD    0.06204
# 18     EURGBP    0.11111     GBPCHF    0.16667  ...     AUDNZD    0.06204
# 19     GBPAUD    0.11111     CADJPY    0.16667  ...     NZDCAD    0.05519
# 20     AUDJPY    0.05455     EURGBP    0.16667  ...     CADCHF    0.04423
# 21     NZDCHF    0.05455     GBPCAD    0.10206  ...     EURNZD    0.03548
# 22     USDCAD    0.05455     CADCHF    0.08909  ...     AUDUSD    0.02597
# 23     USDJPY    0.05455     GBPAUD    0.08909  ...     EURCHF    0.01645
# 24     NZDUSD    0.05455     EURAUD    0.08909  ...     EURAUD    0.00970
# 25     EURAUD    0.00000     AUDUSD    0.08909  ...     CHFJPY    0.00672
# 26     EURJPY    0.00000     NZDJPY    0.00000  ...     GBPJPY    0.00345
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDJPY    0.34238     USDCHF    0.49237     USDCHF    0.49099
# 1      USDCHF    0.31175     GBPCAD    0.38516     AUDCAD    0.46429
# 2      GBPCAD    0.30241     AUDCAD    0.37500     GBPCHF    0.33929
# 3      NZDCHF    0.22591     NZDJPY    0.37500     EURCAD    0.33929
# 4      GBPCHF    0.19623     EURUSD    0.28721     AUDNZD    0.33929
# 5      EURUSD    0.17216     EURCAD    0.28721     EURUSD    0.33929
# 6      AUDJPY    0.17216     GBPCHF    0.25000     NZDJPY    0.32733
# 7      NZDUSD    0.17216     AUDNZD    0.25000     GBPCAD    0.26189
# 8      AUDCAD    0.15714     NZDCHF    0.20412     GBPUSD    0.21822
# 9      EURNZD    0.15714     GBPUSD    0.20412     CADJPY    0.19643
# 10     GBPUSD    0.14833     CADJPY    0.16667     NZDCAD    0.19643
# 11     CADJPY    0.13876     USDJPY    0.16667     USDJPY    0.19643
# 12     EURCAD    0.12016     EURJPY    0.13363     EURJPY    0.18898
# 13     GBPAUD    0.10702     AUDJPY    0.12309     EURAUD    0.18898
# 14     EURJPY    0.10566     NZDCAD    0.08206     USDCAD    0.07143
# 15     AUDNZD    0.09782     EURCHF    0.08206     EURCHF    0.07143
# 16     EURCHF    0.08472     AUDCHF    0.08206     NZDCHF    0.07143
# 17     USDJPY    0.08472     AUDUSD    0.04280     GBPJPY    0.07143
# 18     EURAUD    0.06917     CADCHF    0.04280     NZDUSD    0.07143
# 19     AUDUSD    0.06917     GBPAUD    0.04167     AUDJPY    0.07143
# 20     USDCAD    0.06917     CHFJPY    0.04167     AUDUSD    0.05455
# 21     CADCHF    0.04891     EURAUD    0.04167     GBPAUD    0.05455
# 22     AUDCHF    0.03257     EURNZD    0.04167     EURNZD    0.05455
# 23     NZDCAD    0.03257     NZDUSD    0.04167     AUDCHF    0.05455
# 24     GBPJPY    0.01043     GBPJPY    0.04167     CADCHF    0.05455
# 25     CHFJPY    0.00478     EURGBP    0.04167     EURGBP    0.05455
# 26     EURGBP    0.00478     USDCAD    0.00000     CHFJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.81650
# 1      EURCAD    0.40825
# 2      AUDCAD    0.40825
# 3      NZDJPY    0.40825
# 4      AUDNZD    0.40825
# 5      EURUSD    0.40825
# 6      EURGBP    0.25000
# 7      NZDCAD    0.25000
# 8      USDJPY    0.25000
# 9      USDCAD    0.25000
# 10     CADJPY    0.25000
# 11     GBPCHF    0.16667
# 12     EURCHF    0.16667
# 13     AUDCHF    0.16667
# 14     NZDCHF    0.16667
# 15     GBPUSD    0.16667
# 16     AUDJPY    0.16667
# 17     CHFJPY    0.10206
# 18     GBPCAD    0.10206
# 19     EURNZD    0.08909
# 20     AUDUSD    0.08909
# 21     EURAUD    0.08909
# 22     NZDUSD    0.08909
# 23     CADCHF    0.08909
# 24     GBPAUD    0.08909
# 25     EURJPY    0.00000
# 26     GBPJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
