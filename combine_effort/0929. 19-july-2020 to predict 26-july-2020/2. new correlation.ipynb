# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:06:10.573067

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.34542     USDJPY    0.30556     GBPUSD    0.40825
# 1      NZDCAD    0.25223     AUDNZD    0.30208     USDJPY    0.37500
# 2      GBPUSD    0.25223     GBPUSD    0.27217     NZDUSD    0.32824
# 3      USDCHF    0.21753     EURJPY    0.19767     NZDCAD    0.31180
# 4      EURJPY    0.17138     EURCAD    0.19094     AUDUSD    0.31180
# 5      EURUSD    0.17138     GBPCAD    0.19094     AUDCAD    0.31180
# 6      CADCHF    0.16116     AUDCAD    0.16477     USDCAD    0.28721
# 7      EURCAD    0.16116     CHFJPY    0.16477     CHFJPY    0.25000
# 8      NZDUSD    0.16116     EURAUD    0.13608     NZDJPY    0.25000
# 9      CHFJPY    0.14804     NZDJPY    0.11111     EURAUD    0.25000
# 10     AUDCAD    0.13636     USDCHF    0.11111     GBPCHF    0.20412
# 11     CADJPY    0.11613     CADCHF    0.10985     EURJPY    0.17118
# 12     AUDCHF    0.10714     NZDUSD    0.10985     EURGBP    0.16667
# 13     AUDJPY    0.09869     USDCAD    0.10985     CADJPY    0.16667
# 14     AUDUSD    0.08058     EURGBP    0.10985     AUDJPY    0.12309
# 15     EURNZD    0.08058     NZDCHF    0.08183     AUDNZD    0.12309
# 16     EURAUD    0.07114     AUDUSD    0.08183     EURUSD    0.12309
# 17     AUDNZD    0.06580     EURNZD    0.08183     GBPAUD    0.08206
# 18     GBPCHF    0.06580     GBPCHF    0.05455     EURCAD    0.08206
# 19     USDCAD    0.04516     CADJPY    0.05455     GBPJPY    0.08206
# 20     NZDJPY    0.02988     NZDCAD    0.02778     EURNZD    0.08206
# 21     GBPAUD    0.02597     EURCHF    0.02746     AUDCHF    0.04167
# 22     GBPCAD    0.02597     GBPAUD    0.02746     USDCHF    0.04167
# 23     GBPJPY    0.00970     AUDJPY    0.02746     GBPCAD    0.00000
# 24     EURCHF    0.00970     AUDCHF    0.00000     NZDCHF    0.00000
# 25     EURGBP    0.00970     GBPJPY    0.00000     CADCHF    0.00000
# 26     NZDCHF    0.00000     EURUSD    0.00000     EURCHF    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      GBPCHF    0.37796     AUDNZD    0.33333  ...     GBPCAD    0.42767
# 1      GBPUSD    0.37796     CADCHF    0.33333  ...     GBPCHF    0.33333
# 2      NZDCAD    0.35355     EURNZD    0.33333  ...     GBPUSD    0.31127
# 3      AUDCAD    0.35355     GBPCAD    0.33333  ...     USDJPY    0.25000
# 4      AUDUSD    0.35355     USDCAD    0.33333  ...     AUDUSD    0.24495
# 5      EURGBP    0.28868     GBPUSD    0.33333  ...     CADCHF    0.24495
# 6      EURCAD    0.28868     GBPCHF    0.33333  ...     EURCAD    0.24495
# 7      AUDNZD    0.28868     CADJPY    0.33333  ...     EURGBP    0.22935
# 8      USDJPY    0.28868     GBPJPY    0.27217  ...     EURUSD    0.22935
# 9      NZDUSD    0.28868     NZDCHF    0.27217  ...     GBPAUD    0.18094
# 10     NZDJPY    0.20000     AUDJPY    0.27217  ...     AUDCAD    0.18094
# 11     EURAUD    0.20000     EURCHF    0.27217  ...     AUDCHF    0.18094
# 12     USDCAD    0.18898     NZDUSD    0.27217  ...     EURCHF    0.18021
# 13     CADJPY    0.18898     NZDJPY    0.27217  ...     NZDCAD    0.14744
# 14     AUDCHF    0.10660     EURAUD    0.27217  ...     GBPJPY    0.14744
# 15     EURJPY    0.10000     EURCAD    0.21822  ...     USDCAD    0.11440
# 16     USDCHF    0.10000     AUDCAD    0.21822  ...     USDCHF    0.09869
# 17     GBPAUD    0.10000     NZDCAD    0.21822  ...     AUDJPY    0.08333
# 18     GBPCAD    0.09449     EURGBP    0.21822  ...     CHFJPY    0.08333
# 19     EURNZD    0.09449     GBPAUD    0.21822  ...     EURJPY    0.06553
# 20     GBPJPY    0.09449     AUDCHF    0.21822  ...     EURAUD    0.06553
# 21     CADCHF    0.09449     CHFJPY    0.21822  ...     NZDJPY    0.05046
# 22     CHFJPY    0.00000     AUDUSD    0.21822  ...     CADJPY    0.04903
# 23     AUDJPY    0.00000     USDJPY    0.21822  ...     NZDCHF    0.00000
# 24     NZDCHF    0.00000     EURUSD    0.21822  ...     EURNZD    0.00000
# 25     EURUSD    0.00000     EURJPY    0.16667  ...     NZDUSD    0.00000
# 26     EURCHF    0.00000     USDCHF    0.16667  ...     AUDNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.38889     USDJPY    0.53340     USDJPY    0.66667
# 1      GBPCHF    0.35460     EURGBP    0.32824     AUDJPY    0.38889
# 2      GBPCAD    0.32733     CHFJPY    0.32824     CHFJPY    0.38889
# 3      EURGBP    0.30208     GBPCHF    0.30151     NZDCHF    0.38889
# 4      CHFJPY    0.30208     USDCHF    0.28721     USDCHF    0.28868
# 5      EURNZD    0.21822     EURJPY    0.24232     NZDJPY    0.28868
# 6      EURJPY    0.19767     GBPAUD    0.21212     EURAUD    0.28868
# 7      EURCAD    0.19094     AUDJPY    0.21212     EURJPY    0.28868
# 8      NZDCAD    0.16667     EURAUD    0.12309     GBPAUD    0.28868
# 9      AUDJPY    0.16477     NZDJPY    0.12309     GBPJPY    0.21822
# 10     AUDNZD    0.16477     EURCHF    0.10050     CADCHF    0.21822
# 11     EURCHF    0.16477     CADCHF    0.10050     AUDCHF    0.18464
# 12     AUDCHF    0.13608     NZDCHF    0.10050     EURCAD    0.11111
# 13     GBPUSD    0.13608     GBPUSD    0.10050     EURGBP    0.11111
# 14     NZDJPY    0.11111     GBPCAD    0.10050     EURCHF    0.11111
# 15     CADCHF    0.10985     AUDCHF    0.08206     NZDUSD    0.11111
# 16     GBPAUD    0.10985     CADJPY    0.08206     EURUSD    0.11111
# 17     USDCAD    0.10985     NZDCAD    0.06580     AUDNZD    0.11111
# 18     AUDCAD    0.10985     AUDCAD    0.06580     AUDUSD    0.06804
# 19     NZDCHF    0.08183     AUDUSD    0.06580     AUDCAD    0.06804
# 20     AUDUSD    0.05455     EURNZD    0.01010     NZDCAD    0.06804
# 21     CADJPY    0.05455     EURCAD    0.01010     GBPUSD    0.05455
# 22     USDCHF    0.02778     NZDUSD    0.01010     GBPCAD    0.05455
# 23     NZDUSD    0.02746     GBPJPY    0.01010     GBPCHF    0.05455
# 24     GBPJPY    0.00000     EURUSD    0.01010     EURNZD    0.05455
# 25     EURAUD    0.00000     USDCAD    0.01010     CADJPY    0.05455
# 26     EURUSD    0.00000     AUDNZD    0.01010     USDCAD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    0.65465
# 1      CHFJPY    0.65465
# 2      USDCHF    0.50000
# 3      EURJPY    0.50000
# 4      GBPJPY    0.40825
# 5      NZDJPY    0.40825
# 6      NZDUSD    0.40825
# 7      AUDJPY    0.40825
# 8      EURAUD    0.40825
# 9      NZDCHF    0.40825
# 10     NZDCAD    0.21822
# 11     AUDCAD    0.21822
# 12     EURCAD    0.21822
# 13     GBPAUD    0.21822
# 14     EURGBP    0.21822
# 15     AUDCHF    0.21822
# 16     AUDUSD    0.21822
# 17     EURUSD    0.21822
# 18     GBPCAD    0.20000
# 19     GBPUSD    0.20000
# 20     CADCHF    0.20000
# 21     EURNZD    0.20000
# 22     CADJPY    0.20000
# 23     GBPCHF    0.20000
# 24     USDCAD    0.20000
# 25     AUDNZD    0.20000
# 26     EURCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
