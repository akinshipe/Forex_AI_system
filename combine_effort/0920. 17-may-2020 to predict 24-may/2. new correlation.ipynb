# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 10:49:35.249911

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.44000     USDJPY    0.53035     USDCHF    0.41414
# 1      USDJPY    0.40291     USDCHF    0.26726     USDJPY    0.41414
# 2      USDCHF    0.36000     GBPUSD    0.26726     AUDCAD    0.41414
# 3      NZDUSD    0.32026     NZDCAD    0.26726     GBPUSD    0.41414
# 4      EURJPY    0.32026     AUDCAD    0.26726     EURJPY    0.39394
# 5      CHFJPY    0.28365     EURJPY    0.26726     NZDUSD    0.37284
# 6      EURUSD    0.28090     CADJPY    0.20536     AUDUSD    0.32824
# 7      AUDUSD    0.28090     NZDUSD    0.19643     EURAUD    0.32824
# 8      GBPUSD    0.28000     CHFJPY    0.14382     CHFJPY    0.30151
# 9      AUDCAD    0.24019     EURUSD    0.12585     EURUSD    0.24232
# 10     NZDJPY    0.16330     AUDUSD    0.12585     USDCAD    0.24232
# 11     CADCHF    0.16013     AUDJPY    0.12585     AUDCHF    0.24232
# 12     GBPJPY    0.16013     NZDJPY    0.08183     NZDJPY    0.19192
# 13     AUDNZD    0.12157     AUDNZD    0.08183     EURCAD    0.19192
# 14     GBPAUD    0.08058     EURNZD    0.07143     AUDNZD    0.17911
# 15     NZDCHF    0.08006     CADCHF    0.07143     GBPAUD    0.15352
# 16     GBPCAD    0.08006     USDCAD    0.07143     EURCHF    0.15352
# 17     EURCAD    0.08006     EURGBP    0.07143     GBPJPY    0.12309
# 18     CADJPY    0.08006     GBPJPY    0.06250     CADCHF    0.12309
# 19     EURCHF    0.04052     GBPCAD    0.06250     EURNZD    0.12309
# 20     GBPCHF    0.04013     NZDCHF    0.06250     CADJPY    0.12309
# 21     EURAUD    0.04000     EURCAD    0.06250     GBPCAD    0.10050
# 22     EURNZD    0.04000     GBPAUD    0.05455     AUDJPY    0.10050
# 23     AUDCHF    0.00000     EURCHF    0.01849     NZDCAD    0.10050
# 24     AUDJPY    0.00000     GBPCHF    0.00899     EURGBP    0.10050
# 25     USDCAD    0.00000     EURAUD    0.00000     NZDCHF    0.03161
# 26     EURGBP    0.00000     AUDCHF    0.00000     GBPCHF    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDCAD    0.60010     USDJPY    0.66667  ...     GBPCAD    0.39906
# 1      USDJPY    0.49099     NZDUSD    0.66667  ...     AUDUSD    0.37888
# 2      NZDUSD    0.49099     GBPUSD    0.66667  ...     GBPUSD    0.36470
# 3      EURNZD    0.49099     AUDUSD    0.58333  ...     GBPCHF    0.35286
# 4      GBPUSD    0.49099     NZDCAD    0.58333  ...     EURGBP    0.33092
# 5      NZDCAD    0.46429     AUDCAD    0.58333  ...     AUDCHF    0.33092
# 6      AUDUSD    0.46429     USDCHF    0.53452  ...     GBPJPY    0.33092
# 7      EURAUD    0.46429     EURUSD    0.53452  ...     AUDCAD    0.33092
# 8      EURJPY    0.46429     USDCAD    0.53452  ...     EURUSD    0.29758
# 9      CHFJPY    0.33929     CADJPY    0.53452  ...     NZDCAD    0.28365
# 10     AUDCHF    0.33929     EURNZD    0.53452  ...     EURCHF    0.23153
# 11     NZDJPY    0.32733     GBPJPY    0.53452  ...     EURAUD    0.20261
# 12     USDCHF    0.21822     EURJPY    0.40825  ...     USDJPY    0.18286
# 13     GBPAUD    0.21822     NZDJPY    0.40825  ...     NZDCHF    0.16871
# 14     CADJPY    0.21822     EURAUD    0.40825  ...     NZDUSD    0.16871
# 15     EURGBP    0.21822     EURGBP    0.40825  ...     EURJPY    0.16871
# 16     NZDCHF    0.21822     AUDCHF    0.40825  ...     CADCHF    0.15573
# 17     EURCHF    0.21822     CHFJPY    0.40825  ...     AUDJPY    0.14368
# 18     GBPCHF    0.21822     GBPCHF    0.40825  ...     NZDJPY    0.13234
# 19     USDCAD    0.21822     GBPCAD    0.25000  ...     EURNZD    0.12157
# 20     EURUSD    0.21822     NZDCHF    0.25000  ...     USDCHF    0.12157
# 21     AUDJPY    0.19643     AUDJPY    0.25000  ...     CHFJPY    0.09688
# 22     GBPJPY    0.09449     EURCHF    0.25000  ...     EURCAD    0.08760
# 23     AUDNZD    0.09449     AUDNZD    0.25000  ...     USDCAD    0.07462
# 24     GBPCAD    0.07143     GBPAUD    0.16667  ...     AUDNZD    0.06732
# 25     CADCHF    0.07143     EURCAD    0.16667  ...     GBPAUD    0.06204
# 26     EURCAD    0.05455     CADCHF    0.00000  ...     CADJPY    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.53035     GBPCHF    0.73855     EURGBP    0.66667
# 1      GBPCHF    0.45701     EURGBP    0.61237     GBPCHF    0.66667
# 2      EURGBP    0.39551     GBPCAD    0.61237     GBPCAD    0.49099
# 3      AUDUSD    0.35747     EURNZD    0.45833     AUDCHF    0.49099
# 4      AUDCHF    0.33634     NZDCAD    0.40825     AUDCAD    0.44444
# 5      EURAUD    0.33634     AUDCHF    0.38516     EURCHF    0.38889
# 6      AUDCAD    0.33634     NZDCHF    0.38516     GBPUSD    0.38889
# 7      NZDCAD    0.33634     USDJPY    0.32824     NZDCHF    0.38889
# 8      GBPUSD    0.33634     AUDCAD    0.32824     EURNZD    0.38889
# 9      GBPJPY    0.27866     GBPUSD    0.32824     NZDUSD    0.38889
# 10     NZDCHF    0.27866     NZDUSD    0.31180     USDJPY    0.38889
# 11     EURNZD    0.26068     EURCHF    0.31180     CHFJPY    0.32733
# 12     EURCHF    0.24661     EURAUD    0.25000     AUDUSD    0.32733
# 13     USDJPY    0.22172     AUDUSD    0.25000     NZDCAD    0.32733
# 14     EURUSD    0.22172     GBPJPY    0.25000     EURAUD    0.32733
# 15     NZDUSD    0.14382     CHFJPY    0.20412     GBPJPY    0.28868
# 16     EURCAD    0.14382     AUDNZD    0.17118     EURJPY    0.21822
# 17     CADCHF    0.12585     EURUSD    0.17118     CADCHF    0.21822
# 18     NZDJPY    0.10985     GBPAUD    0.13363     NZDJPY    0.16667
# 19     GBPAUD    0.10985     EURJPY    0.12309     GBPAUD    0.16667
# 20     CHFJPY    0.08597     EURCAD    0.12309     EURCAD    0.16667
# 21     USDCHF    0.06727     NZDJPY    0.08206     USDCHF    0.11111
# 22     EURJPY    0.06727     USDCHF    0.08206     CADJPY    0.11111
# 23     AUDJPY    0.04977     USDCAD    0.04280     USDCAD    0.11111
# 24     AUDNZD    0.02746     CADCHF    0.04167     EURUSD    0.11111
# 25     CADJPY    0.00899     CADJPY    0.04167     AUDJPY    0.05455
# 26     USDCAD    0.00899     AUDJPY    0.00000     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.81650
# 1      GBPCHF    0.81650
# 2      GBPUSD    0.66667
# 3      USDJPY    0.66667
# 4      NZDUSD    0.66667
# 5      GBPCAD    0.66667
# 6      NZDCAD    0.58333
# 7      AUDCAD    0.58333
# 8      AUDUSD    0.58333
# 9      EURNZD    0.53452
# 10     GBPJPY    0.53452
# 11     USDCHF    0.53452
# 12     USDCAD    0.53452
# 13     EURUSD    0.53452
# 14     AUDCHF    0.40825
# 15     EURAUD    0.40825
# 16     NZDJPY    0.40825
# 17     NZDCHF    0.25000
# 18     EURCHF    0.25000
# 19     AUDJPY    0.25000
# 20     GBPAUD    0.16667
# 21     EURCAD    0.16667
# 22     AUDNZD    0.16667
# 23     CADJPY    0.08909
# 24     CADCHF    0.00000
# 25     CHFJPY    0.00000
# 26     EURJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
