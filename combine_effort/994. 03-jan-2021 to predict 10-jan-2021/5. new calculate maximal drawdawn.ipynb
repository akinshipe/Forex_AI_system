# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
from sklearn.compose import make_column_transformer
import time
from datetime import datetime, timedelta

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['predict'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 07:01:17.245468

# %%
print('---------------- Script Has Started Execution-----------------------')

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

current_week_dataframe = pd.read_csv('current_week_values/current_week_values.csv' ) 

current_week_date = current_week_dataframe['date'].iloc[:1].values[0]

current_week_date = datetime.strptime(current_week_date, '%Y.%m.%d')

week_start_date  = current_week_date + timedelta(days=7)
week_end_date = current_week_date + timedelta(days=12)
week_start_date = week_start_date.strftime("%Y.%m.%d")
week_end_date = week_end_date.strftime("%Y.%m.%d")
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
trade_info = pd.read_csv('files/next_week_trades.csv' ) 
    


currency_pairs = []

for index, row in trade_info.iterrows():
    
    current_trade_info = {'name' : row.names, 'direction': row.next_week_prediction, 'dataframe': None }
    
    currency_pairs.append(current_trade_info)

print(currency_pairs)
# Out:
# [{'name': 'USDCHF', 'direction': 'S', 'dataframe': None}, {'name': 'GBPUSD', 'direction': 'B', 'dataframe': None}, {'name': 'EURUSD', 'direction': 'B', 'dataframe': None}, {'name': 'USDJPY', 'direction': 'S', 'dataframe': None}, {'name': 'USDCAD', 'direction': 'B', 'dataframe': None}, {'name': 'NZDUSD', 'direction': 'B', 'dataframe': None}, {'name': 'GBPCHF', 'direction': 'B', 'dataframe': None}, {'name': 'EURCHF', 'direction': 'S', 'dataframe': None}, {'name': 'CHFJPY', 'direction': 'B', 'dataframe': None}, {'name': 'CADCHF', 'direction': 'B', 'dataframe': None}, {'name': 'EURGBP', 'direction': 'B', 'dataframe': None}, {'name': 'GBPJPY', 'direction': 'B', 'dataframe': None}, {'name': 'GBPCAD', 'direction': 'S', 'dataframe': None}, {'name': 'GBPAUD', 'direction': 'B', 'dataframe': None}, {'name': 'EURJPY', 'direction': 'B', 'dataframe': None}, {'name': 'EURCAD', 'direction': 'S', 'dataframe': None}, {'name': 'EURAUD', 'direction': 'B', 'dataframe': None}, {'name': 'EURNZD', 'direction': 'B', 'dataframe': None}, {'name': 'AUDJPY', 'direction': 'B', 'dataframe': None}, {'name': 'NZDJPY', 'direction': 'B', 'dataframe': None}]

# %%
# this cell checks if all the currency pairs have the same number of rows

total_rows = 0

for a in currency_pairs:
    current_currency_dataframe = pd.read_csv('recent_5min_data/' + a['name']+ str(5) + '.csv', names=headers  ) 
    
    # save current currency dataframe to memory to speedup the consecutive calls to the dataframe by saving to a variable
    #filter dataframe to only return needed rows for the week
    
    a['dataframe']= current_currency_dataframe.loc[  (current_currency_dataframe['date'] >= week_start_date)
                                                   
                                                     & 
                                                      (current_currency_dataframe['date'] <= week_end_date)
                                                                                                      ]  
    
    a['dataframe'] = a['dataframe'].head(1440)
    
    
    
    if  a['dataframe']['ignore'].iloc[-1] != '23:50':
        
          raise Exception("incorrect rows in 5 mins data")
            
    if a['dataframe']['date'].iloc[-1] != week_end_date :
        
        raise Exception("Something is wrong with weekend date")
    
    
   
    
    #drops the first 24 columns so as to start analysis by 2am and not 12am
    #a['dataframe'] = a['dataframe'].iloc[24: , :]
    
    #reset the index of the dataframe to refresh it
    a['dataframe'].reset_index(drop=True, inplace=True)
    
    print('----------------------------',a['name'])
    
    
    current_currency_dataframe_row_ammount = len(a['dataframe'].index)
    
    if total_rows == 0:
        total_rows = current_currency_dataframe_row_ammount
       
        
    else:
        if total_rows != current_currency_dataframe_row_ammount:
            print('ERROR,   ERROR,    ERROR-------lenght of files in', a ,'are not the same with total rows: ', total_rows)
            total_rows = "lenght of rows is not the same"

print(total_rows)
# Out:
# ---------------------------- USDCHF
# ---------------------------- GBPUSD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'GBPUSD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:45  1.36794  1.36837  1.36760  1.36812     350
# 1    2021.01.14  18:50  1.36812  1.36856  1.36810  1.36831     208
# 2    2021.01.14  18:55  1.36830  1.36904  1.36830  1.36892     234
# 3    2021.01.14  19:00  1.36894  1.36937  1.36875  1.36884     263
# 4    2021.01.14  19:05  1.36884  1.36891  1.36848  1.36855     253
# ..          ...    ...      ...      ...      ...      ...     ...
# 345  2021.01.15  23:30  1.35854  1.35868  1.35833  1.35837      91
# 346  2021.01.15  23:35  1.35827  1.35846  1.35820  1.35836     103
# 347  2021.01.15  23:40  1.35834  1.35840  1.35810  1.35813      73
# 348  2021.01.15  23:45  1.35815  1.35815  1.35763  1.35766     111
# 349  2021.01.15  23:50  1.35767  1.35826  1.35764  1.35820     166
#
# [350 rows x 7 columns]} are not the same with total rows:  353
# ---------------------------- EURUSD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURUSD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:20  1.21421  1.21475  1.21415  1.21460     323
# 1    2021.01.14  18:25  1.21460  1.21484  1.21444  1.21481     312
# 2    2021.01.14  18:30  1.21480  1.21481  1.21424  1.21454     451
# 3    2021.01.14  18:35  1.21454  1.21473  1.21435  1.21462     323
# 4    2021.01.14  18:40  1.21462  1.21485  1.21453  1.21466     272
# ..          ...    ...      ...      ...      ...      ...     ...
# 350  2021.01.15  23:30  1.20756  1.20764  1.20752  1.20762      49
# 351  2021.01.15  23:35  1.20762  1.20771  1.20759  1.20763      81
# 352  2021.01.15  23:40  1.20762  1.20772  1.20761  1.20766      48
# 353  2021.01.15  23:45  1.20765  1.20766  1.20750  1.20751      68
# 354  2021.01.15  23:50  1.20751  1.20773  1.20750  1.20766     185
#
# [355 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- USDJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'USDJPY', 'direction': 'S', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:35  103.730  103.745  103.729  103.730     208
# 1    2021.01.14  18:40  103.730  103.731  103.695  103.699     237
# 2    2021.01.14  18:45  103.699  103.713  103.657  103.660     283
# 3    2021.01.14  18:50  103.660  103.675  103.651  103.664     250
# 4    2021.01.14  18:55  103.664  103.684  103.655  103.664     244
# ..          ...    ...      ...      ...      ...      ...     ...
# 347  2021.01.15  23:30  103.874  103.877  103.873  103.875      48
# 348  2021.01.15  23:35  103.875  103.879  103.873  103.878      43
# 349  2021.01.15  23:40  103.878  103.882  103.875  103.879      68
# 350  2021.01.15  23:45  103.879  103.913  103.878  103.911      58
# 351  2021.01.15  23:50  103.911  103.913  103.866  103.869     167
#
# [352 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- USDCAD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'USDCAD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:20  1.26499  1.26499  1.26457  1.26457     315
# 1    2021.01.14  18:25  1.26458  1.26467  1.26413  1.26419     360
# 2    2021.01.14  18:30  1.26420  1.26460  1.26417  1.26448     377
# 3    2021.01.14  18:35  1.26446  1.26501  1.26446  1.26485     405
# 4    2021.01.14  18:40  1.26484  1.26495  1.26449  1.26475     320
# ..          ...    ...      ...      ...      ...      ...     ...
# 350  2021.01.15  23:30  1.27337  1.27405  1.27337  1.27399     152
# 351  2021.01.15  23:35  1.27400  1.27440  1.27395  1.27438     190
# 352  2021.01.15  23:40  1.27438  1.27442  1.27356  1.27363     115
# 353  2021.01.15  23:45  1.27365  1.27395  1.27349  1.27392      88
# 354  2021.01.15  23:50  1.27392  1.27413  1.27366  1.27403     255
#
# [355 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- NZDUSD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'NZDUSD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:30  0.72164  0.72165  0.72124  0.72155     237
# 1    2021.01.14  18:35  0.72154  0.72155  0.72116  0.72137     178
# 2    2021.01.14  18:40  0.72137  0.72172  0.72129  0.72145     247
# 3    2021.01.14  18:45  0.72145  0.72201  0.72136  0.72198     365
# 4    2021.01.14  18:50  0.72198  0.72233  0.72192  0.72207     250
# ..          ...    ...      ...      ...      ...      ...     ...
# 348  2021.01.15  23:30  0.71341  0.71348  0.71338  0.71338      24
# 349  2021.01.15  23:35  0.71338  0.71341  0.71317  0.71339      41
# 350  2021.01.15  23:40  0.71339  0.71340  0.71328  0.71338      23
# 351  2021.01.15  23:45  0.71338  0.71338  0.71296  0.71297      87
# 352  2021.01.15  23:50  0.71294  0.71312  0.71286  0.71298     166
#
# [353 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- GBPCHF
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'GBPCHF', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:10  1.21491  1.21592  1.21447  1.21555     508
# 1    2021.01.14  18:15  1.21556  1.21577  1.21528  1.21557     427
# 2    2021.01.14  18:20  1.21557  1.21599  1.21532  1.21555     340
# 3    2021.01.14  18:25  1.21553  1.21598  1.21530  1.21530     338
# 4    2021.01.14  18:30  1.21530  1.21547  1.21475  1.21475     383
# ..          ...    ...      ...      ...      ...      ...     ...
# 352  2021.01.15  23:30  1.21096  1.21107  1.21060  1.21068      92
# 353  2021.01.15  23:35  1.21068  1.21084  1.21049  1.21074     115
# 354  2021.01.15  23:40  1.21074  1.21076  1.21052  1.21054     109
# 355  2021.01.15  23:45  1.21055  1.21066  1.21015  1.21021      93
# 356  2021.01.15  23:50  1.21021  1.21067  1.21014  1.21063     136
#
# [357 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURCHF
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURCHF', 'direction': 'S', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:35  1.07811  1.07837  1.07797  1.07799     224
# 1    2021.01.14  18:40  1.07800  1.07815  1.07756  1.07772     189
# 2    2021.01.14  18:45  1.07772  1.07823  1.07772  1.07819     209
# 3    2021.01.14  18:50  1.07818  1.07826  1.07800  1.07803     166
# 4    2021.01.14  18:55  1.07804  1.07818  1.07799  1.07814     176
# ..          ...    ...      ...      ...      ...      ...     ...
# 347  2021.01.15  23:30  1.07645  1.07649  1.07637  1.07638      34
# 348  2021.01.15  23:35  1.07638  1.07651  1.07631  1.07648      62
# 349  2021.01.15  23:40  1.07648  1.07656  1.07642  1.07647      60
# 350  2021.01.15  23:45  1.07648  1.07653  1.07637  1.07641     106
# 351  2021.01.15  23:50  1.07641  1.07650  1.07634  1.07644     230
#
# [352 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- CHFJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'CHFJPY', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:40  116.871  116.891  116.839  116.871     254
# 1    2021.01.14  18:45  116.871  116.896  116.841  116.841     288
# 2    2021.01.14  18:50  116.841  116.889  116.834  116.879     227
# 3    2021.01.14  18:55  116.879  116.897  116.857  116.859     255
# 4    2021.01.14  19:00  116.859  116.891  116.859  116.867     246
# ..          ...    ...      ...      ...      ...      ...     ...
# 346  2021.01.15  23:30  116.518  116.532  116.517  116.531      25
# 347  2021.01.15  23:35  116.531  116.539  116.514  116.525      63
# 348  2021.01.15  23:40  116.525  116.536  116.519  116.532      33
# 349  2021.01.15  23:45  116.532  116.560  116.530  116.558      45
# 350  2021.01.15  23:50  116.558  116.561  116.516  116.517      76
#
# [351 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- CADCHF
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'CADCHF', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:15  0.70216  0.70217  0.70196  0.70203     226
# 1    2021.01.14  18:20  0.70203  0.70224  0.70201  0.70216     220
# 2    2021.01.14  18:25  0.70216  0.70227  0.70198  0.70204     213
# 3    2021.01.14  18:30  0.70202  0.70217  0.70190  0.70191     169
# 4    2021.01.14  18:35  0.70191  0.70201  0.70159  0.70161     228
# ..          ...    ...      ...      ...      ...      ...     ...
# 351  2021.01.15  23:30  0.69993  0.69993  0.69952  0.69954      47
# 352  2021.01.15  23:35  0.69954  0.69956  0.69932  0.69935      97
# 353  2021.01.15  23:40  0.69935  0.69980  0.69934  0.69976      99
# 354  2021.01.15  23:45  0.69976  0.69979  0.69961  0.69964      96
# 355  2021.01.15  23:50  0.69959  0.69976  0.69944  0.69950     143
#
# [356 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURGBP
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURGBP', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:40  0.88786  0.88796  0.88763  0.88790     215
# 1    2021.01.14  18:45  0.88790  0.88840  0.88789  0.88828     299
# 2    2021.01.14  18:50  0.88828  0.88839  0.88801  0.88828     250
# 3    2021.01.14  18:55  0.88828  0.88832  0.88782  0.88786     218
# 4    2021.01.14  19:00  0.88786  0.88800  0.88774  0.88780     277
# ..          ...    ...      ...      ...      ...      ...     ...
# 346  2021.01.15  23:30  0.88883  0.88902  0.88877  0.88901      48
# 347  2021.01.15  23:35  0.88901  0.88907  0.88889  0.88899      65
# 348  2021.01.15  23:40  0.88900  0.88922  0.88898  0.88913      45
# 349  2021.01.15  23:45  0.88914  0.88935  0.88907  0.88935      88
# 350  2021.01.15  23:50  0.88935  0.88938  0.88903  0.88903     137
#
# [351 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- GBPJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'GBPJPY', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  19:05  141.909  141.912  141.881  141.889     307
# 1    2021.01.14  19:10  141.889  141.889  141.812  141.829     336
# 2    2021.01.14  19:15  141.830  141.847  141.812  141.830     301
# 3    2021.01.14  19:20  141.830  141.849  141.818  141.849     237
# 4    2021.01.14  19:25  141.850  141.861  141.835  141.858     218
# ..          ...    ...      ...      ...      ...      ...     ...
# 341  2021.01.15  23:30  141.113  141.124  141.087  141.091      41
# 342  2021.01.15  23:35  141.091  141.109  141.079  141.094      74
# 343  2021.01.15  23:40  141.094  141.099  141.075  141.083      50
# 344  2021.01.15  23:45  141.083  141.093  141.067  141.067      89
# 345  2021.01.15  23:50  141.067  141.084  141.056  141.070     125
#
# [346 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- GBPCAD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'GBPCAD', 'direction': 'S', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:30  1.73095  1.73106  1.73035  1.73047     421
# 1    2021.01.14  18:35  1.73048  1.73076  1.73022  1.73029     435
# 2    2021.01.14  18:40  1.73029  1.73057  1.72995  1.73010     385
# 3    2021.01.14  18:45  1.73009  1.73014  1.72942  1.72957     419
# 4    2021.01.14  18:50  1.72957  1.73004  1.72937  1.72937     287
# ..          ...    ...      ...      ...      ...      ...     ...
# 348  2021.01.15  23:30  1.72985  1.73064  1.72985  1.73040     126
# 349  2021.01.15  23:35  1.73040  1.73119  1.73038  1.73095     183
# 350  2021.01.15  23:40  1.73095  1.73104  1.72956  1.72971     110
# 351  2021.01.15  23:45  1.72971  1.72991  1.72935  1.72947     118
# 352  2021.01.15  23:50  1.72966  1.73053  1.72945  1.73038     161
#
# [353 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- GBPAUD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'GBPAUD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:25  1.75933  1.75995  1.75869  1.75884     345
# 1    2021.01.14  18:30  1.75884  1.75899  1.75840  1.75854     508
# 2    2021.01.14  18:35  1.75853  1.75871  1.75814  1.75814     526
# 3    2021.01.14  18:40  1.75814  1.75845  1.75761  1.75773     396
# 4    2021.01.14  18:45  1.75777  1.75798  1.75703  1.75709     472
# ..          ...    ...      ...      ...      ...      ...     ...
# 349  2021.01.15  23:30  1.76234  1.76273  1.76233  1.76238     119
# 350  2021.01.15  23:35  1.76238  1.76283  1.76228  1.76237     126
# 351  2021.01.15  23:40  1.76237  1.76244  1.76189  1.76214      84
# 352  2021.01.15  23:45  1.76214  1.76289  1.76214  1.76260     152
# 353  2021.01.15  23:50  1.76262  1.76334  1.76248  1.76303     142
#
# [354 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURJPY', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  19:00  125.996  126.015  125.981  125.994     302
# 1    2021.01.14  19:05  125.994  126.006  125.981  125.986     275
# 2    2021.01.14  19:10  125.986  125.992  125.960  125.982     299
# 3    2021.01.14  19:15  125.983  126.013  125.978  126.004     291
# 4    2021.01.14  19:20  126.004  126.014  125.999  126.007     190
# ..          ...    ...      ...      ...      ...      ...     ...
# 342  2021.01.15  23:30  125.433  125.441  125.429  125.441      36
# 343  2021.01.15  23:35  125.441  125.450  125.435  125.445      56
# 344  2021.01.15  23:40  125.446  125.460  125.445  125.452      64
# 345  2021.01.15  23:45  125.452  125.475  125.447  125.470      82
# 346  2021.01.15  23:50  125.469  125.474  125.430  125.439     159
#
# [347 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURCAD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURCAD', 'direction': 'S', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:50  1.53641  1.53663  1.53625  1.53626     329
# 1    2021.01.14  18:55  1.53623  1.53643  1.53548  1.53564     371
# 2    2021.01.14  19:00  1.53564  1.53591  1.53537  1.53543     473
# 3    2021.01.14  19:05  1.53545  1.53561  1.53525  1.53547     322
# 4    2021.01.14  19:10  1.53546  1.53580  1.53502  1.53517     288
# ..          ...    ...      ...      ...      ...      ...     ...
# 344  2021.01.15  23:30  1.53763  1.53852  1.53763  1.53844     119
# 345  2021.01.15  23:35  1.53845  1.53900  1.53839  1.53899     166
# 346  2021.01.15  23:40  1.53900  1.53904  1.53803  1.53808     116
# 347  2021.01.15  23:45  1.53810  1.53826  1.53793  1.53822     133
# 348  2021.01.15  23:50  1.53823  1.53881  1.53796  1.53861     228
#
# [349 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURAUD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURAUD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:30  1.56049  1.56072  1.56021  1.56068     498
# 1    2021.01.14  18:35  1.56068  1.56117  1.56060  1.56101     450
# 2    2021.01.14  18:40  1.56101  1.56105  1.56053  1.56075     365
# 3    2021.01.14  18:45  1.56076  1.56137  1.56068  1.56082     519
# 4    2021.01.14  18:50  1.56084  1.56095  1.56048  1.56058     449
# ..          ...    ...      ...      ...      ...      ...     ...
# 348  2021.01.15  23:30  1.56660  1.56694  1.56658  1.56684     104
# 349  2021.01.15  23:35  1.56684  1.56708  1.56679  1.56691      99
# 350  2021.01.15  23:40  1.56691  1.56697  1.56675  1.56689      70
# 351  2021.01.15  23:45  1.56691  1.56769  1.56688  1.56769     126
# 352  2021.01.15  23:50  1.56769  1.56793  1.56729  1.56767     181
# [353 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- EURNZD
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'EURNZD', 'direction': 'B', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.01.14  18:55  1.68327  1.68341  1.68229  1.68241     366
# 1    2021.01.14  19:00  1.68241  1.68244  1.68154  1.68162     476
# 2    2021.01.14  19:05  1.68162  1.68213  1.68162  1.68209     354
# 3    2021.01.14  19:10  1.68209  1.68222  1.68149  1.68191     437
# 4    2021.01.14  19:15  1.68197  1.68208  1.68126  1.68166     505
# ..          ...    ...      ...      ...      ...      ...     ...
# 343  2021.01.15  23:30  1.69240  1.69266  1.69238  1.69262      90
# 344  2021.01.15  23:35  1.69263  1.69310  1.69255  1.69264      79
# 345  2021.01.15  23:40  1.69264  1.69281  1.69263  1.69272      65
# 346  2021.01.15  23:45  1.69271  1.69352  1.69261  1.69352     132
# 347  2021.01.15  23:50  1.69352  1.69382  1.69311  1.69360     175
#
# [348 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- AUDJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'AUDJPY', 'direction': 'B', 'dataframe':            date ignore    open    high     low   close  volume
# 0    2021.01.14  18:30  80.702  80.729  80.695  80.718     325
# 1    2021.01.14  18:35  80.718  80.723  80.701  80.706     238
# 2    2021.01.14  18:40  80.706  80.718  80.691  80.698     251
# 3    2021.01.14  18:45  80.698  80.727  80.695  80.709     345
# 4    2021.01.14  18:50  80.709  80.743  80.702  80.739     326
# ..          ...    ...     ...     ...     ...     ...     ...
# 348  2021.01.15  23:30  80.064  80.064  80.045  80.051      38
# 349  2021.01.15  23:35  80.051  80.055  80.041  80.051      50
# 350  2021.01.15  23:40  80.051  80.064  80.050  80.056      34
# 351  2021.01.15  23:45  80.056  80.058  80.022  80.025     111
# 352  2021.01.15  23:50  80.025  80.030  79.999  80.009     164
#
# [353 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# ---------------------------- NZDJPY
# ERROR,   ERROR,    ERROR-------lenght of files in {'name': 'NZDJPY', 'direction': 'B', 'dataframe':            date ignore    open    high     low   close  volume
# 0    2021.01.14  18:40  74.826  74.841  74.803  74.814     246
# 1    2021.01.14  18:45  74.814  74.847  74.810  74.838     257
# 2    2021.01.14  18:50  74.838  74.870  74.830  74.851     253
# 3    2021.01.14  18:55  74.851  74.894  74.847  74.885     269
# 4    2021.01.14  19:00  74.885  74.925  74.884  74.916     251
# ..          ...    ...     ...     ...     ...     ...     ...
# 346  2021.01.15  23:30  74.107  74.111  74.100  74.100      47
# 347  2021.01.15  23:35  74.100  74.106  74.082  74.106      82
# 348  2021.01.15  23:40  74.107  74.108  74.098  74.105      68
# 349  2021.01.15  23:45  74.105  74.110  74.081  74.083     108
# 350  2021.01.15  23:50  74.071  74.081  74.050  74.057     153
#
# [351 rows x 7 columns]} are not the same with total rows:  lenght of rows is not the same
# lenght of rows is not the same

# %%
timeframe = []
trade_values = []

for b in range(total_rows):
    
   
    # save current timefreame to timeframe list
    timeframe.append(currency_pairs[0]['dataframe'].loc[b]['date'] + ' '+ currency_pairs[0]['dataframe'].loc[b]['ignore']  )
    
    sum_of_all_open_trades = 0
    
    for c in currency_pairs:
        
        
        if c['direction'] == 'B':
            
            current_trade_value =  c['dataframe'].loc[b]['close'] - c['dataframe'].loc[0]['open']
            
        if c['direction'] == 'S':
            
            current_trade_value =  c['dataframe'].loc[0]['open'] -  c['dataframe'].loc[b]['close']
            
        
        pips_corrector = 100000

        if c['name'].endswith('JPY'):   # use this to correct multiplier of jpy pairs
            pips_corrector = 1000
        
        current_trade_value = current_trade_value * pips_corrector
        
        #print(c['name'], '---', current_trade_value )
        
        
        
        sum_of_all_open_trades = sum_of_all_open_trades + current_trade_value
        
       
        
    
    trade_values.append(sum_of_all_open_trades)
  
    


trade_values_dataframe = pd.DataFrame()
trade_values_dataframe['timeframe'] = timeframe
trade_values_dataframe['profit'] = trade_values
trade_values_dataframe.sort_values(by=['timeframe'], ascending=False, inplace=True, ignore_index= True)

maximal_drawup_dataframe = pd.DataFrame()
maximal_drawup_dataframe[0] = ['' for r in trade_values]
maximal_drawup_dataframe['timeframe1'] = timeframe
maximal_drawup_dataframe['drawup'] = trade_values
maximal_drawup_dataframe.sort_values(by=['drawup'], ascending=False, inplace=True, ignore_index= True)

maximal_drawdown_dataframe = pd.DataFrame()
maximal_drawdown_dataframe[1] = ['' for r in trade_values]
maximal_drawdown_dataframe['timeframe2'] = timeframe
maximal_drawdown_dataframe['drawdown'] = trade_values
maximal_drawdown_dataframe.sort_values(by=['drawdown'], ascending=True, inplace=True, ignore_index= True)



main_dataframe = pd.concat([trade_values_dataframe, maximal_drawup_dataframe, maximal_drawdown_dataframe ], axis = 1)



main_dataframe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_15748/698127570.py in <module>
#       2 trade_values = []
#       3
# ----> 4 for b in range(total_rows):
#       5
#       6
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
main_dataframe.to_csv('files/' + 'maximaldraw_down_and_up' + '.csv', index=False)

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['drawdownup'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
