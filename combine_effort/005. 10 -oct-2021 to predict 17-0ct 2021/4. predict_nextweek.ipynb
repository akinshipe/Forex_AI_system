# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 08:26:02.140129
# 2021-12-07 08:26:02.149101
# 2021-12-07 08:27:02.157959
# 2021-12-07 08:28:02.165357
# 2021-12-07 08:29:02.179281
# 2021-12-07 08:30:02.192112
# 2021-12-07 08:31:02.201454
# 2021-12-07 08:32:02.216939
# 2021-12-07 08:33:02.245065
# 2021-12-07 08:34:02.253600
# 2021-12-07 08:35:02.268579
# 2021-12-07 08:36:02.273165
# 2021-12-07 08:37:02.284778
# 2021-12-07 08:38:02.287452
# 2021-12-07 08:39:02.304068
# 2021-12-07 08:40:02.317439
# 2021-12-07 08:41:02.335292
# 2021-12-07 08:42:02.345658
# 2021-12-07 08:43:02.359779
# 2021-12-07 08:44:02.372279
# 2021-12-07 08:45:02.380948
# 2021-12-07 08:46:02.394727
# 2021-12-07 08:47:02.409417
# 2021-12-07 08:48:02.425248
# 2021-12-07 08:49:02.431409
# 2021-12-07 08:50:02.437103
# 2021-12-07 08:51:02.451748
# 2021-12-07 08:52:02.473253
# 2021-12-07 08:53:02.477077
# 2021-12-07 08:54:02.486577
# 2021-12-07 08:55:02.489965
# 2021-12-07 08:56:02.500457
# 2021-12-07 08:57:02.503848
# 2021-12-07 08:58:02.515099
# 2021-12-07 08:59:02.538849
# 2021-12-07 09:00:02.542146
# 2021-12-07 09:01:02.552625
# 2021-12-07 09:02:02.562697
# 2021-12-07 09:03:02.582649
# 2021-12-07 09:04:02.598766
# 2021-12-07 09:05:02.603211
# 2021-12-07 09:06:02.618591
# 2021-12-07 09:07:02.623274
# 2021-12-07 09:08:02.628847
# 2021-12-07 09:09:02.631140
# 2021-12-07 09:10:02.632220
# 2021-12-07 09:11:02.635249
# 2021-12-07 09:12:02.656814
# 2021-12-07 09:13:02.673207
# 2021-12-07 09:14:02.682134
# 2021-12-07 09:15:02.690652
# 2021-12-07 09:16:02.697434
# 2021-12-07 09:17:02.705024
# 2021-12-07 09:18:02.716522
# 2021-12-07 09:19:02.728556
# 2021-12-07 09:20:02.734305
# 2021-12-07 09:21:02.742775
# 2021-12-07 09:22:02.751622
# 2021-12-07 09:23:02.767447
# 2021-12-07 09:24:02.781116
# 2021-12-07 09:25:02.783990
# 2021-12-07 09:26:02.799422
# 2021-12-07 09:27:02.817488
# 2021-12-07 09:28:02.832026
# 2021-12-07 09:29:02.840507
# 2021-12-07 09:30:02.852335
# 2021-12-07 09:31:02.865377
# 2021-12-07 09:32:02.877622
# 2021-12-07 09:33:02.891621
# 2021-12-07 09:34:02.904831
# 2021-12-07 09:35:02.908781
# 2021-12-07 09:36:02.914087
# 2021-12-07 09:37:02.924884
# 2021-12-07 09:38:02.938927
# 2021-12-07 09:39:02.941872
# 2021-12-07 09:40:02.942033
# 2021-12-07 09:41:02.949384
# 2021-12-07 09:42:02.967967
# 2021-12-07 09:43:02.978810
# 2021-12-07 09:44:02.980230
# 2021-12-07 09:45:02.995070
# 2021-12-07 09:46:02.995240
# 2021-12-07 09:47:03.012597
# 2021-12-07 09:48:03.021465
# 2021-12-07 09:49:03.031382
# 2021-12-07 09:50:03.047969
# 2021-12-07 09:51:03.053570
# 2021-12-07 09:52:03.063967
# 2021-12-07 09:53:03.074642
# 2021-12-07 09:54:03.092502
# 2021-12-07 09:55:03.103259
# 2021-12-07 09:56:03.108866
# 2021-12-07 09:57:03.121234
# 2021-12-07 09:58:03.130906
# 2021-12-07 09:59:03.137227
# 2021-12-07 10:00:03.153738
# 2021-12-07 10:01:03.170911
# 2021-12-07 10:02:03.182993
# 2021-12-07 10:03:03.187443
# 2021-12-07 10:04:03.195537
# 2021-12-07 10:05:03.212870
# 2021-12-07 10:06:03.224820
# 2021-12-07 10:07:03.235235
# 2021-12-07 10:08:03.254405
# 2021-12-07 10:09:03.261841
# 2021-12-07 10:10:03.272589
# 2021-12-07 10:11:03.278190

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
