# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 08:19:15.323667

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      AUDNZD    0.29417     EURUSD    0.42857     EURUSD    0.53452
# 1      GBPUSD    0.28123     GBPUSD    0.34717     EURGBP    0.40825
# 2      CHFJPY    0.25000     AUDUSD    0.30861     AUDUSD    0.38516
# 3      USDCHF    0.21868     CHFJPY    0.30861     CHFJPY    0.38516
# 4      AUDUSD    0.19852     EURGBP    0.27890     USDCHF    0.38516
# 5      EURUSD    0.19852     USDCHF    0.26984     GBPUSD    0.31180
# 6      GBPCAD    0.19612     AUDNZD    0.26245     AUDNZD    0.28721
# 7      USDJPY    0.19612     EURNZD    0.26245     AUDCHF    0.28721
# 8      EURJPY    0.18711     NZDJPY    0.23757     GBPCHF    0.28721
# 9      NZDJPY    0.16667     AUDJPY    0.23757     EURNZD    0.28721
# 10     NZDUSD    0.16330     NZDUSD    0.23757     GBPAUD    0.25678
# 11     EURNZD    0.16330     GBPCAD    0.21822     NZDUSD    0.25000
# 12     AUDCAD    0.11580     AUDCHF    0.20787     AUDJPY    0.25000
# 13     AUDJPY    0.11580     GBPJPY    0.19623     NZDJPY    0.25000
# 14     AUDCHF    0.11440     USDCAD    0.19623     GBPCAD    0.20412
# 15     USDCAD    0.09829     EURCAD    0.13211     EURCAD    0.20412
# 16     EURGBP    0.09829     CADCHF    0.13211     GBPJPY    0.17118
# 17     GBPAUD    0.08333     CADJPY    0.13211     EURJPY    0.17118
# 18     NZDCHF    0.08165     GBPCHF    0.11664     NZDCAD    0.12309
# 19     CADCHF    0.08165     GBPAUD    0.11664     USDCAD    0.08909
# 20     GBPCHF    0.08165     EURJPY    0.11111     NZDCHF    0.08206
# 21     GBPJPY    0.06580     NZDCAD    0.08909     EURAUD    0.08206
# 22     EURAUD    0.04903     USDJPY    0.07274     EURCHF    0.04280
# 23     CADJPY    0.04903     EURCHF    0.04528     CADCHF    0.04167
# 24     NZDCAD    0.03309     AUDCAD    0.04528     USDJPY    0.04167
# 25     EURCAD    0.03269     NZDCHF    0.01468     CADJPY    0.04167
# 26     EURCHF    0.03269     EURAUD    0.01468     AUDCAD    0.04167
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66144     EURNZD    0.80178  ...     GBPCAD    0.23775
# 1      USDCHF    0.49099     EURGBP    0.66667  ...     EURGBP    0.20773
# 2      AUDUSD    0.49099     AUDNZD    0.58333  ...     GBPCHF    0.20064
# 3      CHFJPY    0.49099     USDCHF    0.53452  ...     CHFJPY    0.18021
# 4      EURNZD    0.47246     AUDUSD    0.53452  ...     CADCHF    0.12039
# 5      AUDNZD    0.47246     AUDJPY    0.53452  ...     NZDJPY    0.09829
# 6      EURGBP    0.46429     EURUSD    0.53452  ...     USDJPY    0.08353
# 7      GBPUSD    0.37796     CHFJPY    0.53452  ...     EURAUD    0.08353
# 8      NZDUSD    0.37796     EURJPY    0.53452  ...     EURCAD    0.07711
# 9      EURCAD    0.33929     USDCAD    0.53452  ...     EURCHF    0.07711
# 10     AUDJPY    0.33929     GBPUSD    0.40825  ...     AUDCHF    0.07711
# 11     GBPCHF    0.32733     NZDJPY    0.40825  ...     CADJPY    0.07711
# 12     GBPAUD    0.32733     GBPJPY    0.40825  ...     GBPAUD    0.06553
# 13     NZDJPY    0.26189     GBPCAD    0.40825  ...     EURUSD    0.05366
# 14     EURJPY    0.21822     AUDCHF    0.40825  ...     AUDJPY    0.05366
# 15     USDJPY    0.21822     GBPCHF    0.40825  ...     GBPUSD    0.05366
# 16     AUDCAD    0.21822     NZDUSD    0.40825  ...     USDCAD    0.04670
# 17     USDCAD    0.21822     NZDCHF    0.35635  ...     EURNZD    0.04013
# 18     GBPCAD    0.19643     EURAUD    0.35635  ...     NZDUSD    0.04013
# 19     AUDCHF    0.19643     NZDCAD    0.35635  ...     NZDCHF    0.04013
# 20     NZDCHF    0.18898     CADCHF    0.25000  ...     AUDUSD    0.02764
# 21     GBPJPY    0.09449     CADJPY    0.25000  ...     NZDCAD    0.02764
# 22     NZDCAD    0.09449     GBPAUD    0.16667  ...     AUDCAD    0.02764
# 23     CADJPY    0.07143     AUDCAD    0.16667  ...     EURJPY    0.02341
# 24     EURCHF    0.05455     USDJPY    0.16667  ...     USDCHF    0.02150
# 25     CADCHF    0.05455     EURCAD    0.00000  ...     GBPJPY    0.00970
# 26     EURAUD    0.05455     EURCHF    0.00000  ...     AUDNZD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      EURAUD    0.26068     CADJPY    0.32824     USDJPY    0.44444
# 1      NZDCHF    0.26068     USDJPY    0.28721     AUDCAD    0.44444
# 2      GBPUSD    0.25882     GBPUSD    0.28511     EURCAD    0.32733
# 3      EURNZD    0.19643     EURJPY    0.24232     GBPUSD    0.28868
# 4      NZDCAD    0.19094     AUDNZD    0.19192     EURUSD    0.28868
# 5      NZDJPY    0.19094     NZDCAD    0.19192     NZDCAD    0.28868
# 6      NZDUSD    0.19094     EURNZD    0.19192     NZDUSD    0.28868
# 7      CHFJPY    0.18898     EURAUD    0.19192     EURGBP    0.21822
# 8      USDCHF    0.17496     NZDCHF    0.19192     CADJPY    0.21822
# 9      CADJPY    0.14382     USDCAD    0.15352     EURAUD    0.16667
# 10     CADCHF    0.12585     AUDJPY    0.12309     USDCHF    0.16667
# 11     AUDCAD    0.12016     EURCAD    0.10050     CHFJPY    0.16667
# 12     GBPJPY    0.12016     GBPCAD    0.10050     EURCHF    0.16667
# 13     EURUSD    0.11664     EURGBP    0.10050     AUDUSD    0.16667
# 14     GBPAUD    0.07143     CADCHF    0.08206     NZDJPY    0.12309
# 15     AUDNZD    0.06250     NZDUSD    0.08206     CADCHF    0.11111
# 16     GBPCHF    0.06250     NZDJPY    0.08206     GBPAUD    0.11111
# 17     AUDCHF    0.05455     AUDCAD    0.08206     EURJPY    0.11111
# 18     AUDJPY    0.05455     EURUSD    0.06580     GBPCHF    0.11111
# 19     AUDUSD    0.04725     GBPJPY    0.03161     USDCAD    0.11111
# 20     EURJPY    0.02916     GBPAUD    0.03161     AUDCHF    0.05455
# 21     EURCHF    0.01849     CHFJPY    0.03161     GBPCAD    0.05455
# 22     USDCAD    0.01849     EURCHF    0.03161     AUDJPY    0.05455
# 23     EURCAD    0.00899     AUDUSD    0.03161     NZDCHF    0.00000
# 24     EURGBP    0.00899     USDCHF    0.03161     GBPJPY    0.00000
# 25     GBPCAD    0.00000     AUDCHF    0.01010     EURNZD    0.00000
# 26     USDJPY    0.00000     GBPCHF    0.01010     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURCHF    0.40825
# 1      CADJPY    0.25000
# 2      EURGBP    0.16667
# 3      AUDCAD    0.16667
# 4      GBPAUD    0.16667
# 5      CADCHF    0.16667
# 6      AUDNZD    0.16667
# 7      USDJPY    0.16667
# 8      NZDJPY    0.10206
# 9      GBPUSD    0.10206
# 10     GBPJPY    0.10206
# 11     NZDUSD    0.10206
# 12     EURJPY    0.08909
# 13     EURAUD    0.08909
# 14     NZDCAD    0.08909
# 15     EURUSD    0.08909
# 16     AUDJPY    0.08909
# 17     EURNZD    0.08909
# 18     USDCHF    0.08909
# 19     USDCAD    0.08909
# 20     NZDCHF    0.08909
# 21     AUDUSD    0.08909
# 22     CHFJPY    0.08909
# 23     EURCAD    0.00000
# 24     GBPCAD    0.00000
# 25     AUDCHF    0.00000
# 26     GBPCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
