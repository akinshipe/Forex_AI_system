# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:13:06.725662

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPUSD    0.31253     EURUSD    0.46291     EURUSD    0.66375
# 1      CHFJPY    0.30279     GBPUSD    0.39129     USDCHF    0.53340
# 2      EURUSD    0.28123     CHFJPY    0.35000     EURNZD    0.49237
# 3      EURJPY    0.27217     EURGBP    0.33296     CHFJPY    0.45303
# 4      AUDNZD    0.26212     EURNZD    0.33072     GBPUSD    0.45303
# 5      USDCHF    0.25000     USDCHF    0.30861     AUDUSD    0.45303
# 6      AUDUSD    0.25000     AUDUSD    0.30861     EURGBP    0.41414
# 7      NZDUSD    0.21246     AUDNZD    0.28284     AUDNZD    0.39394
# 8      AUDCAD    0.16667     GBPJPY    0.24456     EURCAD    0.39394
# 9      NZDJPY    0.16667     AUDJPY    0.24456     GBPJPY    0.32824
# 10     AUDJPY    0.16667     NZDUSD    0.24456     AUDJPY    0.32824
# 11     EURNZD    0.16330     EURCAD    0.23623     EURJPY    0.32824
# 12     USDJPY    0.16330     EURJPY    0.20000     NZDUSD    0.32824
# 13     GBPJPY    0.14804     AUDCHF    0.19565     AUDCHF    0.28721
# 14     GBPCAD    0.11440     GBPCAD    0.18898     EURAUD    0.28721
# 15     EURGBP    0.09829     NZDJPY    0.14434     GBPCHF    0.19192
# 16     NZDCAD    0.08333     USDCAD    0.09782     NZDCHF    0.17911
# 17     GBPAUD    0.08333     EURCHF    0.09782     CADCHF    0.17911
# 18     AUDCHF    0.06553     NZDCAD    0.09782     EURCHF    0.12309
# 19     USDCAD    0.04903     EURAUD    0.09513     USDJPY    0.12309
# 20     EURCAD    0.04903     GBPAUD    0.09513     NZDJPY    0.12309
# 21     EURAUD    0.04903     AUDCAD    0.05000     AUDCAD    0.12309
# 22     CADJPY    0.04903     CADCHF    0.04757     NZDCAD    0.12309
# 23     EURCHF    0.04903     USDJPY    0.04757     GBPAUD    0.08206
# 24     GBPCHF    0.03269     CADJPY    0.04757     USDCAD    0.03161
# 25     NZDCHF    0.03269     GBPCHF    0.04725     GBPCAD    0.01010
# 26     CADCHF    0.00000     NZDCHF    0.00000     CADJPY    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66144     EURNZD    0.80178  ...     GBPCAD    0.19678
# 1      EURNZD    0.60010     USDCHF    0.66667  ...     GBPCHF    0.19678
# 2      USDCHF    0.49099     EURJPY    0.66667  ...     CHFJPY    0.19590
# 3      EURGBP    0.49099     EURUSD    0.66667  ...     EURGBP    0.17138
# 4      AUDNZD    0.46429     EURAUD    0.58333  ...     USDJPY    0.16116
# 5      CHFJPY    0.37796     AUDNZD    0.58333  ...     NZDJPY    0.14804
# 6      AUDUSD    0.37796     EURGBP    0.53452  ...     EURAUD    0.12581
# 7      GBPUSD    0.37796     GBPUSD    0.53452  ...     EURUSD    0.10123
# 8      EURCAD    0.33929     AUDJPY    0.53452  ...     GBPAUD    0.09869
# 9      EURJPY    0.33929     CHFJPY    0.53452  ...     CADCHF    0.08058
# 10     EURAUD    0.32733     AUDUSD    0.53452  ...     EURJPY    0.07722
# 11     NZDUSD    0.26189     GBPJPY    0.53452  ...     AUDNZD    0.07114
# 12     GBPJPY    0.21822     EURCAD    0.40825  ...     AUDCHF    0.07114
# 13     AUDJPY    0.21822     NZDUSD    0.40825  ...     AUDJPY    0.06580
# 14     GBPCAD    0.19643     USDCAD    0.25000  ...     GBPUSD    0.05519
# 15     AUDCHF    0.19643     EURCHF    0.25000  ...     GBPJPY    0.05519
# 16     GBPCHF    0.19643     AUDCHF    0.16667  ...     NZDCHF    0.04516
# 17     NZDCHF    0.18898     CADCHF    0.16667  ...     NZDUSD    0.04516
# 18     USDJPY    0.09449     NZDCHF    0.10206  ...     USDCAD    0.04516
# 19     NZDJPY    0.09449     NZDCAD    0.10206  ...     EURCHF    0.03548
# 20     AUDCAD    0.09449     USDJPY    0.08909  ...     EURCAD    0.03548
# 21     EURCHF    0.07143     NZDJPY    0.08909  ...     CADJPY    0.03548
# 22     CADJPY    0.07143     AUDCAD    0.08909  ...     AUDUSD    0.01645
# 23     USDCAD    0.07143     GBPAUD    0.08909  ...     AUDCAD    0.01645
# 24     GBPAUD    0.05455     GBPCAD    0.00000  ...     NZDCAD    0.01645
# 25     CADCHF    0.05455     GBPCHF    0.00000  ...     USDCHF    0.01645
# 26     NZDCAD    0.04029     CADJPY    0.00000  ...     EURNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.34586     GBPUSD    0.38982     AUDJPY    0.21822
# 1      EURAUD    0.33634     USDJPY    0.28721     AUDNZD    0.19643
# 2      NZDJPY    0.27217     CADJPY    0.21212     EURCHF    0.19643
# 3      NZDCHF    0.27217     EURCAD    0.21212     CADJPY    0.19643
# 4      EURNZD    0.26726     AUDNZD    0.19192     EURCAD    0.19643
# 5      EURUSD    0.21822     EURUSD    0.17911     AUDCAD    0.18898
# 6      GBPJPY    0.20751     AUDJPY    0.12309     NZDJPY    0.18898
# 7      NZDCAD    0.20751     AUDCHF    0.12309     GBPUSD    0.18898
# 8      NZDUSD    0.20751     EURJPY    0.12309     USDJPY    0.18898
# 9      CADCHF    0.20180     GBPAUD    0.08206     EURUSD    0.18898
# 10     AUDNZD    0.20000     NZDCAD    0.08206     AUDUSD    0.09449
# 11     AUDCAD    0.14142     AUDCAD    0.08206     NZDCHF    0.09449
# 12     CHFJPY    0.14142     NZDJPY    0.08206     CHFJPY    0.09449
# 13     GBPCHF    0.13363     EURNZD    0.08206     GBPCHF    0.07143
# 14     USDCHF    0.07274     EURAUD    0.08206     USDCAD    0.07143
# 15     AUDUSD    0.07274     USDCHF    0.08206     AUDCHF    0.07143
# 16     AUDCHF    0.06917     GBPJPY    0.08206     GBPCAD    0.07143
# 17     EURCHF    0.06917     EURCHF    0.08206     EURJPY    0.07143
# 18     AUDJPY    0.06917     NZDUSD    0.08206     EURNZD    0.05455
# 19     USDCAD    0.06917     NZDCHF    0.03161     USDCHF    0.05455
# 20     GBPAUD    0.06727     CADCHF    0.03161     EURAUD    0.05455
# 21     CADJPY    0.06727     CHFJPY    0.03161     GBPAUD    0.05455
# 22     USDJPY    0.06727     AUDUSD    0.03161     GBPJPY    0.05455
# 23     EURGBP    0.06727     USDCAD    0.03161     CADCHF    0.05455
# 24     GBPCAD    0.00000     GBPCAD    0.01010     EURGBP    0.05455
# 25     EURJPY    0.00000     GBPCHF    0.01010     NZDUSD    0.04029
# 26     EURCAD    0.00000     EURGBP    0.01010     NZDCAD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDNZD    0.40825
# 1      EURCHF    0.40825
# 2      GBPUSD    0.21822
# 3      AUDCAD    0.21822
# 4      NZDJPY    0.21822
# 5      AUDJPY    0.21822
# 6      EURNZD    0.21822
# 7      GBPAUD    0.21822
# 8      GBPJPY    0.21822
# 9      EURGBP    0.21822
# 10     AUDUSD    0.21822
# 11     CHFJPY    0.21822
# 12     USDJPY    0.21822
# 13     EURCAD    0.20000
# 14     GBPCHF    0.20000
# 15     GBPCAD    0.20000
# 16     CADJPY    0.20000
# 17     NZDCAD    0.00000
# 18     EURUSD    0.00000
# 19     USDCAD    0.00000
# 20     CADCHF    0.00000
# 21     EURAUD    0.00000
# 22     AUDCHF    0.00000
# 23     EURJPY    0.00000
# 24     NZDUSD    0.00000
# 25     NZDCHF    0.00000
# 26     USDCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
