# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-16 08:50:34.141616

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.29758     USDCHF    0.30208     AUDCHF    0.53340
# 1      NZDJPY    0.15573     AUDCHF    0.25000     AUDNZD    0.50252
# 2      USDCHF    0.14943     NZDCHF    0.21822     NZDCHF    0.50252
# 3      EURUSD    0.14943     EURUSD    0.16477     EURAUD    0.41414
# 4      NZDCAD    0.13497     GBPCAD    0.14434     USDCHF    0.41414
# 5      EURAUD    0.13497     GBPCHF    0.13608     GBPCAD    0.38982
# 6      NZDCHF    0.12157     AUDNZD    0.13608     NZDCAD    0.32824
# 7      AUDUSD    0.12157     NZDUSD    0.13608     AUDUSD    0.30151
# 8      GBPAUD    0.12157     AUDUSD    0.13608     EURNZD    0.30151
# 9      EURJPY    0.10895     EURAUD    0.11111     EURUSD    0.30151
# 10     AUDNZD    0.10895     EURCHF    0.11111     NZDUSD    0.30151
# 11     GBPCHF    0.10895     USDCAD    0.08472     EURCHF    0.21212
# 12     AUDJPY    0.10123     NZDCAD    0.08183     NZDJPY    0.19192
# 13     EURCAD    0.08760     GBPUSD    0.08183     GBPAUD    0.19192
# 14     CADJPY    0.08760     GBPJPY    0.08183     GBPCHF    0.19192
# 15     CHFJPY    0.08181     GBPAUD    0.08183     CHFJPY    0.17911
# 16     GBPUSD    0.07462     AUDCAD    0.05455     AUDJPY    0.12309
# 17     NZDUSD    0.07462     NZDJPY    0.05455     AUDCAD    0.12309
# 18     EURGBP    0.07462     CADJPY    0.05455     EURJPY    0.10050
# 19     USDJPY    0.06732     EURJPY    0.05455     CADCHF    0.10050
# 20     AUDCHF    0.06204     EURCAD    0.05455     CADJPY    0.10050
# 21     CADCHF    0.06204     USDJPY    0.05455     EURGBP    0.10050
# 22     USDCAD    0.06204     CHFJPY    0.02778     GBPJPY    0.08206
# 23     EURCHF    0.05366     AUDJPY    0.02746     USDCAD    0.08206
# 24     GBPCAD    0.02764     CADCHF    0.02746     GBPUSD    0.01010
# 25     AUDCAD    0.02764     EURGBP    0.02746     USDJPY    0.01010
# 26     EURNZD    0.00649     EURNZD    0.00000     EURCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.44444     AUDCHF    0.66667  ...     EURNZD    0.23775
# 1      GBPCHF    0.38889     CADCHF    0.53452  ...     USDCAD    0.17138
# 2      AUDCHF    0.38889     AUDNZD    0.40825  ...     CADCHF    0.15198
# 3      USDCHF    0.38889     NZDCHF    0.40825  ...     CHFJPY    0.14385
# 4      EURUSD    0.32733     EURUSD    0.40825  ...     USDJPY    0.13497
# 5      NZDCHF    0.32733     EURAUD    0.40825  ...     EURJPY    0.11433
# 6      GBPCAD    0.28868     EURCAD    0.40825  ...     AUDCAD    0.11433
# 7      EURCHF    0.28868     GBPCAD    0.35635  ...     EURGBP    0.08353
# 8      CADCHF    0.28868     NZDCAD    0.25000  ...     EURCAD    0.08353
# 9      EURCAD    0.21822     AUDCAD    0.25000  ...     NZDJPY    0.07711
# 10     EURAUD    0.21822     CADJPY    0.25000  ...     NZDUSD    0.07711
# 11     AUDCAD    0.16667     GBPJPY    0.25000  ...     CADJPY    0.07711
# 12     CHFJPY    0.16667     USDCHF    0.25000  ...     AUDCHF    0.07114
# 13     AUDJPY    0.16667     CHFJPY    0.25000  ...     USDCHF    0.05366
# 14     NZDCAD    0.11111     EURCHF    0.25000  ...     EURUSD    0.05366
# 15     GBPUSD    0.11111     GBPCHF    0.25000  ...     GBPJPY    0.04670
# 16     NZDJPY    0.11111     USDJPY    0.25000  ...     GBPCAD    0.04670
# 17     GBPAUD    0.11111     GBPAUD    0.16667  ...     EURCHF    0.04670
# 18     CADJPY    0.11111     AUDUSD    0.16667  ...     GBPCHF    0.04670
# 19     EURNZD    0.05455     EURGBP    0.16667  ...     NZDCAD    0.04670
# 20     USDCAD    0.05455     EURJPY    0.08909  ...     GBPAUD    0.04013
# 21     EURJPY    0.05455     AUDJPY    0.08909  ...     NZDCHF    0.04013
# 22     AUDUSD    0.05455     GBPUSD    0.00000  ...     AUDUSD    0.04013
# 23     GBPJPY    0.05455     NZDUSD    0.00000  ...     EURAUD    0.03382
# 24     USDJPY    0.05455     EURNZD    0.00000  ...     AUDNZD    0.03382
# 25     NZDUSD    0.05455     NZDJPY    0.00000  ...     AUDJPY    0.00970
# 26     EURGBP    0.05455     USDCAD    0.00000  ...     GBPUSD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.43444     USDJPY    0.61616     USDJPY    0.49099
# 1      USDJPY    0.33929     USDCAD    0.53340     USDCAD    0.49099
# 2      USDCHF    0.27866     EURUSD    0.50252     AUDUSD    0.49099
# 3      EURUSD    0.27866     USDCHF    0.41414     NZDUSD    0.49099
# 4      EURNZD    0.26726     NZDUSD    0.30151     EURNZD    0.49099
# 5      EURCAD    0.19643     EURNZD    0.30151     USDCHF    0.38889
# 6      EURGBP    0.14382     EURGBP    0.30151     EURUSD    0.32733
# 7      AUDNZD    0.13363     AUDUSD    0.30151     NZDCHF    0.21822
# 8      NZDUSD    0.13363     CHFJPY    0.24232     EURGBP    0.21822
# 9      AUDUSD    0.13363     GBPCHF    0.21212     GBPCHF    0.16667
# 10     GBPCAD    0.09449     GBPUSD    0.21212     NZDCAD    0.16667
# 11     CHFJPY    0.08183     EURCHF    0.19192     GBPUSD    0.16667
# 12     AUDCHF    0.08183     AUDCAD    0.12309     CADJPY    0.16667
# 13     EURAUD    0.08183     AUDCHF    0.12309     CHFJPY    0.11111
# 14     AUDCAD    0.07143     AUDJPY    0.12309     AUDCAD    0.11111
# 15     NZDJPY    0.07143     CADJPY    0.10050     NZDJPY    0.11111
# 16     CADJPY    0.07143     EURJPY    0.10050     AUDJPY    0.11111
# 17     NZDCAD    0.06250     NZDCHF    0.10050     AUDNZD    0.11111
# 18     EURJPY    0.06250     CADCHF    0.10050     GBPAUD    0.11111
# 19     GBPAUD    0.06250     AUDNZD    0.10050     AUDCHF    0.11111
# 20     GBPJPY    0.06250     GBPJPY    0.08206     EURAUD    0.05455
# 21     GBPUSD    0.06250     NZDCAD    0.08206     EURJPY    0.05455
# 22     NZDCHF    0.06250     GBPCAD    0.03161     GBPJPY    0.05455
# 23     EURCHF    0.05455     GBPAUD    0.01010     EURCAD    0.05455
# 24     AUDJPY    0.00899     EURCAD    0.01010     CADCHF    0.00000
# 25     CADCHF    0.00899     EURAUD    0.01010     GBPCAD    0.00000
# 26     GBPCHF    0.00000     NZDJPY    0.01010     EURCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDUSD    0.60000
# 1      EURNZD    0.60000
# 2      USDCAD    0.60000
# 3      USDCHF    0.40825
# 4      CADJPY    0.40825
# 5      GBPAUD    0.40825
# 6      EURGBP    0.40825
# 7      USDJPY    0.40825
# 8      AUDUSD    0.40825
# 9      EURJPY    0.21822
# 10     CADCHF    0.21822
# 11     AUDJPY    0.21822
# 12     GBPCAD    0.21822
# 13     EURCAD    0.20000
# 14     NZDJPY    0.20000
# 15     EURUSD    0.20000
# 16     EURAUD    0.20000
# 17     AUDNZD    0.20000
# 18     GBPUSD    0.20000
# 19     NZDCHF    0.20000
# 20     EURCHF    0.00000
# 21     GBPJPY    0.00000
# 22     AUDCHF    0.00000
# 23     CHFJPY    0.00000
# 24     AUDCAD    0.00000
# 25     NZDCAD    0.00000
# 26     GBPCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
