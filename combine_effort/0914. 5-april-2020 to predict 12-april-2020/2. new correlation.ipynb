# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-11 12:12:53.119126

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.35065     NZDCAD    0.33036     USDJPY    0.37500
# 1      USDCHF    0.33307     EURCAD    0.33036     GBPCAD    0.37500
# 2      NZDCAD    0.31366     USDJPY    0.32733     EURJPY    0.32824
# 3      CHFJPY    0.29870     USDCHF    0.26726     GBPAUD    0.23570
# 4      EURUSD    0.27743     EURJPY    0.26726     EURGBP    0.20412
# 5      USDJPY    0.27743     AUDCAD    0.26068     GBPJPY    0.20412
# 6      NZDUSD    0.26948     CHFJPY    0.21822     CADJPY    0.20412
# 7      GBPUSD    0.23282     GBPUSD    0.20536     AUDNZD    0.20412
# 8      AUDUSD    0.22531     CADCHF    0.20536     USDCAD    0.20412
# 9      NZDJPY    0.20646     USDCAD    0.19643     GBPCHF    0.20412
# 10     AUDCAD    0.18831     CADJPY    0.19643     AUDUSD    0.17118
# 11     EURCAD    0.16116     EURUSD    0.13363     NZDJPY    0.16667
# 12     GBPJPY    0.15198     NZDUSD    0.13363     AUDJPY    0.16667
# 13     CADCHF    0.13636     EURGBP    0.12585     NZDUSD    0.12309
# 14     GBPCHF    0.11613     GBPAUD    0.11664     EURUSD    0.12309
# 15     NZDCHF    0.10714     NZDJPY    0.08183     USDCHF    0.12309
# 16     GBPAUD    0.10714     AUDCHF    0.07143     EURCAD    0.08206
# 17     EURCHF    0.09869     EURAUD    0.07143     EURNZD    0.08206
# 18     EURGBP    0.09054     NZDCHF    0.06250     CADCHF    0.08206
# 19     AUDJPY    0.08058     GBPCAD    0.05455     AUDCAD    0.08206
# 20     GBPCAD    0.08058     AUDJPY    0.05455     EURCHF    0.04280
# 21     AUDNZD    0.07114     GBPCHF    0.05455     CHFJPY    0.04167
# 22     AUDCHF    0.06204     AUDUSD    0.05455     EURAUD    0.04167
# 23     EURAUD    0.05519     EURCHF    0.01849     NZDCHF    0.04167
# 24     CADJPY    0.04516     AUDNZD    0.00899     AUDCHF    0.04167
# 25     USDCAD    0.03548     GBPJPY    0.00000     NZDCAD    0.04167
# 26     EURNZD    0.00000     EURNZD    0.00000     GBPUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.49099     EURJPY    0.81650  ...     GBPCAD    0.40291
# 1      USDCHF    0.33929     CHFJPY    0.60000  ...     GBPCHF    0.35807
# 2      CHFJPY    0.33929     GBPAUD    0.50000  ...     EURGBP    0.33307
# 3      AUDNZD    0.33929     EURAUD    0.40825  ...     GBPJPY    0.33307
# 4      GBPCAD    0.32733     EURCAD    0.40825  ...     GBPUSD    0.33307
# 5      USDJPY    0.32733     USDJPY    0.40825  ...     EURUSD    0.28710
# 6      NZDCAD    0.21822     AUDCAD    0.40825  ...     AUDCHF    0.26449
# 7      GBPCHF    0.21822     EURNZD    0.40825  ...     AUDUSD    0.26449
# 8      GBPAUD    0.20045     GBPUSD    0.40825  ...     NZDCAD    0.25223
# 9      GBPUSD    0.19643     NZDCAD    0.21822  ...     EURCHF    0.23028
# 10     EURAUD    0.18898     AUDUSD    0.21822  ...     NZDCHF    0.21753
# 11     AUDCAD    0.18898     NZDUSD    0.21822  ...     EURJPY    0.21753
# 12     CADCHF    0.18898     EURCHF    0.21822  ...     AUDCAD    0.21753
# 13     NZDCHF    0.09449     AUDCHF    0.21822  ...     EURCAD    0.16116
# 14     NZDJPY    0.07143     NZDCHF    0.21822  ...     AUDJPY    0.16116
# 15     AUDJPY    0.07143     USDCHF    0.20000  ...     NZDUSD    0.13636
# 16     CADJPY    0.07143     AUDJPY    0.20000  ...     EURAUD    0.13636
# 17     EURNZD    0.07143     EURUSD    0.20000  ...     USDJPY    0.12581
# 18     EURGBP    0.07143     NZDJPY    0.20000  ...     NZDJPY    0.11613
# 19     EURCAD    0.07143     CADJPY    0.00000  ...     USDCAD    0.11613
# 20     GBPJPY    0.07143     EURGBP    0.00000  ...     CHFJPY    0.10714
# 21     EURUSD    0.05455     GBPCAD    0.00000  ...     CADCHF    0.10714
# 22     USDCAD    0.05455     GBPJPY    0.00000  ...     GBPAUD    0.10714
# 23     AUDUSD    0.04029     CADCHF    0.00000  ...     AUDNZD    0.09054
# 24     AUDCHF    0.04029     GBPCHF    0.00000  ...     EURNZD    0.08058
# 25     EURCHF    0.04029     USDCAD    0.00000  ...     USDCHF    0.07114
# 26     NZDUSD    0.04029     AUDNZD    0.00000  ...     CADJPY    0.03548
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.65908     GBPCAD    0.69752     GBPCAD    0.72222
# 1      GBPCHF    0.52177     EURGBP    0.50252     GBPCHF    0.66667
# 2      AUDUSD    0.43939     GBPCHF    0.50252     NZDCHF    0.57735
# 3      EURCAD    0.41349     EURCAD    0.41414     EURCHF    0.49237
# 4      AUDCHF    0.41349     NZDCHF    0.32824     AUDCHF    0.49237
# 5      GBPUSD    0.39551     AUDCHF    0.32824     EURGBP    0.49099
# 6      EURCHF    0.38620     EURAUD    0.32824     EURNZD    0.49099
# 7      AUDCAD    0.35747     NZDCAD    0.32824     EURCAD    0.49099
# 8      EURUSD    0.33634     GBPUSD    0.30151     NZDCAD    0.38889
# 9      GBPJPY    0.33634     GBPJPY    0.30151     AUDCAD    0.28868
# 10     EURGBP    0.32127     EURCHF    0.24232     EURAUD    0.28868
# 11     NZDCHF    0.27866     AUDUSD    0.24232     GBPUSD    0.21822
# 12     EURAUD    0.27866     AUDCAD    0.21212     GBPJPY    0.21822
# 13     NZDCAD    0.27866     EURUSD    0.21212     USDCHF    0.21822
# 14     CADCHF    0.26068     EURNZD    0.19192     CHFJPY    0.21822
# 15     EURJPY    0.20180     CADCHF    0.19192     AUDNZD    0.21822
# 16     GBPAUD    0.16147     GBPAUD    0.17408     NZDUSD    0.18464
# 17     USDCAD    0.14382     CHFJPY    0.12309     AUDUSD    0.18464
# 18     AUDJPY    0.10985     USDJPY    0.12309     USDCAD    0.16667
# 19     NZDJPY    0.10985     CADJPY    0.10050     EURJPY    0.11111
# 20     USDCHF    0.06727     AUDNZD    0.10050     USDJPY    0.11111
# 21     EURNZD    0.06727     USDCAD    0.10050     EURUSD    0.11111
# 22     NZDUSD    0.06727     AUDJPY    0.08206     GBPAUD    0.06804
# 23     AUDNZD    0.04977     NZDJPY    0.08206     CADJPY    0.05455
# 24     CHFJPY    0.02746     EURJPY    0.01010     AUDJPY    0.05455
# 25     USDJPY    0.02746     NZDUSD    0.01010     NZDJPY    0.05455
# 26     CADJPY    0.00899     USDCHF    0.01010     CADCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.66667
# 1      GBPCHF    0.66667
# 2      GBPCAD    0.58333
# 3      NZDCHF    0.53452
# 4      AUDCHF    0.53452
# 5      EURCHF    0.53452
# 6      CHFJPY    0.40825
# 7      EURAUD    0.25000
# 8      EURNZD    0.25000
# 9      EURJPY    0.25000
# 10     CADCHF    0.25000
# 11     USDJPY    0.25000
# 12     GBPUSD    0.25000
# 13     GBPJPY    0.25000
# 14     AUDCAD    0.25000
# 15     EURCAD    0.25000
# 16     CADJPY    0.16667
# 17     AUDNZD    0.16667
# 18     USDCAD    0.16667
# 19     GBPAUD    0.10206
# 20     NZDUSD    0.08909
# 21     AUDUSD    0.08909
# 22     NZDCAD    0.08909
# 23     AUDJPY    0.00000
# 24     NZDJPY    0.00000
# 25     EURUSD    0.00000
# 26     USDCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
