# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 09:01:24.233261

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.34542     NZDCAD    0.38889     NZDCAD    0.31180
# 1      NZDCAD    0.26212     GBPUSD    0.35460     EURJPY    0.28571
# 2      GBPUSD    0.23028     AUDUSD    0.28868     USDJPY    0.21822
# 3      AUDCAD    0.19852     AUDCAD    0.28868     EURUSD    0.19048
# 4      USDCHF    0.16667     USDJPY    0.27217     AUDUSD    0.19048
# 5      CADJPY    0.14744     NZDUSD    0.27217     AUDCAD    0.19048
# 6      CHFJPY    0.13457     CHFJPY    0.25000     AUDNZD    0.15352
# 7      AUDCHF    0.13234     EURAUD    0.21822     NZDCHF    0.15352
# 8      NZDUSD    0.13074     NZDJPY    0.21822     GBPAUD    0.15352
# 9      EURCAD    0.13074     EURUSD    0.19767     GBPCAD    0.15352
# 10     AUDNZD    0.11580     GBPCHF    0.13608     GBPUSD    0.15352
# 11     EURUSD    0.11580     EURGBP    0.10985     NZDJPY    0.15352
# 12     USDCAD    0.09869     EURNZD    0.10985     CADCHF    0.15352
# 13     EURJPY    0.08333     AUDJPY    0.08183     EURAUD    0.15352
# 14     AUDJPY    0.08333     AUDNZD    0.08183     GBPCHF    0.15352
# 15     NZDJPY    0.08333     USDCAD    0.08183     NZDUSD    0.15352
# 16     CADCHF    0.08165     EURJPY    0.05648     AUDJPY    0.08909
# 17     EURCHF    0.08165     USDCHF    0.05648     CADJPY    0.08909
# 18     AUDUSD    0.06580     GBPAUD    0.05455     EURCAD    0.08909
# 19     GBPCAD    0.06553     GBPJPY    0.05455     EURGBP    0.06580
# 20     GBPAUD    0.04963     NZDCHF    0.05455     GBPJPY    0.06580
# 21     EURGBP    0.04903     CADJPY    0.05455     AUDCHF    0.04762
# 22     GBPCHF    0.03309     AUDCHF    0.02778     USDCHF    0.04762
# 23     EURAUD    0.03269     EURCHF    0.02778     CHFJPY    0.02288
# 24     GBPJPY    0.01638     EURCAD    0.02746     EURCHF    0.02288
# 25     NZDCHF    0.00000     GBPCAD    0.00000     USDCAD    0.02288
# 26     EURNZD    0.00000     CADCHF    0.00000     EURNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.36364     NZDCAD    0.58333  ...     GBPCAD    0.31366
# 1      NZDCAD    0.26189     EURUSD    0.40825  ...     GBPCHF    0.22531
# 2      GBPUSD    0.26189     USDCAD    0.35635  ...     EURGBP    0.19678
# 3      EURJPY    0.21320     EURJPY    0.35635  ...     AUDUSD    0.18831
# 4      AUDCHF    0.21320     CADJPY    0.35635  ...     EURCHF    0.16116
# 5      CHFJPY    0.18464     AUDCHF    0.35635  ...     CADCHF    0.16116
# 6      EURCAD    0.18464     GBPUSD    0.25000  ...     GBPJPY    0.15198
# 7      USDJPY    0.18464     USDJPY    0.25000  ...     AUDCAD    0.14368
# 8      USDCAD    0.12309     EURCAD    0.25000  ...     AUDCHF    0.14368
# 9      GBPAUD    0.12309     AUDNZD    0.16667  ...     GBPAUD    0.14368
# 10     AUDCAD    0.10660     GBPAUD    0.16667  ...     USDJPY    0.13636
# 11     EURCHF    0.10660     GBPCAD    0.16667  ...     EURCAD    0.11613
# 12     AUDUSD    0.10660     AUDJPY    0.16667  ...     CHFJPY    0.11289
# 13     USDCHF    0.07538     NZDCHF    0.16667  ...     GBPUSD    0.10714
# 14     EURAUD    0.04029     EURNZD    0.16667  ...     EURJPY    0.09869
# 15     NZDJPY    0.04029     NZDJPY    0.16667  ...     USDCHF    0.09869
# 16     AUDJPY    0.04029     NZDUSD    0.16667  ...     CADJPY    0.07114
# 17     CADJPY    0.04029     EURAUD    0.16667  ...     NZDCAD    0.07114
# 18     EURNZD    0.04029     EURCHF    0.10206  ...     EURUSD    0.06204
# 19     EURGBP    0.04029     AUDCAD    0.08909  ...     AUDNZD    0.06204
# 20     GBPCAD    0.04029     USDCHF    0.08909  ...     NZDUSD    0.03548
# 21     GBPJPY    0.04029     CHFJPY    0.08909  ...     EURAUD    0.03548
# 22     NZDCHF    0.04029     AUDUSD    0.08909  ...     USDCAD    0.02597
# 23     CADCHF    0.04029     GBPJPY    0.00000  ...     AUDJPY    0.01645
# 24     GBPCHF    0.04029     CADCHF    0.00000  ...     NZDJPY    0.01645
# 25     NZDUSD    0.04029     GBPCHF    0.00000  ...     NZDCHF    0.00000
# 26     AUDNZD    0.04029     EURGBP    0.00000  ...     EURNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.26726     CHFJPY    0.31449     NZDCHF    0.46429
# 1      USDCHF    0.25882     EURAUD    0.30151     EURNZD    0.46429
# 2      CHFJPY    0.21822     NZDCHF    0.30151     EURAUD    0.46429
# 3      EURAUD    0.20536     GBPUSD    0.30151     NZDCAD    0.33929
# 4      GBPAUD    0.19643     USDCHF    0.21822     GBPUSD    0.33929
# 5      NZDCHF    0.19643     EURUSD    0.21822     EURUSD    0.26189
# 6      EURCHF    0.19094     NZDCAD    0.20412     CHFJPY    0.21822
# 7      EURGBP    0.14382     CADJPY    0.20412     USDCHF    0.20045
# 8      GBPCHF    0.13363     USDJPY    0.20000     NZDJPY    0.19643
# 9      CADCHF    0.13363     EURNZD    0.20000     CADJPY    0.19643
# 10     GBPCAD    0.13363     USDCAD    0.10483     EURGBP    0.19643
# 11     EURNZD    0.12585     EURCHF    0.10483     CADCHF    0.19643
# 12     NZDCAD    0.08183     GBPCAD    0.10050     GBPCHF    0.19643
# 13     NZDJPY    0.07143     NZDJPY    0.10050     NZDUSD    0.19643
# 14     GBPUSD    0.07143     GBPAUD    0.10050     AUDNZD    0.19643
# 15     GBPJPY    0.07143     EURGBP    0.10050     EURCHF    0.18898
# 16     AUDJPY    0.07143     GBPJPY    0.10050     EURJPY    0.18898
# 17     CADJPY    0.07143     CADCHF    0.10050     AUDCHF    0.09449
# 18     AUDNZD    0.06250     GBPCHF    0.10050     AUDUSD    0.09449
# 19     USDCAD    0.06250     NZDUSD    0.10050     AUDCAD    0.09449
# 20     AUDCHF    0.05455     AUDNZD    0.10050     GBPJPY    0.07143
# 21     AUDUSD    0.04725     EURJPY    0.00000     GBPCAD    0.07143
# 22     AUDCAD    0.04725     EURCAD    0.00000     AUDJPY    0.07143
# 23     EURUSD    0.01849     AUDCHF    0.00000     GBPAUD    0.05455
# 24     EURJPY    0.01849     AUDJPY    0.00000     EURCAD    0.05455
# 25     EURCAD    0.00899     AUDCAD    0.00000     USDCAD    0.05455
# 26     NZDUSD    0.00000     AUDUSD    0.00000     USDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      CADJPY    0.65465
# 1      EURJPY    0.65465
# 2      EURCHF    0.50000
# 3      AUDNZD    0.40825
# 4      NZDCHF    0.40825
# 5      NZDCAD    0.40825
# 6      USDJPY    0.40825
# 7      AUDJPY    0.40825
# 8      EURNZD    0.40825
# 9      EURAUD    0.40825
# 10     GBPUSD    0.40825
# 11     AUDCAD    0.21822
# 12     USDCHF    0.21822
# 13     AUDCHF    0.21822
# 14     CHFJPY    0.21822
# 15     AUDUSD    0.21822
# 16     USDCAD    0.21822
# 17     GBPJPY    0.20000
# 18     CADCHF    0.20000
# 19     GBPCHF    0.20000
# 20     EURGBP    0.20000
# 21     GBPCAD    0.00000
# 22     GBPAUD    0.00000
# 23     EURCAD    0.00000
# 24     NZDUSD    0.00000
# 25     NZDJPY    0.00000
# 26     EURUSD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
