# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-06 23:34:35.229129
# 2021-12-06 23:34:35.232352
# 2021-12-06 23:35:35.238672
# 2021-12-06 23:36:35.253186
# 2021-12-06 23:37:35.274137
# 2021-12-06 23:38:35.283310
# 2021-12-06 23:39:35.293748
# 2021-12-06 23:40:35.300809
# 2021-12-06 23:41:35.307743
# 2021-12-06 23:42:35.315232
# 2021-12-06 23:43:35.321763
# 2021-12-06 23:44:35.328627
# 2021-12-06 23:45:35.338423
# 2021-12-06 23:46:35.342426
# 2021-12-06 23:47:35.360525
# 2021-12-06 23:48:35.385304
# 2021-12-06 23:49:35.400658
# 2021-12-06 23:50:35.406694
# 2021-12-06 23:51:35.418117
# 2021-12-06 23:52:35.434048
# 2021-12-06 23:53:35.451074
# 2021-12-06 23:54:35.459147
# 2021-12-06 23:55:35.466779
# 2021-12-06 23:56:35.488239
# 2021-12-06 23:57:35.493384
# 2021-12-06 23:58:35.505478
# 2021-12-06 23:59:35.512116
# 2021-12-07 00:00:35.517485
# 2021-12-07 00:01:35.532617
# 2021-12-07 00:02:35.552703
# 2021-12-07 00:03:35.566825
# 2021-12-07 00:04:35.573925
# 2021-12-07 00:05:35.576850
# 2021-12-07 00:06:35.583208
# 2021-12-07 00:07:35.588276
# 2021-12-07 00:08:35.594757
# 2021-12-07 00:09:35.599875
# 2021-12-07 00:10:35.608741
# 2021-12-07 00:11:35.613142
# 2021-12-07 00:12:35.625557
# 2021-12-07 00:13:35.647587
# 2021-12-07 00:14:35.671511
# 2021-12-07 00:15:35.689836
# 2021-12-07 00:16:35.696767
# 2021-12-07 00:17:35.711136
# 2021-12-07 00:18:35.717791
# 2021-12-07 00:19:35.739766
# 2021-12-07 00:20:35.757604
# 2021-12-07 00:21:35.773268
# 2021-12-07 04:21:38.801008
# 2021-12-07 04:22:38.818377
# 2021-12-07 04:23:38.823678
# 2021-12-07 04:24:38.844449
# 2021-12-07 04:25:38.860767
# 2021-12-07 04:26:38.879272

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 10 [-0.1252]
# GBPUSD 20 [0.32715329]
# EURUSD 10 [0.1334]
# USDJPY 15 [-0.9313]
# USDCAD 10 [0.19768921]
# NZDUSD 15 [1.]
# GBPCHF 10 [0.54678429]
# EURCHF 10 [-0.49137302]
# CHFJPY 20 [0.99981333]
# CADCHF 10 [0.56139667]
# EURGBP 10 [0.7209]
# GBPJPY 15 [0.9307]
# GBPCAD 20 [-0.75106478]
# GBPAUD 15 [0.71575182]
# EURJPY 10 [0.75307655]
# EURCAD 10 [-0.98957]
# EURAUD 10 [0.2952131]
# EURNZD 10 [0.29072992]
# AUDJPY 10 [1.]
# NZDJPY 10 [0.54924917]
# ['S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
