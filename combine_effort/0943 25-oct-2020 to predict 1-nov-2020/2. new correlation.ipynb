# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 15:06:21.853715

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.27783     GBPUSD    0.38620     EURUSD    0.42857
# 1      GBPUSD    0.23028     AUDUSD    0.34717     GBPUSD    0.37284
# 2      NZDCAD    0.18021     NZDCAD    0.33887     CHFJPY    0.31180
# 3      GBPCAD    0.14744     NZDUSD    0.29579     AUDCHF    0.28511
# 4      USDCHF    0.13457     EURUSD    0.29187     AUDUSD    0.25163
# 5      CHFJPY    0.13457     NZDJPY    0.24661     NZDCAD    0.21822
# 6      AUDNZD    0.13074     AUDCAD    0.24456     NZDJPY    0.21822
# 7      NZDUSD    0.13074     USDJPY    0.20751     NZDUSD    0.21822
# 8      EURUSD    0.11580     CHFJPY    0.19767     EURGBP    0.15352
# 9      AUDCAD    0.11580     GBPJPY    0.15714     GBPCHF    0.15352
# 10     AUDCHF    0.11440     EURAUD    0.15714     AUDJPY    0.15352
# 11     EURJPY    0.08333     USDCHF    0.14833     EURNZD    0.15352
# 12     NZDJPY    0.08333     AUDJPY    0.10702     EURCAD    0.15352
# 13     GBPAUD    0.08333     EURNZD    0.10702     GBPJPY    0.15352
# 14     EURNZD    0.08165     AUDNZD    0.10702     GBPAUD    0.13363
# 15     CADJPY    0.08165     USDCAD    0.10702     USDCHF    0.12599
# 16     AUDUSD    0.06580     AUDCHF    0.08472     EURCHF    0.08909
# 17     AUDJPY    0.04963     GBPCAD    0.06917     USDCAD    0.08909
# 18     EURGBP    0.04903     GBPAUD    0.06917     AUDCAD    0.08909
# 19     EURCAD    0.04903     NZDCHF    0.06917     USDJPY    0.08909
# 20     EURAUD    0.03269     CADJPY    0.06917     GBPCAD    0.06580
# 21     NZDCHF    0.03269     EURCHF    0.05648     NZDCHF    0.06580
# 22     CADCHF    0.03269     EURCAD    0.01849     EURAUD    0.06580
# 23     GBPCHF    0.03269     CADCHF    0.01849     CADCHF    0.06580
# 24     USDCAD    0.01645     GBPCHF    0.01849     EURJPY    0.02288
# 25     GBPJPY    0.01638     EURGBP    0.01849     CADJPY    0.00000
# 26     EURCHF    0.00000     EURJPY    0.00478     AUDNZD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.49237     EURUSD    0.81650  ...     GBPCAD    0.31807
# 1      NZDCAD    0.44444     USDCHF    0.60000  ...     EURGBP    0.28205
# 2      GBPUSD    0.38889     NZDCAD    0.60000  ...     GBPCHF    0.27885
# 3      AUDCHF    0.32733     AUDCAD    0.60000  ...     AUDCHF    0.19872
# 4      NZDJPY    0.32733     AUDUSD    0.60000  ...     CHFJPY    0.17485
# 5      NZDUSD    0.32733     NZDUSD    0.60000  ...     EURCHF    0.16013
# 6      USDCHF    0.28868     CHFJPY    0.60000  ...     AUDCAD    0.15573
# 7      AUDUSD    0.28868     EURCAD    0.60000  ...     USDJPY    0.12179
# 8      CHFJPY    0.28868     GBPUSD    0.40825  ...     CADCHF    0.11859
# 9      EURCAD    0.21822     NZDJPY    0.40825  ...     EURCAD    0.11859
# 10     GBPJPY    0.21822     AUDJPY    0.40825  ...     AUDUSD    0.11613
# 11     EURGBP    0.21822     EURNZD    0.40825  ...     GBPAUD    0.11440
# 12     GBPCHF    0.21822     GBPAUD    0.40825  ...     CADJPY    0.08006
# 13     NZDCHF    0.16667     EURGBP    0.40825  ...     NZDCAD    0.07711
# 14     GBPAUD    0.16667     GBPCHF    0.40825  ...     GBPJPY    0.07711
# 15     EURAUD    0.16667     USDJPY    0.21822  ...     USDCHF    0.07258
# 16     CADJPY    0.16667     AUDNZD    0.21822  ...     NZDJPY    0.04903
# 17     EURNZD    0.11111     GBPJPY    0.20000  ...     USDCAD    0.04516
# 18     AUDJPY    0.11111     GBPCAD    0.20000  ...     EURAUD    0.04167
# 19     AUDCAD    0.11111     EURJPY    0.20000  ...     NZDUSD    0.04167
# 20     USDJPY    0.11111     AUDCHF    0.20000  ...     NZDCHF    0.03846
# 21     CADCHF    0.05455     EURAUD    0.20000  ...     AUDNZD    0.03846
# 22     GBPCAD    0.05455     CADCHF    0.20000  ...     GBPUSD    0.03548
# 23     AUDNZD    0.05455     EURCHF    0.20000  ...     EURJPY    0.03269
# 24     EURCHF    0.00000     NZDCHF    0.00000  ...     AUDJPY    0.00649
# 25     EURJPY    0.00000     CADJPY    0.00000  ...     EURUSD    0.00649
# 26     USDCAD    0.00000     USDCAD    0.00000  ...     EURNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDCHF    0.26726     NZDCHF    0.30151     CADJPY    0.49099
# 1      CHFJPY    0.21822     EURNZD    0.30151     EURCHF    0.37796
# 2      EURGBP    0.20536     EURAUD    0.30151     EURJPY    0.37796
# 3      EURAUD    0.20536     GBPUSD    0.30151     AUDNZD    0.33929
# 4      GBPCHF    0.19643     EURUSD    0.21822     AUDCHF    0.33929
# 5      EURUSD    0.15714     EURCHF    0.20412     USDJPY    0.32733
# 6      NZDJPY    0.14382     CHFJPY    0.20412     GBPUSD    0.32733
# 7      AUDJPY    0.14382     AUDNZD    0.20000     NZDCAD    0.21822
# 8      GBPUSD    0.14382     NZDCAD    0.20000     AUDCAD    0.21822
# 9      GBPCAD    0.13363     NZDJPY    0.20000     AUDJPY    0.21822
# 10     USDJPY    0.13363     CADJPY    0.20000     EURNZD    0.21822
# 11     CADJPY    0.13363     NZDUSD    0.20000     EURAUD    0.21822
# 12     GBPAUD    0.13363     USDCHF    0.11547     NZDCHF    0.21822
# 13     EURNZD    0.12585     EURJPY    0.10483     GBPCAD    0.19643
# 14     AUDNZD    0.12585     AUDUSD    0.10483     EURGBP    0.19643
# 15     USDCHF    0.12016     AUDCHF    0.10050     GBPCHF    0.19643
# 16     NZDCAD    0.08183     GBPJPY    0.10050     CHFJPY    0.09449
# 17     GBPJPY    0.07143     GBPCAD    0.10050     AUDUSD    0.09449
# 18     EURCAD    0.07143     EURCAD    0.10050     USDCAD    0.09449
# 19     CADCHF    0.07143     CADCHF    0.10050     USDCHF    0.09449
# 20     NZDUSD    0.07143     GBPCHF    0.10050     GBPJPY    0.07143
# 21     AUDCHF    0.05455     AUDJPY    0.10050     CADCHF    0.07143
# 22     EURCHF    0.05455     EURGBP    0.10050     EURCAD    0.07143
# 23     AUDCAD    0.04725     GBPAUD    0.00000     NZDUSD    0.07143
# 24     AUDUSD    0.02916     USDCAD    0.00000     NZDJPY    0.07143
# 25     EURJPY    0.01849     AUDCAD    0.00000     GBPAUD    0.05455
# 26     USDCAD    0.00899     USDJPY    0.00000     EURUSD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.53452
# 1      GBPCHF    0.53452
# 2      USDJPY    0.52381
# 3      GBPUSD    0.35635
# 4      EURUSD    0.35635
# 5      CADJPY    0.35635
# 6      NZDCAD    0.21822
# 7      AUDCAD    0.21822
# 8      EURAUD    0.21822
# 9      EURCAD    0.21822
# 10     EURJPY    0.21822
# 11     GBPCAD    0.21822
# 12     GBPJPY    0.21822
# 13     USDCHF    0.21822
# 14     AUDCHF    0.21822
# 15     CADCHF    0.21822
# 16     CHFJPY    0.21822
# 17     EURCHF    0.21822
# 18     NZDUSD    0.21822
# 19     AUDUSD    0.21822
# 20     NZDCHF    0.08909
# 21     GBPAUD    0.08909
# 22     EURNZD    0.08909
# 23     AUDJPY    0.08909
# 24     NZDJPY    0.08909
# 25     USDCAD    0.08909
# 26     AUDNZD    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
