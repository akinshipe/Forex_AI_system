# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 23:10:05.897012

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.27421     EURJPY    0.40360     CADJPY    0.47140
# 1      CADJPY    0.27421     CADJPY    0.38536     GBPCHF    0.35722
# 2      EURJPY    0.27263     GBPJPY    0.25065     USDCAD    0.25000
# 3      GBPJPY    0.27263     AUDNZD    0.23783     EURJPY    0.22866
# 4      EURUSD    0.21627     CHFJPY    0.23783     GBPJPY    0.22866
# 5      AUDNZD    0.18021     GBPCHF    0.23324     USDCHF    0.16667
# 6      GBPUSD    0.15418     EURUSD    0.20180     NZDCHF    0.16667
# 7      EURNZD    0.15198     EURNZD    0.16477     CHFJPY    0.16667
# 8      EURGBP    0.15198     EURAUD    0.16477     CADCHF    0.13363
# 9      AUDJPY    0.14385     EURGBP    0.16477     EURUSD    0.12309
# 10     NZDJPY    0.11699     USDCAD    0.10702     EURCAD    0.12309
# 11     GBPCHF    0.10701     NZDJPY    0.10090     GBPUSD    0.08909
# 12     NZDUSD    0.10701     AUDJPY    0.09513     EURGBP    0.08909
# 13     CADCHF    0.10701     AUDCAD    0.08597     AUDCHF    0.08206
# 14     AUDCHF    0.10417     USDJPY    0.08597     GBPAUD    0.08206
# 15     NZDCAD    0.09829     GBPUSD    0.07099     AUDUSD    0.08206
# 16     EURCAD    0.07711     NZDUSD    0.07099     AUDJPY    0.08206
# 17     GBPAUD    0.07114     EURCHF    0.04757     NZDCAD    0.08206
# 18     EURAUD    0.07114     GBPCAD    0.04757     EURCHF    0.04280
# 19     NZDCHF    0.06118     NZDCAD    0.04757     AUDNZD    0.04280
# 20     AUDUSD    0.06118     AUDCHF    0.04757     NZDUSD    0.04167
# 21     USDJPY    0.04013     AUDUSD    0.02746     USDJPY    0.04167
# 22     AUDCAD    0.02764     NZDCHF    0.01468     AUDCAD    0.04167
# 23     EURCHF    0.02341     EURCAD    0.00899     GBPCAD    0.00000
# 24     USDCAD    0.02150     USDCHF    0.00899     EURAUD    0.00000
# 25     GBPCAD    0.02150     GBPAUD    0.00899     EURNZD    0.00000
# 26     USDCHF    0.00970     CADCHF    0.00530     NZDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      USDCHF    0.44444     CADJPY    0.53452  ...     GBPUSD    0.24131
# 1      GBPCHF    0.43082     GBPCHF    0.53452  ...     EURUSD    0.19852
# 2      CADJPY    0.43082     CADCHF    0.53452  ...     USDJPY    0.16330
# 3      CADCHF    0.43082     GBPJPY    0.40825  ...     CADJPY    0.15309
# 4      AUDCHF    0.32733     GBPCAD    0.40825  ...     USDCHF    0.14804
# 5      AUDNZD    0.28868     AUDCHF    0.40825  ...     EURAUD    0.14804
# 6      USDCAD    0.28868     NZDJPY    0.35635  ...     GBPCAD    0.13457
# 7      GBPJPY    0.27217     USDCAD    0.35635  ...     AUDCAD    0.11580
# 8      NZDUSD    0.21822     AUDNZD    0.25000  ...     GBPJPY    0.11169
# 9      EURJPY    0.21822     EURUSD    0.25000  ...     GBPCHF    0.10206
# 10     EURAUD    0.21822     AUDUSD    0.25000  ...     NZDCAD    0.08333
# 11     NZDJPY    0.18464     GBPAUD    0.25000  ...     AUDNZD    0.08333
# 12     USDJPY    0.16667     USDCHF    0.16667  ...     EURJPY    0.07446
# 13     NZDCHF    0.16667     EURCHF    0.16667  ...     EURCHF    0.06804
# 14     AUDUSD    0.16667     NZDUSD    0.16667  ...     GBPAUD    0.06580
# 15     EURCAD    0.16667     GBPUSD    0.08909  ...     EURNZD    0.06580
# 16     CHFJPY    0.11111     CHFJPY    0.08909  ...     NZDJPY    0.05251
# 17     GBPUSD    0.11111     EURAUD    0.08909  ...     NZDCHF    0.05046
# 18     EURUSD    0.05455     AUDCAD    0.08909  ...     AUDCHF    0.05046
# 19     NZDCAD    0.05455     EURGBP    0.08909  ...     AUDUSD    0.05046
# 20     AUDJPY    0.05455     NZDCHF    0.00000  ...     AUDJPY    0.03364
# 21     GBPAUD    0.05455     EURCAD    0.00000  ...     USDCAD    0.03364
# 22     EURNZD    0.05455     EURNZD    0.00000  ...     EURCAD    0.03269
# 23     GBPCAD    0.00000     AUDJPY    0.00000  ...     CADCHF    0.01701
# 24     AUDCAD    0.00000     USDJPY    0.00000  ...     CHFJPY    0.01701
# 25     EURCHF    0.00000     NZDCAD    0.00000  ...     NZDUSD    0.01701
# 26     EURGBP    0.00000     EURJPY    0.00000  ...     EURGBP    0.01645
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.42640     GBPCAD    0.42366     AUDNZD    0.50000
# 1      GBPCAD    0.35000     GBPCHF    0.36690     GBPCAD    0.50000
# 2      GBPJPY    0.27735     AUDNZD    0.31868     GBPCHF    0.42640
# 3      GBPUSD    0.26650     GBPJPY    0.30826     AUDCAD    0.40000
# 4      USDJPY    0.23783     NZDJPY    0.30261     AUDCHF    0.37796
# 5      AUDCHF    0.20000     AUDCAD    0.25678     GBPJPY    0.35355
# 6      AUDCAD    0.19026     USDCHF    0.25678     GBPUSD    0.28868
# 7      USDCHF    0.18898     USDJPY    0.25678     USDCHF    0.28868
# 8      NZDJPY    0.17678     GBPUSD    0.25163     AUDUSD    0.28868
# 9      EURAUD    0.14434     AUDCHF    0.24232     USDJPY    0.28868
# 10     EURGBP    0.14434     AUDUSD    0.17911     NZDJPY    0.21320
# 11     EURUSD    0.14142     EURUSD    0.17911     EURGBP    0.20000
# 12     CHFJPY    0.10000     EURCHF    0.12088     USDCAD    0.20000
# 13     AUDJPY    0.10000     EURNZD    0.10483     GBPAUD    0.18898
# 14     GBPAUD    0.09449     EURAUD    0.10483     EURUSD    0.18898
# 15     CADCHF    0.05573     CADJPY    0.06052     EURAUD    0.18898
# 16     NZDUSD    0.05330     NZDUSD    0.04280     EURJPY    0.18898
# 17     CADJPY    0.05330     NZDCHF    0.04280     CADJPY    0.10660
# 18     EURCHF    0.05000     CHFJPY    0.04280     CADCHF    0.10660
# 19     NZDCAD    0.05000     USDCAD    0.04280     EURCHF    0.10000
# 20     AUDNZD    0.05000     GBPAUD    0.03161     EURNZD    0.09449
# 21     USDCAD    0.04891     EURCAD    0.03161     AUDJPY    0.09449
# 22     EURCAD    0.04725     NZDCAD    0.03161     NZDUSD    0.09449
# 23     NZDCHF    0.00000     AUDJPY    0.03161     NZDCAD    0.09449
# 24     EURJPY    0.00000     EURGBP    0.02288     CHFJPY    0.00000
# 25     AUDUSD    0.00000     CADCHF    0.02288     EURCAD    0.00000
# 26     EURNZD    0.00000     EURJPY    0.01468     NZDCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDNZD    0.66667
# 1      GBPCHF    0.53452
# 2      AUDCHF    0.40825
# 3      USDJPY    0.40825
# 4      GBPCAD    0.40825
# 5      GBPJPY    0.40825
# 6      AUDCAD    0.35635
# 7      NZDJPY    0.35635
# 8      EURAUD    0.35635
# 9      CHFJPY    0.35635
# 10     USDCHF    0.25000
# 11     EURUSD    0.25000
# 12     EURCHF    0.16667
# 13     NZDUSD    0.16667
# 14     GBPAUD    0.16667
# 15     AUDUSD    0.16667
# 16     CADCHF    0.08909
# 17     GBPUSD    0.08909
# 18     CADJPY    0.08909
# 19     USDCAD    0.08909
# 20     EURGBP    0.08909
# 21     NZDCHF    0.00000
# 22     EURCAD    0.00000
# 23     EURNZD    0.00000
# 24     AUDJPY    0.00000
# 25     NZDCAD    0.00000
# 26     EURJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
