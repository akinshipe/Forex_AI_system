# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-12 08:56:46.022969

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.39451     USDJPY    0.46371     EURJPY    0.41414
# 1      NZDCAD    0.36116     GBPUSD    0.27866     USDJPY    0.38982
# 2      USDCHF    0.32450     USDCHF    0.26726     GBPUSD    0.30151
# 3      GBPUSD    0.31807     EURJPY    0.26726     AUDNZD    0.24232
# 4      USDJPY    0.31366     NZDCAD    0.26726     CHFJPY    0.21212
# 5      CHFJPY    0.29758     AUDCAD    0.26726     USDCHF    0.21212
# 6      EURUSD    0.27536     CADJPY    0.26726     GBPCAD    0.19192
# 7      NZDUSD    0.27536     CADCHF    0.20536     EURCAD    0.12309
# 8      AUDUSD    0.19485     EURCAD    0.19643     EURGBP    0.10050
# 9      GBPJPY    0.19485     AUDJPY    0.19094     AUDCAD    0.10050
# 10     NZDJPY    0.17138     CHFJPY    0.14382     CADJPY    0.10050
# 11     AUDCAD    0.15743     EURUSD    0.13363     EURAUD    0.10050
# 12     CADCHF    0.12721     USDCAD    0.13363     NZDJPY    0.08206
# 13     NZDCHF    0.11433     NZDUSD    0.13363     AUDJPY    0.08206
# 14     EURCAD    0.07711     EURAUD    0.13363     EURUSD    0.08206
# 15     AUDNZD    0.07114     AUDNZD    0.08183     GBPAUD    0.06580
# 16     EURCHF    0.06553     EURCHF    0.08183     NZDCHF    0.03161
# 17     AUDJPY    0.04670     AUDCHF    0.06250     EURCHF    0.03161
# 18     GBPCAD    0.04013     AUDUSD    0.06250     NZDUSD    0.03161
# 19     EURAUD    0.04013     GBPCAD    0.05455     GBPCHF    0.01010
# 20     EURNZD    0.04013     NZDJPY    0.05455     GBPJPY    0.01010
# 21     CADJPY    0.04013     GBPAUD    0.04725     USDCAD    0.01010
# 22     GBPAUD    0.03382     GBPCHF    0.01849     EURNZD    0.01010
# 23     AUDCHF    0.03382     EURGBP    0.00899     AUDCHF    0.01010
# 24     USDCAD    0.03382     GBPJPY    0.00000     CADCHF    0.01010
# 25     EURGBP    0.03382     NZDCHF    0.00000     AUDUSD    0.01010
# 26     GBPCHF    0.00321     EURNZD    0.00000     NZDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.73214     GBPUSD    0.81650  ...     GBPCAD    0.40291
# 1      CHFJPY    0.60714     EURNZD    0.65465  ...     GBPUSD    0.36775
# 2      USDCHF    0.33929     NZDUSD    0.65465  ...     GBPCHF    0.35807
# 3      EURAUD    0.33929     EURAUD    0.60000  ...     EURGBP    0.33307
# 4      GBPUSD    0.33929     NZDCAD    0.60000  ...     GBPJPY    0.33307
# 5      AUDCAD    0.33929     EURJPY    0.60000  ...     EURUSD    0.33307
# 6      GBPAUD    0.26189     AUDUSD    0.60000  ...     AUDUSD    0.33307
# 7      NZDUSD    0.26189     AUDCAD    0.60000  ...     AUDCHF    0.33307
# 8      AUDUSD    0.21822     CHFJPY    0.60000  ...     AUDCAD    0.28710
# 9      CADJPY    0.21822     AUDCHF    0.40825  ...     NZDCAD    0.24175
# 10     AUDCHF    0.21822     EURGBP    0.40825  ...     EURCHF    0.23028
# 11     EURNZD    0.21822     GBPCHF    0.40825  ...     EURJPY    0.21753
# 12     USDJPY    0.21822     USDCAD    0.40825  ...     NZDUSD    0.17138
# 13     GBPJPY    0.21822     USDJPY    0.40825  ...     NZDCHF    0.17138
# 14     EURUSD    0.21822     NZDCHF    0.21822  ...     EURAUD    0.16116
# 15     NZDJPY    0.19643     GBPJPY    0.21822  ...     AUDJPY    0.15198
# 16     AUDJPY    0.19643     GBPAUD    0.21822  ...     CADCHF    0.15198
# 17     EURGBP    0.19643     CADJPY    0.21822  ...     CHFJPY    0.14368
# 18     AUDNZD    0.18898     AUDJPY    0.20000  ...     USDJPY    0.13636
# 19     EURCHF    0.09449     NZDJPY    0.20000  ...     EURCAD    0.12581
# 20     USDCAD    0.09449     USDCHF    0.20000  ...     USDCHF    0.11613
# 21     GBPCAD    0.07143     GBPCAD    0.20000  ...     NZDJPY    0.10714
# 22     GBPCHF    0.07143     EURUSD    0.20000  ...     EURNZD    0.08058
# 23     NZDCAD    0.07143     EURCAD    0.00000  ...     GBPAUD    0.07114
# 24     EURCAD    0.05455     CADCHF    0.00000  ...     USDCAD    0.07114
# 25     NZDCHF    0.05455     EURCHF    0.00000  ...     AUDNZD    0.05519
# 26     CADCHF    0.05455     AUDNZD    0.00000  ...     CADJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.58333     GBPCHF    0.73855     GBPCHF    0.76376
# 1      GBPCHF    0.50830     GBPCAD    0.69752     EURGBP    0.60010
# 2      EURGBP    0.38446     EURGBP    0.61237     GBPCAD    0.60010
# 3      GBPUSD    0.38446     GBPUSD    0.40825     GBPUSD    0.49099
# 4      AUDUSD    0.35460     EURCHF    0.38516     EURNZD    0.38889
# 5      AUDCHF    0.32733     NZDCHF    0.38516     AUDCHF    0.38889
# 6      NZDCAD    0.27217     GBPJPY    0.32824     NZDCHF    0.38889
# 7      AUDCAD    0.27217     NZDCAD    0.32824     USDJPY    0.38889
# 8      NZDCHF    0.27217     EURNZD    0.32824     CHFJPY    0.32733
# 9      GBPJPY    0.27217     AUDCHF    0.32824     EURCHF    0.28868
# 10     EURUSD    0.27217     EURUSD    0.25000     AUDJPY    0.21822
# 11     EURAUD    0.27217     EURCAD    0.25000     EURAUD    0.21822
# 12     EURCHF    0.25000     AUDCAD    0.20412     EURJPY    0.21822
# 13     EURCAD    0.21822     EURAUD    0.20412     NZDJPY    0.21822
# 14     CADCHF    0.19094     AUDNZD    0.17118     NZDCAD    0.21822
# 15     GBPAUD    0.14434     NZDUSD    0.17118     AUDCAD    0.21822
# 16     NZDUSD    0.13608     USDJPY    0.17118     NZDUSD    0.18464
# 17     EURJPY    0.13608     GBPAUD    0.13363     CADJPY    0.16667
# 18     EURNZD    0.13608     CHFJPY    0.12309     GBPAUD    0.12309
# 19     USDJPY    0.11111     AUDUSD    0.12309     GBPJPY    0.11111
# 20     AUDJPY    0.02778     USDCHF    0.12309     EURCAD    0.11111
# 21     NZDJPY    0.02778     CADCHF    0.08206     AUDUSD    0.11111
# 22     AUDNZD    0.02778     EURJPY    0.08206     EURUSD    0.11111
# 23     CHFJPY    0.02746     USDCAD    0.08206     CADCHF    0.11111
# 24     CADJPY    0.00000     AUDJPY    0.04167     USDCHF    0.05455
# 25     USDCAD    0.00000     NZDJPY    0.04167     USDCAD    0.00000
# 26     USDCHF    0.00000     CADJPY    0.00000     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.81650
# 1      GBPCHF    0.81650
# 2      GBPCAD    0.60000
# 3      AUDCHF    0.40825
# 4      USDJPY    0.40825
# 5      GBPUSD    0.40825
# 6      EURCHF    0.40825
# 7      GBPAUD    0.21822
# 8      GBPJPY    0.21822
# 9      NZDCHF    0.21822
# 10     EURNZD    0.21822
# 11     CADJPY    0.21822
# 12     NZDUSD    0.21822
# 13     EURAUD    0.20000
# 14     NZDJPY    0.20000
# 15     AUDCAD    0.20000
# 16     NZDCAD    0.20000
# 17     AUDJPY    0.20000
# 18     USDCHF    0.20000
# 19     EURJPY    0.20000
# 20     CHFJPY    0.20000
# 21     AUDUSD    0.20000
# 22     EURUSD    0.20000
# 23     EURCAD    0.00000
# 24     CADCHF    0.00000
# 25     USDCAD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
