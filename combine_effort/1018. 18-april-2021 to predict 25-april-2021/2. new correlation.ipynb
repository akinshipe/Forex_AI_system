# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 08:01:08.398416

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.29870     EURUSD    0.40089     NZDCAD    0.49237
# 1      EURJPY    0.26318     NZDCAD    0.40089     EURCAD    0.41414
# 2      GBPJPY    0.25567     EURCAD    0.33333     EURUSD    0.41414
# 3      GBPCHF    0.22531     USDJPY    0.20751     USDJPY    0.37284
# 4      NZDCAD    0.22531     AUDCAD    0.20180     EURCHF    0.37284
# 5      CADJPY    0.17459     GBPJPY    0.20180     CHFJPY    0.32824
# 6      EURCAD    0.17138     GBPUSD    0.20000     AUDCAD    0.28721
# 7      USDJPY    0.16116     NZDUSD    0.20000     AUDNZD    0.28511
# 8      EURCHF    0.12581     GBPCHF    0.20000     GBPCHF    0.21212
# 9      EURAUD    0.12581     AUDNZD    0.13608     USDCAD    0.21212
# 10     AUDCAD    0.10714     EURNZD    0.13608     AUDJPY    0.21212
# 11     GBPUSD    0.10714     AUDJPY    0.13363     GBPUSD    0.21212
# 12     NZDUSD    0.09869     EURAUD    0.13363     NZDUSD    0.19192
# 13     USDCHF    0.09054     USDCHF    0.13363     GBPJPY    0.19192
# 14     AUDUSD    0.09054     AUDUSD    0.13363     CADCHF    0.12309
# 15     GBPAUD    0.08058     GBPCAD    0.06917     CADJPY    0.12309
# 16     AUDJPY    0.06580     EURCHF    0.06917     EURNZD    0.12309
# 17     AUDCHF    0.05519     NZDJPY    0.06917     EURJPY    0.12309
# 18     GBPCAD    0.05313     NZDCHF    0.06727     EURAUD    0.10050
# 19     NZDCHF    0.05313     CADJPY    0.06727     USDCHF    0.10050
# 20     CHFJPY    0.05313     GBPAUD    0.06667     AUDCHF    0.10050
# 21     CADCHF    0.04083     EURJPY    0.06667     AUDUSD    0.10050
# 22     USDCAD    0.03548     USDCAD    0.06667     NZDCHF    0.03161
# 23     EURGBP    0.00970     AUDCHF    0.00000     NZDJPY    0.03161
# 24     EURNZD    0.00970     CADCHF    0.00000     GBPAUD    0.01010
# 25     AUDNZD    0.00970     CHFJPY    0.00000     GBPCAD    0.01010
# 26     NZDJPY    0.00345     EURGBP    0.00000     EURGBP    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.47246     EURCAD    0.58333  ...     GBPCAD    0.19590
# 1      USDJPY    0.37796     AUDCHF    0.58333  ...     GBPCHF    0.18286
# 2      EURCHF    0.37796     AUDUSD    0.58333  ...     USDCHF    0.15198
# 3      EURUSD    0.33929     EURGBP    0.40825  ...     AUDNZD    0.15198
# 4      USDCAD    0.33929     NZDUSD    0.40825  ...     GBPUSD    0.13636
# 5      CHFJPY    0.33929     CHFJPY    0.40825  ...     AUDCAD    0.13636
# 6      EURCAD    0.33929     AUDNZD    0.40825  ...     EURUSD    0.10714
# 7      NZDCAD    0.32733     EURAUD    0.35635  ...     AUDJPY    0.09869
# 8      GBPJPY    0.32733     USDJPY    0.35635  ...     EURGBP    0.09054
# 9      AUDUSD    0.21822     AUDJPY    0.35635  ...     GBPJPY    0.08983
# 10     AUDJPY    0.21822     GBPAUD    0.35635  ...     NZDJPY    0.08292
# 11     AUDCHF    0.21822     NZDCAD    0.25000  ...     EURCAD    0.07114
# 12     EURAUD    0.21822     GBPUSD    0.25000  ...     NZDUSD    0.06580
# 13     EURJPY    0.21822     GBPJPY    0.25000  ...     AUDCHF    0.05519
# 14     GBPCHF    0.19643     EURNZD    0.25000  ...     NZDCHF    0.05313
# 15     GBPAUD    0.09449     EURJPY    0.16667  ...     USDCAD    0.04516
# 16     USDCHF    0.07143     AUDCAD    0.16667  ...     EURCHF    0.04516
# 17     GBPCAD    0.07143     NZDJPY    0.16667  ...     CADCHF    0.04423
# 18     GBPUSD    0.07143     CADJPY    0.16667  ...     EURAUD    0.03548
# 19     EURGBP    0.07143     USDCHF    0.16667  ...     CHFJPY    0.02988
# 20     NZDCHF    0.05455     EURUSD    0.16667  ...     NZDCAD    0.01959
# 21     EURNZD    0.05455     NZDCHF    0.16667  ...     EURJPY    0.01645
# 22     CADJPY    0.05455     CADCHF    0.16667  ...     EURNZD    0.00970
# 23     CADCHF    0.05455     USDCAD    0.16667  ...     AUDUSD    0.00970
# 24     NZDJPY    0.05455     EURCHF    0.10206  ...     CADJPY    0.00672
# 25     AUDCAD    0.05455     GBPCAD    0.00000  ...     USDJPY    0.00672
# 26     NZDUSD    0.05455     GBPCHF    0.00000  ...     GBPAUD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      NZDUSD    0.40825     NZDUSD    0.60053     NZDUSD    0.72222
# 1      GBPCHF    0.27217     GBPUSD    0.45303     USDCAD    0.49099
# 2      USDCAD    0.27217     USDCAD    0.45303     GBPUSD    0.49099
# 3      GBPUSD    0.27217     GBPJPY    0.38982     GBPJPY    0.44444
# 4      EURNZD    0.25000     EURNZD    0.38516     NZDJPY    0.44444
# 5      AUDCAD    0.24716     EURJPY    0.38516     CADJPY    0.44444
# 6      GBPJPY    0.24716     NZDJPY    0.34066     AUDUSD    0.44444
# 7      AUDCHF    0.21822     AUDUSD    0.31449     AUDCHF    0.44444
# 8      AUDUSD    0.21822     AUDCHF    0.31449     EURNZD    0.38889
# 9      EURUSD    0.21822     CADJPY    0.25678     EURJPY    0.38889
# 10     NZDCAD    0.19094     NZDCAD    0.25678     EURGBP    0.32733
# 11     USDCHF    0.19094     CHFJPY    0.25678     GBPCHF    0.32733
# 12     CHFJPY    0.16667     AUDCAD    0.25678     CHFJPY    0.32733
# 13     GBPAUD    0.13608     EURCHF    0.25163     GBPAUD    0.28868
# 14     EURJPY    0.13608     GBPCHF    0.24232     AUDNZD    0.28868
# 15     EURCAD    0.13608     EURUSD    0.24232     EURCHF    0.28868
# 16     NZDCHF    0.10985     EURGBP    0.24232     EURUSD    0.21822
# 17     CADJPY    0.10985     AUDNZD    0.20588     NZDCHF    0.16667
# 18     NZDJPY    0.08472     GBPAUD    0.17911     CADCHF    0.16667
# 19     GBPCAD    0.08472     AUDJPY    0.17911     EURAUD    0.16667
# 20     EURAUD    0.08183     NZDCHF    0.12088     AUDJPY    0.16667
# 21     EURCHF    0.05648     EURAUD    0.10483     AUDCAD    0.16667
# 22     USDJPY    0.05648     USDCHF    0.10483     NZDCAD    0.16667
# 23     EURGBP    0.05455     CADCHF    0.04280     GBPCAD    0.05455
# 24     AUDJPY    0.05455     EURCAD    0.03161     EURCAD    0.05455
# 25     CADCHF    0.02778     GBPCAD    0.03161     USDCHF    0.05455
# 26     AUDNZD    0.02778     USDJPY    0.02288     USDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDUSD    0.81650
# 1      AUDUSD    0.66667
# 2      GBPJPY    0.66667
# 3      NZDJPY    0.66667
# 4      AUDCHF    0.66667
# 5      CADJPY    0.66667
# 6      EURJPY    0.58333
# 7      GBPUSD    0.58333
# 8      EURNZD    0.58333
# 9      USDCAD    0.58333
# 10     GBPAUD    0.53452
# 11     EURAUD    0.53452
# 12     AUDJPY    0.53452
# 13     EURGBP    0.40825
# 14     GBPCHF    0.40825
# 15     CHFJPY    0.40825
# 16     AUDCAD    0.25000
# 17     NZDCAD    0.25000
# 18     USDCHF    0.25000
# 19     EURCAD    0.25000
# 20     NZDCHF    0.25000
# 21     CADCHF    0.25000
# 22     EURUSD    0.16667
# 23     EURCHF    0.10206
# 24     USDJPY    0.08909
# 25     GBPCAD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
