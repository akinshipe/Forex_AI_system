# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 11:58:46.483070

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.31807     USDCHF    0.33929     CADJPY    0.49237
# 1      CHFJPY    0.24982     NZDCAD    0.33036     USDJPY    0.49237
# 2      NZDCAD    0.23775     EURCAD    0.33036     USDCAD    0.28721
# 3      USDCHF    0.20192     USDJPY    0.32733     AUDJPY    0.25678
# 4      EURUSD    0.19872     CADJPY    0.32733     USDCHF    0.25000
# 5      USDJPY    0.19872     CADCHF    0.26726     AUDNZD    0.25000
# 6      AUDCAD    0.19872     GBPUSD    0.21822     EURAUD    0.20412
# 7      AUDUSD    0.19678     EURUSD    0.20536     AUDCHF    0.20412
# 8      NZDUSD    0.19678     EURJPY    0.19643     EURJPY    0.20412
# 9      GBPAUD    0.16013     USDCAD    0.19643     EURCAD    0.20412
# 10     GBPUSD    0.15743     AUDCHF    0.19643     EURCHF    0.17118
# 11     EURGBP    0.12581     EURAUD    0.19643     AUDUSD    0.17118
# 12     GBPCAD    0.12179     AUDJPY    0.18898     GBPAUD    0.16667
# 13     EURCAD    0.12179     NZDUSD    0.13363     GBPCAD    0.16667
# 14     EURNZD    0.12179     AUDCAD    0.13363     GBPCHF    0.16667
# 15     NZDJPY    0.12179     EURNZD    0.12585     CADCHF    0.12309
# 16     AUDCHF    0.11859     EURGBP    0.12016     GBPUSD    0.12309
# 17     GBPJPY    0.11859     GBPAUD    0.12016     NZDCAD    0.08206
# 18     EURCHF    0.11613     CHFJPY    0.08183     AUDCAD    0.08206
# 19     AUDJPY    0.08353     GBPJPY    0.05455     EURGBP    0.08206
# 20     NZDCHF    0.07711     AUDUSD    0.05455     GBPJPY    0.08206
# 21     GBPCHF    0.07711     NZDJPY    0.04725     EURNZD    0.04280
# 22     AUDNZD    0.04903     GBPCHF    0.04725     NZDJPY    0.04280
# 23     CADCHF    0.04167     GBPCAD    0.01849     CHFJPY    0.04167
# 24     EURAUD    0.04167     AUDNZD    0.01849     EURUSD    0.00000
# 25     CADJPY    0.03846     EURCHF    0.00899     NZDCHF    0.00000
# 26     USDCAD    0.00000     NZDCHF    0.00000     NZDUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.57735     AUDNZD    0.65465  ...     GBPCAD    0.33092
# 1      GBPCAD    0.40000     GBPAUD    0.50000  ...     GBPJPY    0.33092
# 2      NZDUSD    0.37796     GBPCHF    0.40825  ...     EURJPY    0.29758
# 3      GBPCHF    0.37796     NZDCAD    0.40825  ...     GBPUSD    0.29758
# 4      GBPJPY    0.28868     EURJPY    0.40825  ...     GBPCHF    0.27156
# 5      NZDCAD    0.28868     GBPCAD    0.40825  ...     EURGBP    0.26449
# 6      USDJPY    0.28868     USDCHF    0.40825  ...     AUDUSD    0.26449
# 7      USDCAD    0.28868     AUDCAD    0.21822  ...     AUDCHF    0.24982
# 8      AUDUSD    0.28868     CADCHF    0.21822  ...     EURUSD    0.24982
# 9      EURJPY    0.28868     NZDCHF    0.21822  ...     NZDCAD    0.21627
# 10     CADJPY    0.28868     EURAUD    0.21822  ...     AUDJPY    0.19025
# 11     AUDCHF    0.28868     USDJPY    0.20000  ...     EURCHF    0.18286
# 12     NZDCHF    0.28868     EURCAD    0.20000  ...     CHFJPY    0.17898
# 13     EURNZD    0.28868     CADJPY    0.20000  ...     AUDCAD    0.16871
# 14     NZDJPY    0.21320     EURNZD    0.20000  ...     EURCAD    0.15573
# 15     AUDJPY    0.21320     EURGBP    0.20000  ...     NZDCHF    0.13497
# 16     GBPAUD    0.21320     GBPJPY    0.20000  ...     USDCAD    0.12157
# 17     USDCHF    0.20000     GBPUSD    0.20000  ...     GBPAUD    0.12157
# 18     EURCHF    0.20000     CHFJPY    0.20000  ...     AUDNZD    0.11580
# 19     EURUSD    0.18898     USDCAD    0.00000  ...     NZDUSD    0.10123
# 20     EURGBP    0.18898     EURCHF    0.00000  ...     EURAUD    0.08760
# 21     CHFJPY    0.10000     AUDUSD    0.00000  ...     CADJPY    0.07462
# 22     EURCAD    0.09449     AUDCHF    0.00000  ...     CADCHF    0.07462
# 23     EURAUD    0.09449     AUDJPY    0.00000  ...     NZDJPY    0.07462
# 24     AUDCAD    0.09449     NZDJPY    0.00000  ...     EURNZD    0.00649
# 25     GBPUSD    0.00000     EURUSD    0.00000  ...     USDJPY    0.00649
# 26     CADCHF    0.00000     NZDUSD    0.00000  ...     USDCHF    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.64950     GBPCAD    0.49237     GBPCAD    0.57735
# 1      GBPUSD    0.44444     EURCAD    0.30151     EURCAD    0.49099
# 2      GBPCHF    0.43301     EURAUD    0.30151     GBPCHF    0.49099
# 3      AUDUSD    0.38889     AUDCHF    0.30151     AUDNZD    0.38889
# 4      EURCAD    0.35460     NZDCHF    0.30151     AUDCHF    0.38889
# 5      EURUSD    0.32733     GBPCHF    0.28721     NZDCAD    0.38889
# 6      AUDCHF    0.32733     AUDUSD    0.24232     USDCAD    0.38889
# 7      GBPJPY    0.30556     EURCHF    0.24232     NZDCHF    0.38889
# 8      EURCHF    0.30208     NZDCAD    0.21212     EURGBP    0.32733
# 9      AUDCAD    0.27217     AUDCAD    0.21212     CHFJPY    0.28868
# 10     CADCHF    0.27217     USDCAD    0.21212     EURCHF    0.28868
# 11     EURGBP    0.22591     EURGBP    0.19192     USDCHF    0.28868
# 12     GBPAUD    0.22591     CADCHF    0.19192     EURAUD    0.21822
# 13     EURJPY    0.21822     GBPUSD    0.19192     AUDCAD    0.21822
# 14     USDCAD    0.21822     GBPJPY    0.19192     AUDJPY    0.18464
# 15     NZDCAD    0.21822     EURNZD    0.17911     NZDJPY    0.18464
# 16     EURAUD    0.19094     USDCHF    0.12309     GBPUSD    0.16667
# 17     NZDCHF    0.13608     CHFJPY    0.12309     GBPJPY    0.16667
# 18     USDCHF    0.08183     AUDNZD    0.12309     CADCHF    0.16667
# 19     AUDNZD    0.05648     EURJPY    0.10050     EURNZD    0.16667
# 20     CHFJPY    0.02778     NZDUSD    0.10050     GBPAUD    0.12309
# 21     CADJPY    0.02778     EURUSD    0.10050     AUDUSD    0.11111
# 22     USDJPY    0.02778     GBPAUD    0.08206     EURJPY    0.11111
# 23     EURNZD    0.02746     AUDJPY    0.03161     CADJPY    0.11111
# 24     AUDJPY    0.00000     NZDJPY    0.03161     USDJPY    0.11111
# 25     NZDJPY    0.00000     CADJPY    0.01010     NZDUSD    0.05455
# 26     NZDUSD    0.00000     USDJPY    0.01010     EURUSD    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCHF    0.66667
# 1      GBPCHF    0.66667
# 2      GBPCAD    0.58333
# 3      USDCAD    0.58333
# 4      NZDCHF    0.53452
# 5      AUDNZD    0.53452
# 6      EURGBP    0.40825
# 7      EURCHF    0.40825
# 8      CHFJPY    0.40825
# 9      AUDCHF    0.40825
# 10     EURNZD    0.40825
# 11     EURCAD    0.40825
# 12     EURJPY    0.25000
# 13     NZDCAD    0.25000
# 14     NZDJPY    0.25000
# 15     AUDJPY    0.25000
# 16     EURUSD    0.16667
# 17     NZDUSD    0.10206
# 18     AUDUSD    0.10206
# 19     GBPAUD    0.10206
# 20     EURAUD    0.08909
# 21     AUDCAD    0.08909
# 22     CADCHF    0.08909
# 23     GBPJPY    0.00000
# 24     CADJPY    0.00000
# 25     GBPUSD    0.00000
# 26     USDJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
