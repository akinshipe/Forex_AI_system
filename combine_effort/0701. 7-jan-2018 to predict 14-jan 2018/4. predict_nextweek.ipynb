# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import ast
import time
from datetime import datetime

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['feature'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 03:11:47.979025
# 2021-12-10 03:11:47.987007
# 2021-12-10 03:12:47.997966
# 2021-12-10 03:13:48.006063
# 2021-12-10 03:14:48.014022
# 2021-12-10 03:15:48.037898
# 2021-12-10 03:16:48.045544
# 2021-12-10 03:17:48.049628
# 2021-12-10 03:18:48.071188
# 2021-12-10 03:19:48.081734
# 2021-12-10 03:20:48.092519
# 2021-12-10 03:21:48.108482
# 2021-12-10 03:22:48.124704
# 2021-12-10 03:23:48.133037
# 2021-12-10 03:24:48.150933
# 2021-12-10 03:25:48.160290
# 2021-12-10 03:26:48.184764
# 2021-12-10 03:27:48.212780
# 2021-12-10 03:28:48.217580
# 2021-12-10 03:29:48.230612
# 2021-12-10 03:30:48.249496
# 2021-12-10 03:31:48.275967
# 2021-12-10 03:32:48.281344
# 2021-12-10 03:33:48.308511
# 2021-12-10 03:34:48.321894
# 2021-12-10 03:35:48.329556
# 2021-12-10 03:36:48.347942
# 2021-12-10 03:37:48.356707
# 2021-12-10 03:38:48.362429
# 2021-12-10 03:39:48.369350
# 2021-12-10 03:40:48.387020
# 2021-12-10 03:41:48.410801
# 2021-12-10 03:42:48.429993
# 2021-12-10 03:43:48.443075
# 2021-12-10 03:44:48.466553
# 2021-12-10 03:45:48.476186
# 2021-12-10 03:46:48.481562
# 2021-12-10 03:47:48.496937
# 2021-12-10 03:48:48.524220
# 2021-12-10 03:49:48.548689
# 2021-12-10 03:50:48.566755
# 2021-12-10 03:51:48.582032
# 2021-12-10 03:52:48.591894
# 2021-12-10 03:53:48.601001
# 2021-12-10 03:54:48.620022
# 2021-12-10 03:55:48.643808
# 2021-12-10 03:56:48.648442
# 2021-12-10 03:57:48.664790
# 2021-12-10 03:58:48.682386
# 2021-12-10 03:59:48.697683
# 2021-12-10 04:00:48.709954
# 2021-12-10 04:01:48.725927
# 2021-12-10 04:02:48.751875
# 2021-12-10 04:03:48.756200
# 2021-12-10 04:04:48.784166
# 2021-12-10 04:05:48.794395
# 2021-12-10 04:06:48.819703
# 2021-12-10 04:07:48.825723
# 2021-12-10 04:08:48.848032
# 2021-12-10 04:09:48.851800
# 2021-12-10 04:10:48.874295
# 2021-12-10 04:11:48.882895
# 2021-12-10 04:12:48.897738
# 2021-12-10 05:46:50.387213
# 2021-12-10 05:47:50.390170
# 2021-12-10 05:48:50.413050
# 2021-12-10 05:49:50.421223
# 2021-12-10 05:50:50.425095
# 2021-12-10 05:51:50.435453
# 2021-12-10 05:52:50.450085
# 2021-12-10 05:53:50.462413
# 2021-12-10 05:54:50.467561
# 2021-12-10 05:55:50.472243
# 2021-12-10 05:56:50.496984
# 2021-12-10 05:57:50.514543
# 2021-12-10 05:58:50.541028
# 2021-12-10 05:59:50.546923
# 2021-12-10 06:00:50.566969
# 2021-12-10 06:01:50.593747
# 2021-12-10 06:02:50.598485
# 2021-12-10 06:03:50.619376
# 2021-12-10 06:04:50.629754
# 2021-12-10 06:05:50.655606
# 2021-12-10 06:06:50.679010

# %%
print('---------------- Script Has Started Execution-----------------------')

next_week_prediction_score = []
next_week_prediction =[]

next_week_trades = pd.read_csv('files/next_week_trades.csv'  ) 




for index, row in next_week_trades.iterrows():
    
   
    
    current_currency = row.names
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    weeks = row.week
    wanted_features = ast.literal_eval(row.needed_features)
    n_estimators = 20000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None




    raw_data = raw_data[:weeks]

    X_train = pd.DataFrame()

    for q in wanted_features:

        X_train[q] = raw_data[q]


    #print(X_train)  

    y_train = raw_data['nextweek_'+ current_currency]

    #print(y_train)



    prediction_model=RandomForestRegressor(
                                                n_estimators=n_estimators,
                                               n_jobs =-1,
                                               min_samples_leaf=min_samples_leaf,
                                                max_features=max_features,
                                               max_samples = max_samples
                                          )



    prediction_model.fit(X_train,y_train)


    current_week_values = pd.read_csv('current_week_values/current_week_values.csv'  ) 

    X_pred = pd.DataFrame()

    for h in wanted_features:

        X_pred[h] = current_week_values[h]

    #print(X_pred)

    y_pred = prediction_model.predict(X_pred)

    
    if y_pred[0] > 0:
        
        value = 'B'
        
    else:
        value = 'S'
        
    next_week_prediction_score.append(y_pred[0])
    next_week_prediction.append(value)
    
    print(row.names, row.week, y_pred)



print(next_week_prediction)
# Out:
# ---------------- Script Has Started Execution-----------------------
# USDCHF 10 [-1.]
# GBPUSD 20 [0.45906413]
# EURUSD 10 [-0.20496956]
# USDJPY 10 [-0.4371]
# USDCAD 10 [-0.8941]
# AUDUSD 10 [-0.49168218]
# CHFJPY 30 [0.62148071]
# CADCHF 10 [-0.71585675]
# AUDCHF 30 [-0.57014615]
# NZDCHF 20 [-1.]
# EURGBP 20 [-0.01060515]
# GBPJPY 10 [1.]
# EURJPY 10 [0.8929]
# EURCAD 30 [0.6863]
# EURAUD 20 [0.30357427]
# CADJPY 10 [0.66536782]
# AUDJPY 10 [0.5553619]
# NZDJPY 30 [0.50687407]
# NZDCAD 30 [-0.62535645]
# AUDNZD 20 [0.50353328]
# ['S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B']

# %%
next_week_trades['next_week_prediction_score'] = next_week_prediction_score
next_week_trades['next_week_prediction'] = next_week_prediction

next_week_trades.to_csv("files/next_week_trades.csv")

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['predict'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        1        1           0
