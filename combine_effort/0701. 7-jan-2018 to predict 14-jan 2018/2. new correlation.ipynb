# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:10:27.662633

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDCHF    0.36876     EURCHF    0.38052     EURCHF    0.50443
# 1      EURCHF    0.35588     CADCHF    0.33634     CADCHF    0.41414
# 2      CADCHF    0.32450     USDCHF    0.27866     GBPAUD    0.32824
# 3      USDJPY    0.27156     GBPAUD    0.27866     EURGBP    0.30151
# 4      NZDCHF    0.25223     NZDCHF    0.27866     CHFJPY    0.21212
# 5      GBPAUD    0.20773     EURGBP    0.26068     CADJPY    0.21212
# 6      EURUSD    0.20773     USDJPY    0.24716     GBPCAD    0.21212
# 7      EURCAD    0.19485     CHFJPY    0.20180     NZDCHF    0.21212
# 8      EURNZD    0.17138     GBPCAD    0.18552     AUDCHF    0.21212
# 9      AUDCHF    0.17138     AUDCHF    0.14382     USDCHF    0.21212
# 10     GBPCAD    0.16386     GBPUSD    0.14382     NZDJPY    0.19192
# 11     GBPCHF    0.15743     EURNZD    0.14382     EURUSD    0.19192
# 12     GBPUSD    0.12721     EURCAD    0.12585     EURAUD    0.17911
# 13     CHFJPY    0.12039     NZDJPY    0.10985     NZDCAD    0.15352
# 14     NZDUSD    0.09054     GBPJPY    0.10702     GBPJPY    0.15352
# 15     GBPJPY    0.09054     EURUSD    0.08597     AUDCAD    0.15352
# 16     AUDNZD    0.07711     CADJPY    0.08597     AUDNZD    0.12309
# 17     EURAUD    0.05366     GBPCHF    0.08597     GBPUSD    0.12309
# 18     NZDJPY    0.04013     AUDNZD    0.06727     AUDJPY    0.12309
# 19     CADJPY    0.03382     EURJPY    0.04757     EURNZD    0.10050
# 20     AUDJPY    0.03382     AUDCAD    0.04757     EURCAD    0.10050
# 21     NZDCAD    0.02150     NZDCAD    0.04757     AUDUSD    0.10050
# 22     EURJPY    0.01638     EURAUD    0.03257     NZDUSD    0.08206
# 23     AUDCAD    0.01638     USDCAD    0.02746     USDJPY    0.08206
# 24     AUDUSD    0.00970     AUDJPY    0.02746     EURJPY    0.03161
# 25     USDCAD    0.00321     NZDUSD    0.02746     GBPCHF    0.03161
# 26     EURGBP    0.00321     AUDUSD    0.00899     USDCAD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      CADCHF    0.66667     EURCHF    0.76376  ...     GBPCHF    0.40032
# 1      EURCHF    0.57735     EURAUD    0.61237  ...     USDCHF    0.28090
# 2      EURGBP    0.32733     NZDCHF    0.50000  ...     EURCHF    0.28090
# 3      EURUSD    0.32733     CADCHF    0.50000  ...     EURNZD    0.24175
# 4      EURAUD    0.28868     CHFJPY    0.40825  ...     EURGBP    0.24019
# 5      AUDUSD    0.21822     CADJPY    0.40825  ...     NZDCAD    0.20602
# 6      AUDJPY    0.21822     AUDJPY    0.40825  ...     USDJPY    0.20261
# 7      CHFJPY    0.21822     EURCAD    0.40825  ...     AUDCHF    0.16116
# 8      NZDCHF    0.21822     AUDCAD    0.32733  ...     AUDNZD    0.16013
# 9      EURCAD    0.21822     AUDCHF    0.32733  ...     CADCHF    0.16013
# 10     GBPCAD    0.21822     USDCAD    0.32733  ...     EURAUD    0.12157
# 11     NZDCAD    0.18464     GBPUSD    0.32733  ...     EURCAD    0.12039
# 12     NZDJPY    0.16667     GBPJPY    0.32733  ...     GBPUSD    0.12039
# 13     NZDUSD    0.16667     NZDCAD    0.32733  ...     EURUSD    0.12039
# 14     GBPAUD    0.11111     EURJPY    0.32733  ...     NZDJPY    0.12000
# 15     EURJPY    0.11111     USDCHF    0.32733  ...     AUDCAD    0.08165
# 16     USDCHF    0.11111     NZDJPY    0.25000  ...     AUDUSD    0.08058
# 17     GBPJPY    0.11111     NZDUSD    0.25000  ...     GBPJPY    0.08058
# 18     AUDCHF    0.11111     EURUSD    0.21822  ...     NZDCHF    0.08058
# 19     GBPCHF    0.11111     EURGBP    0.10206  ...     GBPCAD    0.08006
# 20     AUDNZD    0.11111     GBPAUD    0.10206  ...     CADJPY    0.04013
# 21     GBPUSD    0.05455     GBPCHF    0.10206  ...     AUDJPY    0.04013
# 22     EURNZD    0.05455     AUDUSD    0.10206  ...     GBPAUD    0.04013
# 23     CADJPY    0.05455     AUDNZD    0.10206  ...     CHFJPY    0.04000
# 24     USDCAD    0.05455     EURNZD    0.00000  ...     EURJPY    0.00000
# 25     USDJPY    0.05455     GBPCAD    0.00000  ...     NZDUSD    0.00000
# 26     AUDCAD    0.00000     USDJPY    0.00000  ...     USDCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.53035     USDCHF    0.66375     USDCHF    0.66667
# 1      USDCHF    0.33929     AUDUSD    0.52414     AUDUSD    0.60010
# 2      EURNZD    0.33929     GBPCHF    0.34066     GBPAUD    0.44444
# 3      EURGBP    0.33929     EURNZD    0.31449     NZDUSD    0.38889
# 4      EURCHF    0.33072     GBPAUD    0.25678     USDJPY    0.32733
# 5      CADCHF    0.26726     USDJPY    0.25678     EURAUD    0.28868
# 6      GBPJPY    0.25882     EURUSD    0.24232     EURCHF    0.28868
# 7      AUDCHF    0.20536     USDCAD    0.24232     USDCAD    0.21822
# 8      AUDUSD    0.20536     CADCHF    0.24232     EURUSD    0.21822
# 9      GBPUSD    0.19643     EURCHF    0.20588     AUDJPY    0.21822
# 10     GBPAUD    0.19643     GBPCAD    0.17911     GBPUSD    0.21822
# 11     EURCAD    0.19643     NZDUSD    0.17118     EURNZD    0.21822
# 12     USDJPY    0.19094     AUDJPY    0.17118     GBPCHF    0.16667
# 13     NZDCAD    0.18898     GBPUSD    0.17118     AUDCHF    0.16667
# 14     GBPCAD    0.14382     EURAUD    0.12088     NZDCAD    0.12309
# 15     EURUSD    0.14382     EURCAD    0.10483     EURJPY    0.11111
# 16     CADJPY    0.12585     EURGBP    0.10483     NZDJPY    0.11111
# 17     EURJPY    0.09449     EURJPY    0.09890     AUDNZD    0.11111
# 18     NZDJPY    0.08183     AUDNZD    0.04280     GBPJPY    0.11111
# 19     USDCAD    0.08183     NZDCHF    0.03161     CADCHF    0.11111
# 20     NZDCHF    0.07143     AUDCHF    0.03161     EURCAD    0.05455
# 21     AUDJPY    0.05455     CADJPY    0.03161     GBPCAD    0.05455
# 22     NZDUSD    0.05455     CHFJPY    0.03161     CADJPY    0.05455
# 23     AUDCAD    0.04725     NZDJPY    0.03161     NZDCHF    0.05455
# 24     EURAUD    0.01849     GBPJPY    0.02288     CHFJPY    0.05455
# 25     CHFJPY    0.00000     AUDCAD    0.02288     EURGBP    0.05455
# 26     AUDNZD    0.00000     NZDCAD    0.02288     AUDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      AUDUSD    0.66667
# 1      GBPAUD    0.58333
# 2      USDCHF    0.53452
# 3      GBPCAD    0.40825
# 4      USDJPY    0.40825
# 5      NZDUSD    0.40825
# 6      EURNZD    0.40825
# 7      EURCHF    0.35635
# 8      AUDCHF    0.35635
# 9      AUDJPY    0.25000
# 10     CADJPY    0.25000
# 11     EURCAD    0.25000
# 12     EURGBP    0.25000
# 13     CHFJPY    0.16667
# 14     EURAUD    0.16667
# 15     GBPCHF    0.16667
# 16     AUDNZD    0.16667
# 17     NZDJPY    0.10206
# 18     GBPUSD    0.08909
# 19     GBPJPY    0.08909
# 20     EURJPY    0.08909
# 21     USDCAD    0.08909
# 22     EURUSD    0.08909
# 23     AUDCAD    0.08909
# 24     NZDCAD    0.08909
# 25     NZDCHF    0.00000
# 26     CADCHF    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
