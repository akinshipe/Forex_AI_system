# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-07 11:48:59.430456

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURUSD    0.33092     NZDCAD    0.39747     NZDCAD    0.73380
# 1      EURJPY    0.29041     GBPCHF    0.36711     EURUSD    0.66375
# 2      GBPJPY    0.28158     AUDCAD    0.34586     NZDUSD    0.66375
# 3      CADJPY    0.25212     AUDCHF    0.29579     AUDCAD    0.60053
# 4      NZDUSD    0.20599     GBPJPY    0.28230     GBPUSD    0.52414
# 5      USDCHF    0.18286     EURUSD    0.24661     GBPCHF    0.38982
# 6      AUDCAD    0.17898     EURNZD    0.24661     EURCAD    0.38982
# 7      GBPUSD    0.16864     CADJPY    0.22591     NZDCHF    0.38982
# 8      NZDCAD    0.16864     NZDCHF    0.22591     USDCHF    0.38516
# 9      GBPCHF    0.16864     NZDUSD    0.20751     EURNZD    0.38516
# 10     CHFJPY    0.16864     GBPUSD    0.20751     AUDCHF    0.38516
# 11     EURCAD    0.12157     EURAUD    0.19767     USDJPY    0.31868
# 12     AUDNZD    0.12157     EURGBP    0.17216     AUDUSD    0.31868
# 13     EURCHF    0.10895     CADCHF    0.13876     GBPJPY    0.25678
# 14     AUDUSD    0.10895     EURCHF    0.12016     GBPCAD    0.20588
# 15     GBPAUD    0.10123     GBPAUD    0.10702     EURGBP    0.17911
# 16     AUDJPY    0.09688     AUDNZD    0.10702     GBPAUD    0.17118
# 17     EURAUD    0.08760     CHFJPY    0.10702     EURCHF    0.17118
# 18     EURNZD    0.08760     EURCAD    0.06917     EURJPY    0.10483
# 19     NZDCHF    0.07357     AUDUSD    0.05648     USDCAD    0.10483
# 20     USDCAD    0.06204     GBPCAD    0.04891     CADCHF    0.09890
# 21     NZDJPY    0.06190     AUDJPY    0.01849     EURAUD    0.09890
# 22     EURGBP    0.05366     USDCAD    0.01849     CHFJPY    0.09890
# 23     CADCHF    0.03715     EURJPY    0.00478     CADJPY    0.04280
# 24     AUDCHF    0.02764     NZDJPY    0.00478     NZDJPY    0.04280
# 25     USDJPY    0.01959     USDJPY    0.00478     AUDJPY    0.03161
# 26     GBPCAD    0.01198     USDCHF    0.00478     AUDNZD    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDCAD    0.75593     NZDCAD    0.76376  ...     AUDNZD    0.20000
# 1      AUDCAD    0.70000     AUDCAD    0.76376  ...     USDCHF    0.16116
# 2      NZDUSD    0.66144     NZDUSD    0.61237  ...     EURUSD    0.16013
# 3      GBPUSD    0.57735     EURGBP    0.50000  ...     NZDJPY    0.13093
# 4      EURUSD    0.57735     EURUSD    0.50000  ...     NZDCHF    0.12666
# 5      USDCHF    0.50000     GBPCHF    0.50000  ...     GBPCAD    0.12666
# 6      EURNZD    0.50000     CHFJPY    0.50000  ...     CADJPY    0.12361
# 7      GBPJPY    0.37796     GBPUSD    0.50000  ...     GBPUSD    0.12361
# 8      EURGBP    0.37796     GBPAUD    0.40825  ...     AUDCAD    0.12157
# 9      GBPCHF    0.37796     USDJPY    0.40825  ...     AUDJPY    0.12157
# 10     EURCAD    0.28868     AUDUSD    0.40825  ...     EURGBP    0.12039
# 11     AUDCHF    0.28868     EURCHF    0.40825  ...     EURCAD    0.12000
# 12     NZDCHF    0.28868     AUDCHF    0.40825  ...     EURJPY    0.08333
# 13     EURCHF    0.28868     EURNZD    0.40825  ...     USDJPY    0.08058
# 14     GBPAUD    0.28868     EURAUD    0.32733  ...     GBPAUD    0.08058
# 15     AUDUSD    0.28868     USDCHF    0.32733  ...     EURAUD    0.08006
# 16     USDCAD    0.28868     GBPCAD    0.21822  ...     EURNZD    0.08006
# 17     EURJPY    0.20000     EURCAD    0.21822  ...     CHFJPY    0.04120
# 18     USDJPY    0.20000     NZDCHF    0.21822  ...     GBPCHF    0.04120
# 19     EURAUD    0.20000     AUDNZD    0.16667  ...     NZDCAD    0.04120
# 20     NZDJPY    0.18898     EURJPY    0.10206  ...     AUDCHF    0.04013
# 21     GBPCAD    0.10000     GBPJPY    0.10206  ...     EURCHF    0.04013
# 22     CHFJPY    0.09449     AUDJPY    0.10206  ...     AUDUSD    0.04013
# 23     CADJPY    0.09449     NZDJPY    0.10206  ...     CADCHF    0.00000
# 24     CADCHF    0.09449     CADJPY    0.00000  ...     NZDUSD    0.00000
# 25     AUDJPY    0.00000     CADCHF    0.00000  ...     USDCAD    0.00000
# 26     AUDNZD    0.00000     USDCAD    0.00000  ...     GBPJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      AUDCAD    0.33634     EURGBP    0.37284     NZDUSD    0.46771
# 1      USDCHF    0.24661     NZDUSD    0.37284     GBPUSD    0.40825
# 2      GBPCAD    0.23783     EURUSD    0.37284     EURUSD    0.40825
# 3      EURUSD    0.22172     USDCHF    0.31180     USDCAD    0.40825
# 4      NZDUSD    0.20180     EURCAD    0.28511     EURCHF    0.40825
# 5      GBPUSD    0.20180     AUDCAD    0.28511     USDCHF    0.35355
# 6      EURCAD    0.20180     USDJPY    0.25163     EURNZD    0.35355
# 7      AUDUSD    0.16477     AUDUSD    0.25163     EURJPY    0.35355
# 8      AUDCHF    0.14382     USDCAD    0.21822     EURCAD    0.27217
# 9      USDCAD    0.12585     NZDCAD    0.21822     NZDCAD    0.20045
# 10     NZDCAD    0.12585     GBPUSD    0.21822     NZDJPY    0.20045
# 11     GBPCHF    0.10985     GBPJPY    0.08909     EURGBP    0.20045
# 12     EURJPY    0.10702     NZDJPY    0.08909     CADCHF    0.20045
# 13     USDJPY    0.10702     GBPAUD    0.08909     CHFJPY    0.20045
# 14     NZDJPY    0.10702     EURNZD    0.08909     AUDNZD    0.16667
# 15     EURNZD    0.08597     CADJPY    0.08909     GBPJPY    0.13363
# 16     EURGBP    0.08597     AUDCHF    0.08909     GBPCHF    0.13363
# 17     GBPAUD    0.08597     EURCHF    0.08909     CADJPY    0.13363
# 18     CHFJPY    0.04977     GBPCHF    0.06580     NZDCHF    0.06804
# 19     AUDNZD    0.04977     AUDJPY    0.06580     AUDCHF    0.06804
# 20     GBPJPY    0.03257     NZDCHF    0.06580     GBPAUD    0.06804
# 21     CADCHF    0.03257     GBPCAD    0.04762     AUDJPY    0.06804
# 22     EURAUD    0.02746     AUDNZD    0.04762     AUDUSD    0.06804
# 23     NZDCHF    0.02746     EURAUD    0.02288     GBPCAD    0.00000
# 24     CADJPY    0.02746     CADCHF    0.02288     EURAUD    0.00000
# 25     AUDJPY    0.00899     CHFJPY    0.02288     AUDCAD    0.00000
# 26     EURCHF    0.00899     EURJPY    0.00000     USDJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDJPY    0.40825
# 1      NZDUSD    0.40825
# 2      EURGBP    0.33333
# 3      GBPCHF    0.33333
# 4      GBPUSD    0.33333
# 5      CADJPY    0.33333
# 6      CHFJPY    0.33333
# 7      CADCHF    0.33333
# 8      USDCAD    0.33333
# 9      EURUSD    0.33333
# 10     EURCHF    0.27217
# 11     AUDUSD    0.27217
# 12     AUDCHF    0.27217
# 13     USDJPY    0.27217
# 14     GBPJPY    0.27217
# 15     GBPAUD    0.27217
# 16     EURJPY    0.27217
# 17     AUDJPY    0.27217
# 18     EURNZD    0.27217
# 19     NZDCAD    0.21822
# 20     AUDCAD    0.21822
# 21     USDCHF    0.21822
# 22     EURAUD    0.21822
# 23     EURCAD    0.21822
# 24     GBPCAD    0.21822
# 25     NZDCHF    0.21822
# 26     AUDNZD    0.11111
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
