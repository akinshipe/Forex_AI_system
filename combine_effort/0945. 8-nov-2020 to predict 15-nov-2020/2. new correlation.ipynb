# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-14 18:28:39.197359

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPUSD    0.27891     GBPUSD    0.38620     EURUSD    0.42366
# 1      USDJPY    0.23753     AUDUSD    0.34717     GBPUSD    0.38516
# 2      AUDNZD    0.22653     NZDUSD    0.29579     CHFJPY    0.31868
# 3      CHFJPY    0.18846     EURUSD    0.29187     EURGBP    0.31449
# 4      EURJPY    0.18846     NZDCAD    0.29187     GBPAUD    0.25678
# 5      USDCHF    0.18846     USDJPY    0.24661     USDCHF    0.25163
# 6      GBPCAD    0.18684     NZDJPY    0.24661     AUDUSD    0.25163
# 7      AUDUSD    0.16530     AUDCAD    0.24456     NZDUSD    0.24232
# 8      AUDCAD    0.16530     CHFJPY    0.19767     EURCAD    0.24232
# 9      EURUSD    0.16530     AUDNZD    0.15714     NZDCAD    0.24232
# 10     NZDCAD    0.14385     EURNZD    0.15714     NZDJPY    0.24232
# 11     NZDJPY    0.13457     GBPJPY    0.15714     CADCHF    0.17911
# 12     NZDUSD    0.12361     USDCHF    0.14833     AUDCHF    0.17911
# 13     EURNZD    0.12361     EURCAD    0.10702     EURNZD    0.17911
# 14     GBPAUD    0.11775     EURAUD    0.10702     GBPCAD    0.17911
# 15     EURAUD    0.09237     AUDJPY    0.10702     GBPCHF    0.17911
# 16     EURGBP    0.09237     USDCAD    0.10702     AUDJPY    0.17118
# 17     GBPCHF    0.07258     EURGBP    0.10702     USDJPY    0.17118
# 18     AUDCHF    0.07258     AUDCHF    0.08472     GBPJPY    0.17118
# 19     CADCHF    0.07258     GBPCAD    0.06917     USDCAD    0.17118
# 20     GBPJPY    0.06118     GBPAUD    0.06917     EURAUD    0.10483
# 21     AUDJPY    0.05046     CADCHF    0.06917     AUDNZD    0.10483
# 22     EURCAD    0.04120     CADJPY    0.06917     AUDCAD    0.09890
# 23     EURCHF    0.04120     EURCHF    0.05648     EURCHF    0.09890
# 24     USDCAD    0.02988     NZDCHF    0.01849     CADJPY    0.03161
# 25     NZDCHF    0.00990     GBPCHF    0.01849     NZDCHF    0.03161
# 26     CADJPY    0.00990     EURJPY    0.00478     EURJPY    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66144     EURUSD    0.81650  ...     GBPCAD    0.35588
# 1      USDCHF    0.49099     USDCHF    0.60000  ...     EURGBP    0.32450
# 2      CHFJPY    0.49099     CHFJPY    0.60000  ...     GBPCHF    0.31807
# 3      AUDUSD    0.49099     AUDCAD    0.60000  ...     CHFJPY    0.22653
# 4      GBPUSD    0.49099     EURCAD    0.60000  ...     USDJPY    0.16386
# 5      NZDCAD    0.46429     GBPUSD    0.60000  ...     AUDCHF    0.15743
# 6      NZDJPY    0.46429     EURGBP    0.60000  ...     CADCHF    0.15743
# 7      EURCAD    0.46429     NZDUSD    0.60000  ...     GBPAUD    0.14744
# 8      EURGBP    0.46429     AUDUSD    0.60000  ...     EURCAD    0.12039
# 9      NZDUSD    0.46429     GBPCHF    0.40825  ...     EURCHF    0.12039
# 10     AUDCAD    0.33929     GBPAUD    0.40825  ...     NZDCAD    0.11433
# 11     AUDJPY    0.33929     NZDCAD    0.40825  ...     AUDCAD    0.10895
# 12     GBPJPY    0.33929     NZDJPY    0.40825  ...     NZDJPY    0.09829
# 13     GBPAUD    0.32733     AUDJPY    0.40825  ...     AUDJPY    0.09829
# 14     GBPCHF    0.32733     EURNZD    0.40825  ...     USDCAD    0.09054
# 15     EURJPY    0.21822     AUDNZD    0.40825  ...     EURJPY    0.06118
# 16     EURCHF    0.21822     USDJPY    0.21822  ...     EURUSD    0.05366
# 17     EURNZD    0.19643     GBPCAD    0.20000  ...     AUDNZD    0.04670
# 18     AUDCHF    0.19643     EURCHF    0.20000  ...     EURNZD    0.04013
# 19     AUDNZD    0.19643     USDCAD    0.20000  ...     NZDUSD    0.04013
# 20     USDCAD    0.09449     EURAUD    0.20000  ...     GBPJPY    0.03382
# 21     USDJPY    0.09449     GBPJPY    0.20000  ...     AUDUSD    0.02764
# 22     GBPCAD    0.07143     CADCHF    0.20000  ...     USDCHF    0.02150
# 23     CADCHF    0.07143     EURJPY    0.20000  ...     GBPUSD    0.00970
# 24     EURAUD    0.07143     CADJPY    0.00000  ...     EURAUD    0.00321
# 25     CADJPY    0.07143     NZDCHF    0.00000  ...     CADJPY    0.00321
# 26     NZDCHF    0.07143     AUDCHF    0.00000  ...     NZDCHF    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      CHFJPY    0.27217     EURGBP    0.30151     EURGBP    0.49099
# 1      NZDCHF    0.26726     EURAUD    0.30151     GBPUSD    0.44444
# 2      EURUSD    0.20751     GBPUSD    0.28721     GBPCHF    0.38889
# 3      NZDJPY    0.20180     EURCHF    0.24232     GBPCAD    0.32733
# 4      GBPUSD    0.20180     CADJPY    0.21212     EURUSD    0.28868
# 5      AUDJPY    0.20180     GBPCHF    0.21212     USDJPY    0.28868
# 6      EURAUD    0.20180     CADCHF    0.21212     NZDCAD    0.21822
# 7      EURGBP    0.20180     GBPCAD    0.21212     NZDJPY    0.21822
# 8      USDJPY    0.20180     NZDJPY    0.19192     NZDUSD    0.21822
# 9      CADCHF    0.20000     NZDUSD    0.19192     CADJPY    0.21822
# 10     GBPCAD    0.20000     EURNZD    0.19192     EURCAD    0.21822
# 11     GBPAUD    0.20000     NZDCHF    0.19192     AUDCHF    0.21822
# 12     GBPCHF    0.13363     NZDCAD    0.19192     USDCHF    0.16667
# 13     NZDUSD    0.13363     CHFJPY    0.17911     CHFJPY    0.16667
# 14     GBPJPY    0.13363     EURUSD    0.17408     AUDUSD    0.16667
# 15     EURNZD    0.13363     EURJPY    0.15352     GBPAUD    0.11111
# 16     AUDUSD    0.07274     GBPAUD    0.12309     EURJPY    0.11111
# 17     NZDCAD    0.06917     AUDNZD    0.10050     EURCHF    0.11111
# 18     USDCHF    0.06917     GBPJPY    0.08206     NZDCHF    0.05455
# 19     EURJPY    0.06917     AUDJPY    0.08206     GBPJPY    0.05455
# 20     EURCAD    0.06727     USDCAD    0.08206     CADCHF    0.05455
# 21     USDCAD    0.06727     USDJPY    0.08206     EURAUD    0.05455
# 22     CADJPY    0.06667     AUDUSD    0.06580     EURNZD    0.05455
# 23     AUDCHF    0.00000     USDCHF    0.06580     AUDJPY    0.05455
# 24     EURCHF    0.00000     AUDCAD    0.03161     AUDCAD    0.05455
# 25     AUDCAD    0.00000     EURCAD    0.01010     AUDNZD    0.05455
# 26     AUDNZD    0.00000     AUDCHF    0.01010     USDCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.81650
# 1      GBPCHF    0.66667
# 2      EURUSD    0.58333
# 3      CHFJPY    0.40825
# 4      AUDCAD    0.40825
# 5      EURCAD    0.40825
# 6      GBPCAD    0.40825
# 7      GBPUSD    0.40825
# 8      USDCHF    0.40825
# 9      NZDUSD    0.40825
# 10     AUDUSD    0.40825
# 11     USDJPY    0.35635
# 12     AUDNZD    0.25000
# 13     NZDCHF    0.25000
# 14     GBPAUD    0.25000
# 15     AUDJPY    0.25000
# 16     EURNZD    0.25000
# 17     CADJPY    0.16667
# 18     AUDCHF    0.16667
# 19     NZDCAD    0.16667
# 20     NZDJPY    0.16667
# 21     EURCHF    0.00000
# 22     EURAUD    0.00000
# 23     CADCHF    0.00000
# 24     EURJPY    0.00000
# 25     GBPJPY    0.00000
# 26     USDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
