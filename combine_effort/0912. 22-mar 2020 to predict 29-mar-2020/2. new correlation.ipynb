# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-11 12:01:37.569743

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.31366     NZDCAD    0.33036     AUDJPY    0.37500
# 1      NZDCAD    0.27536     USDCHF    0.26726     USDJPY    0.37500
# 2      CHFJPY    0.25223     EURJPY    0.26726     AUDUSD    0.31180
# 3      USDCHF    0.24418     EURCAD    0.26068     CADJPY    0.28721
# 4      EURUSD    0.23775     USDJPY    0.25882     GBPCAD    0.28721
# 5      USDJPY    0.23775     CHFJPY    0.21822     AUDCHF    0.25000
# 6      NZDUSD    0.23282     GBPUSD    0.20536     EURAUD    0.25000
# 7      GBPUSD    0.19485     USDCAD    0.19643     EURGBP    0.20412
# 8      AUDCAD    0.19485     AUDCAD    0.19643     EURJPY    0.20412
# 9      AUDUSD    0.19025     CADJPY    0.19094     GBPJPY    0.20412
# 10     NZDJPY    0.16386     EURUSD    0.13363     AUDNZD    0.20412
# 11     GBPAUD    0.15743     NZDUSD    0.13363     GBPCHF    0.20412
# 12     EURGBP    0.13497     CADCHF    0.13363     USDCAD    0.20412
# 13     GBPCAD    0.12721     AUDCHF    0.13363     NZDJPY    0.16667
# 14     EURCAD    0.12039     EURAUD    0.13363     GBPAUD    0.13363
# 15     NZDCHF    0.11433     EURGBP    0.12585     NZDUSD    0.12309
# 16     GBPJPY    0.11433     GBPAUD    0.12016     EURUSD    0.12309
# 17     EURCHF    0.10895     AUDJPY    0.12016     USDCHF    0.12309
# 18     EURNZD    0.08353     EURCHF    0.08183     EURCHF    0.08909
# 19     GBPCHF    0.07711     GBPJPY    0.06250     CADCHF    0.08206
# 20     AUDCHF    0.07114     EURNZD    0.06250     EURCAD    0.08206
# 21     CADCHF    0.04670     GBPCHF    0.05455     EURNZD    0.08206
# 22     EURAUD    0.04670     AUDUSD    0.05455     NZDCHF    0.04167
# 23     CADJPY    0.04013     NZDJPY    0.01849     CHFJPY    0.04167
# 24     AUDJPY    0.04013     GBPCAD    0.00899     AUDCAD    0.04167
# 25     AUDNZD    0.00970     AUDNZD    0.00899     NZDCAD    0.04167
# 26     USDCAD    0.00321     NZDCHF    0.00000     GBPUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.38889     EURJPY    0.81650  ...     GBPCAD    0.36876
# 1      EURJPY    0.38889     CHFJPY    0.60000  ...     GBPJPY    0.36876
# 2      GBPCAD    0.32733     GBPAUD    0.50000  ...     GBPUSD    0.36876
# 3      NZDCAD    0.28868     AUDNZD    0.40825  ...     EURUSD    0.32450
# 4      USDJPY    0.28868     NZDCAD    0.21822  ...     GBPCHF    0.31807
# 5      AUDUSD    0.28868     AUDCAD    0.21822  ...     EURGBP    0.29758
# 6      NZDUSD    0.28868     USDCAD    0.21822  ...     AUDUSD    0.29758
# 7      GBPCHF    0.28868     GBPCHF    0.21822  ...     NZDCAD    0.28824
# 8      AUDCHF    0.28868     CADCHF    0.21822  ...     AUDCHF    0.25223
# 9      USDCAD    0.21822     EURAUD    0.21822  ...     EURJPY    0.25223
# 10     EURNZD    0.21822     NZDCHF    0.21822  ...     EURCHF    0.21627
# 11     GBPJPY    0.21822     GBPCAD    0.20000  ...     NZDCHF    0.20773
# 12     EURCHF    0.18464     NZDJPY    0.20000  ...     AUDCAD    0.20773
# 13     NZDCHF    0.18464     AUDJPY    0.20000  ...     AUDJPY    0.20064
# 14     AUDJPY    0.16667     CADJPY    0.20000  ...     EURCAD    0.20064
# 15     CADCHF    0.16667     USDCHF    0.20000  ...     NZDUSD    0.17138
# 16     NZDJPY    0.16667     GBPJPY    0.00000  ...     NZDJPY    0.15743
# 17     CADJPY    0.16667     GBPUSD    0.00000  ...     CHFJPY    0.15198
# 18     GBPAUD    0.12309     EURCAD    0.00000  ...     EURAUD    0.12721
# 19     AUDCAD    0.11111     AUDCHF    0.00000  ...     CADCHF    0.11433
# 20     USDCHF    0.11111     EURNZD    0.00000  ...     AUDNZD    0.09054
# 21     EURAUD    0.11111     EURCHF    0.00000  ...     EURNZD    0.08353
# 22     EURCAD    0.11111     NZDUSD    0.00000  ...     USDJPY    0.08353
# 23     CHFJPY    0.11111     AUDUSD    0.00000  ...     GBPAUD    0.07711
# 24     EURUSD    0.11111     USDJPY    0.00000  ...     USDCAD    0.07711
# 25     EURGBP    0.11111     EURUSD    0.00000  ...     USDCHF    0.07711
# 26     GBPUSD    0.05455     EURGBP    0.00000  ...     CADJPY    0.04013
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.66518     GBPCAD    0.61616     GBPCAD    0.73214
# 1      AUDUSD    0.49099     EURCAD    0.39394     GBPCHF    0.66144
# 2      GBPUSD    0.46429     GBPCHF    0.30151     EURCHF    0.56408
# 3      GBPCHF    0.46371     GBPJPY    0.30151     NZDCHF    0.56408
# 4      EURCAD    0.41349     GBPUSD    0.30151     EURGBP    0.49099
# 5      EURUSD    0.40089     EURGBP    0.30151     EURCAD    0.49099
# 6      AUDCHF    0.40089     EURAUD    0.28721     NZDCAD    0.37796
# 7      EURCHF    0.35460     AUDCHF    0.28721     AUDCHF    0.37796
# 8      AUDCAD    0.33929     NZDCHF    0.28721     GBPUSD    0.33929
# 9      NZDCAD    0.33929     AUDCAD    0.28721     EURNZD    0.33929
# 10     GBPJPY    0.33036     NZDCAD    0.28721     GBPJPY    0.33929
# 11     EURAUD    0.26726     AUDUSD    0.28511     AUDCAD    0.21822
# 12     EURJPY    0.26726     EURCHF    0.28511     EURAUD    0.21822
# 13     NZDCHF    0.26726     CADCHF    0.21212     USDCHF    0.21822
# 14     CADCHF    0.26726     EURNZD    0.21212     CHFJPY    0.21822
# 15     EURGBP    0.26068     EURUSD    0.19192     EURUSD    0.21822
# 16     NZDUSD    0.13363     GBPAUD    0.15352     AUDNZD    0.21822
# 17     GBPAUD    0.12016     NZDJPY    0.12309     USDCAD    0.19643
# 18     AUDJPY    0.12016     AUDJPY    0.12309     NZDUSD    0.09449
# 19     NZDJPY    0.12016     AUDNZD    0.10050     AUDUSD    0.09449
# 20     USDCAD    0.07143     EURJPY    0.10050     USDJPY    0.09449
# 21     EURNZD    0.06250     USDCAD    0.10050     CADCHF    0.05455
# 22     CHFJPY    0.05455     CHFJPY    0.08206     EURJPY    0.05455
# 23     CADJPY    0.05455     USDJPY    0.08206     CADJPY    0.05455
# 24     USDJPY    0.01849     CADJPY    0.01010     AUDJPY    0.05455
# 25     AUDNZD    0.00899     NZDUSD    0.01010     NZDJPY    0.05455
# 26     USDCHF    0.00000     USDCHF    0.01010     GBPAUD    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDCHF    0.65465
# 1      GBPCHF    0.65465
# 2      GBPCAD    0.60000
# 3      CHFJPY    0.60000
# 4      EURCHF    0.50000
# 5      AUDCHF    0.50000
# 6      EURGBP    0.40825
# 7      EURCAD    0.40825
# 8      USDJPY    0.40825
# 9      EURJPY    0.40825
# 10     GBPUSD    0.40825
# 11     EURNZD    0.40825
# 12     CADCHF    0.21822
# 13     AUDCAD    0.21822
# 14     USDCAD    0.21822
# 15     NZDCAD    0.21822
# 16     EURAUD    0.21822
# 17     NZDJPY    0.20000
# 18     AUDJPY    0.20000
# 19     CADJPY    0.20000
# 20     USDCHF    0.20000
# 21     GBPAUD    0.00000
# 22     GBPJPY    0.00000
# 23     NZDUSD    0.00000
# 24     AUDUSD    0.00000
# 25     EURUSD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
