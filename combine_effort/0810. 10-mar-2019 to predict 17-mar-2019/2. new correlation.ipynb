# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 22:39:00.836054

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPJPY    0.23028     USDCHF    0.30208     AUDNZD    0.49237
# 1      EURUSD    0.16667     NZDUSD    0.20180     AUDCHF    0.45833
# 2      EURAUD    0.14804     AUDNZD    0.20180     EURAUD    0.45833
# 3      USDCHF    0.13457     GBPCAD    0.17216     EURNZD    0.40825
# 4      AUDCHF    0.13234     AUDCHF    0.16477     NZDCHF    0.40825
# 5      CADCHF    0.13234     AUDUSD    0.14382     USDCHF    0.38516
# 6      NZDCAD    0.13074     EURUSD    0.14382     GBPCAD    0.37500
# 7      AUDUSD    0.11440     NZDCAD    0.14382     NZDCAD    0.32824
# 8      NZDJPY    0.08165     AUDCAD    0.14382     EURUSD    0.32824
# 9      GBPAUD    0.08165     NZDCHF    0.14382     NZDUSD    0.28721
# 10     EURCAD    0.06580     EURGBP    0.12585     CHFJPY    0.25678
# 11     AUDNZD    0.06553     USDCAD    0.10985     GBPAUD    0.20412
# 12     GBPCHF    0.06553     EURCHF    0.10702     AUDUSD    0.20412
# 13     AUDCAD    0.04963     GBPUSD    0.08597     EURGBP    0.20412
# 14     NZDCHF    0.04903     GBPJPY    0.08597     GBPUSD    0.12309
# 15     AUDJPY    0.03309     EURAUD    0.08597     AUDCAD    0.12309
# 16     GBPUSD    0.03269     EURJPY    0.06727     EURCHF    0.12309
# 17     EURJPY    0.03269     EURCAD    0.06727     GBPCHF    0.08206
# 18     NZDUSD    0.03269     EURNZD    0.06727     EURCAD    0.08206
# 19     EURGBP    0.03269     CADJPY    0.06727     USDJPY    0.08206
# 20     CHFJPY    0.01701     NZDJPY    0.06727     CADCHF    0.08206
# 21     EURCHF    0.01645     GBPCHF    0.06727     NZDJPY    0.08206
# 22     USDCAD    0.01645     CADCHF    0.04977     USDCAD    0.04280
# 23     EURNZD    0.01638     USDJPY    0.04977     GBPJPY    0.04167
# 24     CADJPY    0.01638     CHFJPY    0.03257     AUDJPY    0.04167
# 25     GBPCAD    0.00000     AUDJPY    0.02746     EURJPY    0.00000
# 26     USDJPY    0.00000     GBPAUD    0.00899     CADJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.60010     EURUSD    0.81650  ...     USDCAD    0.25223
# 1      USDCHF    0.57735     EURAUD    0.66667  ...     EURNZD    0.19485
# 2      EURAUD    0.49099     GBPCAD    0.58333  ...     CADCHF    0.19025
# 3      GBPCAD    0.44444     USDCHF    0.53452  ...     EURGBP    0.16386
# 4      AUDNZD    0.44444     EURCAD    0.53452  ...     GBPCHF    0.12721
# 5      AUDCHF    0.38889     AUDCHF    0.53452  ...     GBPAUD    0.12039
# 6      NZDCHF    0.32733     CADCHF    0.40825  ...     CADJPY    0.11433
# 7      EURNZD    0.32733     NZDJPY    0.40825  ...     AUDCHF    0.10895
# 8      CHFJPY    0.28868     AUDJPY    0.35635  ...     AUDCAD    0.10895
# 9      EURGBP    0.21822     EURJPY    0.35635  ...     CHFJPY    0.10701
# 10     GBPCHF    0.21822     EURGBP    0.35635  ...     USDJPY    0.09829
# 11     NZDCAD    0.21822     AUDNZD    0.35635  ...     EURUSD    0.09829
# 12     EURCAD    0.21822     NZDCHF    0.25000  ...     EURCAD    0.09054
# 13     NZDUSD    0.16667     EURNZD    0.25000  ...     GBPUSD    0.08353
# 14     AUDJPY    0.16667     CHFJPY    0.16667  ...     NZDCAD    0.08353
# 15     GBPAUD    0.16667     GBPUSD    0.16667  ...     NZDUSD    0.07711
# 16     USDCAD    0.11111     GBPJPY    0.16667  ...     NZDCHF    0.07711
# 17     GBPJPY    0.11111     GBPAUD    0.16667  ...     EURJPY    0.07711
# 18     CADJPY    0.11111     USDCAD    0.16667  ...     USDCHF    0.06118
# 19     CADCHF    0.11111     USDJPY    0.16667  ...     GBPCAD    0.04013
# 20     NZDJPY    0.11111     EURCHF    0.08909  ...     NZDJPY    0.04013
# 21     EURCHF    0.11111     GBPCHF    0.08909  ...     AUDNZD    0.03382
# 22     EURJPY    0.05455     CADJPY    0.08909  ...     AUDJPY    0.02764
# 23     USDJPY    0.05455     NZDUSD    0.00000  ...     EURAUD    0.00970
# 24     GBPUSD    0.05455     AUDUSD    0.00000  ...     GBPJPY    0.00970
# 25     AUDCAD    0.05455     AUDCAD    0.00000  ...     EURCHF    0.00970
# 26     AUDUSD    0.05455     NZDCAD    0.00000  ...     AUDUSD    0.00321
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDCAD    0.40825     USDCAD    0.73380     USDCAD    0.66667
# 1      USDJPY    0.33634     EURUSD    0.70353     EURUSD    0.60010
# 2      USDCHF    0.27217     USDCHF    0.52414     USDCHF    0.57735
# 3      EURUSD    0.26726     USDJPY    0.50252     USDJPY    0.49099
# 4      EURNZD    0.20000     AUDUSD    0.40000     AUDUSD    0.49099
# 5      EURCAD    0.20000     GBPUSD    0.30151     NZDUSD    0.38889
# 6      AUDUSD    0.13363     NZDUSD    0.30151     GBPCHF    0.32733
# 7      GBPAUD    0.13363     GBPCHF    0.30151     GBPUSD    0.32733
# 8      NZDCHF    0.13363     EURCHF    0.30151     NZDCHF    0.21822
# 9      GBPCAD    0.06917     EURAUD    0.20412     AUDCAD    0.21822
# 10     CHFJPY    0.06917     CADJPY    0.20000     EURAUD    0.21822
# 11     EURCHF    0.06917     EURNZD    0.20000     EURNZD    0.21822
# 12     CADCHF    0.06727     GBPAUD    0.20000     CADCHF    0.16667
# 13     GBPUSD    0.06727     EURGBP    0.20000     EURCHF    0.16667
# 14     GBPJPY    0.06727     NZDCHF    0.20000     GBPCAD    0.16667
# 15     EURAUD    0.06727     CHFJPY    0.10483     GBPAUD    0.16667
# 16     CADJPY    0.06667     EURCAD    0.10050     CADJPY    0.16667
# 17     NZDJPY    0.06667     CADCHF    0.10050     NZDJPY    0.11111
# 18     AUDNZD    0.06667     NZDJPY    0.10050     AUDJPY    0.11111
# 19     EURJPY    0.06667     AUDCAD    0.10050     AUDNZD    0.11111
# 20     GBPCHF    0.06667     NZDCAD    0.10050     GBPJPY    0.11111
# 21     NZDUSD    0.06667     AUDNZD    0.10050     AUDCHF    0.11111
# 22     AUDCHF    0.00000     GBPJPY    0.00000     EURCAD    0.05455
# 23     AUDJPY    0.00000     GBPCAD    0.00000     EURJPY    0.05455
# 24     AUDCAD    0.00000     EURJPY    0.00000     NZDCAD    0.05455
# 25     NZDCAD    0.00000     AUDCHF    0.00000     EURGBP    0.05455
# 26     EURGBP    0.00000     AUDJPY    0.00000     CHFJPY    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      USDCAD    1.00000
# 1      AUDUSD    0.81650
# 2      NZDUSD    0.81650
# 3      CADJPY    0.80178
# 4      CADCHF    0.61237
# 5      NZDCHF    0.58333
# 6      EURNZD    0.58333
# 7      USDCHF    0.53452
# 8      EURUSD    0.40825
# 9      NZDJPY    0.40825
# 10     EURCAD    0.35635
# 11     EURJPY    0.35635
# 12     AUDCHF    0.35635
# 13     EURCHF    0.35635
# 14     GBPCHF    0.35635
# 15     AUDJPY    0.35635
# 16     GBPCAD    0.25000
# 17     GBPAUD    0.25000
# 18     USDJPY    0.25000
# 19     GBPUSD    0.16667
# 20     GBPJPY    0.16667
# 21     CHFJPY    0.16667
# 22     EURAUD    0.16667
# 23     EURGBP    0.08909
# 24     AUDNZD    0.08909
# 25     AUDCAD    0.00000
# 26     NZDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
