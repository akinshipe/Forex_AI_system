# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:03:29.373681

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      CHFJPY    0.36192     CHFJPY    0.53612     EURJPY    0.81125
# 1      NZDUSD    0.32904     EURJPY    0.53612     CHFJPY    0.60053
# 2      EURJPY    0.32904     EURUSD    0.46429     GBPJPY    0.46442
# 3      GBPUSD    0.32904     USDCHF    0.40089     EURNZD    0.45303
# 4      AUDUSD    0.31652     EURNZD    0.35460     EURAUD    0.45303
# 5      EURUSD    0.29870     GBPJPY    0.34247     USDCHF    0.41414
# 6      GBPJPY    0.29599     EURCAD    0.33929     EURUSD    0.41414
# 7      NZDJPY    0.29599     EURGBP    0.33929     CADJPY    0.38982
# 8      NZDCAD    0.26258     AUDUSD    0.33072     NZDJPY    0.30151
# 9      USDCHF    0.21753     NZDUSD    0.33072     EURCAD    0.30151
# 10     CADJPY    0.21753     EURAUD    0.29579     EURGBP    0.30151
# 11     USDJPY    0.19678     AUDCHF    0.29579     NZDUSD    0.30151
# 12     AUDJPY    0.19590     NZDJPY    0.26245     AUDUSD    0.28511
# 13     AUDCAD    0.17620     GBPUSD    0.26245     AUDJPY    0.28511
# 14     AUDNZD    0.13636     AUDJPY    0.25882     AUDCHF    0.24232
# 15     USDCAD    0.13636     CADJPY    0.25882     USDCAD    0.19192
# 16     EURCAD    0.12581     AUDNZD    0.19643     AUDNZD    0.19192
# 17     EURNZD    0.11613     NZDCAD    0.18898     EURCHF    0.17911
# 18     NZDCHF    0.11289     CADCHF    0.17496     GBPUSD    0.17408
# 19     EURCHF    0.11289     GBPAUD    0.14382     CADCHF    0.15352
# 20     GBPCHF    0.11289     USDJPY    0.13363     GBPAUD    0.12309
# 21     AUDCHF    0.09066     AUDCAD    0.12016     USDJPY    0.10050
# 22     EURGBP    0.08058     EURCHF    0.12016     GBPCAD    0.06580
# 23     GBPAUD    0.07114     GBPCHF    0.09449     GBPCHF    0.06580
# 24     GBPCAD    0.01959     USDCAD    0.05455     AUDCAD    0.06580
# 25     EURAUD    0.01645     GBPCAD    0.05455     NZDCHF    0.05025
# 26     CADCHF    0.01645     NZDCHF    0.02916     NZDCAD    0.05025
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.86603     EURJPY    1.00000  ...     AUDNZD    0.14368
# 1      EURAUD    0.57735     CHFJPY    0.80178  ...     CADJPY    0.14368
# 2      CHFJPY    0.57735     CADJPY    0.76376  ...     GBPUSD    0.13170
# 3      AUDCHF    0.49237     NZDJPY    0.50918  ...     EURGBP    0.12157
# 4      CADJPY    0.43082     USDCHF    0.42857  ...     EURAUD    0.11580
# 5      CADCHF    0.40825     EURAUD    0.42857  ...     EURUSD    0.10123
# 6      EURNZD    0.38889     AUDCHF    0.42857  ...     GBPCAD    0.09688
# 7      GBPJPY    0.32733     EURGBP    0.42857  ...     USDJPY    0.08760
# 8      USDCHF    0.21822     AUDNZD    0.42857  ...     GBPCHF    0.08515
# 9      EURCAD    0.21822     EURUSD    0.42857  ...     NZDCHF    0.08181
# 10     EURGBP    0.21822     USDJPY    0.42857  ...     CHFJPY    0.08181
# 11     EURUSD    0.21822     CADCHF    0.32733  ...     USDCAD    0.06204
# 12     AUDCAD    0.18464     GBPUSD    0.32733  ...     USDCHF    0.06204
# 13     GBPCHF    0.12309     GBPCHF    0.21822  ...     AUDUSD    0.06190
# 14     GBPCAD    0.12309     NZDCAD    0.21822  ...     AUDCHF    0.03715
# 15     AUDJPY    0.12309     USDCAD    0.21822  ...     EURJPY    0.03715
# 16     USDCAD    0.11111     EURCAD    0.21822  ...     NZDUSD    0.03715
# 17     USDJPY    0.11111     GBPAUD    0.21822  ...     CADCHF    0.03309
# 18     NZDUSD    0.08006     GBPCAD    0.21822  ...     GBPAUD    0.02764
# 19     NZDJPY    0.08006     NZDCHF    0.21822  ...     AUDCAD    0.02432
# 20     NZDCHF    0.06804     NZDUSD    0.21822  ...     NZDCAD    0.02432
# 21     GBPUSD    0.06804     EURNZD    0.08909  ...     GBPJPY    0.01198
# 22     AUDUSD    0.06804     AUDUSD    0.04762  ...     NZDJPY    0.01198
# 23     NZDCAD    0.06804     AUDJPY    0.04762  ...     EURCAD    0.00649
# 24     GBPAUD    0.05455     AUDCAD    0.04762  ...     EURNZD    0.00649
# 25     EURCHF    0.00000     EURCHF    0.04762  ...     EURCHF    0.00167
# 26     AUDNZD    0.00000     GBPJPY    0.00000  ...     AUDJPY    0.00167
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.32077     AUDNZD    0.28721     GBPCHF    0.36364
# 1      USDJPY    0.26726     CADJPY    0.25678     GBPCAD    0.36364
# 2      CADJPY    0.25882     GBPAUD    0.25000     AUDJPY    0.31818
# 3      EURUSD    0.20536     GBPUSD    0.23570     CADJPY    0.31818
# 4      AUDNZD    0.19643     USDJPY    0.20412     GBPUSD    0.30151
# 5      GBPAUD    0.14382     EURCHF    0.17118     EURGBP    0.26189
# 6      USDCHF    0.13363     AUDUSD    0.13363     EURCAD    0.26189
# 7      EURJPY    0.12016     CADCHF    0.13363     GBPAUD    0.26189
# 8      AUDCHF    0.12016     AUDJPY    0.13363     EURJPY    0.21320
# 9      AUDJPY    0.12016     NZDCAD    0.10206     AUDNZD    0.21320
# 10     NZDJPY    0.11664     NZDUSD    0.10206     CHFJPY    0.21320
# 11     CADCHF    0.11664     NZDJPY    0.10206     NZDUSD    0.20696
# 12     NZDCHF    0.11664     NZDCHF    0.10206     NZDJPY    0.20696
# 13     EURCAD    0.06250     AUDCAD    0.08909     GBPJPY    0.16116
# 14     EURGBP    0.06250     GBPCHF    0.08909     USDCAD    0.12309
# 15     GBPCAD    0.05455     GBPCAD    0.08909     EURNZD    0.12309
# 16     EURNZD    0.05455     USDCHF    0.08206     USDJPY    0.12309
# 17     USDCAD    0.05455     USDCAD    0.08206     EURCHF    0.10660
# 18     AUDUSD    0.04725     EURUSD    0.08206     EURAUD    0.10660
# 19     NZDUSD    0.04725     GBPJPY    0.05717     NZDCAD    0.07538
# 20     NZDCAD    0.04725     EURJPY    0.04280     CADCHF    0.07538
# 21     GBPCHF    0.04725     EURAUD    0.04280     AUDUSD    0.07538
# 22     GBPJPY    0.04029     EURNZD    0.04280     NZDCHF    0.07538
# 23     EURCHF    0.01849     AUDCHF    0.04280     EURUSD    0.04029
# 24     EURAUD    0.01849     CHFJPY    0.04280     USDCHF    0.04029
# 25     CHFJPY    0.01849     EURCAD    0.00000     AUDCHF    0.02273
# 26     AUDCAD    0.01849     EURGBP    0.00000     AUDCAD    0.02273
#
#    AUDNZD__10  AUDNZD_10
# 0      NZDJPY    0.50918
# 1      EURNZD    0.35635
# 2      GBPUSD    0.32733
# 3      EURCAD    0.21822
# 4      NZDCAD    0.21822
# 5      USDCAD    0.21822
# 6      NZDUSD    0.21822
# 7      GBPCHF    0.21822
# 8      GBPAUD    0.21822
# 9      GBPCAD    0.21822
# 10     CADCHF    0.21822
# 11     CADJPY    0.21822
# 12     NZDCHF    0.21822
# 13     CHFJPY    0.08909
# 14     EURAUD    0.04762
# 15     AUDJPY    0.04762
# 16     AUDCAD    0.04762
# 17     USDCHF    0.04762
# 18     EURGBP    0.04762
# 19     EURJPY    0.04762
# 20     AUDCHF    0.04762
# 21     EURCHF    0.04762
# 22     AUDUSD    0.04762
# 23     USDJPY    0.04762
# 24     EURUSD    0.04762
# 25     AUDNZD    0.04762
# 26     GBPJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
