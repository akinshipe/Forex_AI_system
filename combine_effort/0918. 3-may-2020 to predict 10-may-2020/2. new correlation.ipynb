# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-12 08:58:22.211808

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.39839     USDJPY    0.46371     EURJPY    0.50252
# 1      NZDCAD    0.36218     USDCHF    0.33929     USDJPY    0.40825
# 2      CHFJPY    0.33092     EURJPY    0.33929     GBPUSD    0.40000
# 3      USDCHF    0.32450     GBPUSD    0.27866     USDCHF    0.30151
# 4      GBPUSD    0.32026     NZDCAD    0.26726     CHFJPY    0.30151
# 5      USDJPY    0.31807     AUDCAD    0.26726     AUDNZD    0.20412
# 6      EURUSD    0.27885     CADJPY    0.26726     EURUSD    0.20412
# 7      NZDUSD    0.27885     CHFJPY    0.21822     AUDCAD    0.20000
# 8      AUDUSD    0.19872     CADCHF    0.20536     NZDUSD    0.10483
# 9      GBPJPY    0.19872     EURCAD    0.19643     EURCHF    0.10483
# 10     NZDJPY    0.16871     AUDJPY    0.19094     NZDCHF    0.10483
# 11     CADCHF    0.16386     EURUSD    0.13363     AUDJPY    0.10050
# 12     AUDCAD    0.16013     USDCAD    0.13363     CADJPY    0.10050
# 13     AUDNZD    0.11613     NZDUSD    0.13363     EURNZD    0.10050
# 14     EURCAD    0.08006     AUDCHF    0.13363     EURAUD    0.10050
# 15     EURAUD    0.08006     EURAUD    0.13363     EURCAD    0.10050
# 16     CADJPY    0.08006     AUDNZD    0.08183     EURGBP    0.10050
# 17     NZDCHF    0.07711     EURCHF    0.08183     GBPCAD    0.10050
# 18     EURCHF    0.07462     GBPJPY    0.07143     GBPJPY    0.10050
# 19     GBPCAD    0.03846     NZDCHF    0.07143     AUDUSD    0.10050
# 20     GBPCHF    0.03846     AUDUSD    0.06250     GBPCHF    0.00000
# 21     GBPAUD    0.03548     GBPCAD    0.05455     USDCAD    0.00000
# 22     AUDCHF    0.00321     GBPCHF    0.05455     AUDCHF    0.00000
# 23     AUDJPY    0.00321     GBPAUD    0.04725     CADCHF    0.00000
# 24     USDCAD    0.00321     NZDJPY    0.01849     NZDJPY    0.00000
# 25     EURGBP    0.00321     EURGBP    0.00899     NZDCAD    0.00000
# 26     EURNZD    0.00000     EURNZD    0.00000     GBPAUD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    0.73214     EURJPY    0.81650  ...     GBPCAD    0.39906
# 1      CHFJPY    0.60714     CHFJPY    0.81650  ...     GBPUSD    0.36470
# 2      AUDCAD    0.46429     GBPUSD    0.81650  ...     EURUSD    0.33092
# 3      GBPUSD    0.46429     NZDUSD    0.66667  ...     AUDUSD    0.33092
# 4      NZDUSD    0.37796     AUDCAD    0.58333  ...     GBPJPY    0.33092
# 5      USDCHF    0.33929     AUDUSD    0.58333  ...     GBPCHF    0.31795
# 6      AUDUSD    0.33929     NZDCAD    0.58333  ...     EURGBP    0.29758
# 7      USDJPY    0.33929     EURNZD    0.53452  ...     AUDCHF    0.29758
# 8      EURUSD    0.33929     GBPJPY    0.53452  ...     AUDCAD    0.28365
# 9      EURAUD    0.33929     USDCAD    0.53452  ...     NZDCAD    0.23684
# 10     GBPAUD    0.26189     CADJPY    0.40825  ...     EURCHF    0.23153
# 11     EURCHF    0.21822     USDCHF    0.40825  ...     EURJPY    0.21627
# 12     EURNZD    0.21822     NZDJPY    0.40825  ...     CADCHF    0.19025
# 13     AUDCHF    0.21822     USDJPY    0.40825  ...     CHFJPY    0.17898
# 14     GBPJPY    0.21822     EURUSD    0.40825  ...     NZDUSD    0.16871
# 15     NZDCAD    0.19643     EURAUD    0.40825  ...     NZDCHF    0.13497
# 16     NZDJPY    0.19643     AUDJPY    0.25000  ...     USDJPY    0.13497
# 17     USDCAD    0.09449     EURGBP    0.25000  ...     EURCAD    0.12157
# 18     CADJPY    0.09449     AUDCHF    0.25000  ...     EURAUD    0.12157
# 19     AUDJPY    0.07143     GBPCHF    0.25000  ...     AUDJPY    0.10895
# 20     EURGBP    0.07143     GBPCAD    0.16667  ...     USDCHF    0.10895
# 21     EURCAD    0.07143     CADCHF    0.16667  ...     USDCAD    0.10895
# 22     GBPCHF    0.07143     GBPAUD    0.08909  ...     AUDNZD    0.10123
# 23     GBPCAD    0.05455     NZDCHF    0.08909  ...     NZDJPY    0.09688
# 24     NZDCHF    0.05455     EURCAD    0.00000  ...     GBPAUD    0.06204
# 25     CADCHF    0.05455     EURCHF    0.00000  ...     CADJPY    0.04052
# 26     AUDNZD    0.05455     AUDNZD    0.00000  ...     EURNZD    0.04052
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.58333     GBPCAD    0.69752     EURGBP    0.66144
# 1      GBPCHF    0.44444     GBPCHF    0.66667     GBPCHF    0.66144
# 2      EURGBP    0.38446     EURGBP    0.53340     GBPCAD    0.57735
# 3      GBPUSD    0.38446     NZDCAD    0.40825     GBPUSD    0.47246
# 4      AUDUSD    0.35460     GBPUSD    0.40825     USDJPY    0.37796
# 5      GBPJPY    0.32733     EURCHF    0.38516     EURCHF    0.28868
# 6      EURUSD    0.27217     NZDCHF    0.38516     EURNZD    0.28868
# 7      EURAUD    0.27217     EURNZD    0.32824     GBPJPY    0.28868
# 8      NZDCAD    0.27217     EURCAD    0.32824     AUDCHF    0.28868
# 9      AUDCAD    0.27217     GBPJPY    0.32824     NZDCHF    0.28868
# 10     AUDCHF    0.27217     AUDCHF    0.25000     GBPAUD    0.21320
# 11     EURCHF    0.25000     AUDNZD    0.25000     NZDUSD    0.20000
# 12     EURCAD    0.21822     USDJPY    0.25000     AUDJPY    0.18898
# 13     NZDCHF    0.21822     EURUSD    0.25000     CHFJPY    0.18898
# 14     EURJPY    0.19094     AUDCAD    0.20412     AUDCAD    0.18898
# 15     CADCHF    0.19094     NZDUSD    0.17118     NZDCAD    0.18898
# 16     GBPAUD    0.14434     CADCHF    0.16667     USDCAD    0.10000
# 17     NZDUSD    0.13608     USDCAD    0.16667     CADJPY    0.10000
# 18     EURNZD    0.13608     GBPAUD    0.13363     NZDJPY    0.09449
# 19     USDJPY    0.11111     CHFJPY    0.12309     USDCHF    0.09449
# 20     NZDJPY    0.08472     AUDUSD    0.12309     EURAUD    0.09449
# 21     USDCHF    0.05455     EURAUD    0.12309     EURCAD    0.09449
# 22     AUDJPY    0.02778     AUDJPY    0.12309     EURJPY    0.09449
# 23     CHFJPY    0.02778     USDCHF    0.12309     AUDUSD    0.09449
# 24     AUDNZD    0.02778     EURJPY    0.08206     EURUSD    0.09449
# 25     CADJPY    0.00000     CADJPY    0.08206     CADCHF    0.00000
# 26     USDCAD    0.00000     NZDJPY    0.04167     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.66667
# 1      GBPCHF    0.66667
# 2      GBPCAD    0.58333
# 3      GBPJPY    0.53452
# 4      GBPUSD    0.40825
# 5      EURCHF    0.40825
# 6      USDCHF    0.40825
# 7      USDJPY    0.40825
# 8      EURUSD    0.40825
# 9      GBPAUD    0.35635
# 10     NZDUSD    0.25000
# 11     AUDCHF    0.25000
# 12     AUDJPY    0.16667
# 13     NZDCAD    0.16667
# 14     CADCHF    0.16667
# 15     AUDUSD    0.16667
# 16     AUDCAD    0.16667
# 17     CADJPY    0.10206
# 18     NZDCHF    0.08909
# 19     USDCAD    0.08909
# 20     EURNZD    0.08909
# 21     NZDJPY    0.00000
# 22     EURJPY    0.00000
# 23     EURAUD    0.00000
# 24     EURCAD    0.00000
# 25     CHFJPY    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
