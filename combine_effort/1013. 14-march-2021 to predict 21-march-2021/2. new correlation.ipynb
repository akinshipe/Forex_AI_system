# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 10:01:13.295200

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.32360     EURJPY    0.59093     EURJPY    0.80178
# 1      CHFJPY    0.30920     CHFJPY    0.52177     CADJPY    0.47140
# 2      GBPJPY    0.28904     EURUSD    0.47087     EURAUD    0.47140
# 3      NZDJPY    0.28904     EURNZD    0.38620     CHFJPY    0.47076
# 4      NZDUSD    0.27421     USDCHF    0.35747     GBPJPY    0.40825
# 5      GBPUSD    0.27421     GBPJPY    0.31278     EURNZD    0.38516
# 6      CADJPY    0.26212     NZDJPY    0.31278     EURUSD    0.32824
# 7      AUDUSD    0.25395     AUDJPY    0.31175     AUDNZD    0.25678
# 8      EURUSD    0.25223     AUDUSD    0.31175     USDCHF    0.25000
# 9      AUDJPY    0.19061     CADJPY    0.31175     EURGBP    0.25000
# 10     AUDNZD    0.18021     NZDUSD    0.30826     AUDCHF    0.23570
# 11     EURNZD    0.15743     EURGBP    0.30208     NZDCAD    0.23570
# 12     NZDCAD    0.15418     EURCAD    0.27866     AUDJPY    0.23570
# 13     USDCAD    0.13497     AUDNZD    0.26068     NZDJPY    0.22866
# 14     USDCHF    0.12721     GBPAUD    0.22172     AUDCAD    0.17118
# 15     USDJPY    0.11433     AUDCHF    0.19026     GBPCAD    0.17118
# 16     NZDCHF    0.10701     EURAUD    0.19026     USDCAD    0.16667
# 17     EURCHF    0.10701     EURCHF    0.17216     CADCHF    0.15309
# 18     GBPCHF    0.10701     GBPUSD    0.16147     AUDUSD    0.13363
# 19     AUDCHF    0.09996     CADCHF    0.13211     EURCHF    0.13363
# 20     GBPAUD    0.07711     USDCAD    0.10985     GBPAUD    0.12309
# 21     EURGBP    0.07711     AUDCAD    0.10985     EURCAD    0.12309
# 22     GBPCAD    0.07114     NZDCAD    0.09513     NZDUSD    0.10206
# 23     AUDCAD    0.06946     GBPCHF    0.07099     GBPCHF    0.10206
# 24     EURCAD    0.04013     USDJPY    0.06727     NZDCHF    0.05717
# 25     CADCHF    0.02341     GBPCAD    0.02746     USDJPY    0.04167
# 26     EURAUD    0.02150     NZDCHF    0.00530     GBPUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURJPY    1.00000     EURJPY    1.00000  ...     GBPUSD    0.18711
# 1      CHFJPY    0.53300     NZDJPY    0.66667  ...     AUDNZD    0.16667
# 2      EURUSD    0.49237     CADJPY    0.66667  ...     CADJPY    0.16667
# 3      CADJPY    0.45227     CHFJPY    0.61237  ...     EURUSD    0.14804
# 4      GBPJPY    0.44320     EURCAD    0.40825  ...     CHFJPY    0.13457
# 5      USDCHF    0.42640     NZDCHF    0.37500  ...     EURAUD    0.13457
# 6      EURAUD    0.42640     EURCHF    0.37500  ...     EURGBP    0.11440
# 7      AUDCHF    0.36364     EURGBP    0.32733  ...     NZDCHF    0.10206
# 8      CADCHF    0.30151     EURAUD    0.32733  ...     EURCAD    0.08165
# 9      AUDNZD    0.30151     GBPCAD    0.32733  ...     NZDCAD    0.06895
# 10     EURNZD    0.26189     GBPUSD    0.32733  ...     AUDCAD    0.06895
# 11     EURCHF    0.21320     AUDNZD    0.32733  ...     GBPCHF    0.06804
# 12     NZDJPY    0.20696     AUDCHF    0.32733  ...     USDCAD    0.04963
# 13     AUDCAD    0.18464     EURUSD    0.32733  ...     EURNZD    0.04903
# 14     EURCAD    0.18464     CADCHF    0.25000  ...     NZDJPY    0.03501
# 15     EURGBP    0.18464     USDJPY    0.25000  ...     GBPJPY    0.03501
# 16     USDCAD    0.12309     USDCHF    0.25000  ...     GBPAUD    0.03269
# 17     GBPCAD    0.10660     NZDUSD    0.21822  ...     EURJPY    0.01724
# 18     USDJPY    0.10660     AUDJPY    0.21822  ...     AUDCHF    0.01724
# 19     NZDCAD    0.10660     GBPCHF    0.16667  ...     EURCHF    0.01701
# 20     GBPCHF    0.07538     AUDUSD    0.10206  ...     AUDJPY    0.01701
# 21     NZDUSD    0.07538     USDCAD    0.10206  ...     CADCHF    0.01701
# 22     AUDJPY    0.07538     NZDCAD    0.10206  ...     NZDUSD    0.01701
# 23     NZDCHF    0.07538     GBPAUD    0.00000  ...     GBPCAD    0.01645
# 24     GBPAUD    0.04029     EURNZD    0.00000  ...     USDJPY    0.01638
# 25     AUDUSD    0.02273     AUDCAD    0.00000  ...     USDCHF    0.01638
# 26     GBPUSD    0.02273     GBPJPY    0.00000  ...     AUDUSD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.33634     GBPUSD    0.37796     GBPCAD    0.35355
# 1      CADJPY    0.31175     GBPCHF    0.32733     GBPUSD    0.30151
# 2      GBPUSD    0.27890     AUDCAD    0.25163     NZDJPY    0.29417
# 3      AUDNZD    0.26068     GBPCAD    0.25163     USDCAD    0.27217
# 4      EURUSD    0.20180     GBPJPY    0.21822     GBPCHF    0.25000
# 5      USDCHF    0.18552     AUDNZD    0.20588     EURNZD    0.20045
# 6      EURJPY    0.17216     EURCHF    0.19048     AUDNZD    0.16667
# 7      AUDJPY    0.17216     GBPAUD    0.15352     NZDCHF    0.16667
# 8      AUDCAD    0.16477     USDCHF    0.13363     CADCHF    0.16667
# 9      CADCHF    0.16147     USDCAD    0.13363     CADJPY    0.16667
# 10     NZDJPY    0.15374     USDJPY    0.13363     AUDJPY    0.16667
# 11     NZDCHF    0.15374     EURAUD    0.12599     NZDUSD    0.16667
# 12     GBPJPY    0.15374     AUDCHF    0.12599     GBPJPY    0.13363
# 13     EURCAD    0.12585     NZDCAD    0.12599     GBPAUD    0.13363
# 14     EURGBP    0.10985     AUDJPY    0.12599     AUDCHF    0.07538
# 15     USDCAD    0.10985     CADJPY    0.12599     AUDUSD    0.07538
# 16     AUDCHF    0.09513     EURGBP    0.08909     EURJPY    0.07538
# 17     GBPAUD    0.08597     EURUSD    0.06580     AUDCAD    0.06804
# 18     GBPCHF    0.08113     EURCAD    0.06580     EURGBP    0.06804
# 19     EURAUD    0.04757     CADCHF    0.05455     EURCAD    0.06804
# 20     NZDCAD    0.04757     NZDUSD    0.05455     EURUSD    0.06804
# 21     EURNZD    0.03257     EURJPY    0.04762     EURAUD    0.00000
# 22     AUDUSD    0.03257     AUDUSD    0.04762     CHFJPY    0.00000
# 23     EURCHF    0.03257     NZDJPY    0.03056     EURCHF    0.00000
# 24     GBPCAD    0.02746     NZDCHF    0.03056     USDJPY    0.00000
# 25     CHFJPY    0.02746     EURNZD    0.02288     NZDCAD    0.00000
# 26     NZDUSD    0.01468     CHFJPY    0.02288     USDCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      CADJPY    0.50918
# 1      NZDJPY    0.50918
# 2      GBPCAD    0.42857
# 3      GBPUSD    0.42857
# 4      USDCAD    0.35635
# 5      USDCHF    0.21822
# 6      EURJPY    0.21822
# 7      GBPAUD    0.21822
# 8      NZDCHF    0.21822
# 9      CADCHF    0.21822
# 10     EURCHF    0.21822
# 11     GBPCHF    0.21822
# 12     AUDCAD    0.21822
# 13     USDJPY    0.21822
# 14     EURNZD    0.21822
# 15     CHFJPY    0.08909
# 16     AUDUSD    0.08909
# 17     NZDCAD    0.08909
# 18     EURCAD    0.08909
# 19     AUDJPY    0.04762
# 20     EURGBP    0.04762
# 21     EURAUD    0.04762
# 22     AUDCHF    0.04762
# 23     NZDUSD    0.04762
# 24     EURUSD    0.04762
# 25     AUDNZD    0.04762
# 26     GBPJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
