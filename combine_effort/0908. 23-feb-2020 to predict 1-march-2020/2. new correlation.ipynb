# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-10 11:10:32.367964

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      USDJPY    0.23775     USDCHF    0.33929     USDJPY    0.47076
# 1      EURJPY    0.23775     EURCAD    0.33036     CADJPY    0.47076
# 2      USDCHF    0.20192     USDJPY    0.32733     EURAUD    0.40825
# 3      NZDCAD    0.19872     CADJPY    0.32733     USDCAD    0.37500
# 4      CHFJPY    0.16871     EURUSD    0.26726     AUDJPY    0.35635
# 5      EURGBP    0.16386     USDCAD    0.26726     USDCHF    0.32824
# 6      GBPAUD    0.16013     CADCHF    0.26726     EURCAD    0.28721
# 7      AUDCAD    0.16013     EURAUD    0.26726     AUDCHF    0.28721
# 8      EURUSD    0.15743     NZDCAD    0.26068     AUDUSD    0.25000
# 9      NZDUSD    0.15743     AUDJPY    0.25882     CADCHF    0.20412
# 10     EURCAD    0.12179     EURJPY    0.19643     AUDNZD    0.17118
# 11     EURNZD    0.12179     EURNZD    0.19643     EURCHF    0.17118
# 12     GBPCAD    0.12179     AUDCHF    0.19643     GBPCAD    0.16667
# 13     EURCHF    0.11613     GBPUSD    0.14382     EURNZD    0.16667
# 14     AUDUSD    0.11613     NZDJPY    0.12016     GBPCHF    0.13363
# 15     GBPCHF    0.11613     EURGBP    0.12016     NZDJPY    0.13363
# 16     AUDCHF    0.08006     CHFJPY    0.08183     EURJPY    0.12309
# 17     CADCHF    0.08006     NZDUSD    0.06250     NZDCHF    0.08206
# 18     USDCAD    0.08006     AUDCAD    0.06250     NZDUSD    0.08206
# 19     GBPJPY    0.08006     GBPAUD    0.05455     AUDCAD    0.08206
# 20     CADJPY    0.07711     GBPJPY    0.05455     NZDCAD    0.08206
# 21     GBPUSD    0.07711     EURCHF    0.05455     CHFJPY    0.04280
# 22     EURAUD    0.04167     GBPCHF    0.04725     GBPJPY    0.04280
# 23     NZDJPY    0.04167     AUDUSD    0.01849     GBPAUD    0.04280
# 24     NZDCHF    0.03846     AUDNZD    0.01849     EURGBP    0.04280
# 25     AUDNZD    0.00649     GBPCAD    0.00899     GBPUSD    0.04167
# 26     AUDJPY    0.00321     NZDCHF    0.00000     EURUSD    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDJPY    0.57735     NZDCAD    0.66667  ...     GBPCAD    0.33092
# 1      AUDUSD    0.57735     EURNZD    0.58333  ...     GBPUSD    0.29758
# 2      GBPCAD    0.44444     AUDNZD    0.53452  ...     EURJPY    0.29758
# 3      USDJPY    0.44444     AUDUSD    0.53452  ...     GBPJPY    0.28365
# 4      USDCAD    0.44444     NZDUSD    0.53452  ...     AUDUSD    0.26449
# 5      CADJPY    0.44444     GBPCAD    0.40825  ...     NZDCAD    0.24982
# 6      NZDJPY    0.43082     USDCAD    0.40825  ...     GBPCHF    0.22531
# 7      EURAUD    0.38889     USDJPY    0.35635  ...     EURGBP    0.21627
# 8      NZDUSD    0.32733     NZDJPY    0.35635  ...     EURUSD    0.21627
# 9      EURNZD    0.28868     AUDJPY    0.35635  ...     AUDCAD    0.20261
# 10     GBPJPY    0.28868     CADJPY    0.35635  ...     AUDCHF    0.20261
# 11     CHFJPY    0.28868     AUDCAD    0.25000  ...     AUDJPY    0.19025
# 12     AUDNZD    0.21822     EURAUD    0.25000  ...     CHFJPY    0.17898
# 13     AUDCHF    0.21822     EURCAD    0.25000  ...     EURAUD    0.16871
# 14     NZDCAD    0.21822     EURJPY    0.25000  ...     EURCAD    0.15573
# 15     EURUSD    0.21822     USDCHF    0.25000  ...     NZDUSD    0.13497
# 16     AUDCAD    0.21822     NZDCHF    0.25000  ...     CADCHF    0.12157
# 17     EURGBP    0.16667     AUDCHF    0.25000  ...     USDCAD    0.12157
# 18     GBPUSD    0.16667     GBPCHF    0.25000  ...     EURCHF    0.10123
# 19     GBPCHF    0.16667     GBPJPY    0.16667  ...     NZDCHF    0.08760
# 20     GBPAUD    0.12309     CADCHF    0.16667  ...     EURNZD    0.08760
# 21     USDCHF    0.11111     CHFJPY    0.16667  ...     NZDJPY    0.07462
# 22     EURCAD    0.05455     EURCHF    0.10206  ...     AUDNZD    0.06732
# 23     EURJPY    0.05455     GBPAUD    0.08909  ...     USDJPY    0.05366
# 24     NZDCHF    0.05455     EURUSD    0.08909  ...     GBPAUD    0.04052
# 25     CADCHF    0.05455     GBPUSD    0.00000  ...     CADJPY    0.02764
# 26     EURCHF    0.00000     EURGBP    0.00000  ...     USDCHF    0.00649
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCAD    0.59093     GBPCAD    0.58333     GBPCAD    0.60010
# 1      GBPUSD    0.45134     AUDUSD    0.45833     EURAUD    0.49099
# 2      AUDUSD    0.43541     EURAUD    0.40825     AUDUSD    0.37796
# 3      EURCAD    0.43444     GBPUSD    0.37500     AUDCHF    0.33929
# 4      CADCHF    0.34586     GBPCHF    0.35635     NZDCAD    0.33929
# 5      EURUSD    0.34586     EURCAD    0.32824     AUDCAD    0.33929
# 6      GBPCHF    0.34238     NZDCAD    0.32824     EURCAD    0.33929
# 7      EURJPY    0.29579     AUDCAD    0.32824     EURGBP    0.32733
# 8      AUDCAD    0.29579     NZDCHF    0.28721     GBPCHF    0.32733
# 9      AUDCHF    0.25882     EURJPY    0.28721     GBPUSD    0.32733
# 10     NZDCAD    0.24661     AUDCHF    0.28721     USDCHF    0.21822
# 11     GBPJPY    0.22591     GBPJPY    0.25678     USDCAD    0.21822
# 12     USDCAD    0.20751     EURGBP    0.25678     CADCHF    0.19643
# 13     EURAUD    0.20751     CADCHF    0.20412     NZDCHF    0.19643
# 14     EURCHF    0.19767     EURUSD    0.20412     EURJPY    0.19643
# 15     EURGBP    0.13876     EURCHF    0.17118     GBPJPY    0.18898
# 16     CHFJPY    0.08472     EURNZD    0.16667     EURNZD    0.18898
# 17     GBPAUD    0.08472     NZDJPY    0.13363     AUDJPY    0.18898
# 18     NZDCHF    0.06917     AUDJPY    0.13363     CHFJPY    0.09449
# 19     CADJPY    0.05648     USDCHF    0.12309     EURCHF    0.09449
# 20     USDJPY    0.05648     NZDUSD    0.08206     NZDUSD    0.07143
# 21     USDCHF    0.01849     GBPAUD    0.04280     EURUSD    0.07143
# 22     EURNZD    0.01849     CADJPY    0.04280     AUDNZD    0.07143
# 23     NZDUSD    0.01849     CHFJPY    0.04280     CADJPY    0.05455
# 24     AUDJPY    0.00478     USDJPY    0.04280     USDJPY    0.05455
# 25     NZDJPY    0.00478     AUDNZD    0.04280     GBPAUD    0.04029
# 26     AUDNZD    0.00478     USDCAD    0.04167     NZDJPY    0.04029
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCAD    0.81650
# 1      USDCHF    0.66667
# 2      GBPCHF    0.66667
# 3      NZDCAD    0.66667
# 4      EURCAD    0.66667
# 5      NZDCHF    0.66667
# 6      EURNZD    0.58333
# 7      AUDNZD    0.53452
# 8      EURCHF    0.40825
# 9      GBPUSD    0.40825
# 10     USDCAD    0.40825
# 11     EURGBP    0.40825
# 12     AUDCHF    0.25000
# 13     CHFJPY    0.25000
# 14     EURAUD    0.25000
# 15     AUDCAD    0.25000
# 16     GBPJPY    0.16667
# 17     CADCHF    0.16667
# 18     EURJPY    0.16667
# 19     NZDUSD    0.08909
# 20     AUDUSD    0.08909
# 21     GBPAUD    0.08909
# 22     USDJPY    0.08909
# 23     CADJPY    0.08909
# 24     AUDJPY    0.08909
# 25     NZDJPY    0.08909
# 26     EURUSD    0.08909
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
