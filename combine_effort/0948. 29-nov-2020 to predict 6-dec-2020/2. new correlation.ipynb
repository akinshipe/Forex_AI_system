# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-15 08:17:36.091815

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      GBPUSD    0.27891     EURUSD    0.30861     EURUSD    0.48038
# 1      AUDNZD    0.25732     AUDUSD    0.30861     USDCHF    0.31868
# 2      USDJPY    0.23753     AUDNZD    0.26245     AUDUSD    0.31868
# 3      CHFJPY    0.21868     GBPUSD    0.23757     GBPUSD    0.31868
# 4      EURUSD    0.19590     NZDUSD    0.23757     CHFJPY    0.31868
# 5      EURJPY    0.18846     NZDJPY    0.23757     EURGBP    0.31449
# 6      USDCHF    0.18846     AUDJPY    0.23757     GBPAUD    0.25678
# 7      AUDUSD    0.16530     GBPAUD    0.21822     AUDCHF    0.25678
# 8      GBPCAD    0.15505     GBPCAD    0.21822     NZDCAD    0.24232
# 9      EURNZD    0.15505     NZDCAD    0.19623     NZDJPY    0.24232
# 10     AUDCAD    0.13457     USDCAD    0.19623     EURCAD    0.24232
# 11     NZDJPY    0.13457     CHFJPY    0.19623     NZDUSD    0.24232
# 12     NZDUSD    0.12361     EURGBP    0.17496     GBPCHF    0.17911
# 13     AUDCHF    0.10417     USDJPY    0.17496     EURNZD    0.17911
# 14     GBPAUD    0.08515     EURNZD    0.16147     AUDNZD    0.17911
# 15     NZDCAD    0.08181     AUDCAD    0.15430     USDJPY    0.17118
# 16     AUDJPY    0.08181     USDCHF    0.15430     GBPJPY    0.17118
# 17     USDCAD    0.06118     CADCHF    0.13211     AUDJPY    0.17118
# 18     EURAUD    0.06118     EURCAD    0.13211     GBPCAD    0.10483
# 19     EURGBP    0.06118     CADJPY    0.13211     EURJPY    0.09890
# 20     GBPJPY    0.06118     AUDCHF    0.10566     USDCAD    0.09890
# 21     NZDCHF    0.04120     NZDCHF    0.08909     AUDCAD    0.09890
# 22     CADCHF    0.04120     GBPJPY    0.08909     CADJPY    0.04280
# 23     GBPCHF    0.04120     EURAUD    0.08909     NZDCHF    0.03161
# 24     EURCAD    0.00990     EURCHF    0.04528     CADCHF    0.03161
# 25     CADJPY    0.00990     GBPCHF    0.01468     EURAUD    0.03161
# 26     EURCHF    0.00990     EURJPY    0.00000     EURCHF    0.02288
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      EURUSD    0.66667     EURGBP    0.65465  ...     GBPCAD    0.27885
# 1      USDCHF    0.49099     AUDUSD    0.53452  ...     EURGBP    0.24418
# 2      CHFJPY    0.49099     AUDJPY    0.53452  ...     GBPCHF    0.24019
# 3      EURCAD    0.49099     EURJPY    0.53452  ...     CHFJPY    0.21246
# 4      AUDUSD    0.49099     CHFJPY    0.53452  ...     CADCHF    0.16013
# 5      GBPAUD    0.44444     USDCHF    0.53452  ...     NZDJPY    0.13074
# 6      EURGBP    0.44444     USDCAD    0.53452  ...     USDJPY    0.12179
# 7      AUDNZD    0.43082     EURUSD    0.53452  ...     EURCHF    0.11859
# 8      EURNZD    0.43082     AUDNZD    0.52381  ...     EURCAD    0.11859
# 9      NZDUSD    0.38889     EURNZD    0.52381  ...     AUDJPY    0.08760
# 10     AUDCAD    0.38889     GBPUSD    0.42857  ...     USDCAD    0.08353
# 11     AUDJPY    0.32733     NZDJPY    0.42857  ...     EURAUD    0.08353
# 12     USDJPY    0.28868     GBPJPY    0.42857  ...     NZDUSD    0.08006
# 13     NZDCAD    0.28868     NZDUSD    0.42857  ...     AUDCHF    0.07711
# 14     NZDJPY    0.28868     GBPCAD    0.35635  ...     NZDCAD    0.07462
# 15     GBPCHF    0.28868     GBPCHF    0.35635  ...     GBPAUD    0.07462
# 16     GBPUSD    0.28868     GBPAUD    0.35635  ...     GBPUSD    0.04516
# 17     EURJPY    0.21822     EURCAD    0.21822  ...     EURUSD    0.04516
# 18     AUDCHF    0.16667     AUDCHF    0.21822  ...     AUDNZD    0.04167
# 19     CADCHF    0.16667     CADJPY    0.21822  ...     EURNZD    0.03846
# 20     NZDCHF    0.12309     USDJPY    0.08909  ...     CADJPY    0.03846
# 21     USDCAD    0.11111     CADCHF    0.08909  ...     AUDCAD    0.03269
# 22     EURCHF    0.11111     EURCHF    0.08909  ...     EURJPY    0.00990
# 23     GBPJPY    0.11111     AUDCAD    0.08909  ...     USDCHF    0.00990
# 24     GBPCAD    0.05455     NZDCHF    0.04762  ...     AUDUSD    0.00649
# 25     CADJPY    0.05455     EURAUD    0.04762  ...     GBPJPY    0.00321
# 26     EURAUD    0.00000     NZDCAD    0.04762  ...     NZDCHF    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPUSD    0.32733     GBPUSD    0.38982     GBPUSD    0.40000
# 1      CHFJPY    0.25882     CADJPY    0.32824     USDJPY    0.40000
# 2      GBPJPY    0.19094     USDJPY    0.28721     EURGBP    0.28868
# 3      NZDJPY    0.19094     EURJPY    0.24232     EURUSD    0.28868
# 4      NZDUSD    0.19094     AUDNZD    0.19192     AUDCAD    0.28868
# 5      EURAUD    0.19094     NZDCAD    0.19192     NZDUSD    0.28868
# 6      NZDCHF    0.19094     NZDJPY    0.19192     GBPCHF    0.20000
# 7      EURUSD    0.18898     NZDUSD    0.19192     CADJPY    0.18898
# 8      CADJPY    0.14382     EURNZD    0.19192     EURCAD    0.18898
# 9      EURNZD    0.12585     CADCHF    0.19192     USDCHF    0.18898
# 10     CADCHF    0.12585     NZDCHF    0.19192     CHFJPY    0.18898
# 11     NZDCAD    0.12016     EURAUD    0.19192     AUDUSD    0.18898
# 12     USDCHF    0.09449     EURCHF    0.15352     AUDNZD    0.10660
# 13     USDJPY    0.07143     AUDJPY    0.12309     NZDCHF    0.10660
# 14     EURGBP    0.06250     AUDCHF    0.12309     EURNZD    0.10660
# 15     AUDNZD    0.06250     EURGBP    0.10050     NZDCAD    0.10000
# 16     AUDJPY    0.05455     GBPCAD    0.10050     NZDJPY    0.10000
# 17     EURJPY    0.04725     GBPAUD    0.08206     EURAUD    0.10000
# 18     AUDUSD    0.04725     GBPJPY    0.08206     AUDJPY    0.09449
# 19     AUDCAD    0.04725     EURUSD    0.06580     GBPCAD    0.09449
# 20     AUDCHF    0.01849     CHFJPY    0.03161     EURJPY    0.09449
# 21     EURCHF    0.01849     AUDUSD    0.03161     USDCAD    0.00000
# 22     USDCAD    0.01849     USDCAD    0.03161     CADCHF    0.00000
# 23     EURCAD    0.00899     AUDCAD    0.03161     AUDCHF    0.00000
# 24     GBPCHF    0.00899     USDCHF    0.03161     GBPAUD    0.00000
# 25     GBPCAD    0.00000     EURCAD    0.01010     GBPJPY    0.00000
# 26     GBPAUD    0.00000     GBPCHF    0.01010     EURCHF    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURGBP    0.40825
# 1      GBPUSD    0.35635
# 2      NZDJPY    0.35635
# 3      NZDUSD    0.35635
# 4      GBPJPY    0.35635
# 5      GBPCHF    0.25000
# 6      GBPCAD    0.25000
# 7      AUDCAD    0.16667
# 8      AUDJPY    0.16667
# 9      EURJPY    0.16667
# 10     GBPAUD    0.16667
# 11     USDCHF    0.16667
# 12     CADCHF    0.16667
# 13     CHFJPY    0.16667
# 14     EURCHF    0.16667
# 15     AUDUSD    0.16667
# 16     USDCAD    0.16667
# 17     USDJPY    0.16667
# 18     EURUSD    0.16667
# 19     NZDCHF    0.08909
# 20     EURAUD    0.08909
# 21     EURNZD    0.08909
# 22     NZDCAD    0.08909
# 23     AUDNZD    0.08909
# 24     AUDCHF    0.00000
# 25     EURCAD    0.00000
# 26     CADJPY    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
