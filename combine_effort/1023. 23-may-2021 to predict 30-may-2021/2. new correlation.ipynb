# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 09:50:18.086099

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      EURJPY    0.28356     EURJPY    0.43179     CADJPY    0.47140
# 1      GBPJPY    0.28356     CADJPY    0.40825     GBPCHF    0.23570
# 2      CHFJPY    0.27891     AUDNZD    0.33072     EURJPY    0.22866
# 3      CADJPY    0.27891     GBPJPY    0.29881     GBPJPY    0.22866
# 4      AUDNZD    0.23028     CHFJPY    0.25882     EURGBP    0.17118
# 5      EURUSD    0.21753     EURNZD    0.21822     USDCAD    0.17118
# 6      GBPUSD    0.16116     EURGBP    0.21822     GBPUSD    0.17118
# 7      EURNZD    0.15198     EURUSD    0.20536     CHFJPY    0.16667
# 8      EURGBP    0.15198     GBPCHF    0.19138     NZDCHF    0.16667
# 9      AUDJPY    0.14804     EURAUD    0.15714     USDCHF    0.16667
# 10     NZDJPY    0.12588     AUDJPY    0.12016     CADCHF    0.13363
# 11     GBPCHF    0.11289     GBPCAD    0.09449     AUDNZD    0.13363
# 12     NZDUSD    0.11289     NZDCAD    0.09449     AUDCAD    0.12309
# 13     AUDUSD    0.11289     USDJPY    0.07143     GBPCAD    0.08909
# 14     CADCHF    0.11289     GBPAUD    0.07143     AUDCHF    0.08206
# 15     GBPAUD    0.10714     USDCHF    0.07143     EURAUD    0.08206
# 16     AUDCHF    0.09869     AUDUSD    0.05455     AUDJPY    0.08206
# 17     NZDCHF    0.06580     NZDJPY    0.04213     NZDCAD    0.08206
# 18     NZDCAD    0.06580     CADCHF    0.04029     EURCHF    0.04280
# 19     GBPCAD    0.05313     GBPUSD    0.02916     NZDUSD    0.04167
# 20     USDJPY    0.04516     NZDCHF    0.02916     USDJPY    0.04167
# 21     EURCAD    0.03548     NZDUSD    0.02916     EURUSD    0.04167
# 22     EURCHF    0.02988     EURCHF    0.01849     EURCAD    0.04167
# 23     USDCAD    0.02988     AUDCHF    0.01849     AUDUSD    0.00000
# 24     EURAUD    0.02597     USDCAD    0.01849     GBPAUD    0.00000
# 25     AUDCAD    0.01959     EURCAD    0.00899     EURNZD    0.00000
# 26     USDCHF    0.01959     AUDCAD    0.00899     NZDJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      AUDNZD    0.43082     NZDJPY    0.58333  ...     GBPUSD    0.27217
# 1      GBPCHF    0.43082     AUDNZD    0.53452  ...     EURUSD    0.23028
# 2      CADJPY    0.43082     EURJPY    0.40825  ...     EURAUD    0.14804
# 3      EURAUD    0.32733     NZDUSD    0.40825  ...     GBPJPY    0.14548
# 4      AUDCHF    0.32733     EURCHF    0.40825  ...     GBPCHF    0.13457
# 5      USDCHF    0.32733     USDCAD    0.35635  ...     GBPCAD    0.13457
# 6      CADCHF    0.28868     USDJPY    0.25000  ...     USDJPY    0.13074
# 7      GBPJPY    0.27217     AUDUSD    0.25000  ...     CADJPY    0.11775
# 8      NZDUSD    0.21822     GBPCHF    0.25000  ...     USDCHF    0.11580
# 9      EURJPY    0.21822     CADCHF    0.25000  ...     AUDCAD    0.11580
# 10     USDCAD    0.18464     AUDJPY    0.25000  ...     EURNZD    0.09829
# 11     NZDJPY    0.18464     NZDCHF    0.25000  ...     NZDCAD    0.08333
# 12     EURCAD    0.16667     CADJPY    0.25000  ...     AUDNZD    0.08333
# 13     EURCHF    0.11111     EURCAD    0.25000  ...     NZDCHF    0.08333
# 14     CHFJPY    0.11111     AUDCAD    0.16667  ...     AUDCHF    0.08333
# 15     GBPUSD    0.11111     EURAUD    0.16667  ...     GBPAUD    0.06580
# 16     AUDCAD    0.11111     USDCHF    0.16667  ...     CADCHF    0.05046
# 17     EURUSD    0.05455     GBPUSD    0.16667  ...     CHFJPY    0.05046
# 18     NZDCAD    0.05455     AUDCHF    0.16667  ...     NZDUSD    0.05046
# 19     AUDJPY    0.05455     CHFJPY    0.16667  ...     AUDUSD    0.05046
# 20     GBPAUD    0.05455     EURGBP    0.16667  ...     EURJPY    0.03637
# 21     EURNZD    0.05455     GBPCAD    0.08909  ...     EURCHF    0.03364
# 22     USDJPY    0.05455     GBPJPY    0.08909  ...     USDCAD    0.03364
# 23     AUDUSD    0.05455     GBPAUD    0.00000  ...     EURCAD    0.03269
# 24     NZDCHF    0.05455     EURNZD    0.00000  ...     NZDJPY    0.01724
# 25     GBPCAD    0.00000     EURUSD    0.00000  ...     EURGBP    0.01638
# 26     EURGBP    0.00000     NZDCAD    0.00000  ...     AUDJPY    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPCHF    0.42640     GBPCAD    0.48038     GBPCAD    0.50000
# 1      GBPCAD    0.35000     GBPCHF    0.42366     AUDNZD    0.42640
# 2      GBPJPY    0.31623     GBPUSD    0.31868     GBPCHF    0.42640
# 3      GBPUSD    0.30861     GBPJPY    0.30826     AUDCHF    0.37796
# 4      AUDCHF    0.24456     NZDJPY    0.30261     GBPJPY    0.35355
# 5      AUDCAD    0.19026     USDCHF    0.25678     AUDCAD    0.28868
# 6      USDCHF    0.18898     EURUSD    0.25678     GBPUSD    0.28868
# 7      EURUSD    0.18898     USDJPY    0.25678     NZDJPY    0.21320
# 8      USDJPY    0.18898     AUDNZD    0.25163     CADCHF    0.20000
# 9      EURGBP    0.14434     AUDCHF    0.24232     EURGBP    0.20000
# 10     NZDJPY    0.11146     AUDCAD    0.17911     USDCHF    0.18898
# 11     CADCHF    0.10660     EURCHF    0.12088     EURUSD    0.18898
# 12     EURAUD    0.09782     USDCAD    0.12088     AUDUSD    0.18898
# 13     EURCHF    0.09782     EURNZD    0.10483     EURJPY    0.18898
# 14     EURCAD    0.09513     AUDUSD    0.10483     NZDCAD    0.18898
# 15     GBPAUD    0.09449     GBPAUD    0.10483     EURNZD    0.18898
# 16     EURJPY    0.05573     EURGBP    0.09890     USDJPY    0.18898
# 17     NZDCAD    0.05000     CADJPY    0.06052     USDCAD    0.10660
# 18     AUDNZD    0.05000     CHFJPY    0.04280     CADJPY    0.10660
# 19     CHFJPY    0.04891     NZDUSD    0.04280     NZDCHF    0.09449
# 20     AUDJPY    0.04891     NZDCHF    0.04280     NZDUSD    0.09449
# 21     USDCAD    0.04891     EURCAD    0.04280     GBPAUD    0.09449
# 22     AUDUSD    0.00000     EURAUD    0.03161     EURAUD    0.09449
# 23     NZDUSD    0.00000     AUDJPY    0.03161     AUDJPY    0.09449
# 24     EURNZD    0.00000     NZDCAD    0.03161     CHFJPY    0.00000
# 25     CADJPY    0.00000     CADCHF    0.02288     EURCHF    0.00000
# 26     NZDCHF    0.00000     EURJPY    0.01468     EURCAD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      GBPCHF    0.66667
# 1      AUDCHF    0.58333
# 2      AUDNZD    0.53452
# 3      GBPCAD    0.53452
# 4      GBPJPY    0.53452
# 5      EURUSD    0.40825
# 6      EURJPY    0.27217
# 7      CADCHF    0.25000
# 8      CADJPY    0.25000
# 9      GBPUSD    0.25000
# 10     USDCHF    0.25000
# 11     USDJPY    0.25000
# 12     EURGBP    0.25000
# 13     CHFJPY    0.16667
# 14     NZDCHF    0.16667
# 15     AUDUSD    0.16667
# 16     EURCAD    0.16667
# 17     EURAUD    0.16667
# 18     AUDJPY    0.16667
# 19     NZDJPY    0.16667
# 20     AUDCAD    0.16667
# 21     USDCAD    0.08909
# 22     EURCHF    0.00000
# 23     NZDUSD    0.00000
# 24     GBPAUD    0.00000
# 25     EURNZD    0.00000
# 26     NZDCAD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
