# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
current_currency = 'USDCHF10080'.replace('10080','')
raw_data = pd.read_csv('files/' + current_currency + '.csv'  )

# %%
cut_off = [ 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7  ]

for cut in cut_off:
   
    
    

    number_of_accurate_prediction = 0
    number_of_trades = 0


    step_down = 50
    
    n_estimators = 8000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None


    
    for v in range(step_down):

        print('step_down ', v)


        data = raw_data.copy()
        data = data[v:]
        #print(data['date'].head(1))



        X = data.drop(columns=[
                                    'date',
                                   'nextweek_'+ current_currency])

        y = data['nextweek_'+ current_currency]




        X_train = X[1:]
        y_train = y[1:]
        X_test = X[:1]
        y_test = y[:1]



        clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                     max_features=max_features, max_samples = max_samples)

        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)


        y_test = y_test.values




        if y_pred[0] > cut  or y_pred[0] < (-1*cut) :
            number_of_trades = number_of_trades + 1
            #print(y_pred[0], y_test[0])


            if (y_pred[0] > 0 and y_test[0] == 1) or (y_pred[0] < 0 and y_test[0]) == -1:
                 number_of_accurate_prediction = number_of_accurate_prediction +1


    print(number_of_accurate_prediction)
    print(number_of_trades)  
    
    if number_of_trades !=0:
        print('Accuracy is ', 100*number_of_accurate_prediction/number_of_trades,'%')
        print('Avereage trade  trade per weeks is ',  number_of_trades/step_down)
    else:
        print('--------there is no trade')
        
    print('-------------------------------------------------------------------cut of is ', cut)
# Out:
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 24
# 45
# Accuracy is  53.333333333333336 %
# Avereage trade  trade per weeks is  0.9
# -------------------------------------------------------------------cut of is  0.05
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 22
# 42
# Accuracy is  52.38095238095238 %
# Avereage trade  trade per weeks is  0.84
# -------------------------------------------------------------------cut of is  0.1
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 19
# 38
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  0.76
# -------------------------------------------------------------------cut of is  0.15
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 18
# 37
# Accuracy is  48.648648648648646 %
# Avereage trade  trade per weeks is  0.74
# -------------------------------------------------------------------cut of is  0.2
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 13
# 30
# Accuracy is  43.333333333333336 %
# Avereage trade  trade per weeks is  0.6
# -------------------------------------------------------------------cut of is  0.25
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 11
# 27
# Accuracy is  40.74074074074074 %
# Avereage trade  trade per weeks is  0.54
# -------------------------------------------------------------------cut of is  0.3
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 8
# 22
# Accuracy is  36.36363636363637 %
# Avereage trade  trade per weeks is  0.44
# -------------------------------------------------------------------cut of is  0.35
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 7
# 16
# Accuracy is  43.75 %
# Avereage trade  trade per weeks is  0.32
# -------------------------------------------------------------------cut of is  0.4
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 5
# 12
# Accuracy is  41.666666666666664 %
# Avereage trade  trade per weeks is  0.24
# -------------------------------------------------------------------cut of is  0.45
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 5
# 9
# Accuracy is  55.55555555555556 %
# Avereage trade  trade per weeks is  0.18
# -------------------------------------------------------------------cut of is  0.5
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 3
# 5
# Accuracy is  60.0 %
# Avereage trade  trade per weeks is  0.1
# -------------------------------------------------------------------cut of is  0.55
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 1
# 2
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  0.04
# -------------------------------------------------------------------cut of is  0.6
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 0
# 0
# --------there is no trade
# -------------------------------------------------------------------cut of is  0.65
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 0
# 0
# --------there is no trade
# -------------------------------------------------------------------cut of is  0.7

# %%
feature_importance = pd.DataFrame(clf.feature_importances_,
                        index = X_train.columns,
                        columns = ['importance']).sort_values('importance', ascending =False)
feature_importance
# Out:
#         importance
# EURCHF    0.059803
# AUDNZD    0.048328
# GBPCAD    0.046308
# AUDCAD    0.044888
# GBPUSD    0.043675
# USDCAD    0.042783
# NZDCAD    0.042746
# GBPCHF    0.041819
# EURGBP    0.041519
# USDCHF    0.039914
# CHFJPY    0.039847
# EURNZD    0.035941
# GBPAUD    0.035819
# NZDUSD    0.034669
# AUDUSD    0.034112
# EURCAD    0.033216
# CADJPY    0.032818
# AUDCHF    0.032365
# EURUSD    0.032112
# NZDJPY    0.031386
# AUDJPY    0.030831
# CADCHF    0.030513
# USDJPY    0.030199
# EURJPY    0.030166
# EURAUD    0.029000
# NZDCHF    0.028020
# GBPJPY    0.027202
