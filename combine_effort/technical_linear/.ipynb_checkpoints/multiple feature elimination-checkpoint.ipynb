# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
current_currency = 'USDCHF10080'.replace('10080','')
raw_data = pd.read_csv('files/' + current_currency + '.csv'  )
print()

# %%
features = raw_data.columns.values.tolist()
features.remove( 'date')
features.remove( 'nextweek_'+ current_currency)

for fea in features:
    
    
    

    number_of_accurate_prediction = 0
    number_of_trades = 0


    step_down = 50
    cut_off = 0
    n_estimators = 8000
    min_samples_leaf = 1
    max_features = "auto"
    max_samples = None


    
    for v in range(step_down):

        print('step_down ', v)


        data = raw_data.copy()
        data = data[v:]
        
        data.drop(columns=[fea])m
        #print(data['date'].head(1))



        X = data.drop(columns=[
                                    'date',
                                   'nextweek_'+ current_currency])

        y = data['nextweek_'+ current_currency]




        X_train = X[1:]
        y_train = y[1:]
        X_test = X[:1]
        y_test = y[:1]



        clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                     max_features=max_features, max_samples = max_samples)

        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)


        y_test = y_test.values




        if y_pred[0] > cut_off  or y_pred[0] < (-1*cut_off) :
            number_of_trades = number_of_trades + 1
            #print(y_pred[0], y_test[0])


            if (y_pred[0] > 0 and y_test[0] == 1) or (y_pred[0] < 0 and y_test[0]) == -1:
                 number_of_accurate_prediction = number_of_accurate_prediction +1


    print(number_of_accurate_prediction)
    print(number_of_trades)  
    
    if number_of_trades !=0:
        print('Accuracy is ', 100*number_of_accurate_prediction/number_of_trades,'%')
        print('Avereage trade  trade per weeks is ',  number_of_trades/step_down)
    else:
        print('--------there is no trade')
        
    print('---------------------------------------------------------------feature of is ', fea)
# Out:
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 27
# 50
# Accuracy is  54.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  USDCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 27
# 50
# Accuracy is  54.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  GBPUSD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURUSD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  USDJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  USDCAD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  AUDUSD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 27
# 50
# Accuracy is  54.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  NZDUSD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  GBPCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  CHFJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  CADCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  AUDCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  NZDCHF
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURGBP
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  GBPJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  GBPCAD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  GBPAUD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURCAD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURAUD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  EURNZD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 25
# 50
# Accuracy is  50.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  CADJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 27
# 50
# Accuracy is  54.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  AUDJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  NZDJPY
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  AUDCAD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 26
# 50
# Accuracy is  52.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  NZDCAD
# step_down  0
# step_down  1
# step_down  2
# step_down  3
# step_down  4
# step_down  5
# step_down  6
# step_down  7
# step_down  8
# step_down  9
# step_down  10
# step_down  11
# step_down  12
# step_down  13
# step_down  14
# step_down  15
# step_down  16
# step_down  17
# step_down  18
# step_down  19
# step_down  20
# step_down  21
# step_down  22
# step_down  23
# step_down  24
# step_down  25
# step_down  26
# step_down  27
# step_down  28
# step_down  29
# step_down  30
# step_down  31
# step_down  32
# step_down  33
# step_down  34
# step_down  35
# step_down  36
# step_down  37
# step_down  38
# step_down  39
# step_down  40
# step_down  41
# step_down  42
# step_down  43
# step_down  44
# step_down  45
# step_down  46
# step_down  47
# step_down  48
# step_down  49
# 27
# 50
# Accuracy is  54.0 %
# Avereage trade  trade per weeks is  1.0
# ---------------------------------------------------------------feature of is  AUDNZD

# %%
feature_importance = pd.DataFrame(clf.feature_importances_,
                        index = X_train.columns,
                        columns = ['importance']).sort_values('importance', ascending =False)
feature_importance
# Out:
#         importance
# EURCHF    0.060049
# AUDNZD    0.048335
# GBPCAD    0.046675
# AUDCAD    0.044883
# GBPUSD    0.043597
# NZDCAD    0.042850
# USDCAD    0.042461
# GBPCHF    0.041984
# EURGBP    0.041450
# CHFJPY    0.039829
# USDCHF    0.039681
# EURNZD    0.036293
# GBPAUD    0.035443
# NZDUSD    0.034324
# AUDUSD    0.034020
# EURCAD    0.033489
# CADJPY    0.032861
# AUDCHF    0.032389
# EURUSD    0.032103
# NZDJPY    0.031897
# AUDJPY    0.030974
# CADCHF    0.030575
# USDJPY    0.030165
# EURJPY    0.029746
# EURAUD    0.029039
# NZDCHF    0.027720
# GBPJPY    0.027170
