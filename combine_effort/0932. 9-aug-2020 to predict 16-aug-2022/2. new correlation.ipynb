# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-13 22:10:40.712646

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      NZDCAD    0.31253     NZDJPY    0.24661     NZDCAD    0.42857
# 1      GBPUSD    0.26212     EURJPY    0.24456     GBPCHF    0.37284
# 2      USDJPY    0.25000     EURAUD    0.20751     GBPUSD    0.37284
# 3      NZDUSD    0.18021     GBPUSD    0.20751     AUDCAD    0.32733
# 4      AUDCAD    0.16667     CHFJPY    0.19767     AUDUSD    0.32733
# 5      NZDJPY    0.13457     EURGBP    0.17216     NZDJPY    0.31180
# 6      CHFJPY    0.13457     USDJPY    0.17216     EURAUD    0.31180
# 7      USDCHF    0.11580     AUDCAD    0.14833     NZDUSD    0.31180
# 8      EURJPY    0.11580     AUDNZD    0.14833     USDJPY    0.28511
# 9      GBPCHF    0.11580     EURCAD    0.12016     EURGBP    0.28511
# 10     CADJPY    0.09869     NZDUSD    0.12016     NZDCHF    0.21822
# 11     EURCAD    0.08165     GBPCHF    0.12016     AUDCHF    0.19048
# 12     CADCHF    0.08165     GBPCAD    0.12016     USDCAD    0.15352
# 13     NZDCHF    0.08165     NZDCAD    0.10702     GBPJPY    0.15352
# 14     EURCHF    0.08165     EURNZD    0.08472     EURCAD    0.13363
# 15     AUDJPY    0.06804     CADJPY    0.06917     EURNZD    0.13363
# 16     AUDUSD    0.06580     EURCHF    0.06917     GBPCAD    0.06580
# 17     EURUSD    0.06580     GBPJPY    0.06917     GBPAUD    0.06580
# 18     USDCAD    0.06553     AUDUSD    0.05648     USDCHF    0.04762
# 19     AUDCHF    0.04963     AUDJPY    0.05648     EURJPY    0.04762
# 20     EURGBP    0.04903     GBPAUD    0.03257     AUDJPY    0.02288
# 21     EURNZD    0.03269     CADCHF    0.03257     CHFJPY    0.02288
# 22     GBPAUD    0.01645     NZDCHF    0.03257     EURCHF    0.02288
# 23     GBPCAD    0.01645     EURUSD    0.03257     EURUSD    0.02288
# 24     EURAUD    0.01638     USDCAD    0.01849     AUDNZD    0.02288
# 25     GBPJPY    0.01638     AUDCHF    0.01849     CADCHF    0.00000
# 26     AUDNZD    0.00000     USDCHF    0.00478     CADJPY    0.00000
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDJPY    0.40825     USDCHF        0.0  ...     GBPCAD    0.42767
# 1      NZDCAD    0.35355     GBPUSD        0.0  ...     AUDUSD    0.34542
# 2      NZDUSD    0.35355     EURUSD        0.0  ...     GBPUSD    0.31127
# 3      AUDUSD    0.25000     USDJPY        0.0  ...     GBPCHF    0.29778
# 4      AUDCAD    0.25000     USDCAD        0.0  ...     EURUSD    0.26318
# 5      GBPCAD    0.20045     AUDUSD        0.0  ...     USDJPY    0.25000
# 6      USDJPY    0.20045     NZDUSD        0.0  ...     AUDCAD    0.25000
# 7      GBPCHF    0.20045     GBPCHF        0.0  ...     EURCHF    0.24495
# 8      NZDCHF    0.20045     EURCHF        0.0  ...     EURCAD    0.24495
# 9      CADCHF    0.20045     CHFJPY        0.0  ...     CADCHF    0.24495
# 10     USDCHF    0.16667     CADCHF        0.0  ...     AUDCHF    0.21506
# 11     EURJPY    0.16667     AUDCHF        0.0  ...     EURGBP    0.19612
# 12     EURAUD    0.13363     NZDCHF        0.0  ...     GBPAUD    0.18094
# 13     GBPUSD    0.13363     EURGBP        0.0  ...     NZDCAD    0.18094
# 14     EURUSD    0.07538     GBPJPY        0.0  ...     GBPJPY    0.14744
# 15     CHFJPY    0.07538     GBPCAD        0.0  ...     EURJPY    0.13234
# 16     CADJPY    0.06804     GBPAUD        0.0  ...     USDCHF    0.13234
# 17     EURNZD    0.06804     EURJPY        0.0  ...     EURAUD    0.06553
# 18     AUDNZD    0.06804     EURCAD        0.0  ...     NZDUSD    0.06553
# 19     GBPAUD    0.06804     EURAUD        0.0  ...     CHFJPY    0.05046
# 20     GBPJPY    0.06804     EURNZD        0.0  ...     NZDJPY    0.05046
# 21     USDCAD    0.06804     CADJPY        0.0  ...     EURNZD    0.03269
# 22     EURCAD    0.00000     AUDJPY        0.0  ...     AUDJPY    0.01701
# 23     AUDJPY    0.00000     NZDJPY        0.0  ...     CADJPY    0.01645
# 24     AUDCHF    0.00000     AUDCAD        0.0  ...     USDCAD    0.01638
# 25     EURCHF    0.00000     NZDCAD        0.0  ...     NZDCHF    0.00000
# 26     EURGBP    0.00000     AUDNZD        0.0  ...     AUDNZD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      USDJPY    0.52579     USDJPY    0.59216     USDJPY    0.66144
# 1      CHFJPY    0.33887     NZDCHF    0.43644     NZDCHF    0.47246
# 2      GBPCHF    0.29579     GBPAUD    0.37284     CHFJPY    0.42640
# 3      GBPCAD    0.25882     NZDJPY    0.31180     EURAUD    0.37796
# 4      EURGBP    0.24661     EURAUD    0.31180     USDCHF    0.35355
# 5      NZDJPY    0.24661     USDCHF    0.28571     EURJPY    0.35355
# 6      EURJPY    0.24456     AUDJPY    0.25163     NZDJPY    0.28868
# 7      GBPUSD    0.20751     CHFJPY    0.25163     EURNZD    0.28868
# 8      EURCHF    0.20751     CADCHF    0.21822     GBPJPY    0.28868
# 9      AUDJPY    0.19767     NZDCAD    0.19048     GBPAUD    0.28868
# 10     GBPAUD    0.17216     EURJPY    0.19048     NZDUSD    0.20000
# 11     AUDCAD    0.13876     AUDCHF    0.19048     AUDJPY    0.20000
# 12     USDCHF    0.13876     GBPJPY    0.15352     AUDCHF    0.20000
# 13     AUDCHF    0.12016     EURGBP    0.15352     NZDCAD    0.20000
# 14     EURCAD    0.12016     EURNZD    0.13363     GBPCHF    0.18898
# 15     AUDUSD    0.08472     EURCAD    0.08909     CADCHF    0.18898
# 16     GBPJPY    0.06917     NZDUSD    0.08909     EURUSD    0.10660
# 17     EURAUD    0.06917     GBPUSD    0.06580     EURCAD    0.10000
# 18     CADJPY    0.06917     GBPCAD    0.06580     EURGBP    0.10000
# 19     EURNZD    0.05648     GBPCHF    0.06580     EURCHF    0.10000
# 20     NZDCHF    0.03257     USDCAD    0.06580     GBPCAD    0.09449
# 21     CADCHF    0.03257     AUDUSD    0.05455     GBPUSD    0.09449
# 22     EURUSD    0.03257     AUDCAD    0.05455     CADJPY    0.00000
# 23     NZDCAD    0.03257     EURCHF    0.02288     AUDUSD    0.00000
# 24     NZDUSD    0.01849     EURUSD    0.02288     AUDCAD    0.00000
# 25     USDCAD    0.01849     AUDNZD    0.02288     USDCAD    0.00000
# 26     AUDNZD    0.00478     CADJPY    0.00000     AUDNZD    0.00000
#
#    AUDNZD__10  AUDNZD_10
# 0      EURNZD    0.80178
# 1      NZDCHF    0.80178
# 2      USDJPY    0.65465
# 3      NZDJPY    0.65465
# 4      EURAUD    0.65465
# 5      GBPJPY    0.53452
# 6      NZDCAD    0.53452
# 7      NZDUSD    0.53452
# 8      USDCHF    0.50918
# 9      AUDJPY    0.42857
# 10     CHFJPY    0.42857
# 11     AUDCHF    0.42857
# 12     GBPCAD    0.42857
# 13     EURCAD    0.35635
# 14     EURGBP    0.35635
# 15     CADCHF    0.35635
# 16     GBPCHF    0.35635
# 17     AUDNZD    0.35635
# 18     EURJPY    0.32733
# 19     AUDUSD    0.32733
# 20     AUDCAD    0.32733
# 21     EURUSD    0.32733
# 22     GBPUSD    0.21822
# 23     GBPAUD    0.21822
# 24     CADJPY    0.08909
# 25     USDCAD    0.08909
# 26     EURCHF    0.04762
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
