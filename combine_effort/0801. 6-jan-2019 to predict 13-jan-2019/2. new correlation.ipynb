# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime

# %%
q = 0
last_trial_time = datetime.now()
while q < 1:
    
    print(last_trial_time)
    control_dataframe = pd.read_csv('control.csv' ) 
    
    if control_dataframe['classify'].iloc[:1].values == 1:     
        
        q = q+1
        
        
        
    else:  
        last_trial_time = datetime.now()
        time.sleep(60)
# Out:
# 2021-12-08 16:19:34.925290

# %%
currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]
print('---------------- Script Has Started Execution-----------------------')
# Out:
# ---------------- Script Has Started Execution-----------------------

# %%
# declare the variable to hold all corelation data
combine_correlation_data = pd.DataFrame()

#loop through all currency
for z in currency_pairs:
    
    current_currency = z.replace('10080','')
    raw_data = pd.read_csv('files/' + current_currency + '.csv'  ) 
    
    
    weeks = [50, 30, 20, 15, 10]
    
    #loop through all availale weeks
    for y in weeks:
        
        currency_list = []
        correlation_score = []
        
        #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
        for x in currency_pairs:          

            #duplicates the raw data to work with
            current_data = raw_data.copy()
            
            #returns on the the amount of rows of weeks needed to perform correlation on
            current_data = current_data.head(y)
            
            #returns the two columns that correlation is being calculated for
            new_df = current_data[['nextweek_'+ current_currency, x.replace('10080','')]]

            correlation = new_df.corr()
            correlation = correlation[x.replace('10080','')][0:1].values[0]
            
            #gets the absolute value of the correlation to 5 digit number
            correlation = abs(round(correlation, 5))
            
            #apppends the current currency and the corelation values to their respective lists
            currency_list.append(x.replace('10080',''))
            correlation_score.append(correlation)
            
            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score
            
            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)
        
            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)
            
        # add the current_currency dataframe to the global dataframe
        combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
        #print(len(correlation_score))
    
print(combine_correlation_data)


# save global dataframe to csv
combine_correlation_data.to_csv('files/auto-correlation2.csv', index=False)
# Out:
#    USDCHF__50  USDCHF_50 USDCHF__30  USDCHF_30 USDCHF__20  USDCHF_20  \
# 0      AUDCHF    0.24495     GBPJPY    0.33634     NZDUSD    0.30151
# 1      CADCHF    0.24495     EURJPY    0.31175     USDCAD    0.28511
# 2      GBPJPY    0.18021     USDCHF    0.30208     USDCHF    0.21212
# 3      AUDUSD    0.14744     EURCHF    0.27866     GBPAUD    0.21212
# 4      EURCHF    0.14744     NZDJPY    0.26068     AUDCAD    0.21212
# 5      GBPAUD    0.13074     USDJPY    0.20180     AUDUSD    0.21212
# 6      EURGBP    0.11440     NZDCHF    0.20180     CADCHF    0.21212
# 7      GBPUSD    0.11440     AUDJPY    0.20180     GBPUSD    0.21212
# 8      NZDJPY    0.09869     GBPCHF    0.18552     NZDJPY    0.19192
# 9      NZDCAD    0.09829     GBPAUD    0.14382     EURJPY    0.17911
# 10     EURAUD    0.09829     NZDUSD    0.12585     EURCHF    0.12309
# 11     USDCHF    0.08333     CADJPY    0.12585     EURCAD    0.12309
# 12     EURUSD    0.08333     GBPUSD    0.12585     NZDCAD    0.10050
# 13     GBPCAD    0.08165     USDCAD    0.10985     AUDJPY    0.10050
# 14     CHFJPY    0.06580     AUDCAD    0.10702     EURGBP    0.10050
# 15     AUDJPY    0.06553     EURCAD    0.08597     GBPJPY    0.10050
# 16     USDJPY    0.06553     EURAUD    0.06727     NZDCHF    0.10050
# 17     USDCAD    0.04963     CADCHF    0.06727     USDJPY    0.10050
# 18     AUDCAD    0.04963     AUDUSD    0.06727     EURAUD    0.08206
# 19     CADJPY    0.04903     NZDCAD    0.06727     CADJPY    0.08206
# 20     EURJPY    0.03364     EURNZD    0.06727     CHFJPY    0.08206
# 21     NZDCHF    0.03269     EURGBP    0.04977     GBPCHF    0.08206
# 22     NZDUSD    0.03269     EURUSD    0.04977     EURUSD    0.08206
# 23     AUDNZD    0.03269     CHFJPY    0.03257     GBPCAD    0.03161
# 24     GBPCHF    0.01645     GBPCAD    0.00899     AUDCHF    0.01010
# 25     EURCAD    0.01638     AUDCHF    0.00899     EURNZD    0.01010
# 26     EURNZD    0.00000     AUDNZD    0.00899     AUDNZD    0.01010
#
#    USDCHF__15  USDCHF_15 USDCHF__10  USDCHF_10  ... AUDNZD__50  AUDNZD_50  \
# 0      NZDUSD    0.32733     CHFJPY    0.65465  ...     EURCAD    0.23775
# 1      USDCHF    0.28868     NZDCHF    0.60000  ...     NZDUSD    0.20192
# 2      USDCAD    0.27217     EURNZD    0.60000  ...     EURJPY    0.17485
# 3      CHFJPY    0.21822     NZDUSD    0.60000  ...     EURNZD    0.16013
# 4      NZDCAD    0.21822     USDCAD    0.50000  ...     GBPJPY    0.15743
# 5      EURNZD    0.21822     USDCHF    0.40825  ...     NZDJPY    0.12581
# 6      EURCAD    0.21822     NZDCAD    0.40825  ...     GBPAUD    0.12179
# 7      NZDCHF    0.21822     NZDJPY    0.40825  ...     EURGBP    0.11859
# 8      CADCHF    0.21822     EURAUD    0.40825  ...     CHFJPY    0.11613
# 9      AUDNZD    0.21822     EURCAD    0.40825  ...     AUDCAD    0.08760
# 10     AUDUSD    0.21822     GBPCAD    0.40825  ...     AUDUSD    0.08353
# 11     USDJPY    0.21822     AUDNZD    0.40825  ...     CADCHF    0.08006
# 12     NZDJPY    0.16667     AUDCHF    0.40825  ...     AUDCHF    0.08006
# 13     GBPUSD    0.16667     AUDUSD    0.40825  ...     EURAUD    0.07711
# 14     GBPCAD    0.16667     CADCHF    0.21822  ...     USDJPY    0.07711
# 15     EURJPY    0.12309     EURJPY    0.21822  ...     NZDCAD    0.07711
# 16     AUDCHF    0.11111     GBPCHF    0.21822  ...     USDCAD    0.07462
# 17     EURCHF    0.11111     GBPAUD    0.20000  ...     USDCHF    0.04903
# 18     GBPAUD    0.05455     EURCHF    0.20000  ...     CADJPY    0.04167
# 19     AUDJPY    0.05455     AUDJPY    0.20000  ...     GBPUSD    0.03846
# 20     GBPCHF    0.05455     USDJPY    0.20000  ...     NZDCHF    0.03846
# 21     AUDCAD    0.05455     GBPUSD    0.00000  ...     AUDNZD    0.03846
# 22     EURGBP    0.05455     GBPJPY    0.00000  ...     GBPCHF    0.03548
# 23     EURAUD    0.00000     CADJPY    0.00000  ...     EURUSD    0.03269
# 24     GBPJPY    0.00000     AUDCAD    0.00000  ...     AUDJPY    0.00321
# 25     CADJPY    0.00000     EURUSD    0.00000  ...     EURCHF    0.00321
# 26     EURUSD    0.00000     EURGBP    0.00000  ...     GBPCAD    0.00000
#
#    AUDNZD__30  AUDNZD_30 AUDNZD__20  AUDNZD_20 AUDNZD__15  AUDNZD_15  \
# 0      GBPAUD    0.40089     EURCAD    0.40825     USDCAD    0.53452
# 1      EURJPY    0.34586     USDJPY    0.40000     EURUSD    0.47246
# 2      EURCAD    0.33634     EURJPY    0.31449     GBPAUD    0.46429
# 3      USDJPY    0.33333     GBPAUD    0.30151     USDJPY    0.33929
# 4      CHFJPY    0.20751     USDCAD    0.21822     EURCAD    0.33929
# 5      EURGBP    0.20180     EURUSD    0.20412     CHFJPY    0.33929
# 6      AUDJPY    0.20000     CHFJPY    0.20412     EURJPY    0.26189
# 7      EURNZD    0.20000     CADJPY    0.20412     EURCHF    0.21822
# 8      USDCHF    0.13608     EURAUD    0.20412     GBPCHF    0.19643
# 9      USDCAD    0.13608     NZDUSD    0.20000     AUDCAD    0.19643
# 10     EURCHF    0.13363     AUDJPY    0.20000     EURAUD    0.18898
# 11     GBPCAD    0.13363     GBPCAD    0.10483     USDCHF    0.18898
# 12     NZDJPY    0.13363     USDCHF    0.10050     CADJPY    0.09449
# 13     CADJPY    0.13363     AUDCAD    0.10050     GBPJPY    0.09449
# 14     NZDUSD    0.13363     NZDJPY    0.10050     AUDJPY    0.07143
# 15     AUDNZD    0.13363     EURNZD    0.10050     EURNZD    0.07143
# 16     GBPUSD    0.13363     AUDNZD    0.10050     NZDCAD    0.07143
# 17     AUDCAD    0.06917     GBPUSD    0.10050     EURGBP    0.07143
# 18     GBPCHF    0.06727     AUDCHF    0.10050     NZDCHF    0.07143
# 19     EURUSD    0.06727     CADCHF    0.10050     CADCHF    0.07143
# 20     GBPJPY    0.06667     AUDUSD    0.10050     NZDUSD    0.07143
# 21     CADCHF    0.06667     GBPJPY    0.00000     AUDUSD    0.07143
# 22     EURAUD    0.06667     NZDCHF    0.00000     AUDNZD    0.07143
# 23     NZDCHF    0.06667     EURCHF    0.00000     GBPCAD    0.05455
# 24     NZDCAD    0.06667     GBPCHF    0.00000     GBPUSD    0.05455
# 25     AUDUSD    0.06667     NZDCAD    0.00000     AUDCHF    0.05455
# 26     AUDCHF    0.00000     EURGBP    0.00000     NZDJPY    0.05455
#
#    AUDNZD__10  AUDNZD_10
# 0      USDJPY    1.00000
# 1      EURUSD    0.81650
# 2      CHFJPY    0.65465
# 3      EURJPY    0.65465
# 4      AUDJPY    0.60000
# 5      GBPAUD    0.60000
# 6      GBPJPY    0.50000
# 7      USDCAD    0.50000
# 8      USDCHF    0.40825
# 9      AUDCAD    0.40825
# 10     NZDJPY    0.40825
# 11     CADJPY    0.40825
# 12     EURAUD    0.40825
# 13     EURCAD    0.40825
# 14     EURGBP    0.40825
# 15     GBPUSD    0.40825
# 16     AUDCHF    0.40825
# 17     CADCHF    0.21822
# 18     GBPCHF    0.21822
# 19     NZDCHF    0.20000
# 20     EURNZD    0.20000
# 21     EURCHF    0.20000
# 22     NZDUSD    0.20000
# 23     GBPCAD    0.00000
# 24     AUDUSD    0.00000
# 25     NZDCAD    0.00000
# 26     AUDNZD    0.00000
#
# [27 rows x 270 columns]

# %%
control_dataframe = pd.read_csv('control.csv' ) 
control_dataframe['corelation'].iloc[:1] = 1


print(control_dataframe)
control_dataframe.to_csv('control.csv', index=False)
# Out:
#    classify  corelation  feature  predict  drawdownup
# 0         1           1        0        0           0
