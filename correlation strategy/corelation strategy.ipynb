# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime, timedelta
import ast

all_currency_pairs = ['USDCHF',
                 'GBPUSD', 'EURUSD', 'USDJPY', 'USDCAD', 'AUDUSD', 'NZDUSD',
                 'GBPCHF', 'EURCHF', 'CHFJPY', 'CADCHF', 'AUDCHF', 'NZDCHF', 'EURGBP',
                 'GBPJPY', 'GBPCAD', 'GBPAUD', 'EURJPY', 'EURCAD', 'EURAUD', 'EURNZD',
                'CADJPY', 'AUDJPY', 'NZDJPY', 'AUDCAD', 'NZDCAD', 'AUDNZD'
                ]



headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
raw_df = pd.read_csv("../raw_weekly_data/NZDCAD10080.csv", names = headers )



needed_weeks_df = raw_df.loc[(raw_df['date'] >= "2015.01.01")   ]   

needed_weeks_df = needed_weeks_df.iloc[::-1]

needed_weeks_df = needed_weeks_df.reset_index(drop=True)



available_weeks = needed_weeks_df['date'].values



#print(raw_df)
print(available_weeks)
# Out:
# ['2021.11.28' '2021.11.21' '2021.11.14' '2021.11.07' '2021.10.31'
#  '2021.10.24' '2021.10.17' '2021.10.10' '2021.10.03' '2021.09.26'
#  '2021.09.19' '2021.09.12' '2021.09.05' '2021.08.29' '2021.08.22'
#  '2021.08.15' '2021.08.08' '2021.08.01' '2021.07.25' '2021.07.18'
#  '2021.07.11' '2021.07.04' '2021.06.27' '2021.06.20' '2021.06.13'
#  '2021.06.06' '2021.05.30' '2021.05.23' '2021.05.16' '2021.05.09'
#  '2021.05.02' '2021.04.25' '2021.04.18' '2021.04.11' '2021.04.04'
#  '2021.03.28' '2021.03.21' '2021.03.14' '2021.03.07' '2021.02.28'
#  '2021.02.21' '2021.02.14' '2021.02.07' '2021.01.31' '2021.01.24'
#  '2021.01.17' '2021.01.10' '2021.01.03' '2020.12.27' '2020.12.20'
#  '2020.12.13' '2020.12.06' '2020.11.29' '2020.11.22' '2020.11.15'
#  '2020.11.08' '2020.11.01' '2020.10.25' '2020.10.18' '2020.10.11'
#  '2020.10.04' '2020.09.27' '2020.09.20' '2020.09.13' '2020.09.06'
#  '2020.08.30' '2020.08.23' '2020.08.16' '2020.08.09' '2020.08.02'
#  '2020.07.26' '2020.07.19' '2020.07.12' '2020.07.05' '2020.06.28'
#  '2020.06.21' '2020.06.14' '2020.06.07' '2020.05.31' '2020.05.24'
#  '2020.05.17' '2020.05.10' '2020.05.03' '2020.04.26' '2020.04.19'
#  '2020.04.12' '2020.04.05' '2020.03.29' '2020.03.22' '2020.03.15'
#  '2020.03.08' '2020.03.01' '2020.02.23' '2020.02.16' '2020.02.09'
#  '2020.02.02' '2020.01.26' '2020.01.19' '2020.01.12' '2020.01.05'
#  '2019.12.29' '2019.12.22' '2019.12.15' '2019.12.08' '2019.12.01'
#  '2019.11.24' '2019.11.17' '2019.11.10' '2019.11.03' '2019.10.27'
#  '2019.10.20' '2019.10.13' '2019.10.06' '2019.09.29' '2019.09.22'
#  '2019.09.15' '2019.09.08' '2019.09.01' '2019.08.25' '2019.08.18'
#  '2019.08.11' '2019.08.04' '2019.07.28' '2019.07.21' '2019.07.14'
#  '2019.07.07' '2019.06.30' '2019.06.23' '2019.06.16' '2019.06.09'
#  '2019.06.02' '2019.05.26' '2019.05.19' '2019.05.12' '2019.05.05'
#  '2019.04.28' '2019.04.21' '2019.04.14' '2019.04.07' '2019.03.31'
#  '2019.03.24' '2019.03.17' '2019.03.10' '2019.03.03' '2019.02.24'
#  '2019.02.17' '2019.02.10' '2019.02.03' '2019.01.27' '2019.01.20'
#  '2019.01.13' '2019.01.06' '2018.12.30' '2018.12.23' '2018.12.16'
#  '2018.12.09' '2018.12.02' '2018.11.25' '2018.11.18' '2018.11.11'
#  '2018.11.04' '2018.10.28' '2018.10.21' '2018.10.14' '2018.10.07'
#  '2018.09.30' '2018.09.23' '2018.09.16' '2018.09.09' '2018.09.02'
#  '2018.08.26' '2018.08.19' '2018.08.12' '2018.08.05' '2018.07.29'
#  '2018.07.22' '2018.07.15' '2018.07.08' '2018.07.01' '2018.06.24'
#  '2018.06.17' '2018.06.10' '2018.06.03' '2018.05.27' '2018.05.20'
#  '2018.05.13' '2018.05.06' '2018.04.29' '2018.04.22' '2018.04.15'
#  '2018.04.08' '2018.04.01' '2018.03.25' '2018.03.18' '2018.03.11'
#  '2018.03.04' '2018.02.25' '2018.02.18' '2018.02.11' '2018.02.04'
#  '2018.01.28' '2018.01.21' '2018.01.14' '2018.01.07' '2017.12.31'
#  '2017.12.24' '2017.12.17' '2017.12.10' '2017.12.03' '2017.11.26'
#  '2017.11.19' '2017.11.12' '2017.11.05' '2017.10.29' '2017.10.22'
#  '2017.10.15' '2017.10.08' '2017.10.01' '2017.09.24' '2017.09.17'
#  '2017.09.10' '2017.09.03' '2017.08.27' '2017.08.20' '2017.08.13'
#  '2017.08.06' '2017.07.30' '2017.07.23' '2017.07.16' '2017.07.09'
#  '2017.07.02' '2017.06.25' '2017.06.18' '2017.06.11' '2017.06.04'
#  '2017.05.28' '2017.05.21' '2017.05.14' '2017.05.07' '2017.04.30'
#  '2017.04.23' '2017.04.16' '2017.04.09' '2017.04.02' '2017.03.26'
#  '2017.03.19' '2017.03.05' '2017.02.26' '2017.02.19' '2017.02.12'
#  '2017.02.05' '2017.01.29' '2017.01.22' '2017.01.15' '2017.01.08'
#  '2017.01.01' '2016.12.25' '2016.12.18' '2016.12.11' '2016.12.04'
#  '2016.11.27' '2016.11.20' '2016.11.13' '2016.11.06' '2016.10.30'
#  '2016.10.23' '2016.10.16' '2016.10.09' '2016.10.02' '2016.09.25'
#  '2016.09.18' '2016.09.11' '2016.09.04' '2016.08.28' '2016.08.21'
#  '2016.08.14' '2016.08.07' '2016.07.31' '2016.07.24' '2016.07.17'
#  '2016.07.10' '2016.07.03' '2016.06.26' '2016.06.19' '2016.06.12'
#  '2016.06.05' '2016.05.29' '2016.05.22' '2016.05.15' '2016.05.08'
#  '2016.05.01' '2016.04.24' '2016.04.17' '2016.04.10' '2016.04.03'
#  '2016.03.27' '2016.03.20' '2016.03.13' '2016.03.06' '2016.02.28'
#  '2016.02.21' '2016.02.14' '2016.02.07' '2016.01.31' '2016.01.24'
#  '2016.01.17' '2016.01.10' '2016.01.03' '2015.12.27' '2015.12.20'
#  '2015.12.13' '2015.12.06' '2015.11.29' '2015.11.22' '2015.11.15'
#  '2015.11.08' '2015.11.01' '2015.10.25' '2015.10.18' '2015.10.11'
#  '2015.10.04' '2015.09.27' '2015.09.20' '2015.09.13' '2015.09.06'
#  '2015.08.30' '2015.08.23' '2015.08.16' '2015.08.09' '2015.08.02'
#  '2015.07.26' '2015.07.19' '2015.07.12' '2015.07.05' '2015.06.28'
#  '2015.06.21' '2015.06.14' '2015.06.07' '2015.05.31' '2015.05.24'
#  '2015.05.17' '2015.05.10' '2015.05.03' '2015.04.26' '2015.04.19'
#  '2015.04.12' '2015.04.05' '2015.03.29' '2015.03.22' '2015.03.15'
#  '2015.03.08' '2015.03.01' '2015.02.22' '2015.02.15' '2015.02.08'
#  '2015.02.01' '2015.01.25' '2015.01.18' '2015.01.11' '2015.01.04']

# %%
for y in available_weeks:
    
    current_date = datetime.strptime(y, '%Y.%m.%d').strftime('%A')
    
    if current_date != 'Sunday':
       
        print('error-----------------------------', y, '  is not a sunday')
        
        raise Exception('error-----------------------------', y, ' did is not a sunday')

# %%
for a in available_weeks:
  
  
    path = "./files/" + a

    try: 
        os.makedirs(path)
        control_file = pd.DataFrame()
        
        for  b in range(8):
            control_file['control' + str(b)] = -1
            
            
        control_file.to_csv(path + '/control.csv')
        
        

    except OSError as error: 
         raise Exception(error)

# %%
# classif historical currency data

raw_currency_pair_classification_df = []

for a in all_currency_pairs:
    
    classification_df = pd.DataFrame()
    
    classification_score =[]
    
    current_currency_df = pd.read_csv("../raw_weekly_data/" + a + "10080.csv", names = headers ) 
        
        
    current_currency_df = current_currency_df.loc[(current_currency_df['date'] >= '2014.01.01' ) ]
    
    current_currency_df = current_currency_df.iloc[::-1]   
        
    current_currency_df = current_currency_df.reset_index(drop=True)
    
    classification_df['date'] = current_currency_df['date']
    
    
    for b in (range(len(current_currency_df.index))):
            
            row = current_currency_df.loc[b,:]
                            
            #condition when the curreny movement is a buy
            

            if row.open < row.close:
                
                 classification_score.append(1)
                #print(b, a, row.date, row.open, row.close)
                          
            else:
                
                #print(b, a,row.date, row.open, row.close)
                 classification_score.append(-1)

                    
    
    classification_df['class'] = classification_score
    
    raw_currency_pair_classification_df.append({'name': a, 'data': classification_df })
                    
                    
                    
    #print('------------------------------------------------------------------------------------------',a)
    
    
print(len(raw_currency_pair_classification_df))
# Out:
# 27

# %%
for c in available_weeks :
    
    current_week_classification_df = pd.DataFrame()

    for index, d in enumerate(raw_currency_pair_classification_df):
              
        current_currency = d['name']

        current_currency_df = d['data']
        #print(d)
        
        
        current_currency_df = current_currency_df.loc[(current_currency_df['date'] <= c ) ]
        
        current_currency_df = current_currency_df.reset_index(drop=True)
                
        current_currency_df = current_currency_df.head(52)   
         
        #print(c, d['name'],current_currency_df)  
        
        
        if index == 0 :
            
            current_week_classification_df['date'] = current_currency_df['date']
        
    
        current_week_classification_df[current_currency] = current_currency_df['class']
    
    
    
    #print(current_week_classification_df)   

    print('-----------------------------------------------------------------------------------------------------' , c )

    
    # creating dataframe with next week for each currency
    
    for index, e in enumerate(all_currency_pairs):
        
        
        current_week_classification_dataframe = current_week_classification_df.copy()
        
        current_currency_list = current_week_classification_dataframe[e].values.tolist()
        
        current_currency_list.insert(0,0)
        
        current_currency_list.pop()
        
        
        
        current_week_classification_dataframe['nextweek_'+ e] = current_currency_list
        
        if index == 0:
        
            currrent_week_values_df = current_week_classification_dataframe.iloc[:1, :28]


            current_week_values_df = currrent_week_values_df.reset_index(drop =True)

            current_week_values_df.to_csv("files/" + c + "/current_week_values.csv", index = False)

            #print(current_week_values_df)
        
        
        #print(current_week_classification_dataframe)
        
        
        current_week_classification_dataframe = current_week_classification_dataframe.iloc[1:, :]
        
        
        current_week_classification_dataframe = current_week_classification_dataframe.reset_index(drop =True)
        
        
        current_week_classification_dataframe.to_csv("files/" + c + "/"+ e + ".csv", index = False)
        
        #print(current_week_classification_dataframe)
        
        #print(e, )
# Out:
# ----------------------------------------------------------------------------------------------------- 2021.11.28
# ----------------------------------------------------------------------------------------------------- 2021.11.21
# ----------------------------------------------------------------------------------------------------- 2021.11.14
# ----------------------------------------------------------------------------------------------------- 2021.11.07
# ----------------------------------------------------------------------------------------------------- 2021.10.31
# ----------------------------------------------------------------------------------------------------- 2021.10.24
# ----------------------------------------------------------------------------------------------------- 2021.10.17
# ----------------------------------------------------------------------------------------------------- 2021.10.10
# ----------------------------------------------------------------------------------------------------- 2021.10.03
# ----------------------------------------------------------------------------------------------------- 2021.09.26
# ----------------------------------------------------------------------------------------------------- 2021.09.19
# ----------------------------------------------------------------------------------------------------- 2021.09.12
# ----------------------------------------------------------------------------------------------------- 2021.09.05
# ----------------------------------------------------------------------------------------------------- 2021.08.29
# ----------------------------------------------------------------------------------------------------- 2021.08.22
# ----------------------------------------------------------------------------------------------------- 2021.08.15
# ----------------------------------------------------------------------------------------------------- 2021.08.08
# ----------------------------------------------------------------------------------------------------- 2021.08.01
# ----------------------------------------------------------------------------------------------------- 2021.07.25
# ----------------------------------------------------------------------------------------------------- 2021.07.18
# ----------------------------------------------------------------------------------------------------- 2021.07.11
# ----------------------------------------------------------------------------------------------------- 2021.07.04
# ----------------------------------------------------------------------------------------------------- 2021.06.27
# ----------------------------------------------------------------------------------------------------- 2021.06.20
# ----------------------------------------------------------------------------------------------------- 2021.06.13
# ----------------------------------------------------------------------------------------------------- 2021.06.06
# ----------------------------------------------------------------------------------------------------- 2021.05.30
# ----------------------------------------------------------------------------------------------------- 2021.05.23
# ----------------------------------------------------------------------------------------------------- 2021.05.16
# ----------------------------------------------------------------------------------------------------- 2021.05.09
# ----------------------------------------------------------------------------------------------------- 2021.05.02
# ----------------------------------------------------------------------------------------------------- 2021.04.25
# ----------------------------------------------------------------------------------------------------- 2021.04.18
# ----------------------------------------------------------------------------------------------------- 2021.04.11
# ----------------------------------------------------------------------------------------------------- 2021.04.04
# ----------------------------------------------------------------------------------------------------- 2021.03.28
# ----------------------------------------------------------------------------------------------------- 2021.03.21
# ----------------------------------------------------------------------------------------------------- 2021.03.14
# ----------------------------------------------------------------------------------------------------- 2021.03.07
# ----------------------------------------------------------------------------------------------------- 2021.02.28
# ----------------------------------------------------------------------------------------------------- 2021.02.21
# ----------------------------------------------------------------------------------------------------- 2021.02.14
# ----------------------------------------------------------------------------------------------------- 2021.02.07
# ----------------------------------------------------------------------------------------------------- 2021.01.31
# ----------------------------------------------------------------------------------------------------- 2021.01.24
# ----------------------------------------------------------------------------------------------------- 2021.01.17
# ----------------------------------------------------------------------------------------------------- 2021.01.10
# ----------------------------------------------------------------------------------------------------- 2021.01.03
# ----------------------------------------------------------------------------------------------------- 2020.12.27
# ----------------------------------------------------------------------------------------------------- 2020.12.20
# ----------------------------------------------------------------------------------------------------- 2020.12.13
# ----------------------------------------------------------------------------------------------------- 2020.12.06
# ----------------------------------------------------------------------------------------------------- 2020.11.29
# ----------------------------------------------------------------------------------------------------- 2020.11.22
# ----------------------------------------------------------------------------------------------------- 2020.11.15
# ----------------------------------------------------------------------------------------------------- 2020.11.08
# ----------------------------------------------------------------------------------------------------- 2020.11.01
# ----------------------------------------------------------------------------------------------------- 2020.10.25
# ----------------------------------------------------------------------------------------------------- 2020.10.18
# ----------------------------------------------------------------------------------------------------- 2020.10.11
# ----------------------------------------------------------------------------------------------------- 2020.10.04
# ----------------------------------------------------------------------------------------------------- 2020.09.27
# ----------------------------------------------------------------------------------------------------- 2020.09.20
# ----------------------------------------------------------------------------------------------------- 2020.09.13
# ----------------------------------------------------------------------------------------------------- 2020.09.06
# ----------------------------------------------------------------------------------------------------- 2020.08.30
# ----------------------------------------------------------------------------------------------------- 2020.08.23
# ----------------------------------------------------------------------------------------------------- 2020.08.16
# ----------------------------------------------------------------------------------------------------- 2020.08.09
# ----------------------------------------------------------------------------------------------------- 2020.08.02
# ----------------------------------------------------------------------------------------------------- 2020.07.26
# ----------------------------------------------------------------------------------------------------- 2020.07.19
# ----------------------------------------------------------------------------------------------------- 2020.07.12
# ----------------------------------------------------------------------------------------------------- 2020.07.05
# ----------------------------------------------------------------------------------------------------- 2020.06.28
# ----------------------------------------------------------------------------------------------------- 2020.06.21
# ----------------------------------------------------------------------------------------------------- 2020.06.14
# ----------------------------------------------------------------------------------------------------- 2020.06.07
# ----------------------------------------------------------------------------------------------------- 2020.05.31
# ----------------------------------------------------------------------------------------------------- 2020.05.24
# ----------------------------------------------------------------------------------------------------- 2020.05.17
# ----------------------------------------------------------------------------------------------------- 2020.05.10
# ----------------------------------------------------------------------------------------------------- 2020.05.03
# ----------------------------------------------------------------------------------------------------- 2020.04.26
# ----------------------------------------------------------------------------------------------------- 2020.04.19
# ----------------------------------------------------------------------------------------------------- 2020.04.12
# ----------------------------------------------------------------------------------------------------- 2020.04.05
# ----------------------------------------------------------------------------------------------------- 2020.03.29
# ----------------------------------------------------------------------------------------------------- 2020.03.22
# ----------------------------------------------------------------------------------------------------- 2020.03.15
# ----------------------------------------------------------------------------------------------------- 2020.03.08
# ----------------------------------------------------------------------------------------------------- 2020.03.01
# ----------------------------------------------------------------------------------------------------- 2020.02.23
# ----------------------------------------------------------------------------------------------------- 2020.02.16
# ----------------------------------------------------------------------------------------------------- 2020.02.09
# ----------------------------------------------------------------------------------------------------- 2020.02.02
# ----------------------------------------------------------------------------------------------------- 2020.01.26
# ----------------------------------------------------------------------------------------------------- 2020.01.19
# ----------------------------------------------------------------------------------------------------- 2020.01.12
# ----------------------------------------------------------------------------------------------------- 2020.01.05
# ----------------------------------------------------------------------------------------------------- 2019.12.29
# ----------------------------------------------------------------------------------------------------- 2019.12.22
# ----------------------------------------------------------------------------------------------------- 2019.12.15
# ----------------------------------------------------------------------------------------------------- 2019.12.08
# ----------------------------------------------------------------------------------------------------- 2019.12.01
# ----------------------------------------------------------------------------------------------------- 2019.11.24
# ----------------------------------------------------------------------------------------------------- 2019.11.17
# ----------------------------------------------------------------------------------------------------- 2019.11.10
# ----------------------------------------------------------------------------------------------------- 2019.11.03
# ----------------------------------------------------------------------------------------------------- 2019.10.27
# ----------------------------------------------------------------------------------------------------- 2019.10.20
# ----------------------------------------------------------------------------------------------------- 2019.10.13
# ----------------------------------------------------------------------------------------------------- 2019.10.06
# ----------------------------------------------------------------------------------------------------- 2019.09.29
# ----------------------------------------------------------------------------------------------------- 2019.09.22
# ----------------------------------------------------------------------------------------------------- 2019.09.15
# ----------------------------------------------------------------------------------------------------- 2019.09.08
# ----------------------------------------------------------------------------------------------------- 2019.09.01
# ----------------------------------------------------------------------------------------------------- 2019.08.25
# ----------------------------------------------------------------------------------------------------- 2019.08.18
# ----------------------------------------------------------------------------------------------------- 2019.08.11
# ----------------------------------------------------------------------------------------------------- 2019.08.04
# ----------------------------------------------------------------------------------------------------- 2019.07.28
# ----------------------------------------------------------------------------------------------------- 2019.07.21
# ----------------------------------------------------------------------------------------------------- 2019.07.14
# ----------------------------------------------------------------------------------------------------- 2019.07.07
# ----------------------------------------------------------------------------------------------------- 2019.06.30
# ----------------------------------------------------------------------------------------------------- 2019.06.23
# ----------------------------------------------------------------------------------------------------- 2019.06.16
# ----------------------------------------------------------------------------------------------------- 2019.06.09
# ----------------------------------------------------------------------------------------------------- 2019.06.02
# ----------------------------------------------------------------------------------------------------- 2019.05.26
# ----------------------------------------------------------------------------------------------------- 2019.05.19
# ----------------------------------------------------------------------------------------------------- 2019.05.12
# ----------------------------------------------------------------------------------------------------- 2019.05.05
# ----------------------------------------------------------------------------------------------------- 2019.04.28
# ----------------------------------------------------------------------------------------------------- 2019.04.21
# ----------------------------------------------------------------------------------------------------- 2019.04.14
# ----------------------------------------------------------------------------------------------------- 2019.04.07
# ----------------------------------------------------------------------------------------------------- 2019.03.31
# ----------------------------------------------------------------------------------------------------- 2019.03.24
# ----------------------------------------------------------------------------------------------------- 2019.03.17
# ----------------------------------------------------------------------------------------------------- 2019.03.10
# ----------------------------------------------------------------------------------------------------- 2019.03.03
# ----------------------------------------------------------------------------------------------------- 2019.02.24
# ----------------------------------------------------------------------------------------------------- 2019.02.17
# ----------------------------------------------------------------------------------------------------- 2019.02.10
# ----------------------------------------------------------------------------------------------------- 2019.02.03
# ----------------------------------------------------------------------------------------------------- 2019.01.27
# ----------------------------------------------------------------------------------------------------- 2019.01.20
# ----------------------------------------------------------------------------------------------------- 2019.01.13
# ----------------------------------------------------------------------------------------------------- 2019.01.06
# ----------------------------------------------------------------------------------------------------- 2018.12.30
# ----------------------------------------------------------------------------------------------------- 2018.12.23
# ----------------------------------------------------------------------------------------------------- 2018.12.16
# ----------------------------------------------------------------------------------------------------- 2018.12.09
# ----------------------------------------------------------------------------------------------------- 2018.12.02
# ----------------------------------------------------------------------------------------------------- 2018.11.25
# ----------------------------------------------------------------------------------------------------- 2018.11.18
# ----------------------------------------------------------------------------------------------------- 2018.11.11
# ----------------------------------------------------------------------------------------------------- 2018.11.04
# ----------------------------------------------------------------------------------------------------- 2018.10.28
# ----------------------------------------------------------------------------------------------------- 2018.10.21
# ----------------------------------------------------------------------------------------------------- 2018.10.14
# ----------------------------------------------------------------------------------------------------- 2018.10.07
# ----------------------------------------------------------------------------------------------------- 2018.09.30
# ----------------------------------------------------------------------------------------------------- 2018.09.23
# ----------------------------------------------------------------------------------------------------- 2018.09.16
# ----------------------------------------------------------------------------------------------------- 2018.09.09
# ----------------------------------------------------------------------------------------------------- 2018.09.02
# ----------------------------------------------------------------------------------------------------- 2018.08.26
# ----------------------------------------------------------------------------------------------------- 2018.08.19
# ----------------------------------------------------------------------------------------------------- 2018.08.12
# ----------------------------------------------------------------------------------------------------- 2018.08.05
# ----------------------------------------------------------------------------------------------------- 2018.07.29
# ----------------------------------------------------------------------------------------------------- 2018.07.22
# ----------------------------------------------------------------------------------------------------- 2018.07.15
# ----------------------------------------------------------------------------------------------------- 2018.07.08
# ----------------------------------------------------------------------------------------------------- 2018.07.01
# ----------------------------------------------------------------------------------------------------- 2018.06.24
# ----------------------------------------------------------------------------------------------------- 2018.06.17
# ----------------------------------------------------------------------------------------------------- 2018.06.10
# ----------------------------------------------------------------------------------------------------- 2018.06.03
# ----------------------------------------------------------------------------------------------------- 2018.05.27
# ----------------------------------------------------------------------------------------------------- 2018.05.20
# ----------------------------------------------------------------------------------------------------- 2018.05.13
# ----------------------------------------------------------------------------------------------------- 2018.05.06
# ----------------------------------------------------------------------------------------------------- 2018.04.29
# ----------------------------------------------------------------------------------------------------- 2018.04.22
# ----------------------------------------------------------------------------------------------------- 2018.04.15
# ----------------------------------------------------------------------------------------------------- 2018.04.08
# ----------------------------------------------------------------------------------------------------- 2018.04.01
# ----------------------------------------------------------------------------------------------------- 2018.03.25
# ----------------------------------------------------------------------------------------------------- 2018.03.18
# ----------------------------------------------------------------------------------------------------- 2018.03.11
# ----------------------------------------------------------------------------------------------------- 2018.03.04
# ----------------------------------------------------------------------------------------------------- 2018.02.25
# ----------------------------------------------------------------------------------------------------- 2018.02.18
# ----------------------------------------------------------------------------------------------------- 2018.02.11
# ----------------------------------------------------------------------------------------------------- 2018.02.04
# ----------------------------------------------------------------------------------------------------- 2018.01.28
# ----------------------------------------------------------------------------------------------------- 2018.01.21
# ----------------------------------------------------------------------------------------------------- 2018.01.14
# ----------------------------------------------------------------------------------------------------- 2018.01.07
# ----------------------------------------------------------------------------------------------------- 2017.12.31
# ----------------------------------------------------------------------------------------------------- 2017.12.24
# ----------------------------------------------------------------------------------------------------- 2017.12.17
# ----------------------------------------------------------------------------------------------------- 2017.12.10
# ----------------------------------------------------------------------------------------------------- 2017.12.03
# ----------------------------------------------------------------------------------------------------- 2017.11.26
# ----------------------------------------------------------------------------------------------------- 2017.11.19
# ----------------------------------------------------------------------------------------------------- 2017.11.12
# ----------------------------------------------------------------------------------------------------- 2017.11.05
# ----------------------------------------------------------------------------------------------------- 2017.10.29
# ----------------------------------------------------------------------------------------------------- 2017.10.22
# ----------------------------------------------------------------------------------------------------- 2017.10.15
# ----------------------------------------------------------------------------------------------------- 2017.10.08
# ----------------------------------------------------------------------------------------------------- 2017.10.01
# ----------------------------------------------------------------------------------------------------- 2017.09.24
# ----------------------------------------------------------------------------------------------------- 2017.09.17
# ----------------------------------------------------------------------------------------------------- 2017.09.10
# ----------------------------------------------------------------------------------------------------- 2017.09.03
# ----------------------------------------------------------------------------------------------------- 2017.08.27
# ----------------------------------------------------------------------------------------------------- 2017.08.20
# ----------------------------------------------------------------------------------------------------- 2017.08.13
# ----------------------------------------------------------------------------------------------------- 2017.08.06
# ----------------------------------------------------------------------------------------------------- 2017.07.30
# ----------------------------------------------------------------------------------------------------- 2017.07.23
# ----------------------------------------------------------------------------------------------------- 2017.07.16
# ----------------------------------------------------------------------------------------------------- 2017.07.09
# ----------------------------------------------------------------------------------------------------- 2017.07.02
# ----------------------------------------------------------------------------------------------------- 2017.06.25
# ----------------------------------------------------------------------------------------------------- 2017.06.18
# ----------------------------------------------------------------------------------------------------- 2017.06.11
# ----------------------------------------------------------------------------------------------------- 2017.06.04
# ----------------------------------------------------------------------------------------------------- 2017.05.28
# ----------------------------------------------------------------------------------------------------- 2017.05.21
# ----------------------------------------------------------------------------------------------------- 2017.05.14
# ----------------------------------------------------------------------------------------------------- 2017.05.07
# ----------------------------------------------------------------------------------------------------- 2017.04.30
# ----------------------------------------------------------------------------------------------------- 2017.04.23
# ----------------------------------------------------------------------------------------------------- 2017.04.16
# ----------------------------------------------------------------------------------------------------- 2017.04.09
# ----------------------------------------------------------------------------------------------------- 2017.04.02
# ----------------------------------------------------------------------------------------------------- 2017.03.26
# ----------------------------------------------------------------------------------------------------- 2017.03.19
# ----------------------------------------------------------------------------------------------------- 2017.03.05
# ----------------------------------------------------------------------------------------------------- 2017.02.26
# ----------------------------------------------------------------------------------------------------- 2017.02.19
# ----------------------------------------------------------------------------------------------------- 2017.02.12
# ----------------------------------------------------------------------------------------------------- 2017.02.05
# ----------------------------------------------------------------------------------------------------- 2017.01.29
# ----------------------------------------------------------------------------------------------------- 2017.01.22
# ----------------------------------------------------------------------------------------------------- 2017.01.15
# ----------------------------------------------------------------------------------------------------- 2017.01.08
# ----------------------------------------------------------------------------------------------------- 2017.01.01
# ----------------------------------------------------------------------------------------------------- 2016.12.25
# ----------------------------------------------------------------------------------------------------- 2016.12.18
# ----------------------------------------------------------------------------------------------------- 2016.12.11
# ----------------------------------------------------------------------------------------------------- 2016.12.04
# ----------------------------------------------------------------------------------------------------- 2016.11.27
# ----------------------------------------------------------------------------------------------------- 2016.11.20
# ----------------------------------------------------------------------------------------------------- 2016.11.13
# ----------------------------------------------------------------------------------------------------- 2016.11.06
# ----------------------------------------------------------------------------------------------------- 2016.10.30
# ----------------------------------------------------------------------------------------------------- 2016.10.23
# ----------------------------------------------------------------------------------------------------- 2016.10.16
# ----------------------------------------------------------------------------------------------------- 2016.10.09
# ----------------------------------------------------------------------------------------------------- 2016.10.02
# ----------------------------------------------------------------------------------------------------- 2016.09.25
# ----------------------------------------------------------------------------------------------------- 2016.09.18
# ----------------------------------------------------------------------------------------------------- 2016.09.11
# ----------------------------------------------------------------------------------------------------- 2016.09.04
# ----------------------------------------------------------------------------------------------------- 2016.08.28
# ----------------------------------------------------------------------------------------------------- 2016.08.21
# ----------------------------------------------------------------------------------------------------- 2016.08.14
# ----------------------------------------------------------------------------------------------------- 2016.08.07
# ----------------------------------------------------------------------------------------------------- 2016.07.31
# ----------------------------------------------------------------------------------------------------- 2016.07.24
# ----------------------------------------------------------------------------------------------------- 2016.07.17
# ----------------------------------------------------------------------------------------------------- 2016.07.10
# ----------------------------------------------------------------------------------------------------- 2016.07.03
# ----------------------------------------------------------------------------------------------------- 2016.06.26
# ----------------------------------------------------------------------------------------------------- 2016.06.19
# ----------------------------------------------------------------------------------------------------- 2016.06.12
# ----------------------------------------------------------------------------------------------------- 2016.06.05
# ----------------------------------------------------------------------------------------------------- 2016.05.29
# ----------------------------------------------------------------------------------------------------- 2016.05.22
# ----------------------------------------------------------------------------------------------------- 2016.05.15
# ----------------------------------------------------------------------------------------------------- 2016.05.08
# ----------------------------------------------------------------------------------------------------- 2016.05.01
# ----------------------------------------------------------------------------------------------------- 2016.04.24
# ----------------------------------------------------------------------------------------------------- 2016.04.17
# ----------------------------------------------------------------------------------------------------- 2016.04.10
# ----------------------------------------------------------------------------------------------------- 2016.04.03
# ----------------------------------------------------------------------------------------------------- 2016.03.27
# ----------------------------------------------------------------------------------------------------- 2016.03.20
# ----------------------------------------------------------------------------------------------------- 2016.03.13
# ----------------------------------------------------------------------------------------------------- 2016.03.06
# ----------------------------------------------------------------------------------------------------- 2016.02.28
# ----------------------------------------------------------------------------------------------------- 2016.02.21
# ----------------------------------------------------------------------------------------------------- 2016.02.14
# ----------------------------------------------------------------------------------------------------- 2016.02.07
# ----------------------------------------------------------------------------------------------------- 2016.01.31
# ----------------------------------------------------------------------------------------------------- 2016.01.24
# ----------------------------------------------------------------------------------------------------- 2016.01.17
# ----------------------------------------------------------------------------------------------------- 2016.01.10
# ----------------------------------------------------------------------------------------------------- 2016.01.03
# ----------------------------------------------------------------------------------------------------- 2015.12.27
# ----------------------------------------------------------------------------------------------------- 2015.12.20
# ----------------------------------------------------------------------------------------------------- 2015.12.13
# ----------------------------------------------------------------------------------------------------- 2015.12.06
# ----------------------------------------------------------------------------------------------------- 2015.11.29
# ----------------------------------------------------------------------------------------------------- 2015.11.22
# ----------------------------------------------------------------------------------------------------- 2015.11.15
# ----------------------------------------------------------------------------------------------------- 2015.11.08
# ----------------------------------------------------------------------------------------------------- 2015.11.01
# ----------------------------------------------------------------------------------------------------- 2015.10.25
# ----------------------------------------------------------------------------------------------------- 2015.10.18
# ----------------------------------------------------------------------------------------------------- 2015.10.11
# ----------------------------------------------------------------------------------------------------- 2015.10.04
# ----------------------------------------------------------------------------------------------------- 2015.09.27
# ----------------------------------------------------------------------------------------------------- 2015.09.20
# ----------------------------------------------------------------------------------------------------- 2015.09.13
# ----------------------------------------------------------------------------------------------------- 2015.09.06
# ----------------------------------------------------------------------------------------------------- 2015.08.30
# ----------------------------------------------------------------------------------------------------- 2015.08.23
# ----------------------------------------------------------------------------------------------------- 2015.08.16
# ----------------------------------------------------------------------------------------------------- 2015.08.09
# ----------------------------------------------------------------------------------------------------- 2015.08.02
# ----------------------------------------------------------------------------------------------------- 2015.07.26
# ----------------------------------------------------------------------------------------------------- 2015.07.19
# ----------------------------------------------------------------------------------------------------- 2015.07.12
# ----------------------------------------------------------------------------------------------------- 2015.07.05
# ----------------------------------------------------------------------------------------------------- 2015.06.28
# ----------------------------------------------------------------------------------------------------- 2015.06.21
# ----------------------------------------------------------------------------------------------------- 2015.06.14
# ----------------------------------------------------------------------------------------------------- 2015.06.07
# ----------------------------------------------------------------------------------------------------- 2015.05.31
# ----------------------------------------------------------------------------------------------------- 2015.05.24
# ----------------------------------------------------------------------------------------------------- 2015.05.17
# ----------------------------------------------------------------------------------------------------- 2015.05.10
# ----------------------------------------------------------------------------------------------------- 2015.05.03
# ----------------------------------------------------------------------------------------------------- 2015.04.26
# ----------------------------------------------------------------------------------------------------- 2015.04.19
# ----------------------------------------------------------------------------------------------------- 2015.04.12
# ----------------------------------------------------------------------------------------------------- 2015.04.05
# ----------------------------------------------------------------------------------------------------- 2015.03.29
# ----------------------------------------------------------------------------------------------------- 2015.03.22
# ----------------------------------------------------------------------------------------------------- 2015.03.15
# ----------------------------------------------------------------------------------------------------- 2015.03.08
# ----------------------------------------------------------------------------------------------------- 2015.03.01
# ----------------------------------------------------------------------------------------------------- 2015.02.22
# ----------------------------------------------------------------------------------------------------- 2015.02.15
# ----------------------------------------------------------------------------------------------------- 2015.02.08
# ----------------------------------------------------------------------------------------------------- 2015.02.01
# ----------------------------------------------------------------------------------------------------- 2015.01.25
# ----------------------------------------------------------------------------------------------------- 2015.01.18
# ----------------------------------------------------------------------------------------------------- 2015.01.11
# ----------------------------------------------------------------------------------------------------- 2015.01.04

# %%
#this is the function that calculate the correlation of the data

def correlate(current_week):
    
        # declare the variable to hold all corelation data
    combine_correlation_data = pd.DataFrame()

    #loop through all currency
    for z in all_currency_pairs:

        current_currency = z
        raw_data = pd.read_csv('files/' + current_week + '/' + current_currency + '.csv'  ) 
        
        #print(z, raw_data)

        weeks = [50, 30, 20, 15, 10]

        #loop through all availale weeks
        for y in weeks:

            currency_list = []
            correlation_score = []

            #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
            for x in all_currency_pairs:          

                #duplicates the raw data to work with
                current_data = raw_data.copy()

                #returns on the the amount of rows of weeks needed to perform correlation on
                current_data = current_data.head(y)

                #returns the two columns that correlation is being calculated for
                new_df = current_data[['nextweek_'+ current_currency, x]]
                
                #print(new_df)
                
                correlation = new_df.corr()
                
                #print(correlation)
                correlation = correlation[x][0:1].values[0]
                
                #print(correlation)

                #gets the absolute value of the correlation to 5 digit number
                correlation = abs(round(correlation, 5))
                
                
                #apppends the current currency and the corelation values to their respective lists
                currency_list.append(x)
                correlation_score.append(correlation)

            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score

            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)

            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)

            # add the current_currency dataframe to the global dataframe
            combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
            #print(len(correlation_score))

    #print(combine_correlation_data)
    
    #print(current_week)
    
    


    # save global dataframe to csv
    combine_correlation_data.to_csv('files/' + current_week + '/auto-correlation2.csv', index=False)

# %%
#calls correlation function and creates correlation information for all weeks and save it in each week folder

for f in available_weeks:

    y = correlate(f)
    print(f)
# Out:
# 2021.11.28
# 2021.11.21
# 2021.11.14
# 2021.11.07
# 2021.10.31
# 2021.10.24
# 2021.10.17
# 2021.10.10
# 2021.10.03
# 2021.09.26
# 2021.09.19
# 2021.09.12
# 2021.09.05
# 2021.08.29
# 2021.08.22
# 2021.08.15
# 2021.08.08
# 2021.08.01
# 2021.07.25
# 2021.07.18
# 2021.07.11
# 2021.07.04
# 2021.06.27
# 2021.06.20
# 2021.06.13
# 2021.06.06
# 2021.05.30
# 2021.05.23
# 2021.05.16
# 2021.05.09
# 2021.05.02
# 2021.04.25
# 2021.04.18
# 2021.04.11
# 2021.04.04
# 2021.03.28
# 2021.03.21
# 2021.03.14
# 2021.03.07
# 2021.02.28
# 2021.02.21
# 2021.02.14
# 2021.02.07
# 2021.01.31
# 2021.01.24
# 2021.01.17
# 2021.01.10
# 2021.01.03
# 2020.12.27
# 2020.12.20
# 2020.12.13
# 2020.12.06
# 2020.11.29
# 2020.11.22
# 2020.11.15
# 2020.11.08
# 2020.11.01
# 2020.10.25
# 2020.10.18
# 2020.10.11
# 2020.10.04
# 2020.09.27
# 2020.09.20
# 2020.09.13
# 2020.09.06
# 2020.08.30
# 2020.08.23
# 2020.08.16
# 2020.08.09
# 2020.08.02
# 2020.07.26
# 2020.07.19
# 2020.07.12
# 2020.07.05
# 2020.06.28
# 2020.06.21
# 2020.06.14
# 2020.06.07
# 2020.05.31
# 2020.05.24
# 2020.05.17
# 2020.05.10
# 2020.05.03
# 2020.04.26
# 2020.04.19
# 2020.04.12
# 2020.04.05
# 2020.03.29
# 2020.03.22
# 2020.03.15
# 2020.03.08
# 2020.03.01
# 2020.02.23
# 2020.02.16
# 2020.02.09
# 2020.02.02
# 2020.01.26
# 2020.01.19
# 2020.01.12
# 2020.01.05
# 2019.12.29
# 2019.12.22
# 2019.12.15
# 2019.12.08
# 2019.12.01
# 2019.11.24
# 2019.11.17
# 2019.11.10
# 2019.11.03
# 2019.10.27
# 2019.10.20
# 2019.10.13
# 2019.10.06
# 2019.09.29
# 2019.09.22
# 2019.09.15
# 2019.09.08
# 2019.09.01
# 2019.08.25
# 2019.08.18
# 2019.08.11
# 2019.08.04
# 2019.07.28
# 2019.07.21
# 2019.07.14
# 2019.07.07
# 2019.06.30
# 2019.06.23
# 2019.06.16
# 2019.06.09
# 2019.06.02
# 2019.05.26
# 2019.05.19
# 2019.05.12
# 2019.05.05
# 2019.04.28
# 2019.04.21
# 2019.04.14
# 2019.04.07
# 2019.03.31
# 2019.03.24
# 2019.03.17
# 2019.03.10
# 2019.03.03
# 2019.02.24
# 2019.02.17
# 2019.02.10
# 2019.02.03
# 2019.01.27
# 2019.01.20
# 2019.01.13
# 2019.01.06
# 2018.12.30
# 2018.12.23
# 2018.12.16
# 2018.12.09
# 2018.12.02
# 2018.11.25
# 2018.11.18
# 2018.11.11
# 2018.11.04
# 2018.10.28
# 2018.10.21
# 2018.10.14
# 2018.10.07
# 2018.09.30
# 2018.09.23
# 2018.09.16
# 2018.09.09
# 2018.09.02
# 2018.08.26
# 2018.08.19
# 2018.08.12
# 2018.08.05
# 2018.07.29
# 2018.07.22
# 2018.07.15
# 2018.07.08
# 2018.07.01
# 2018.06.24
# 2018.06.17
# 2018.06.10
# 2018.06.03
# 2018.05.27
# 2018.05.20
# 2018.05.13
# 2018.05.06
# 2018.04.29
# 2018.04.22
# 2018.04.15
# 2018.04.08
# 2018.04.01
# 2018.03.25
# 2018.03.18
# 2018.03.11
# 2018.03.04
# 2018.02.25
# 2018.02.18
# 2018.02.11
# 2018.02.04
# 2018.01.28
# 2018.01.21
# 2018.01.14
# 2018.01.07
# 2017.12.31
# 2017.12.24
# 2017.12.17
# 2017.12.10
# 2017.12.03
# 2017.11.26
# 2017.11.19
# 2017.11.12
# 2017.11.05
# 2017.10.29
# 2017.10.22
# 2017.10.15
# 2017.10.08
# 2017.10.01
# 2017.09.24
# 2017.09.17
# 2017.09.10
# 2017.09.03
# 2017.08.27
# 2017.08.20
# 2017.08.13
# 2017.08.06
# 2017.07.30
# 2017.07.23
# 2017.07.16
# 2017.07.09
# 2017.07.02
# 2017.06.25
# 2017.06.18
# 2017.06.11
# 2017.06.04
# 2017.05.28
# 2017.05.21
# 2017.05.14
# 2017.05.07
# 2017.04.30
# 2017.04.23
# 2017.04.16
# 2017.04.09
# 2017.04.02
# 2017.03.26
# 2017.03.19
# 2017.03.05
# 2017.02.26
# 2017.02.19
# 2017.02.12
# 2017.02.05
# 2017.01.29
# 2017.01.22
# 2017.01.15
# 2017.01.08
# 2017.01.01
# 2016.12.25
# 2016.12.18
# 2016.12.11
# 2016.12.04
# 2016.11.27
# 2016.11.20
# 2016.11.13
# 2016.11.06
# 2016.10.30
# 2016.10.23
# 2016.10.16
# 2016.10.09
# 2016.10.02
# 2016.09.25
# 2016.09.18
# 2016.09.11
# 2016.09.04
# 2016.08.28
# 2016.08.21
# 2016.08.14
# 2016.08.07
# 2016.07.31
# 2016.07.24
# 2016.07.17
# 2016.07.10
# 2016.07.03
# 2016.06.26
# 2016.06.19
# 2016.06.12
# 2016.06.05
# 2016.05.29
# 2016.05.22
# 2016.05.15
# 2016.05.08
# 2016.05.01
# 2016.04.24
# 2016.04.17
# 2016.04.10
# 2016.04.03
# 2016.03.27
# 2016.03.20
# 2016.03.13
# 2016.03.06
# 2016.02.28
# 2016.02.21
# 2016.02.14
# 2016.02.07
# 2016.01.31
# 2016.01.24
# 2016.01.17
# 2016.01.10
# 2016.01.03
# 2015.12.27
# 2015.12.20
# 2015.12.13
# 2015.12.06
# 2015.11.29
# 2015.11.22
# 2015.11.15
# 2015.11.08
# 2015.11.01
# 2015.10.25
# 2015.10.18
# 2015.10.11
# 2015.10.04
# 2015.09.27
# 2015.09.20
# 2015.09.13
# 2015.09.06
# 2015.08.30
# 2015.08.23
# 2015.08.16
# 2015.08.09
# 2015.08.02
# 2015.07.26
# 2015.07.19
# 2015.07.12
# 2015.07.05
# 2015.06.28
# 2015.06.21
# 2015.06.14
# 2015.06.07
# 2015.05.31
# 2015.05.24
# 2015.05.17
# 2015.05.10
# 2015.05.03
# 2015.04.26
# 2015.04.19
# 2015.04.12
# 2015.04.05
# 2015.03.29
# 2015.03.22
# 2015.03.15
# 2015.03.08
# 2015.03.01
# 2015.02.22
# 2015.02.15
# 2015.02.08
# 2015.02.01
# 2015.01.25
# 2015.01.18
# 2015.01.11
# 2015.01.04

# %%
# function that gets the needed features from the correlation information

def needed_features(processed_week):
    
    
    # load the corelation data from CSV
    correlation_dataframe = pd.read_csv('files/' + processed_week + '/auto-correlation2.csv'  ) 

    # declair the variable that will hold all testable units, the week and the needed feature
    currency_pair_detail = []
    
    # loop through all currency pairs
    for a in all_currency_pairs:

        current_currency = a.replace('10080','')


        weeks = [    {'week_name' : 10, 'correlation_cutoff' : 0.632},
                     {'week_name' : 15, 'correlation_cutoff' : 0.514},
                     {'week_name' : 20, 'correlation_cutoff' : 0.444},
                     {'week_name' : 30, 'correlation_cutoff' : 0.361},
                     {'week_name' : 50, 'correlation_cutoff' : 0.279},
                ]


        #loop throuh all available weeks
        for b in weeks:

            needed_column_list = []

            #check if the current currency in the current week has any currency above the correlation score of the week
            #this is to avoid running analysis for weeks with no correlation

            if  correlation_dataframe[current_currency + '_' + str(b['week_name'])][0] > b['correlation_cutoff']:

                #loop though weeks to get all the currency pairs in the weeks lesser than current week according to my strategy
                for c in weeks:

                    if c['week_name'] <= b['week_name']:

                        #gets the needed two needed columns
                        current_needed_columns = correlation_dataframe[[current_currency + '__' + str(c['week_name']), current_currency + '_' + str(c['week_name'])]] 

                        #get the rows that has corelation
                        current_needed_columns = current_needed_columns.loc[ (current_needed_columns[current_currency + '_' + str(c['week_name'])] >= c['correlation_cutoff'])]

                        #converts the currency pairs that passes to list
                        current_needed_columns = current_needed_columns[current_currency + '__' + str(c['week_name'])].values.tolist()

                        #loop through all the currency pairs that passes and append each currency pair to the list if it is not there already
                        for d in current_needed_columns :
                            if d not in needed_column_list:
                                needed_column_list.append(d) 


            #creates a dictionary with the needed info for the currency and week
            current_currency_detail = {'currency_name': current_currency, 'week': b['week_name'], 'needed_features':needed_column_list }

            #appends all non empty currency detail to the global list
            if len(current_currency_detail['needed_features']) > 0:
                currency_pair_detail.append(current_currency_detail)








    #print(currency_pair_detail)

    return currency_pair_detail

# %%
def learn_best_trading_parameters(processed_week, currency_pair_detail ):
    
    for e in currency_pair_detail:
    
        #print (e['currency_name'])
        current_currency = e['currency_name']

      
        raw_data = pd.read_csv('files/' + processed_week + '/'+ e['currency_name'] + '.csv'   ) 
        weeks = e['week']

        number_of_accurate_prediction = 0
        number_of_trades = 0


        step_down = 5
        cut_off = 0
        n_estimators = 100
        min_samples_leaf = 1
        max_features = "auto"
        max_samples = None



        for v in range(step_down):




            data = raw_data.copy()
            data = data[v:v+weeks]
            #print(data['date'])


            y = data['nextweek_'+ current_currency]


            X = data.loc[:, e['needed_features'] ]






            X_train = X[1:]
            y_train = y[1:]
            X_test = X[:1]
            y_test = y[:1]




            clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                         max_features=max_features, max_samples = max_samples)

            clf.fit(X_train,y_train)
            y_pred=clf.predict(X_test)


            y_test = y_test.values




            if y_pred[0] > cut_off  or y_pred[0] < (-1*cut_off) :
                number_of_trades = number_of_trades + 1
                #print(y_pred[0], y_test[0])


                if (y_pred[0] > 0 and y_test[0] == 1) or (y_pred[0] < 0 and y_test[0]) == -1:
                    number_of_accurate_prediction = number_of_accurate_prediction +1



        e['accuracy_score'] =  100*number_of_accurate_prediction/number_of_trades
        #print(e['accuracy_score'])
        
    return currency_pair_detail

# %%
def next_week_prediction(currency_pair_detail):
    
    next_week_trades =[]

    for f in all_currency_pairs:

        current_currency = f.replace('10080','')
        current_currency_list =[]
        current_currency_best_trade = None

        for g in currency_pair_detail:



            if g['currency_name'] == current_currency:

                current_currency_list.append(g)


        current_currency_list.sort(key=lambda x: x['week'], reverse=False)

        for h in current_currency_list:

            if h['accuracy_score'] > 99.9:

                current_currency_best_trade = h

                break


        if current_currency_best_trade == None:

            for i in current_currency_list:

                if i['accuracy_score'] > 79.9:

                    current_currency_best_trade = i

                    break


        if current_currency_best_trade != None:

            next_week_trades.append(current_currency_best_trade)




    #print(next_week_trades)  
    
    return next_week_trades

# %%
def save_next_week_trades(processed_week, next_week_trades):
    
    # creating a dataframe for nextweek trades and saving it in csv

    name =[]
    week = []
    needed_features = []
    accuracy =[]

    for j in next_week_trades:

        name.append(j['currency_name'])
        week.append(j['week'])
        needed_features.append(j['needed_features'])
        accuracy.append(j['accuracy_score'])


    next_week_trades_dataframe = pd.DataFrame()
    next_week_trades_dataframe['names']=name
    next_week_trades_dataframe['week'] =week
    next_week_trades_dataframe['needed_features'] = needed_features
    next_week_trades_dataframe['accuracy']=accuracy


    print(next_week_trades_dataframe)

    next_week_trades_dataframe.to_csv('files/' + processed_week + '/next_week_trades.csv', index = False   ) 
    
    return 'OK'

# %%
for g in available_weeks:

    currency_pair_detail = needed_features(g)

    currency_pair_detail = learn_best_trading_parameters(g, currency_pair_detail)

    next_week_trades = next_week_prediction(currency_pair_detail)

    final_output = save_next_week_trades(g, next_week_trades)

    print('------$$$$$$$$$$$$$$$$$-----------------------------------------------------------', g)
# Out:
#      names  week                           needed_features  accuracy
# 0   EURUSD    15                                  [CHFJPY]      80.0
# 1   USDJPY    15                                  [EURNZD]      80.0
# 2   AUDUSD    10          [AUDJPY, GBPAUD, EURJPY, USDCAD]      80.0
# 3   NZDUSD    10                  [AUDUSD, GBPAUD, AUDJPY]      80.0
# 4   EURCHF    15                          [EURAUD, AUDNZD]     100.0
# 5   CHFJPY    10                                  [GBPUSD]      80.0
# 6   CADCHF    10                                  [EURNZD]      80.0
# 7   AUDCHF    20                                  [NZDCHF]      80.0
# 8   NZDCHF    50          [AUDNZD, EURCAD, GBPCHF, USDCHF]      80.0
# 9   GBPCAD    10                  [AUDJPY, GBPCHF, GBPAUD]      80.0
# 10  GBPAUD    50  [AUDJPY, GBPAUD, EURJPY, USDCAD, NZDUSD]      80.0
# 11  EURCAD    15                                  [EURNZD]      80.0
# 12  EURNZD    20                  [CHFJPY, USDCHF, GBPUSD]      80.0
# 13  CADJPY    30  [AUDJPY, GBPAUD, NZDCAD, USDCAD, EURJPY]      80.0
# 14  AUDJPY    10          [AUDJPY, GBPAUD, EURJPY, USDCAD]      80.0
# 15  NZDJPY    10                  [AUDUSD, GBPAUD, AUDJPY]      80.0
# 16  AUDCAD    10                  [USDCHF, USDCAD, EURJPY]      80.0
# 17  NZDCAD    10                                  [NZDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.28
#      names  week                   needed_features  accuracy
# 0   USDCHF    15                          [USDJPY]      80.0
# 1   EURUSD    10                  [EURGBP, GBPJPY]      80.0
# 2   USDJPY    15          [EURNZD, NZDCAD, EURGBP]     100.0
# 3   USDCAD    10                          [NZDCAD]      80.0
# 4   AUDUSD    10  [AUDJPY, GBPAUD, EURJPY, USDCAD]      80.0
# 5   NZDUSD    10          [AUDUSD, GBPAUD, AUDJPY]      80.0
# 6   GBPCHF    30                  [EURNZD, NZDCHF]      80.0
# 7   EURCHF    10          [USDJPY, EURAUD, EURCAD]     100.0
# 8   CHFJPY    10                          [GBPUSD]     100.0
# 9   CADCHF    10          [EURNZD, NZDCAD, NZDCHF]     100.0
# 10  AUDCHF    15                          [NZDCHF]      80.0
# 11  NZDCHF    10                          [EURUSD]      80.0
# 12  GBPJPY    10                          [GBPJPY]      80.0
# 13  GBPCAD    15                          [GBPCHF]      80.0
# 14  GBPAUD    15                          [CHFJPY]      80.0
# 15  EURJPY    10                          [NZDCAD]      80.0
# 16  EURCAD    10                  [EURNZD, NZDCAD]      80.0
# 17  EURAUD    15                  [USDCHF, NZDCAD]     100.0
# 18  EURNZD    20          [CHFJPY, USDCHF, GBPUSD]      80.0
# 19  AUDJPY    15                          [CHFJPY]      80.0
# 20  NZDJPY    30                          [USDCHF]      80.0
# 21  AUDCAD    10  [USDCHF, EURUSD, USDCAD, EURJPY]      80.0
# 22  NZDCAD    10                          [NZDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_21816/1178094462.py in <module>
#       3     currency_pair_detail = needed_features(g)
#       4
# ----> 5     currency_pair_detail = learn_best_trading_parameters(g, currency_pair_detail)
#       6
#       7     next_week_trades = next_week_prediction(currency_pair_detail)
#
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_21816/1068870110.py in learn_best_trading_parameters(processed_week, currency_pair_detail)
#      54                                          max_features=max_features, max_samples = max_samples)
#      55
# ---> 56             clf.fit(X_train,y_train)
#      57             y_pred=clf.predict(X_test)
#      58
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\multiprocessing\pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\multiprocessing\pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
def predict_nextweek_trades_direction(processed_week):
    next_week_prediction_score = []
    next_week_prediction =[]

    next_week_trades = pd.read_csv('files/' + processed_week + '/next_week_trades.csv'  ) 




    for index, row in next_week_trades.iterrows():



        current_currency = row.names
        raw_data = pd.read_csv('files/' + processed_week +'/' + current_currency + '.csv'    ) 
        weeks = row.week
        wanted_features = ast.literal_eval(row.needed_features)
        n_estimators = 100
        min_samples_leaf = 1
        max_features = "auto"
        max_samples = None




        raw_data = raw_data[:weeks]

        X_train = pd.DataFrame()

        for q in wanted_features:

            X_train[q] = raw_data[q]


        #print(X_train)  

        y_train = raw_data['nextweek_'+ current_currency]

        #print(y_train)



        prediction_model=RandomForestRegressor(
                                                    n_estimators=n_estimators,
                                                   n_jobs =-1,
                                                   min_samples_leaf=min_samples_leaf,
                                                    max_features=max_features,
                                                   max_samples = max_samples
                                              )



        prediction_model.fit(X_train,y_train)


        current_week_values = pd.read_csv('files/' + processed_week + '/current_week_values.csv'   ) 

        X_pred = pd.DataFrame()

        for h in wanted_features:

            X_pred[h] = current_week_values[h]

        #print(X_pred)

        y_pred = prediction_model.predict(X_pred)


        if y_pred[0] > 0:

            value = 'S'

        else:
            value = 'B'

        next_week_prediction_score.append(y_pred[0])
        next_week_prediction.append(value)

        print(row.names, row.week, y_pred)



    #print(next_week_prediction)
    print(processed_week)
    
    next_week_trades['next_week_prediction_score'] = next_week_prediction_score
    next_week_trades['next_week_prediction'] = next_week_prediction

    next_week_trades.to_csv('files/' + processed_week + '/next_week_trades.csv', index = False )

# %%
for g in available_weeks:
    predict_nextweek_trades_direction(g)
# Out:
# EURUSD 15 [0.49263353]
# USDJPY 15 [0.76681507]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# EURCHF 15 [0.984]
# CHFJPY 10 [-0.3037619]
# CADCHF 10 [0.61336508]
# AUDCHF 20 [0.72938817]
# NZDCHF 50 [0.56466522]
# GBPCAD 10 [0.72]
# GBPAUD 50 [0.48267226]
# EURCAD 15 [-0.79524703]
# EURNZD 20 [0.86]
# CADJPY 30 [-0.17489033]
# AUDJPY 10 [-1.]
# NZDJPY 10 [-1.]
# AUDCAD 10 [0.27542857]
# NZDCAD 10 [-0.6729127]
# ['B', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'S']
# USDCHF 15 [0.97733333]
# EURUSD 10 [-1.]
# USDJPY 15 [1.]
# USDCAD 10 [-0.23046032]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 30 [0.47175838]
# EURCHF 10 [0.44]
# CHFJPY 10 [-0.32621429]
# CADCHF 10 [1.]
# AUDCHF 15 [1.]
# NZDCHF 10 [0.906]
# GBPJPY 10 [0.976]
# GBPCAD 15 [-0.62121284]
# GBPAUD 15 [-0.70815584]
# EURJPY 10 [0.25235714]
# EURCAD 10 [-1.]
# EURAUD 15 [-1.]
# EURNZD 20 [0.55333333]
# AUDJPY 15 [0.71341198]
# NZDJPY 30 [0.51849865]
# AUDCAD 10 [0.94]
# NZDCAD 10 [-0.69126984]
# ['B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S']
# GBPUSD 10 [0.32]
# EURUSD 10 [-1.]
# USDJPY 10 [-0.34466667]
# USDCAD 10 [1.]
# AUDUSD 15 [-0.9]
# GBPCHF 50 [0.53416668]
# EURCHF 10 [-1.]
# CADCHF 10 [-0.56]
# AUDCHF 10 [0.76]
# NZDCHF 10 [1.]
# GBPCAD 15 [0.54825086]
# EURJPY 10 [-1.]
# EURCAD 20 [-0.72]
# EURAUD 15 [0.98]
# EURNZD 15 [0.85555556]
# NZDJPY 10 [0.896]
# AUDCAD 15 [-0.40970635]
# NZDCAD 15 [0.54428571]
# AUDNZD 10 [0.48]
# ['B', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B']
# USDCHF 10 [-1.]
# GBPUSD 10 [0.12140476]
# EURUSD 15 [-0.74]
# USDJPY 15 [0.86]
# USDCAD 10 [-0.52083333]
# AUDUSD 10 [-0.44971429]
# NZDUSD 10 [-1.]
# GBPCHF 30 [-0.40061061]
# EURCHF 30 [-0.14572222]
# CADCHF 15 [0.7955]
# AUDCHF 10 [-0.98]
# NZDCHF 10 [-1.]
# EURGBP 10 [0.43380159]
# EURJPY 10 [0.46933333]
# EURCAD 15 [-0.42]
# EURAUD 15 [-0.02]
# EURNZD 10 [1.]
# CADJPY 10 [0.97]
# NZDJPY 30 [-0.1716769]
# AUDCAD 10 [-0.98]
# NZDCAD 15 [-0.96]
# AUDNZD 10 [0.52]
# ['S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B']
# USDCHF 15 [1.]
# GBPUSD 20 [-0.96666667]
# EURUSD 15 [-0.98133333]
# USDJPY 15 [1.]
# AUDUSD 10 [1.]
# NZDUSD 50 [0.33053752]
# GBPCHF 30 [0.54781909]
# EURCHF 30 [0.2480146]
# CADCHF 10 [0.73104762]
# AUDCHF 20 [0.64170274]
# NZDCHF 10 [0.58]
# EURGBP 10 [-0.956]
# GBPCAD 10 [-1.]
# GBPAUD 10 [-1.]
# EURJPY 20 [-0.99]
# EURCAD 15 [-0.86]
# EURAUD 15 [-1.]
# EURNZD 10 [0.3]
# CADJPY 10 [-0.37165079]
# AUDJPY 15 [1.]
# NZDJPY 30 [0.7402896]
# AUDCAD 10 [-0.32]
# NZDCAD 10 [-0.92]
# AUDNZD 15 [-0.23]
# ['B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S']
# GBPUSD 15 [0.56520418]
# USDJPY 20 [-0.60755267]
# USDCAD 20 [-0.36586136]
# AUDUSD 15 [0.45866667]
# GBPCHF 15 [0.71645815]
# EURCHF 20 [-0.69339875]
# CADCHF 30 [0.84166667]
# AUDCHF 15 [-0.22979487]
# NZDCHF 10 [-0.22]
# EURGBP 15 [-0.13866667]
# GBPCAD 10 [-0.5]
# GBPAUD 15 [0.10182251]
# EURCAD 15 [-0.78]
# EURAUD 15 [0.44084127]
# EURNZD 20 [0.25611111]
# CADJPY 15 [0.65918254]
# AUDJPY 50 [-0.26336526]
# NZDJPY 50 [0.08918806]
# AUDCAD 10 [0.8]
# NZDCAD 50 [-0.04611905]
# AUDNZD 15 [-0.524]
# ['B', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S']
# EURUSD 10 [0.64640476]
# USDJPY 10 [-0.406]
# AUDUSD 15 [0.201]
# GBPCHF 30 [-0.40081529]
# EURCHF 10 [0.846]
# CHFJPY 30 [0.26328055]
# CADCHF 10 [-0.91166667]
# AUDCHF 10 [-0.37392857]
# NZDCHF 20 [1.]
# EURGBP 10 [0.3362619]
# GBPJPY 30 [-0.28072007]
# EURNZD 20 [-0.66070635]
# CADJPY 10 [-0.66914286]
# AUDCAD 10 [0.32]
# NZDCAD 15 [0.97216667]
# AUDNZD 20 [-1.]
# ['B', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S']
# USDCHF 50 [0.53911888]
# USDJPY 10 [-0.33042857]
# AUDUSD 15 [0.547]
# NZDUSD 15 [0.75880808]
# GBPCHF 10 [1.]
# CHFJPY 10 [-1.]
# CADCHF 10 [0.62]
# AUDCHF 10 [1.]
# NZDCHF 50 [0.36457128]
# EURGBP 10 [0.66430952]
# GBPCAD 10 [1.]
# GBPAUD 10 [-0.86]
# EURAUD 15 [-0.34]
# EURNZD 20 [0.11266667]
# CADJPY 15 [0.22742857]
# AUDJPY 30 [-0.09520202]
# AUDCAD 10 [1.]
# ['B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B']
# USDCHF 20 [0.96]
# USDJPY 10 [1.]
# AUDUSD 15 [0.53726984]
# NZDUSD 15 [0.70288095]
# GBPCHF 10 [1.]
# EURCHF 10 [-0.96922222]
# CHFJPY 10 [-1.]
# CADCHF 10 [1.]
# AUDCHF 10 [1.]
# NZDCHF 15 [-1.]
# EURGBP 50 [-0.745]
# GBPCAD 10 [-0.276]
# EURAUD 30 [0.74]
# EURNZD 10 [-0.50783333]
# AUDJPY 10 [0.96]
# AUDCAD 10 [1.]
# NZDCAD 10 [-0.96533333]
# ['B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S']
# USDCHF 20 [-0.6]
# AUDUSD 10 [0.55904762]
# GBPCHF 10 [1.]
# EURCHF 10 [0.92]
# CHFJPY 10 [-0.08]
# CADCHF 15 [0.66397169]
# AUDCHF 10 [1.]
# EURGBP 10 [-0.95]
# GBPCAD 10 [-0.34131746]
# GBPAUD 30 [0.54782364]
# EURNZD 20 [-0.03192857]
# CADJPY 20 [-0.64314286]
# AUDJPY 50 [-0.89214897]
# AUDCAD 15 [1.]
# ['S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'B']
# USDCHF 10 [-0.94]
# USDJPY 20 [-0.50540476]
# USDCAD 10 [-1.]
# AUDUSD 50 [-0.31532478]
# NZDUSD 10 [0.986]
# GBPCHF 30 [1.]
# EURCHF 10 [-0.64973016]
# CHFJPY 10 [-0.62]
# CADCHF 10 [-0.18721429]
# AUDCHF 10 [-0.66809524]
# EURGBP 50 [0.06846809]
# GBPCAD 10 [0.61554762]
# GBPAUD 30 [-0.23565433]
# EURCAD 10 [0.72]
# EURAUD 20 [-0.13535692]
# EURNZD 10 [-0.96]
# CADJPY 10 [1.]
# AUDJPY 20 [0.29924553]
# AUDCAD 10 [0.958]
# NZDCAD 10 [0.97]
# AUDNZD 20 [-0.98]
# ['S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [-0.38866667]
# GBPUSD 15 [1.]
# EURUSD 10 [0.94466667]
# USDJPY 10 [-0.66]
# USDCAD 10 [-0.971]
# AUDUSD 50 [-0.20649013]
# NZDUSD 10 [-0.6247619]
# EURCHF 20 [0.48220763]
# CHFJPY 10 [0.62681746]
# CADCHF 15 [0.64221656]
# EURGBP 10 [-0.932]
# GBPJPY 10 [-0.27565873]
# GBPCAD 10 [-0.43957143]
# GBPAUD 30 [-0.16664586]
# EURCAD 10 [0.67452381]
# EURAUD 30 [-0.47448918]
# EURNZD 10 [1.]
# AUDJPY 20 [0.29189588]
# NZDJPY 20 [-0.35830719]
# ['S', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S']
# USDCHF 10 [0.2]
# GBPUSD 10 [0.11333333]
# EURUSD 10 [-0.04466667]
# USDJPY 10 [0.92]
# USDCAD 15 [-0.19070369]
# AUDUSD 50 [-0.15756935]
# GBPCHF 30 [-0.73980941]
# EURGBP 10 [0.64233333]
# GBPJPY 10 [-0.29442857]
# GBPCAD 30 [-0.32566667]
# GBPAUD 50 [-0.20055272]
# EURJPY 10 [0.3561746]
# EURCAD 10 [-0.51961905]
# EURAUD 30 [0.60919526]
# EURNZD 10 [0.2]
# NZDJPY 30 [-0.7025]
# ['B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S']
# USDCHF 15 [1.]
# GBPUSD 10 [-0.978]
# EURUSD 10 [-0.958]
# USDJPY 20 [0.181]
# USDCAD 15 [1.]
# GBPCHF 50 [-0.20522679]
# CHFJPY 10 [1.]
# EURGBP 10 [1.]
# GBPJPY 20 [-0.48272333]
# GBPCAD 15 [0.74285714]
# GBPAUD 50 [0.4961833]
# EURNZD 15 [0.79669769]
# CADJPY 10 [1.]
# AUDCAD 10 [-0.2862619]
# ['B', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [1.]
# GBPUSD 10 [-0.84224603]
# EURUSD 10 [-0.7077619]
# USDJPY 15 [-0.62683333]
# USDCAD 10 [0.8465]
# GBPCHF 30 [-0.84479737]
# EURCHF 15 [-0.75498124]
# CHFJPY 10 [-0.9]
# EURGBP 10 [1.]
# GBPJPY 15 [-0.992]
# GBPCAD 10 [1.]
# GBPAUD 50 [0.02420063]
# EURJPY 15 [-0.99666667]
# EURAUD 10 [1.]
# EURNZD 10 [1.]
# AUDJPY 20 [-0.996]
# AUDCAD 10 [-0.95533333]
# NZDCAD 50 [-0.31216922]
# ['B', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S']
# USDCHF 10 [-0.98]
# GBPUSD 15 [-0.9]
# EURUSD 10 [-0.36]
# USDJPY 10 [1.]
# AUDUSD 30 [-0.55089022]
# GBPCHF 15 [0.26487646]
# EURCHF 20 [0.43859307]
# CHFJPY 10 [1.]
# EURGBP 10 [0.32]
# GBPJPY 20 [-0.16423232]
# GBPCAD 10 [1.]
# EURAUD 30 [-0.19630233]
# EURNZD 10 [-0.52402381]
# CADJPY 10 [-0.451]
# AUDJPY 20 [0.51534088]
# NZDJPY 50 [0.44620986]
# ['S', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B']
# USDCHF 10 [0.66]
# GBPUSD 10 [1.]
# EURUSD 10 [0.96]
# USDCAD 30 [-0.38048343]
# AUDUSD 30 [-0.64480927]
# CHFJPY 10 [1.]
# EURGBP 10 [0.988]
# GBPJPY 15 [0.7152588]
# GBPCAD 30 [-0.71666667]
# GBPAUD 50 [0.77267949]
# EURJPY 10 [0.20047619]
# EURCAD 15 [-0.39275108]
# EURAUD 15 [1.]
# EURNZD 10 [0.62607143]
# AUDJPY 10 [0.20460317]
# NZDJPY 30 [-0.40998413]
# ['B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.42]
# GBPUSD 10 [-0.84]
# EURUSD 10 [-0.86]
# USDJPY 15 [0.66]
# AUDUSD 20 [-0.76084626]
# GBPCHF 15 [-0.73852309]
# EURCHF 10 [-1.]
# CHFJPY 10 [0.14]
# CADCHF 50 [0.61433006]
# AUDCHF 20 [-1.]
# NZDCHF 30 [-0.24660007]
# GBPJPY 15 [-0.41181446]
# GBPCAD 50 [-0.90033333]
# GBPAUD 50 [0.14093514]
# EURJPY 10 [-1.]
# EURCAD 15 [-1.]
# EURAUD 10 [1.]
# EURNZD 10 [1.]
# CADJPY 10 [0.03273016]
# AUDJPY 10 [-1.]
# NZDJPY 30 [-0.20897281]
# NZDCAD 10 [-1.]
# ['B', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S']
# USDCHF 50 [1.]
# GBPUSD 10 [0.1]
# EURUSD 10 [0.]
# USDJPY 10 [0.38]
# AUDUSD 10 [-1.]
# GBPCHF 10 [0.17040476]
# EURCHF 10 [0.25528571]
# CHFJPY 20 [0.06]
# CADCHF 50 [-0.11257994]
# AUDCHF 10 [-0.8]
# GBPCAD 15 [-0.4]
# GBPAUD 10 [1.]
# EURCAD 15 [0.045]
# EURAUD 10 [1.]
# EURNZD 10 [-0.21302381]
# AUDJPY 10 [0.34623016]
# NZDJPY 15 [0.69502525]
# AUDCAD 10 [-0.948]
# ['B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S']
# USDCHF 10 [-1.]
# GBPUSD 20 [0.75173477]
# EURUSD 10 [0.98]
# USDJPY 10 [-0.96]
# AUDUSD 20 [0.12558181]
# GBPCHF 15 [-0.55629365]
# EURCHF 10 [-1.]
# CHFJPY 10 [0.994]
# AUDCHF 10 [-0.54419048]
# GBPCAD 15 [0.4675]
# GBPAUD 50 [0.41178361]
# EURJPY 30 [0.44188065]
# EURCAD 10 [0.38366667]
# EURAUD 20 [-0.07480336]
# EURNZD 10 [1.]
# CADJPY 30 [-0.04884127]
# AUDJPY 10 [-1.]
# NZDJPY 50 [-0.65222944]
# AUDCAD 10 [-0.958]
# ['S', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'S']
# USDCHF 30 [-0.146]
# GBPUSD 10 [-0.95]
# EURUSD 10 [-0.88]
# USDJPY 10 [-0.12]
# EURCHF 50 [-1.]
# CHFJPY 15 [-0.56245022]
# AUDCHF 10 [-0.68]
# GBPAUD 50 [0.74194283]
# EURJPY 30 [0.19090476]
# EURCAD 10 [-0.32]
# EURAUD 20 [0.77256016]
# EURNZD 15 [-0.67371429]
# CADJPY 30 [-0.48667388]
# AUDJPY 10 [-0.72]
# NZDJPY 30 [-0.96285714]
# AUDCAD 10 [0.61702381]
# ['S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 10 [0.85824603]
# EURUSD 20 [-0.95]
# USDJPY 10 [1.]
# GBPCHF 15 [0.45032517]
# EURCHF 30 [0.54470663]
# AUDCHF 10 [-0.968]
# GBPAUD 20 [0.76178211]
# EURCAD 10 [0.46815873]
# EURAUD 20 [0.75739999]
# CADJPY 50 [-0.66802309]
# AUDJPY 10 [-0.974]
# NZDJPY 30 [-0.48]
# AUDCAD 50 [0.61983529]
# NZDCAD 10 [-0.57788095]
# ['B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'S']
# USDCHF 20 [0.41172611]
# EURUSD 20 [0.60666667]
# USDJPY 10 [-0.21301587]
# NZDUSD 15 [0.49832828]
# GBPCHF 15 [0.16828571]
# AUDCHF 10 [0.69478571]
# GBPJPY 15 [0.71411117]
# GBPCAD 10 [0.92]
# EURCAD 50 [0.70880952]
# EURNZD 10 [-0.30252381]
# CADJPY 50 [-0.32277561]
# AUDJPY 15 [0.45893362]
# NZDCAD 20 [-0.53942063]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'S']
# USDCHF 50 [0.29196083]
# USDJPY 15 [-0.72316378]
# GBPCHF 15 [-0.5687381]
# EURCHF 15 [-0.49812177]
# CADCHF 10 [-0.46590476]
# AUDCHF 10 [-0.71388095]
# GBPCAD 10 [-0.49733333]
# EURNZD 50 [0.967]
# AUDJPY 10 [0.92]
# AUDNZD 30 [1.]
# ['B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B']
# USDCHF 50 [-0.62528632]
# GBPUSD 15 [-0.991]
# EURUSD 20 [-0.72885326]
# USDJPY 30 [-0.27094393]
# AUDUSD 15 [-0.75320346]
# GBPCHF 10 [-0.95]
# EURCHF 10 [-1.]
# CADCHF 15 [0.75680475]
# AUDCHF 10 [0.57952381]
# GBPJPY 10 [-0.964]
# GBPCAD 20 [0.63350794]
# GBPAUD 15 [0.73391947]
# CADJPY 10 [-0.974]
# AUDJPY 10 [0.984]
# NZDJPY 10 [-0.98]
# AUDCAD 10 [-0.41002381]
# ['S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'S']
# USDCHF 20 [-0.52336508]
# GBPUSD 15 [-0.69665873]
# USDJPY 10 [-1.]
# USDCAD 15 [0.68292857]
# AUDUSD 15 [-0.7419798]
# GBPCHF 10 [-0.78]
# EURCHF 10 [-0.36]
# CHFJPY 10 [-0.11183333]
# AUDCHF 10 [-1.]
# EURGBP 10 [-1.]
# GBPJPY 15 [0.98]
# GBPCAD 10 [0.94]
# EURJPY 10 [-0.63066667]
# EURNZD 10 [-0.46]
# NZDJPY 10 [0.7]
# AUDCAD 10 [0.34126984]
# ['S', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B']
# GBPUSD 15 [1.]
# EURUSD 50 [0.74787501]
# USDJPY 50 [0.49758452]
# USDCAD 20 [0.58580952]
# GBPCHF 10 [1.]
# EURCHF 15 [0.982]
# CHFJPY 10 [1.]
# CADCHF 20 [0.35295238]
# EURGBP 30 [-0.66857071]
# GBPJPY 15 [0.50557143]
# GBPCAD 10 [1.]
# GBPAUD 10 [-0.97]
# EURJPY 30 [1.]
# EURAUD 10 [-0.962]
# CADJPY 15 [1.]
# NZDJPY 10 [0.6]
# ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B']
# GBPUSD 10 [-0.18311111]
# USDJPY 50 [-0.43967444]
# USDCAD 10 [-1.]
# GBPCHF 15 [-0.54906349]
# EURCHF 30 [0.23424242]
# CHFJPY 10 [1.]
# AUDCHF 10 [-1.]
# EURGBP 10 [0.24996825]
# GBPJPY 50 [0.14641108]
# GBPCAD 10 [-0.35057143]
# EURJPY 30 [0.35214939]
# EURCAD 20 [0.29962457]
# EURAUD 10 [1.]
# CADJPY 15 [-0.02544517]
# NZDJPY 10 [-0.28685714]
# AUDCAD 10 [-1.]
# NZDCAD 10 [-0.986]
# ['S', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S']
# USDJPY 50 [-0.51994179]
# USDCAD 10 [-1.]
# EURCHF 30 [1.]
# AUDCHF 10 [-0.6]
# EURGBP 15 [-0.76184343]
# GBPCAD 20 [0.96]
# EURJPY 30 [0.26754541]
# CADJPY 30 [1.]
# NZDJPY 10 [1.]
# NZDCAD 10 [0.39745238]
# ['S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B']
# USDCHF 50 [0.33324558]
# USDJPY 50 [-0.47586649]
# USDCAD 10 [0.24795238]
# GBPCHF 10 [-0.3]
# EURCHF 30 [0.10690687]
# AUDCHF 10 [-0.4]
# EURGBP 20 [-0.92065934]
# GBPCAD 15 [0.09595238]
# EURJPY 30 [0.21016197]
# EURNZD 10 [-1.]
# NZDJPY 10 [-0.10571429]
# ['B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'S', 'S']
# GBPUSD 10 [0.45610317]
# USDCAD 20 [-0.46022062]
# AUDUSD 20 [0.51393956]
# GBPCHF 10 [-1.]
# AUDCHF 10 [-0.96]
# EURGBP 15 [0.35222222]
# GBPAUD 10 [-0.988]
# EURJPY 20 [0.28506707]
# EURNZD 50 [-0.69996825]
# NZDCAD 10 [0.42780159]
# ['B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'S', 'B']
# USDCAD 10 [0.42061905]
# NZDUSD 30 [-0.00238124]
# GBPCHF 20 [1.]
# EURCHF 10 [1.]
# AUDCHF 10 [0.92]
# EURGBP 15 [-0.92166667]
# GBPAUD 10 [0.41328571]
# EURJPY 20 [0.23047256]
# EURNZD 10 [1.]
# NZDJPY 20 [-0.95]
# AUDCAD 10 [-0.984]
# NZDCAD 10 [0.43280159]
# ['B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B']
# USDJPY 10 [-0.34351587]
# USDCAD 10 [-0.986]
# GBPCHF 20 [-0.13916378]
# EURCHF 20 [1.]
# CADCHF 10 [-0.33629365]
# AUDCHF 10 [-0.78]
# EURGBP 10 [0.74]
# GBPCAD 15 [1.]
# EURJPY 20 [1.]
# EURCAD 10 [0.3923254]
# EURNZD 10 [-1.]
# NZDJPY 20 [0.826]
# AUDCAD 10 [1.]
# NZDCAD 10 [1.]
# ['S', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B']
# USDJPY 30 [0.65011604]
# EURCHF 20 [1.]
# CHFJPY 15 [0.59567682]
# CADCHF 10 [-0.32122222]
# EURGBP 20 [-0.98666667]
# GBPCAD 10 [0.76]
# EURJPY 30 [0.48368571]
# EURCAD 10 [0.34642063]
# EURNZD 30 [0.32809524]
# CADJPY 15 [1.]
# AUDCAD 10 [0.98666667]
# NZDCAD 10 [1.]
# ['B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B']
# USDCAD 15 [0.97466667]
# NZDUSD 15 [-0.92266667]
# GBPCHF 30 [-0.37934799]
# EURCHF 20 [1.]
# CHFJPY 10 [-0.982]
# AUDCHF 10 [-0.20792063]
# EURGBP 30 [-0.29804762]
# GBPJPY 30 [-0.91806926]
# GBPCAD 30 [-0.17622751]
# GBPAUD 15 [0.90933333]
# EURJPY 20 [0.11867994]
# EURNZD 10 [-1.]
# AUDCAD 10 [-0.32230159]
# ['B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S']
# USDCHF 10 [1.]
# EURUSD 30 [-0.13215007]
# USDCAD 15 [-0.29748818]
# GBPCHF 15 [1.]
# EURCHF 20 [1.]
# AUDCHF 10 [0.7977381]
# GBPJPY 30 [1.]
# GBPCAD 20 [0.46295238]
# GBPAUD 15 [-0.23461572]
# EURJPY 30 [-0.06871025]
# EURCAD 50 [-0.46697619]
# EURAUD 15 [-0.62718149]
# EURNZD 30 [-0.56]
# CADJPY 20 [0.21093651]
# NZDJPY 15 [1.]
# AUDCAD 10 [0.34243651]
# NZDCAD 30 [1.]
# AUDNZD 20 [0.0632253]
# ['B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B']
# USDCHF 10 [1.]
# USDJPY 50 [-0.96]
# GBPCHF 15 [1.]
# GBPJPY 30 [0.908]
# GBPCAD 15 [-0.25821429]
# EURJPY 50 [0.40014647]
# EURAUD 15 [-0.53652015]
# EURNZD 15 [0.52]
# NZDJPY 20 [0.8]
# NZDCAD 10 [-0.98]
# ['B', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S']
# USDCHF 10 [-0.78]
# EURUSD 15 [0.995]
# USDJPY 10 [-0.774]
# EURCHF 20 [0.52]
# CHFJPY 20 [1.]
# CADCHF 10 [-0.776]
# NZDCHF 50 [0.72621552]
# GBPJPY 20 [1.]
# GBPCAD 20 [0.53438765]
# EURCAD 20 [0.992]
# EURNZD 15 [0.88]
# CADJPY 10 [-0.675]
# AUDJPY 10 [1.]
# NZDJPY 10 [-0.74]
# NZDCAD 10 [-0.916]
# ['S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S']
# USDCHF 10 [1.]
# EURUSD 15 [-0.62642857]
# USDJPY 10 [1.]
# AUDUSD 10 [0.71639683]
# GBPCHF 15 [0.46614286]
# EURCHF 10 [0.75009524]
# CHFJPY 20 [-0.23958686]
# CADCHF 10 [1.]
# NZDCHF 10 [0.77046032]
# GBPJPY 15 [1.]
# GBPAUD 50 [0.61940454]
# EURJPY 10 [0.76923016]
# EURCAD 20 [-0.54857152]
# EURNZD 10 [0.56]
# CADJPY 10 [0.78]
# NZDJPY 20 [0.98]
# AUDCAD 15 [0.551]
# NZDCAD 10 [0.74874603]
# ['B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B']
# USDCHF 10 [0.64]
# EURUSD 10 [-0.68]
# USDJPY 10 [0.66]
# AUDUSD 10 [0.70837302]
# NZDUSD 10 [-0.834]
# GBPCHF 15 [1.]
# EURCHF 15 [-0.28044444]
# CHFJPY 20 [-0.37938251]
# CADCHF 50 [-0.5584127]
# NZDCHF 10 [0.10866667]
# EURGBP 15 [0.50011616]
# GBPJPY 15 [0.635]
# GBPAUD 50 [-0.80755339]
# EURJPY 10 [0.22306349]
# EURCAD 20 [-0.49977159]
# EURNZD 10 [0.51503175]
# CADJPY 10 [0.32]
# NZDJPY 10 [0.28]
# AUDCAD 10 [0.67911905]
# NZDCAD 10 [-0.864]
# ['B', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.16]
# GBPUSD 20 [1.]
# EURUSD 10 [0.02]
# USDJPY 10 [-0.02]
# USDCAD 10 [1.]
# AUDUSD 30 [-0.13681065]
# NZDUSD 30 [0.7]
# EURCHF 30 [0.15036075]
# CHFJPY 50 [0.65304346]
# CADCHF 10 [-0.03666667]
# NZDCHF 10 [0.33338889]
# EURGBP 10 [-1.]
# GBPJPY 20 [0.74]
# GBPCAD 15 [1.]
# GBPAUD 10 [0.978]
# EURJPY 15 [-0.50311905]
# EURNZD 10 [-0.84]
# CADJPY 10 [-0.0252381]
# NZDJPY 10 [0.5]
# AUDCAD 30 [0.92666667]
# NZDCAD 10 [0.48331746]
# ['B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B']
# USDCHF 10 [0.84]
# GBPUSD 15 [1.]
# EURUSD 10 [-0.86]
# USDJPY 10 [0.82]
# USDCAD 10 [-0.64857143]
# AUDUSD 15 [1.]
# NZDUSD 10 [1.]
# GBPCHF 15 [1.]
# EURCHF 20 [-0.89978571]
# CHFJPY 20 [0.0592944]
# CADCHF 50 [0.]
# NZDCHF 20 [-0.06936575]
# EURGBP 30 [-0.13590249]
# GBPJPY 20 [1.]
# GBPCAD 30 [0.63597908]
# GBPAUD 10 [-0.59344444]
# EURJPY 15 [0.62260184]
# EURCAD 20 [-0.6181056]
# EURNZD 10 [1.]
# CADJPY 10 [1.]
# NZDJPY 10 [1.]
# AUDCAD 20 [0.63522222]
# NZDCAD 15 [0.10246825]
# ['B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'B']
# USDCHF 10 [0.94]
# GBPUSD 15 [0.17492857]
# EURUSD 10 [-0.92]
# USDJPY 10 [0.68935714]
# USDCAD 15 [-0.74180087]
# AUDUSD 20 [0.9925]
# NZDUSD 10 [1.]
# GBPCHF 15 [-0.56281097]
# EURCHF 15 [1.]
# CHFJPY 50 [0.040474]
# CADCHF 10 [1.]
# NZDCHF 20 [-0.30045615]
# EURGBP 10 [0.9]
# GBPJPY 20 [0.92]
# GBPCAD 20 [-0.98]
# GBPAUD 15 [-0.54219986]
# EURNZD 10 [-0.88]
# CADJPY 10 [1.]
# NZDJPY 20 [1.]
# AUDCAD 20 [0.38942857]
# NZDCAD 20 [-0.26478954]
# ['B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S']
# USDCHF 10 [-0.96666667]
# GBPUSD 20 [1.]
# EURUSD 15 [1.]
# USDJPY 10 [-0.948]
# USDCAD 15 [-0.71096687]
# NZDUSD 10 [1.]
# GBPCHF 10 [0.8]
# EURCHF 15 [0.4346746]
# CADCHF 20 [0.92012821]
# NZDCHF 15 [0.869]
# EURGBP 10 [-0.6425]
# GBPJPY 10 [1.]
# GBPCAD 10 [0.82]
# GBPAUD 15 [-0.44667027]
# EURCAD 20 [-0.65252381]
# CADJPY 10 [0.74704762]
# NZDJPY 20 [1.]
# AUDCAD 15 [1.]
# NZDCAD 15 [0.86466667]
# ['S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B']
# USDCHF 10 [0.99333333]
# GBPUSD 20 [1.]
# EURUSD 20 [0.46]
# USDJPY 15 [-1.]
# USDCAD 20 [-0.57055944]
# NZDUSD 10 [1.]
# GBPCHF 10 [1.]
# EURCHF 15 [0.38509524]
# CHFJPY 50 [0.04834162]
# CADCHF 20 [0.76370672]
# NZDCHF 20 [0.8254569]
# EURGBP 10 [-0.29638889]
# GBPJPY 10 [0.48]
# GBPCAD 10 [1.]
# GBPAUD 15 [-0.24281746]
# EURCAD 15 [-0.24]
# EURNZD 15 [-0.69113059]
# CADJPY 10 [0.74075397]
# NZDJPY 20 [1.]
# AUDCAD 20 [0.51421556]
# NZDCAD 20 [0.79400241]
# AUDNZD 10 [-0.84]
# ['B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.27033333]
# GBPUSD 10 [-0.478]
# EURUSD 10 [-0.3182381]
# USDJPY 20 [-0.4]
# AUDUSD 10 [1.]
# NZDUSD 10 [1.]
# GBPCHF 20 [0.88870707]
# EURCHF 30 [0.78984177]
# CHFJPY 15 [-0.0860116]
# CADCHF 20 [0.66439827]
# AUDCHF 15 [0.63777456]
# NZDCHF 15 [1.]
# EURGBP 10 [-0.34004762]
# GBPJPY 15 [-0.3]
# GBPCAD 30 [0.59441991]
# GBPAUD 15 [0.77499184]
# EURCAD 20 [-0.44071429]
# EURAUD 15 [-0.64924942]
# EURNZD 15 [-0.60771701]
# NZDJPY 15 [1.]
# AUDCAD 15 [1.]
# NZDCAD 15 [1.]
# AUDNZD 10 [1.]
# ['B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B']
# USDCHF 10 [-0.8]
# GBPUSD 10 [-0.51166667]
# EURUSD 10 [0.86]
# USDJPY 30 [-0.83428571]
# USDCAD 15 [-1.]
# AUDUSD 50 [0.62179323]
# NZDUSD 10 [1.]
# GBPCHF 20 [-0.003]
# EURCHF 10 [-0.58576984]
# CHFJPY 15 [-0.47395238]
# CADCHF 10 [1.]
# NZDCHF 30 [0.72648729]
# EURGBP 10 [0.06]
# GBPJPY 15 [0.06]
# GBPCAD 30 [0.56191126]
# GBPAUD 15 [-0.65850722]
# EURJPY 15 [-0.46]
# EURCAD 10 [-1.]
# EURAUD 10 [-0.78001587]
# EURNZD 10 [-1.]
# AUDJPY 10 [-0.302]
# NZDJPY 50 [0.51556277]
# AUDCAD 30 [1.]
# ['S', 'S', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B']
# USDCHF 10 [-0.18]
# GBPUSD 20 [0.32328649]
# EURUSD 10 [0.14]
# USDJPY 15 [-0.94]
# USDCAD 20 [0.30228127]
# NZDUSD 15 [1.]
# GBPCHF 10 [0.48799206]
# EURCHF 10 [-0.45422222]
# CHFJPY 15 [0.81313437]
# CADCHF 10 [0.57466667]
# EURGBP 10 [0.64259524]
# GBPJPY 15 [0.94]
# GBPCAD 20 [-0.72028355]
# EURJPY 10 [0.75000794]
# EURCAD 10 [-0.982]
# EURAUD 10 [0.29633333]
# AUDJPY 10 [1.]
# NZDJPY 10 [0.48633333]
# ['S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B']
# USDCHF 10 [-0.47633333]
# GBPUSD 20 [0.55808164]
# EURUSD 30 [0.38795238]
# USDJPY 15 [1.]
# USDCAD 10 [-0.72]
# NZDUSD 50 [-0.2333776]
# GBPCHF 30 [0.35607251]
# EURCHF 15 [0.57821695]
# CADCHF 20 [0.83]
# EURGBP 10 [1.]
# GBPJPY 10 [1.]
# GBPCAD 20 [-0.77455561]
# GBPAUD 10 [0.71311905]
# EURJPY 10 [0.3365]
# EURCAD 10 [0.65203968]
# EURAUD 30 [0.34857143]
# AUDCAD 15 [-0.04634427]
# NZDCAD 15 [-0.13485714]
# ['S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'S']
# USDCHF 10 [-1.]
# GBPUSD 10 [1.]
# EURUSD 30 [0.16771429]
# USDJPY 10 [-0.48]
# NZDUSD 50 [-0.28698875]
# EURCHF 15 [-0.26638095]
# CHFJPY 10 [-0.98]
# GBPJPY 30 [0.67225354]
# GBPAUD 10 [1.]
# EURJPY 15 [0.59843651]
# EURAUD 10 [-1.]
# EURNZD 15 [-0.22985714]
# ['S', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S']
# GBPUSD 10 [-0.78]
# EURUSD 10 [-1.]
# USDJPY 20 [0.84]
# NZDUSD 10 [-0.275]
# EURCHF 10 [-0.3]
# GBPJPY 10 [-0.82]
# GBPAUD 50 [-0.04442857]
# EURJPY 10 [-0.964]
# EURCAD 10 [-0.4]
# EURAUD 10 [-1.]
# EURNZD 15 [-1.]
# ['S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S']
# USDCHF 50 [0.3]
# GBPUSD 10 [0.9]
# EURUSD 20 [0.45657143]
# USDJPY 20 [0.4]
# NZDUSD 10 [1.]
# EURCHF 20 [0.61528571]
# CADCHF 15 [0.93833333]
# NZDCHF 10 [-0.46821429]
# GBPJPY 15 [0.53405922]
# GBPCAD 15 [-0.63775763]
# GBPAUD 15 [-0.46207071]
# EURJPY 10 [0.69950794]
# EURCAD 10 [0.177]
# NZDJPY 10 [1.]
# NZDCAD 10 [-0.42933333]
# ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.15697619]
# GBPUSD 50 [0.54829059]
# EURUSD 10 [-0.13507937]
# USDJPY 10 [-0.82]
# USDCAD 10 [0.17892063]
# AUDUSD 20 [-0.21256349]
# NZDUSD 10 [-0.34533333]
# EURCHF 20 [-0.11999711]
# CADCHF 10 [-1.]
# GBPJPY 10 [-0.23990476]
# GBPAUD 15 [0.86]
# EURAUD 10 [0.94]
# NZDJPY 10 [-0.24033333]
# AUDCAD 20 [-0.44787002]
# NZDCAD 15 [-0.01919048]
# ['B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S']
# USDCHF 10 [0.33472222]
# EURUSD 10 [-0.31469841]
# USDJPY 15 [1.]
# AUDUSD 10 [-0.29278571]
# EURCHF 10 [0.7191746]
# CHFJPY 50 [-0.09641441]
# CADCHF 10 [0.68]
# EURGBP 10 [-0.63028571]
# GBPJPY 15 [0.49783838]
# GBPAUD 10 [1.]
# CADJPY 10 [-0.974]
# NZDJPY 50 [-0.09444838]
# AUDCAD 20 [-0.26909091]
# AUDNZD 15 [-0.80265257]
# ['B', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'S']
# USDCHF 10 [0.64847619]
# GBPUSD 10 [-0.19825397]
# EURUSD 50 [-0.27478016]
# USDJPY 10 [0.92]
# USDCAD 10 [0.63294444]
# AUDUSD 10 [-0.61697619]
# NZDUSD 10 [-0.17104762]
# GBPCHF 20 [0.70246204]
# CHFJPY 30 [-0.0684242]
# CADCHF 10 [1.]
# EURGBP 30 [-0.37213966]
# GBPJPY 30 [0.43265898]
# GBPAUD 10 [-0.17989683]
# EURCAD 10 [-0.66294444]
# CADJPY 10 [0.33376984]
# AUDJPY 50 [-0.06069966]
# AUDCAD 15 [-0.66495238]
# AUDNZD 10 [0.28681746]
# ['B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'B']
# USDCHF 10 [-1.]
# GBPUSD 10 [-0.35602381]
# EURUSD 10 [0.01594444]
# USDJPY 15 [0.36]
# USDCAD 20 [0.28060942]
# AUDUSD 10 [-0.67340476]
# NZDUSD 10 [-0.30570635]
# GBPCHF 20 [0.62219525]
# EURCHF 10 [-0.988]
# CHFJPY 10 [0.978]
# CADCHF 10 [0.4015]
# EURGBP 30 [0.63661305]
# GBPJPY 50 [0.45781956]
# GBPAUD 10 [-0.64083333]
# EURCAD 10 [0.01203175]
# CADJPY 10 [0.33187302]
# NZDJPY 50 [0.03487369]
# AUDCAD 10 [-0.18273016]
# AUDNZD 10 [0.60976984]
# ['S', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B']
# USDCHF 10 [0.7087381]
# GBPUSD 10 [-0.6430873]
# EURUSD 10 [-0.56580952]
# USDJPY 15 [1.]
# AUDUSD 10 [-0.64420635]
# NZDUSD 10 [-0.67445238]
# GBPCHF 20 [0.67337005]
# CHFJPY 10 [-0.52342857]
# NZDCHF 10 [-0.33244444]
# GBPJPY 50 [-0.22706936]
# GBPCAD 10 [-1.]
# GBPAUD 10 [0.35630159]
# EURCAD 10 [-1.]
# CADJPY 10 [-0.65507143]
# NZDJPY 15 [-0.49538095]
# AUDCAD 10 [-1.]
# NZDCAD 15 [-1.]
# AUDNZD 10 [-0.3265]
# ['B', 'S', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S']
# USDCHF 10 [-0.984]
# GBPUSD 10 [1.]
# EURUSD 10 [1.]
# USDJPY 15 [-0.82]
# AUDUSD 10 [1.]
# CHFJPY 10 [0.982]
# CADCHF 50 [-0.72989017]
# NZDCHF 10 [1.]
# GBPJPY 50 [0.40665261]
# GBPCAD 10 [1.]
# GBPAUD 10 [-0.33872222]
# EURCAD 10 [1.]
# CADJPY 10 [0.29042857]
# NZDJPY 50 [0.70811151]
# AUDCAD 10 [1.]
# NZDCAD 10 [0.38]
# AUDNZD 50 [0.38739275]
# ['S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B']
# GBPUSD 10 [-0.60780952]
# EURUSD 30 [-0.0995875]
# USDJPY 10 [0.74]
# EURCHF 10 [0.70115873]
# CADCHF 10 [1.]
# NZDCHF 10 [-0.59292063]
# GBPJPY 50 [-0.23991336]
# GBPCAD 10 [-0.54]
# GBPAUD 10 [1.]
# EURCAD 10 [-1.]
# EURNZD 30 [0.34707565]
# CADJPY 10 [-1.]
# NZDJPY 10 [1.]
# AUDCAD 10 [-1.]
# NZDCAD 10 [-1.]
# AUDNZD 50 [0.37281214]
# ['S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B']
# GBPUSD 10 [1.]
# EURUSD 30 [0.76741225]
# USDJPY 10 [-1.]
# GBPCHF 10 [1.]
# EURCHF 15 [-0.56427778]
# CADCHF 20 [-0.98]
# NZDCHF 50 [0.24769361]
# EURGBP 10 [-1.]
# GBPJPY 50 [0.4234979]
# GBPCAD 10 [1.]
# EURCAD 10 [1.]
# EURAUD 15 [-0.4295469]
# EURNZD 10 [-1.]
# AUDCAD 10 [0.96]
# NZDCAD 10 [1.]
# ['B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B']
# USDCHF 50 [-0.54596395]
# EURUSD 50 [-0.15322917]
# USDJPY 10 [0.1]
# USDCAD 15 [-0.78602142]
# NZDUSD 10 [0.984]
# GBPCHF 10 [-0.32561905]
# CHFJPY 30 [0.72421894]
# CADCHF 20 [0.74]
# NZDCHF 10 [0.97]
# GBPCAD 10 [-1.]
# GBPAUD 10 [0.992]
# EURCAD 10 [-1.]
# EURAUD 30 [0.24553862]
# EURNZD 10 [-0.926]
# NZDJPY 10 [0.946]
# AUDCAD 10 [-0.68592857]
# NZDCAD 10 [-1.]
# ['S', 'S', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'S']
# USDCHF 50 [0.3239724]
# EURUSD 50 [-0.22321105]
# USDJPY 10 [1.]
# USDCAD 50 [0.24741752]
# AUDUSD 30 [-0.09402845]
# NZDUSD 50 [-0.42504762]
# EURCHF 10 [1.]
# CADCHF 10 [0.74419841]
# AUDCHF 20 [0.05474242]
# GBPCAD 10 [-0.7327619]
# GBPAUD 10 [0.86]
# EURCAD 10 [-0.64900794]
# EURAUD 10 [0.988]
# AUDJPY 30 [-0.39126302]
# NZDJPY 20 [1.]
# AUDCAD 10 [-0.26897619]
# NZDCAD 10 [-1.]
# ['B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'S']
# USDCHF 50 [-0.55076571]
# GBPUSD 15 [-0.50142857]
# EURUSD 30 [0.66596063]
# USDJPY 50 [-0.25581179]
# USDCAD 15 [0.40146465]
# NZDUSD 20 [-0.58505134]
# GBPCHF 10 [-0.31873016]
# EURCHF 10 [-0.24747619]
# CHFJPY 50 [0.79731208]
# CADCHF 20 [-0.50573882]
# AUDCHF 15 [-0.32206349]
# EURGBP 10 [0.32521429]
# GBPJPY 15 [-0.42832756]
# GBPCAD 10 [1.]
# GBPAUD 15 [-0.94]
# EURCAD 50 [-0.48533333]
# EURAUD 10 [-0.34411905]
# CADJPY 20 [-0.37628571]
# AUDJPY 30 [0.41736685]
# NZDJPY 15 [-0.54571212]
# NZDCAD 10 [0.66833333]
# ['S', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'B']
# USDCHF 30 [0.0531284]
# GBPUSD 10 [0.46]
# EURUSD 50 [0.29764361]
# USDJPY 20 [-0.57885753]
# NZDUSD 50 [0.14507589]
# GBPCHF 20 [-0.67603102]
# EURCHF 10 [1.]
# CHFJPY 50 [0.80356757]
# CADCHF 20 [-0.42]
# AUDCHF 15 [1.]
# GBPJPY 10 [0.976]
# GBPAUD 10 [-1.]
# EURCAD 10 [1.]
# EURAUD 10 [1.]
# CADJPY 20 [-0.19]
# NZDJPY 30 [0.68510534]
# NZDCAD 10 [-0.992]
# ['B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S']
# EURUSD 30 [-0.06300383]
# USDJPY 20 [0.47491987]
# GBPCHF 10 [-0.98]
# CHFJPY 50 [0.85]
# CADCHF 20 [0.38342388]
# AUDCHF 20 [0.89866667]
# EURGBP 10 [0.934]
# GBPJPY 10 [-0.31276984]
# GBPAUD 15 [0.12]
# EURCAD 20 [-0.18075781]
# EURAUD 10 [-0.24872222]
# NZDJPY 30 [0.52205556]
# NZDCAD 50 [-0.08965657]
# AUDNZD 15 [0.6032619]
# ['S', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B']
# GBPUSD 10 [0.57233333]
# USDJPY 50 [-0.21382703]
# USDCAD 50 [0.2792114]
# GBPCHF 50 [-0.84575441]
# CHFJPY 20 [0.8228961]
# AUDCHF 10 [-0.12896032]
# EURGBP 50 [-0.73904288]
# GBPJPY 10 [-0.15538095]
# EURJPY 10 [0.04933333]
# EURCAD 20 [1.]
# EURAUD 15 [-0.98533333]
# AUDJPY 50 [0.57562723]
# NZDCAD 50 [-0.36446898]
# AUDNZD 15 [-0.52942641]
# ['B', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S']
# USDCAD 50 [-0.02595238]
# AUDCHF 10 [1.]
# NZDCHF 10 [-0.67980952]
# GBPJPY 10 [1.]
# GBPAUD 20 [-0.03545455]
# EURCAD 20 [-0.15612042]
# EURAUD 10 [0.44600794]
# EURNZD 20 [0.51722835]
# CADJPY 50 [0.47525074]
# AUDJPY 50 [0.05811476]
# NZDJPY 30 [-0.44609746]
# AUDNZD 15 [0.26871889]
# ['S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B']
# GBPUSD 10 [-0.98333333]
# EURUSD 10 [-0.34033333]
# USDCAD 50 [0.06766667]
# AUDUSD 10 [-0.291]
# GBPCHF 10 [-1.]
# EURCHF 30 [-0.45260463]
# CHFJPY 15 [-0.2155873]
# NZDCHF 50 [0.2362181]
# EURGBP 10 [1.]
# GBPJPY 10 [0.52052381]
# GBPAUD 20 [-1.]
# EURJPY 10 [-0.37609524]
# EURAUD 20 [-1.]
# EURNZD 20 [-0.62452237]
# CADJPY 10 [-1.]
# AUDJPY 15 [-0.29541342]
# AUDCAD 10 [-0.19884127]
# NZDCAD 30 [-0.32745238]
# AUDNZD 50 [-0.10138095]
# ['S', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S']
# GBPUSD 10 [0.44380952]
# EURUSD 10 [0.80180952]
# AUDUSD 10 [0.77301587]
# NZDUSD 15 [0.59310939]
# GBPCHF 10 [-1.]
# EURCHF 20 [1.]
# CHFJPY 10 [1.]
# NZDCHF 10 [-1.]
# EURGBP 10 [0.992]
# GBPJPY 15 [1.]
# GBPAUD 20 [0.39048268]
# EURJPY 10 [0.73709524]
# EURNZD 10 [1.]
# CADJPY 10 [0.72000794]
# AUDJPY 10 [1.]
# AUDCAD 15 [-0.14230159]
# NZDCAD 50 [-0.26352381]
# AUDNZD 50 [0.46]
# ['B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B']
# GBPUSD 10 [0.50357937]
# EURUSD 10 [0.79257937]
# USDCAD 10 [0.968]
# AUDUSD 10 [0.77609524]
# NZDUSD 15 [0.79641736]
# GBPCHF 10 [-0.968]
# CHFJPY 10 [1.]
# NZDCHF 10 [0.62385714]
# EURGBP 10 [1.]
# GBPAUD 15 [0.22854007]
# EURJPY 10 [0.72797619]
# EURNZD 10 [-0.57899206]
# CADJPY 10 [-0.32]
# AUDJPY 15 [0.14]
# AUDCAD 10 [0.82925397]
# NZDCAD 10 [1.]
# AUDNZD 10 [-0.12]
# ['B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S']
# GBPUSD 10 [0.74871429]
# EURUSD 10 [0.7780873]
# USDCAD 15 [0.02]
# AUDUSD 10 [0.78739683]
# NZDUSD 15 [-0.05404762]
# GBPCHF 10 [0.26050794]
# CHFJPY 10 [0.988]
# EURGBP 15 [-0.39931746]
# GBPJPY 30 [-0.97]
# GBPCAD 15 [0.69156926]
# GBPAUD 15 [0.44856494]
# EURJPY 10 [0.77452381]
# CADJPY 10 [1.]
# AUDJPY 10 [1.]
# NZDJPY 50 [0.82677778]
# AUDCAD 10 [0.76388889]
# NZDCAD 10 [0.18]
# AUDNZD 10 [1.]
# ['B', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']
# GBPUSD 10 [-0.07959524]
# USDCAD 50 [-1.]
# NZDUSD 10 [0.46704762]
# GBPCHF 10 [-0.21375397]
# CHFJPY 20 [0.04557143]
# CADCHF 30 [0.46385565]
# AUDCHF 10 [-0.19350794]
# EURGBP 15 [-0.45243867]
# GBPCAD 10 [-0.93]
# GBPAUD 15 [-0.5397043]
# EURAUD 10 [-0.73587302]
# CADJPY 10 [0.73378571]
# NZDCAD 10 [-0.38]
# AUDNZD 10 [0.3289127]
# ['S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'B']
# GBPUSD 10 [0.66698413]
# USDJPY 30 [0.21783652]
# USDCAD 10 [-1.]
# GBPCHF 10 [0.6564127]
# CADCHF 30 [0.61088412]
# AUDCHF 10 [0.88]
# EURGBP 20 [0.6305295]
# GBPJPY 15 [0.58288883]
# GBPCAD 10 [-0.26787302]
# GBPAUD 15 [-0.18809524]
# EURAUD 10 [-1.]
# CADJPY 10 [1.]
# AUDJPY 50 [-0.03400832]
# NZDCAD 50 [0.41466667]
# AUDNZD 10 [-0.65881746]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'S']
# USDCHF 30 [1.]
# GBPUSD 10 [-0.83512698]
# EURUSD 20 [-1.]
# USDJPY 30 [-0.46083189]
# USDCAD 10 [-0.72]
# GBPCHF 10 [-0.1712619]
# CHFJPY 15 [-1.]
# CADCHF 15 [0.96]
# AUDCHF 10 [-0.56]
# EURGBP 15 [-0.48426462]
# GBPCAD 10 [-0.964]
# GBPAUD 10 [0.94]
# EURCAD 10 [-0.34079365]
# EURAUD 10 [0.52]
# CADJPY 10 [-0.06]
# AUDJPY 10 [-0.942]
# NZDCAD 15 [0.01280952]
# AUDNZD 10 [0.7865873]
# ['B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B']
# USDCHF 15 [0.46537374]
# GBPUSD 20 [-0.08602742]
# EURUSD 15 [-0.78]
# USDJPY 30 [-0.19929183]
# USDCAD 10 [0.98]
# NZDUSD 10 [-0.798]
# GBPCHF 15 [0.10495238]
# EURCHF 10 [-0.964]
# CHFJPY 10 [-0.96]
# CADCHF 10 [-0.89204762]
# AUDCHF 15 [-0.02733333]
# EURGBP 50 [0.15316234]
# GBPJPY 15 [-0.8]
# GBPCAD 50 [-0.49290476]
# GBPAUD 20 [0.4634449]
# EURJPY 10 [-0.96]
# EURCAD 10 [-0.32605556]
# EURAUD 15 [-0.04995238]
# CADJPY 10 [-0.12]
# NZDJPY 15 [-0.98]
# NZDCAD 15 [1.]
# AUDNZD 15 [-0.31967027]
# ['B', 'S', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'S']
# GBPUSD 30 [-0.031]
# EURUSD 10 [-0.46]
# USDJPY 30 [0.51749324]
# USDCAD 15 [-0.43361905]
# NZDUSD 10 [0.69395238]
# GBPCHF 10 [1.]
# CHFJPY 10 [-0.7]
# CADCHF 30 [0.44865359]
# AUDCHF 10 [0.76]
# GBPJPY 10 [-0.34]
# GBPCAD 50 [0.37547619]
# EURJPY 10 [-0.62]
# EURAUD 10 [-0.78]
# EURNZD 15 [1.]
# CADJPY 10 [0.98]
# NZDCAD 20 [0.78977733]
# AUDNZD 20 [-0.13799334]
# ['S', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'S']
# GBPUSD 10 [-0.4]
# EURUSD 15 [-0.74666667]
# NZDUSD 10 [-0.05733333]
# GBPCHF 10 [-0.982]
# CHFJPY 10 [0.62709524]
# GBPJPY 10 [-0.36]
# GBPCAD 10 [-0.87257143]
# EURJPY 10 [0.63960317]
# EURCAD 10 [-0.62757937]
# CADJPY 10 [-0.92]
# NZDCAD 15 [-0.29301371]
# ['S', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'S']
# USDCHF 10 [0.962]
# GBPUSD 10 [-0.914]
# EURUSD 10 [-0.944]
# NZDUSD 10 [1.]
# GBPCHF 10 [1.]
# CADCHF 30 [0.57656349]
# GBPJPY 10 [-0.922]
# GBPCAD 15 [-0.55477778]
# EURNZD 10 [-0.97]
# NZDJPY 10 [1.]
# AUDCAD 15 [0.79844578]
# NZDCAD 20 [-0.27167954]
# ['B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S']
# USDCHF 15 [0.22680952]
# GBPUSD 10 [1.]
# EURUSD 10 [0.72024603]
# USDCAD 50 [-0.40795949]
# AUDUSD 20 [0.73566495]
# NZDUSD 10 [-0.64511905]
# GBPCHF 10 [0.913]
# CADCHF 15 [0.68606277]
# GBPJPY 10 [0.70444444]
# EURCAD 50 [-0.24831746]
# EURAUD 50 [-0.43203248]
# EURNZD 10 [1.]
# CADJPY 50 [0.45127146]
# AUDJPY 50 [0.13930738]
# NZDJPY 10 [-0.94]
# AUDCAD 20 [0.73380719]
# NZDCAD 20 [0.79743867]
# AUDNZD 20 [1.]
# ['B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B']
# USDCHF 30 [-0.59850505]
# GBPUSD 10 [1.]
# EURUSD 15 [0.56019048]
# AUDUSD 15 [-0.50136075]
# NZDUSD 15 [0.24]
# GBPCHF 10 [1.]
# EURCHF 10 [-0.60046032]
# CHFJPY 10 [-0.58757143]
# AUDCHF 10 [-0.22819048]
# GBPJPY 15 [0.51371429]
# EURJPY 10 [-0.64826984]
# EURAUD 20 [0.17656277]
# EURNZD 30 [0.98]
# NZDJPY 15 [0.27766667]
# AUDCAD 20 [0.276]
# NZDCAD 15 [-0.47731385]
# AUDNZD 20 [0.64]
# ['S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B']
# USDCHF 30 [-0.50214286]
# GBPUSD 10 [0.65357143]
# EURUSD 10 [-0.48606349]
# USDCAD 10 [0.982]
# AUDUSD 15 [-0.70840476]
# NZDUSD 10 [-0.984]
# EURCHF 10 [-1.]
# CHFJPY 10 [-0.982]
# CADCHF 10 [-0.985]
# NZDCHF 10 [-1.]
# EURGBP 10 [-0.972]
# GBPJPY 10 [-0.45061905]
# GBPCAD 15 [0.70304762]
# GBPAUD 15 [0.75969841]
# EURJPY 10 [-0.952]
# EURCAD 20 [-0.56035714]
# EURAUD 20 [0.64308369]
# EURNZD 10 [1.]
# CADJPY 10 [-0.988]
# AUDJPY 20 [-0.38090476]
# NZDJPY 10 [-1.]
# AUDCAD 15 [-0.68403752]
# NZDCAD 20 [-0.62319697]
# AUDNZD 50 [0.85833333]
# ['S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'B']
# USDCHF 50 [0.505]
# GBPUSD 10 [0.52825397]
# AUDUSD 30 [-0.42084854]
# NZDUSD 10 [0.31361905]
# GBPCHF 10 [-0.37299206]
# EURCHF 50 [-0.99]
# CHFJPY 10 [0.41926984]
# CADCHF 10 [-0.92]
# AUDCHF 50 [-0.33512095]
# NZDCHF 10 [0.47159524]
# EURGBP 10 [0.45062698]
# GBPJPY 15 [-0.48]
# GBPCAD 15 [-0.55881363]
# GBPAUD 15 [0.35704762]
# EURJPY 10 [0.39734921]
# EURCAD 10 [-0.68980952]
# EURAUD 15 [-0.72275397]
# EURNZD 50 [-0.20474596]
# AUDJPY 20 [0.23005988]
# NZDJPY 10 [1.]
# AUDCAD 15 [0.78924797]
# NZDCAD 15 [0.54065734]
# AUDNZD 20 [-1.]
# ['B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [-1.]
# GBPUSD 50 [0.61333333]
# EURUSD 10 [0.9]
# NZDUSD 10 [-0.958]
# EURCHF 10 [0.96]
# CHFJPY 10 [0.37399206]
# CADCHF 10 [-1.]
# NZDCHF 10 [-0.99]
# GBPJPY 10 [0.3]
# GBPCAD 20 [0.98722222]
# GBPAUD 10 [1.]
# EURJPY 10 [0.40043651]
# EURCAD 10 [0.37887302]
# EURNZD 10 [1.]
# AUDJPY 10 [-1.]
# NZDJPY 15 [0.32]
# AUDNZD 15 [0.52745238]
# ['S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B']
# USDCHF 30 [0.916]
# EURUSD 20 [-0.94]
# USDCAD 10 [0.78]
# AUDUSD 10 [-0.66294444]
# NZDUSD 15 [-1.]
# EURCHF 10 [-0.31378571]
# CHFJPY 10 [-0.57106349]
# CADCHF 20 [0.26813978]
# AUDCHF 20 [-0.76543989]
# NZDCHF 10 [-0.94]
# EURGBP 50 [0.63840302]
# GBPJPY 10 [-1.]
# GBPCAD 10 [0.986]
# GBPAUD 10 [0.38]
# EURJPY 50 [-0.3602381]
# EURCAD 10 [-0.34049206]
# EURNZD 15 [0.93]
# AUDJPY 10 [-0.62]
# NZDJPY 10 [-0.64]
# AUDCAD 10 [-0.56128571]
# NZDCAD 10 [-0.64197619]
# AUDNZD 10 [-0.66037302]
# ['B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S']
# USDCHF 50 [-0.55407937]
# GBPUSD 50 [0.4058857]
# EURUSD 15 [0.72130087]
# USDCAD 10 [-0.66368254]
# NZDUSD 15 [-0.2]
# EURCHF 10 [0.38730159]
# CHFJPY 15 [0.69536508]
# CADCHF 10 [-0.35148413]
# NZDCHF 10 [0.08]
# GBPJPY 10 [0.46390476]
# GBPCAD 20 [0.97333333]
# GBPAUD 10 [0.3367381]
# EURJPY 50 [0.39866667]
# EURCAD 10 [-0.9]
# EURNZD 15 [0.72]
# AUDJPY 10 [1.]
# NZDJPY 10 [1.]
# NZDCAD 20 [0.437]
# AUDNZD 10 [-0.47316667]
# ['S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [-0.988]
# GBPUSD 50 [-0.45965353]
# EURUSD 10 [0.98666667]
# USDCAD 10 [-1.]
# NZDUSD 50 [-0.06]
# EURCHF 10 [-0.59761905]
# CHFJPY 10 [0.968]
# NZDCHF 10 [0.92]
# EURGBP 50 [-1.]
# GBPJPY 10 [0.98]
# GBPCAD 10 [-0.33863492]
# EURJPY 10 [1.]
# EURCAD 10 [-0.1]
# EURNZD 10 [-0.54]
# CADJPY 10 [0.41387302]
# AUDJPY 10 [1.]
# NZDJPY 10 [1.]
# AUDNZD 10 [0.56]
# ['S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B']
# USDCHF 10 [0.69757143]
# GBPUSD 50 [0.06641703]
# EURUSD 10 [-0.67334127]
# USDJPY 20 [1.]
# USDCAD 10 [1.]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# EURCHF 10 [-0.988]
# CHFJPY 10 [-0.64342857]
# CADCHF 20 [0.23292857]
# AUDCHF 10 [-0.982]
# NZDCHF 10 [-1.]
# GBPJPY 10 [-0.84]
# GBPCAD 30 [0.98240909]
# GBPAUD 10 [1.]
# EURJPY 10 [-0.34188889]
# EURAUD 10 [1.]
# EURNZD 10 [1.]
# CADJPY 10 [0.68622222]
# AUDJPY 10 [-0.54874603]
# NZDJPY 10 [-0.63733333]
# AUDCAD 10 [-0.984]
# NZDCAD 10 [-1.]
# AUDNZD 50 [0.56666667]
# ['B', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 10 [-0.986]
# GBPUSD 10 [1.]
# EURUSD 10 [0.984]
# USDJPY 15 [0.90316667]
# USDCAD 10 [-0.54410317]
# AUDUSD 10 [0.96]
# NZDUSD 10 [0.94]
# GBPCHF 20 [-0.42887266]
# CHFJPY 10 [1.]
# CADCHF 15 [-1.]
# NZDCHF 50 [-0.92588235]
# EURGBP 50 [-0.98]
# GBPJPY 50 [0.27451565]
# GBPAUD 50 [0.21912204]
# EURJPY 15 [1.]
# EURCAD 10 [0.2938254]
# EURNZD 10 [-0.59562698]
# CADJPY 10 [0.54884127]
# NZDJPY 30 [1.]
# AUDCAD 10 [0.5512619]
# NZDCAD 10 [0.96]
# AUDNZD 10 [0.50430952]
# ['S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B']
# USDCHF 10 [0.67242063]
# EURUSD 10 [-0.62602381]
# USDJPY 15 [0.12222222]
# USDCAD 10 [1.]
# AUDUSD 10 [0.22]
# NZDUSD 10 [0.04]
# GBPCHF 10 [-0.99]
# CHFJPY 10 [0.42]
# CADCHF 10 [-0.75844444]
# EURGBP 10 [0.99]
# GBPJPY 20 [-0.63933333]
# GBPCAD 30 [-1.]
# EURJPY 15 [0.86]
# EURCAD 30 [-1.]
# CADJPY 10 [0.42]
# AUDNZD 10 [1.]
# ['B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B']
# USDCHF 10 [-0.926]
# EURUSD 10 [0.906]
# USDJPY 15 [-0.1222381]
# USDCAD 10 [0.6]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 20 [-0.48861996]
# EURCHF 50 [-0.48364007]
# CHFJPY 10 [-0.3]
# CADCHF 10 [-0.71104762]
# AUDCHF 15 [-0.78920052]
# GBPJPY 10 [-0.46]
# GBPAUD 50 [0.21022076]
# EURJPY 10 [-0.92]
# EURCAD 20 [0.48590136]
# EURAUD 10 [0.76264286]
# CADJPY 20 [-0.40425819]
# AUDJPY 30 [-0.02613186]
# AUDCAD 30 [-0.43043887]
# NZDCAD 10 [-0.74125397]
# AUDNZD 10 [0.78]
# ['S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 15 [-1.]
# GBPUSD 20 [-0.02580808]
# EURUSD 15 [-0.56569397]
# USDJPY 20 [-0.51448557]
# USDCAD 10 [1.]
# AUDUSD 15 [-0.55373959]
# NZDUSD 30 [0.598]
# GBPCHF 10 [0.32611111]
# CHFJPY 10 [-0.96]
# CADCHF 10 [-0.7504127]
# EURGBP 10 [-0.6793254]
# GBPJPY 10 [0.82]
# GBPCAD 10 [1.]
# GBPAUD 50 [-0.05617682]
# EURJPY 10 [-0.92]
# EURCAD 10 [0.33742857]
# EURAUD 10 [0.76242063]
# EURNZD 10 [-0.57815873]
# CADJPY 20 [-0.45102065]
# AUDJPY 15 [1.]
# NZDJPY 30 [0.552]
# AUDCAD 30 [-0.42249891]
# AUDNZD 50 [0.77333333]
# ['S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B']
# GBPUSD 20 [0.87666667]
# EURUSD 15 [-0.45236508]
# USDJPY 10 [-0.42486508]
# USDCAD 10 [0.06]
# AUDUSD 20 [-0.72641558]
# NZDUSD 10 [-1.]
# GBPCHF 10 [-1.]
# CHFJPY 30 [0.362]
# CADCHF 30 [1.]
# EURGBP 20 [0.62369442]
# GBPJPY 15 [0.08166667]
# GBPCAD 10 [0.72]
# GBPAUD 20 [-0.34216417]
# EURJPY 20 [-0.88]
# EURCAD 10 [-0.52570635]
# EURNZD 10 [1.]
# CADJPY 10 [-0.42715079]
# AUDJPY 15 [0.00944661]
# NZDJPY 30 [-0.38129643]
# AUDNZD 50 [0.01]
# ['B', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'S', 'B', 'S', 'B']
# GBPUSD 20 [0.448]
# EURUSD 50 [-0.97466667]
# USDJPY 20 [-0.36971501]
# USDCAD 10 [1.]
# AUDUSD 10 [-1.]
# NZDUSD 15 [-1.]
# CHFJPY 30 [0.73]
# CADCHF 30 [0.96]
# NZDCHF 10 [0.27700794]
# EURGBP 10 [0.86]
# GBPJPY 10 [-0.34]
# GBPCAD 10 [0.36]
# GBPAUD 50 [-0.79170831]
# EURJPY 20 [0.772]
# EURCAD 15 [0.43932423]
# EURNZD 15 [-0.87474242]
# CADJPY 20 [-0.32692352]
# AUDJPY 10 [-0.30385714]
# NZDJPY 10 [-0.34749206]
# NZDCAD 10 [-0.57395238]
# AUDNZD 10 [0.32]
# ['B', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'B']
# USDCHF 10 [0.98]
# EURUSD 10 [-1.]
# USDCAD 10 [0.88]
# AUDUSD 10 [-1.]
# NZDUSD 20 [-0.57142857]
# GBPCHF 10 [0.3749127]
# EURCHF 15 [-0.77553691]
# CHFJPY 20 [-1.]
# CADCHF 15 [0.701]
# AUDCHF 10 [0.20021429]
# NZDCHF 10 [0.39433333]
# EURGBP 10 [0.2]
# GBPJPY 15 [-0.96666667]
# GBPCAD 15 [0.4383254]
# GBPAUD 20 [-0.19977756]
# EURJPY 20 [-0.43604762]
# EURCAD 15 [0.51726701]
# EURAUD 30 [-0.66484848]
# EURNZD 10 [-1.]
# NZDJPY 15 [-0.18083333]
# AUDCAD 10 [0.29883333]
# NZDCAD 10 [0.98]
# AUDNZD 10 [-0.56630952]
# ['B', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S']
# USDCHF 10 [-0.98]
# GBPUSD 20 [0.87766667]
# EURUSD 10 [0.53814286]
# USDCAD 15 [-0.88]
# AUDUSD 10 [0.55735714]
# NZDUSD 30 [0.2]
# GBPCHF 30 [1.]
# EURCHF 20 [0.08748266]
# CHFJPY 20 [1.]
# CADCHF 15 [-0.42]
# AUDCHF 15 [-0.55877128]
# EURGBP 20 [-0.96]
# GBPJPY 20 [1.]
# GBPCAD 10 [0.4]
# GBPAUD 50 [0.21413106]
# EURAUD 20 [-0.52852031]
# EURNZD 10 [-0.08]
# NZDCAD 15 [-0.16]
# AUDNZD 10 [0.74635714]
# ['S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B']
# USDCHF 30 [-0.99]
# GBPUSD 20 [0.6379039]
# EURUSD 20 [0.7]
# USDCAD 10 [0.3]
# AUDUSD 20 [-0.21833333]
# NZDUSD 15 [0.625]
# EURCHF 20 [-0.78982062]
# CHFJPY 15 [1.]
# CADCHF 10 [-1.]
# AUDCHF 30 [-0.50183844]
# GBPJPY 20 [0.7462381]
# GBPCAD 10 [-0.22623016]
# EURCAD 10 [1.]
# EURAUD 30 [0.47670054]
# EURNZD 10 [-0.94]
# AUDCAD 20 [-1.]
# NZDCAD 10 [0.95733333]
# AUDNZD 10 [-0.97333333]
# ['S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'S']
# USDCHF 10 [-1.]
# GBPUSD 20 [-0.41792691]
# EURUSD 30 [-0.98]
# USDCAD 15 [0.98]
# AUDUSD 30 [-1.]
# EURCHF 15 [-0.98]
# CHFJPY 15 [-0.67477778]
# CADCHF 10 [-1.]
# EURGBP 10 [-1.]
# GBPJPY 20 [-0.7]
# GBPCAD 10 [-0.16938095]
# EURJPY 10 [-0.28222222]
# EURCAD 20 [0.25202381]
# EURAUD 10 [1.]
# EURNZD 15 [-0.29725397]
# NZDJPY 15 [-0.50095094]
# AUDCAD 20 [-1.]
# NZDCAD 10 [-0.36621429]
# AUDNZD 10 [0.6335873]
# ['S', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 10 [0.9875]
# GBPUSD 20 [0.61929221]
# EURUSD 30 [-0.38]
# USDCAD 10 [0.98]
# AUDUSD 30 [0.32833333]
# NZDUSD 20 [0.52747619]
# EURCHF 10 [0.63902381]
# CHFJPY 15 [0.15227056]
# CADCHF 10 [-0.924]
# AUDCHF 20 [-1.]
# EURGBP 20 [-1.]
# GBPCAD 10 [-0.37762698]
# EURJPY 10 [0.972]
# EURNZD 15 [0.34593146]
# NZDJPY 15 [0.45266667]
# AUDCAD 20 [-1.]
# NZDCAD 20 [-0.17371429]
# AUDNZD 10 [0.40284127]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'B']
# USDCHF 10 [-0.98]
# GBPUSD 20 [-1.]
# EURUSD 30 [-0.79]
# USDCAD 10 [0.48854762]
# AUDUSD 20 [0.43548879]
# NZDUSD 20 [0.2]
# EURCHF 20 [-0.95981746]
# CHFJPY 15 [-0.03777778]
# CADCHF 10 [-0.946]
# EURGBP 10 [0.22804762]
# GBPJPY 10 [1.]
# GBPCAD 10 [0.36343651]
# GBPAUD 20 [-0.3035089]
# EURJPY 50 [0.32973686]
# EURNZD 10 [0.13759524]
# NZDJPY 15 [-0.05333333]
# AUDCAD 20 [0.38]
# NZDCAD 20 [0.82333333]
# AUDNZD 10 [-0.35889683]
# ['S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S']
# USDCHF 10 [-1.]
# GBPUSD 20 [-0.18]
# EURUSD 15 [1.]
# NZDUSD 50 [-0.89201587]
# EURCHF 10 [-0.984]
# CHFJPY 10 [-0.53950794]
# CADCHF 10 [1.]
# AUDCHF 10 [0.72559524]
# NZDCHF 15 [0.99666667]
# GBPJPY 10 [0.13069048]
# GBPCAD 10 [0.06047619]
# GBPAUD 20 [0.75326795]
# EURJPY 50 [-0.57257612]
# EURCAD 10 [0.97]
# EURAUD 10 [-0.63896825]
# EURNZD 10 [-0.44]
# NZDJPY 10 [-0.5152381]
# NZDCAD 10 [0.984]
# AUDNZD 10 [-0.84]
# ['S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'S']
# USDCHF 10 [0.37583333]
# USDJPY 10 [-0.988]
# AUDUSD 10 [0.39946032]
# NZDUSD 15 [1.]
# GBPCHF 15 [-0.622]
# EURCHF 10 [0.37319841]
# CHFJPY 10 [1.]
# CADCHF 10 [-0.47566667]
# EURGBP 15 [0.99314286]
# GBPAUD 15 [-0.49060101]
# EURJPY 10 [0.32859524]
# EURCAD 10 [0.984]
# EURNZD 15 [-1.]
# CADJPY 10 [-1.]
# NZDJPY 10 [1.]
# AUDCAD 10 [0.995]
# NZDCAD 10 [0.948]
# AUDNZD 10 [-0.956]
# ['B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.62693651]
# GBPUSD 10 [-0.62171429]
# EURUSD 15 [0.23371789]
# USDJPY 50 [0.48524266]
# AUDUSD 10 [0.41696825]
# NZDUSD 15 [-0.94]
# GBPCHF 15 [0.82]
# EURCHF 20 [0.67]
# CHFJPY 15 [-0.41178571]
# CADCHF 10 [0.73495238]
# AUDCHF 10 [1.]
# NZDCHF 15 [-1.]
# GBPCAD 10 [-0.58530952]
# GBPAUD 20 [0.73111977]
# EURJPY 10 [0.32]
# EURCAD 10 [-0.67097619]
# EURAUD 30 [-0.60260196]
# CADJPY 10 [1.]
# AUDCAD 10 [0.71242857]
# NZDCAD 10 [-0.63365079]
# AUDNZD 15 [0.62]
# ['B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B']
# USDCHF 10 [-0.982]
# GBPUSD 10 [-0.53976984]
# EURUSD 10 [-0.67422222]
# USDJPY 20 [0.67768815]
# AUDUSD 10 [0.38315079]
# NZDUSD 15 [0.80257143]
# GBPCHF 15 [-0.09116378]
# EURCHF 10 [-1.]
# CHFJPY 10 [0.72804762]
# CADCHF 10 [0.16]
# AUDCHF 10 [1.]
# NZDCHF 10 [-1.]
# GBPJPY 10 [-0.60413492]
# GBPCAD 10 [-0.61504762]
# EURJPY 15 [-0.94422222]
# EURCAD 10 [-1.]
# EURAUD 30 [0.29151134]
# EURNZD 10 [0.21715079]
# CADJPY 10 [1.]
# AUDJPY 20 [-0.20732928]
# NZDJPY 10 [0.59738095]
# AUDCAD 10 [0.74469048]
# NZDCAD 10 [-1.]
# AUDNZD 10 [1.]
# ['S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B']
# USDCHF 10 [-0.98]
# GBPUSD 15 [0.197]
# EURUSD 20 [0.6]
# USDJPY 50 [0.56757088]
# USDCAD 30 [0.30191847]
# NZDUSD 15 [-0.94]
# GBPCHF 15 [0.55766667]
# EURCHF 10 [-1.]
# CHFJPY 10 [0.07057143]
# CADCHF 10 [-0.68]
# AUDCHF 15 [0.16]
# NZDCHF 10 [-0.94]
# EURGBP 15 [-1.]
# GBPCAD 20 [0.56833333]
# GBPAUD 30 [0.36555676]
# EURCAD 30 [0.04509524]
# EURAUD 30 [-0.4432733]
# EURNZD 10 [0.5681746]
# CADJPY 10 [1.]
# AUDJPY 10 [-0.128]
# NZDJPY 10 [-0.11542857]
# AUDCAD 10 [0.6400873]
# NZDCAD 10 [-0.48]
# AUDNZD 10 [1.]
# ['S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'B']
# USDCHF 10 [1.]
# GBPUSD 50 [-1.]
# EURUSD 10 [-0.98]
# USDJPY 50 [0.37118008]
# USDCAD 30 [0.73178638]
# NZDUSD 15 [-0.53866667]
# GBPCHF 15 [1.]
# EURCHF 10 [0.65153968]
# CHFJPY 10 [-0.98]
# CADCHF 10 [1.]
# AUDCHF 15 [1.]
# NZDCHF 15 [0.06]
# EURGBP 15 [-0.4]
# GBPJPY 10 [-1.]
# GBPCAD 10 [-0.92]
# GBPAUD 50 [-0.61232828]
# EURJPY 10 [-0.84]
# EURCAD 50 [-0.76968254]
# EURAUD 50 [-0.53663556]
# EURNZD 15 [0.65837879]
# CADJPY 10 [1.]
# AUDJPY 10 [-0.59018254]
# NZDJPY 10 [-1.]
# AUDCAD 10 [-0.4]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.97]
# ['B', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 10 [-0.76]
# GBPUSD 15 [-0.22]
# EURUSD 15 [-0.14]
# USDJPY 50 [-0.7374026]
# USDCAD 15 [-0.07546032]
# NZDUSD 10 [-0.33409524]
# GBPCHF 10 [1.]
# EURCHF 30 [-0.03912698]
# CHFJPY 10 [0.54]
# CADCHF 10 [-0.26]
# AUDCHF 10 [-0.47647619]
# NZDCHF 10 [-0.423]
# EURGBP 15 [0.28]
# GBPJPY 10 [0.16]
# GBPCAD 15 [-0.46]
# EURJPY 10 [0.96]
# EURCAD 30 [0.73168171]
# EURNZD 15 [0.41709524]
# AUDJPY 15 [0.78836869]
# NZDJPY 10 [0.66]
# AUDCAD 10 [0.60403968]
# NZDCAD 10 [1.]
# AUDNZD 10 [-0.3000873]
# ['S', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S']
# USDCHF 10 [0.8]
# GBPUSD 15 [0.83512821]
# EURUSD 15 [0.42]
# USDJPY 50 [0.01930303]
# USDCAD 10 [1.]
# AUDUSD 50 [0.37666667]
# NZDUSD 10 [0.74]
# GBPCHF 30 [0.26087302]
# EURCHF 30 [0.29626623]
# CHFJPY 10 [0.42]
# CADCHF 10 [0.7]
# AUDCHF 10 [0.41004762]
# NZDCHF 10 [1.]
# EURGBP 10 [-1.]
# GBPJPY 15 [0.11333333]
# GBPCAD 15 [0.91428571]
# EURJPY 10 [0.45498413]
# EURCAD 10 [-0.988]
# NZDJPY 10 [0.38]
# ...
# GBPJPY 10 [-0.8]
# GBPCAD 10 [0.79590476]
# GBPAUD 30 [0.75785716]
# EURCAD 10 [-0.30966667]
# EURAUD 10 [1.]
# AUDCAD 30 [-0.32413925]
# NZDCAD 30 [0.17190255]
# ['B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'B']
# USDCHF 10 [1.]
# USDJPY 10 [-0.087]
# AUDUSD 50 [-0.49298425]
# GBPCHF 10 [-1.]
# EURCHF 10 [1.]
# GBPCAD 10 [0.74615873]
# GBPAUD 30 [0.48424387]
# EURJPY 10 [-0.18338889]
# EURCAD 15 [1.]
# AUDJPY 15 [-1.]
# AUDCAD 30 [0.25192063]
# AUDNZD 10 [-0.38311111]
# ['B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S']
# USDCHF 10 [-0.2232381]
# GBPUSD 15 [-0.88522222]
# EURUSD 20 [0.99538462]
# USDJPY 10 [0.6135]
# USDCAD 10 [-0.4]
# AUDUSD 50 [-0.05069841]
# GBPCHF 10 [-0.43736508]
# EURCHF 10 [1.]
# CHFJPY 10 [0.10842857]
# CADCHF 50 [-0.7230303]
# NZDCHF 30 [0.57380003]
# GBPJPY 10 [0.98]
# GBPCAD 15 [-0.10466667]
# EURJPY 10 [1.]
# EURCAD 15 [0.78]
# EURAUD 20 [1.]
# ['S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B']
# USDCHF 10 [0.99]
# EURUSD 30 [-1.]
# USDJPY 10 [-0.34004762]
# USDCAD 10 [0.7797619]
# AUDUSD 30 [0.58165633]
# GBPCHF 10 [0.82]
# EURCHF 10 [-0.48457143]
# CADCHF 30 [-0.58339683]
# AUDCHF 15 [0.9475]
# NZDCHF 10 [0.37588889]
# EURGBP 10 [-0.99]
# GBPCAD 10 [-0.22333333]
# GBPAUD 30 [0.48398846]
# EURJPY 10 [-0.37980952]
# EURCAD 10 [-0.18757143]
# EURAUD 15 [-1.]
# EURNZD 30 [-0.33530952]
# AUDJPY 10 [0.938]
# AUDCAD 10 [0.56]
# ['B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B']
# GBPUSD 15 [-0.59188345]
# EURUSD 30 [-0.15838555]
# USDJPY 20 [-0.03142857]
# USDCAD 15 [-0.21738328]
# AUDUSD 15 [0.17205728]
# GBPCHF 10 [0.456]
# CADCHF 30 [0.94333333]
# AUDCHF 15 [0.19704762]
# NZDCHF 30 [-0.38306684]
# EURGBP 15 [-0.96]
# GBPJPY 10 [0.64290476]
# GBPCAD 10 [0.19066667]
# GBPAUD 20 [0.40049138]
# EURJPY 10 [-0.94]
# EURCAD 10 [-0.341]
# EURAUD 15 [-0.35271429]
# EURNZD 15 [1.]
# AUDJPY 10 [0.37103968]
# AUDCAD 10 [0.48]
# ['S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B']
# USDCHF 10 [0.35368254]
# GBPUSD 15 [0.58319841]
# EURUSD 15 [-0.21033333]
# USDJPY 50 [0.1324733]
# USDCAD 10 [1.]
# AUDUSD 30 [0.04848124]
# NZDUSD 20 [0.96]
# GBPCHF 10 [-0.32]
# EURCHF 20 [-0.983]
# CHFJPY 15 [-0.992]
# CADCHF 20 [-0.76444444]
# AUDCHF 15 [0.38]
# NZDCHF 30 [0.65303291]
# EURGBP 15 [1.]
# GBPJPY 10 [-0.54666667]
# GBPCAD 10 [0.70326984]
# GBPAUD 50 [0.60357648]
# EURJPY 10 [1.]
# EURCAD 15 [1.]
# EURAUD 10 [-0.962]
# EURNZD 30 [-1.]
# AUDJPY 10 [0.48]
# NZDJPY 20 [0.44645094]
# AUDCAD 10 [0.76]
# AUDNZD 20 [-0.94333333]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'S']
# GBPUSD 10 [0.95]
# USDJPY 20 [0.82]
# USDCAD 10 [1.]
# AUDUSD 50 [-0.994]
# GBPCHF 50 [0.66]
# CADCHF 10 [-1.]
# AUDCHF 10 [0.838]
# NZDCHF 15 [0.38289683]
# EURGBP 15 [0.34]
# GBPJPY 10 [-0.15457143]
# GBPCAD 10 [1.]
# GBPAUD 30 [-0.1107096]
# EURJPY 10 [1.]
# EURCAD 15 [1.]
# EURAUD 10 [-0.836]
# EURNZD 10 [1.]
# AUDJPY 10 [-0.6]
# AUDCAD 50 [-1.]
# AUDNZD 10 [-0.30550794]
# ['B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S']
# GBPUSD 10 [0.81]
# EURUSD 15 [-0.74933333]
# USDJPY 30 [-0.06984127]
# AUDUSD 15 [-1.]
# NZDUSD 50 [-0.153251]
# GBPCHF 10 [-0.4]
# EURCHF 50 [-0.2800316]
# CADCHF 10 [-0.5]
# AUDCHF 10 [-0.02]
# NZDCHF 20 [0.20475441]
# EURGBP 15 [-0.36]
# GBPJPY 50 [0.78572683]
# GBPCAD 10 [1.]
# EURJPY 10 [0.64]
# EURCAD 10 [-0.26]
# EURAUD 10 [-0.2]
# EURNZD 10 [0.412]
# CADJPY 10 [0.27963492]
# AUDJPY 10 [0.44466667]
# AUDCAD 10 [0.54]
# NZDCAD 10 [-1.]
# AUDNZD 30 [-0.12595238]
# ['B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'S']
# GBPUSD 15 [-0.37301587]
# EURUSD 15 [0.802504]
# USDJPY 15 [0.55590476]
# USDCAD 50 [-0.38712833]
# AUDUSD 10 [-1.]
# NZDUSD 20 [-0.056]
# GBPCHF 10 [-0.52]
# CADCHF 15 [-1.]
# AUDCHF 20 [-0.63232323]
# EURGBP 10 [0.98]
# GBPJPY 20 [1.]
# EURJPY 10 [1.]
# EURCAD 10 [1.]
# EURAUD 10 [1.]
# CADJPY 15 [1.]
# AUDJPY 50 [-0.33871076]
# NZDJPY 20 [-0.25507143]
# AUDCAD 10 [-0.984]
# ['S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'S']
# USDCHF 50 [0.49905295]
# USDCAD 30 [-0.44527334]
# AUDUSD 10 [-1.]
# NZDUSD 15 [-0.83477722]
# GBPCHF 10 [-0.28]
# EURCHF 15 [0.33981419]
# CHFJPY 10 [0.47701587]
# AUDCHF 15 [0.06]
# EURGBP 10 [0.28]
# GBPJPY 50 [0.55243506]
# GBPAUD 30 [-0.58]
# EURJPY 10 [0.5]
# EURCAD 15 [0.32909524]
# EURAUD 10 [0.86]
# EURNZD 10 [-0.486]
# CADJPY 15 [-0.10868254]
# NZDJPY 20 [0.41309524]
# AUDCAD 10 [-0.29395238]
# NZDCAD 10 [0.412]
# ['B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'S', 'B']
# GBPUSD 20 [0.73762438]
# EURUSD 20 [0.99333333]
# AUDUSD 10 [-0.26165079]
# NZDUSD 15 [-0.30966667]
# GBPCHF 10 [-0.4]
# EURCHF 15 [0.26961544]
# CHFJPY 10 [0.45919841]
# CADCHF 15 [0.26390043]
# AUDCHF 15 [-0.23552381]
# NZDCHF 10 [-0.78340476]
# EURGBP 10 [-0.22]
# GBPJPY 30 [0.931]
# GBPAUD 30 [0.8042705]
# EURJPY 10 [0.38919048]
# EURAUD 20 [0.70204762]
# EURNZD 10 [0.77234127]
# CADJPY 15 [-0.38226623]
# NZDJPY 20 [0.50617499]
# AUDCAD 10 [-0.96971429]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.74407143]
# ['B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'B']
# USDCHF 10 [-1.]
# GBPUSD 10 [0.35684921]
# EURUSD 20 [-0.17893026]
# AUDUSD 30 [-0.44035637]
# NZDUSD 10 [0.015]
# GBPCHF 10 [-0.96]
# CHFJPY 15 [0.98]
# CADCHF 15 [-1.]
# NZDCHF 20 [-0.47106352]
# EURGBP 10 [0.95]
# GBPJPY 30 [-0.08193233]
# GBPAUD 10 [0.08433333]
# EURJPY 10 [1.]
# EURAUD 30 [0.37999659]
# CADJPY 15 [-0.37462482]
# AUDJPY 10 [0.41922222]
# NZDJPY 15 [1.]
# AUDCAD 10 [-1.]
# NZDCAD 10 [-1.]
# AUDNZD 15 [-0.06414935]
# ['S', 'B', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'S']
# USDCHF 10 [-1.]
# GBPUSD 10 [-0.37584921]
# EURUSD 20 [0.35966667]
# USDJPY 20 [0.61589261]
# USDCAD 15 [-0.77206349]
# AUDUSD 20 [0.7846397]
# NZDUSD 10 [-1.]
# GBPCHF 10 [0.98]
# CHFJPY 20 [0.66]
# CADCHF 20 [0.74]
# AUDCHF 10 [-0.034]
# NZDCHF 10 [-1.]
# GBPJPY 30 [1.]
# GBPCAD 20 [0.22509068]
# GBPAUD 30 [0.80819131]
# EURJPY 20 [0.95394444]
# EURCAD 10 [1.]
# EURNZD 15 [0.65810761]
# CADJPY 20 [0.79413883]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.7992619]
# ['S', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B']
# USDCHF 10 [-0.58]
# EURUSD 20 [-0.15641708]
# USDCAD 15 [-0.63695221]
# AUDUSD 20 [0.42168254]
# NZDUSD 15 [0.04]
# GBPCHF 10 [1.]
# CHFJPY 10 [-0.02]
# CADCHF 50 [0.74733333]
# AUDCHF 10 [0.01733333]
# NZDCHF 10 [-1.]
# EURGBP 10 [0.57657143]
# GBPJPY 15 [0.78888917]
# GBPAUD 30 [0.77333167]
# EURJPY 50 [-0.59714286]
# EURNZD 50 [0.49741988]
# CADJPY 15 [-0.35875685]
# AUDCAD 10 [0.62330952]
# AUDNZD 10 [0.79729365]
# ['S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B']
# USDCHF 10 [-1.]
# GBPUSD 15 [-0.57358586]
# USDJPY 10 [0.72460317]
# AUDUSD 20 [0.56075397]
# NZDUSD 20 [-0.40847619]
# GBPCHF 10 [0.8]
# CHFJPY 10 [-0.2]
# CADCHF 50 [0.12]
# AUDCHF 10 [0.02]
# NZDCHF 50 [-0.19952397]
# EURGBP 50 [0.35001123]
# GBPJPY 30 [0.84430407]
# GBPAUD 30 [0.76476984]
# EURJPY 20 [-0.16766667]
# EURCAD 10 [0.53019841]
# EURAUD 30 [-0.91]
# EURNZD 50 [0.65236472]
# AUDJPY 10 [0.7263254]
# NZDCAD 15 [0.36166089]
# AUDNZD 10 [0.79792857]
# ['S', 'S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'B']
# USDCHF 10 [-1.]
# GBPUSD 15 [-0.53295005]
# EURUSD 20 [-0.45368565]
# USDJPY 10 [0.65877778]
# USDCAD 20 [0.4613225]
# AUDUSD 10 [0.6772619]
# GBPCHF 10 [0.48]
# EURCHF 10 [-1.]
# CHFJPY 10 [-0.54492857]
# CADCHF 10 [0.56155556]
# AUDCHF 10 [0.56103968]
# EURGBP 30 [0.28017483]
# GBPJPY 30 [0.85554566]
# GBPCAD 15 [0.25118942]
# GBPAUD 30 [0.69372333]
# EURJPY 30 [0.74]
# EURCAD 20 [-0.759171]
# EURAUD 10 [-0.24353968]
# AUDJPY 10 [0.69116667]
# NZDCAD 50 [-0.56378571]
# ['S', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'S']
# USDCHF 15 [-0.78621212]
# EURUSD 20 [-0.44066647]
# USDJPY 10 [-0.4]
# USDCAD 30 [0.58966667]
# NZDUSD 10 [0.82]
# GBPCHF 10 [-0.92]
# EURCHF 10 [0.60355556]
# CHFJPY 10 [1.]
# CADCHF 50 [-0.45654631]
# AUDCHF 30 [-0.35892857]
# NZDCHF 20 [0.78934099]
# GBPJPY 20 [-0.75352958]
# GBPCAD 20 [-0.48798413]
# GBPAUD 15 [-0.67748341]
# EURJPY 15 [0.17269841]
# EURCAD 20 [0.35981139]
# EURAUD 30 [0.28546662]
# EURNZD 15 [-1.]
# CADJPY 50 [-0.67457344]
# AUDJPY 20 [-0.62463492]
# NZDJPY 20 [0.85]
# NZDCAD 15 [0.55630453]
# AUDNZD 10 [-0.72610317]
# ['S', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S']
# USDCHF 15 [0.77155411]
# GBPUSD 10 [1.]
# EURUSD 15 [0.74652986]
# USDJPY 10 [-0.986]
# USDCAD 30 [-1.]
# AUDUSD 15 [0.74821723]
# NZDUSD 10 [-1.]
# GBPCHF 10 [0.98]
# EURCHF 30 [-1.]
# CHFJPY 30 [-0.50594813]
# CADCHF 50 [0.61780572]
# AUDCHF 30 [0.61945101]
# NZDCHF 10 [-1.]
# GBPJPY 50 [0.69196642]
# EURJPY 30 [-0.00642857]
# EURCAD 20 [-0.76964502]
# EURAUD 30 [-0.55750734]
# EURNZD 10 [0.988]
# CADJPY 50 [0.9425]
# AUDJPY 15 [0.71598896]
# NZDJPY 10 [-0.98]
# AUDCAD 50 [0.33190496]
# NZDCAD 10 [-1.]
# AUDNZD 20 [1.]
# ['B', 'B', 'B', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'B']
# USDCHF 10 [0.32712698]
# GBPUSD 10 [0.956]
# EURUSD 10 [1.]
# USDJPY 10 [0.44]
# USDCAD 20 [-0.97373016]
# NZDUSD 10 [-0.81577778]
# GBPCHF 10 [0.27147619]
# EURCHF 30 [0.36]
# AUDCHF 20 [0.7173234]
# GBPJPY 50 [0.23732684]
# EURJPY 30 [0.44691059]
# EURCAD 20 [0.12637055]
# EURNZD 10 [-0.525]
# CADJPY 50 [0.71963348]
# AUDJPY 20 [1.]
# AUDCAD 50 [0.29136385]
# NZDCAD 10 [-1.]
# AUDNZD 10 [1.]
# ['B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'B']
# EURUSD 20 [0.38817299]
# USDJPY 10 [-0.32690476]
# GBPCHF 10 [-0.79]
# EURCHF 15 [-0.99527778]
# CADCHF 15 [-0.44076479]
# AUDCHF 15 [-0.48185354]
# NZDCHF 15 [-0.47669658]
# EURGBP 15 [0.49513492]
# EURAUD 20 [0.50156427]
# AUDJPY 20 [0.54930581]
# NZDCAD 10 [-0.5747619]
# AUDNZD 10 [-0.72]
# ['B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S']
# EURUSD 10 [-0.956]
# USDJPY 20 [0.5923254]
# GBPCHF 10 [0.58]
# EURCHF 50 [-0.6]
# CADCHF 10 [1.]
# AUDCHF 10 [1.]
# EURGBP 15 [0.12161905]
# EURJPY 30 [-0.41132295]
# EURAUD 10 [-0.956]
# EURNZD 10 [-0.85333333]
# AUDJPY 20 [0.23085331]
# NZDCAD 10 [0.42]
# AUDNZD 10 [0.96]
# ['S', 'B', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'B']
# USDJPY 10 [-0.42663492]
# USDCAD 10 [0.40956349]
# GBPCHF 15 [0.78]
# EURCHF 30 [-0.15153846]
# NZDCHF 15 [0.41038095]
# EURGBP 50 [-0.54816667]
# GBPCAD 20 [0.95602564]
# EURNZD 10 [0.31209524]
# NZDCAD 10 [-0.36860317]
# AUDNZD 10 [0.5692619]
# ['S', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'S', 'B']
# GBPCHF 10 [-1.]
# EURCHF 20 [0.69226768]
# CADCHF 10 [0.86]
# AUDCHF 10 [0.74]
# NZDCHF 15 [0.76]
# GBPCAD 15 [0.53495671]
# GBPAUD 20 [-0.49508311]
# EURAUD 30 [0.14159524]
# EURNZD 10 [-1.]
# NZDCAD 10 [0.38533333]
# AUDNZD 10 [-0.6995]
# ['S', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S']
# GBPUSD 15 [0.98533333]
# USDJPY 10 [-1.]
# AUDUSD 20 [-1.]
# GBPCHF 10 [0.02]
# EURCHF 20 [-0.98]
# CHFJPY 10 [0.946]
# CADCHF 10 [-0.76]
# AUDCHF 10 [-0.9]
# NZDCHF 10 [-0.82]
# GBPCAD 15 [-0.58609668]
# GBPAUD 10 [0.874]
# EURAUD 10 [1.]
# EURNZD 10 [0.94]
# NZDCAD 10 [-0.32]
# AUDNZD 10 [-0.65538095]
# ['B', 'S', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'S']
# USDCHF 50 [-0.13724889]
# GBPCHF 10 [-0.92]
# EURCHF 20 [-0.911]
# CADCHF 10 [-0.94]
# AUDCHF 10 [-0.9]
# NZDCHF 15 [0.36]
# GBPCAD 15 [-0.59080592]
# GBPAUD 15 [0.3030873]
# EURAUD 10 [1.]
# EURNZD 10 [0.92]
# NZDJPY 10 [-0.956]
# NZDCAD 10 [-0.8602381]
# AUDNZD 30 [-0.69929199]
# ['S', 'S', 'S', 'S', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'S', 'S']
# USDCHF 10 [1.]
# EURUSD 10 [-1.]
# USDJPY 10 [1.]
# AUDUSD 30 [0.46882479]
# NZDUSD 10 [1.]
# GBPCHF 10 [-0.36]
# EURCHF 20 [-0.44]
# CHFJPY 10 [-1.]
# CADCHF 10 [-0.7]
# AUDCHF 10 [-0.68]
# NZDCHF 10 [-0.37742857]
# GBPJPY 10 [1.]
# GBPCAD 10 [1.]
# GBPAUD 15 [0.60553341]
# EURJPY 10 [0.926]
# EURAUD 20 [-0.815]
# EURNZD 10 [0.32]
# AUDJPY 30 [0.5541766]
# NZDCAD 10 [-0.33359524]
# ['B', 'S', 'B', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'S']
# USDCHF 50 [0.73671992]
# EURUSD 20 [-0.98222222]
# USDCAD 20 [1.]
# AUDUSD 20 [-0.7453236]
# NZDUSD 10 [-1.]
# GBPCHF 10 [-0.88]
# EURCHF 10 [0.84]
# CHFJPY 20 [0.53949872]
# CADCHF 10 [-0.36466667]
# AUDCHF 10 [-0.33390476]
# NZDCHF 10 [-0.304]
# EURGBP 10 [-1.]
# GBPCAD 10 [-0.32565873]
# GBPAUD 15 [-0.75929726]
# EURJPY 10 [-1.]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 30 [-0.77285459]
# AUDJPY 15 [-0.76383217]
# NZDCAD 10 [0.75168254]
# ['B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B']
# USDCHF 15 [-0.2137381]
# EURUSD 15 [-0.66993651]
# AUDUSD 20 [-0.70114913]
# GBPCHF 10 [-0.04]
# EURCHF 10 [0.18]
# CADCHF 10 [0.64752381]
# AUDCHF 30 [0.78534885]
# NZDCHF 50 [-0.65853044]
# GBPJPY 10 [0.019]
# GBPCAD 10 [-0.37057143]
# EURJPY 10 [-0.89666667]
# EURCAD 10 [0.31020635]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 20 [-0.47149434]
# AUDJPY 15 [-0.75797436]
# NZDCAD 10 [0.26807143]
# ['S', 'S', 'S', 'S', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'S', 'S', 'S', 'S', 'B']
# USDCHF 15 [0.78660462]
# GBPUSD 10 [0.32087302]
# EURUSD 50 [0.87071429]
# USDCAD 15 [1.]
# AUDUSD 20 [-0.6779596]
# NZDUSD 15 [0.54513647]
# GBPCHF 10 [0.78842857]
# EURCHF 10 [1.]
# CADCHF 10 [1.]
# NZDCHF 50 [-0.19809074]
# EURGBP 10 [0.98]
# GBPJPY 10 [0.94]
# GBPCAD 15 [0.6510873]
# EURJPY 15 [0.96]
# EURCAD 10 [0.31284921]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 20 [0.01336508]
# AUDJPY 10 [-0.34833333]
# AUDCAD 30 [0.10044043]
# NZDCAD 10 [1.]
# ['B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'S', 'B', 'B']
# GBPUSD 10 [0.19949206]
# EURUSD 30 [-1.]
# AUDUSD 20 [-0.55442481]
# NZDUSD 10 [0.43348413]
# GBPCHF 50 [0.75633333]
# EURCHF 20 [-0.52]
# CADCHF 20 [-0.01371429]
# NZDCHF 50 [-0.29818649]
# EURGBP 20 [-0.96]
# GBPJPY 10 [-0.62]
# GBPCAD 10 [-0.4]
# EURJPY 15 [-0.56]
# EURCAD 10 [-1.]
# EURAUD 20 [-0.71533988]
# EURNZD 10 [-1.]
# CADJPY 20 [0.56280159]
# AUDJPY 10 [0.54366667]
# NZDJPY 20 [0.18798413]
# AUDCAD 10 [0.45330159]
# NZDCAD 10 [0.96]
# ['B', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'B']
# GBPUSD 10 [0.60683333]
# EURUSD 15 [0.26205556]
# USDCAD 10 [-0.57533333]
# AUDUSD 30 [0.72933333]
# CHFJPY 50 [0.19817123]
# NZDCHF 50 [0.37261953]
# EURGBP 20 [0.14]
# GBPJPY 10 [0.99333333]
# GBPCAD 10 [0.26728571]
# EURJPY 10 [0.60338889]
# EURCAD 15 [-0.02828066]
# EURAUD 15 [0.49740077]
# EURNZD 10 [-1.]
# CADJPY 10 [0.95666667]
# AUDJPY 50 [0.59564474]
# NZDJPY 20 [1.]
# AUDCAD 10 [-0.51576984]
# NZDCAD 10 [0.52]
# AUDNZD 30 [-0.76511663]
# ['B', 'B', 'S', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'B', 'B', 'S', 'B', 'S']
# USDCHF 50 [-0.00599567]
# GBPUSD 10 [-0.6]
# EURUSD 15 [0.32801587]
# USDCAD 20 [1.]
# AUDUSD 50 [-0.90066667]
# CADCHF 10 [-0.34745238]
# NZDCHF 50 [0.30921855]
# EURGBP 10 [0.97]
# GBPJPY 10 [0.11933333]
# GBPCAD 10 [0.62465873]
# GBPAUD 30 [-0.05233333]
# EURJPY 10 [0.44659524]
# EURCAD 10 [-0.72]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 30 [-0.50166667]
# AUDJPY 10 [0.12178571]
# NZDJPY 10 [0.29306349]
# AUDCAD 10 [-0.77551587]
# NZDCAD 10 [0.4]
# ['S', 'S', 'B', 'B', 'S', 'S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'S', 'S', 'S', 'B', 'B', 'S', 'B']
# USDCHF 10 [-0.25888095]
# GBPUSD 10 [0.42592857]
# EURUSD 10 [0.49214286]
# USDJPY 20 [0.79742352]
# GBPCHF 10 [0.2]
# CHFJPY 50 [-0.33571284]
# CADCHF 10 [0.974]
# EURGBP 20 [-0.28]
# GBPJPY 10 [0.99]
# GBPCAD 10 [-1.]
# EURJPY 10 [-0.60228571]
# EURCAD 10 [-1.]
# EURAUD 10 [0.44045238]
# EURNZD 10 [0.455]
# CADJPY 15 [0.98266667]
# AUDCAD 10 [0.37430952]
# NZDCAD 30 [-0.38025397]
# ['S', 'B', 'B', 'B', 'B', 'S', 'B', 'S', 'B', 'S', 'S', 'S', 'B', 'B', 'B', 'B', 'S']
# USDCHF 30 [0.75278571]
# GBPUSD 10 [0.26961905]
# EURUSD 10 [0.33033333]
# USDCAD 10 [1.]
# AUDUSD 15 [0.33294444]
# GBPCHF 10 [-0.36]
# EURCHF 20 [-1.]
# CHFJPY 10 [0.29895238]
# EURGBP 20 [0.6855]
# GBPJPY 30 [-0.96]
# GBPCAD 10 [0.61129365]
# CADJPY 10 [0.12492857]
# NZDCAD 10 [0.5]
# AUDNZD 15 [-1.]
# ['B', 'B', 'B', 'B', 'B', 'S', 'S', 'B', 'B', 'S', 'B', 'B', 'B', 'S']
# GBPUSD 30 [-0.99428571]
# EURUSD 15 [-1.]
# USDJPY 15 [-0.35918975]
# USDCAD 20 [0.83555316]
# AUDUSD 15 [0.59865729]
# GBPCHF 10 [-0.14]
# EURCHF 20 [-1.]
# CHFJPY 10 [-0.958]
# CADCHF 20 [0.19971429]
# AUDCHF 15 [1.]
# EURGBP 20 [-0.92]
# GBPCAD 10 [0.32]
# EURCAD 30 [-0.90333333]
# CADJPY 10 [-0.44910317]
# NZDCAD 10 [0.04]
# AUDNZD 15 [0.44120635]
# ['S', 'S', 'S', 'B', 'B', 'S', 'S', 'S', 'B', 'B', 'S', 'B', 'S', 'S', 'B', 'B']
# USDCAD 10 [-0.432]
# AUDUSD 15 [0.08716595]
# GBPCHF 10 [-1.]
# EURCHF 30 [0.23697486]
# EURGBP 10 [0.16]
# NZDCAD 10 [1.]
# AUDNZD 20 [-0.77871065]
# ['S', 'B', 'S', 'B', 'B', 'B', 'S']

# %%
print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx   END of SCRIPT')
