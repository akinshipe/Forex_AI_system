# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime, timedelta
import ast

all_currency_pairs = ['USDCHF',
                 'GBPUSD', 'EURUSD', 'USDJPY', 'USDCAD', 'AUDUSD', 'NZDUSD',
                 'GBPCHF', 'EURCHF', 'CHFJPY', 'CADCHF', 'AUDCHF', 'NZDCHF', 'EURGBP',
                 'GBPJPY', 'GBPCAD', 'GBPAUD', 'EURJPY', 'EURCAD', 'EURAUD', 'EURNZD',
                'CADJPY', 'AUDJPY', 'NZDJPY', 'AUDCAD', 'NZDCAD', 'AUDNZD'
                ]



headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
raw_df = pd.read_csv("../raw_weekly_data/NZDCAD10080.csv", names = headers )



needed_weeks_df = raw_df.loc[(raw_df['date'] >= "2015.01.01")   ]   

needed_weeks_df = needed_weeks_df.iloc[::-1]

needed_weeks_df = needed_weeks_df.reset_index(drop=True)



available_weeks = needed_weeks_df['date'].values



#print(raw_df)
print(available_weeks)
# Out:
# ['2021.11.28' '2021.11.21' '2021.11.14' '2021.11.07' '2021.10.31'
#  '2021.10.24' '2021.10.17' '2021.10.10' '2021.10.03' '2021.09.26'
#  '2021.09.19' '2021.09.12' '2021.09.05' '2021.08.29' '2021.08.22'
#  '2021.08.15' '2021.08.08' '2021.08.01' '2021.07.25' '2021.07.18'
#  '2021.07.11' '2021.07.04' '2021.06.27' '2021.06.20' '2021.06.13'
#  '2021.06.06' '2021.05.30' '2021.05.23' '2021.05.16' '2021.05.09'
#  '2021.05.02' '2021.04.25' '2021.04.18' '2021.04.11' '2021.04.04'
#  '2021.03.28' '2021.03.21' '2021.03.14' '2021.03.07' '2021.02.28'
#  '2021.02.21' '2021.02.14' '2021.02.07' '2021.01.31' '2021.01.24'
#  '2021.01.17' '2021.01.10' '2021.01.03' '2020.12.27' '2020.12.20'
#  '2020.12.13' '2020.12.06' '2020.11.29' '2020.11.22' '2020.11.15'
#  '2020.11.08' '2020.11.01' '2020.10.25' '2020.10.18' '2020.10.11'
#  '2020.10.04' '2020.09.27' '2020.09.20' '2020.09.13' '2020.09.06'
#  '2020.08.30' '2020.08.23' '2020.08.16' '2020.08.09' '2020.08.02'
#  '2020.07.26' '2020.07.19' '2020.07.12' '2020.07.05' '2020.06.28'
#  '2020.06.21' '2020.06.14' '2020.06.07' '2020.05.31' '2020.05.24'
#  '2020.05.17' '2020.05.10' '2020.05.03' '2020.04.26' '2020.04.19'
#  '2020.04.12' '2020.04.05' '2020.03.29' '2020.03.22' '2020.03.15'
#  '2020.03.08' '2020.03.01' '2020.02.23' '2020.02.16' '2020.02.09'
#  '2020.02.02' '2020.01.26' '2020.01.19' '2020.01.12' '2020.01.05'
#  '2019.12.29' '2019.12.22' '2019.12.15' '2019.12.08' '2019.12.01'
#  '2019.11.24' '2019.11.17' '2019.11.10' '2019.11.03' '2019.10.27'
#  '2019.10.20' '2019.10.13' '2019.10.06' '2019.09.29' '2019.09.22'
#  '2019.09.15' '2019.09.08' '2019.09.01' '2019.08.25' '2019.08.18'
#  '2019.08.11' '2019.08.04' '2019.07.28' '2019.07.21' '2019.07.14'
#  '2019.07.07' '2019.06.30' '2019.06.23' '2019.06.16' '2019.06.09'
#  '2019.06.02' '2019.05.26' '2019.05.19' '2019.05.12' '2019.05.05'
#  '2019.04.28' '2019.04.21' '2019.04.14' '2019.04.07' '2019.03.31'
#  '2019.03.24' '2019.03.17' '2019.03.10' '2019.03.03' '2019.02.24'
#  '2019.02.17' '2019.02.10' '2019.02.03' '2019.01.27' '2019.01.20'
#  '2019.01.13' '2019.01.06' '2018.12.30' '2018.12.23' '2018.12.16'
#  '2018.12.09' '2018.12.02' '2018.11.25' '2018.11.18' '2018.11.11'
#  '2018.11.04' '2018.10.28' '2018.10.21' '2018.10.14' '2018.10.07'
#  '2018.09.30' '2018.09.23' '2018.09.16' '2018.09.09' '2018.09.02'
#  '2018.08.26' '2018.08.19' '2018.08.12' '2018.08.05' '2018.07.29'
#  '2018.07.22' '2018.07.15' '2018.07.08' '2018.07.01' '2018.06.24'
#  '2018.06.17' '2018.06.10' '2018.06.03' '2018.05.27' '2018.05.20'
#  '2018.05.13' '2018.05.06' '2018.04.29' '2018.04.22' '2018.04.15'
#  '2018.04.08' '2018.04.01' '2018.03.25' '2018.03.18' '2018.03.11'
#  '2018.03.04' '2018.02.25' '2018.02.18' '2018.02.11' '2018.02.04'
#  '2018.01.28' '2018.01.21' '2018.01.14' '2018.01.07' '2017.12.31'
#  '2017.12.24' '2017.12.17' '2017.12.10' '2017.12.03' '2017.11.26'
#  '2017.11.19' '2017.11.12' '2017.11.05' '2017.10.29' '2017.10.22'
#  '2017.10.15' '2017.10.08' '2017.10.01' '2017.09.24' '2017.09.17'
#  '2017.09.10' '2017.09.03' '2017.08.27' '2017.08.20' '2017.08.13'
#  '2017.08.06' '2017.07.30' '2017.07.23' '2017.07.16' '2017.07.09'
#  '2017.07.02' '2017.06.25' '2017.06.18' '2017.06.11' '2017.06.04'
#  '2017.05.28' '2017.05.21' '2017.05.14' '2017.05.07' '2017.04.30'
#  '2017.04.23' '2017.04.16' '2017.04.09' '2017.04.02' '2017.03.26'
#  '2017.03.19' '2017.03.05' '2017.02.26' '2017.02.19' '2017.02.12'
#  '2017.02.05' '2017.01.29' '2017.01.22' '2017.01.15' '2017.01.08'
#  '2017.01.01' '2016.12.25' '2016.12.18' '2016.12.11' '2016.12.04'
#  '2016.11.27' '2016.11.20' '2016.11.13' '2016.11.06' '2016.10.30'
#  '2016.10.23' '2016.10.16' '2016.10.09' '2016.10.02' '2016.09.25'
#  '2016.09.18' '2016.09.11' '2016.09.04' '2016.08.28' '2016.08.21'
#  '2016.08.14' '2016.08.07' '2016.07.31' '2016.07.24' '2016.07.17'
#  '2016.07.10' '2016.07.03' '2016.06.26' '2016.06.19' '2016.06.12'
#  '2016.06.05' '2016.05.29' '2016.05.22' '2016.05.15' '2016.05.08'
#  '2016.05.01' '2016.04.24' '2016.04.17' '2016.04.10' '2016.04.03'
#  '2016.03.27' '2016.03.20' '2016.03.13' '2016.03.06' '2016.02.28'
#  '2016.02.21' '2016.02.14' '2016.02.07' '2016.01.31' '2016.01.24'
#  '2016.01.17' '2016.01.10' '2016.01.03' '2015.12.27' '2015.12.20'
#  '2015.12.13' '2015.12.06' '2015.11.29' '2015.11.22' '2015.11.15'
#  '2015.11.08' '2015.11.01' '2015.10.25' '2015.10.18' '2015.10.11'
#  '2015.10.04' '2015.09.27' '2015.09.20' '2015.09.13' '2015.09.06'
#  '2015.08.30' '2015.08.23' '2015.08.16' '2015.08.09' '2015.08.02'
#  '2015.07.26' '2015.07.19' '2015.07.12' '2015.07.05' '2015.06.28'
#  '2015.06.21' '2015.06.14' '2015.06.07' '2015.05.31' '2015.05.24'
#  '2015.05.17' '2015.05.10' '2015.05.03' '2015.04.26' '2015.04.19'
#  '2015.04.12' '2015.04.05' '2015.03.29' '2015.03.22' '2015.03.15'
#  '2015.03.08' '2015.03.01' '2015.02.22' '2015.02.15' '2015.02.08'
#  '2015.02.01' '2015.01.25' '2015.01.18' '2015.01.11' '2015.01.04']

# %%
for y in available_weeks:
    
    current_date = datetime.strptime(y, '%Y.%m.%d').strftime('%A')
    
    if current_date != 'Sunday':
       
        print('error-----------------------------', y, '  is not a sunday')
        
        raise Exception('error-----------------------------', y, ' did is not a sunday')

# %%
for a in available_weeks:
  
  
    path = "./files/" + a

    try: 
        os.makedirs(path)
        control_file = pd.DataFrame()
        
        for  b in range(8):
            control_file['control' + str(b)] = -1
            
            
        control_file.to_csv(path + '/control.csv')
        
        

    except OSError as error: 
         raise Exception(error)

# %%
# classif historical currency data

raw_currency_pair_classification_df = []

for a in all_currency_pairs:
    
    classification_df = pd.DataFrame()
    
    classification_score =[]
    
    current_currency_df = pd.read_csv("../raw_weekly_data/" + a + "10080.csv", names = headers ) 
        
        
    current_currency_df = current_currency_df.loc[(current_currency_df['date'] >= '2014.01.01' ) ]
    
    current_currency_df = current_currency_df.iloc[::-1]   
        
    current_currency_df = current_currency_df.reset_index(drop=True)
    
    classification_df['date'] = current_currency_df['date']
    
    
    for b in (range(len(current_currency_df.index))):
            
            row = current_currency_df.loc[b,:]
                            
            #condition when the curreny movement is a buy
            

            if row.open < row.close:
                
                 classification_score.append(1)
                #print(b, a, row.date, row.open, row.close)
                          
            else:
                
                #print(b, a,row.date, row.open, row.close)
                 classification_score.append(-1)

                    
    
    classification_df['class'] = classification_score
    
    raw_currency_pair_classification_df.append({'name': a, 'data': classification_df })
                    
                    
                    
    #print('------------------------------------------------------------------------------------------',a)
    
    
print(len(raw_currency_pair_classification_df))
# Out:
# 27

# %%
for c in available_weeks :
    
    current_week_classification_df = pd.DataFrame()

    for index, d in enumerate(raw_currency_pair_classification_df):
              
        current_currency = d['name']

        current_currency_df = d['data']
        #print(d)
        
        
        current_currency_df = current_currency_df.loc[(current_currency_df['date'] <= c ) ]
        
        current_currency_df = current_currency_df.reset_index(drop=True)
                
        current_currency_df = current_currency_df.head(52)   
         
        #print(c, d['name'],current_currency_df)  
        
        
        if index == 0 :
            
            current_week_classification_df['date'] = current_currency_df['date']
        
    
        current_week_classification_df[current_currency] = current_currency_df['class']
    
    
    
    #print(current_week_classification_df)   

    print('-----------------------------------------------------------------------------------------------------' , c )

    
    # creating dataframe with next week for each currency
    
    for index, e in enumerate(all_currency_pairs):
        
        
        current_week_classification_dataframe = current_week_classification_df.copy()
        
        current_currency_list = current_week_classification_dataframe[e].values.tolist()
        
        current_currency_list.insert(0,0)
        
        current_currency_list.pop()
        
        
        
        current_week_classification_dataframe['nextweek_'+ e] = current_currency_list
        
        if index == 0:
        
            currrent_week_values_df = current_week_classification_dataframe.iloc[:1, :28]


            current_week_values_df = currrent_week_values_df.reset_index(drop =True)

            current_week_values_df.to_csv("files/" + c + "/current_week_values.csv", index = False)

            #print(current_week_values_df)
        
        
        #print(current_week_classification_dataframe)
        
        
        current_week_classification_dataframe = current_week_classification_dataframe.iloc[1:, :]
        
        
        current_week_classification_dataframe = current_week_classification_dataframe.reset_index(drop =True)
        
        
        current_week_classification_dataframe.to_csv("files/" + c + "/"+ e + ".csv", index = False)
        
        #print(current_week_classification_dataframe)
        
        #print(e, )
# Out:
# ----------------------------------------------------------------------------------------------------- 2021.11.28
# ----------------------------------------------------------------------------------------------------- 2021.11.21
# ----------------------------------------------------------------------------------------------------- 2021.11.14
# ----------------------------------------------------------------------------------------------------- 2021.11.07
# ----------------------------------------------------------------------------------------------------- 2021.10.31
# ----------------------------------------------------------------------------------------------------- 2021.10.24
# ----------------------------------------------------------------------------------------------------- 2021.10.17
# ----------------------------------------------------------------------------------------------------- 2021.10.10
# ----------------------------------------------------------------------------------------------------- 2021.10.03
# ----------------------------------------------------------------------------------------------------- 2021.09.26
# ----------------------------------------------------------------------------------------------------- 2021.09.19
# ----------------------------------------------------------------------------------------------------- 2021.09.12
# ----------------------------------------------------------------------------------------------------- 2021.09.05
# ----------------------------------------------------------------------------------------------------- 2021.08.29
# ----------------------------------------------------------------------------------------------------- 2021.08.22
# ----------------------------------------------------------------------------------------------------- 2021.08.15
# ----------------------------------------------------------------------------------------------------- 2021.08.08
# ----------------------------------------------------------------------------------------------------- 2021.08.01
# ----------------------------------------------------------------------------------------------------- 2021.07.25
# ----------------------------------------------------------------------------------------------------- 2021.07.18
# ----------------------------------------------------------------------------------------------------- 2021.07.11
# ----------------------------------------------------------------------------------------------------- 2021.07.04
# ----------------------------------------------------------------------------------------------------- 2021.06.27
# ----------------------------------------------------------------------------------------------------- 2021.06.20
# ----------------------------------------------------------------------------------------------------- 2021.06.13
# ----------------------------------------------------------------------------------------------------- 2021.06.06
# ----------------------------------------------------------------------------------------------------- 2021.05.30
# ----------------------------------------------------------------------------------------------------- 2021.05.23
# ----------------------------------------------------------------------------------------------------- 2021.05.16
# ----------------------------------------------------------------------------------------------------- 2021.05.09
# ----------------------------------------------------------------------------------------------------- 2021.05.02
# ----------------------------------------------------------------------------------------------------- 2021.04.25
# ----------------------------------------------------------------------------------------------------- 2021.04.18
# ----------------------------------------------------------------------------------------------------- 2021.04.11
# ----------------------------------------------------------------------------------------------------- 2021.04.04
# ----------------------------------------------------------------------------------------------------- 2021.03.28
# ----------------------------------------------------------------------------------------------------- 2021.03.21
# ----------------------------------------------------------------------------------------------------- 2021.03.14
# ----------------------------------------------------------------------------------------------------- 2021.03.07
# ----------------------------------------------------------------------------------------------------- 2021.02.28
# ----------------------------------------------------------------------------------------------------- 2021.02.21
# ----------------------------------------------------------------------------------------------------- 2021.02.14
# ----------------------------------------------------------------------------------------------------- 2021.02.07
# ----------------------------------------------------------------------------------------------------- 2021.01.31
# ----------------------------------------------------------------------------------------------------- 2021.01.24
# ----------------------------------------------------------------------------------------------------- 2021.01.17
# ----------------------------------------------------------------------------------------------------- 2021.01.10
# ----------------------------------------------------------------------------------------------------- 2021.01.03
# ----------------------------------------------------------------------------------------------------- 2020.12.27
# ----------------------------------------------------------------------------------------------------- 2020.12.20
# ----------------------------------------------------------------------------------------------------- 2020.12.13
# ----------------------------------------------------------------------------------------------------- 2020.12.06
# ----------------------------------------------------------------------------------------------------- 2020.11.29
# ----------------------------------------------------------------------------------------------------- 2020.11.22
# ----------------------------------------------------------------------------------------------------- 2020.11.15
# ----------------------------------------------------------------------------------------------------- 2020.11.08
# ----------------------------------------------------------------------------------------------------- 2020.11.01
# ----------------------------------------------------------------------------------------------------- 2020.10.25
# ----------------------------------------------------------------------------------------------------- 2020.10.18
# ----------------------------------------------------------------------------------------------------- 2020.10.11
# ----------------------------------------------------------------------------------------------------- 2020.10.04
# ----------------------------------------------------------------------------------------------------- 2020.09.27
# ----------------------------------------------------------------------------------------------------- 2020.09.20
# ----------------------------------------------------------------------------------------------------- 2020.09.13
# ----------------------------------------------------------------------------------------------------- 2020.09.06
# ----------------------------------------------------------------------------------------------------- 2020.08.30
# ----------------------------------------------------------------------------------------------------- 2020.08.23
# ----------------------------------------------------------------------------------------------------- 2020.08.16
# ----------------------------------------------------------------------------------------------------- 2020.08.09
# ----------------------------------------------------------------------------------------------------- 2020.08.02
# ----------------------------------------------------------------------------------------------------- 2020.07.26
# ----------------------------------------------------------------------------------------------------- 2020.07.19
# ----------------------------------------------------------------------------------------------------- 2020.07.12
# ----------------------------------------------------------------------------------------------------- 2020.07.05
# ----------------------------------------------------------------------------------------------------- 2020.06.28
# ----------------------------------------------------------------------------------------------------- 2020.06.21
# ----------------------------------------------------------------------------------------------------- 2020.06.14
# ----------------------------------------------------------------------------------------------------- 2020.06.07
# ----------------------------------------------------------------------------------------------------- 2020.05.31
# ----------------------------------------------------------------------------------------------------- 2020.05.24
# ----------------------------------------------------------------------------------------------------- 2020.05.17
# ----------------------------------------------------------------------------------------------------- 2020.05.10
# ----------------------------------------------------------------------------------------------------- 2020.05.03
# ----------------------------------------------------------------------------------------------------- 2020.04.26
# ----------------------------------------------------------------------------------------------------- 2020.04.19
# ----------------------------------------------------------------------------------------------------- 2020.04.12
# ----------------------------------------------------------------------------------------------------- 2020.04.05
# ----------------------------------------------------------------------------------------------------- 2020.03.29
# ----------------------------------------------------------------------------------------------------- 2020.03.22
# ----------------------------------------------------------------------------------------------------- 2020.03.15
# ----------------------------------------------------------------------------------------------------- 2020.03.08
# ----------------------------------------------------------------------------------------------------- 2020.03.01
# ----------------------------------------------------------------------------------------------------- 2020.02.23
# ----------------------------------------------------------------------------------------------------- 2020.02.16
# ----------------------------------------------------------------------------------------------------- 2020.02.09
# ----------------------------------------------------------------------------------------------------- 2020.02.02
# ----------------------------------------------------------------------------------------------------- 2020.01.26
# ----------------------------------------------------------------------------------------------------- 2020.01.19
# ----------------------------------------------------------------------------------------------------- 2020.01.12
# ----------------------------------------------------------------------------------------------------- 2020.01.05
# ----------------------------------------------------------------------------------------------------- 2019.12.29
# ----------------------------------------------------------------------------------------------------- 2019.12.22
# ----------------------------------------------------------------------------------------------------- 2019.12.15
# ----------------------------------------------------------------------------------------------------- 2019.12.08
# ----------------------------------------------------------------------------------------------------- 2019.12.01
# ----------------------------------------------------------------------------------------------------- 2019.11.24
# ----------------------------------------------------------------------------------------------------- 2019.11.17
# ----------------------------------------------------------------------------------------------------- 2019.11.10
# ----------------------------------------------------------------------------------------------------- 2019.11.03
# ----------------------------------------------------------------------------------------------------- 2019.10.27
# ----------------------------------------------------------------------------------------------------- 2019.10.20
# ----------------------------------------------------------------------------------------------------- 2019.10.13
# ----------------------------------------------------------------------------------------------------- 2019.10.06
# ----------------------------------------------------------------------------------------------------- 2019.09.29
# ----------------------------------------------------------------------------------------------------- 2019.09.22
# ----------------------------------------------------------------------------------------------------- 2019.09.15
# ----------------------------------------------------------------------------------------------------- 2019.09.08
# ----------------------------------------------------------------------------------------------------- 2019.09.01
# ----------------------------------------------------------------------------------------------------- 2019.08.25
# ----------------------------------------------------------------------------------------------------- 2019.08.18
# ----------------------------------------------------------------------------------------------------- 2019.08.11
# ----------------------------------------------------------------------------------------------------- 2019.08.04
# ----------------------------------------------------------------------------------------------------- 2019.07.28
# ----------------------------------------------------------------------------------------------------- 2019.07.21
# ----------------------------------------------------------------------------------------------------- 2019.07.14
# ----------------------------------------------------------------------------------------------------- 2019.07.07
# ----------------------------------------------------------------------------------------------------- 2019.06.30
# ----------------------------------------------------------------------------------------------------- 2019.06.23
# ----------------------------------------------------------------------------------------------------- 2019.06.16
# ----------------------------------------------------------------------------------------------------- 2019.06.09
# ----------------------------------------------------------------------------------------------------- 2019.06.02
# ----------------------------------------------------------------------------------------------------- 2019.05.26
# ----------------------------------------------------------------------------------------------------- 2019.05.19
# ----------------------------------------------------------------------------------------------------- 2019.05.12
# ----------------------------------------------------------------------------------------------------- 2019.05.05
# ----------------------------------------------------------------------------------------------------- 2019.04.28
# ----------------------------------------------------------------------------------------------------- 2019.04.21
# ----------------------------------------------------------------------------------------------------- 2019.04.14
# ----------------------------------------------------------------------------------------------------- 2019.04.07
# ----------------------------------------------------------------------------------------------------- 2019.03.31
# ----------------------------------------------------------------------------------------------------- 2019.03.24
# ----------------------------------------------------------------------------------------------------- 2019.03.17
# ----------------------------------------------------------------------------------------------------- 2019.03.10
# ----------------------------------------------------------------------------------------------------- 2019.03.03
# ----------------------------------------------------------------------------------------------------- 2019.02.24
# ----------------------------------------------------------------------------------------------------- 2019.02.17
# ----------------------------------------------------------------------------------------------------- 2019.02.10
# ----------------------------------------------------------------------------------------------------- 2019.02.03
# ----------------------------------------------------------------------------------------------------- 2019.01.27
# ----------------------------------------------------------------------------------------------------- 2019.01.20
# ----------------------------------------------------------------------------------------------------- 2019.01.13
# ----------------------------------------------------------------------------------------------------- 2019.01.06
# ----------------------------------------------------------------------------------------------------- 2018.12.30
# ----------------------------------------------------------------------------------------------------- 2018.12.23
# ----------------------------------------------------------------------------------------------------- 2018.12.16
# ----------------------------------------------------------------------------------------------------- 2018.12.09
# ----------------------------------------------------------------------------------------------------- 2018.12.02
# ----------------------------------------------------------------------------------------------------- 2018.11.25
# ----------------------------------------------------------------------------------------------------- 2018.11.18
# ----------------------------------------------------------------------------------------------------- 2018.11.11
# ----------------------------------------------------------------------------------------------------- 2018.11.04
# ----------------------------------------------------------------------------------------------------- 2018.10.28
# ----------------------------------------------------------------------------------------------------- 2018.10.21
# ----------------------------------------------------------------------------------------------------- 2018.10.14
# ----------------------------------------------------------------------------------------------------- 2018.10.07
# ----------------------------------------------------------------------------------------------------- 2018.09.30
# ----------------------------------------------------------------------------------------------------- 2018.09.23
# ----------------------------------------------------------------------------------------------------- 2018.09.16
# ----------------------------------------------------------------------------------------------------- 2018.09.09
# ----------------------------------------------------------------------------------------------------- 2018.09.02
# ----------------------------------------------------------------------------------------------------- 2018.08.26
# ----------------------------------------------------------------------------------------------------- 2018.08.19
# ----------------------------------------------------------------------------------------------------- 2018.08.12
# ----------------------------------------------------------------------------------------------------- 2018.08.05
# ----------------------------------------------------------------------------------------------------- 2018.07.29
# ----------------------------------------------------------------------------------------------------- 2018.07.22
# ----------------------------------------------------------------------------------------------------- 2018.07.15
# ----------------------------------------------------------------------------------------------------- 2018.07.08
# ----------------------------------------------------------------------------------------------------- 2018.07.01
# ----------------------------------------------------------------------------------------------------- 2018.06.24
# ----------------------------------------------------------------------------------------------------- 2018.06.17
# ----------------------------------------------------------------------------------------------------- 2018.06.10
# ----------------------------------------------------------------------------------------------------- 2018.06.03
# ----------------------------------------------------------------------------------------------------- 2018.05.27
# ----------------------------------------------------------------------------------------------------- 2018.05.20
# ----------------------------------------------------------------------------------------------------- 2018.05.13
# ----------------------------------------------------------------------------------------------------- 2018.05.06
# ----------------------------------------------------------------------------------------------------- 2018.04.29
# ----------------------------------------------------------------------------------------------------- 2018.04.22
# ----------------------------------------------------------------------------------------------------- 2018.04.15
# ----------------------------------------------------------------------------------------------------- 2018.04.08
# ----------------------------------------------------------------------------------------------------- 2018.04.01
# ----------------------------------------------------------------------------------------------------- 2018.03.25
# ----------------------------------------------------------------------------------------------------- 2018.03.18
# ----------------------------------------------------------------------------------------------------- 2018.03.11
# ----------------------------------------------------------------------------------------------------- 2018.03.04
# ----------------------------------------------------------------------------------------------------- 2018.02.25
# ----------------------------------------------------------------------------------------------------- 2018.02.18
# ----------------------------------------------------------------------------------------------------- 2018.02.11
# ----------------------------------------------------------------------------------------------------- 2018.02.04
# ----------------------------------------------------------------------------------------------------- 2018.01.28
# ----------------------------------------------------------------------------------------------------- 2018.01.21
# ----------------------------------------------------------------------------------------------------- 2018.01.14
# ----------------------------------------------------------------------------------------------------- 2018.01.07
# ----------------------------------------------------------------------------------------------------- 2017.12.31
# ----------------------------------------------------------------------------------------------------- 2017.12.24
# ----------------------------------------------------------------------------------------------------- 2017.12.17
# ----------------------------------------------------------------------------------------------------- 2017.12.10
# ----------------------------------------------------------------------------------------------------- 2017.12.03
# ----------------------------------------------------------------------------------------------------- 2017.11.26
# ----------------------------------------------------------------------------------------------------- 2017.11.19
# ----------------------------------------------------------------------------------------------------- 2017.11.12
# ----------------------------------------------------------------------------------------------------- 2017.11.05
# ----------------------------------------------------------------------------------------------------- 2017.10.29
# ----------------------------------------------------------------------------------------------------- 2017.10.22
# ----------------------------------------------------------------------------------------------------- 2017.10.15
# ----------------------------------------------------------------------------------------------------- 2017.10.08
# ----------------------------------------------------------------------------------------------------- 2017.10.01
# ----------------------------------------------------------------------------------------------------- 2017.09.24
# ----------------------------------------------------------------------------------------------------- 2017.09.17
# ----------------------------------------------------------------------------------------------------- 2017.09.10
# ----------------------------------------------------------------------------------------------------- 2017.09.03
# ----------------------------------------------------------------------------------------------------- 2017.08.27
# ----------------------------------------------------------------------------------------------------- 2017.08.20
# ----------------------------------------------------------------------------------------------------- 2017.08.13
# ----------------------------------------------------------------------------------------------------- 2017.08.06
# ----------------------------------------------------------------------------------------------------- 2017.07.30
# ----------------------------------------------------------------------------------------------------- 2017.07.23
# ----------------------------------------------------------------------------------------------------- 2017.07.16
# ----------------------------------------------------------------------------------------------------- 2017.07.09
# ----------------------------------------------------------------------------------------------------- 2017.07.02
# ----------------------------------------------------------------------------------------------------- 2017.06.25
# ----------------------------------------------------------------------------------------------------- 2017.06.18
# ----------------------------------------------------------------------------------------------------- 2017.06.11
# ----------------------------------------------------------------------------------------------------- 2017.06.04
# ----------------------------------------------------------------------------------------------------- 2017.05.28
# ----------------------------------------------------------------------------------------------------- 2017.05.21
# ----------------------------------------------------------------------------------------------------- 2017.05.14
# ----------------------------------------------------------------------------------------------------- 2017.05.07
# ----------------------------------------------------------------------------------------------------- 2017.04.30
# ----------------------------------------------------------------------------------------------------- 2017.04.23
# ----------------------------------------------------------------------------------------------------- 2017.04.16
# ----------------------------------------------------------------------------------------------------- 2017.04.09
# ----------------------------------------------------------------------------------------------------- 2017.04.02
# ----------------------------------------------------------------------------------------------------- 2017.03.26
# ----------------------------------------------------------------------------------------------------- 2017.03.19
# ----------------------------------------------------------------------------------------------------- 2017.03.05
# ----------------------------------------------------------------------------------------------------- 2017.02.26
# ----------------------------------------------------------------------------------------------------- 2017.02.19
# ----------------------------------------------------------------------------------------------------- 2017.02.12
# ----------------------------------------------------------------------------------------------------- 2017.02.05
# ----------------------------------------------------------------------------------------------------- 2017.01.29
# ----------------------------------------------------------------------------------------------------- 2017.01.22
# ----------------------------------------------------------------------------------------------------- 2017.01.15
# ----------------------------------------------------------------------------------------------------- 2017.01.08
# ----------------------------------------------------------------------------------------------------- 2017.01.01
# ----------------------------------------------------------------------------------------------------- 2016.12.25
# ----------------------------------------------------------------------------------------------------- 2016.12.18
# ----------------------------------------------------------------------------------------------------- 2016.12.11
# ----------------------------------------------------------------------------------------------------- 2016.12.04
# ----------------------------------------------------------------------------------------------------- 2016.11.27
# ----------------------------------------------------------------------------------------------------- 2016.11.20
# ----------------------------------------------------------------------------------------------------- 2016.11.13
# ----------------------------------------------------------------------------------------------------- 2016.11.06
# ----------------------------------------------------------------------------------------------------- 2016.10.30
# ----------------------------------------------------------------------------------------------------- 2016.10.23
# ----------------------------------------------------------------------------------------------------- 2016.10.16
# ----------------------------------------------------------------------------------------------------- 2016.10.09
# ----------------------------------------------------------------------------------------------------- 2016.10.02
# ----------------------------------------------------------------------------------------------------- 2016.09.25
# ----------------------------------------------------------------------------------------------------- 2016.09.18
# ----------------------------------------------------------------------------------------------------- 2016.09.11
# ----------------------------------------------------------------------------------------------------- 2016.09.04
# ----------------------------------------------------------------------------------------------------- 2016.08.28
# ----------------------------------------------------------------------------------------------------- 2016.08.21
# ----------------------------------------------------------------------------------------------------- 2016.08.14
# ----------------------------------------------------------------------------------------------------- 2016.08.07
# ----------------------------------------------------------------------------------------------------- 2016.07.31
# ----------------------------------------------------------------------------------------------------- 2016.07.24
# ----------------------------------------------------------------------------------------------------- 2016.07.17
# ----------------------------------------------------------------------------------------------------- 2016.07.10
# ----------------------------------------------------------------------------------------------------- 2016.07.03
# ----------------------------------------------------------------------------------------------------- 2016.06.26
# ----------------------------------------------------------------------------------------------------- 2016.06.19
# ----------------------------------------------------------------------------------------------------- 2016.06.12
# ----------------------------------------------------------------------------------------------------- 2016.06.05
# ----------------------------------------------------------------------------------------------------- 2016.05.29
# ----------------------------------------------------------------------------------------------------- 2016.05.22
# ----------------------------------------------------------------------------------------------------- 2016.05.15
# ----------------------------------------------------------------------------------------------------- 2016.05.08
# ----------------------------------------------------------------------------------------------------- 2016.05.01
# ----------------------------------------------------------------------------------------------------- 2016.04.24
# ----------------------------------------------------------------------------------------------------- 2016.04.17
# ----------------------------------------------------------------------------------------------------- 2016.04.10
# ----------------------------------------------------------------------------------------------------- 2016.04.03
# ----------------------------------------------------------------------------------------------------- 2016.03.27
# ----------------------------------------------------------------------------------------------------- 2016.03.20
# ----------------------------------------------------------------------------------------------------- 2016.03.13
# ----------------------------------------------------------------------------------------------------- 2016.03.06
# ----------------------------------------------------------------------------------------------------- 2016.02.28
# ----------------------------------------------------------------------------------------------------- 2016.02.21
# ----------------------------------------------------------------------------------------------------- 2016.02.14
# ----------------------------------------------------------------------------------------------------- 2016.02.07
# ----------------------------------------------------------------------------------------------------- 2016.01.31
# ----------------------------------------------------------------------------------------------------- 2016.01.24
# ----------------------------------------------------------------------------------------------------- 2016.01.17
# ----------------------------------------------------------------------------------------------------- 2016.01.10
# ----------------------------------------------------------------------------------------------------- 2016.01.03
# ----------------------------------------------------------------------------------------------------- 2015.12.27
# ----------------------------------------------------------------------------------------------------- 2015.12.20
# ----------------------------------------------------------------------------------------------------- 2015.12.13
# ----------------------------------------------------------------------------------------------------- 2015.12.06
# ----------------------------------------------------------------------------------------------------- 2015.11.29
# ----------------------------------------------------------------------------------------------------- 2015.11.22
# ----------------------------------------------------------------------------------------------------- 2015.11.15
# ----------------------------------------------------------------------------------------------------- 2015.11.08
# ----------------------------------------------------------------------------------------------------- 2015.11.01
# ----------------------------------------------------------------------------------------------------- 2015.10.25
# ----------------------------------------------------------------------------------------------------- 2015.10.18
# ----------------------------------------------------------------------------------------------------- 2015.10.11
# ----------------------------------------------------------------------------------------------------- 2015.10.04
# ----------------------------------------------------------------------------------------------------- 2015.09.27
# ----------------------------------------------------------------------------------------------------- 2015.09.20
# ----------------------------------------------------------------------------------------------------- 2015.09.13
# ----------------------------------------------------------------------------------------------------- 2015.09.06
# ----------------------------------------------------------------------------------------------------- 2015.08.30
# ----------------------------------------------------------------------------------------------------- 2015.08.23
# ----------------------------------------------------------------------------------------------------- 2015.08.16
# ----------------------------------------------------------------------------------------------------- 2015.08.09
# ----------------------------------------------------------------------------------------------------- 2015.08.02
# ----------------------------------------------------------------------------------------------------- 2015.07.26
# ----------------------------------------------------------------------------------------------------- 2015.07.19
# ----------------------------------------------------------------------------------------------------- 2015.07.12
# ----------------------------------------------------------------------------------------------------- 2015.07.05
# ----------------------------------------------------------------------------------------------------- 2015.06.28
# ----------------------------------------------------------------------------------------------------- 2015.06.21
# ----------------------------------------------------------------------------------------------------- 2015.06.14
# ----------------------------------------------------------------------------------------------------- 2015.06.07
# ----------------------------------------------------------------------------------------------------- 2015.05.31
# ----------------------------------------------------------------------------------------------------- 2015.05.24
# ----------------------------------------------------------------------------------------------------- 2015.05.17
# ----------------------------------------------------------------------------------------------------- 2015.05.10
# ----------------------------------------------------------------------------------------------------- 2015.05.03
# ----------------------------------------------------------------------------------------------------- 2015.04.26
# ----------------------------------------------------------------------------------------------------- 2015.04.19
# ----------------------------------------------------------------------------------------------------- 2015.04.12
# ----------------------------------------------------------------------------------------------------- 2015.04.05
# ----------------------------------------------------------------------------------------------------- 2015.03.29
# ----------------------------------------------------------------------------------------------------- 2015.03.22
# ----------------------------------------------------------------------------------------------------- 2015.03.15
# ----------------------------------------------------------------------------------------------------- 2015.03.08
# ----------------------------------------------------------------------------------------------------- 2015.03.01
# ----------------------------------------------------------------------------------------------------- 2015.02.22
# ----------------------------------------------------------------------------------------------------- 2015.02.15
# ----------------------------------------------------------------------------------------------------- 2015.02.08
# ----------------------------------------------------------------------------------------------------- 2015.02.01
# ----------------------------------------------------------------------------------------------------- 2015.01.25
# ----------------------------------------------------------------------------------------------------- 2015.01.18
# ----------------------------------------------------------------------------------------------------- 2015.01.11
# ----------------------------------------------------------------------------------------------------- 2015.01.04

# %%
#this is the function that calculate the correlation of the data

def correlate(current_week):
    
        # declare the variable to hold all corelation data
    combine_correlation_data = pd.DataFrame()

    #loop through all currency
    for z in all_currency_pairs:

        current_currency = z
        raw_data = pd.read_csv('files/' + current_week + '/' + current_currency + '.csv'  ) 
        
        #print(z, raw_data)

        weeks = [50, 30, 20, 15, 10]

        #loop through all availale weeks
        for y in weeks:

            currency_list = []
            correlation_score = []

            #loops through all currency pairs again to calculate the corelation of each currency pair with the current iteration of z
            for x in all_currency_pairs:          

                #duplicates the raw data to work with
                current_data = raw_data.copy()

                #returns on the the amount of rows of weeks needed to perform correlation on
                current_data = current_data.head(y)

                #returns the two columns that correlation is being calculated for
                new_df = current_data[['nextweek_'+ current_currency, x]]
                
                #print(new_df)
                
                correlation = new_df.corr()
                
                #print(correlation)
                correlation = correlation[x][0:1].values[0]
                
                #print(correlation)

                #gets the absolute value of the correlation to 5 digit number
                correlation = abs(round(correlation, 5))
                
                
                #apppends the current currency and the corelation values to their respective lists
                currency_list.append(x)
                correlation_score.append(correlation)

            #creates a mini data frame with the information
            current_correlation_dataframe = pd.DataFrame()  
            current_correlation_dataframe [current_currency + '__' + str(y) ] = currency_list
            current_correlation_dataframe [current_currency + '_' + str(y) ] = correlation_score

            # sort the dataframe with corelation value from large to small
            current_correlation_dataframe.sort_values(by=[current_currency + '_' + str(y)], ascending=False, inplace=True, ignore_index= True)

            #fill the NaN values with zero
            current_correlation_dataframe.fillna(0, inplace=True)

            # add the current_currency dataframe to the global dataframe
            combine_correlation_data = pd.concat((combine_correlation_data, current_correlation_dataframe),axis=1)
            #print(len(correlation_score))

    #print(combine_correlation_data)
    
    #print(current_week)
    
    


    # save global dataframe to csv
    combine_correlation_data.to_csv('files/' + current_week + '/auto-correlation2.csv', index=False)

# %%
#calls correlation function and creates correlation information for all weeks and save it in each week folder

for f in available_weeks:

    y = correlate(f)
    print(f)
# Out:
# 2021.11.28
# 2021.11.21
# 2021.11.14
# 2021.11.07
# 2021.10.31
# 2021.10.24
# 2021.10.17
# 2021.10.10
# 2021.10.03
# 2021.09.26
# 2021.09.19
# 2021.09.12
# 2021.09.05
# 2021.08.29
# 2021.08.22
# 2021.08.15
# 2021.08.08
# 2021.08.01
# 2021.07.25
# 2021.07.18
# 2021.07.11
# 2021.07.04
# 2021.06.27
# 2021.06.20
# 2021.06.13
# 2021.06.06
# 2021.05.30
# 2021.05.23
# 2021.05.16
# 2021.05.09
# 2021.05.02
# 2021.04.25
# 2021.04.18
# 2021.04.11
# 2021.04.04
# 2021.03.28
# 2021.03.21
# 2021.03.14
# 2021.03.07
# 2021.02.28
# 2021.02.21
# 2021.02.14
# 2021.02.07
# 2021.01.31
# 2021.01.24
# 2021.01.17
# 2021.01.10
# 2021.01.03
# 2020.12.27
# 2020.12.20
# 2020.12.13
# 2020.12.06
# 2020.11.29
# 2020.11.22
# 2020.11.15
# 2020.11.08
# 2020.11.01
# 2020.10.25
# 2020.10.18
# 2020.10.11
# 2020.10.04
# 2020.09.27
# 2020.09.20
# 2020.09.13
# 2020.09.06
# 2020.08.30
# 2020.08.23
# 2020.08.16
# 2020.08.09
# 2020.08.02
# 2020.07.26
# 2020.07.19
# 2020.07.12
# 2020.07.05
# 2020.06.28
# 2020.06.21
# 2020.06.14
# 2020.06.07
# 2020.05.31
# 2020.05.24
# 2020.05.17
# 2020.05.10
# 2020.05.03
# 2020.04.26
# 2020.04.19
# 2020.04.12
# 2020.04.05
# 2020.03.29
# 2020.03.22
# 2020.03.15
# 2020.03.08
# 2020.03.01
# 2020.02.23
# 2020.02.16
# 2020.02.09
# 2020.02.02
# 2020.01.26
# 2020.01.19
# 2020.01.12
# 2020.01.05
# 2019.12.29
# 2019.12.22
# 2019.12.15
# 2019.12.08
# 2019.12.01
# 2019.11.24
# 2019.11.17
# 2019.11.10
# 2019.11.03
# 2019.10.27
# 2019.10.20
# 2019.10.13
# 2019.10.06
# 2019.09.29
# 2019.09.22
# 2019.09.15
# 2019.09.08
# 2019.09.01
# 2019.08.25
# 2019.08.18
# 2019.08.11
# 2019.08.04
# 2019.07.28
# 2019.07.21
# 2019.07.14
# 2019.07.07
# 2019.06.30
# 2019.06.23
# 2019.06.16
# 2019.06.09
# 2019.06.02
# 2019.05.26
# 2019.05.19
# 2019.05.12
# 2019.05.05
# 2019.04.28
# 2019.04.21
# 2019.04.14
# 2019.04.07
# 2019.03.31
# 2019.03.24
# 2019.03.17
# 2019.03.10
# 2019.03.03
# 2019.02.24
# 2019.02.17
# 2019.02.10
# 2019.02.03
# 2019.01.27
# 2019.01.20
# 2019.01.13
# 2019.01.06
# 2018.12.30
# 2018.12.23
# 2018.12.16
# 2018.12.09
# 2018.12.02
# 2018.11.25
# 2018.11.18
# 2018.11.11
# 2018.11.04
# 2018.10.28
# 2018.10.21
# 2018.10.14
# 2018.10.07
# 2018.09.30
# 2018.09.23
# 2018.09.16
# 2018.09.09
# 2018.09.02
# 2018.08.26
# 2018.08.19
# 2018.08.12
# 2018.08.05
# 2018.07.29
# 2018.07.22
# 2018.07.15
# 2018.07.08
# 2018.07.01
# 2018.06.24
# 2018.06.17
# 2018.06.10
# 2018.06.03
# 2018.05.27
# 2018.05.20
# 2018.05.13
# 2018.05.06
# 2018.04.29
# 2018.04.22
# 2018.04.15
# 2018.04.08
# 2018.04.01
# 2018.03.25
# 2018.03.18
# 2018.03.11
# 2018.03.04
# 2018.02.25
# 2018.02.18
# 2018.02.11
# 2018.02.04
# 2018.01.28
# 2018.01.21
# 2018.01.14
# 2018.01.07
# 2017.12.31
# 2017.12.24
# 2017.12.17
# 2017.12.10
# 2017.12.03
# 2017.11.26
# 2017.11.19
# 2017.11.12
# 2017.11.05
# 2017.10.29
# 2017.10.22
# 2017.10.15
# 2017.10.08
# 2017.10.01
# 2017.09.24
# 2017.09.17
# 2017.09.10
# 2017.09.03
# 2017.08.27
# 2017.08.20
# 2017.08.13
# 2017.08.06
# 2017.07.30
# 2017.07.23
# 2017.07.16
# 2017.07.09
# 2017.07.02
# 2017.06.25
# 2017.06.18
# 2017.06.11
# 2017.06.04
# 2017.05.28
# 2017.05.21
# 2017.05.14
# 2017.05.07
# 2017.04.30
# 2017.04.23
# 2017.04.16
# 2017.04.09
# 2017.04.02
# 2017.03.26
# 2017.03.19
# 2017.03.05
# 2017.02.26
# 2017.02.19
# 2017.02.12
# 2017.02.05
# 2017.01.29
# 2017.01.22
# 2017.01.15
# 2017.01.08
# 2017.01.01
# 2016.12.25
# 2016.12.18
# 2016.12.11
# 2016.12.04
# 2016.11.27
# 2016.11.20
# 2016.11.13
# 2016.11.06
# 2016.10.30
# 2016.10.23
# 2016.10.16
# 2016.10.09
# 2016.10.02
# 2016.09.25
# 2016.09.18
# 2016.09.11
# 2016.09.04
# 2016.08.28
# 2016.08.21
# 2016.08.14
# 2016.08.07
# 2016.07.31
# 2016.07.24
# 2016.07.17
# 2016.07.10
# 2016.07.03
# 2016.06.26
# 2016.06.19
# 2016.06.12
# 2016.06.05
# 2016.05.29
# 2016.05.22
# 2016.05.15
# 2016.05.08
# 2016.05.01
# 2016.04.24
# 2016.04.17
# 2016.04.10
# 2016.04.03
# 2016.03.27
# 2016.03.20
# 2016.03.13
# 2016.03.06
# 2016.02.28
# 2016.02.21
# 2016.02.14
# 2016.02.07
# 2016.01.31
# 2016.01.24
# 2016.01.17
# 2016.01.10
# 2016.01.03
# 2015.12.27
# 2015.12.20
# 2015.12.13
# 2015.12.06
# 2015.11.29
# 2015.11.22
# 2015.11.15
# 2015.11.08
# 2015.11.01
# 2015.10.25
# 2015.10.18
# 2015.10.11
# 2015.10.04
# 2015.09.27
# 2015.09.20
# 2015.09.13
# 2015.09.06
# 2015.08.30
# 2015.08.23
# 2015.08.16
# 2015.08.09
# 2015.08.02
# 2015.07.26
# 2015.07.19
# 2015.07.12
# 2015.07.05
# 2015.06.28
# 2015.06.21
# 2015.06.14
# 2015.06.07
# 2015.05.31
# 2015.05.24
# 2015.05.17
# 2015.05.10
# 2015.05.03
# 2015.04.26
# 2015.04.19
# 2015.04.12
# 2015.04.05
# 2015.03.29
# 2015.03.22
# 2015.03.15
# 2015.03.08
# 2015.03.01
# 2015.02.22
# 2015.02.15
# 2015.02.08
# 2015.02.01
# 2015.01.25
# 2015.01.18
# 2015.01.11
# 2015.01.04

# %%
# function that gets the needed features from the correlation information

def needed_features(processed_week):
    
    
    # load the corelation data from CSV
    correlation_dataframe = pd.read_csv('files/' + processed_week + '/auto-correlation2.csv'  ) 

    # declair the variable that will hold all testable units, the week and the needed feature
    currency_pair_detail = []
    
    # loop through all currency pairs
    for a in all_currency_pairs:

        current_currency = a.replace('10080','')


        weeks = [    {'week_name' : 10, 'correlation_cutoff' : 0.632},
                     {'week_name' : 15, 'correlation_cutoff' : 0.514},
                     {'week_name' : 20, 'correlation_cutoff' : 0.444},
                     {'week_name' : 30, 'correlation_cutoff' : 0.361},
                     {'week_name' : 50, 'correlation_cutoff' : 0.279},
                ]


        #loop throuh all available weeks
        for b in weeks:

            needed_column_list = []

            #check if the current currency in the current week has any currency above the correlation score of the week
            #this is to avoid running analysis for weeks with no correlation

            if  correlation_dataframe[current_currency + '_' + str(b['week_name'])][0] > b['correlation_cutoff']:

                #loop though weeks to get all the currency pairs in the weeks lesser than current week according to my strategy
                for c in weeks:

                    if c['week_name'] <= b['week_name']:

                        #gets the needed two needed columns
                        current_needed_columns = correlation_dataframe[[current_currency + '__' + str(c['week_name']), current_currency + '_' + str(c['week_name'])]] 

                        #get the rows that has corelation
                        current_needed_columns = current_needed_columns.loc[ (current_needed_columns[current_currency + '_' + str(c['week_name'])] >= c['correlation_cutoff'])]

                        #converts the currency pairs that passes to list
                        current_needed_columns = current_needed_columns[current_currency + '__' + str(c['week_name'])].values.tolist()

                        #loop through all the currency pairs that passes and append each currency pair to the list if it is not there already
                        for d in current_needed_columns :
                            if d not in needed_column_list:
                                needed_column_list.append(d) 


            #creates a dictionary with the needed info for the currency and week
            current_currency_detail = {'currency_name': current_currency, 'week': b['week_name'], 'needed_features':needed_column_list }

            #appends all non empty currency detail to the global list
            if len(current_currency_detail['needed_features']) > 0:
                currency_pair_detail.append(current_currency_detail)








    #print(currency_pair_detail)

    return currency_pair_detail

# %%
def learn_best_trading_parameters(processed_week, currency_pair_detail ):
    
    for e in currency_pair_detail:
    
        #print (e['currency_name'])
        current_currency = e['currency_name']

      
        raw_data = pd.read_csv('files/' + processed_week + '/'+ e['currency_name'] + '.csv'   ) 
        weeks = e['week']

        number_of_accurate_prediction = 0
        number_of_trades = 0


        step_down = 5
        cut_off = 0
        n_estimators = 100
        min_samples_leaf = 1
        max_features = "auto"
        max_samples = None



        for v in range(step_down):




            data = raw_data.copy()
            data = data[v:v+weeks]
            #print(data['date'])


            y = data['nextweek_'+ current_currency]


            X = data.loc[:, e['needed_features'] ]






            X_train = X[1:]
            y_train = y[1:]
            X_test = X[:1]
            y_test = y[:1]




            clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                         max_features=max_features, max_samples = max_samples)

            clf.fit(X_train,y_train)
            y_pred=clf.predict(X_test)


            y_test = y_test.values




            if y_pred[0] > cut_off  or y_pred[0] < (-1*cut_off) :
                number_of_trades = number_of_trades + 1
                #print(y_pred[0], y_test[0])


                if (y_pred[0] > 0 and y_test[0] == 1) or (y_pred[0] < 0 and y_test[0]) == -1:
                    number_of_accurate_prediction = number_of_accurate_prediction +1



        e['accuracy_score'] =  100*number_of_accurate_prediction/number_of_trades
        #print(e['accuracy_score'])
        
    return currency_pair_detail

# %%
def next_week_prediction(currency_pair_detail):
    
    next_week_trades =[]

    for f in all_currency_pairs:

        current_currency = f.replace('10080','')
        current_currency_list =[]
        current_currency_best_trade = None

        for g in currency_pair_detail:



            if g['currency_name'] == current_currency:

                current_currency_list.append(g)


        current_currency_list.sort(key=lambda x: x['week'], reverse=False)

        for h in current_currency_list:

            if h['accuracy_score'] > 99.9:

                current_currency_best_trade = h

                break


        if current_currency_best_trade == None:

            for i in current_currency_list:

                if i['accuracy_score'] > 79.9:

                    current_currency_best_trade = i

                    break


        if current_currency_best_trade != None:

            next_week_trades.append(current_currency_best_trade)




    #print(next_week_trades)  
    
    return next_week_trades

# %%
def save_next_week_trades(processed_week, next_week_trades):
    
    # creating a dataframe for nextweek trades and saving it in csv

    name =[]
    week = []
    needed_features = []
    accuracy =[]

    for j in next_week_trades:

        name.append(j['currency_name'])
        week.append(j['week'])
        needed_features.append(j['needed_features'])
        accuracy.append(j['accuracy_score'])


    next_week_trades_dataframe = pd.DataFrame()
    next_week_trades_dataframe['names']=name
    next_week_trades_dataframe['week'] =week
    next_week_trades_dataframe['needed_features'] = needed_features
    next_week_trades_dataframe['accuracy']=accuracy


    print(next_week_trades_dataframe)

    next_week_trades_dataframe.to_csv('files/' + processed_week + '/next_week_trades.csv', index = False   ) 
    
    return 'OK'

# %%
for g in available_weeks:

    currency_pair_detail = needed_features(g)

    currency_pair_detail = learn_best_trading_parameters(g, currency_pair_detail)

    next_week_trades = next_week_prediction(currency_pair_detail)

    final_output = save_next_week_trades(g, next_week_trades)

    print('------$$$$$$$$$$$$$$$$$-----------------------------------------------------------', g)
# Out:
#      names  week                           needed_features  accuracy
# 0   EURUSD    15                                  [CHFJPY]      80.0
# 1   USDJPY    15                                  [EURNZD]      80.0
# 2   USDCAD    50                  [USDJPY, EURUSD, NZDJPY]      80.0
# 3   AUDUSD    10          [AUDJPY, GBPAUD, EURJPY, USDCAD]      80.0
# 4   NZDUSD    10                  [AUDUSD, GBPAUD, AUDJPY]      80.0
# 5   EURCHF    15                          [EURAUD, AUDNZD]     100.0
# 6   CADCHF    10                                  [EURNZD]      80.0
# 7   AUDCHF    20                                  [NZDCHF]      80.0
# 8   NZDCHF    50          [AUDNZD, EURCAD, GBPCHF, USDCHF]      80.0
# 9   GBPCAD    10                  [AUDJPY, GBPCHF, GBPAUD]      80.0
# 10  GBPAUD    50  [AUDJPY, GBPAUD, EURJPY, USDCAD, NZDUSD]      80.0
# 11  EURCAD    15                                  [EURNZD]      80.0
# 12  EURNZD    20                  [CHFJPY, USDCHF, GBPUSD]      80.0
# 13  CADJPY    10                          [AUDJPY, GBPAUD]      80.0
# 14  NZDJPY    10                  [AUDUSD, GBPAUD, AUDJPY]      80.0
# 15  AUDCAD    10                  [USDCHF, USDCAD, EURJPY]      80.0
# 16  NZDCAD    10                                  [NZDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.28
#      names  week                   needed_features  accuracy
# 0   USDCHF    15                          [USDJPY]      80.0
# 1   EURUSD    10                  [EURGBP, GBPJPY]      80.0
# 2   USDJPY    15          [EURNZD, NZDCAD, EURGBP]     100.0
# 3   USDCAD    10                          [NZDCAD]      80.0
# 4   AUDUSD    10  [AUDJPY, GBPAUD, EURJPY, USDCAD]      80.0
# 5   NZDUSD    10          [AUDUSD, GBPAUD, AUDJPY]      80.0
# 6   GBPCHF    30                  [EURNZD, NZDCHF]      80.0
# 7   EURCHF    10          [USDJPY, EURAUD, EURCAD]     100.0
# 8   CHFJPY    10                          [GBPUSD]     100.0
# 9   CADCHF    10          [EURNZD, NZDCAD, NZDCHF]     100.0
# 10  AUDCHF    10                          [NZDCHF]      80.0
# 11  NZDCHF    10                          [EURUSD]      80.0
# 12  GBPJPY    20                  [GBPJPY, NZDCAD]      80.0
# 13  GBPCAD    15                          [GBPCHF]      80.0
# 14  EURJPY    10                          [NZDCAD]      80.0
# 15  EURCAD    10                  [EURNZD, NZDCAD]      80.0
# 16  EURAUD    15                  [USDCHF, NZDCAD]     100.0
# 17  EURNZD    20          [CHFJPY, USDCHF, GBPUSD]      80.0
# 18  AUDJPY    15                          [CHFJPY]      80.0
# 19  NZDJPY    30                          [USDCHF]      80.0
# 20  AUDCAD    10  [USDCHF, EURUSD, USDCAD, EURJPY]      80.0
# 21  NZDCAD    10                          [NZDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.21
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                   [AUDCHF, EURCAD]      80.0
# 1   GBPUSD    15                   [EURGBP, CADCHF, AUDCHF, USDJPY]      80.0
# 2   EURUSD    20  [NZDUSD, CHFJPY, CADJPY, AUDUSD, NZDJPY, USDJP...     100.0
# 3   USDJPY    15                   [EURNZD, EURGBP, NZDUSD, CADJPY]     100.0
# 4   USDCAD    10                                           [NZDCAD]      80.0
# 5   AUDUSD    10   [GBPAUD, AUDJPY, EURAUD, EURJPY, USDCAD, GBPUSD]      80.0
# 6   NZDUSD    10                   [AUDUSD, GBPUSD, GBPAUD, AUDJPY]      80.0
# 7   GBPCHF    30                                   [EURNZD, NZDCHF]      80.0
# 8   EURCHF    10                                   [EURAUD, EURCAD]     100.0
# 9   CHFJPY    10                                           [GBPUSD]      80.0
# 10  CADCHF    10   [EURNZD, NZDUSD, NZDCAD, AUDUSD, NZDJPY, CHFJPY]      80.0
# 11  AUDCHF    10                                   [AUDCHF, NZDCHF]     100.0
# 12  NZDCHF    10                                           [AUDNZD]      80.0
# 13  GBPCAD    15                                           [GBPCHF]      80.0
# 14  EURJPY    10                                           [NZDCAD]      80.0
# 15  EURCAD    10                                           [EURNZD]      80.0
# 16  EURAUD    15                                   [USDCHF, NZDCAD]     100.0
# 17  EURNZD    15                                   [GBPUSD, CHFJPY]      80.0
# 18  AUDJPY    15                                           [CHFJPY]      80.0
# 19  AUDCAD    15           [USDCHF, GBPUSD, EURUSD, USDCAD, EURJPY]     100.0
# 20  NZDCAD    15                   [NZDUSD, EURAUD, GBPUSD, EURNZD]      80.0
# 21  AUDNZD    10                           [EURGBP, GBPJPY, AUDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.14
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                           [AUDCHF, EURCAD, USDJPY]      80.0
# 1   GBPUSD    10                                           [EURGBP]      80.0
# 2   EURUSD    15                   [EURGBP, NZDUSD, CHFJPY, USDJPY]     100.0
# 3   USDJPY    15                           [EURNZD, EURCAD, EURGBP]     100.0
# 4   USDCAD    10                                   [NZDCAD, AUDNZD]     100.0
# 5   AUDUSD    10                           [GBPAUD, AUDJPY, EURAUD]      80.0
# 6   NZDUSD    10                                           [AUDUSD]      80.0
# 7   GBPCHF    30                                           [NZDCHF]     100.0
# 8   EURCHF    50   [AUDJPY, EURAUD, GBPAUD, AUDNZD, NZDJPY, USDJPY]     100.0
# 9   CADCHF    10  [EURNZD, NZDUSD, NZDCHF, AUDCAD, NZDCAD, NZDJP...      80.0
# 10  AUDCHF    10                                   [NZDCHF, AUDCHF]     100.0
# 11  NZDCHF    10                   [AUDNZD, GBPUSD, EURUSD, EURCAD]      80.0
# 12  EURGBP    10                                           [NZDCHF]      80.0
# 13  EURJPY    10                                   [NZDCAD, AUDNZD]     100.0
# 14  EURCAD    15  [EURNZD, NZDUSD, NZDJPY, NZDCAD, AUDUSD, AUDCA...      80.0
# 15  EURAUD    10                                           [USDCHF]     100.0
# 16  EURNZD    10                   [GBPUSD, USDCHF, NZDUSD, CHFJPY]     100.0
# 17  CADJPY    10                                           [NZDCAD]      80.0
# 18  NZDJPY    30                                           [USDCHF]      80.0
# 19  AUDCAD    15           [USDCHF, EURUSD, USDCAD, EURJPY, GBPUSD]     100.0
# 20  NZDCAD    15  [NZDUSD, NZDJPY, EURNZD, GBPUSD, AUDUSD, GBPAU...     100.0
# 21  AUDNZD    10   [NZDUSD, NZDJPY, CADJPY, AUDUSD, AUDCHF, GBPJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.11.07
#      names  week                                   needed_features  accuracy
# 0   USDCHF    15                          [AUDCHF, EURCAD, USDJPY]      80.0
# 1   GBPUSD    20                          [EURGBP, USDJPY, CADCHF]     100.0
# 2   EURUSD    15                  [EURGBP, NZDUSD, CHFJPY, USDJPY]     100.0
# 3   USDJPY    20          [EURNZD, EURCAD, CADJPY, NZDJPY, NZDCHF]     100.0
# 4   AUDUSD    15                                  [USDCHF, NZDCHF]     100.0
# 5   NZDUSD    10                                          [AUDUSD]      80.0
# 6   GBPCHF    30                                          [NZDCHF]     100.0
# 7   EURCHF    30                                          [NZDJPY]      80.0
# 8   CADCHF    10                          [EURNZD, NZDCAD, NZDUSD]      80.0
# 9   AUDCHF    15                                          [NZDCHF]      80.0
# 10  NZDCHF    10                          [AUDNZD, GBPUSD, EURUSD]      80.0
# 11  EURGBP    10                                          [NZDCHF]      80.0
# 12  GBPCAD    10                                  [GBPCHF, GBPJPY]     100.0
# 13  GBPAUD    10                                          [USDCHF]     100.0
# 14  EURJPY    15                                          [NZDCAD]     100.0
# 15  EURCAD    15          [EURNZD, NZDCAD, NZDUSD, NZDJPY, NZDCHF]      80.0
# 16  EURAUD    15                                  [USDCHF, NZDCHF]     100.0
# 17  EURNZD    10                  [USDCHF, GBPUSD, NZDUSD, CHFJPY]     100.0
# 18  CADJPY    10                                          [NZDCAD]      80.0
# 19  AUDJPY    15                                  [USDCHF, NZDCHF]     100.0
# 20  NZDJPY    30                                          [USDCHF]      80.0
# 21  AUDCAD    10  [USDCHF, GBPUSD, USDCAD, EURJPY, NZDJPY, EURUSD]      80.0
# 22  NZDCAD    10  [NZDUSD, GBPUSD, EURNZD, NZDJPY, AUDUSD, EURUSD]      80.0
# 23  AUDNZD    10  [NZDUSD, AUDCHF, CADJPY, AUDUSD, GBPJPY, NZDJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.10.31
#      names  week                                    needed_features  accuracy
# 0   GBPUSD    15                                   [EURCAD, USDJPY]      80.0
# 1   EURUSD    20                                   [CHFJPY, USDJPY]      80.0
# 2   USDJPY    20                   [EURCAD, CADJPY, NZDJPY, NZDCHF]      80.0
# 3   AUDUSD    15                   [CHFJPY, USDCHF, EURAUD, NZDCHF]     100.0
# 4   GBPCHF    15                                           [EURGBP]      80.0
# 5   EURCHF    20                                           [NZDJPY]      80.0
# 6   CADCHF    10   [EURNZD, EURUSD, USDJPY, NZDCAD, NZDUSD, GBPUSD]      80.0
# 7   AUDCHF    15                                           [NZDCHF]      80.0
# 8   NZDCHF    10                   [AUDNZD, NZDUSD, GBPUSD, NZDCAD]      80.0
# 9   EURGBP    10                                   [GBPCHF, NZDCHF]      80.0
# 10  GBPCAD    10                                   [GBPCHF, GBPJPY]      80.0
# 11  GBPAUD    15                                           [USDCHF]      80.0
# 12  EURCAD    15  [EURNZD, EURUSD, NZDCAD, USDCAD, EURJPY, NZDUS...      80.0
# 13  EURAUD    15                           [USDCHF, CHFJPY, NZDCHF]     100.0
# 14  EURNZD    20                           [CHFJPY, USDCHF, GBPUSD]     100.0
# 15  CADJPY    15                           [NZDCAD, GBPCHF, AUDCAD]     100.0
# 16  AUDJPY    50                                   [USDCHF, AUDCAD]      80.0
# 17  NZDJPY    50                                           [USDCHF]      80.0
# 18  AUDCAD    10  [NZDJPY, CHFJPY, USDCHF, USDCAD, NZDUSD, EURJP...      80.0
# 19  NZDCAD    50                   [GBPUSD, NZDUSD, EURUSD, EURNZD]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.10.24
#      names  week                                   needed_features  accuracy
# 0   EURUSD    10                                          [CHFJPY]      80.0
# 1   USDJPY    10                                          [EURNZD]      80.0
# 2   AUDUSD    15          [CHFJPY, USDCHF, NZDCHF, EURAUD, CADJPY]     100.0
# 3   NZDUSD    15                                  [EURGBP, CHFJPY]     100.0
# 4   GBPCHF    30                                          [NZDCHF]      80.0
# 5   EURCHF    10                                          [CADCHF]     100.0
# 6   CHFJPY    30                                  [GBPJPY, EURCAD]      80.0
# 7   CADCHF    10          [EURUSD, USDJPY, NZDCAD, NZDUSD, GBPUSD]      80.0
# 8   AUDCHF    10                                          [NZDCHF]     100.0
# 9   NZDCHF    20  [GBPCAD, EURNZD, NZDCAD, NZDUSD, AUDNZD, GBPUSD]      80.0
# 10  EURGBP    10                                  [NZDCHF, GBPCHF]     100.0
# 11  GBPJPY    30                                          [NZDCAD]      80.0
# 12  GBPCAD    15  [NZDCAD, NZDUSD, GBPUSD, GBPCHF, EURUSD, USDCAD]      80.0
# 13  EURNZD    20                          [CHFJPY, USDCHF, GBPUSD]     100.0
# 14  CADJPY    10                  [NZDCAD, AUDNZD, AUDCAD, NZDCHF]     100.0
# 15  NZDJPY    50                                          [USDCHF]      80.0
# 16  AUDCAD    10                          [CHFJPY, EURJPY, USDCHF]     100.0
# 17  NZDCAD    15                                  [EURNZD, GBPUSD]     100.0
# 18  AUDNZD    10                          [NZDUSD, GBPUSD, EURUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.10.17
#      names  week                                    needed_features  accuracy
# 0   USDCHF    50  [NZDCAD, AUDCAD, EURUSD, EURNZD, NZDUSD, GBPUS...     100.0
# 1   USDJPY    10                                           [EURNZD]     100.0
# 2   AUDUSD    15                           [NZDCHF, CHFJPY, EURAUD]     100.0
# 3   NZDUSD    15                                           [EURGBP]      80.0
# 4   GBPCHF    10                                           [EURGBP]     100.0
# 5   EURCHF    10                                           [AUDNZD]      80.0
# 6   CHFJPY    10                                   [GBPJPY, EURNZD]      80.0
# 7   CADCHF    10                                   [USDJPY, EURUSD]     100.0
# 8   AUDCHF    10                           [USDJPY, EURGBP, EURCHF]      80.0
# 9   NZDCHF    50                                   [CADCHF, GBPCHF]      80.0
# 10  EURGBP    10                                   [NZDCHF, GBPCHF]     100.0
# 11  GBPCAD    15                           [GBPUSD, EURUSD, GBPCHF]      80.0
# 12  GBPAUD    10                           [EURCAD, USDJPY, NZDCAD]      80.0
# 13  EURAUD    15           [NZDCAD, AUDNZD, CHFJPY, AUDCAD, NZDCHF]      80.0
# 14  EURNZD    10                                           [CHFJPY]      80.0
# 15  CADJPY    15           [NZDCAD, AUDNZD, CHFJPY, AUDCAD, NZDCHF]      80.0
# 16  AUDJPY    30           [NZDCAD, AUDNZD, CHFJPY, AUDCAD, NZDCHF]      80.0
# 17  AUDCAD    10                                   [CHFJPY, EURJPY]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.10.10
#      names  week                                    needed_features  accuracy
# 0   USDCHF    20  [GBPJPY, NZDCAD, USDCAD, NZDJPY, NZDUSD, EURUS...     100.0
# 1   USDJPY    10                                           [EURNZD]      80.0
# 2   AUDUSD    15                           [CHFJPY, GBPCHF, NZDCHF]      80.0
# 3   NZDUSD    15                                           [EURGBP]      80.0
# 4   GBPCHF    10                                           [EURGBP]      80.0
# 5   EURCHF    10                                   [AUDNZD, CADCHF]     100.0
# 6   CHFJPY    10                                   [GBPJPY, EURJPY]     100.0
# 7   CADCHF    10                                           [USDJPY]     100.0
# 8   AUDCHF    10                                   [EURGBP, EURCHF]      80.0
# 9   NZDCHF    15                   [AUDNZD, NZDCAD, CADCHF, EURNZD]     100.0
# 10  EURGBP    50  [GBPCHF, NZDCHF, NZDCAD, AUDCAD, CADJPY, EURCH...     100.0
# 11  GBPCAD    10                   [EURUSD, GBPUSD, AUDNZD, USDJPY]      80.0
# 12  EURAUD    15           [NZDCAD, GBPCHF, AUDCAD, NZDCHF, CHFJPY]      80.0
# 13  EURNZD    10                                           [CHFJPY]      80.0
# 14  AUDJPY    30           [NZDCAD, GBPCHF, AUDCAD, NZDCHF, CHFJPY]      80.0
# 15  AUDCAD    10                                   [CHFJPY, EURJPY]      80.0
# 16  NZDCAD    10                                   [AUDNZD, EURNZD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.10.03
#      names  week                   needed_features  accuracy
# 0   USDCHF    10  [NZDCAD, AUDCAD, NZDUSD, GBPAUD]      80.0
# 1   AUDUSD    10                  [USDCHF, NZDCHF]      80.0
# 2   GBPCHF    10                          [EURGBP]      80.0
# 3   EURCHF    10                  [EURGBP, CADCHF]     100.0
# 4   CHFJPY    10          [GBPJPY, EURGBP, EURAUD]      80.0
# 5   CADCHF    15                          [USDJPY]     100.0
# 6   AUDCHF    10                          [EURGBP]      80.0
# 7   EURGBP    10                  [GBPCHF, NZDCHF]      80.0
# 8   GBPCAD    10                  [GBPUSD, EURUSD]      80.0
# 9   GBPAUD    30                          [AUDCAD]      80.0
# 10  EURNZD    10                          [CHFJPY]      80.0
# 11  CADJPY    20  [NZDCAD, AUDCAD, CHFJPY, GBPCHF]     100.0
# 12  AUDJPY    50          [USDCHF, NZDCHF, AUDCAD]     100.0
# 13  AUDCAD    15                  [EURAUD, NZDCHF]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.09.26
#      names  week                                   needed_features  accuracy
# 0   USDCHF    10                          [NZDCAD, AUDCAD, NZDUSD]     100.0
# 1   USDJPY    20  [AUDJPY, EURCAD, CADJPY, NZDJPY, USDJPY, CADCHF]     100.0
# 2   USDCAD    20                                  [USDJPY, EURCAD]      80.0
# 3   AUDUSD    50                                  [EURNZD, EURGBP]      80.0
# 4   NZDUSD    10                                          [CHFJPY]     100.0
# 5   GBPCHF    30                                  [EURGBP, NZDCHF]      80.0
# 6   EURCHF    10                                          [EURGBP]      80.0
# 7   CHFJPY    10                          [EURGBP, GBPJPY, EURAUD]      80.0
# 8   CADCHF    10                                          [USDCAD]     100.0
# 9   AUDCHF    10                                          [EURGBP]      80.0
# 10  EURGBP    50                          [AUDCAD, EURJPY, EURCAD]      80.0
# 11  GBPCAD    10                  [USDCAD, GBPUSD, EURUSD, EURJPY]      80.0
# 12  GBPAUD    30                                          [AUDCAD]      80.0
# 13  EURAUD    30                                          [AUDCAD]      80.0
# 14  EURNZD    10                          [CHFJPY, USDCHF, NZDCHF]      80.0
# 15  CADJPY    10                  [NZDCAD, AUDCAD, GBPCHF, CHFJPY]      80.0
# 16  AUDJPY    20                                          [AUDCAD]      80.0
# 17  NZDJPY    30                                          [USDCHF]      80.0
# 18  AUDCAD    10                                          [EURAUD]     100.0
# 19  NZDCAD    10                                          [EURAUD]     100.0
# 20  AUDNZD    20                                  [AUDNZD, USDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.09.19
#      names  week                                   needed_features  accuracy
# 0   USDCHF    10                                  [NZDCAD, AUDCAD]     100.0
# 1   GBPUSD    10                                  [EURCAD, USDJPY]      80.0
# 2   EURUSD    10                                  [EURCAD, USDJPY]      80.0
# 3   USDJPY    10                  [EURCAD, AUDJPY, CADJPY, CADCHF]     100.0
# 4   USDCAD    10                                  [USDJPY, EURCAD]      80.0
# 5   AUDUSD    50                                  [EURNZD, EURGBP]      80.0
# 6   NZDUSD    10                                          [CHFJPY]      80.0
# 7   EURCHF    20                                          [NZDJPY]      80.0
# 8   CHFJPY    10                                          [EURGBP]      80.0
# 9   CADCHF    15                                          [USDJPY]      80.0
# 10  EURGBP    10                                  [NZDCAD, AUDCAD]      80.0
# 11  GBPJPY    10                                          [EURJPY]      80.0
# 12  GBPCAD    10                          [GBPUSD, EURUSD, USDCAD]      80.0
# 13  GBPAUD    30                                          [AUDCAD]      80.0
# 14  EURCAD    10  [CADCHF, AUDJPY, AUDUSD, EURCHF, AUDCHF, GBPAUD]      80.0
# 15  EURAUD    30                                  [CHFJPY, AUDCAD]      80.0
# 16  EURNZD    10                          [CHFJPY, USDCHF, NZDCHF]      80.0
# 17  AUDJPY    20                                          [AUDCAD]      80.0
# 18  NZDJPY    20                                          [USDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.09.12
#      names  week                           needed_features  accuracy
# 0   USDCHF    10  [NZDCAD, NZDUSD, AUDCAD, EURUSD, GBPUSD]     100.0
# 1   GBPUSD    10                          [USDJPY, EURCAD]      80.0
# 2   EURUSD    10                          [USDJPY, EURCAD]     100.0
# 3   USDJPY    10          [EURCAD, CADJPY, USDJPY, CADCHF]     100.0
# 4   USDCAD    15                                  [USDJPY]     100.0
# 5   AUDUSD    50                          [EURGBP, EURNZD]      80.0
# 6   NZDUSD    10                                  [EURGBP]      80.0
# 7   GBPCHF    30                          [EURAUD, NZDCHF]     100.0
# 8   EURGBP    10                          [NZDCAD, AUDCAD]      80.0
# 9   GBPJPY    10                                  [EURJPY]      80.0
# 10  GBPCAD    10                  [GBPUSD, EURUSD, USDCAD]      80.0
# 11  GBPAUD    50                                  [EURGBP]      80.0
# 12  EURJPY    10                                  [USDJPY]     100.0
# 13  EURCAD    10                                  [CADCHF]     100.0
# 14  EURAUD    30                                  [AUDCAD]      80.0
# 15  EURNZD    10          [USDCHF, NZDJPY, NZDCHF, CHFJPY]      80.0
# 16  AUDJPY    30                          [AUDCAD, EURCAD]      80.0
# 17  NZDJPY    10                          [EURGBP, CADCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.09.05
#      names  week                                    needed_features  accuracy
# 0   USDCHF    15   [NZDCAD, AUDCAD, NZDUSD, EURUSD, GBPUSD, USDCHF]     100.0
# 1   GBPUSD    10                                           [USDJPY]      80.0
# 2   EURUSD    10                                           [USDJPY]     100.0
# 3   USDJPY    20  [EURCAD, CADJPY, CADCHF, NZDCHF, NZDJPY, AUDJP...     100.0
# 4   USDCAD    10                                           [USDJPY]     100.0
# 5   GBPCHF    50                                   [NZDCHF, EURUSD]      80.0
# 6   CHFJPY    10                                           [EURGBP]     100.0
# 7   EURGBP    10  [NZDCAD, AUDCAD, EURNZD, AUDCHF, GBPAUD, AUDUS...     100.0
# 8   GBPJPY    20                                           [AUDCHF]      80.0
# 9   GBPCAD    20           [GBPUSD, EURUSD, USDCAD, USDCHF, AUDNZD]     100.0
# 10  GBPAUD    50                                           [EURGBP]      80.0
# 11  EURNZD    15                                   [NZDJPY, NZDCHF]      80.0
# 12  CADJPY    10                                           [EURJPY]      80.0
# 13  AUDCAD    10                                           [EURGBP]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.08.29
#      names  week                                   needed_features  accuracy
# 0   USDCHF    15  [NZDCAD, AUDCAD, NZDUSD, EURUSD, GBPUSD, USDCHF]     100.0
# 1   GBPUSD    10                  [EURUSD, GBPUSD, USDCHF, USDJPY]      80.0
# 2   EURUSD    10                  [EURUSD, GBPUSD, USDCHF, USDJPY]      80.0
# 3   USDJPY    15                  [EURCAD, CADJPY, NZDJPY, CADCHF]     100.0
# 4   USDCAD    50  [EURUSD, GBPUSD, USDCHF, USDJPY, NZDJPY, EURNZD]     100.0
# 5   GBPCHF    50                  [NZDCHF, GBPCAD, NZDCAD, EURUSD]     100.0
# 6   EURCHF    15                                          [NZDJPY]      80.0
# 7   CHFJPY    10                                          [EURGBP]     100.0
# 8   EURGBP    10          [AUDCAD, NZDCAD, GBPCHF, EURCHF, CHFJPY]     100.0
# 9   GBPJPY    10                          [GBPAUD, AUDUSD, AUDCHF]     100.0
# 10  GBPCAD    10                          [GBPUSD, EURUSD, USDCAD]      80.0
# 11  EURJPY    15                          [EURUSD, GBPUSD, AUDCHF]      80.0
# 12  EURAUD    10                  [NZDJPY, NZDCHF, NZDCAD, AUDCAD]     100.0
# 13  EURNZD    10                          [NZDJPY, NZDCHF, EURCAD]     100.0
# 14  AUDJPY    20                          [EURCAD, AUDCAD, AUDCHF]     100.0
# 15  AUDCAD    10                          [GBPCAD, NZDJPY, NZDCHF]      80.0
# 16  NZDCAD    10                          [GBPCAD, NZDJPY, NZDCHF]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.08.22
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                           [AUDCAD, NZDUSD, NZDCAD]      80.0
# 1   GBPUSD    15                   [USDCHF, CADCHF, EURUSD, GBPUSD]     100.0
# 2   EURUSD    50   [USDCHF, CADCHF, EURUSD, GBPUSD, AUDCAD, NZDUSD]     100.0
# 3   USDJPY    10                                   [EURCAD, CADJPY]      80.0
# 4   USDCAD    30                   [USDCHF, EURUSD, GBPUSD, NZDJPY]      80.0
# 5   AUDUSD    30                                   [EURGBP, EURNZD]      80.0
# 6   GBPCHF    20                           [GBPCAD, NZDCHF, NZDCAD]      80.0
# 7   EURCHF    20                                           [NZDJPY]      80.0
# 8   CHFJPY    10                                           [EURGBP]     100.0
# 9   EURGBP    10                           [AUDCAD, NZDCAD, CADJPY]     100.0
# 10  GBPJPY    20                                   [AUDCHF, USDCAD]      80.0
# 11  GBPCAD    50  [CHFJPY, USDCAD, EURNZD, AUDNZD, EURCHF, USDCH...      80.0
# 12  GBPAUD    50                                   [EURGBP, AUDCAD]      80.0
# 13  EURAUD    30                                           [AUDCAD]      80.0
# 14  EURNZD    15                           [NZDJPY, NZDCHF, EURCAD]     100.0
# 15  CADJPY    10                                           [EURJPY]      80.0
# 16  AUDJPY    15                                           [EURCAD]      80.0
# 17  NZDJPY    50                                   [USDCHF, GBPCAD]     100.0
# 18  AUDCAD    10                                           [GBPCAD]      80.0
# 19  NZDCAD    10                                           [GBPCAD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.08.15
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                           [USDCHF, NZDCAD, NZDUSD]     100.0
# 1   GBPUSD    10                                   [CADCHF, USDCHF]     100.0
# 2   EURUSD    10                                   [CADCHF, USDCHF]     100.0
# 3   USDJPY    10           [CADCHF, NZDJPY, CADJPY, EURCAD, NZDCHF]      80.0
# 4   USDCAD    30                                   [USDCHF, NZDJPY]     100.0
# 5   AUDUSD    30                                           [EURGBP]      80.0
# 6   CHFJPY    10                                           [EURGBP]      80.0
# 7   EURGBP    10                                           [NZDCAD]      80.0
# 8   GBPJPY    15                                           [USDCAD]      80.0
# 9   GBPCAD    30  [CHFJPY, USDCHF, USDCAD, EURCHF, AUDNZD, NZDCA...     100.0
# 10  GBPAUD    50                           [NZDUSD, EURGBP, AUDCAD]     100.0
# 11  EURJPY    10                                           [EURGBP]      80.0
# 12  EURCAD    15                                   [NZDUSD, EURNZD]      80.0
# 13  EURNZD    10                           [NZDJPY, NZDCHF, EURCAD]     100.0
# 14  AUDJPY    10                                           [EURCAD]      80.0
# 15  NZDJPY    30                   [NZDCAD, NZDUSD, USDCHF, EURUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.08.08
#      names  week                                   needed_features  accuracy
# 0   USDCHF    10          [USDCHF, EURUSD, NZDCAD, NZDUSD, GBPUSD]      80.0
# 1   GBPUSD    10                          [EURGBP, AUDCAD, CADCHF]     100.0
# 2   EURUSD    10                          [EURGBP, AUDCAD, CADCHF]     100.0
# 3   USDJPY    15  [AUDCAD, NZDJPY, CADJPY, NZDCHF, CADCHF, USDJPY]     100.0
# 4   AUDUSD    30                                  [AUDCAD, EURGBP]      80.0
# 5   GBPCHF    15                                  [NZDJPY, NZDCHF]      80.0
# 6   EURCHF    15                                  [NZDJPY, NZDCHF]      80.0
# 7   CHFJPY    10                                  [EURGBP, EURCAD]     100.0
# 8   CADCHF    50                          [AUDCAD, EURCAD, NZDCAD]      80.0
# 9   AUDCHF    20                          [AUDCAD, NZDCHF, NZDJPY]      80.0
# 10  NZDCHF    30                                          [EURCAD]     100.0
# 11  GBPJPY    15                                          [USDCAD]      80.0
# 12  GBPCAD    30          [CHFJPY, EURCAD, EURCHF, AUDNZD, NZDCHF]     100.0
# 13  GBPAUD    50                                  [AUDCAD, EURGBP]     100.0
# 14  EURJPY    10                                          [EURGBP]      80.0
# 15  EURCAD    15          [NZDUSD, AUDNZD, EURCHF, EURNZD, GBPCHF]     100.0
# 16  EURNZD    10                                  [NZDJPY, NZDCHF]      80.0
# 17  CADJPY    10                                  [AUDNZD, USDCAD]      80.0
# 18  AUDJPY    10                                          [EURCAD]      80.0
# 19  NZDJPY    30                          [USDCHF, EURUSD, EURCAD]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.08.01
#      names  week                   needed_features  accuracy
# 0   USDCHF    10  [USDCHF, GBPUSD, EURUSD, NZDCAD]      80.0
# 1   GBPUSD    10  [AUDCAD, EURGBP, NZDCAD, CADCHF]      80.0
# 2   EURUSD    10  [AUDCAD, EURGBP, NZDCAD, CADCHF]     100.0
# 3   USDJPY    10  [AUDCAD, NZDJPY, CADJPY, NZDCHF]     100.0
# 4   AUDUSD    10                          [EURCHF]      80.0
# 5   GBPCHF    10                  [NZDJPY, NZDCHF]      80.0
# 6   EURCHF    10                  [NZDJPY, NZDCHF]      80.0
# 7   CHFJPY    20  [EURGBP, EURCAD, CADCHF, AUDNZD]     100.0
# 8   AUDCHF    10                  [GBPCHF, AUDCAD]      80.0
# 9   GBPCAD    15          [AUDNZD, EURCAD, CHFJPY]      80.0
# 10  GBPAUD    50  [EURCHF, AUDCAD, EURGBP, GBPCHF]     100.0
# 11  EURCAD    10  [EURNZD, NZDUSD, EURCHF, AUDNZD]     100.0
# 12  EURAUD    10                          [EURCHF]      80.0
# 13  EURNZD    10                  [NZDJPY, NZDCHF]      80.0
# 14  AUDJPY    10                          [EURCAD]      80.0
# 15  NZDJPY    15                          [USDCHF]      80.0
# 16  AUDCAD    10                          [USDCAD]      80.0
# 17  NZDCAD    10                          [AUDJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.07.25
#      names  week                   needed_features  accuracy
# 0   USDCHF    10          [USDCHF, EURUSD, NZDCAD]      80.0
# 1   GBPUSD    20          [AUDCAD, NZDCAD, CADCHF]     100.0
# 2   EURUSD    10          [AUDCAD, NZDCAD, CADCHF]     100.0
# 3   USDJPY    10          [AUDCAD, NZDJPY, CADJPY]     100.0
# 4   EURCHF    10                          [NZDJPY]      80.0
# 5   CHFJPY    10                          [EURGBP]      80.0
# 6   AUDCHF    10                  [AUDCAD, GBPCHF]      80.0
# 7   GBPCAD    15                  [AUDNZD, CHFJPY]      80.0
# 8   GBPAUD    20                          [AUDCAD]      80.0
# 9   EURJPY    30                  [USDCAD, CHFJPY]      80.0
# 10  EURCAD    10          [EURNZD, NZDUSD, AUDNZD]      80.0
# 11  EURAUD    20                          [AUDCAD]      80.0
# 12  EURNZD    30  [NZDJPY, AUDCHF, EURNZD, EURCAD]      80.0
# 13  CADJPY    30                  [USDCAD, GBPCHF]      80.0
# 14  AUDJPY    10                          [EURCAD]      80.0
# 15  NZDJPY    50          [USDCHF, GBPCHF, EURCAD]      80.0
# 16  AUDCAD    10                          [USDCAD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.07.18
#      names  week                   needed_features  accuracy
# 0   USDCHF    10          [USDCHF, EURUSD, NZDCAD]      80.0
# 1   GBPUSD    20                  [CADCHF, NZDCAD]      80.0
# 2   EURUSD    15  [AUDCAD, NZDCAD, AUDJPY, AUDCHF]     100.0
# 3   USDJPY    10  [USDCHF, NZDJPY, AUDCAD, AUDNZD]     100.0
# 4   GBPCHF    15                  [NZDCAD, NZDCHF]      80.0
# 5   EURCHF    50          [USDJPY, NZDJPY, GBPCHF]      80.0
# 6   CHFJPY    15                  [EURCAD, CADCHF]     100.0
# 7   AUDCHF    10                  [AUDCAD, EURCAD]      80.0
# 8   GBPAUD    50          [AUDCAD, EURGBP, GBPCHF]     100.0
# 9   EURJPY    30  [GBPCHF, USDCAD, EURJPY, CHFJPY]      80.0
# 10  EURCAD    10          [NZDUSD, EURNZD, GBPCHF]      80.0
# 11  EURAUD    20                          [AUDCAD]      80.0
# 12  EURNZD    20  [NZDJPY, EURCAD, AUDCHF, EURNZD]      80.0
# 13  CADJPY    50          [USDCAD, GBPCHF, CADCHF]     100.0
# 14  AUDJPY    10                  [AUDCAD, EURCAD]      80.0
# 15  NZDJPY    30  [USDCHF, EURUSD, USDCAD, GBPCHF]      80.0
# 16  AUDCAD    10                          [USDCAD]      80.0
# 17  AUDNZD    10                          [USDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.07.11
#      names  week                           needed_features  accuracy
# 0   USDCHF    10                  [EURUSD, NZDUSD, NZDCAD]      80.0
# 1   EURUSD    15  [AUDCAD, AUDCHF, NZDCAD, AUDUSD, NZDUSD]     100.0
# 2   USDJPY    10                          [AUDCAD, NZDJPY]     100.0
# 3   NZDUSD    20                                  [AUDCAD]      80.0
# 4   GBPCHF    15                          [NZDCHF, NZDCAD]      80.0
# 5   EURCHF    30                  [AUDNZD, NZDJPY, USDJPY]      80.0
# 6   AUDCHF    10                                  [AUDCAD]      80.0
# 7   GBPAUD    20                                  [AUDCAD]      80.0
# 8   EURCAD    10                  [EURNZD, NZDCAD, NZDUSD]      80.0
# 9   EURAUD    20                                  [AUDCAD]      80.0
# 10  CADJPY    10                                  [USDCAD]      80.0
# 11  AUDJPY    10                                  [AUDCAD]      80.0
# 12  NZDJPY    30  [USDCHF, USDCAD, EURJPY, GBPCHF, GBPJPY]      80.0
# 13  AUDCAD    50                                  [EURJPY]      80.0
# 14  NZDCAD    10                          [AUDCAD, AUDCHF]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.07.04
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                           [CHFJPY]      80.0
# 1   EURUSD    15   [AUDCAD, NZDCHF, AUDUSD, NZDUSD, NZDCAD, AUDCHF]      80.0
# 2   USDJPY    10                                           [AUDCAD]      80.0
# 3   AUDUSD    10                                           [AUDCAD]      80.0
# 4   NZDUSD    10                                           [AUDCAD]      80.0
# 5   GBPCHF    15           [NZDCHF, AUDCHF, AUDJPY, NZDCAD, NZDUSD]      80.0
# 6   EURCHF    30                           [NZDJPY, AUDNZD, USDJPY]      80.0
# 7   AUDCHF    10                                   [AUDCAD, AUDUSD]     100.0
# 8   GBPCAD    10                           [AUDNZD, EURCAD, EURCHF]     100.0
# 9   EURCAD    50  [NZDCAD, NZDUSD, EURNZD, NZDCHF, EURJPY, NZDJP...      80.0
# 10  EURNZD    10                                           [AUDCHF]      80.0
# 11  CADJPY    50                                   [USDCAD, GBPCHF]      80.0
# 12  AUDJPY    15                                           [AUDCAD]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.06.27
#      names  week                   needed_features  accuracy
# 0   USDCHF    50  [CHFJPY, EURJPY, CADJPY, GBPJPY]     100.0
# 1   USDJPY    15          [NZDJPY, GBPJPY, EURJPY]     100.0
# 2   GBPCHF    15  [NZDCHF, AUDCHF, NZDUSD, AUDJPY]      80.0
# 3   EURCHF    30                  [NZDJPY, USDJPY]      80.0
# 4   CADCHF    10                  [AUDCHF, AUDJPY]     100.0
# 5   AUDCHF    10          [AUDCAD, CADCHF, AUDUSD]     100.0
# 6   GBPCAD    10                  [AUDNZD, EURCHF]     100.0
# 7   EURNZD    10                  [EURGBP, AUDCHF]      80.0
# 8   CADJPY    50                          [GBPCHF]      80.0
# 9   AUDJPY    10                          [EURGBP]      80.0
# 10  AUDNZD    30                  [GBPCAD, NZDJPY]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.06.20
#      names  week                   needed_features  accuracy
# 0   USDCHF    50          [EURJPY, CADJPY, CHFJPY]      80.0
# 1   GBPUSD    10                          [USDCAD]     100.0
# 2   USDJPY    30                          [AUDCAD]      80.0
# 3   AUDUSD    15                          [EURNZD]     100.0
# 4   GBPCHF    10                          [CHFJPY]      80.0
# 5   EURCHF    10                  [USDCHF, AUDNZD]      80.0
# 6   CHFJPY    10                          [EURCAD]      80.0
# 7   CADCHF    15                          [NZDUSD]      80.0
# 8   AUDCHF    10                          [AUDCAD]      80.0
# 9   GBPJPY    10                          [USDCAD]      80.0
# 10  GBPCAD    20  [AUDNZD, NZDCHF, EURCHF, NZDJPY]     100.0
# 11  GBPAUD    15                          [NZDUSD]     100.0
# 12  EURNZD    10                  [EURGBP, AUDCHF]      80.0
# 13  AUDJPY    10                          [EURGBP]      80.0
# 14  NZDJPY    10                  [USDCHF, USDCAD]      80.0
# 15  AUDCAD    10                          [GBPCAD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.06.13
#      names  week                           needed_features  accuracy
# 0   USDCHF    20                          [CADJPY, GBPCHF]      80.0
# 1   GBPUSD    15                                  [USDCAD]     100.0
# 2   USDJPY    10                                  [USDJPY]      80.0
# 3   USDCAD    15                                  [NZDJPY]      80.0
# 4   AUDUSD    15                                  [EURNZD]      80.0
# 5   GBPCHF    10                          [USDCAD, CHFJPY]     100.0
# 6   EURCHF    10          [USDCHF, USDJPY, AUDNZD, EURUSD]      80.0
# 7   CADCHF    20                  [USDCAD, NZDUSD, AUDCHF]      80.0
# 8   AUDCHF    10                                  [AUDCAD]      80.0
# 9   EURGBP    10                                  [EURCHF]      80.0
# 10  GBPJPY    15                  [AUDCHF, USDCAD, AUDJPY]     100.0
# 11  GBPCAD    10  [AUDNZD, NZDCHF, NZDCAD, GBPAUD, EURCHF]      80.0
# 12  EURNZD    10                  [AUDCHF, EURGBP, USDCHF]      80.0
# 13  CADJPY    15                          [USDCAD, NZDUSD]      80.0
# 14  NZDJPY    10                          [USDCHF, USDCAD]     100.0
# 15  AUDCAD    10                          [GBPUSD, GBPCAD]      80.0
# 16  NZDCAD    15                          [USDCHF, AUDNZD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.06.06
#      names  week                           needed_features  accuracy
# 0   GBPUSD    20                  [AUDNZD, NZDCHF, NZDCAD]     100.0
# 1   EURUSD    50                          [EURJPY, NZDUSD]     100.0
# 2   USDJPY    50                          [AUDCAD, USDJPY]      80.0
# 3   USDCAD    20                                  [NZDJPY]      80.0
# 4   GBPCHF    10          [NZDCHF, NZDCAD, NZDUSD, EURCHF]      80.0
# 5   EURCHF    15                          [AUDNZD, NZDJPY]      80.0
# 6   CADCHF    20                          [NZDUSD, AUDCHF]     100.0
# 7   NZDCHF    10                  [AUDNZD, NZDJPY, GBPUSD]      80.0
# 8   EURGBP    30                          [GBPUSD, EURCAD]      80.0
# 9   GBPJPY    10  [NZDCHF, NZDCAD, AUDJPY, EURNZD, AUDCHF]      80.0
# 10  GBPCAD    10                  [AUDNZD, NZDCHF, NZDCAD]      80.0
# 11  GBPAUD    10                                  [GBPCHF]      80.0
# 12  EURJPY    30                                  [CHFJPY]      80.0
# 13  EURAUD    10                                  [GBPCHF]      80.0
# 14  CADJPY    15                                  [NZDUSD]     100.0
# 15  NZDJPY    10                  [USDCHF, AUDNZD, USDJPY]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.05.30
#      names  week                           needed_features  accuracy
# 0   GBPUSD    10                                  [NZDCAD]      80.0
# 1   USDJPY    50                                  [AUDCAD]      80.0
# 2   USDCAD    10                          [NZDJPY, NZDUSD]     100.0
# 3   GBPCHF    10          [NZDCHF, NZDCAD, NZDUSD, EURCHF]      80.0
# 4   EURCHF    30          [AUDNZD, NZDJPY, USDJPY, GBPCHF]      80.0
# 5   CHFJPY    10                  [CADJPY, CADCHF, GBPAUD]      80.0
# 6   AUDCHF    10  [NZDJPY, GBPUSD, NZDCHF, AUDNZD, GBPCAD]      80.0
# 7   EURGBP    10                                  [EURCHF]      80.0
# 8   GBPJPY    50                                  [EURAUD]     100.0
# 9   GBPCAD    10                                  [AUDNZD]      80.0
# 10  EURJPY    30                                  [CHFJPY]     100.0
# 11  EURCAD    20                                  [GBPUSD]      80.0
# 12  EURAUD    10                                  [GBPCHF]      80.0
# 13  CADJPY    15                                  [NZDUSD]     100.0
# 14  NZDJPY    10                          [USDCHF, EURUSD]     100.0
# 15  AUDCAD    10                                  [GBPAUD]      80.0
# 16  NZDCAD    10                                  [AUDNZD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.05.23
#     names  week                   needed_features  accuracy
# 0  USDJPY    50                          [AUDCAD]      80.0
# 1  USDCAD    10                          [USDCHF]      80.0
# 2  EURCHF    30  [AUDNZD, NZDJPY, USDJPY, GBPCHF]      80.0
# 3  AUDCHF    10          [GBPUSD, NZDCHF, NZDJPY]     100.0
# 4  EURGBP    15          [GBPUSD, GBPCHF, EURCHF]      80.0
# 5  GBPCAD    20          [NZDCHF, GBPAUD, AUDNZD]     100.0
# 6  EURJPY    30                          [CHFJPY]     100.0
# 7  CADJPY    30                          [NZDUSD]      80.0
# 8  NZDJPY    10                          [USDCHF]     100.0
# 9  NZDCAD    10                          [AUDNZD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.05.16
#      names  week                   needed_features  accuracy
# 0   USDCHF    50  [EURCAD, CADJPY, EURJPY, GBPJPY]      80.0
# 1   USDJPY    50                          [AUDCAD]      80.0
# 2   USDCAD    10                          [USDCHF]     100.0
# 3   GBPCHF    10  [GBPUSD, EURCHF, NZDUSD, NZDCHF]      80.0
# 4   EURCHF    30          [USDJPY, GBPCHF, NZDJPY]     100.0
# 5   AUDCHF    10  [GBPUSD, NZDUSD, NZDCHF, NZDJPY]     100.0
# 6   EURGBP    20                  [GBPUSD, AUDCHF]      80.0
# 7   GBPCAD    15  [EURCHF, NZDCHF, GBPAUD, AUDNZD]      80.0
# 8   EURJPY    30                          [CHFJPY]     100.0
# 9   EURNZD    10                          [EURNZD]      80.0
# 10  NZDJPY    10                          [USDCHF]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.05.09
#      names  week                   needed_features  accuracy
# 0   GBPUSD    10                          [AUDNZD]     100.0
# 1   USDCAD    20                          [NZDJPY]      80.0
# 2   AUDUSD    20                          [EURGBP]      80.0
# 3   GBPCHF    10          [GBPUSD, NZDUSD, NZDCHF]      80.0
# 4   EURCHF    30  [USDJPY, GBPCHF, NZDJPY, AUDJPY]      80.0
# 5   AUDCHF    10          [GBPUSD, NZDUSD, NZDCHF]     100.0
# 6   EURGBP    15  [GBPUSD, AUDJPY, NZDUSD, AUDCHF]     100.0
# 7   GBPAUD    10                          [CHFJPY]      80.0
# 8   EURJPY    20                          [CHFJPY]     100.0
# 9   EURNZD    10                          [EURNZD]      80.0
# 10  AUDCAD    10                          [USDCAD]      80.0
# 11  NZDCAD    10                          [AUDNZD]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.05.02
#      names  week                           needed_features  accuracy
# 0   USDCAD    10                                  [EURCAD]      80.0
# 1   GBPCHF    30          [GBPUSD, NZDUSD, EURUSD, USDCHF]      80.0
# 2   EURCHF    10                          [GBPAUD, GBPUSD]      80.0
# 3   AUDCHF    10          [GBPUSD, NZDUSD, NZDJPY, NZDCHF]      80.0
# 4   EURGBP    15  [AUDJPY, GBPUSD, EURGBP, AUDCHF, NZDUSD]     100.0
# 5   GBPAUD    10                                  [AUDNZD]      80.0
# 6   EURJPY    20                                  [CHFJPY]     100.0
# 7   EURNZD    10                                  [EURNZD]     100.0
# 8   NZDJPY    20                  [GBPCAD, EURCAD, GBPCHF]      80.0
# 9   AUDCAD    10                          [EURUSD, AUDUSD]      80.0
# 10  NZDCAD    10                                  [AUDNZD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.04.25
#      names  week                           needed_features  accuracy
# 0   USDJPY    10                                  [NZDUSD]      80.0
# 1   USDCAD    10                                  [EURCAD]      80.0
# 2   EURCHF    20                                  [USDJPY]     100.0
# 3   CADCHF    10                                  [NZDUSD]      80.0
# 4   AUDCHF    10          [GBPUSD, NZDCHF, NZDUSD, AUDJPY]     100.0
# 5   EURGBP    10          [GBPUSD, NZDCHF, NZDUSD, AUDJPY]     100.0
# 6   GBPJPY    10                                  [GBPUSD]      80.0
# 7   GBPCAD    15          [CADCHF, AUDCAD, USDJPY, NZDCHF]     100.0
# 8   EURJPY    20                                  [CHFJPY]     100.0
# 9   EURCAD    10                                  [NZDUSD]      80.0
# 10  EURNZD    10                                  [EURNZD]     100.0
# 11  NZDJPY    20                  [GBPCAD, EURCAD, GBPCHF]      80.0
# 12  AUDCAD    10  [EURUSD, AUDUSD, USDCHF, USDCAD, NZDUSD]      80.0
# 13  NZDCAD    10                          [AUDUSD, EURUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.04.18
#      names  week                           needed_features  accuracy
# 0   USDJPY    30                  [NZDUSD, EURJPY, AUDCAD]      80.0
# 1   EURCHF    20                  [GBPUSD, USDJPY, AUDJPY]     100.0
# 2   CHFJPY    10                          [EURGBP, AUDCHF]      80.0
# 3   AUDCHF    30                          [CHFJPY, GBPUSD]      80.0
# 4   EURGBP    20          [CHFJPY, GBPUSD, CADCHF, EURCAD]     100.0
# 5   GBPCAD    10                          [NZDCHF, AUDCAD]      80.0
# 6   EURJPY    30                          [NZDUSD, CHFJPY]      80.0
# 7   EURCAD    10                                  [NZDUSD]      80.0
# 8   EURNZD    15  [EURNZD, EURUSD, EURCAD, USDCHF, EURJPY]      80.0
# 9   CADJPY    15                          [CHFJPY, GBPCAD]      80.0
# 10  NZDJPY    20                          [GBPCAD, EURCAD]      80.0
# 11  AUDCAD    10          [AUDUSD, EURUSD, USDCAD, NZDUSD]      80.0
# 12  NZDCAD    10                                  [EURUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.04.11
#      names  week           needed_features  accuracy
# 0   USDCAD    15                  [NZDJPY]      80.0
# 1   NZDUSD    15  [GBPCHF, EURGBP, GBPCAD]      80.0
# 2   GBPCHF    30          [EURUSD, USDCAD]      80.0
# 3   EURCHF    20          [USDJPY, AUDJPY]      80.0
# 4   CHFJPY    10                  [AUDCHF]      80.0
# 5   AUDCHF    30          [CHFJPY, GBPUSD]      80.0
# 6   GBPJPY    30          [AUDCAD, EURUSD]      80.0
# 7   GBPCAD    30                  [AUDCAD]      80.0
# 8   GBPAUD    15                  [NZDJPY]      80.0
# 9   EURJPY    20                  [CHFJPY]      80.0
# 10  EURNZD    10          [EURNZD, EURCAD]      80.0
# 11  AUDCAD    10          [GBPUSD, NZDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2021.04.04
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                           [EURJPY]      80.0
# 1   USDCAD    15                                           [NZDJPY]      80.0
# 2   GBPCHF    15                                           [EURUSD]      80.0
# 3   EURCHF    20                                   [USDJPY, AUDUSD]     100.0
# 4   CADCHF    50                           [EURJPY, NZDCAD, EURCAD]      80.0
# 5   NZDCHF    10                                           [EURJPY]      80.0
# 6   EURGBP    30                           [USDCAD, EURCAD, EURCHF]      80.0
# 7   GBPJPY    30                   [NZDCAD, AUDCAD, GBPCAD, EURUSD]     100.0
# 8   GBPCAD    20                           [AUDCAD, EURUSD, USDCAD]      80.0
# 9   GBPAUD    15                                           [NZDJPY]      80.0
# 10  EURJPY    50                                   [CHFJPY, GBPAUD]     100.0
# 11  EURCAD    10                                   [AUDCAD, AUDUSD]      80.0
# 12  EURAUD    15                                   [NZDJPY, NZDCHF]     100.0
# ...
# 5   GBPCHF    10                           [GBPCAD, GBPAUD, GBPJPY]     100.0
# 6   EURCHF    20  [AUDNZD, EURCHF, NZDJPY, CADJPY, AUDCAD, EURGB...     100.0
# 7   CHFJPY    10                                           [AUDCAD]     100.0
# 8   CADCHF    10                   [GBPCHF, GBPJPY, GBPAUD, AUDCAD]     100.0
# 9   AUDCHF    10                   [GBPCHF, GBPJPY, GBPAUD, AUDCAD]     100.0
# 10  NZDCHF    10                                           [GBPCHF]      80.0
# 11  GBPJPY    10                                   [EURCAD, EURJPY]      80.0
# 12  GBPCAD    10                                           [AUDUSD]      80.0
# 13  GBPAUD    15                   [EURNZD, AUDCHF, NZDCHF, USDCHF]      80.0
# 14  EURJPY    10                                           [EURAUD]      80.0
# 15  EURAUD    30   [NZDCHF, AUDCHF, CHFJPY, EURGBP, NZDUSD, EURCHF]     100.0
# 16  EURNZD    10                           [AUDCHF, NZDCHF, CADCHF]     100.0
# 17  AUDJPY    30                                           [EURUSD]      80.0
# 18  NZDCAD    10                           [CADCHF, AUDCHF, NZDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.03.15
#      names  week                                   needed_features  accuracy
# 0   USDCHF    50                  [EURNZD, EURAUD, NZDCHF, GBPAUD]     100.0
# 1   EURUSD    20                          [EURCHF, GBPAUD, AUDCAD]      80.0
# 2   USDCAD    15                          [EURJPY, AUDJPY, GBPJPY]      80.0
# 3   AUDUSD    20                                          [USDJPY]     100.0
# 4   NZDUSD    10                                  [EURJPY, EURGBP]      80.0
# 5   GBPCHF    10                          [GBPCAD, GBPAUD, GBPJPY]      80.0
# 6   EURCHF    10          [AUDNZD, EURCHF, USDCAD, CADJPY, EURGBP]     100.0
# 7   CHFJPY    20                                  [EURCHF, NZDUSD]      80.0
# 8   CADCHF    10                                          [GBPCHF]     100.0
# 9   AUDCHF    10                                          [GBPCHF]     100.0
# 10  NZDCHF    10                                          [GBPCHF]     100.0
# 11  EURGBP    10                                          [EURAUD]      80.0
# 12  GBPJPY    15  [EURCAD, EURJPY, GBPCHF, EURAUD, GBPAUD, EURUSD]      80.0
# 13  GBPCAD    10                                          [AUDUSD]      80.0
# 14  GBPAUD    15                  [EURNZD, AUDCHF, NZDCHF, USDCHF]      80.0
# 15  EURJPY    10                                  [GBPAUD, EURAUD]      80.0
# 16  EURAUD    10                  [USDCHF, CHFJPY, NZDCHF, AUDCHF]      80.0
# 17  EURNZD    10                          [AUDCHF, NZDCHF, CADCHF]     100.0
# 18  CADJPY    20                          [EURJPY, AUDJPY, GBPJPY]      80.0
# 19  AUDJPY    15                                  [EURUSD, EURAUD]     100.0
# 20  NZDCAD    10                                  [AUDCHF, NZDCHF]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.03.08
#      names  week                   needed_features  accuracy
# 0   USDCHF    15                          [NZDCAD]      80.0
# 1   EURUSD    15                  [EURCHF, NZDCAD]      80.0
# 2   AUDUSD    20                          [USDJPY]     100.0
# 3   GBPCHF    10          [GBPCHF, GBPCAD, GBPAUD]      80.0
# 4   EURCHF    10  [AUDNZD, AUDCAD, CADJPY, EURCHF]     100.0
# 5   CADCHF    10                  [GBPCHF, GBPAUD]     100.0
# 6   NZDCHF    50                  [GBPAUD, EURJPY]     100.0
# 7   GBPJPY    10          [EURCAD, GBPCHF, EURAUD]      80.0
# 8   GBPCAD    10                          [AUDUSD]      80.0
# 9   EURJPY    10          [GBPAUD, EURAUD, GBPCHF]      80.0
# 10  EURCAD    10                          [EURGBP]      80.0
# 11  EURAUD    10          [USDCHF, AUDCHF, NZDCHF]      80.0
# 12  EURNZD    10          [AUDCHF, NZDCHF, CADCHF]     100.0
# 13  CADJPY    20                          [EURJPY]      80.0
# 14  AUDJPY    15                  [EURUSD, EURAUD]      80.0
# 15  NZDCAD    10          [AUDCHF, NZDCHF, EURJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.03.01
#      names  week                           needed_features  accuracy
# 0   USDCHF    15                                  [NZDCAD]      80.0
# 1   GBPUSD    10                                  [GBPCHF]      80.0
# 2   EURUSD    15  [EURGBP, GBPCHF, EURCHF, AUDCAD, NZDCAD]      80.0
# 3   USDCAD    15                  [EURJPY, AUDJPY, AUDUSD]      80.0
# 4   AUDUSD    20                                  [USDJPY]     100.0
# 5   NZDUSD    15                                  [GBPCHF]      80.0
# 6   GBPCHF    10                          [GBPCAD, EURCAD]      80.0
# 7   EURCHF    10          [AUDNZD, AUDCAD, EURCHF, CADJPY]      80.0
# 8   CADCHF    10                          [GBPCHF, GBPAUD]      80.0
# 9   NZDCHF    50                                  [EURJPY]      80.0
# 10  EURGBP    10                          [AUDCAD, AUDUSD]      80.0
# 11  GBPJPY    15                  [GBPCHF, GBPAUD, EURCAD]     100.0
# 12  GBPCAD    15                          [AUDUSD, EURGBP]      80.0
# 13  EURJPY    10  [GBPAUD, GBPCHF, EURAUD, NZDCAD, GBPUSD]      80.0
# 14  EURCAD    10                                  [EURGBP]     100.0
# 15  EURAUD    10                  [USDCHF, AUDCHF, NZDCHF]      80.0
# 16  EURNZD    10                  [NZDCHF, AUDCHF, CADCHF]     100.0
# 17  CADJPY    20                  [GBPCHF, GBPJPY, EURJPY]      80.0
# 18  AUDJPY    10                          [EURUSD, GBPAUD]      80.0
# 19  AUDCAD    30                          [USDCHF, AUDCAD]      80.0
# 20  NZDCAD    10                  [NZDCHF, AUDCHF, CADCHF]     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.02.22
#      names  week                                    needed_features  accuracy
# 0   GBPUSD    10                                           [GBPCHF]      80.0
# 1   EURUSD    20                           [EURCHF, AUDCAD, GBPAUD]     100.0
# 2   USDJPY    20                                           [GBPJPY]      80.0
# 3   AUDUSD    20                                           [USDJPY]      80.0
# 4   NZDUSD    10                                   [AUDCHF, NZDCHF]      80.0
# 5   GBPCHF    50  [GBPCAD, EURAUD, EURCAD, GBPUSD, USDCHF, EURUS...      80.0
# 6   EURCHF    10                   [AUDCAD, NZDJPY, EURCHF, CADJPY]      80.0
# 7   CADCHF    10                                   [GBPAUD, GBPCHF]      80.0
# 8   AUDCHF    10                                           [AUDUSD]      80.0
# 9   NZDCHF    50                                   [AUDUSD, GBPAUD]     100.0
# 10  EURGBP    10                                           [AUDCAD]      80.0
# 11  GBPJPY    10           [GBPAUD, GBPCHF, EURCAD, EURAUD, GBPUSD]     100.0
# 12  GBPCAD    10                                   [EURGBP, AUDUSD]      80.0
# 13  EURJPY    15                   [GBPCHF, GBPAUD, NZDCAD, AUDCAD]     100.0
# 14  EURCAD    10                                           [EURGBP]      80.0
# 15  EURAUD    20                                           [EURCHF]      80.0
# 16  EURNZD    10                                   [AUDCHF, NZDCHF]     100.0
# 17  NZDJPY    20                           [GBPUSD, USDCAD, GBPJPY]     100.0
# 18  AUDCAD    10                                           [USDCHF]      80.0
# 19  NZDCAD    10   [NZDCHF, AUDCHF, CADCHF, NZDJPY, GBPCAD, GBPJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.02.15
#      names  week                                    needed_features  accuracy
# 0   GBPUSD    10                                   [GBPCHF, GBPAUD]     100.0
# 1   EURUSD    15                   [AUDCAD, GBPCHF, EURCHF, GBPAUD]     100.0
# 2   USDCAD    15                           [GBPUSD, USDCAD, EURJPY]      80.0
# 3   AUDUSD    30           [AUDCAD, EURGBP, CADJPY, GBPCHF, USDJPY]      80.0
# 4   CHFJPY    50                                           [CHFJPY]      80.0
# 5   NZDCHF    50                                           [GBPAUD]     100.0
# 6   EURGBP    20  [AUDCAD, USDJPY, USDCHF, CADJPY, NZDCAD, EURUS...     100.0
# 7   GBPJPY    10                           [GBPAUD, EURCAD, GBPUSD]     100.0
# 8   GBPCAD    10                                   [EURGBP, AUDUSD]     100.0
# 9   EURJPY    10                                   [GBPCHF, GBPAUD]     100.0
# 10  EURCAD    10                                           [EURGBP]      80.0
# 11  EURNZD    10                                   [NZDCHF, AUDCHF]     100.0
# 12  CADJPY    10                                   [GBPUSD, GBPAUD]     100.0
# 13  AUDJPY    50                                   [EURUSD, EURCAD]      80.0
# 14  NZDJPY    20                           [GBPUSD, GBPJPY, USDCAD]     100.0
# 15  AUDCAD    10                                   [USDCHF, GBPUSD]      80.0
# 16  NZDCAD    10   [GBPCAD, CADCHF, AUDCHF, NZDCHF, GBPJPY, NZDJPY]      80.0
# 17  AUDNZD    30                                   [GBPJPY, GBPAUD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.02.08
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                           [CADCHF]      80.0
# 1   GBPUSD    10                   [NZDCAD, GBPCHF, EURNZD, EURAUD]     100.0
# 2   EURUSD    15                                   [GBPAUD, AUDCAD]     100.0
# 3   USDCAD    15                                   [EURCAD, EURGBP]      80.0
# 4   AUDUSD    20   [AUDCAD, NZDCHF, AUDCHF, EURGBP, CADJPY, GBPCHF]     100.0
# 5   GBPCHF    15  [GBPCAD, EURCAD, USDCHF, EURUSD, CADJPY, GBPUS...      80.0
# 6   CADCHF    10                                           [EURCAD]      80.0
# 7   NZDCHF    50                                           [GBPAUD]      80.0
# 8   EURGBP    10                           [AUDCAD, CADJPY, USDJPY]      80.0
# 9   GBPJPY    15                   [GBPAUD, EURCAD, EURUSD, GBPUSD]     100.0
# 10  GBPCAD    10                                           [EURGBP]     100.0
# 11  GBPAUD    10   [EURNZD, EURAUD, AUDCHF, NZDCHF, GBPCAD, EURCAD]      80.0
# 12  EURJPY    10                                           [GBPAUD]     100.0
# 13  EURCAD    10                           [AUDCHF, NZDCHF, EURGBP]      80.0
# 14  EURAUD    10                                   [AUDCHF, NZDCHF]     100.0
# 15  EURNZD    10                                   [AUDCHF, NZDCHF]     100.0
# 16  CADJPY    10                           [EURUSD, GBPUSD, GBPAUD]     100.0
# 17  AUDJPY    10                                           [GBPJPY]     100.0
# 18  NZDJPY    10                                   [EURUSD, GBPUSD]      80.0
# 19  NZDCAD    10           [NZDCHF, GBPCAD, CADCHF, AUDCHF, USDCHF]      80.0
# 20  AUDNZD    15                                           [AUDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.02.01
#      names  week                                    needed_features  accuracy
# 0   USDCHF    10                                           [CADCHF]     100.0
# 1   GBPUSD    10                                   [GBPCHF, NZDCAD]     100.0
# 2   EURUSD    10                                   [GBPCHF, NZDCAD]     100.0
# 3   GBPCHF    10  [GBPCAD, CADCHF, AUDCHF, NZDCHF, USDCHF, EURCA...     100.0
# 4   CHFJPY    10                                   [NZDJPY, EURCHF]      80.0
# 5   CADCHF    10                                           [EURCAD]      80.0
# 6   EURGBP    20  [NZDCAD, AUDCAD, GBPCHF, CADJPY, USDCHF, USDJP...     100.0
# 7   GBPJPY    30                           [GBPAUD, EURCAD, CADJPY]      80.0
# 8   GBPCAD    10                                           [EURGBP]     100.0
# 9   EURJPY    10                           [EURCHF, GBPAUD, AUDCAD]      80.0
# 10  EURCAD    10                                           [EURGBP]      80.0
# 11  EURAUD    10                                           [NZDUSD]      80.0
# 12  EURNZD    15                           [NZDUSD, AUDCHF, GBPCAD]     100.0
# 13  CADJPY    15                                   [GBPUSD, EURUSD]     100.0
# 14  AUDCAD    10                                           [USDCHF]      80.0
# 15  NZDCAD    10  [GBPCAD, CADCHF, AUDCHF, NZDCHF, USDCHF, EURCA...     100.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.01.25
#      names  week                                    needed_features  accuracy
# 0   USDCHF    30                           [EURGBP, CADCHF, EURAUD]      80.0
# 1   GBPUSD    10                                   [NZDCAD, GBPCHF]     100.0
# 2   EURUSD    30                   [NZDCAD, GBPCHF, GBPAUD, AUDCAD]     100.0
# 3   USDCAD    10                                           [USDCAD]     100.0
# 4   AUDUSD    15                                           [GBPJPY]      80.0
# 5   GBPCHF    10           [USDCHF, CADCHF, EURUSD, EURCAD, GBPCAD]      80.0
# 6   EURCHF    20                           [CADCHF, USDCHF, AUDNZD]     100.0
# 7   CHFJPY    10                                           [EURCHF]     100.0
# 8   EURGBP    20  [AUDCAD, CADJPY, CADCHF, NZDCAD, GBPCHF, USDCH...     100.0
# 9   GBPJPY    30                   [EURUSD, EURCAD, CADJPY, NZDJPY]      80.0
# 10  GBPCAD    10                                           [EURGBP]     100.0
# 11  EURJPY    10                                   [AUDCAD, GBPAUD]      80.0
# 12  EURNZD    10                                           [NZDUSD]      80.0
# 13  CADJPY    10                                   [EURUSD, EURCAD]      80.0
# 14  AUDJPY    50                                           [EURCAD]      80.0
# 15  NZDCAD    10           [USDCHF, CADCHF, EURUSD, EURCAD, GBPCAD]      80.0
# 16  AUDNZD    15                                   [GBPAUD, AUDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.01.18
#      names  week                                    needed_features  accuracy
# 0   GBPUSD    10                                   [NZDCAD, GBPCHF]     100.0
# 1   EURUSD    15                                           [AUDCAD]     100.0
# 2   USDJPY    15                                           [GBPJPY]      80.0
# 3   USDCAD    20                                           [EURCAD]      80.0
# 4   AUDUSD    15                           [GBPJPY, CADJPY, GBPCHF]      80.0
# 5   GBPCHF    10   [USDCHF, EURUSD, EURCAD, GBPCAD, GBPUSD, CADCHF]     100.0
# 6   EURCHF    20                           [CADCHF, EURCAD, AUDNZD]     100.0
# 7   CHFJPY    10                                           [EURCHF]      80.0
# 8   CADCHF    20                           [USDCHF, EURUSD, CADCHF]      80.0
# 9   AUDCHF    15                                           [EURCHF]      80.0
# 10  EURGBP    20  [AUDCAD, CADJPY, USDCHF, EURUSD, NZDCAD, GBPCH...     100.0
# 11  GBPCAD    10                                   [EURGBP, CADCHF]     100.0
# 12  CADJPY    10                           [EURCAD, USDCHF, EURUSD]      80.0
# 13  NZDJPY    10                                           [CADCHF]      80.0
# 14  NZDCAD    10   [USDCHF, EURUSD, EURCAD, GBPCAD, GBPUSD, CADCHF]     100.0
# 15  AUDNZD    15                                   [GBPAUD, AUDUSD]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.01.11
#     names  week                                    needed_features  accuracy
# 0  USDCAD    10                                           [AUDUSD]     100.0
# 1  AUDUSD    15                           [EURGBP, GBPCHF, GBPJPY]      80.0
# 2  GBPCHF    10   [USDCHF, EURUSD, EURCAD, GBPCAD, GBPUSD, CADCHF]     100.0
# 3  EURCHF    30                           [AUDJPY, CADJPY, USDCAD]     100.0
# 4  EURGBP    10  [CADCHF, USDCHF, EURUSD, CADJPY, GBPCHF, NZDCA...      80.0
# 5  CADJPY    10                                           [EURCAD]      80.0
# 6  NZDCAD    10   [USDCHF, EURUSD, EURCAD, GBPCAD, GBPUSD, CADCHF]     100.0
# 7  AUDNZD    20                                           [AUDJPY]      80.0
# ------$$$$$$$$$$$$$$$$$----------------------------------------------------------- 2015.01.04

# %%
def predict_nextweek_trades_direction(processed_week):
    next_week_prediction_score = []
    next_week_prediction =[]

    next_week_trades = pd.read_csv('files/' + processed_week + '/next_week_trades.csv'  ) 




    for index, row in next_week_trades.iterrows():



        current_currency = row.names
        raw_data = pd.read_csv('files/' + processed_week +'/' + current_currency + '.csv'    ) 
        weeks = row.week
        wanted_features = ast.literal_eval(row.needed_features)
        n_estimators = 100
        min_samples_leaf = 1
        max_features = "auto"
        max_samples = None




        raw_data = raw_data[:weeks]

        X_train = pd.DataFrame()

        for q in wanted_features:

            X_train[q] = raw_data[q]


        #print(X_train)  

        y_train = raw_data['nextweek_'+ current_currency]

        #print(y_train)



        prediction_model=RandomForestRegressor(
                                                    n_estimators=n_estimators,
                                                   n_jobs =-1,
                                                   min_samples_leaf=min_samples_leaf,
                                                    max_features=max_features,
                                                   max_samples = max_samples
                                              )



        prediction_model.fit(X_train,y_train)


        current_week_values = pd.read_csv('files/' + processed_week + '/current_week_values.csv'   ) 

        X_pred = pd.DataFrame()

        for h in wanted_features:

            X_pred[h] = current_week_values[h]

        #print(X_pred)

        y_pred = prediction_model.predict(X_pred)


        if y_pred[0] > 0:

            value = 'B'

        else:
            value = 'S'

        next_week_prediction_score.append(y_pred[0])
        next_week_prediction.append(value)

        print(row.names, row.week, y_pred)



    #print(next_week_prediction)
    #print(processed_week)
    
    next_week_trades['next_week_prediction_score'] = next_week_prediction_score
    next_week_trades['next_week_prediction'] = next_week_prediction

    next_week_trades.to_csv('files/' + processed_week + '/next_week_trades.csv', index = False )

# %%
for g in available_weeks:
    predict_nextweek_trades_direction(g)
    print(g)
# Out:
# EURUSD 15 [0.53677273]
# USDJPY 15 [0.76221717]
# USDCAD 50 [0.72687524]
# AUDUSD 10 [-0.98533333]
# NZDUSD 10 [-1.]
# EURCHF 15 [0.9625]
# CADCHF 10 [0.72657937]
# AUDCHF 20 [0.73841053]
# NZDCHF 50 [0.58121284]
# GBPCAD 10 [0.8]
# GBPAUD 50 [0.46820562]
# EURCAD 15 [-0.77415179]
# EURNZD 20 [0.76033333]
# CADJPY 10 [-0.984]
# NZDJPY 10 [-1.]
# AUDCAD 10 [0.42395238]
# NZDCAD 10 [-0.6662381]
# 2021.11.28
# USDCHF 15 [0.98666667]
# EURUSD 10 [-1.]
# USDJPY 15 [1.]
# USDCAD 10 [-0.10835714]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 30 [0.54250266]
# EURCHF 10 [0.16]
# CHFJPY 10 [-0.33090476]
# CADCHF 10 [1.]
# AUDCHF 10 [0.98]
# NZDCHF 10 [0.954]
# GBPJPY 20 [1.]
# GBPCAD 15 [-0.72781602]
# EURJPY 10 [0.19961905]
# EURCAD 10 [-1.]
# EURAUD 15 [-1.]
# EURNZD 20 [0.54266667]
# AUDJPY 15 [0.7613824]
# NZDJPY 30 [0.5279709]
# AUDCAD 10 [0.84]
# NZDCAD 10 [-0.73176984]
# 2021.11.21
# USDCHF 10 [0.78322222]
# GBPUSD 15 [0.54]
# EURUSD 20 [-0.94821429]
# USDJPY 15 [-0.4]
# USDCAD 10 [1.]
# AUDUSD 10 [-0.46]
# NZDUSD 10 [0.1]
# GBPCHF 30 [-0.18181344]
# EURCHF 10 [-1.]
# CHFJPY 10 [1.]
# CADCHF 10 [-0.46]
# AUDCHF 10 [0.76]
# NZDCHF 10 [0.988]
# GBPCAD 15 [0.54724603]
# EURJPY 10 [-1.]
# EURCAD 10 [0.23133333]
# EURAUD 15 [1.]
# EURNZD 15 [0.83416667]
# AUDJPY 15 [-0.45079082]
# AUDCAD 15 [-0.41169553]
# NZDCAD 15 [0.34466667]
# AUDNZD 10 [0.52]
# 2021.11.14
# USDCHF 10 [-1.]
# GBPUSD 10 [0.1705]
# EURUSD 15 [-0.784]
# USDJPY 15 [0.9]
# USDCAD 10 [-0.47445238]
# AUDUSD 10 [-0.6106746]
# NZDUSD 10 [-0.986]
# GBPCHF 30 [-0.40091543]
# EURCHF 50 [0.71795238]
# CADCHF 10 [0.76]
# AUDCHF 10 [-1.]
# NZDCHF 10 [-0.98]
# EURGBP 10 [0.3381746]
# EURJPY 10 [0.44811905]
# EURCAD 15 [-0.54]
# EURAUD 10 [0.20407143]
# EURNZD 10 [1.]
# CADJPY 10 [0.982]
# NZDJPY 30 [-0.20966362]
# AUDCAD 15 [-0.37362482]
# NZDCAD 15 [-0.92]
# AUDNZD 10 [0.64]
# 2021.11.07
# USDCHF 15 [0.98]
# GBPUSD 20 [-0.93366667]
# EURUSD 15 [-0.98666667]
# USDJPY 20 [1.]
# AUDUSD 15 [1.]
# NZDUSD 10 [-1.]
# GBPCHF 30 [0.57426152]
# EURCHF 30 [0.26117998]
# CADCHF 10 [0.74220635]
# AUDCHF 15 [1.]
# NZDCHF 10 [0.34]
# EURGBP 10 [-0.96]
# GBPCAD 10 [-1.]
# GBPAUD 10 [-1.]
# EURJPY 15 [-0.77612005]
# EURCAD 15 [-0.8]
# EURAUD 15 [-1.]
# EURNZD 10 [0.54]
# CADJPY 10 [-0.22065079]
# AUDJPY 15 [1.]
# NZDJPY 30 [0.72065765]
# AUDCAD 10 [-0.26]
# NZDCAD 10 [-0.98]
# AUDNZD 10 [1.]
# 2021.10.31
# GBPUSD 15 [0.47922028]
# EURUSD 20 [0.23389785]
# USDJPY 20 [-0.66840981]
# AUDUSD 15 [0.324]
# GBPCHF 15 [0.64812554]
# EURCHF 20 [-0.66784039]
# CADCHF 10 [0.397]
# AUDCHF 15 [-0.27951948]
# NZDCHF 10 [-0.1]
# EURGBP 10 [-0.48011905]
# GBPCAD 10 [-0.48]
# GBPAUD 15 [0.12319664]
# EURCAD 15 [-0.74]
# EURAUD 15 [0.50675397]
# EURNZD 20 [0.30664935]
# CADJPY 15 [0.73063492]
# AUDJPY 50 [-0.27530719]
# NZDJPY 50 [0.057782]
# AUDCAD 10 [0.74]
# NZDCAD 50 [0.02601587]
# 2021.10.24
# EURUSD 10 [0.54907937]
# USDJPY 10 [-0.3447619]
# AUDUSD 15 [0.30666667]
# NZDUSD 15 [0.22734921]
# GBPCHF 30 [-0.36080245]
# EURCHF 10 [0.874]
# CHFJPY 30 [0.23273954]
# CADCHF 10 [-0.916]
# AUDCHF 10 [-0.2444127]
# NZDCHF 20 [1.]
# EURGBP 10 [0.31387302]
# GBPJPY 30 [-0.30007336]
# GBPCAD 15 [0.54]
# EURNZD 20 [-0.66899711]
# CADJPY 10 [-0.62777778]
# NZDJPY 50 [0.80830016]
# AUDCAD 10 [0.54]
# NZDCAD 15 [0.95392857]
# AUDNZD 10 [-1.]
# 2021.10.17
# USDCHF 50 [0.50457756]
# USDJPY 10 [-0.38285714]
# AUDUSD 15 [0.67]
# NZDUSD 15 [0.75013758]
# GBPCHF 10 [1.]
# EURCHF 10 [0.34634921]
# CHFJPY 10 [-0.995]
# CADCHF 10 [0.66]
# AUDCHF 10 [1.]
# NZDCHF 50 [0.3876132]
# EURGBP 10 [0.63705556]
# GBPCAD 15 [0.98]
# GBPAUD 10 [-0.84]
# EURAUD 15 [-0.38]
# EURNZD 10 [-0.56752381]
# CADJPY 15 [0.40721429]
# AUDJPY 30 [-0.03927778]
# AUDCAD 10 [1.]
# 2021.10.10
# USDCHF 20 [0.9]
# USDJPY 10 [1.]
# AUDUSD 15 [0.49538095]
# NZDUSD 15 [0.6981176]
# GBPCHF 10 [1.]
# EURCHF 10 [-0.96690476]
# CHFJPY 10 [-1.]
# CADCHF 10 [1.]
# AUDCHF 10 [1.]
# NZDCHF 15 [-1.]
# EURGBP 50 [-0.73542857]
# GBPCAD 10 [-0.44083333]
# EURAUD 15 [-0.975]
# EURNZD 10 [-0.5602381]
# AUDJPY 30 [0.04766667]
# AUDCAD 10 [1.]
# NZDCAD 10 [-0.97866667]
# 2021.10.03
# USDCHF 10 [0.54]
# AUDUSD 10 [0.48901587]
# GBPCHF 10 [1.]
# EURCHF 10 [0.78]
# CHFJPY 10 [0.02]
# CADCHF 15 [0.69277095]
# AUDCHF 10 [0.99]
# EURGBP 10 [-0.986]
# GBPCAD 10 [-0.34034127]
# GBPAUD 30 [0.58205685]
# EURNZD 10 [1.]
# CADJPY 20 [-0.82533333]
# AUDJPY 50 [-0.78662302]
# AUDCAD 15 [0.987]
# 2021.09.26
# USDCHF 10 [-0.98]
# USDJPY 20 [-0.38569841]
# USDCAD 20 [-0.43848962]
# AUDUSD 50 [-0.29797212]
# NZDUSD 10 [1.]
# GBPCHF 30 [0.98666667]
# EURCHF 10 [-0.60823016]
# CHFJPY 10 [-0.48]
# CADCHF 10 [-0.17807143]
# AUDCHF 10 [-0.64625397]
# EURGBP 50 [0.15021679]
# GBPCAD 10 [0.66284921]
# GBPAUD 30 [-0.24442764]
# EURAUD 30 [-0.25890363]
# EURNZD 10 [-0.96]
# CADJPY 10 [1.]
# AUDJPY 20 [0.29801659]
# NZDJPY 30 [0.81952419]
# AUDCAD 10 [0.99]
# NZDCAD 10 [0.97]
# AUDNZD 20 [-0.98]
# 2021.09.19
# USDCHF 10 [-0.296]
# GBPUSD 10 [0.9552381]
# EURUSD 10 [0.93833333]
# USDJPY 10 [-0.6]
# USDCAD 10 [-0.99]
# AUDUSD 50 [-0.26239959]
# NZDUSD 10 [-0.54007143]
# EURCHF 20 [0.50776363]
# CHFJPY 10 [0.56414286]
# CADCHF 15 [0.58810012]
# EURGBP 10 [-0.966]
# GBPJPY 10 [-0.38069841]
# GBPCAD 10 [-0.53492857]
# GBPAUD 30 [-0.17728428]
# EURCAD 10 [0.52030159]
# EURAUD 30 [-0.56788312]
# EURNZD 10 [1.]
# AUDJPY 20 [0.33801787]
# NZDJPY 20 [-0.32288495]
# 2021.09.12
# USDCHF 10 [0.04]
# GBPUSD 10 [0.03333333]
# EURUSD 10 [-0.06933333]
# USDJPY 10 [0.84]
# USDCAD 15 [-0.19922145]
# AUDUSD 50 [-0.20807575]
# NZDUSD 10 [1.]
# GBPCHF 30 [-0.72626024]
# EURGBP 10 [0.70216667]
# GBPJPY 10 [-0.34940476]
# GBPCAD 10 [-0.44014286]
# GBPAUD 50 [-0.20157024]
# EURJPY 10 [0.36596825]
# EURCAD 10 [-0.55140476]
# EURAUD 30 [0.60268847]
# EURNZD 10 [0.5]
# AUDJPY 30 [-0.26330331]
# NZDJPY 10 [1.]
# 2021.09.05
# USDCHF 15 [1.]
# GBPUSD 10 [-0.988]
# EURUSD 10 [-0.97]
# USDJPY 20 [0.046]
# USDCAD 10 [0.944]
# GBPCHF 50 [-0.19769198]
# CHFJPY 10 [1.]
# EURGBP 10 [1.]
# GBPJPY 20 [-0.46081496]
# GBPCAD 20 [0.83809524]
# GBPAUD 50 [0.45858315]
# EURNZD 15 [0.69510895]
# CADJPY 10 [1.]
# AUDCAD 10 [-0.35586508]
# 2021.08.29
# USDCHF 15 [1.]
# GBPUSD 10 [-0.80388889]
# EURUSD 10 [-0.82284921]
# USDJPY 15 [-0.5909127]
# USDCAD 50 [-0.03306349]
# GBPCHF 50 [-0.47213919]
# EURCHF 15 [-0.7822583]
# CHFJPY 10 [-0.92]
# EURGBP 10 [0.92]
# GBPJPY 10 [-0.954]
# GBPCAD 10 [1.]
# EURJPY 15 [-1.]
# EURAUD 10 [1.]
# EURNZD 10 [1.]
# AUDJPY 20 [-0.9975]
# AUDCAD 10 [-0.98]
# NZDCAD 10 [-0.98333333]
# 2021.08.22
# USDCHF 10 [-0.94]
# GBPUSD 15 [-0.88]
# EURUSD 50 [0.73379412]
# USDJPY 10 [1.]
# USDCAD 30 [0.43650794]
# AUDUSD 30 [-0.56006888]
# GBPCHF 20 [1.]
# EURCHF 20 [0.41565257]
# CHFJPY 10 [1.]
# EURGBP 10 [0.36]
# GBPJPY 20 [-0.22321717]
# GBPCAD 50 [0.78666667]
# GBPAUD 50 [0.02918995]
# EURAUD 30 [-0.17340997]
# EURNZD 15 [-0.69469048]
# CADJPY 10 [-0.38438095]
# AUDJPY 15 [0.26639683]
# NZDJPY 50 [0.44684228]
# AUDCAD 10 [0.41011111]
# NZDCAD 10 [0.42294444]
# 2021.08.15
# USDCHF 10 [0.7]
# GBPUSD 10 [1.]
# EURUSD 10 [1.]
# USDJPY 10 [0.16488095]
# USDCAD 30 [-0.42971147]
# AUDUSD 30 [-0.62498133]
# CHFJPY 10 [1.]
# EURGBP 10 [1.]
# GBPJPY 15 [0.73748629]
# GBPCAD 30 [-0.6]
# GBPAUD 50 [0.80235032]
# EURJPY 10 [0.2056746]
# EURCAD 15 [-0.56691414]
# EURNZD 10 [0.57704762]
# AUDJPY 10 [0.08637302]
# NZDJPY 30 [-0.45555556]
# 2021.08.08
# USDCHF 10 [0.36]
# GBPUSD 10 [-0.9]
# EURUSD 10 [-0.86]
# USDJPY 15 [0.42]
# AUDUSD 30 [-0.2563966]
# GBPCHF 15 [-0.73750722]
# EURCHF 15 [-0.73594739]
# CHFJPY 10 [0.44]
# CADCHF 50 [0.57062335]
# AUDCHF 20 [-1.]
# NZDCHF 30 [-0.25726749]
# GBPJPY 15 [-0.45955772]
# GBPCAD 30 [-0.63166667]
# GBPAUD 50 [0.16708636]
# EURJPY 10 [-0.99]
# EURCAD 15 [-1.]
# EURNZD 10 [1.]
# CADJPY 10 [0.01657143]
# AUDJPY 10 [-1.]
# NZDJPY 30 [-0.21538652]
# 2021.08.01
# USDCHF 10 [0.76]
# GBPUSD 10 [-0.02]
# EURUSD 10 [-0.02]
# USDJPY 10 [0.4]
# AUDUSD 10 [-1.]
# GBPCHF 10 [0.15352381]
# EURCHF 10 [0.18438889]
# CHFJPY 20 [-0.24]
# AUDCHF 10 [-0.86]
# GBPCAD 15 [-0.46]
# GBPAUD 50 [-0.35650361]
# EURCAD 10 [0.28]
# EURAUD 10 [1.]
# EURNZD 10 [-0.17307143]
# AUDJPY 10 [0.30850794]
# NZDJPY 15 [0.74352337]
# AUDCAD 10 [-1.]
# NZDCAD 10 [0.32665079]
# 2021.07.25
# USDCHF 10 [-0.96]
# GBPUSD 20 [0.70946032]
# EURUSD 10 [1.]
# USDJPY 10 [-1.]
# EURCHF 10 [-1.]
# CHFJPY 10 [1.]
# AUDCHF 10 [-0.62657143]
# GBPCAD 15 [0.56651587]
# GBPAUD 20 [-0.10488739]
# EURJPY 30 [0.47771876]
# EURCAD 10 [0.38433333]
# EURAUD 20 [-0.04881876]
# EURNZD 30 [0.79]
# CADJPY 30 [-0.0687381]
# AUDJPY 10 [-1.]
# NZDJPY 50 [-0.65628571]
# AUDCAD 10 [-0.922]
# 2021.07.18
# USDCHF 10 [-0.56]
# GBPUSD 20 [-0.42978571]
# EURUSD 15 [-0.91166667]
# USDJPY 10 [-0.32]
# GBPCHF 15 [-0.65025325]
# EURCHF 50 [-1.]
# CHFJPY 15 [-0.54555556]
# AUDCHF 10 [-0.78]
# GBPAUD 50 [0.71612338]
# EURJPY 30 [-0.05133333]
# EURCAD 10 [-0.36]
# EURAUD 20 [0.75375663]
# EURNZD 20 [-0.316]
# CADJPY 50 [-0.68543362]
# AUDJPY 10 [-0.7]
# NZDJPY 30 [-0.98428571]
# AUDCAD 10 [0.65210317]
# AUDNZD 10 [0.5414127]
# 2021.07.11
# USDCHF 10 [0.77895238]
# EURUSD 15 [-0.71233333]
# USDJPY 10 [1.]
# NZDUSD 20 [-0.7261574]
# GBPCHF 15 [0.51916955]
# EURCHF 30 [0.63898773]
# AUDCHF 10 [-0.996]
# GBPAUD 20 [0.71135265]
# EURCAD 10 [0.57000794]
# EURAUD 20 [0.77382884]
# CADJPY 10 [-0.52330952]
# AUDJPY 10 [-1.]
# NZDJPY 30 [-0.4]
# AUDCAD 50 [0.62674089]
# NZDCAD 10 [-0.39302381]
# 2021.07.04
# USDCHF 10 [0.46346825]
# EURUSD 15 [0.915]
# USDJPY 10 [-0.11770635]
# AUDUSD 10 [0.13911111]
# NZDUSD 10 [0.25128571]
# GBPCHF 15 [0.13966667]
# EURCHF 30 [-0.36115729]
# AUDCHF 10 [0.60703175]
# GBPCAD 10 [0.88]
# EURCAD 50 [0.71730736]
# EURNZD 10 [-0.32687302]
# CADJPY 50 [-0.28335498]
# AUDJPY 15 [0.48366267]
# 2021.06.27
# USDCHF 50 [0.32225806]
# USDJPY 15 [-0.72469841]
# GBPCHF 15 [-0.64644444]
# EURCHF 30 [-0.43295442]
# CADCHF 10 [-0.47745238]
# AUDCHF 10 [-0.80497619]
# GBPCAD 10 [-0.53640476]
# EURNZD 10 [-0.46]
# CADJPY 50 [0.48295371]
# AUDJPY 10 [0.94]
# AUDNZD 30 [1.]
# 2021.06.20
# USDCHF 50 [-0.60390387]
# GBPUSD 10 [-0.926]
# USDJPY 30 [-0.21264984]
# AUDUSD 15 [-0.74878211]
# GBPCHF 10 [-0.962]
# EURCHF 10 [-0.986]
# CHFJPY 10 [-0.36949206]
# CADCHF 15 [0.73840537]
# AUDCHF 10 [0.63037302]
# GBPJPY 10 [-0.878]
# GBPCAD 20 [0.58521429]
# GBPAUD 15 [0.77368859]
# EURNZD 10 [-0.99142857]
# AUDJPY 10 [0.918]
# NZDJPY 10 [-0.96]
# AUDCAD 10 [-0.50446032]
# 2021.06.13
# USDCHF 20 [-0.42846032]
# GBPUSD 15 [-0.67352381]
# USDJPY 10 [-1.]
# USDCAD 15 [0.63973016]
# AUDUSD 15 [-0.78322078]
# GBPCHF 10 [-0.74]
# EURCHF 10 [-0.36]
# CADCHF 20 [0.98]
# AUDCHF 10 [-1.]
# EURGBP 10 [-1.]
# GBPJPY 15 [1.]
# GBPCAD 10 [0.92]
# EURNZD 10 [-0.4]
# CADJPY 15 [0.40088095]
# NZDJPY 10 [0.6]
# AUDCAD 10 [0.31261905]
# NZDCAD 15 [0.62300794]
# 2021.06.06
# GBPUSD 20 [1.]
# EURUSD 50 [0.73555189]
# USDJPY 50 [0.48812222]
# USDCAD 20 [0.53962698]
# GBPCHF 10 [1.]
# EURCHF 15 [0.982]
# CADCHF 20 [0.39492857]
# NZDCHF 10 [1.]
# EURGBP 30 [-0.67250966]
# GBPJPY 10 [0.34919048]
# GBPCAD 10 [1.]
# GBPAUD 10 [-0.948]
# EURJPY 30 [1.]
# EURAUD 10 [-0.946]
# CADJPY 15 [1.]
# NZDJPY 10 [0.42]
# 2021.05.30
# GBPUSD 10 [-0.19039683]
# USDJPY 50 [-0.43281258]
# USDCAD 10 [-1.]
# GBPCHF 10 [-0.94]
# EURCHF 30 [0.17039683]
# CHFJPY 10 [1.]
# AUDCHF 10 [-1.]
# EURGBP 10 [0.14665079]
# GBPJPY 50 [0.20274662]
# GBPCAD 10 [-0.30642857]
# EURJPY 30 [0.38102674]
# EURCAD 20 [0.28031065]
# EURAUD 10 [1.]
# CADJPY 15 [0.05602731]
# NZDJPY 10 [-0.23104762]
# AUDCAD 10 [-1.]
# NZDCAD 10 [-0.96]
# 2021.05.23
# USDJPY 50 [-0.46446101]
# USDCAD 10 [-1.]
# EURCHF 30 [1.]
# AUDCHF 10 [-0.26]
# EURGBP 15 [-0.78013492]
# GBPCAD 20 [1.]
# EURJPY 30 [0.27230236]
# CADJPY 30 [1.]
# NZDJPY 10 [1.]
# NZDCAD 10 [0.38434127]
# 2021.05.16
# USDCHF 50 [0.33876989]
# USDJPY 50 [-0.47307092]
# USDCAD 10 [0.23666667]
# GBPCHF 10 [-0.48]
# EURCHF 30 [0.13092229]
# AUDCHF 10 [-0.52]
# EURGBP 20 [-0.98]
# GBPCAD 15 [0.24388095]
# EURJPY 30 [0.19692298]
# EURNZD 10 [-0.984]
# NZDJPY 10 [-0.1765]
# 2021.05.09
# GBPUSD 10 [0.46239683]
# USDCAD 20 [-0.4665734]
# AUDUSD 20 [0.53951991]
# GBPCHF 10 [-1.]
# EURCHF 30 [1.]
# AUDCHF 10 [-1.]
# EURGBP 15 [0.33775036]
# GBPAUD 10 [-1.]
# EURJPY 20 [0.24322386]
# EURNZD 10 [0.61496032]
# AUDCAD 10 [0.29103968]
# NZDCAD 10 [0.41224603]
# 2021.05.02
# USDCAD 10 [0.36733333]
# GBPCHF 30 [0.72284921]
# EURCHF 10 [1.]
# AUDCHF 10 [0.94]
# EURGBP 15 [-0.94305556]
# GBPAUD 10 [0.40653968]
# EURJPY 20 [0.25538609]
# EURNZD 10 [1.]
# NZDJPY 20 [-0.94666667]
# AUDCAD 10 [-1.]
# NZDCAD 10 [0.44569841]
# 2021.04.25
# USDJPY 10 [-0.356]
# USDCAD 10 [-1.]
# EURCHF 20 [1.]
# CADCHF 10 [-0.30937302]
# AUDCHF 10 [-0.84]
# EURGBP 10 [0.78]
# GBPJPY 10 [-0.2175]
# EURCHF 10 [-0.18933333]
# CHFJPY 30 [0.6819557]
# CADCHF 20 [-0.44180381]
# AUDCHF 15 [-0.38372222]
# EURGBP 10 [0.35077778]
# GBPJPY 15 [-0.50503158]
# GBPCAD 10 [1.]
# GBPAUD 10 [-0.87266667]
# EURCAD 10 [0.952]
# EURAUD 10 [-0.35718254]
# CADJPY 20 [-0.29471429]
# NZDJPY 15 [-0.5259062]
# NZDCAD 10 [0.59]
# 2020.09.20
# USDCHF 50 [0.39373018]
# GBPUSD 10 [0.32]
# EURUSD 50 [0.24044482]
# USDJPY 50 [0.48621354]
# USDCAD 10 [0.40335714]
# GBPCHF 20 [-0.67446465]
# EURCHF 10 [1.]
# CHFJPY 50 [0.84588604]
# CADCHF 10 [-0.966]
# AUDCHF 15 [1.]
# GBPJPY 10 [0.988]
# GBPAUD 15 [-0.69966667]
# EURCAD 10 [0.984]
# EURAUD 10 [1.]
# CADJPY 20 [0.]
# NZDJPY 30 [0.74240115]
# NZDCAD 10 [-1.]
# 2020.09.13
# GBPUSD 10 [0.984]
# EURUSD 30 [-0.07946548]
# USDJPY 20 [0.47626593]
# GBPCHF 10 [-0.916]
# CHFJPY 50 [0.88]
# CADCHF 20 [0.3476211]
# AUDCHF 20 [0.91633333]
# EURGBP 10 [0.976]
# GBPJPY 10 [-0.32253175]
# GBPAUD 15 [0.06]
# EURJPY 15 [0.79602903]
# EURCAD 20 [-0.13136304]
# EURAUD 10 [-0.13580952]
# NZDJPY 30 [0.50197619]
# NZDCAD 50 [-0.17348685]
# AUDNZD 15 [0.64097619]
# 2020.09.06
# GBPUSD 10 [0.57]
# USDJPY 50 [-0.18125572]
# USDCAD 50 [0.24525325]
# GBPCHF 50 [-0.81204791]
# CHFJPY 50 [0.55033333]
# AUDCHF 10 [-0.18533333]
# EURGBP 50 [-0.71546304]
# GBPJPY 10 [-0.23285714]
# EURJPY 10 [0.09366667]
# EURCAD 20 [0.99]
# EURAUD 15 [-1.]
# NZDCAD 50 [-0.25134921]
# AUDNZD 15 [-0.53425758]
# 2020.08.30
# USDCAD 50 [-0.109]
# AUDCHF 10 [1.]
# NZDCHF 50 [-0.71035237]
# GBPAUD 20 [-0.06171501]
# EURAUD 10 [0.38584127]
# EURNZD 20 [0.48080678]
# CADJPY 50 [0.53270354]
# AUDJPY 50 [0.02241526]
# NZDJPY 30 [-0.4163153]
# NZDCAD 20 [0.6847225]
# AUDNZD 15 [0.31562127]
# 2020.08.23
# GBPUSD 10 [-0.99]
# EURUSD 10 [-0.34909524]
# USDCAD 50 [0.06333333]
# AUDUSD 10 [-0.31728571]
# GBPCHF 10 [-1.]
# EURCHF 30 [-0.49150422]
# CHFJPY 15 [-0.17357937]
# NZDCHF 50 [0.25257288]
# EURGBP 10 [1.]
# GBPJPY 10 [0.61471429]
# GBPAUD 20 [-1.]
# EURJPY 10 [-0.26]
# EURAUD 10 [-0.922]
# EURNZD 20 [-0.58420635]
# CADJPY 50 [-0.12015645]
# AUDJPY 15 [-0.38152092]
# NZDJPY 30 [-0.07642121]
# AUDCAD 10 [-0.15828571]
# NZDCAD 50 [0.47095238]
# 2020.08.16
# GBPUSD 10 [0.38625397]
# EURUSD 10 [0.75543651]
# USDCAD 50 [-0.66666667]
# AUDUSD 10 [0.7614127]
# NZDUSD 15 [0.62563176]
# GBPCHF 10 [-1.]
# EURCHF 20 [1.]
# CHFJPY 10 [1.]
# AUDCHF 10 [-1.]
# EURGBP 10 [1.]
# GBPJPY 15 [1.]
# GBPAUD 20 [0.41510534]
# EURJPY 10 [0.77836508]
# CADJPY 10 [0.75030952]
# AUDJPY 10 [1.]
# AUDCAD 15 [-0.21260317]
# NZDCAD 50 [-0.25569048]
# 2020.08.09
# GBPUSD 10 [0.49584921]
# EURUSD 10 [0.74342063]
# USDCAD 50 [-0.40666667]
# AUDUSD 10 [0.77905556]
# NZDUSD 15 [0.78519947]
# GBPCHF 10 [-0.99]
# CHFJPY 10 [1.]
# NZDCHF 10 [0.57919048]
# GBPAUD 15 [0.21042507]
# EURJPY 10 [0.74434127]
# EURNZD 10 [-0.59745238]
# CADJPY 10 [-0.52]
# AUDJPY 15 [0.14]
# NZDJPY 50 [0.62]
# AUDCAD 10 [0.78707143]
# NZDCAD 10 [1.]
# AUDNZD 10 [0.02]
# 2020.08.02
# GBPUSD 10 [0.70896825]
# EURUSD 10 [0.78042063]
# USDCAD 30 [0.96]
# AUDUSD 10 [0.77433333]
# NZDUSD 10 [1.]
# GBPCHF 10 [0.30907937]
# CHFJPY 10 [1.]
# EURGBP 15 [-0.4305101]
# GBPJPY 15 [-0.84]
# GBPCAD 15 [0.69614791]
# GBPAUD 15 [0.47509957]
# EURJPY 10 [0.77094444]
# CADJPY 10 [1.]
# AUDJPY 10 [1.]
# NZDJPY 50 [0.75966667]
# AUDCAD 10 [0.78636508]
# NZDCAD 10 [0.26]
# AUDNZD 10 [1.]
# 2020.07.26
# GBPUSD 10 [-0.25553175]
# USDCAD 50 [-0.995]
# NZDUSD 15 [0.72833333]
# GBPCHF 10 [-0.16149206]
# CHFJPY 20 [0.15742857]
# CADCHF 30 [0.46297118]
# AUDCHF 10 [-0.20865079]
# EURGBP 15 [-0.44648896]
# GBPJPY 30 [-0.7]
# GBPCAD 10 [-0.944]
# GBPAUD 15 [-0.54454401]
# EURAUD 10 [-0.70787302]
# CADJPY 10 [0.69903968]
# NZDCAD 10 [-0.42]
# AUDNZD 10 [0.44314286]
# 2020.07.19
# GBPUSD 10 [0.66303968]
# USDJPY 30 [0.25591884]
# USDCAD 10 [-1.]
# GBPCHF 10 [0.64914286]
# CADCHF 30 [0.62206127]
# AUDCHF 10 [0.84]
# EURGBP 20 [0.63775663]
# GBPJPY 15 [0.56181174]
# GBPCAD 10 [-0.33376984]
# GBPAUD 15 [-0.24019048]
# EURAUD 10 [-1.]
# CADJPY 10 [1.]
# NZDCAD 50 [0.47012987]
# AUDNZD 10 [-0.69921429]
# 2020.07.12
# USDCHF 30 [0.98166667]
# GBPUSD 10 [-0.84276984]
# EURUSD 20 [-1.]
# USDJPY 30 [-0.49314863]
# USDCAD 10 [-0.78]
# GBPCHF 10 [-0.12036508]
# CHFJPY 10 [-0.98]
# CADCHF 15 [0.96]
# AUDCHF 10 [-0.64]
# EURGBP 10 [-0.36748413]
# GBPCAD 50 [0.10880303]
# GBPAUD 10 [0.98]
# EURAUD 10 [0.48]
# CADJPY 10 [0.04]
# NZDCAD 50 [-0.74383333]
# AUDNZD 15 [0.964]
# 2020.07.05
# USDCHF 20 [0.36577183]
# GBPUSD 10 [-0.26]
# EURUSD 15 [-0.74]
# USDJPY 30 [-0.1594804]
# USDCAD 10 [1.]
# NZDUSD 10 [-0.876]
# GBPCHF 15 [0.1202381]
# EURCHF 10 [-1.]
# CADCHF 15 [-0.60879365]
# AUDCHF 15 [0.072]
# GBPJPY 15 [-0.72]
# GBPCAD 50 [-0.41333333]
# GBPAUD 20 [0.4728941]
# EURJPY 10 [-0.9]
# EURCAD 10 [-0.34288095]
# EURAUD 15 [-0.12766667]
# CADJPY 10 [-0.38]
# NZDJPY 15 [-1.]
# NZDCAD 15 [1.]
# AUDNZD 15 [-0.30261255]
# 2020.06.28
# GBPUSD 20 [0.06647619]
# EURUSD 10 [-0.4]
# USDJPY 30 [0.54908398]
# NZDUSD 10 [0.68325397]
# GBPCHF 10 [1.]
# CHFJPY 10 [-0.66]
# CADCHF 30 [0.47404486]
# AUDCHF 10 [0.62]
# GBPJPY 10 [-0.26]
# GBPCAD 50 [0.29871429]
# EURJPY 10 [-0.72]
# EURCAD 30 [-0.76065534]
# EURAUD 10 [-0.7]
# CADJPY 10 [0.98]
# NZDCAD 30 [0.15812948]
# AUDNZD 15 [-0.32352742]
# 2020.06.21
# GBPUSD 10 [-0.38]
# EURUSD 10 [-0.46]
# NZDUSD 10 [-0.14280952]
# GBPCHF 10 [-1.]
# CHFJPY 10 [0.65048413]
# CADCHF 15 [-0.003]
# GBPJPY 10 [-0.48]
# EURJPY 10 [0.63442063]
# EURCAD 10 [-0.58192857]
# CADJPY 10 [-0.8]
# NZDCAD 15 [-0.37562554]
# 2020.06.14
# USDCHF 10 [0.988]
# GBPUSD 10 [-0.98]
# EURUSD 10 [-0.918]
# AUDUSD 15 [0.7644707]
# NZDUSD 10 [0.986]
# GBPCHF 10 [1.]
# CADCHF 30 [0.56635714]
# GBPJPY 10 [-1.]
# GBPCAD 15 [-0.58274603]
# EURNZD 10 [-0.905]
# NZDJPY 10 [1.]
# AUDCAD 15 [0.76693534]
# NZDCAD 20 [-0.32345022]
# 2020.06.07
# USDCHF 10 [-0.32922222]
# GBPUSD 10 [1.]
# EURUSD 10 [0.6695]
# USDCAD 50 [-0.43588783]
# AUDUSD 20 [0.72724942]
# NZDUSD 10 [-0.5460873]
# EURCHF 15 [0.2625]
# CADCHF 15 [0.74647619]
# AUDCHF 50 [0.57500468]
# GBPJPY 10 [0.6666746]
# EURCAD 30 [-0.77483533]
# EURAUD 50 [-0.41390097]
# EURNZD 10 [1.]
# CADJPY 50 [0.43997061]
# AUDJPY 50 [0.10025466]
# NZDJPY 10 [-0.9]
# AUDCAD 20 [0.69657431]
# NZDCAD 20 [0.76832806]
# AUDNZD 20 [0.96]
# 2020.05.31
# USDCHF 30 [-0.57395238]
# GBPUSD 10 [1.]
# EURUSD 15 [0.36545238]
# AUDUSD 15 [-0.48423332]
# NZDUSD 15 [0.04]
# EURCHF 10 [-0.59266667]
# CHFJPY 10 [-0.61411905]
# AUDCHF 10 [-0.2297619]
# GBPJPY 20 [-0.05]
# EURJPY 10 [-0.59906349]
# EURAUD 10 [0.2254127]
# EURNZD 30 [0.92]
# NZDJPY 15 [0.36542857]
# AUDCAD 15 [-0.49958586]
# NZDCAD 15 [-0.41020996]
# AUDNZD 10 [0.96]
# 2020.05.24
# USDCHF 10 [0.75404762]
# GBPUSD 10 [0.60954762]
# EURUSD 10 [-0.64130952]
# USDCAD 10 [1.]
# AUDUSD 15 [-0.63710101]
# NZDUSD 10 [-1.]
# EURCHF 10 [-0.98]
# CHFJPY 10 [-0.98]
# CADCHF 10 [-0.98166667]
# NZDCHF 10 [-1.]
# GBPJPY 15 [-0.7669697]
# GBPCAD 15 [0.68731746]
# GBPAUD 15 [0.68586508]
# EURJPY 10 [-1.]
# EURCAD 20 [-0.58030952]
# EURAUD 15 [0.70274603]
# EURNZD 50 [0.76781591]
# AUDJPY 20 [-0.32911111]
# NZDJPY 10 [-1.]
# AUDCAD 15 [-0.67234127]
# NZDCAD 15 [-0.68778427]
# AUDNZD 10 [0.22]
# 2020.05.17
# USDCHF 30 [-0.03240476]
# GBPUSD 10 [0.62015079]
# AUDUSD 20 [-0.22916228]
# NZDUSD 10 [0.29098413]
# GBPCHF 10 [-0.4377619]
# EURCHF 10 [-0.32]
# CHFJPY 10 [0.39842063]
# CADCHF 10 [-0.92]
# AUDCHF 50 [-0.3601105]
# NZDCHF 10 [0.46545238]
# EURGBP 10 [0.43850794]
# GBPJPY 10 [-0.38]
# GBPCAD 15 [-0.57756183]
# GBPAUD 15 [0.37495238]
# EURJPY 10 [0.46446032]
# EURCAD 10 [-0.85514286]
# EURAUD 15 [-0.72033261]
# EURNZD 10 [-0.53188095]
# CADJPY 10 [-0.7]
# AUDJPY 20 [0.32362698]
# NZDJPY 10 [1.]
# AUDCAD 15 [0.7982114]
# NZDCAD 15 [0.54684726]
# AUDNZD 10 [-0.5584127]
# 2020.05.10
# USDCHF 10 [-0.82]
# GBPUSD 50 [0.68]
# EURUSD 10 [0.92]
# NZDUSD 15 [-0.48988095]
# EURCHF 10 [0.92]
# CHFJPY 10 [0.4639127]
# CADCHF 10 [-1.]
# NZDCHF 10 [-0.984]
# GBPJPY 10 [-0.12]
# GBPCAD 20 [0.98666667]
# GBPAUD 10 [1.]
# EURJPY 10 [0.46572222]
# EURCAD 10 [0.3737619]
# EURNZD 10 [0.98]
# AUDJPY 10 [-1.]
# NZDJPY 15 [0.42]
# AUDNZD 10 [1.]
# 2020.05.03
# USDCHF 50 [1.]
# EURUSD 20 [-0.88109524]
# USDCAD 10 [0.76]
# AUDUSD 10 [-0.57361905]
# NZDUSD 15 [-1.]
# EURCHF 10 [-0.32823016]
# CHFJPY 10 [-0.42545238]
# CADCHF 20 [0.27392849]
# AUDCHF 20 [-0.80933189]
# NZDCHF 10 [-0.88]
# EURGBP 50 [0.63012955]
# GBPJPY 10 [-1.]
# GBPCAD 10 [1.]
# GBPAUD 10 [0.46]
# EURJPY 30 [-0.30151821]
# EURCAD 10 [-0.28711111]
# EURNZD 15 [0.91166667]
# AUDJPY 10 [-0.8]
# NZDJPY 10 [-0.74]
# AUDCAD 10 [-0.62673016]
# NZDCAD 10 [-0.57276984]
# AUDNZD 10 [-0.7057381]
# 2020.04.26
# USDCHF 50 [-0.46835714]
# GBPUSD 50 [0.39920631]
# EURUSD 15 [0.69243434]
# USDCAD 10 [-0.57747619]
# NZDUSD 15 [-0.1]
# EURCHF 10 [0.35061111]
# CHFJPY 15 [0.66137229]
# CADCHF 10 [-0.54990476]
# NZDCHF 10 [0.18]
# GBPJPY 10 [0.5465]
# GBPCAD 15 [0.96133333]
# GBPAUD 10 [0.19366667]
# EURJPY 50 [0.50218182]
# EURCAD 10 [-0.78]
# EURNZD 15 [0.76]
# AUDJPY 10 [1.]
# NZDJPY 10 [1.]
# NZDCAD 20 [0.20833333]
# AUDNZD 10 [-0.40797619]
# 2020.04.19
# USDCHF 10 [-0.98]
# EURUSD 10 [1.]
# USDCAD 10 [-1.]
# NZDUSD 10 [0.44]
# CHFJPY 10 [0.986]
# CADCHF 20 [0.70401443]
# NZDCHF 10 [0.96]
# EURGBP 50 [-1.]
# GBPJPY 50 [0.60058076]
# GBPCAD 10 [-0.31669841]
# EURJPY 10 [0.984]
# EURCAD 10 [-0.26]
# EURNZD 10 [-0.62]
# CADJPY 10 [0.29307143]
# AUDJPY 10 [1.]
# NZDJPY 10 [1.]
# AUDNZD 10 [0.72]
# 2020.04.12
# USDCHF 10 [0.63145238]
# GBPUSD 50 [-0.077]
# EURUSD 10 [-0.65384921]
# USDJPY 20 [1.]
# USDCAD 10 [1.]
# AUDUSD 10 [-1.]
# NZDUSD 50 [0.29436075]
# EURCHF 10 [-0.962]
# CHFJPY 10 [-0.6915873]
# CADCHF 20 [0.31628571]
# AUDCHF 10 [-1.]
# NZDCHF 10 [-1.]
# GBPJPY 10 [-1.]
# GBPCAD 20 [0.9565]
# EURJPY 15 [-0.68120491]
# EURAUD 10 [1.]
# EURNZD 10 [0.986]
# CADJPY 10 [0.62323016]
# AUDJPY 10 [-0.66692063]
# NZDJPY 10 [-0.62968254]
# AUDCAD 10 [-0.97]
# NZDCAD 15 [-1.]
# AUDNZD 10 [1.]
# 2020.04.05
# USDCHF 10 [-1.]
# GBPUSD 10 [1.]
# EURUSD 10 [0.984]
# USDJPY 10 [-0.38155556]
# USDCAD 10 [-0.58215079]
# AUDUSD 10 [0.92]
# NZDUSD 10 [0.92]
# GBPCHF 20 [-0.43035545]
# EURCHF 10 [0.1478254]
# CHFJPY 10 [1.]
# CADCHF 15 [-1.]
# NZDCHF 50 [-0.93133333]
# EURGBP 50 [-0.96]
# GBPJPY 50 [0.34686472]
# GBPAUD 50 [0.23736691]
# EURJPY 15 [1.]
# EURCAD 10 [0.30343651]
# EURAUD 10 [-0.58504762]
# EURNZD 10 [-0.58613492]
# CADJPY 10 [0.61753175]
# NZDJPY 30 [1.]
# AUDCAD 10 [0.60948413]
# NZDCAD 10 [0.92]
# AUDNZD 10 [0.76709524]
# 2020.03.29
# USDCHF 10 [0.62196032]
# EURUSD 10 [-0.64959524]
# USDJPY 15 [-0.11122727]
# USDCAD 10 [1.]
# AUDUSD 10 [0.24]
# NZDUSD 10 [0.04]
# GBPCHF 10 [-1.]
# CHFJPY 10 [0.3]
# CADCHF 10 [-0.70692857]
# EURGBP 10 [1.]
# GBPCAD 30 [-1.]
# EURJPY 15 [0.78]
# EURCAD 15 [-0.91066667]
# CADJPY 10 [0.52]
# AUDNZD 10 [1.]
# 2020.03.22
# USDCHF 10 [-0.986]
# EURUSD 10 [0.964]
# USDJPY 15 [-0.1054319]
# USDCAD 10 [0.46]
# AUDUSD 20 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 20 [-0.40782603]
# EURCHF 50 [-0.46517864]
# CHFJPY 10 [-0.3]
# CADCHF 10 [-0.79368254]
# AUDCHF 15 [-0.7931186]
# EURGBP 50 [0.59118254]
# GBPJPY 10 [-0.42]
# GBPAUD 50 [0.23137978]
# EURJPY 10 [-0.86]
# EURCAD 20 [0.43405675]
# EURAUD 10 [0.72296825]
# CADJPY 20 [-0.40045869]
# AUDCAD 30 [-0.40542108]
# NZDCAD 10 [-0.70575397]
# AUDNZD 10 [0.82]
# 2020.03.15
# USDCHF 20 [-0.98190476]
# GBPUSD 20 [0.11992857]
# EURUSD 15 [-0.56324315]
# USDJPY 20 [-0.44877204]
# USDCAD 10 [1.]
# AUDUSD 15 [-0.61420019]
# NZDUSD 15 [-0.55962321]
# GBPCHF 10 [0.29495238]
# CHFJPY 10 [-1.]
# CADCHF 10 [-0.77388095]
# NZDCHF 30 [0.74191847]
# EURGBP 10 [-0.6812381]
# GBPJPY 10 [0.92]
# GBPCAD 10 [0.986]
# GBPAUD 50 [-0.17505572]
# EURJPY 10 [-0.94]
# EURCAD 10 [0.44947619]
# EURNZD 10 [-0.66713492]
# CADJPY 20 [-0.49942313]
# AUDJPY 15 [1.]
# NZDJPY 20 [1.]
# AUDCAD 30 [-0.38546392]
# NZDCAD 15 [0.61115079]
# AUDNZD 50 [0.60916667]
# 2020.03.08
# GBPUSD 20 [0.87]
# EURUSD 15 [-0.43038506]
# USDJPY 10 [-0.45284127]
# USDCAD 10 [0.16]
# AUDUSD 20 [-0.70177994]
# NZDUSD 15 [-0.56755067]
# GBPCHF 10 [-1.]
# CHFJPY 15 [-0.20969481]
# CADCHF 10 [0.84]
# EURGBP 10 [0.984]
# GBPJPY 10 [-1.]
# GBPCAD 10 [0.92]
# GBPAUD 20 [-0.26392785]
# EURJPY 20 [-0.74]
# EURCAD 10 [-0.54315873]
# EURNZD 10 [1.]
# CADJPY 10 [-0.47007937]
# NZDJPY 30 [-0.40080447]
# AUDNZD 10 [1.]
# 2020.03.01
# GBPUSD 10 [-0.3692381]
# EURUSD 50 [-0.969]
# USDJPY 10 [-0.34011905]
# USDCAD 10 [1.]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 50 [-0.61433089]
# EURCHF 20 [0.08437537]
# CHFJPY 30 [0.64533333]
# CADCHF 30 [0.92]
# NZDCHF 10 [0.32863492]
# EURGBP 10 [0.82]
# GBPJPY 10 [-0.28]
# GBPCAD 10 [0.36]
# GBPAUD 50 [-0.80891683]
# EURJPY 20 [0.7491746]
# EURCAD 15 [0.53204834]
# EURNZD 15 [-0.8661746]
# CADJPY 20 [-0.33394733]
# AUDJPY 10 [-0.3332619]
# NZDJPY 15 [-0.21831025]
# NZDCAD 10 [-0.69045238]
# AUDNZD 10 [0.1]
# 2020.02.23
# USDCHF 10 [0.96]
# EURUSD 10 [-1.]
# USDCAD 10 [0.92]
# AUDUSD 10 [-1.]
# NZDUSD 20 [-0.59134127]
# GBPCHF 10 [0.38786508]
# EURCHF 20 [-0.78087363]
# CHFJPY 50 [-0.6138759]
# CADCHF 15 [0.925]
# AUDCHF 10 [0.3435]
# NZDCHF 10 [0.38099206]
# EURGBP 10 [0.42]
# GBPJPY 15 [-0.96]
# GBPCAD 15 [0.36693218]
# GBPAUD 50 [-0.10607143]
# EURJPY 10 [0.37583333]
# EURCAD 15 [0.48953968]
# EURAUD 10 [-0.40081746]
# EURNZD 10 [-1.]
# NZDJPY 15 [-0.15844084]
# AUDCAD 10 [0.36412698]
# NZDCAD 10 [1.]
# AUDNZD 10 [-0.48233333]
# 2020.02.16
# USDCHF 10 [-0.88]
# GBPUSD 10 [1.]
# EURUSD 10 [0.46404762]
# USDCAD 30 [-0.56]
# AUDUSD 10 [0.52527778]
# NZDUSD 15 [1.]
# GBPCHF 20 [1.]
# EURCHF 20 [0.18429565]
# CHFJPY 20 [0.99714286]
# CADCHF 15 [-0.48]
# AUDCHF 15 [-0.48397286]
# NZDCHF 10 [-0.1597381]
# EURGBP 20 [-0.98285714]
# GBPJPY 15 [0.90666667]
# GBPCAD 10 [0.42]
# GBPAUD 50 [0.14336253]
# EURCAD 50 [-0.1622684]
# EURAUD 20 [-0.53186996]
# EURNZD 10 [0.06]
# NZDCAD 10 [-0.5]
# AUDNZD 10 [0.84038095]
# 2020.02.09
# USDCHF 30 [-0.98666667]
# GBPUSD 20 [0.64175949]
# EURUSD 20 [0.74]
# USDCAD 10 [0.32]
# AUDUSD 20 [-0.26333333]
# NZDUSD 15 [0.46333333]
# EURCHF 20 [-0.74080087]
# CHFJPY 20 [1.]
# CADCHF 10 [-0.986]
# AUDCHF 30 [-0.54907554]
# GBPJPY 15 [0.88]
# GBPCAD 10 [-0.31629365]
#  [0.0632381]
# EURUSD 10 [0.09904762]
# USDJPY 50 [0.368]
# GBPCHF 15 [-1.]
# CHFJPY 50 [1.]
# AUDCHF 10 [-1.]
# NZDCHF 15 [-0.74190498]
# EURGBP 15 [1.]
# GBPJPY 15 [-0.22861905]
# GBPCAD 15 [-1.]
# EURJPY 10 [0.31469048]
# EURCAD 15 [0.69135886]
# CADJPY 20 [0.70045022]
# AUDNZD 10 [-0.54268254]
# 2019.07.28
# USDCHF 10 [-0.62]
# GBPUSD 10 [0.92]
# EURUSD 10 [0.98]
# USDJPY 10 [-0.58]
# AUDUSD 10 [1.]
# AUDCHF 30 [0.73466667]
# EURGBP 15 [0.24990476]
# GBPJPY 10 [0.83333333]
# GBPCAD 15 [-1.]
# EURJPY 15 [-0.52]
# EURAUD 15 [-0.53473016]
# CADJPY 20 [-0.47897619]
# AUDCAD 50 [0.26784083]
# 2019.07.21
# USDCHF 10 [-0.98]
# GBPUSD 10 [-0.88]
# EURUSD 15 [-0.60185714]
# USDJPY 10 [-1.]
# AUDUSD 10 [1.]
# GBPCHF 15 [-0.81185714]
# EURCHF 15 [-0.730002]
# NZDCHF 10 [1.]
# GBPJPY 15 [-0.83765829]
# GBPCAD 15 [-0.66]
# EURJPY 10 [-0.76646032]
# EURCAD 10 [-0.37670635]
# EURAUD 15 [-0.8]
# EURNZD 10 [-1.]
# CADJPY 20 [0.71231674]
# NZDCAD 10 [1.]
# 2019.07.14
# USDCHF 10 [1.]
# GBPUSD 10 [-1.]
# EURUSD 10 [-1.]
# USDJPY 10 [1.]
# USDCAD 30 [0.92]
# AUDUSD 10 [-0.22]
# NZDUSD 30 [-0.48161448]
# GBPCHF 15 [-0.84]
# EURCHF 15 [-0.49510251]
# CHFJPY 15 [-0.5902381]
# AUDCHF 15 [-0.92]
# NZDCHF 10 [0.944]
# GBPJPY 15 [-0.04903175]
# GBPCAD 15 [-0.9]
# EURJPY 15 [-0.04057143]
# EURCAD 15 [-0.59197619]
# EURNZD 10 [-0.986]
# CADJPY 20 [-0.53495238]
# NZDJPY 30 [-0.6451004]
# NZDCAD 30 [-0.38]
# AUDNZD 15 [0.29725441]
# 2019.07.07
# USDCHF 10 [-0.26]
# GBPUSD 10 [0.14]
# EURUSD 10 [0.86]
# USDJPY 10 [-0.16]
# USDCAD 20 [-0.98]
# AUDUSD 10 [-0.912]
# NZDUSD 10 [-0.986]
# GBPCHF 15 [0.9]
# CHFJPY 20 [-0.6760202]
# CADCHF 10 [0.764]
# NZDCHF 10 [0.888]
# EURGBP 10 [0.48466667]
# GBPJPY 10 [-0.984]
# GBPCAD 15 [0.9]
# EURJPY 15 [-0.73508947]
# EURCAD 15 [0.4]
# EURAUD 15 [1.]
# CADJPY 20 [0.67775547]
# AUDCAD 15 [-0.97666667]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.94]
# 2019.06.30
# GBPUSD 15 [-0.61816345]
# EURUSD 10 [-0.954]
# USDCAD 10 [0.68935714]
# AUDUSD 10 [-0.986]
# NZDUSD 10 [-0.966]
# GBPCHF 15 [0.76]
# CHFJPY 10 [-0.6277381]
# CADCHF 10 [0.748]
# AUDCHF 10 [-0.07190476]
# NZDCHF 10 [0.786]
# EURGBP 10 [0.56]
# GBPJPY 10 [-0.986]
# GBPCAD 10 [0.76]
# GBPAUD 10 [0.962]
# EURJPY 30 [0.38618071]
# EURCAD 15 [-0.61485714]
# EURAUD 15 [0.22]
# CADJPY 15 [-1.]
# NZDJPY 30 [-1.]
# AUDCAD 15 [-0.42]
# NZDCAD 20 [-0.32445774]
# 2019.06.23
# USDCHF 10 [-1.]
# GBPUSD 10 [-0.61764286]
# EURUSD 10 [-0.06]
# USDJPY 50 [-0.23481547]
# USDCAD 30 [-0.25430159]
# AUDUSD 10 [1.]
# NZDUSD 20 [-0.93980952]
# GBPCHF 15 [-1.]
# CHFJPY 10 [0.5572381]
# CADCHF 10 [-1.]
# AUDCHF 10 [0.40657143]
# NZDCHF 10 [-1.]
# EURGBP 30 [0.62266217]
# GBPJPY 10 [-0.65752381]
# GBPCAD 20 [-0.73833333]
# GBPAUD 30 [-0.45137338]
# EURJPY 10 [-0.49166667]
# EURCAD 15 [1.]
# EURAUD 10 [-0.26328571]
# CADJPY 15 [-1.]
# AUDJPY 15 [-1.]
# AUDCAD 15 [0.69613059]
# NZDCAD 15 [-0.5012381]
# AUDNZD 10 [0.98]
# 2019.06.16
# GBPUSD 15 [-0.50145238]
# EURUSD 30 [0.19970879]
# USDCAD 20 [-0.14]
# AUDUSD 10 [0.62638095]
# GBPCHF 15 [-0.84]
# EURCHF 30 [0.74876195]
# CHFJPY 10 [0.33814286]
# CADCHF 10 [-0.68633333]
# AUDCHF 30 [0.92]
# NZDCHF 10 [-0.71833333]
# EURGBP 30 [1.]
# GBPJPY 10 [0.21255556]
# GBPCAD 20 [-1.]
# GBPAUD 10 [-1.]
# EURJPY 10 [0.23034921]
# EURCAD 15 [0.83533333]
# EURAUD 50 [0.481]
# CADJPY 15 [-0.49225397]
# AUDJPY 15 [-0.38666667]
# NZDJPY 30 [-0.38879032]
# AUDCAD 10 [0.96666667]
# NZDCAD 15 [0.48408874]
# AUDNZD 20 [-0.70795238]
# 2019.06.09
# USDCHF 10 [-0.9]
# GBPUSD 10 [0.852]
# EURUSD 50 [-1.]
# USDJPY 10 [-1.]
# USDCAD 15 [-0.52285714]
# AUDUSD 10 [-0.956]
# GBPCHF 10 [0.56]
# CADCHF 10 [-0.1]
# AUDCHF 10 [0.96]
# EURGBP 30 [-0.84]
# GBPJPY 30 [0.064]
# GBPCAD 15 [0.56084921]
# GBPAUD 30 [0.6]
# EURJPY 10 [-1.]
# EURCAD 10 [1.]
# EURAUD 10 [-0.80866667]
# CADJPY 15 [-0.72]
# AUDJPY 20 [-0.52375874]
# NZDJPY 30 [-1.]
# AUDCAD 20 [0.52]
# NZDCAD 20 [-0.53869425]
# AUDNZD 20 [0.52881746]
# 2019.06.02
# USDCHF 20 [0.47106854]
# GBPUSD 20 [-0.92666667]
# EURUSD 10 [-0.98]
# USDCAD 15 [-0.72]
# GBPCHF 10 [-1.]
# EURCHF 20 [-0.5826746]
# CADCHF 10 [0.68]
# AUDCHF 10 [-1.]
# EURGBP 30 [0.6375696]
# GBPJPY 10 [-1.]
# GBPCAD 30 [-0.58114286]
# GBPAUD 30 [-0.00674603]
# EURJPY 10 [0.38595238]
# EURCAD 10 [-0.34466667]
# EURAUD 50 [0.79219048]
# 2019.05.26
# USDCHF 20 [-0.43180159]
# GBPUSD 15 [-1.]
# EURUSD 10 [-0.74]
# NZDUSD 10 [-0.33333333]
# GBPCHF 10 [-1.]
# CHFJPY 10 [1.]
# CADCHF 10 [-0.73523016]
# AUDCHF 30 [-0.27260587]
# EURGBP 10 [1.]
# GBPJPY 30 [-1.]
# GBPCAD 30 [-0.73925808]
# GBPAUD 10 [-1.]
# EURJPY 30 [-0.95666667]
# EURCAD 10 [-1.]
# EURAUD 50 [0.02112698]
# NZDCAD 50 [-0.82]
# AUDNZD 50 [-0.09717316]
# 2019.05.19
# USDCHF 15 [-0.60919841]
# GBPUSD 20 [0.50634127]
# EURUSD 20 [-0.60333333]
# USDJPY 10 [0.985]
# GBPCHF 10 [0.6]
# EURCHF 15 [1.]
# AUDCHF 30 [-0.22409207]
# NZDCHF 10 [0.39596032]
# EURGBP 10 [-1.]
# GBPJPY 10 [0.60503968]
# GBPCAD 15 [0.1981176]
# GBPAUD 10 [1.]
# EURJPY 30 [0.88619048]
# EURCAD 10 [-0.27328571]
# CADJPY 50 [0.29004475]
# AUDCAD 10 [-0.42742857]
# 2019.05.12
# USDCHF 15 [0.77595527]
# EURUSD 20 [-0.43113237]
# USDJPY 10 [0.57]
# USDCAD 10 [0.56895238]
# GBPCHF 10 [-0.42]
# CADCHF 10 [0.63683333]
# AUDCHF 15 [1.]
# NZDCHF 10 [-0.76]
# EURGBP 10 [0.4]
# GBPJPY 10 [-0.22749206]
# GBPCAD 15 [-1.]
# GBPAUD 10 [-0.4]
# EURJPY 30 [-0.78]
# EURAUD 10 [-0.62]
# NZDCAD 10 [0.4058254]
# 2019.05.05
# USDCHF 15 [0.65198341]
# NZDUSD 20 [0.34047192]
# GBPCHF 10 [-0.92833333]
# CHFJPY 15 [0.66]
# CADCHF 10 [-0.15416667]
# EURGBP 10 [0.7]
# GBPJPY 10 [0.99333333]
# GBPCAD 30 [-0.28065079]
# GBPAUD 10 [-0.72]
# EURJPY 10 [0.03666667]
# EURAUD 10 [-0.86]
# CADJPY 10 [-0.9825]
# AUDCAD 10 [-0.11785714]
# 2019.04.28
# USDCHF 30 [-0.19670047]
# USDJPY 10 [1.]
# USDCAD 10 [-0.953]
# AUDUSD 10 [0.22619048]
# NZDUSD 15 [0.40565945]
# GBPCHF 50 [0.62933333]
# CHFJPY 10 [0.972]
# CADCHF 15 [1.]
# EURGBP 10 [-1.]
# GBPCAD 15 [0.74443218]
# GBPAUD 10 [1.]
# EURCAD 50 [-0.31642503]
# EURAUD 10 [1.]
# CADJPY 10 [0.78333333]
# AUDJPY 30 [1.]
# NZDJPY 20 [0.9875]
# AUDCAD 30 [1.]
# NZDCAD 10 [0.986]
# 2019.04.21
# USDCHF 20 [0.47292857]
# GBPUSD 50 [0.86414286]
# USDJPY 10 [0.86]
# USDCAD 20 [-0.68]
# AUDUSD 15 [1.]
# NZDUSD 15 [-0.66779076]
# GBPCHF 20 [0.75208325]
# CHFJPY 10 [0.92]
# CADCHF 15 [1.]
# NZDCHF 10 [0.41460317]
# EURGBP 10 [-1.]
# GBPJPY 10 [1.]
# GBPAUD 10 [0.98]
# EURJPY 30 [-0.38833333]
# EURCAD 10 [0.45111111]
# EURAUD 10 [0.98]
# EURNZD 10 [1.]
# CADJPY 15 [1.]
# AUDJPY 10 [0.88]
# AUDCAD 10 [1.]
# NZDCAD 10 [-0.60352381]
# 2019.04.14
# USDCHF 20 [0.50345238]
# USDJPY 10 [-0.3092381]
# USDCAD 15 [0.51657937]
# AUDUSD 15 [-0.50914286]
# NZDUSD 15 [-0.6363088]
# GBPCHF 20 [-0.27466667]
# EURCHF 15 [-0.42409524]
# CHFJPY 10 [-0.92]
# CADCHF 10 [-0.98]
# AUDCHF 10 [-0.55987302]
# NZDCHF 10 [-1.]
# EURGBP 10 [0.58]
# GBPJPY 15 [-1.]
# GBPCAD 15 [-0.151]
# GBPAUD 10 [-0.48]
# EURJPY 15 [-0.2051746]
# EURCAD 15 [0.27442874]
# EURAUD 10 [-0.66]
# EURNZD 10 [0.58892857]
# CADJPY 10 [-1.]
# AUDJPY 10 [-0.92]
# AUDCAD 10 [-0.14]
# NZDCAD 10 [-0.57640476]
# 2019.04.07
# USDCHF 20 [0.31809524]
# GBPUSD 10 [-1.]
# USDJPY 10 [0.06]
# USDCAD 10 [0.44235714]
# AUDUSD 10 [-0.70468254]
# GBPCHF 15 [-0.44769481]
# EURCHF 20 [0.51077633]
# CHFJPY 10 [0.7]
# CADCHF 10 [1.]
# AUDCHF 10 [0.37743651]
# EURGBP 10 [0.82]
# GBPJPY 20 [-0.07442857]
# GBPCAD 10 [0.07133333]
# GBPAUD 10 [-0.92]
# EURJPY 20 [0.36766667]
# EURCAD 10 [0.36427778]
# EURAUD 10 [-0.9]
# EURNZD 15 [-0.99666667]
# CADJPY 10 [1.]
# AUDJPY 15 [1.]
# AUDCAD 10 [1.]
# NZDCAD 20 [1.]
# 2019.03.31
# USDCHF 10 [-0.34588889]
# GBPUSD 10 [0.58953968]
# EURUSD 10 [0.42819841]
# USDJPY 10 [0.98]
# USDCAD 10 [-1.]
# AUDUSD 10 [-0.48810317]
# GBPCHF 15 [0.74041486]
# EURCHF 10 [1.]
# CHFJPY 10 [1.]
# AUDCHF 10 [-0.56497619]
# EURGBP 10 [-1.]
# GBPJPY 15 [0.53926557]
# GBPCAD 10 [1.]
# GBPAUD 10 [1.]
# EURJPY 20 [0.61959235]
# EURAUD 10 [1.]
# EURNZD 10 [0.984]
# CADJPY 20 [-0.12098413]
# AUDJPY 20 [1.]
# NZDJPY 10 [0.964]
# AUDCAD 10 [-0.56550794]
# NZDCAD 10 [1.]
# 2019.03.24
# USDCHF 20 [0.07475758]
# GBPUSD 10 [-1.]
# USDJPY 20 [-0.3047619]
# USDCAD 10 [-1.]
# AUDUSD 15 [0.69830952]
# GBPCHF 10 [0.984]
# EURCHF 15 [0.94533333]
# CHFJPY 10 [1.]
# NZDCHF 10 [0.982]
# EURGBP 10 [0.58]
# GBPJPY 20 [0.34]
# GBPCAD 10 [-0.62833333]
# GBPAUD 10 [-0.62]
# EURJPY 30 [-0.7348269]
# EURAUD 10 [-0.8]
# EURNZD 10 [-0.16]
# NZDJPY 10 [0.64]
# AUDCAD 15 [-0.51211328]
# NZDCAD 10 [-0.08]
# 2019.03.17
# USDCHF 10 [1.]
# GBPUSD 15 [-0.36456133]
# USDJPY 20 [-0.32522747]
# USDCAD 10 [0.5713254]
# AUDUSD 10 [-0.47661905]
# NZDUSD 10 [-0.39161905]
# GBPCHF 10 [-0.58219048]
# EURCHF 15 [-0.54405556]
# CHFJPY 10 [-0.45296032]
# AUDCHF 30 [0.55874984]
# EURGBP 10 [0.76]
# GBPJPY 10 [-0.47957143]
# GBPCAD 10 [-0.74]
# GBPAUD 10 [-0.95857143]
# EURJPY 50 [0.32159163]
# EURAUD 10 [-0.99333333]
# EURNZD 10 [-0.98666667]
# CADJPY 20 [-0.36668038]
# NZDJPY 15 [-0.72]
# AUDCAD 10 [1.]
# NZDCAD 10 [-0.88]
# AUDNZD 15 [1.]
# 2019.03.10
# USDCHF 10 [-0.9]
# EURUSD 20 [-0.90225397]
# USDJPY 20 [0.1662381]
# USDCAD 10 [-1.]
# AUDUSD 30 [0.84]
# GBPCHF 10 [1.]
# EURCHF 20 [0.80252886]
# CHFJPY 20 [0.07648052]
# AUDCHF 15 [-1.]
# NZDCHF 15 [-0.9757619]
# EURGBP 10 [-1.]
# GBPJPY 10 [0.988]
# GBPCAD 10 [0.76]
# GBPAUD 15 [1.]
# EURJPY 20 [-0.33316667]
# EURAUD 10 [0.30254762]
# EURNZD 15 [0.965]
# AUDJPY 10 [-0.19015873]
# NZDJPY 10 [-1.]
# AUDCAD 10 [-0.986]
# NZDCAD 10 [0.12]
# AUDNZD 20 [-0.41211905]
# 2019.03.03
# EURUSD 10 [0.70946825]
# USDCAD 10 [0.29288889]
# AUDUSD 10 [0.82]
# NZDUSD 10 [0.41383333]
# GBPCHF 10 [0.99]
# EURCHF 20 [0.14070851]
# AUDCHF 15 [0.60790476]
# NZDCHF 10 [0.43369048]
# EURGBP 10 [0.45971429]
# GBPJPY 10 [0.86]
# GBPCAD 10 [-0.5357619]
# GBPAUD 15 [0.93533333]
# EURJPY 10 [1.]
# EURAUD 15 [0.51770424]
# EURNZD 10 [-0.42119048]
# AUDJPY 10 [1.]
# NZDJPY 10 [-0.12]
# AUDCAD 10 [-0.68992857]
# NZDCAD 10 [-0.26]
# AUDNZD 20 [0.35869048]
# 2019.02.24
# USDCHF 10 [-0.38643651]
# GBPUSD 50 [0.50607937]
# AUDUSD 15 [0.865]
# NZDUSD 10 [0.62680952]
# GBPCHF 10 [0.62633333]
# EURCHF 20 [0.67554762]
# CADCHF 10 [1.]
# AUDCHF 10 [1.]
# NZDCHF 10 [0.72459524]
# GBPCAD 20 [-0.5]
# GBPAUD 10 [-0.4942619]
# EURJPY 10 [1.]
# EURAUD 10 [-1.]
# EURNZD 10 [-0.64392063]
# CADJPY 10 [1.]
# AUDJPY 10 [1.]
# NZDJPY 10 [0.98]
# AUDCAD 10 [0.61971429]
# NZDCAD 10 [0.36]
# AUDNZD 20 [0.86]
# 2019.02.17
# GBPUSD 15 [-0.75949206]
# AUDUSD 10 [-0.964]
# NZDUSD 10 [-0.984]
# GBPCHF 10 [-0.16]
# CADCHF 10 [-0.2112619]
# AUDCHF 10 [-0.27946032]
# NZDCHF 10 [-0.962]
# EURGBP 20 [0.00368254]
# GBPCAD 20 [1.]
# GBPAUD 10 [1.]
# EURJPY 10 [-0.88]
# EURCAD 10 [0.2982381]
# EURAUD 10 [0.31187302]
# EURNZD 10 [0.952]
# CADJPY 10 [-0.19590476]
# AUDJPY 10 [-0.56724603]
# NZDJPY 10 [-1.]
# AUDCAD 15 [-0.01669048]
# NZDCAD 10 [0.46]
# AUDNZD 15 [-0.38]
# 2019.02.10
# USDCHF 10 [-0.34420635]
# GBPUSD 15 [0.64374603]
# EURUSD 10 [1.]
# AUDUSD 10 [-0.44]
# NZDUSD 50 [0.05130952]
# GBPCHF 10 [0.61643651]
# AUDCHF 10 [0.78]
# NZDCHF 10 [-0.61197619]
# EURGBP 20 [0.30219048]
# GBPJPY 10 [-0.48]
# GBPCAD 10 [0.44]
# GBPAUD 10 [-0.20605556]
# EURJPY 30 [-0.77]
# EURCAD 10 [0.66125397]
# EURAUD 10 [0.7017381]
# EURNZD 10 [0.59523016]
# CADJPY 10 [0.86]
# AUDJPY 10 [0.68162698]
# NZDJPY 10 [0.56]
# AUDCAD 10 [-0.3]
# NZDCAD 10 [1.]
# AUDNZD 15 [-1.]
# 2019.02.03
# USDCHF 10 [-0.56079365]
# GBPUSD 15 [0.46933333]
# EURUSD 10 [1.]
# AUDUSD 10 [-0.96]
# GBPCHF 10 [0.66696032]
# AUDCHF 20 [-0.37716667]
# NZDCHF 10 [-0.958]
# EURGBP 10 [0.7]
# GBPJPY 15 [0.05266667]
# GBPCAD 10 [1.]
# GBPAUD 10 [1.]
# EURJPY 10 [-0.88]
# EURCAD 10 [-0.94]
# EURAUD 10 [0.5647619]
# EURNZD 10 [0.954]
# CADJPY 10 [-0.9]
# AUDJPY 10 [-0.61952381]
# NZDJPY 10 [-1.]
# AUDCAD 15 [-0.51716955]
# NZDCAD 10 [-1.]
# AUDNZD 15 [1.]
# 2019.01.27
# GBPUSD 20 [-0.12]
# EURUSD 15 [-1.]
# USDJPY 10 [0.952]
# AUDUSD 10 [0.36898413]
# NZDUSD 10 [-0.66]
# GBPCHF 20 [-0.31892063]
# EURCHF 20 [-0.34857143]
# CHFJPY 15 [1.]
# AUDCHF 10 [1.]
# NZDCHF 10 [-0.78]
# EURGBP 15 [-0.94485714]
# GBPJPY 10 [0.88]
# GBPCAD 15 [0.44]
# EURJPY 10 [0.56]
# EURCAD 10 [-0.968]
# EURNZD 10 [0.86]
# CADJPY 30 [0.46323077]
# AUDJPY 10 [1.]
# NZDJPY 10 [-0.34]
# AUDCAD 20 [-0.34052747]
# NZDCAD 10 [-0.92]
# AUDNZD 10 [1.]
# 2019.01.20
# USDCHF 10 [0.42397619]
# EURUSD 20 [0.27014669]
# USDJPY 10 [-0.42307143]
# AUDUSD 15 [-0.40468687]
# GBPCHF 20 [0.74471284]
# EURCHF 20 [0.83007945]
# CHFJPY 50 [0.38808333]
# EURGBP 10 [1.]
# GBPJPY 10 [0.]
# GBPCAD 15 [0.933]
# GBPAUD 30 [-0.43051024]
# EURJPY 10 [1.]
# EURCAD 10 [0.44209524]
# CADJPY 20 [0.39345568]
# AUDJPY 10 [1.]
# AUDCAD 10 [0.984]
# 2019.01.13
# USDCHF 10 [0.46595238]
# EURUSD 20 [-0.78315274]
# AUDUSD 10 [1.]
# NZDUSD 20 [0.71238672]
# GBPCHF 15 [0.34006133]
# EURCHF 20 [0.77935859]
# CHFJPY 20 [-0.3384879]
# AUDCHF 15 [0.0417619]
# NZDCHF 10 [1.]
# EURGBP 10 [-0.37557143]
# GBPJPY 10 [0.78]
# GBPCAD 10 [0.86]
# GBPAUD 50 [-0.59753896]
# EURJPY 10 [0.98]
# EURCAD 30 [0.55711111]
# EURNZD 10 [-0.982]
# CADJPY 10 [-1.]
# NZDJPY 10 [0.86]
# AUDCAD 10 [0.76]
# NZDCAD 50 [1.]
# AUDNZD 30 [-0.25633333]
# 2019.01.06
# USDCHF 50 [0.32755085]
# EURUSD 30 [0.3058522]
# USDJPY 15 [-0.5992129]
# AUDUSD 50 [-0.97207792]
# NZDUSD 30 [0.57903968]
# GBPCHF 15 [0.67020563]
# EURCHF 20 [0.74798823]
# CHFJPY 20 [0.6423799]
# CADCHF 30 [0.8859188]
# GBPJPY 10 [0.27233333]
# GBPCAD 10 [1.]
# EURJPY 10 [0.48111905]
# EURCAD 30 [-0.52]
# EURAUD 15 [0.33198268]
# CADJPY 50 [-0.50065801]
# NZDJPY 50 [-0.37509524]
# AUDCAD 30 [-0.88033333]
# NZDCAD 10 [0.992]
# AUDNZD 10 [-0.8]
# 2018.12.30
# EURUSD 30 [-0.5486886]
# USDJPY 10 [0.94]
# USDCAD 15 [1.]
# AUDUSD 15 [0.57671412]
# NZDUSD 20 [-0.43454665]
# GBPCHF 20 [0.7218113]
# CHFJPY 20 [0.40533405]
# GBPJPY 20 [0.58497852]
# GBPAUD 15 [-0.35192857]
# EURJPY 10 [-1.]
# EURAUD 30 [0.356829]
# CADJPY 15 [0.122]
# AUDCAD 10 [0.53812698]
# NZDCAD 20 [-0.4358624]
# AUDNZD 10 [0.955]
# 2018.12.23
# GBPUSD 10 [-1.]
# EURUSD 30 [0.30693807]
# USDJPY 10 [0.6362381]
# USDCAD 15 [1.]
# AUDUSD 30 [-0.24564041]
# AUDCHF 15 [1.]
# GBPJPY 10 [0.784]
# GBPCAD 10 [-0.2871746]
# GBPAUD 10 [-1.]
# EURJPY 30 [0.20693881]
# EURAUD 15 [-1.]
# CADJPY 20 [-0.6947381]
# AUDJPY 10 [0.954]
# AUDCAD 10 [1.]
# NZDCAD 15 [-0.47325108]
# 2018.12.16
# GBPUSD 10 [0.24866667]
# EURUSD 30 [0.19880021]
# USDJPY 10 [-0.25010317]
# AUDUSD 30 [1.]
# NZDUSD 30 [0.61589454]
# AUDCHF 10 [0.41459524]
# NZDCHF 10 [1.]
# GBPJPY 20 [-0.45009722]
# GBPAUD 10 [-0.096]
# EURJPY 30 [-0.56327675]
# EURAUD 15 [-0.02846304]
# CADJPY 15 [-0.16647114]
# AUDCAD 20 [-0.439]
# NZDCAD 15 [0.64952381]
# 2018.12.09
# GBPUSD 10 [-0.4]
# USDJPY 10 [0.926]
# AUDUSD 30 [0.04403968]
# NZDUSD 30 [-0.06461905]
# GBPCHF 30 [0.16210317]
# GBPJPY 20 [-0.41337809]
# GBPAUD 10 [-1.]
# EURCAD 10 [0.972]
# EURAUD 30 [-0.02520635]
# CADJPY 20 [-0.67]
# NZDJPY 50 [0.23427228]
# AUDCAD 20 [-0.2717619]
# NZDCAD 15 [-0.34666667]
# AUDNZD 10 [-0.76228571]
# 2018.12.02
# GBPUSD 10 [-1.]
# USDJPY 30 [0.5097381]
# AUDUSD 20 [0.53342857]
# NZDUSD 10 [0.35038095]
# GBPCHF 50 [-0.20760045]
# EURGBP 10 [-1.]
# GBPJPY 10 [0.95]
# GBPCAD 10 [-0.37446032]
# GBPAUD 15 [-0.65298052]
# EURCAD 10 [-0.70054762]
# EURAUD 15 [-0.81534543]
# CADJPY 20 [-0.26352381]
# AUDJPY 10 [0.972]
# NZDJPY 10 [0.97]
# AUDCAD 10 [0.26433333]
# NZDCAD 10 [0.33033333]
# 2018.11.25
# GBPUSD 10 [1.]
# USDJPY 30 [-0.91680952]
# USDCAD 10 [-0.18438095]
# AUDUSD 20 [0.65307637]
# NZDUSD 20 [0.57672444]
# GBPCHF 10 [0.984]
# EURCHF 15 [1.]
# AUDCHF 20 [0.985]
# GBPJPY 20 [-0.32962049]
# GBPCAD 10 [0.75140476]
# GBPAUD 10 [-1.]
# EURCAD 10 [0.64080159]
# CADJPY 20 [0.21499198]
# AUDJPY 10 [0.976]
# NZDJPY 10 [1.]
# NZDCAD 15 [0.73132307]
# 2018.11.18
# USDCHF 20 [1.]
# GBPUSD 10 [-1.]
# USDJPY 30 [-0.26317162]
# USDCAD 10 [1.]
# AUDUSD 20 [-0.40591712]
# GBPCHF 10 [0.53209524]
# CHFJPY 15 [-0.51586003]
# CADCHF 30 [0.67349675]
# GBPJPY 20 [-0.15368071]
# GBPAUD 20 [-0.65102526]
# EURCAD 10 [-0.962]
# EURAUD 30 [-0.70975325]
# CADJPY 50 [0.26467596]
# NZDJPY 50 [0.22552165]
# 2018.11.11
# USDCHF 15 [1.]
# GBPUSD 10 [-0.98]
# EURUSD 10 [-1.]
# AUDUSD 30 [0.39429072]
# NZDUSD 50 [-0.17850299]
# GBPCHF 30 [-0.45059404]
# CADCHF 50 [-0.20388123]
# AUDCHF 50 [-0.27770444]
# NZDCHF 30 [-0.32119807]
# GBPCAD 50 [-0.61396825]
# EURCAD 10 [-0.47861111]
# CADJPY 50 [-0.98]
# NZDCAD 20 [-0.6051506]
# 2018.11.04
# USDCHF 15 [0.06557143]
# GBPUSD 30 [-1.]
# EURUSD 20 [-0.44167177]
# USDCAD 10 [-0.22785714]
# AUDUSD 50 [0.30154327]
# NZDUSD 50 [-0.24637163]
# GBPCHF 50 [-0.23869428]
# CADCHF 10 [1.]
# AUDCHF 15 [-0.45782395]
# NZDCHF 30 [-0.33419946]
# EURGBP 50 [0.38372911]
# GBPAUD 15 [0.45033189]
# EURJPY 50 [-0.56321003]
# EURCAD 10 [0.64238889]
# CADJPY 50 [-0.55792207]
# AUDNZD 20 [0.52773532]
# 2018.10.28
# USDCHF 10 [-0.41803968]
# GBPUSD 10 [0.5]
# EURUSD 15 [1.]
# USDJPY 20 [-0.56774858]
# USDCAD 50 [-0.39064214]
# AUDUSD 50 [0.26345479]
# NZDUSD 50 [0.41671874]
# EURCHF 30 [-0.72569708]
# CHFJPY 50 [0.82166667]
# CADCHF 10 [1.]
# AUDCHF 15 [0.7132629]
# EURGBP 15 [0.75228571]
# GBPCAD 10 [0.78]
# EURJPY 50 [0.15031638]
# EURCAD 15 [-0.72286147]
# EURAUD 20 [0.62280092]
# EURNZD 50 [-0.27934509]
# AUDJPY 50 [0.31703048]
# NZDJPY 50 [-0.15542779]
# AUDCAD 15 [-1.]
# 2018.10.21
# USDCHF 15 [0.49820635]
# GBPUSD 10 [-0.78]
# EURUSD 15 [-0.67548773]
# USDJPY 20 [-0.29333333]
# USDCAD 50 [0.45556376]
# AUDUSD 15 [0.65282179]
# NZDUSD 50 [-0.14838393]
# EURCHF 30 [0.30737979]
# CHFJPY 50 [-0.35201136]
# CADCHF 10 [1.]
# NZDCHF 30 [0.48462622]
# EURGBP 10 [-1.]
# NZDJPY 20 [0.99416667]
# AUDCAD 15 [1.]
# NZDCAD 30 [0.43255421]
# 2018.10.14
# USDCHF 30 [0.64466667]
# GBPUSD 15 [-0.83245238]
# EURUSD 15 [-0.58496032]
# USDJPY 20 [0.50293545]
# AUDUSD 15 [-0.61983333]
# NZDUSD 50 [0.41947636]
# EURCHF 30 [0.42770704]
# EURGBP 10 [-1.]
# GBPJPY 15 [-0.51128571]
# GBPCAD 50 [0.07369048]
# NZDJPY 15 [-0.5033189]
# AUDCAD 15 [0.64]
# NZDCAD 10 [-1.]
# 2018.10.07
# EURUSD 15 [1.]
# USDJPY 20 [0.53218223]
# CHFJPY 10 [1.]
# NZDCHF 30 [-0.46393539]
# GBPJPY 10 [1.]
# GBPCAD 50 [0.39727378]
# NZDJPY 15 [-0.49036291]
# AUDCAD 30 [-0.985]
# 2018.09.30
# GBPUSD 15 [-0.54896825]
# EURUSD 15 [0.7224127]
# USDJPY 10 [0.988]
# AUDUSD 15 [0.53657515]
# CHFJPY 10 [0.5932381]
# EURGBP 10 [1.]
# GBPJPY 10 [0.02]
# GBPCAD 15 [-0.84]
# GBPAUD 10 [-1.]
# EURNZD 15 [-0.49421645]
# AUDCAD 50 [-0.76]
# NZDCAD 10 [0.22009524]
# 2018.09.23
# USDCHF 10 [-0.99]
# EURUSD 15 [-0.51266234]
# AUDUSD 15 [-0.80628499]
# CHFJPY 30 [-0.13133828]
# EURGBP 10 [0.2]
# GBPJPY 10 [0.69504762]
# GBPCAD 15 [-0.75833333]
# GBPAUD 10 [-0.48]
# EURCAD 15 [1.]
# AUDCAD 30 [-0.04]
# NZDCAD 15 [0.50238911]
# AUDNZD 10 [-1.]
# 2018.09.16
# USDCHF 10 [-0.26920635]
# EURUSD 10 [-1.]
# USDCAD 50 [0.98414286]
# AUDUSD 10 [-0.988]
# CHFJPY 30 [0.41385613]
# CADCHF 10 [-0.968]
# AUDCHF 10 [-1.]
# NZDCHF 10 [-1.]
# EURGBP 10 [1.]
# GBPJPY 10 [0.1]
# GBPCAD 15 [0.71875685]
# GBPAUD 10 [-0.954]
# EURCAD 15 [1.]
# EURNZD 10 [1.]
# AUDCAD 15 [-0.24969048]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.982]
# 2018.09.09
# USDCHF 10 [0.96]
# EURUSD 10 [0.28684921]
# USDCAD 10 [0.938]
# AUDUSD 10 [0.35140476]
# NZDUSD 10 [-0.966]
# CADCHF 20 [-0.62112329]
# GBPJPY 10 [0.99714286]
# GBPCAD 10 [0.36115873]
# GBPAUD 10 [0.44854762]
# EURCAD 15 [0.9]
# EURAUD 10 [0.88]
# EURNZD 50 [0.53551587]
# AUDCAD 30 [-0.92]
# NZDCAD 10 [0.28899206]
# AUDNZD 10 [0.966]
# 2018.09.02
# USDCHF 10 [0.72]
# GBPUSD 50 [-0.31607591]
# EURUSD 10 [0.982]
# USDCAD 50 [0.03133333]
# NZDUSD 15 [-0.69038889]
# CADCHF 15 [0.35478571]
# AUDCHF 15 [0.36868398]
# NZDCHF 20 [0.50386652]
# EURGBP 10 [-0.19123016]
# GBPJPY 10 [0.988]
# GBPCAD 10 [-0.75366667]
# GBPAUD 15 [-0.58]
# EURJPY 10 [0.44695238]
# EURCAD 10 [-0.54]
# EURAUD 10 [-0.24]
# EURNZD 50 [-0.02634127]
# CADJPY 15 [0.72180087]
# AUDCAD 30 [-0.54]
# NZDCAD 50 [-0.38585065]
# AUDNZD 15 [0.57118254]
# 2018.08.26
# USDCHF 15 [-0.68841081]
# EURUSD 10 [0.54387302]
# USDCAD 20 [0.18907181]
# EURCHF 10 [0.89561905]
# CADCHF 10 [-0.59142063]
# AUDCHF 15 [-0.80276457]
# GBPJPY 10 [0.984]
# GBPCAD 10 [0.54621429]
# GBPAUD 15 [0.6456645]
# EURJPY 10 [0.94638095]
# EURCAD 10 [1.]
# EURAUD 10 [0.28]
# CADJPY 10 [0.88]
# NZDJPY 10 [1.]
# AUDCAD 10 [-0.34]
# NZDCAD 15 [0.5567619]
# AUDNZD 20 [-0.01109799]
# 2018.08.19
# USDCHF 10 [-0.51797619]
# GBPUSD 10 [-1.]
# EURUSD 10 [-1.]
# USDCAD 50 [-0.30616667]
# GBPCHF 10 [0.42411111]
# CADCHF 10 [-0.60039683]
# AUDCHF 15 [-0.6045873]
# EURGBP 10 [-0.16797619]
# GBPCAD 10 [0.40957143]
# GBPAUD 15 [0.26980952]
# EURCAD 10 [1.]
# EURAUD 10 [-0.12]
# EURNZD 30 [-0.48554762]
# CADJPY 10 [-0.56559524]
# NZDJPY 10 [0.966]
# AUDCAD 20 [-0.695]
# NZDCAD 15 [0.68515429]
# AUDNZD 10 [-0.41250794]
# 2018.08.12
# GBPUSD 15 [0.25097619]
# USDJPY 10 [-0.98580952]
# USDCAD 15 [-0.74433261]
# GBPCHF 15 [-0.63419769]
# EURCHF 15 [-1.]
# CHFJPY 20 [-0.24721029]
# AUDCHF 20 [-0.4708254]
# NZDCHF 20 [-0.67940476]
# EURGBP 10 [1.]
# GBPJPY 15 [-0.51571429]
# GBPCAD 20 [-0.22742857]
# GBPAUD 15 [1.]
# EURCAD 10 [-1.]
# EURAUD 10 [0.5752381]
# CADJPY 10 [1.]
# AUDJPY 10 [-1.]
# NZDJPY 15 [-0.68753968]
# AUDCAD 50 [-0.65314214]
# NZDCAD 15 [-0.72527489]
# 2018.08.05
# EURUSD 10 [0.984]
# USDJPY 10 [-0.984]
# USDCAD 50 [-0.56156283]
# AUDUSD 50 [0.41683778]
# NZDUSD 10 [0.93]
# GBPCHF 10 [1.]
# CADCHF 20 [0.99142857]
# AUDCHF 10 [0.63186508]
# EURGBP 10 [-0.28864286]
# GBPAUD 10 [-0.54]
# EURCAD 10 [-0.7]
# EURNZD 10 [-1.]
# CADJPY 50 [0.22402782]
# AUDJPY 10 [-0.944]
# NZDJPY 15 [-0.6522381]
# AUDCAD 50 [-0.9362381]
# NZDCAD 15 [-0.96361905]
# 2018.07.29
# USDCHF 10 [-1.]
# USDJPY 10 [-0.9]
# USDCAD 30 [0.71727417]
# AUDUSD 10 [1.]
# GBPCHF 10 [1.]
# CADCHF 20 [0.51615873]
# AUDCHF 20 [0.68763492]
# NZDCHF 10 [1.]
# GBPJPY 10 [-0.32302381]
# GBPAUD 10 [0.37988095]
# EURCAD 10 [0.24]
# EURAUD 10 [-0.25200794]
# EURNZD 10 [-0.44307143]
# CADJPY 50 [0.6516018]
# AUDJPY 10 [0.36207937]
# NZDJPY 10 [-0.38819048]
# AUDCAD 15 [1.]
# NZDCAD 10 [0.84]
# AUDNZD 10 [-1.]
# 2018.07.22
# USDJPY 10 [-0.8]
# USDCAD 30 [-0.32894697]
# AUDUSD 10 [0.70864286]
# NZDUSD 10 [0.958]
# GBPCHF 10 [0.57984127]
# EURCHF 20 [0.70946032]
# AUDCHF 15 [-0.06866667]
# NZDCHF 10 [0.98]
# GBPJPY 10 [0.92]
# GBPAUD 15 [0.992]
# EURJPY 30 [0.29479783]
# EURCAD 10 [-0.48]
# EURNZD 10 [-1.]
# CADJPY 50 [0.85198413]
# AUDJPY 10 [-0.972]
# NZDJPY 10 [0.48407143]
# AUDCAD 10 [0.36]
# NZDCAD 15 [-0.73788889]
# 2018.07.15
# USDCHF 10 [0.948]
# GBPUSD 10 [-0.45453968]
# USDJPY 15 [0.98]
# USDCAD 20 [0.78550769]
# AUDUSD 10 [1.]
# NZDUSD 10 [-1.]
# EURCHF 20 [-0.19635268]
# AUDCHF 15 [0.96]
# NZDCHF 10 [0.2]
# EURGBP 10 [-1.]
# GBPJPY 50 [-0.50005583]
# EURJPY 30 [-0.472554]
# EURCAD 20 [0.12]
# EURNZD 15 [-0.57891575]
# CADJPY 10 [1.]
# AUDJPY 10 [1.]
# NZDJPY 10 [-0.54]
# AUDCAD 10 [-0.55352381]
# 2018.07.08
# USDCHF 15 [1.]
# GBPUSD 15 [0.50070202]
# USDJPY 15 [1.]
# USDCAD 10 [0.04]
# AUDUSD 10 [1.]
# NZDUSD 50 [0.3882749]
# CHFJPY 10 [-0.20249206]
# CADCHF 20 [-0.52819048]
# NZDCHF 10 [1.]
# GBPJPY 50 [0.66464696]
# GBPAUD 20 [0.2253254]
# EURJPY 20 [-0.55346829]
# EURCAD 50 [0.01572872]
# EURNZD 10 [-1.]
# CADJPY 50 [-0.19735354]
# AUDJPY 50 [-0.29974274]
# NZDJPY 10 [1.]
# AUDCAD 15 [0.36]
# NZDCAD 10 [1.]
# AUDNZD 15 [-0.47989466]
# 2018.07.01
# USDCHF 20 [0.96]
# GBPUSD 10 [-1.]
# EURUSD 20 [-0.3712381]
# USDJPY 20 [0.98285714]
# USDCAD 20 [0.366]
# AUDUSD 10 [-1.]
# NZDUSD 10 [-1.]
# GBPCHF 10 [-1.]
# CHFJPY 10 [-1.]
# CADCHF 30 [-0.01233333]
# NZDCHF 10 [-0.68424603]
# GBPJPY 30 [-0.6861811]
# GBPAUD 15 [-1.]
# EURJPY 30 [-0.00084127]
# EURCAD 10 [-0.88]
# EURAUD 10 [-1.]
# EURNZD 10 [-0.984]
# NZDJPY 50 [-0.26061755]
# AUDCAD 30 [0.33553968]
# NZDCAD 10 [0.42480952]
# AUDNZD 10 [1.]
# 2018.06.24
# USDCHF 10 [-1.]
# GBPUSD 10 [0.22]
# EURUSD 15 [-0.26940476]
# USDJPY 20 [-0.78502192]
# USDCAD 10 [-0.914]
# AUDUSD 10 [0.18]
# NZDUSD 50 [0.45180467]
# GBPCHF 10 [-1.]
# CHFJPY 10 [0.6667381]
# CADCHF 50 [0.228]
# NZDCHF 30 [-0.253]
# EURGBP 50 [-0.30696992]
# GBPJPY 30 [0.57]
# GBPCAD 15 [0.94514286]
# GBPAUD 15 [-0.05766667]
# EURAUD 10 [0.51988889]
# EURNZD 15 [0.6176746]
# AUDJPY 15 [-0.54110284]
# NZDJPY 10 [0.54054762]
# AUDCAD 50 [0.27266667]
# NZDCAD 20 [-0.62]
# AUDNZD 10 [-0.42]
# 2018.06.17
# USDCHF 10 [-0.98]
# GBPUSD 10 [0.33279365]
# EURUSD 30 [-0.65187302]
# USDJPY 20 [-0.02218687]
# USDCAD 10 [-0.34365873]
# AUDUSD 10 [0.37170635]
# NZDUSD 10 [0.36620635]
# GBPCHF 10 [0.96333333]
# CHFJPY 10 [-0.908]
# AUDCHF 50 [0.21406219]
# NZDCHF 10 [0.96]
# EURGBP 50 [0.24905184]
# GBPJPY 50 [-0.93333333]
# GBPCAD 15 [-1.]
# GBPAUD 20 [0.49712593]
# EURCAD 15 [-0.82]
# EURNZD 20 [0.40614619]
# AUDCAD 10 [0.62]
# NZDCAD 15 [-0.32920635]
# AUDNZD 15 [0.55]
# 2018.06.10
# USDCHF 10 [0.56]
# GBPUSD 30 [0.47233766]
# EURUSD 15 [0.97333333]
# USDJPY 20 [0.86]
# AUDUSD 10 [-0.32]
# NZDUSD 10 [0.48]
# GBPCHF 10 [0.96]
# EURCHF 10 [0.96]
# CADCHF 20 [0.32466667]
# AUDCHF 50 [0.26789402]
# NZDCHF 10 [0.938]
# EURGBP 50 [-0.26319083]
# GBPJPY 50 [0.92]
# GBPCAD 15 [0.28633333]
# GBPAUD 20 [-0.42384127]
# EURJPY 10 [0.988]
# EURCAD 10 [0.482]
# EURNZD 20 [-0.57480009]
# AUDCAD 10 [0.44]
# NZDCAD 20 [0.60669048]
# AUDNZD 10 [0.159]
# 2018.06.03
# USDCHF 10 [-0.91]
# GBPUSD 10 [0.30403175]
# EURUSD 15 [-0.05228283]
# USDJPY 10 [-0.72]
# USDCAD 30 [0.49674352]
# NZDUSD 10 [1.]
# GBPCHF 10 [0.58261905]
# EURCHF 15 [-0.5]
# AUDCHF 15 [-1.]
# EURGBP 10 [-0.40387302]
# GBPCAD 15 [0.60868254]
# GBPAUD 20 [0.15957648]
# EURJPY 15 [-0.61711905]
# EURCAD 10 [-1.]
# EURAUD 10 [-0.74854762]
# EURNZD 30 [-0.35721786]
# CADJPY 20 [-0.51062478]
# AUDCAD 10 [0.926]
# NZDCAD 20 [0.64244444]
# AUDNZD 10 [-0.85566667]
# 2018.05.27
# USDCHF 10 [-0.47633333]
# GBPUSD 20 [-0.44929715]
# EURUSD 30 [0.4069703]
# USDJPY 10 [0.1]
# USDCAD 15 [0.77816595]
# NZDUSD 10 [-0.69331746]
# GBPCHF 15 [-1.]
# CHFJPY 10 [-0.94]
# CADCHF 30 [0.34904545]
# AUDCHF 20 [-0.79633333]
# NZDCHF 15 [-0.71220646]
# GBPCAD 15 [0.49697619]
# ...
# GBPUSD 10 [-0.16204762]
# EURUSD 10 [-0.5]
# USDJPY 20 [-0.68252481]
# USDCAD 20 [-1.]
# AUDUSD 30 [-0.52135091]
# NZDUSD 10 [0.63707143]
# CHFJPY 30 [0.19014043]
# CADCHF 30 [0.37534293]
# EURGBP 10 [0.82]
# GBPAUD 50 [0.29914286]
# EURAUD 20 [0.61079582]
# CADJPY 10 [0.972]
# AUDJPY 15 [0.69784488]
# NZDJPY 10 [0.97333333]
# AUDCAD 15 [0.69652237]
# NZDCAD 15 [0.51993723]
# AUDNZD 10 [0.60445238]
# 2016.05.08
# USDCHF 10 [0.6]
# GBPUSD 10 [0.84]
# EURUSD 10 [-1.]
# USDJPY 15 [0.10264286]
# USDCAD 10 [0.31666667]
# NZDUSD 10 [1.]
# CHFJPY 10 [-0.938]
# CADCHF 30 [0.39653334]
# AUDCHF 10 [0.93]
# NZDCHF 10 [0.95]
# EURGBP 10 [0.78]
# GBPJPY 30 [-0.83791311]
# GBPCAD 50 [0.40070633]
# EURCAD 50 [0.45888084]
# EURNZD 10 [-0.95666667]
# CADJPY 10 [0.908]
# AUDJPY 15 [0.59011905]
# NZDJPY 10 [0.94666667]
# NZDCAD 15 [0.34833333]
# AUDNZD 10 [-1.]
# 2016.05.01
# USDCHF 10 [0.98]
# GBPUSD 10 [-0.25847619]
# EURUSD 10 [-0.986]
# USDJPY 10 [1.]
# USDCAD 10 [-0.19166667]
# NZDUSD 10 [-0.94]
# EURCHF 10 [-0.976]
# CHFJPY 15 [-0.95466667]
# AUDCHF 10 [-0.27596032]
# NZDCHF 10 [-0.82]
# EURGBP 10 [-0.12859524]
# GBPJPY 30 [-0.68668464]
# GBPAUD 20 [-1.]
# EURNZD 15 [0.49080952]
# CADJPY 10 [-0.3765873]
# AUDJPY 10 [1.]
# NZDJPY 15 [-0.92]
# AUDCAD 10 [1.]
# NZDCAD 15 [0.11933333]
# AUDNZD 15 [0.86]
# 2016.04.24
# USDCHF 10 [-0.98]
# EURUSD 10 [0.57761905]
# USDJPY 10 [-0.92]
# USDCAD 30 [-0.59017582]
# NZDUSD 10 [0.76]
# GBPCHF 30 [0.55115385]
# CHFJPY 10 [1.]
# CADCHF 15 [0.69468398]
# AUDCHF 10 [1.]
# NZDCHF 10 [0.81388095]
# EURGBP 15 [1.]
# GBPJPY 15 [0.54561905]
# GBPAUD 20 [0.60104545]
# EURJPY 10 [0.938]
# EURCAD 30 [-0.49169897]
# EURAUD 15 [-1.]
# EURNZD 10 [-0.77609524]
# CADJPY 10 [0.79833333]
# AUDJPY 15 [1.]
# NZDJPY 15 [0.96]
# AUDCAD 10 [-0.3163254]
# NZDCAD 15 [-0.54]
# AUDNZD 30 [0.32407899]
# 2016.04.17
# USDCHF 30 [0.82]
# GBPUSD 30 [-1.]
# EURUSD 15 [0.76]
# USDJPY 10 [-0.02]
# AUDUSD 10 [-0.17597619]
# NZDUSD 10 [-0.96]
# GBPCHF 30 [0.37461011]
# CHFJPY 50 [-0.09708636]
# CADCHF 10 [-0.986]
# NZDCHF 10 [0.44571429]
# EURGBP 20 [1.]
# GBPJPY 20 [0.31537662]
# GBPCAD 10 [0.3562381]
# GBPAUD 15 [-0.02727489]
# EURJPY 50 [0.21039307]
# EURCAD 20 [-0.26900713]
# EURAUD 10 [-1.]
# EURNZD 10 [-0.392]
# CADJPY 10 [0.27396032]
# AUDJPY 15 [0.83733333]
# NZDJPY 10 [0.22]
# AUDCAD 10 [-0.18978571]
# NZDCAD 15 [-0.75246753]
# AUDNZD 10 [-0.6628254]
# 2016.04.10
# USDCHF 10 [0.55338095]
# GBPUSD 30 [-0.39398567]
# EURUSD 20 [-0.48652414]
# USDJPY 20 [0.08763218]
# USDCAD 15 [-0.03927356]
# NZDUSD 10 [0.9]
# GBPCHF 30 [-0.41694468]
# CHFJPY 50 [0.02566667]
# CADCHF 10 [0.32609524]
# AUDCHF 20 [0.35114214]
# NZDCHF 10 [0.986]
# EURGBP 15 [0.17270346]
# GBPCAD 10 [-0.9]
# GBPAUD 20 [-1.]
# EURNZD 10 [-0.924]
# CADJPY 20 [0.3569127]
# NZDJPY 10 [0.8]
# AUDCAD 10 [0.988]
# NZDCAD 10 [-0.7482381]
# 2016.04.03
# USDCHF 20 [-0.75738745]
# GBPUSD 20 [0.6605671]
# EURUSD 10 [1.]
# USDJPY 10 [0.1422619]
# USDCAD 30 [-0.3457865]
# NZDUSD 10 [-0.86]
# GBPCHF 20 [-0.48789582]
# CADCHF 10 [-1.]
# NZDCHF 10 [-0.15542857]
# EURGBP 50 [-0.43306688]
# GBPJPY 10 [0.94]
# GBPCAD 10 [0.4102381]
# GBPAUD 20 [-0.84333045]
# EURCAD 10 [0.942]
# EURAUD 15 [-0.53870241]
# EURNZD 10 [-0.35113492]
# CADJPY 15 [0.32333333]
# AUDJPY 20 [0.53285714]
# NZDJPY 10 [-1.]
# AUDCAD 10 [0.84216667]
# 2016.03.27
# USDCHF 15 [0.53100006]
# GBPUSD 20 [0.5317381]
# EURUSD 10 [0.36930952]
# USDCAD 30 [-0.27083474]
# NZDUSD 10 [1.]
# GBPCHF 30 [0.03122078]
# CADCHF 10 [1.]
# AUDCHF 10 [0.41830952]
# NZDCHF 10 [1.]
# EURGBP 10 [-0.92]
# GBPJPY 30 [0.4987381]
# GBPAUD 15 [-0.22719841]
# EURNZD 50 [-0.16766667]
# CADJPY 15 [0.30166667]
# NZDJPY 10 [1.]
# AUDCAD 10 [0.966]
# NZDCAD 15 [-1.]
# 2016.03.20
# USDCHF 15 [0.51645671]
# GBPUSD 20 [-0.38915946]
# EURUSD 10 [-0.62938889]
# USDCAD 10 [-1.]
# AUDUSD 10 [1.]
# NZDUSD 10 [-0.76704762]
# CHFJPY 30 [-0.36]
# NZDCHF 10 [-0.66069048]
# EURGBP 15 [1.]
# GBPJPY 30 [-0.45026481]
# GBPCAD 15 [-0.75766378]
# GBPAUD 15 [-1.]
# EURNZD 15 [-0.44949956]
# CADJPY 50 [-0.15784127]
# AUDJPY 15 [-1.]
# NZDJPY 15 [-0.42892502]
# AUDCAD 10 [0.984]
# NZDCAD 10 [-0.78]
# 2016.03.13
# GBPUSD 30 [0.52311077]
# EURUSD 10 [0.5837619]
# USDCAD 10 [-1.]
# AUDUSD 10 [1.]
# NZDUSD 10 [0.59680159]
# GBPCHF 20 [0.4813653]
# CHFJPY 10 [-0.44869841]
# NZDCHF 50 [-0.15239139]
# EURGBP 10 [0.61033333]
# GBPJPY 30 [0.31582702]
# GBPCAD 15 [0.69206349]
# GBPAUD 15 [-0.62665079]
# EURCAD 50 [-0.21774705]
# EURNZD 30 [-0.05485714]
# CADJPY 20 [0.42]
# AUDJPY 15 [-0.59466667]
# NZDJPY 15 [-0.47420135]
# AUDCAD 15 [0.62]
# AUDNZD 10 [1.]
# 2016.03.06
# USDCHF 20 [1.]
# EURUSD 10 [0.16311111]
# USDJPY 10 [0.35968254]
# USDCAD 30 [0.14420274]
# NZDUSD 15 [-0.90914286]
# CHFJPY 15 [-1.]
# CADCHF 15 [0.34192324]
# EURGBP 10 [1.]
# GBPJPY 15 [-1.]
# GBPCAD 10 [-1.]
# GBPAUD 20 [-0.72613131]
# EURJPY 15 [-1.]
# EURCAD 50 [-0.48210101]
# EURNZD 50 [-0.31624387]
# CADJPY 30 [-0.07820202]
# AUDJPY 15 [-0.68366378]
# AUDCAD 15 [-0.5]
# AUDNZD 20 [0.54748752]
# 2016.02.28
# USDCHF 20 [-0.13834305]
# GBPUSD 30 [0.17744182]
# EURUSD 10 [0.984]
# USDJPY 10 [-1.]
# USDCAD 30 [-0.44016145]
# NZDUSD 20 [0.77129015]
# CHFJPY 10 [-0.3157619]
# CADCHF 15 [0.04002453]
# AUDCHF 20 [-1.]
# GBPAUD 10 [0.2397619]
# EURJPY 10 [0.21342857]
# EURCAD 15 [0.45742091]
# EURNZD 10 [1.]
# CADJPY 10 [-1.]
# AUDJPY 20 [0.42951791]
# AUDCAD 10 [0.24]
# AUDNZD 15 [-0.74946825]
# 2016.02.21
# USDCHF 30 [1.]
# GBPUSD 30 [-0.54006468]
# EURUSD 10 [-0.40353175]
# USDCAD 30 [-0.2152033]
# AUDUSD 20 [0.44982334]
# NZDUSD 20 [0.02418432]
# CADCHF 10 [0.42942063]
# AUDCHF 15 [0.61047985]
# GBPCAD 10 [0.14594444]
# GBPAUD 10 [-0.066]
# EURJPY 10 [0.46845238]
# EURNZD 10 [0.12]
# CADJPY 10 [0.17092063]
# AUDCAD 10 [-0.8]
# NZDCAD 50 [0.22602221]
# AUDNZD 20 [0.43833888]
# 2016.02.14
# USDCHF 50 [-0.15653472]
# GBPUSD 30 [0.26729536]
# EURUSD 10 [-0.65365873]
# USDCAD 30 [-0.16752423]
# GBPCHF 10 [-1.]
# CHFJPY 30 [-0.67867821]
# CADCHF 20 [-0.66130952]
# AUDCHF 20 [-0.22856886]
# GBPAUD 20 [-0.88928571]
# EURJPY 10 [-1.]
# EURCAD 15 [1.]
# EURNZD 30 [0.585]
# CADJPY 10 [-1.]
# AUDCAD 10 [0.82]
# 2016.02.07
# USDCHF 15 [0.93166667]
# EURUSD 15 [-1.]
# USDCAD 10 [1.]
# NZDUSD 20 [0.14955556]
# GBPCHF 15 [-0.49567433]
# CADCHF 30 [0.49803968]
# GBPAUD 15 [-0.98]
# EURJPY 10 [-1.]
# EURNZD 30 [-0.96]
# AUDCAD 15 [0.98857143]
# NZDCAD 30 [0.62144126]
# 2016.01.31
# USDCHF 50 [-1.]
# EURUSD 15 [0.951]
# USDCAD 10 [0.35271429]
# GBPCHF 10 [0.34319841]
# CHFJPY 15 [0.95333333]
# GBPJPY 20 [0.70148557]
# GBPAUD 15 [-0.13765079]
# EURJPY 10 [-0.32320635]
# EURCAD 10 [-0.33736508]
# CADJPY 10 [0.29823016]
# AUDCAD 10 [-0.7]
# NZDCAD 30 [0.988]
# 2016.01.24
# EURUSD 20 [-0.80977778]
# USDJPY 10 [-1.]
# USDCAD 20 [0.995]
# NZDUSD 10 [-0.954]
# CHFJPY 30 [-0.77359169]
# EURGBP 15 [-0.66010895]
# GBPAUD 50 [0.51522222]
# EURJPY 10 [-0.86]
# EURCAD 10 [-0.33737302]
# EURAUD 30 [0.37534127]
# EURNZD 20 [-0.63404412]
# CADJPY 10 [-0.76]
# NZDJPY 10 [-1.]
# AUDCAD 10 [-0.16414286]
# NZDCAD 30 [-0.15452994]
# 2016.01.17
# GBPUSD 20 [-0.38079076]
# EURUSD 15 [-0.78263276]
# USDJPY 10 [0.63764286]
# AUDUSD 10 [-0.95]
# NZDUSD 50 [0.82973138]
# GBPCHF 10 [-1.]
# CHFJPY 20 [-1.]
# CADCHF 10 [-1.]
# EURGBP 10 [1.]
# GBPAUD 15 [-1.]
# EURJPY 15 [-0.98]
# EURCAD 30 [0.986]
# EURAUD 30 [-0.3477201]
# EURNZD 20 [-0.56009524]
# CADJPY 10 [0.96]
# NZDJPY 10 [0.65919841]
# AUDCAD 15 [1.]
# EURNZD 10 [0.8015]
# CADJPY 15 [-0.41368326]
# NZDJPY 20 [0.52770058]
# AUDCAD 10 [-0.95666667]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.77861905]
# 2015.06.28
# USDCHF 10 [-1.]
# GBPUSD 20 [0.02061905]
# EURUSD 20 [-0.13966112]
# AUDUSD 30 [-0.44317266]
# NZDUSD 20 [0.11633333]
# GBPCHF 10 [-0.92]
# CHFJPY 15 [1.]
# CADCHF 15 [-1.]
# NZDCHF 20 [-0.55230686]
# EURGBP 10 [0.96]
# GBPAUD 10 [0.11166667]
# EURJPY 10 [1.]
# EURAUD 30 [0.35786733]
# CADJPY 15 [-0.27855556]
# AUDJPY 10 [0.4803254]
# NZDJPY 15 [0.95466667]
# AUDCAD 10 [-1.]
# NZDCAD 10 [-1.]
# AUDNZD 15 [-0.32427817]
# 2015.06.21
# USDCHF 10 [-1.]
# GBPUSD 10 [-0.3855873]
# EURUSD 20 [0.31092857]
# USDJPY 20 [0.55783636]
# USDCAD 20 [-0.78902153]
# AUDUSD 20 [0.79352453]
# NZDUSD 10 [-1.]
# GBPCHF 10 [1.]
# CHFJPY 10 [-0.616]
# CADCHF 20 [0.82]
# AUDCHF 10 [-0.064]
# NZDCHF 10 [-1.]
# GBPJPY 30 [1.]
# GBPCAD 20 [0.21086401]
# GBPAUD 30 [0.75901304]
# EURJPY 10 [0.88]
# EURCAD 50 [0.44076173]
# EURNZD 10 [0.76330952]
# CADJPY 20 [0.80766786]
# NZDJPY 15 [-0.57842763]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.79065873]
# 2015.06.14
# USDCHF 10 [-0.44]
# USDCAD 15 [-0.58993296]
# AUDUSD 20 [0.53483333]
# NZDUSD 15 [-0.14]
# GBPCHF 10 [1.]
# CHFJPY 10 [-0.04]
# CADCHF 10 [0.66]
# AUDCHF 15 [-0.28153968]
# NZDCHF 50 [-0.36583369]
# EURGBP 10 [0.55566667]
# GBPJPY 15 [0.79853719]
# GBPAUD 30 [0.75183944]
# EURJPY 50 [-0.57666667]
# EURAUD 20 [-0.122]
# EURNZD 50 [0.43760724]
# CADJPY 15 [-0.28322222]
# AUDCAD 10 [0.6695]
# AUDNZD 10 [0.78204762]
# 2015.06.07
# USDCHF 10 [-1.]
# GBPUSD 10 [-0.44669048]
# USDJPY 10 [0.71213492]
# AUDUSD 20 [0.59840476]
# NZDUSD 20 [-0.366]
# GBPCHF 10 [0.82]
# CHFJPY 30 [-0.36]
# CADCHF 50 [0.24666667]
# NZDCHF 50 [-0.23245779]
# EURGBP 10 [-0.88]
# GBPAUD 30 [0.75629032]
# EURJPY 20 [0.008]
# EURCAD 10 [0.42615079]
# EURAUD 30 [-0.969]
# EURNZD 50 [0.68033949]
# AUDJPY 10 [0.75519048]
# AUDCAD 15 [0.34259163]
# NZDCAD 15 [0.34546609]
# AUDNZD 10 [0.74036508]
# 2015.05.31
# USDCHF 10 [-1.]
# GBPUSD 15 [-0.57056405]
# EURUSD 20 [-0.49707437]
# USDJPY 10 [0.71349206]
# USDCAD 20 [0.45349928]
# AUDUSD 10 [0.70315079]
# GBPCHF 10 [0.54]
# EURCHF 10 [-1.]
# CHFJPY 10 [-0.57602381]
# CADCHF 10 [0.57446032]
# AUDCHF 10 [0.65159524]
# EURGBP 30 [0.24527905]
# GBPJPY 30 [0.85535746]
# GBPCAD 15 [0.28537729]
# GBPAUD 30 [0.66090559]
# EURJPY 15 [-1.]
# EURCAD 20 [-0.70215324]
# EURAUD 30 [0.30738095]
# AUDJPY 10 [0.75584127]
# NZDCAD 50 [-0.71716667]
# 2015.05.24
# USDCHF 10 [-0.82]
# GBPUSD 50 [0.09154593]
# EURUSD 20 [-0.50686985]
# USDJPY 10 [-0.52]
# USDCAD 10 [-1.]
# NZDUSD 10 [0.76]
# GBPCHF 10 [-0.9]
# EURCHF 10 [0.62146825]
# CHFJPY 10 [1.]
# CADCHF 10 [-1.]
# NZDCHF 20 [0.79209818]
# GBPJPY 20 [-0.69675302]
# GBPCAD 20 [-0.44200794]
# GBPAUD 15 [-0.68099928]
# EURJPY 10 [1.]
# EURCAD 20 [0.35612198]
# EURAUD 30 [0.31877808]
# EURNZD 15 [-1.]
# CADJPY 50 [-0.67430535]
# AUDJPY 20 [-0.58654762]
# NZDJPY 10 [0.92]
# AUDCAD 10 [-1.]
# NZDCAD 15 [0.48982828]
# AUDNZD 10 [-0.80288095]
# 2015.05.17
# USDCHF 15 [0.72672655]
# GBPUSD 10 [1.]
# EURUSD 15 [0.75621795]
# USDJPY 10 [-0.986]
# USDCAD 30 [-1.]
# AUDUSD 15 [0.71539905]
# NZDUSD 10 [-1.]
# GBPCHF 10 [0.98]
# EURCHF 15 [-0.84]
# CHFJPY 30 [-0.53070801]
# CADCHF 50 [0.61697548]
# AUDCHF 30 [0.68188442]
# NZDCHF 10 [-1.]
# GBPJPY 50 [0.63178355]
# EURJPY 20 [0.57002908]
# EURCAD 20 [-0.7597901]
# EURAUD 30 [-0.51338373]
# CADJPY 30 [1.]
# AUDJPY 15 [0.77228938]
# NZDJPY 10 [-1.]
# AUDCAD 50 [0.27733013]
# NZDCAD 10 [-1.]
# AUDNZD 20 [0.98]
# 2015.05.10
# USDCHF 10 [0.37426984]
# GBPUSD 10 [0.928]
# EURUSD 10 [1.]
# USDJPY 10 [0.38]
# NZDUSD 10 [-0.9052381]
# GBPCHF 10 [0.31103968]
# EURCHF 20 [0.74]
# AUDCHF 20 [0.73499328]
# NZDCHF 10 [-0.9]
# GBPJPY 50 [0.22307442]
# EURJPY 30 [0.45166952]
# EURCAD 20 [0.17224167]
# EURNZD 10 [-0.48266667]
# CADJPY 10 [1.]
# AUDJPY 20 [1.]
# NZDJPY 10 [-0.32984921]
# AUDCAD 50 [0.27228966]
# NZDCAD 10 [-1.]
# AUDNZD 10 [0.995]
# 2015.05.03
# EURUSD 20 [0.46486436]
# USDJPY 10 [-0.25933333]
# GBPCHF 10 [-0.74793651]
# EURCHF 20 [-0.64123016]
# CADCHF 15 [-0.39590115]
# NZDCHF 15 [-0.45381818]
# EURGBP 15 [0.44602381]
# EURCAD 50 [0.63160606]
# EURAUD 20 [0.49201354]
# NZDCAD 10 [-0.50762698]
# AUDNZD 10 [-0.72]
# 2015.04.26
# USDCHF 10 [1.]
# EURUSD 10 [-0.928]
# USDJPY 10 [1.]
# NZDUSD 10 [-0.4272381]
# GBPCHF 15 [1.]
# EURCHF 10 [0.3223254]
# CHFJPY 10 [-1.]
# CADCHF 10 [1.]
# EURGBP 15 [0.02428571]
# EURJPY 30 [-0.42185915]
# EURAUD 10 [-0.956]
# EURNZD 10 [-0.87533333]
# NZDJPY 10 [-0.22784127]
# NZDCAD 10 [0.42]
# AUDNZD 10 [0.94]
# 2015.04.19
# GBPUSD 10 [-0.43246032]
# USDJPY 10 [-0.47877778]
# GBPCHF 15 [0.8]
# EURCHF 30 [-0.19833333]
# NZDCHF 15 [0.62161111]
# GBPCAD 20 [0.92450794]
# EURNZD 10 [0.2337619]
# NZDCAD 10 [-0.25840476]
# AUDNZD 10 [0.46569048]
# 2015.04.12
# GBPUSD 10 [0.952]
# GBPCHF 15 [-0.64]
# EURCHF 20 [0.60515729]
# CADCHF 10 [0.8]
# AUDCHF 10 [0.82]
# NZDCHF 20 [0.54561905]
# GBPCAD 15 [0.53548413]
# GBPAUD 20 [-0.54465455]
# EURNZD 10 [-1.]
# NZDCAD 10 [0.38290476]
# AUDNZD 10 [-0.85933333]
# 2015.04.05
# GBPUSD 15 [0.95333333]
# USDJPY 10 [-1.]
# USDCAD 10 [0.39037302]
# AUDUSD 20 [-1.]
# GBPCHF 15 [-0.39366667]
# EURCHF 20 [-0.96]
# CHFJPY 50 [0.45854853]
# CADCHF 10 [-0.76]
# AUDCHF 10 [-0.76]
# NZDCHF 20 [-0.82]
# GBPCAD 15 [-0.5608002]
# GBPAUD 10 [0.972]
# EURAUD 10 [1.]
# EURNZD 10 [0.9]
# CADJPY 10 [-0.40759524]
# NZDCAD 10 [-0.295]
# AUDNZD 10 [-0.50885714]
# 2015.03.29
# USDCHF 50 [-0.14191196]
# GBPCHF 10 [-0.96]
# EURCHF 10 [0.48]
# CADCHF 10 [-0.94]
# AUDCHF 10 [-0.96]
# NZDCHF 10 [-0.82]
# GBPCAD 15 [-0.56929249]
# EURAUD 10 [0.98]
# EURNZD 10 [0.96]
# NZDJPY 10 [-0.962]
# NZDCAD 10 [-0.9]
# AUDNZD 30 [-0.760332]
# 2015.03.22
# USDCHF 10 [1.]
# EURUSD 10 [-1.]
# USDJPY 10 [1.]
# AUDUSD 30 [0.46906738]
# NZDUSD 10 [1.]
# GBPCHF 10 [-0.28]
# EURCHF 20 [-0.5]
# CHFJPY 10 [-1.]
# CADCHF 10 [-0.76]
# AUDCHF 10 [-0.72]
# NZDCHF 10 [-0.354]
# GBPJPY 10 [1.]
# GBPCAD 10 [0.988]
# GBPAUD 15 [0.67751487]
# EURJPY 10 [0.946]
# EURAUD 30 [-0.86]
# EURNZD 10 [0.14]
# AUDJPY 30 [0.53549956]
# NZDCAD 10 [-0.37588095]
# 2015.03.15
# USDCHF 50 [0.74829725]
# EURUSD 20 [-1.]
# USDCAD 15 [1.]
# AUDUSD 20 [-0.71126389]
# NZDUSD 10 [-1.]
# GBPCHF 10 [-0.96]
# EURCHF 10 [0.86]
# CHFJPY 20 [0.57103236]
# CADCHF 10 [-0.227]
# AUDCHF 10 [-0.42928571]
# NZDCHF 10 [-0.25333333]
# EURGBP 10 [-1.]
# GBPJPY 15 [-1.]
# GBPCAD 10 [-0.31669048]
# GBPAUD 15 [-0.70869075]
# EURJPY 10 [-1.]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 20 [-0.69036941]
# AUDJPY 15 [-0.80836658]
# NZDCAD 10 [0.76672222]
# 2015.03.08
# USDCHF 15 [-0.20157937]
# EURUSD 15 [-0.66428571]
# AUDUSD 20 [-0.71556908]
# GBPCHF 10 [0.02]
# EURCHF 10 [-0.06]
# CADCHF 10 [0.73490476]
# NZDCHF 50 [-0.60001683]
# GBPJPY 10 [-0.14366667]
# GBPCAD 10 [-0.32812698]
# EURJPY 10 [-0.91066667]
# EURCAD 10 [0.2971746]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 20 [-0.41561183]
# AUDJPY 15 [-0.80114391]
# NZDCAD 10 [0.26061905]
# 2015.03.01
# USDCHF 15 [0.77608763]
# GBPUSD 10 [0.3606746]
# EURUSD 15 [0.37916667]
# USDCAD 15 [1.]
# AUDUSD 20 [-0.6825795]
# NZDUSD 15 [0.49482468]
# GBPCHF 10 [0.63225397]
# EURCHF 10 [1.]
# CADCHF 10 [1.]
# NZDCHF 50 [-0.17950869]
# EURGBP 10 [1.]
# GBPJPY 15 [0.51792857]
# GBPCAD 15 [0.61565079]
# EURJPY 10 [0.8]
# EURCAD 10 [0.31698413]
# EURAUD 10 [-1.]
# EURNZD 10 [-1.]
# CADJPY 20 [-0.06267749]
# AUDJPY 10 [-0.38557143]
# AUDCAD 30 [0.11212477]
# NZDCAD 10 [1.]
# 2015.02.22
# GBPUSD 10 [0.25119048]
# EURUSD 20 [-1.]
# USDJPY 20 [0.64942138]
# AUDUSD 20 [-0.57461756]
# NZDUSD 10 [0.38919048]
# GBPCHF 50 [0.64461905]
# EURCHF 10 [0.]
# CADCHF 10 [-0.28902381]
# AUDCHF 10 [-0.32785714]
# NZDCHF 50 [-0.29427424]
# EURGBP 10 [-1.]
# GBPJPY 10 [-0.62]
# GBPCAD 10 [-0.48]
# EURJPY 15 [-0.64]
# EURCAD 10 [-1.]
# EURAUD 20 [-0.74184127]
# EURNZD 10 [-1.]
# NZDJPY 20 [0.13574603]
# AUDCAD 10 [0.42305556]
# NZDCAD 10 [0.92]
# 2015.02.15
# GBPUSD 10 [0.68165079]
# EURUSD 15 [0.21300794]
# USDCAD 15 [-0.896]
# AUDUSD 30 [0.50333333]
# CHFJPY 50 [0.18007182]
# NZDCHF 50 [0.36759587]
# EURGBP 20 [0.36]
# GBPJPY 10 [1.]
# GBPCAD 10 [0.31666667]
# EURJPY 10 [0.62769048]
# EURCAD 10 [0.36259524]
# EURNZD 10 [-1.]
# CADJPY 10 [0.98]
# AUDJPY 50 [0.57845989]
# NZDJPY 20 [1.]
# AUDCAD 10 [-0.51227778]
# NZDCAD 10 [0.56]
# AUDNZD 30 [-0.77182956]
# 2015.02.08
# USDCHF 10 [-0.23538095]
# GBPUSD 10 [-0.68]
# EURUSD 15 [0.3709127]
# USDCAD 15 [1.]
# AUDUSD 20 [-1.]
# GBPCHF 15 [-0.2]
# CADCHF 10 [-0.28022222]
# NZDCHF 50 [0.29624274]
# EURGBP 10 [0.98]
# GBPJPY 15 [0.30047619]
# GBPCAD 10 [0.62395238]
# GBPAUD 10 [-1.]
# EURJPY 10 [0.34334921]
# EURCAD 10 [-0.82]
# EURAUD 10 [-0.984]
# EURNZD 10 [-1.]
# CADJPY 10 [0.35166667]
# AUDJPY 10 [0.21228571]
# NZDJPY 10 [0.22415079]
# NZDCAD 10 [0.66]
# AUDNZD 15 [0.44633333]
# 2015.02.01
# USDCHF 10 [-0.2119127]
# GBPUSD 10 [0.49871429]
# EURUSD 10 [0.49657143]
# GBPCHF 10 [0.24]
# CHFJPY 10 [-0.982]
# CADCHF 10 [0.952]
# EURGBP 20 [-0.42]
# GBPJPY 30 [0.27084127]
# GBPCAD 10 [-0.982]
# EURJPY 10 [-0.54088095]
# EURCAD 10 [-1.]
# EURAUD 10 [0.42219048]
# EURNZD 15 [0.13011111]
# CADJPY 15 [0.98666667]
# AUDCAD 10 [0.39819841]
# NZDCAD 10 [-0.28]
# 2015.01.25
# USDCHF 30 [0.78581746]
# GBPUSD 10 [0.29766667]
# EURUSD 30 [-0.17199351]
# USDCAD 10 [1.]
# AUDUSD 15 [0.36522799]
# GBPCHF 10 [-0.38]
# EURCHF 20 [-1.]
# CHFJPY 10 [0.30165873]
# EURGBP 20 [0.51290476]
# GBPJPY 30 [-0.98]
# GBPCAD 10 [0.59735714]
# EURJPY 10 [0.43757143]
# EURNZD 10 [0.3878254]
# CADJPY 10 [0.1187381]
# AUDJPY 50 [0.32816379]
# NZDCAD 10 [0.36]
# AUDNZD 15 [-1.]
# 2015.01.18
# GBPUSD 10 [-1.]
# EURUSD 15 [-1.]
# USDJPY 15 [-0.31007143]
# USDCAD 20 [0.85646712]
# AUDUSD 15 [0.68911905]
# GBPCHF 10 [-0.14]
# EURCHF 20 [-0.99833333]
# CHFJPY 10 [-0.926]
# CADCHF 20 [0.16713492]
# AUDCHF 15 [0.98666667]
# EURGBP 20 [-0.9]
# GBPCAD 10 [0.28780952]
# CADJPY 10 [-0.52730159]
# NZDJPY 10 [1.]
# NZDCAD 10 [0.14]
# AUDNZD 15 [0.56713492]
# 2015.01.11
# USDCAD 10 [-0.408]
# AUDUSD 15 [-0.03903968]
# GBPCHF 10 [-1.]
# EURCHF 30 [0.21762504]
# EURGBP 10 [0.24]
# CADJPY 10 [-0.3459127]
# NZDCAD 10 [1.]
# AUDNZD 20 [-0.79937379]
# 2015.01.04

# %%
print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx   END of SCRIPT')
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx   END of SCRIPT
