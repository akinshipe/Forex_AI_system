# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

# %%
#currency_pairs = ['USDCHF10080',
                 #'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 #'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 #'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                #'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                #]

headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
percent =[]
number_of_trades = []


trial_number = 2500
cut_off_sets = [ 0.435, 0.445, 0.455 ]
n_estimators = 250
min_samples_leaf = 1
max_features = "auto"
max_samples = None

for h in cut_off_sets:
    
    cut_off = h
    
    percent =[]
    number_of_trades = []


    for x in range(trial_number):


        current_currency = 'USDCHF10080'.replace('10080','')

        data = pd.read_csv('files/' + current_currency + '.csv'  ) 
        #print(len(data))
        data = data.head(len(data)-0)
        #print(len(data))


        X = data.drop(columns=['date','nextweek_'+ current_currency])

        y = data['nextweek_'+ current_currency]

        test_sample_item = 20

        X_train = X[test_sample_item:]
        y_train = y[test_sample_item:]
        X_test = X[:test_sample_item]
        y_test = y[:test_sample_item]




        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1 )



        clf=RandomForestRegressor(n_estimators=n_estimators, n_jobs =-1, min_samples_leaf=min_samples_leaf,
                                 max_features = max_features, max_samples = max_samples)
        #Train the model using the training sets y_pred=clf.predict(X_test)
        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)

        #class_percent = 0
        #for index, q in enumerate(y_pred):
            #if q == y_test[index]:
                #class_percent = class_percent+1
            #print( q, y_test[index])
        #print(current_currency,100*class_percent/len(y_pred),'%')


        #print('Regressor test ----------------------------------------------------------------------------------------------')


        regress_percent = 0
        total_items =0 


        for index, q in enumerate(y_pred):

            if q > cut_off  or q < (-1*cut_off) :
                total_items = total_items + 1
                #print(q, y_test[index])

                if q > 0 and y_test[index] == 1 or q < 0 and y_test[index] == -1:
                    regress_percent = regress_percent +1



        if total_items != 0:
            current_percentage =  100*regress_percent/total_items
            #print(current_currency, current_percentage,'%')
            percent.append(current_percentage)
            number_of_trades.append(total_items)




        if x % (trial_number/10) == 0:
            print(x)
    print('usdchf average percent is ', sum(percent)/len(percent))
    print('average of ', sum(number_of_trades)/trial_number, ' trades every ', test_sample_item, ' weeks')
    print('cut off = ', cut_off)
# Out:
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# usdchf average percent is  93.48861904761995
# average of  6.0524  trades every  20  weeks
# cut off =  0.435
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# usdchf average percent is  94.6703174603183
# average of  5.8432  trades every  20  weeks
# cut off =  0.445
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# usdchf average percent is  95.99695238095308
# average of  5.5932  trades every  20  weeks
# cut off =  0.455

# %%
feature_importance = pd.DataFrame(clf.feature_importances_,
                        index = X_train.columns,
                        columns = ['importance']).sort_values('importance', ascending =False)
feature_importance
# Out:
#         importance
# AUDNZD    0.058576
# USDCAD    0.057720
# AUDCAD    0.056048
# GBPUSD    0.054881
# GBPCHF    0.051821
# NZDCAD    0.051089
# EURGBP    0.049376
# GBPAUD    0.049287
# USDCHF    0.048337
# CHFJPY    0.047046
# NZDCHF    0.046625
# NZDUSD    0.044323
# EURAUD    0.042958
# EURCAD    0.042327
# AUDJPY    0.040039
# EURUSD    0.039772
# AUDCHF    0.039639
# CADCHF    0.038954
# CADJPY    0.038049
# GBPJPY    0.035676
# EURJPY    0.034934
# USDJPY    0.032521
