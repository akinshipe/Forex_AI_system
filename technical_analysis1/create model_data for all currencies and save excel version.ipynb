# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np


currency_list = [
#                  'USDCHF10080',                 
              #'GBPUSD10080',
                  #'EURUSD10080',
    #'USDJPY10080', 
    #'USDCAD10080', 
    #'AUDUSD10080',
    #'NZDUSD10080',
                  #'GBPCHF10080', 
    #'EURCHF10080', 
    #'CHFJPY10080',
    #'CADCHF10080', 
    #'AUDCHF10080', 
    #'NZDCHF10080', 
    'EURGBP10080',
           #     'GBPJPY10080', 
    #'GBPCAD10080',
    #'GBPAUD10080',
    #'EURJPY10080',
    #'EURCAD10080', 
    #'EURAUD10080', 
    
        #'EURNZD10080',
                  # 'AUDJPY10080',
    #'AUDJPY10080', 
    #'NZDJPY10080',
    #'AUDCAD10080',
    #'NZDCAD10080', 
                #'AUDNZD10080'
                ]

# %%
# read data frame from excel
original_data = pd.read_excel('files/combine_data_dataframe.xlsx', sheet_name=0)

print(original_data)

#loop through all currenct so as to populate model training data for each currenct and save as excel file
for x in currency_list:
    
    #copies original data so as not to mutate it
    data = original_data.copy( deep = True)
    
    next_week_data = []
    
    #picks the data for that currency and populate nextweek columns with it
    next_week_data = data[x +'_class'].to_list()
   
    #  shifts the row down by 1 step so as to have nextweek data on the same row ith this week data
   
    next_week_data.insert(0,0)
    next_week_data.pop()
    
    # creates a data frame of the nextweek data and populate it 
    next_week_data_frame = pd.DataFrame( columns = ['nextweek_class',])
    
   
    
    next_week_data_frame['nextweek_class'] = next_week_data
    
   
   
    #join the two dataframe togeter
    data = pd.concat([ next_week_data_frame  , data], axis=1, )
    
     #deletes the column 4 the column 4 is a duplicate of the index when two dataframes where concated together   
    data.drop(data.columns[1], axis=1, inplace=True)
    
    
    #deletes the first row of the column as it has invalid data for nextweek forecast
    data = data.iloc[1: , :]
    
    
    
    
    
    
    

    
    
    #data for each currency is exported to different excel files
    
    data.to_excel("files/currency_training_data/" + x.replace('10080','') + "_combine_data_dataframe.xlsx") 
    
    print(x) 
data.describe()
# Out:
#       Unnamed: 0 date_start  USDCAD10080_volume  USDCAD10080_class  \
# 0              0 1993-05-16                4575                -12
# 1              1 1993-05-23                4525                  8
# 2              2 1993-05-30                3575                  9
# 3              3 1993-06-06                4885                  3
# 4              4 1993-06-13                3895                 -6
# ...          ...        ...                 ...                ...
# 1411        1411 2021-08-01              241289                 16
# 1412        1412 2021-08-08              203604                 -4
# 1413        1413 2021-08-15              273555                 30
# 1414        1414 2021-08-22              233704                -20
# 1415        1415 2021-08-29              262700                -12
#
#       CADCHF10080_volume  CADCHF10080_class  EURGBP10080_volume  \
# 0                      3                -18                4165
# 1                      5                -36                4685
# 2                      5                 20                4215
# 3                      5                 12                5075
# 4                      5                 36                5325
# ...                  ...                ...                 ...
# 1411              130402                  3              207898
# 1412              115034                 12              176495
# 1413              151310                -24              195055
# 1414              141727                 24              181066
# 1415              144869                 24              182071
#
#       EURGBP10080_class
# 0                   -20
# 1                     8
# 2                     9
# 3                   -24
# 4                   -24
# ...                 ...
# 1411                 -4
# 1412                  6
# 1413                 20
# 1414                 -2
# 1415                  4
#
# [1416 rows x 8 columns]
# EURGBP10080
#        nextweek_class  USDCAD10080_volume  USDCAD10080_class  \
# count     1415.000000        1.415000e+03        1415.000000
# mean        -0.049470        1.614477e+05           0.867845
# std         12.354916        1.999916e+05          14.447884
# min        -30.000000        1.180000e+02         -36.000000
# 25%         -9.000000        1.663550e+04          -9.000000
# 50%         -1.000000        4.607300e+04           1.000000
# 75%          9.000000        2.575760e+05          12.000000
# max         36.000000        1.024602e+06          36.000000
#
#        CADCHF10080_volume  CADCHF10080_class  EURGBP10080_volume  \
# count        1.415000e+03        1415.000000        1.415000e+03
# mean         1.582201e+05           0.476325        1.833765e+05
# std          1.919912e+05          15.302396        2.163341e+05
# min          5.000000e+00         -36.000000        7.300000e+01
# 25%          9.440000e+02         -10.000000        2.381250e+04
# 50%          6.034000e+04           1.000000        4.484600e+04
# 75%          2.900400e+05          12.000000        2.936745e+05
# max          1.024835e+06          36.000000        1.019557e+06
#
#        EURGBP10080_class
# count        1415.000000
# mean           -0.032509
# std            12.343977
# min           -30.000000
# 25%            -9.000000
# 50%            -1.000000
# 75%             9.000000
# max            36.000000
