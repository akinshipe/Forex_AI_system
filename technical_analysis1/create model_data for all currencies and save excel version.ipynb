# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np


currency_list = [
                  'USDCHF1440',                 
              #'GBPUSD1440',
                  #'EURUSD1440',
    #'USDJPY1440', 
    #'USDCAD1440', 
    #'AUDUSD1440',
    #'NZDUSD1440',
                  #'GBPCHF1440', 
    #'EURCHF1440', 
    #'CHFJPY1440',
    #'CADCHF1440', 
    #'AUDCHF1440', 
    #'NZDCHF1440', 
    #'EURGBP1440',
           #     'GBPJPY1440', 
    #'GBPCAD1440',
    #'GBPAUD1440',
    #'EURJPY1440',
    #'EURCAD1440', 
    #'EURAUD1440', 
    
        #'EURNZD1440',
                  # 'AUDJPY1440',
    #'AUDJPY1440', 
    #'NZDJPY1440',
    #'AUDCAD1440',
    #'NZDCAD1440', 
                #'AUDNZD1440'
                ]

# %%
# read data frame from excel
original_data = pd.read_excel('files/combine_data_dataframe.xlsx', sheet_name=0)

print(original_data)

#loop through all currenct so as to populate model training data for each currenct and save as excel file
for x in currency_list:
    
    #copies original data so as not to mutate it
    data = original_data.copy( deep = True)
    
    next_week_data = []
    
    #picks the data for that currency and populate nextweek columns with it
    next_week_data = data[x +'_class'].to_list()
   
    #  shifts the row down by 1 step so as to have nextweek data on the same row ith this week data
   
    next_week_data.insert(0,0)
    next_week_data.pop()
    
    # creates a data frame of the nextweek data and populate it 
    next_week_data_frame = pd.DataFrame( columns = ['nextweek_class',])
    
   
    
    next_week_data_frame['nextweek_class'] = next_week_data
    
   
   
    #join the two dataframe togeter
    data = pd.concat([ next_week_data_frame  , data], axis=1, )
    
     #deletes the column 4 the column 4 is a duplicate of the index when two dataframes where concated together   
    data.drop(data.columns[1], axis=1, inplace=True)
    
    
    #deletes the first row of the column as it has invalid data for nextweek forecast
    data = data.iloc[1: , :]
    
    
    
    
    
    
    

    
    
    #data for each currency is exported to different excel files
    
    data.to_excel("files/currency_training_data/" + x.replace('10080','') + "_combine_data_dataframe.xlsx") 
    
    print(x) 
data.describe()
# Out:
#       Unnamed: 0 date_start  USDCHF1440_volume  USDCHF1440_class  \
# 0              0 1987-01-02               1401                12
# 1              1 1987-01-05               3301                16
# 2              2 1987-01-06               2251               -30
# 3              3 1987-01-07               3101                16
# 4              4 1987-01-08               3701               -12
# ...          ...        ...                ...               ...
# 8877        8877 2021-09-21              34219                -8
# 8878        8878 2021-09-22              45315                 4
# 8879        8879 2021-09-23              37632                -2
# 8880        8880 2021-09-24              27809                 2
# 8881        8881 2021-09-27                  5                 6
#
#       USDCHF1440_day
# 0                  5
# 1                  1
# 2                  2
# 3                  3
# 4                  4
# ...              ...
# 8877               2
# 8878               3
# 8879               4
# 8880               5
# 8881               1
#
# [8882 rows x 5 columns]
# USDCHF1440
#        nextweek_class  USDCHF1440_volume  USDCHF1440_class  USDCHF1440_day
# count     8881.000000        8881.000000       8881.000000     8881.000000
# mean         0.324738       26433.004954          0.324063        2.998311
# std         12.583610       31535.228071         12.583144        1.414412
# min        -36.000000           1.000000        -36.000000        1.000000
# 25%         -8.000000        3051.000000         -8.000000        2.000000
# 50%          1.000000       11374.000000          1.000000        3.000000
# 75%          9.000000       43153.000000          9.000000        4.000000
# max         36.000000      231739.000000         36.000000        6.000000
