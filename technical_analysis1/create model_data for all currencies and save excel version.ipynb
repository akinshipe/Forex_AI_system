# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np


currency_list = [
#                  'USDCHF10080',                 
              #'GBPUSD10080',
                  #'EURUSD10080',
    #'USDJPY10080', 
    #'USDCAD10080', 
    #'AUDUSD10080',
    #'NZDUSD10080',
                  #'GBPCHF10080', 
    #'EURCHF10080', 
    #'CHFJPY10080',
    #'CADCHF10080', 
    #'AUDCHF10080', 
    #'NZDCHF10080', 
    'EURGBP10080',
           #     'GBPJPY10080', 
    #'GBPCAD10080',
    #'GBPAUD10080',
    #'EURJPY10080',
    #'EURCAD10080', 
    #'EURAUD10080', 
    
        #'EURNZD10080',
                  # 'AUDJPY10080',
    #'AUDJPY10080', 
    #'NZDJPY10080',
    #'AUDCAD10080',
    #'NZDCAD10080', 
                #'AUDNZD10080'
                ]

# %%
# read data frame from excel
original_data = pd.read_excel('files/combine_data_dataframe.xlsx', sheet_name=0)

print(original_data)

#loop through all currenct so as to populate model training data for each currenct and save as excel file
for x in currency_list:
    
    #copies original data so as not to mutate it
    data = original_data.copy( deep = True)
    
    next_week_data = []
    
    #picks the data for that currency and populate nextweek columns with it
    next_week_data = data[x +'_class'].to_list()
   
    #  shifts the row down by 1 step so as to have nextweek data on the same row ith this week data
   
    next_week_data.insert(0,0)
    next_week_data.pop()
    
    # creates a data frame of the nextweek data and populate it 
    next_week_data_frame = pd.DataFrame( columns = ['nextweek_class',])
    
   
    
    next_week_data_frame['nextweek_class'] = next_week_data
    
   
   
    #join the two dataframe togeter
    data = pd.concat([ next_week_data_frame  , data], axis=1, )
    
     #deletes the column 4 the column 4 is a duplicate of the index when two dataframes where concated together   
    data.drop(data.columns[1], axis=1, inplace=True)
    
    
    #deletes the first row of the column as it has invalid data for nextweek forecast
    data = data.iloc[1: , :]
    
    
    
    
    
    
    

    
    
    #data for each currency is exported to different excel files
    
    data.to_excel("files/currency_training_data/" + x.replace('10080','') + "_combine_data_dataframe.xlsx") 
    
    print(x) 
data.describe()
# Out:
#      Unnamed: 0 date_start  CADCHF10080_volume  CADCHF10080_class  \
# 0             0 2007-08-19               63886                  4
# 1             1 2007-08-26               60259                  2
# 2             2 2007-09-02               52045                -10
# 3             3 2007-09-09               65823                 20
# 4             4 2007-09-16               75100                 20
# ..          ...        ...                 ...                ...
# 709         709 2021-08-01              130402                  3
# 710         710 2021-08-08              115034                 12
# 711         711 2021-08-15              151310                -24
# 712         712 2021-08-22              141727                 24
# 713         713 2021-08-29              144869                 24
#
#      NZDCHF10080_volume  NZDCHF10080_class  EURGBP10080_volume  \
# 0                 27017                 25               19245
# 1                 21985                -30               18995
# 2                 26287                -25               16108
# 3                 41536                 30               18578
# 4                 59708                 10               21895
# ..                  ...                ...                 ...
# 709              162419                 24              207898
# 710              139853                 18              176495
# 711              171738                -30              195055
# 712              150887                 16              181066
# 713              124706                 25              182071
#
#      EURGBP10080_class
# 0                   -2
# 1                   -6
# 2                    4
# 3                   20
# 4                   15
# ..                 ...
# 709                 -4
# 710                  6
# 711                 20
# 712                 -2
# 713                  4
#
# [714 rows x 8 columns]
# EURGBP10080
#        nextweek_class  CADCHF10080_volume  CADCHF10080_class  \
# count      713.000000        7.130000e+02         713.000000
# mean         0.528752        3.082437e+05           0.872370
# std         13.042156        1.645626e+05          14.615454
# min        -30.000000        1.658500e+04         -36.000000
# 25%         -9.000000        1.868210e+05          -9.000000
# 50%          1.000000        2.892390e+05           1.000000
# 75%          9.000000        3.868840e+05          12.000000
# max         36.000000        1.024835e+06          36.000000
#
#        NZDCHF10080_volume  NZDCHF10080_class  EURGBP10080_volume  \
# count          713.000000         713.000000        7.130000e+02
# mean        258672.022440           1.084151        3.406428e+05
# std         127167.913549          14.139203        2.042418e+05
# min          12107.000000         -36.000000        1.250900e+04
# 25%         171216.000000          -9.000000        2.148840e+05
# 50%         246550.000000           1.000000        2.930700e+05
# 75%         326879.000000          12.000000        4.323460e+05
# max         889936.000000          30.000000        1.019557e+06
#
#        EURGBP10080_class
# count         713.000000
# mean            0.537167
# std            13.042458
# min           -30.000000
# 25%            -9.000000
# 50%             1.000000
# 75%             9.000000
# max            36.000000
