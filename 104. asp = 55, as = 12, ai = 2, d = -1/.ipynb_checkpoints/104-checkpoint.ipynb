# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime, timedelta

all_currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]



headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
raw_df = pd.read_csv("../raw_weekly_data/NZDCAD10080.csv", names = headers )



needed_weeks_df = raw_df.loc[(raw_df['date'] >= "2015.01.01")   ]   



needed_weeks_df = needed_weeks_df.reset_index(drop=True)



available_weeks = needed_weeks_df['date'].values



#print(raw_df)
print(available_weeks)

# %%
for y in available_weeks:
    
    current_date = datetime.strptime(y, '%Y.%m.%d').strftime('%A')
    
    if current_date != 'Sunday':
        available_weeks = [x for x in available_weeks if x != y]
        print('error-----------------------------', y, ' did is not a sunday')
        
        raise Exception('error-----------------------------', y, ' did is not a sunday')

# %%
for a in available_weeks:
  
  
    path = "./files/" + a

    try: 
        os.makedirs(path)
        control_file = pd.DataFrame()
        
        for  b in range(8):
            control_file['control' + str(b)] = -1
            
            
        control_file.to_csv(path + '/control.csv')
        
        

    except OSError as error: 
         raise Exception(error)

# %%
all_currency_pair_df = []

for d in all_currency_pairs:
    
    current_currency_df = pd.read_csv("../raw_weekly_data/" + d + ".csv", names = headers ) 
    
    
    
    current_currency_df = current_currency_df.iloc[::-1]
    
    
    current_currency_df = current_currency_df.reset_index(drop=True)
    
   
      
    current_currency_df = {'name': d.replace('10080',''),'dataframe': current_currency_df }
    
    
    
    all_currency_pair_df.append(current_currency_df)
    

print(all_currency_pair_df)

# %%
acceptable_signal_percent = 70

analysis_span = 52

analysis_interval = 3

no_of_weeks_analysis = [c for c in range(0, analysis_span, analysis_interval)]

all_time_next_week_trade =[]

for e in available_weeks:
    
    next_week_trade = []

    for f in all_currency_pair_df:
        
        
        current_currency_df = f['dataframe'].copy(deep = True)
        
        

        current_currency_df = current_currency_df.loc[(current_currency_df['date'] <= e )   ] 
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True)
        
        

        current_currency_df = current_currency_df.head(analysis_span)
        
        
        
        #print(f['name'], current_currency_df)

        needed_value_list = []
        
        needed_direction_list = []
        
        for g in no_of_weeks_analysis:
            
            needed_value = current_currency_df.copy()['close'][g]
            
            
            needed_value_list.append(needed_value)
            
          
        
        #print(f['name'], needed_value_list)
       
        
        for index, h in enumerate(needed_value_list):
            
            if index == 0:
                
                continue
                
            if h - needed_value_list[index-1] > 0 :
                
                needed_direction_list.append('S')
            
            else:
                
                needed_direction_list.append('B')
                
                
        #print(f['name'],needed_direction_list)  
        
        if (100 * needed_direction_list.count('S') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'S'})
        
        if ( 100 * needed_direction_list.count('B') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'B'})
    
    
    
    if len(next_week_trade) > 0:
        
        all_time_next_week_trade.append( {'week': e, 'next_week_trades': next_week_trade} )
    
    
    
    
    print('--------------------------------------------------------------------------------------------', e )
    #print(next_week_trade)
    #print(len(next_week_trade))
    
    
    
if len(all_time_next_week_trade) == 0:
             
    raise Exception("no week passed the acceptable_signal_percent ")
        
        
    
print(len(all_time_next_week_trade))

# %%
# creating a nextweek trades dataframe for each week and saving the dataframe in that week'd folder

for i in all_time_next_week_trade:
    
    current_week_data = i['next_week_trades']
    current_week_name = i['week']
    
    
    
    currency_name =[]
    trade_direction = []
    
    for j in current_week_data:
        
        currency_name.append(j['name'])
        trade_direction.append(j['direction'])       
          
    
    next_week_trades_dataframe = pd.DataFrame()
    next_week_trades_dataframe['name']= currency_name
    next_week_trades_dataframe['direction'] = trade_direction
    
    
    print(next_week_trades_dataframe)

    next_week_trades_dataframe.to_csv("files/" + current_week_name + '/next_week_trades.csv')

# %%
#loading 30 minutes data for all currency in to memeory to spead up processing

all_currency_thirty_minutes_data = {}

for z in all_currency_pairs:
    current_currency = z.replace('10080','')
    current_currency_df = pd.read_csv('../raw_30_minutes_data/' + current_currency + '30.csv', names=headers ) 
    
    all_currency_thirty_minutes_data[current_currency] = current_currency_df
    
    #print( current_currency, )
    
    
print(len(all_currency_thirty_minutes_data))

# %%
qualified_weeks =[]

for k in all_time_next_week_trade:
    
    current_week_data = k['next_week_trades']
    current_week_date = k['week']
    
    current_week_date = datetime.strptime(current_week_date, '%Y.%m.%d')

    week_start_date  = current_week_date + timedelta(days=7)
    week_end_date = current_week_date + timedelta(days=12)
    
    current_week_date = current_week_date.strftime("%Y.%m.%d")
    week_start_date = week_start_date.strftime("%Y.%m.%d")
    week_end_date = week_end_date.strftime("%Y.%m.%d")      

    
    

    #print(current_week_date, week_start_date, week_end_date)
    
    qualified_currencies = 0
   
    for l in current_week_data:
        
        
        current_currency = l['name'] 
        
        current_currency_df = all_currency_thirty_minutes_data[current_currency].copy()
        
        
        
        
        current_currency_df = current_currency_df.loc[  (current_currency_df['date'] >= week_start_date)
                                                   
                                                                                 & 
                                                              (current_currency_df['date'] <= week_end_date)
                                                            ]  
    
        
        
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True )
        
        #print( current_currency, week_start_date, week_end_date, current_currency_df)
       
        
       
        current_currency_dataframe_row_ammount = len(current_currency_df.index)
        
        if  current_currency_dataframe_row_ammount < 238:
            
            print(current_currency,len(current_currency_df),week_start_date,'less than 238, skipping ',current_week_date)
            break
            
            
            #raise Exception("lenght is lesss than 238")
            
            
        
        if  current_currency_dataframe_row_ammount != 240:
            
           
            
            if (current_currency_df['ignore'].tail(1).values == '22:30' ):
                
              
                
                last_row = current_currency_df.copy().tail(1)
                
                
                
                last_row.tail()['ignore'] = '23:00'
                
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
               
                
                
                last_row.tail()['ignore'] = '23:30'
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
              
                
                #print(current_currency, current_currency_df)
                
                if  len(current_currency_df.index) != 240:
              
                    print(current_currency, current_currency_df)
                    raise Exception("number of rows is still wrong after repair")
        
            else:
                
                print(current_currency,len(current_currency_df),week_start_date,"irrepairable,skipping ",current_week_date)
                break
        
        if current_currency_df['ignore'].iloc[-1] != '23:30' :
        
            print(current_currency, current_currency_df)
            raise Exception("last row is not 23:30")
        
        
      
        
        
       
        current_currency_df.to_csv("files/" + k['week'] + '/' + current_currency +".csv", index=None)
        
        qualified_currencies = qualified_currencies +1
        
        
        
    if qualified_currencies == len(current_week_data):
            
        qualified_weeks.append(k)
        
    
   
        
        #print(current_currency_df)
        
        
        
    #print('-----------------------------------------------------------------------------------------------', week_start_date)


print(len(qualified_weeks))

# %%
timeframe = []
trade_values = []
unique_time_frames = []

for m in qualified_weeks:

    
    
    current_week = m['week']
   
    current_week_data = m['next_week_trades']
    
    current_week_drawdown_df = pd.DataFrame()
    
    current_week_profit = pd.DataFrame()
  

    
    
    for index, n in enumerate(current_week_data):
        
        
        
        current_currency = n['name']
        current_currency_direction = n['direction']
        current_currency_df =  pd.read_csv("files/" + current_week + '/' + current_currency +".csv" ) 
        
       
        
        
        # adding timeframe to the maximal draw down and profit df
        if index == 0:
            
            current_week_drawdown_df['date'] = current_currency_df['date']
            current_week_profit['date'] = current_currency_df['date']
           
            #saving unique_timeframes in a week to use later in the script
            if len(unique_time_frames) == 0:
                
                unique_time_frames = current_currency_df['ignore'].values
                
                
        
        
        #print(current_currency_df)
        maximal_draw_down =[]
        profit = []
        pips_corrector = 100000
            
        if current_currency.endswith('JPY'):
                
            pips_corrector = 1000
            
        
        
        
        for o in range(240):
                   
            if current_currency_direction == 'B':
                
                
                dd = current_currency_df.loc[o,'low'] - current_currency_df.loc[0,'open']
                p = current_currency_df.loc[o,'close'] - current_currency_df.loc[0,'open']
              
            if current_currency_direction == 'S':
                
                
                dd = current_currency_df.loc[0,'open'] - current_currency_df.loc[o,'high']
                p = current_currency_df.loc[0,'open'] - current_currency_df.loc[o,'close']
            
            
            maximal_draw_down.append(dd*pips_corrector)
            profit.append(p*pips_corrector)
                
        
        current_week_drawdown_df[current_currency] = maximal_draw_down
        current_week_profit[current_currency] = profit
            
    current_week_drawdown_df['empty'] = ['' for p in range(240)]      
    current_week_drawdown_df["sum"] = current_week_drawdown_df.drop(["empty", 'date'], axis=1, inplace=False).sum(axis=1)        
    
    current_week_drawdown_df.to_csv("files/" + current_week + '/' + 'maximal_draw_down.csv', index= None)
    
    
    
    current_week_profit['empty'] = ['' for p in range(240)]      
    current_week_profit["sum"] = current_week_profit.drop(["empty", 'date'], axis=1, inplace=False).sum(axis=1)        
    
    current_week_profit.to_csv("files/" + current_week + '/' + 'profit.csv', index= None)
    
    
    
    #print(current_week_drawdown_df)
        
    
    
    
    
    
    
    
    
    
    print('--------------------------------------------------------------------------------------------------', m)   
    
    
#print(current_week_drawdown_df)
#print(current_week_profit)

print(unique_time_frames)
# Out:
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.08', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.15', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.08', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.15', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CADCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.12', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.03', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.17', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.24', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.31', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.07', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.21', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.28', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.05', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.12', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.19', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.26', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.02', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.09', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.16', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.23', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.30', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.13', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.20', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.27', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.11', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.18', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.25', 'next_week_trades': [{'name': 'GBPAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.08', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.29', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.06', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.27', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.03', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.10', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.24', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.02.14', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.20', 'next_week_trades': [{'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.03', 'next_week_trades': [{'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.10', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.24', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.01', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.22', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.05', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.12', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.26', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.03', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.10', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.17', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.24', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.31', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.07', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.14', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.21', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.28', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.04', 'next_week_trades': [{'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.18', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.25', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.16', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.23', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.30', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.06', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.13', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.20', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.27', 'next_week_trades': [{'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.12.04', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.12.25', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.01.08', 'next_week_trades': [{'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.01.15', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.02.05', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.02.26', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.05', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.19', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.26', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.09', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.16', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.23', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.30', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.07', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.14', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.21', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.28', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.04', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.11', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.18', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.25', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.02', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.09', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.16', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.23', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.30', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.06', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.13', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.20', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.10', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.17', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.24', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.01', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.08', 'next_week_trades': [{'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.29', 'next_week_trades': [{'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.05', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.19', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.26', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.12.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.12.31', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.07', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.21', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.28', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.04', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.18', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.25', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.11', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.25', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.01', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.08', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.29', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.06', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.13', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.20', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.27', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.06.10', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.06.17', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.01', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.08', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.15', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.12', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.02', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.16', 'next_week_trades': [{'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.23', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.30', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.10.14', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.10.21', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.11.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.11.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.02', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.09', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.30', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.13', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.20', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.03', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.10', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.17', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.24', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.03', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.17', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.24', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.31', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.07', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.14', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.21', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.28', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.05', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.12', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.19', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.26', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.02', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.09', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.16', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.23', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.30', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.07', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.14', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.21', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.28', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.08.04', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# ...
# -------------------------------------------------------------------------------------------------- {'week': '2021.03.14', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CADCHF', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.03.21', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.03.28', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.04', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.11', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.18', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.02', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.16', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.23', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.30', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.13', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.20', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.27', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.04', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.18', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.25', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.01', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.08', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.15', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.29', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.05', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.12', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.19', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.26', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.03', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.10', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.17', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.24', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.31', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.07', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.21', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# ['00:00' '00:30' '01:00' '01:30' '02:00' '02:30' '03:00' '03:30' '04:00'
#  '04:30' '05:00' '05:30' '06:00' '06:30' '07:00' '07:30' '08:00' '08:30'
#  '09:00' '09:30' '10:00' '10:30' '11:00' '11:30' '12:00' '12:30' '13:00'
#  '13:30' '14:00' '14:30' '15:00' '15:30' '16:00' '16:30' '17:00' '17:30'
#  '18:00' '18:30' '19:00' '19:30' '20:00' '20:30' '21:00' '21:30' '22:00'
#  '22:30' '23:00' '23:30' '00:00' '00:30' '01:00' '01:30' '02:00' '02:30'
#  '03:00' '03:30' '04:00' '04:30' '05:00' '05:30' '06:00' '06:30' '07:00'
#  '07:30' '08:00' '08:30' '09:00' '09:30' '10:00' '10:30' '11:00' '11:30'
#  '12:00' '12:30' '13:00' '13:30' '14:00' '14:30' '15:00' '15:30' '16:00'
#  '16:30' '17:00' '17:30' '18:00' '18:30' '19:00' '19:30' '20:00' '20:30'
#  '21:00' '21:30' '22:00' '22:30' '23:00' '23:30' '00:00' '00:30' '01:00'
#  '01:30' '02:00' '02:30' '03:00' '03:30' '04:00' '04:30' '05:00' '05:30'
#  '06:00' '06:30' '07:00' '07:30' '08:00' '08:30' '09:00' '09:30' '10:00'
#  '10:30' '11:00' '11:30' '12:00' '12:30' '13:00' '13:30' '14:00' '14:30'
#  '15:00' '15:30' '16:00' '16:30' '17:00' '17:30' '18:00' '18:30' '19:00'
#  '19:30' '20:00' '20:30' '21:00' '21:30' '22:00' '22:30' '23:00' '23:30'
#  '00:00' '00:30' '01:00' '01:30' '02:00' '02:30' '03:00' '03:30' '04:00'
#  '04:30' '05:00' '05:30' '06:00' '06:30' '07:00' '07:30' '08:00' '08:30'
#  '09:00' '09:30' '10:00' '10:30' '11:00' '11:30' '12:00' '12:30' '13:00'
#  '13:30' '14:00' '14:30' '15:00' '15:30' '16:00' '16:30' '17:00' '17:30'
#  '18:00' '18:30' '19:00' '19:30' '20:00' '20:30' '21:00' '21:30' '22:00'
#  '22:30' '23:00' '23:30' '00:00' '00:30' '01:00' '01:30' '02:00' '02:30'
#  '03:00' '03:30' '04:00' '04:30' '05:00' '05:30' '06:00' '06:30' '07:00'
#  '07:30' '08:00' '08:30' '09:00' '09:30' '10:00' '10:30' '11:00' '11:30'
#  '12:00' '12:30' '13:00' '13:30' '14:00' '14:30' '15:00' '15:30' '16:00'
#  '16:30' '17:00' '17:30' '18:00' '18:30' '19:00' '19:30' '20:00' '20:30'
#  '21:00' '21:30' '22:00' '22:30' '23:00' '23:30']

# %%
day_time_frames = []

for index, w in enumerate(unique_time_frames):
    
    if index >= 192: 
        day = 'FRI'  
        day_time_frames.append(day + ' ' + w)
        
    elif index >= 144: 
        day = 'THUR'  
        day_time_frames.append(day + ' ' + w)
00', 'THUR 02:30', 'THUR 03:00', 'THUR 03:30', 'THUR 04:00', 'THUR 04:30', 'THUR 05:00', 'THUR 05:30', 'THUR 06:00', 'THUR 06:30', 'THUR 07:00', 'THUR 07:30', 'THUR 08:00', 'THUR 08:30', 'THUR 09:00', 'THUR 09:30', 'THUR 10:00', 'THUR 10:30', 'THUR 11:00', 'THUR 11:30', 'THUR 12:00', 'THUR 12:30', 'THUR 13:00', 'THUR 13:30', 'THUR 14:00', 'THUR 14:30', 'THUR 15:00', 'THUR 15:30', 'THUR 16:00', 'THUR 16:30', 'THUR 17:00', 'THUR 17:30', 'THUR 18:00', 'THUR 18:30', 'THUR 19:00', 'THUR 19:30', 'THUR 20:00', 'THUR 20:30', 'THUR 21:00', 'THUR 21:30', 'THUR 22:00', 'THUR 22:30', 'THUR 23:00', 'THUR 23:30', 'FRI 00:00', 'FRI 00:30', 'FRI 01:00', 'FRI 01:30', 'FRI 02:00', 'FRI 02:30', 'FRI 03:00', 'FRI 03:30', 'FRI 04:00', 'FRI 04:30', 'FRI 05:00', 'FRI 05:30', 'FRI 06:00', 'FRI 06:30', 'FRI 07:00', 'FRI 07:30', 'FRI 08:00', 'FRI 08:30', 'FRI 09:00', 'FRI 09:30', 'FRI 10:00', 'FRI 10:30', 'FRI 11:00', 'FRI 11:30', 'FRI 12:00', 'FRI 12:30', 'FRI 13:00', 'FRI 13:30', 'FRI 14:00', 'FRI 14:30', 'FRI 15:00', 'FRI 15:30', 'FRI 16:00', 'FRI 16:30', 'FRI 17:00', 'FRI 17:30', 'FRI 18:00', 'FRI 18:30', 'FRI 19:00', 'FRI 19:30', 'FRI 20:00', 'FRI 20:30', 'FRI 21:00', 'FRI 21:30', 'FRI 22:00', 'FRI 22:30', 'FRI 23:00', 'FRI 23:30']

# %%
#combining all maximal drawdowns for all weeks
combine_week_drawdown_df = pd.DataFrame()

combine_week_drawdown_df['date'] = day_time_frames

for index, q in enumerate(qualified_weeks):
    
    current_week = q['week']
    current_week_dd_df = pd.read_csv("files/" + current_week + '/' + 'maximal_draw_down' +".csv" ) 
    #print(current_week_dd_df)
    
   
    combine_week_drawdown_df[current_week] = current_week_dd_df['sum']
    

combine_week_drawdown_df['empty'] = ['' for r in range(240)]      
combine_week_drawdown_df["sum"] = combine_week_drawdown_df.drop(["empty",'date' ], axis=1, inplace=False).sum(axis=1)        

combine_week_drawdown_df.to_csv("files/" + 'combine_week_drawdown_df.csv', index= None)

print(combine_week_drawdown_df)

# %%
#combining all profits drawdowns for all weeks
combine_week_profit_df = pd.DataFrame()

combine_week_profit_df['date'] = day_time_frames

for index, q in enumerate(qualified_weeks):
    
    current_week = q['week']
    current_week_profit_df = pd.read_csv("files/" + current_week + '/' + 'profit' +".csv" ) 
    #print(current_week_dd_df)
    
   
    combine_week_profit_df[current_week] = current_week_profit_df['sum']
    

combine_week_profit_df['empty'] = ['' for r in range(240)]      
combine_week_profit_df["sum"] = combine_week_profit_df.drop(["empty",'date' ], axis=1, inplace=False).sum(axis=1)        

combine_week_profit_df.to_csv("files/" + 'combine_week_profit_df.csv', index= None)

print(combine_week_profit_df)

# %%
#loading all profit and drawdown dataframe to memory to speed up processing

qualified_weeks_dfs=[]

for v in qualified_weeks:
    
    current_week = v['week']

    current_week_profit_df = pd.read_csv("files/" + current_week + '/profit.csv')
    current_week_drawdown_df = pd.read_csv("files/" + current_week + '/maximal_draw_down.csv')
    
    qualified_weeks_dfs.append( 
                                { 'week': current_week,
                                   'profit_df' : current_week_profit_df,
                                   'drawdown_df': current_week_drawdown_df
                                }
                                )
    

print(qualified_weeks_dfs)
# Out:
# [{'week': '2015.01.11', 'profit_df':            date  EURUSD  EURCHF  EURGBP  EURCAD  empty     sum
# 0    2015.01.19   -89.0   -27.0   -37.0   -96.0    NaN  -249.0
# 1    2015.01.19  -111.0   -28.0   -58.0   -96.0    NaN  -293.0
# 2    2015.01.19  -112.0  -267.0   -12.0  -102.0    NaN  -493.0
# 3    2015.01.19   -80.0   242.0    -6.0    -5.0    NaN   151.0
# 4    2015.01.19   -65.0   200.0    13.0    48.0    NaN   196.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.01.23  3069.0   820.0  1462.0 -1291.0    NaN  4060.0
# 236  2015.01.23  3203.0   906.0  1473.0 -1100.0    NaN  4482.0
# 237  2015.01.23  3453.0   845.0  1634.0  -806.0    NaN  5126.0
# 238  2015.01.23  3433.0   761.0  1585.0  -982.0    NaN  4797.0
# 239  2015.01.23  3492.0  1211.0  1625.0  -671.0    NaN  5657.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  EURUSD  EURCHF  EURGBP  EURCAD  empty     sum
# 0    2015.01.19  -145.0   -54.0  -107.0  -154.0    NaN  -460.0
# 1    2015.01.19  -126.0   -91.0   -82.0  -122.0    NaN  -421.0
# 2    2015.01.19  -201.0  -322.0   -72.0  -199.0    NaN  -794.0
# 3    2015.01.19  -204.0  -292.0   -71.0  -159.0    NaN  -726.0
# 4    2015.01.19  -127.0   186.0   -26.0   -56.0    NaN   -23.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.01.23  3068.0   704.0  1448.0 -1355.0    NaN  3865.0
# 236  2015.01.23  3052.0   797.0  1443.0 -1309.0    NaN  3983.0
# 237  2015.01.23  3204.0   845.0  1474.0 -1100.0    NaN  4423.0
# 238  2015.01.23  3189.0   681.0  1429.0 -1123.0    NaN  4176.0
# 239  2015.01.23  3360.0   675.0  1539.0 -1089.0    NaN  4485.0
#
# [240 rows x 7 columns]}, {'week': '2015.01.18', 'profit_df':            date  EURUSD  EURCHF  EURGBP  empty     sum
# 0    2015.01.26    75.0   -44.0   112.0    NaN   143.0
# 1    2015.01.26    67.0    32.0    92.0    NaN   191.0
# 2    2015.01.26   241.0   283.0   157.0    NaN   681.0
# 3    2015.01.26    80.0    53.0    47.0    NaN   180.0
# 4    2015.01.26  -292.0   -22.0   -96.0    NaN  -410.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.01.30 -1417.0 -5363.0  -636.0    NaN -7416.0
# 236  2015.01.30 -1431.0 -5506.0  -654.0    NaN -7591.0
# 237  2015.01.30 -1497.0 -5550.0  -664.0    NaN -7711.0
# 238  2015.01.30 -1413.0 -5607.0  -538.0    NaN -7558.0
# 239  2015.01.30 -1352.0 -5757.0  -573.0    NaN -7682.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  EURUSD  EURCHF  EURGBP  empty     sum
# 0    2015.01.26   -66.0   -51.0    -1.0    NaN  -118.0
# 1    2015.01.26     8.0   -84.0    23.0    NaN   -53.0
# 2    2015.01.26     9.0    -1.0    76.0    NaN    84.0
# 3    2015.01.26    68.0    48.0    41.0    NaN   157.0
# 4    2015.01.26  -512.0  -183.0  -209.0    NaN  -904.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.01.30 -1509.0 -6255.0  -696.0    NaN -8460.0
# 236  2015.01.30 -1490.0 -5555.0  -671.0    NaN -7716.0
# 237  2015.01.30 -1656.0 -5582.0  -747.0    NaN -7985.0
# 238  2015.01.30 -1502.0 -5707.0  -664.0    NaN -7873.0
# 239  2015.01.30 -1421.0 -5757.0  -650.0    NaN -7828.0
#
# [240 rows x 6 columns]}, {'week': '2015.01.25', 'profit_df':            date  GBPUSD  EURUSD  EURGBP  empty    sum
# 0    2015.02.02    72.0    59.0     1.0    NaN  132.0
# 1    2015.02.02    48.0     8.0   -34.0    NaN   22.0
# 2    2015.02.02   142.0    42.0   -72.0    NaN  112.0
# 3    2015.02.02   104.0    47.0   -47.0    NaN  104.0
# 4    2015.02.02   154.0    34.0   -86.0    NaN  102.0
# ..          ...     ...     ...     ...    ...    ...
# 235  2015.02.06 -1381.0   -71.0   605.0    NaN -847.0
# 236  2015.02.06 -1445.0  -100.0   612.0    NaN -933.0
# 237  2015.02.06 -1419.0   -81.0   613.0    NaN -887.0
# 238  2015.02.06 -1478.0   -92.0   636.0    NaN -934.0
# 239  2015.02.06 -1317.0    13.0   685.0    NaN -619.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  GBPUSD  EURUSD  EURGBP  empty     sum
# 0    2015.02.02   -49.0   -87.0   -77.0    NaN  -213.0
# 1    2015.02.02    43.0   -76.0  -106.0    NaN  -139.0
# 2    2015.02.02    46.0   -20.0  -103.0    NaN   -77.0
# 3    2015.02.02    82.0    27.0   -82.0    NaN    27.0
# 4    2015.02.02   106.0    33.0   -92.0    NaN    47.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.02.06 -1405.0   -80.0   565.0    NaN  -920.0
# 236  2015.02.06 -1506.0  -132.0   585.0    NaN -1053.0
# 237  2015.02.06 -1496.0  -110.0   594.0    NaN -1012.0
# 238  2015.02.06 -1509.0  -118.0   591.0    NaN -1036.0
# 239  2015.02.06 -1584.0  -117.0   615.0    NaN -1086.0
#
# [240 rows x 6 columns]}, {'week': '2015.02.08', 'profit_df':            date  USDCHF  EURUSD  GBPCHF  EURGBP  empty     sum
# 0    2015.02.16    45.0    10.0    12.0   -57.0    NaN    10.0
# 1    2015.02.16    55.0    14.0   -12.0   -67.0    NaN   -10.0
# 4    2015.02.23    85.0   142.0  -250.0    30.0   108.0    NaN   115.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2015.02.27  -556.0  1927.0  2268.0  1472.0  3300.0    NaN  8411.0
# 236  2015.02.27  -437.0  1998.0  2272.0  1469.0  3357.0    NaN  8659.0
# 237  2015.02.27  -430.0  2024.0  2232.0  1490.0  3399.0    NaN  8715.0
# 238  2015.02.27  -456.0  2012.0  2214.0  1474.0  3348.0    NaN  8592.0
# 239  2015.02.27  -464.0  1965.0  2215.0  1428.0  3309.0    NaN  8453.0
#
# [240 rows x 8 columns]}, {'week': '2015.02.22', 'profit_df':            date  USDCHF  EURUSD  GBPCHF  EURGBP  EURJPY  EURCAD  empty  \
# 0    2015.03.02    62.0   -49.0   134.0   -37.0    22.0   -78.0    NaN
# 1    2015.03.02    54.0    -5.0   134.0    -5.0    29.0   -44.0    NaN
# 2    2015.03.02   112.0   121.0    60.0   -13.0    74.0    48.0    NaN
# 3    2015.03.02   118.0   204.0    20.0    18.0   114.0   111.0    NaN
# 4    2015.03.02   207.0   148.0   185.0     4.0   -32.0    52.0    NaN
# ..          ...     ...     ...     ...     ...     ...     ...    ...
# 235  2015.03.06  3185.0  3248.0  1202.0   314.0  2834.0  2874.0    NaN
# 236  2015.03.06  3214.0  3324.0  1203.0   342.0  2879.0  2965.0    NaN
# 237  2015.03.06  3201.0  3313.0  1283.0   382.0  2911.0  2950.0    NaN
# 238  2015.03.06  3205.0  3358.0  1213.0   372.0  2934.0  3014.0    NaN
# 239  2015.03.06  3268.0  3372.0  1265.0   393.0  2863.0  2929.0    NaN
#
#          sum
# 0       54.0
# 1      163.0
# 2      402.0
# 3      585.0
# 4      564.0
# ..       ...
# 235  13657.0
# 236  13927.0
# 237  14040.0
# 238  14096.0
# 239  14090.0
#
# [240 rows x 9 columns], 'drawdown_df':            date  USDCHF  EURUSD  GBPCHF  EURGBP  EURJPY  EURCAD  empty  \
# 0    2015.03.02    -7.0   -54.0     0.0   -42.0   -42.0   -80.0    NaN
# 1    2015.03.02    48.0   -58.0    54.0   -52.0   -27.0   -95.0    NaN
# 2    2015.03.02    10.0   -16.0    -2.0   -19.0   -10.0   -50.0    NaN
# 3    2015.03.02    86.0    84.0     6.0   -20.0    47.0    26.0    NaN
# 4    2015.03.02   100.0    93.0    21.0   -21.0   -77.0    11.0    NaN
# ..          ...     ...     ...     ...     ...     ...     ...    ...
# 235  2015.03.06  3042.0  3168.0  1155.0   304.0  2765.0  2824.0    NaN
# 236  2015.03.06  3130.0  3224.0  1048.0   272.0  2781.0  2835.0    NaN
# 237  2015.03.06  3141.0  3272.0  1087.0   308.0  2850.0  2923.0    NaN
# 238  2015.03.06  3166.0  3260.0  1196.0   354.0  2857.0  2890.0    NaN
# 239  2015.03.06  3191.0  3336.0  1150.0   343.0  2845.0  2895.0    NaN
#
#          sum
# 0     -225.0
# 1     -130.0
# 2      -87.0
# 3      229.0
# 4      127.0
# ..       ...
# 235  13258.0
# 236  13290.0
# 237  13581.0
# 238  13723.0
# 239  13760.0
#
# [240 rows x 9 columns]}, {'week': '2015.03.01', 'profit_df':            date  USDCHF  EURUSD  USDCAD  AUDUSD  NZDUSD  GBPCHF  EURGBP  \
# 0    2015.03.09   -24.0    19.0   -28.0    -9.0    23.0    -1.0     6.0
# 1    2015.03.09  -124.0   -83.0  -115.0   -74.0    45.0    48.0    47.0
# 2    2015.03.09  -211.0  -160.0  -153.0  -108.0    51.0   -36.0    11.0
# 3    2015.03.09  -216.0  -144.0  -133.0  -100.0    69.0  -111.0    -5.0
# 4    2015.03.09  -222.0  -246.0  -187.0  -107.0    45.0   -35.0   -37.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.03.13  1908.0  3525.0  1713.0   831.0   410.0   -55.0   942.0
# 236  2015.03.13  1802.0  3366.0  1660.0   798.0   416.0  -165.0   858.0
# 237  2015.03.13  1816.0  3386.0  1621.0   771.0   506.0  -148.0   898.0
# 238  2015.03.13  1816.0  3386.0  1621.0   771.0   506.0  -148.0   898.0
# 239  2015.03.13  1816.0  3386.0  1621.0   771.0   506.0  -148.0   898.0
#
#      empty     sum
# 0      NaN   -14.0
# 1      NaN  -256.0
# 2      NaN  -606.0
# 3      NaN  -640.0
# 4      NaN  -789.0
# ..     ...     ...
# 235    NaN  9274.0
# 236    NaN  8735.0
# 237    NaN  8850.0
# 238    NaN  8850.0
# 239    NaN  8850.0
#
# [240 rows x 10 columns], 'drawdown_df':            date  USDCHF  EURUSD  USDCAD  AUDUSD  NZDUSD  GBPCHF  EURGBP  \
# 0    2015.03.09   -43.0   -61.0   -48.0   -21.0   -10.0   -16.0   -32.0
# 1    2015.03.09  -137.0  -103.0  -115.0   -75.0    11.0   -19.0   -19.0
# 2    2015.03.09  -304.0  -163.0  -158.0  -111.0    25.0  -187.0    -6.0
# 3    2015.03.09  -232.0  -159.0  -164.0  -124.0    28.0  -118.0    -7.0
# 4    2015.03.09  -284.0  -257.0  -203.0  -170.0     2.0  -184.0   -46.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.03.13  1875.0  3419.0  1563.0   762.0   362.0  -132.0   856.0
# 236  2015.03.13  1791.0  3356.0  1562.0   780.0   393.0  -182.0   856.0
# 237  2015.03.13  1778.0  3329.0  1585.0   725.0   295.0  -320.0   781.0
# 238  2015.03.13  1778.0  3329.0  1585.0   725.0   295.0  -320.0   781.0
# 239  2015.03.13  1778.0  3329.0  1585.0   725.0   295.0  -320.0   781.0
#
#      empty     sum
# 0      NaN  -231.0
# 1      NaN  -457.0
# 2      NaN  -904.0
# 3      NaN  -776.0
# 4      NaN -1142.0
# ..     ...     ...
# 235    NaN  8705.0
# 236    NaN  8556.0
# 237    NaN  8173.0
# 238    NaN  8173.0
# 239    NaN  8173.0
#
# [240 rows x 10 columns]}, {'week': '2015.03.08', 'profit_df':            date  GBPUSD  EURUSD  GBPCHF  EURGBP  EURNZD  empty     sum
# 0    2015.03.16  -138.0  -170.0   236.0   -59.0   -16.0    NaN  -147.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.04.03  -896.0  -938.0 -1324.0   948.0  -409.0 -1048.0  -501.0
# 236  2015.04.03  -888.0  -941.0 -1306.0   947.0  -426.0 -1045.0  -509.0
# 237  2015.04.03  -875.0  -920.0 -1290.0   978.0  -419.0  -988.0  -464.0
# 238  2015.04.03  -894.0  -864.0 -1255.0   968.0  -403.0 -1010.0  -442.0
# 239  2015.04.03 -1180.0  -918.0 -1312.0   983.0  -567.0 -1402.0  -479.0
#
#      empty     sum
# 0      NaN  -497.0
# 1      NaN  -443.0
# 2      NaN  -399.0
# 3      NaN  -317.0
# 4      NaN  -442.0
# ..     ...     ...
# 235    NaN -4168.0
# 236    NaN -4168.0
# 237    NaN -3978.0
# 238    NaN -3900.0
# 239    NaN -4875.0
#
# [240 rows x 10 columns]}, {'week': '2015.03.29', 'profit_df':            date  GBPUSD  EURUSD  GBPCHF  EURGBP  empty     sum
# 0    2015.04.06   -50.0    52.0   134.0   -98.0    NaN    38.0
# 1    2015.04.06    62.0    62.0     4.0  -106.0    NaN    22.0
# 2    2015.04.06    92.0    93.0   127.0  -177.0    NaN   135.0
# 3    2015.04.06   -10.0   -15.0   111.0  -197.0    NaN  -111.0
# 4    2015.04.06   -85.0   -98.0   161.0  -216.0    NaN  -238.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.04.10  2702.0  3972.0  1448.0  1153.0    NaN  9275.0
# 236  2015.04.10  2752.0  3968.0  1419.0  1127.0    NaN  9266.0
# 237  2015.04.10  2710.0  3923.0  1465.0  1122.0    NaN  9220.0
# 238  2015.04.10  2856.0  4052.0  1473.0  1134.0    NaN  9515.0
# 239  2015.04.10  2869.0  3977.0  1423.0  1078.0    NaN  9347.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  GBPUSD  EURUSD  GBPCHF  EURGBP  empty     sum
# 0    2015.04.06   -78.0   -18.0   -30.0  -177.0    NaN  -303.0
# 1    2015.04.06   -59.0    31.0    -2.0  -174.0    NaN  -204.0
# 2    2015.04.06   -88.0    34.0    27.0  -197.0    NaN  -224.0
# 3    2015.04.06   -31.0   -37.0    97.0  -204.0    NaN  -175.0
# 4    2015.04.06  -150.0  -166.0    58.0  -241.0    NaN  -499.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.04.10  2636.0  3948.0  1412.0  1142.0    NaN  9138.0
# 236  2015.04.10  2685.0  3947.0  1379.0  1116.0    NaN  9127.0
# 237  2015.04.10  2682.0  3923.0  1380.0  1119.0    NaN  9104.0
# 238  2015.04.10  2674.0  3922.0  1448.0  1117.0    NaN  9161.0
# 239  2015.04.10  2840.0  3972.0  1350.0  1075.0    NaN  9237.0
#
# [240 rows x 7 columns]}, {'week': '2015.04.05', 'profit_df':            date  USDCHF  EURUSD  EURCHF  CADCHF  EURGBP  EURJPY  EURCAD  \
# 0    2015.04.13   101.0   113.0   -16.0   -73.0    89.0    72.0   -17.0
# 1    2015.04.13    38.0    77.0    43.0  -115.0    70.0    43.0   -45.0
# 2    2015.04.13    68.0    -3.0   -46.0   -39.0    10.0   -91.0   -62.0
# 3    2015.04.13    15.0   -93.0   -85.0   -38.0    -3.0  -130.0  -153.0
# 4    2015.04.13    11.0  -103.0   -89.0   -45.0    -8.0  -105.0  -172.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.04.17 -2510.0 -1881.0   913.0   -11.0   333.0  -723.0  1132.0
# 236  2015.04.17 -2700.0 -2133.0   876.0   -73.0   226.0 -1009.0   990.0
# 237  2015.04.17 -2733.0 -2141.0   905.0  -117.0   176.0 -1063.0   956.0
# 238  2015.04.17 -2685.0 -2041.0   940.0   -32.0   218.0 -1061.0  1152.0
# 239  2015.04.17 -2722.0 -2059.0   951.0  -114.0   223.0 -1085.0   902.0
#
#      empty     sum
# 0      NaN   269.0
# 1      NaN   111.0
# 2      NaN  -163.0
# 3      NaN  -487.0
# 4      NaN  -511.0
# ..     ...     ...
# 235    NaN -2747.0
# 236    NaN -3823.0
# 237    NaN -4017.0
# 238    NaN -3509.0
# 239    NaN -3904.0
#
# [240 rows x 10 columns], 'drawdown_df':            date  USDCHF  EURUSD  EURCHF  CADCHF  EURGBP  EURJPY  EURCAD  \
# 0    2015.04.13     0.0     0.0   -74.0   -73.0     0.0    -7.0  -106.0
# 1    2015.04.13    18.0    70.0   -44.0  -136.0    36.0    20.0   -88.0
# 2    2015.04.13    44.0    -5.0   -63.0  -109.0    10.0  -104.0   -94.0
# 3    2015.04.13    11.0  -105.0  -105.0   -84.0   -24.0  -141.0  -205.0
# 4    2015.04.13     0.0  -137.0  -112.0   -53.0   -43.0  -170.0  -194.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.04.17 -2627.0 -1958.0   882.0  -218.0   309.0  -799.0   897.0
# 236  2015.04.17 -2717.0 -2155.0   868.0   -89.0   221.0 -1032.0   952.0
# 237  2015.04.17 -2756.0 -2201.0   816.0  -122.0   176.0 -1154.0   902.0
# 238  2015.04.17 -2752.0 -2162.0   844.0  -128.0   169.0 -1103.0   942.0
# 239  2015.04.17 -2759.0 -2062.0   912.0  -379.0   199.0 -1087.0   881.0
#
#      empty     sum
# 0      NaN  -260.0
# 1      NaN  -124.0
# 2      NaN  -321.0
# 3      NaN  -653.0
# 4      NaN  -709.0
# ..     ...     ...
# 235    NaN -3514.0
# 236    NaN -3952.0
# 237    NaN -4339.0
# 238    NaN -4190.0
# 239    NaN -4295.0
#
# [240 rows x 10 columns]}, {'week': '2015.04.12', 'profit_df':            date  USDCHF  EURUSD  EURGBP  empty    sum
# 0    2015.04.20   -67.0   -42.0     7.0    NaN -102.0
# 1    2015.04.20   -72.0   -18.0    26.0    NaN  -64.0
# 2    2015.04.20    80.0   125.0    59.0    NaN  264.0
# 3    2015.04.20   127.0   155.0    42.0    NaN  324.0
# 4    2015.04.20     7.0    46.0    45.0    NaN   98.0
# ..          ...     ...     ...     ...    ...    ...
# 235  2015.04.24   240.0  -585.0   631.0    NaN  286.0
# 236  2015.04.24   216.0  -562.0   628.0    NaN  282.0
# 239  2015.05.01   147.0 -3458.0 -3557.0 -2375.0 -5695.0    NaN -14938.0
#
# [240 rows x 8 columns]}, {'week': '2015.04.26', 'profit_df':            date  USDCHF  EURUSD  EURJPY  EURCAD  empty    sum
# 0    2015.05.04   -71.0   -30.0   -12.0   -59.0    NaN -172.0
# 1    2015.05.04     9.0    -8.0   -10.0   -72.0    NaN  -81.0
# 2    2015.05.04   -56.0   -27.0    51.0   -51.0    NaN  -83.0
# 3    2015.05.04    -2.0    69.0   114.0   -18.0    NaN  163.0
# 4    2015.05.04     0.0    42.0   105.0   -50.0    NaN   97.0
# ..          ...     ...     ...     ...     ...    ...    ...
# 235  2015.05.08  -218.0  -128.0   324.0   513.0    NaN  491.0
# 236  2015.05.08  -248.0  -211.0   285.0   487.0    NaN  313.0
# 237  2015.05.08  -242.0  -150.0   392.0   577.0    NaN  577.0
# 238  2015.05.08  -228.0  -145.0   393.0   484.0    NaN  504.0
# 239  2015.05.08  -143.0  -163.0   359.0   643.0    NaN  696.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  USDCHF  EURUSD  EURJPY  EURCAD  empty    sum
# 0    2015.05.04   -71.0   -90.0   -31.0  -113.0    NaN -305.0
# 1    2015.05.04  -106.0   -76.0   -63.0  -174.0    NaN -419.0
# 2    2015.05.04   -75.0   -27.0   -29.0  -151.0    NaN -282.0
# 3    2015.05.04   -66.0   -36.0   -21.0   -57.0    NaN -180.0
# 4    2015.05.04   -38.0    -1.0    51.0   -74.0    NaN  -62.0
# ..          ...     ...     ...     ...     ...    ...    ...
# 235  2015.05.08  -267.0  -136.0   312.0   468.0    NaN  377.0
# 236  2015.05.08  -268.0  -216.0   271.0   463.0    NaN  250.0
# 237  2015.05.08  -268.0  -244.0   254.0   465.0    NaN  207.0
# 238  2015.05.08  -250.0  -165.0   376.0   457.0    NaN  418.0
# 239  2015.05.08  -230.0  -183.0   326.0   471.0    NaN  384.0
#
# [240 rows x 7 columns]}, {'week': '2015.05.03', 'profit_df':            date  EURUSD  NZDUSD  EURGBP  empty     sum
# 0    2015.05.11    -3.0   262.0    18.0    NaN   277.0
# 1    2015.05.11     2.0   149.0    23.0    NaN   174.0
# 2    2015.05.11    15.0   219.0   -19.0    NaN   215.0
# 3    2015.05.11    35.0   315.0   -23.0    NaN   327.0
# 4    2015.05.11    81.0   342.0   -10.0    NaN   413.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.05.15 -2643.0  -395.0  -286.0    NaN -3324.0
# 236  2015.05.15 -2512.0  -303.0  -303.0    NaN -3118.0
# 237  2015.05.15 -2473.0  -295.0  -253.0    NaN -3021.0
# 238  2015.05.15 -2434.0  -175.0  -272.0    NaN -2881.0
# 239  2015.05.15 -2466.0   -82.0  -279.0    NaN -2827.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  EURUSD  NZDUSD  EURGBP  empty     sum
# 0    2015.05.11   -53.0   -53.0    -3.0    NaN  -109.0
# 1    2015.05.11   -19.0   143.0     6.0    NaN   130.0
#
#      empty     sum
# 0      NaN   212.0
# 1      NaN  1305.0
# 2      NaN   255.0
# 3      NaN   213.0
# 4      NaN   176.0
# ..     ...     ...
# 235    NaN   669.0
# 236    NaN   718.0
# 237    NaN   669.0
# 238    NaN   566.0
# 239    NaN   328.0
#
# [240 rows x 10 columns], 'drawdown_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  EURCHF  EURJPY  EURCAD  \
# 0    2015.05.25   -25.0   -37.0     0.0    -8.0   -11.0   -81.0   -49.0
# 1    2015.05.25    16.0    31.0    33.0    17.0    -1.0   -31.0   -22.0
# 2    2015.05.25    20.0    35.0    31.0     4.0    16.0   -13.0    13.0
# 3    2015.05.25   -18.0    11.0     9.0   -56.0     0.0   -22.0    33.0
# 4    2015.05.25   -34.0   -35.0    13.0   -18.0    14.0   -66.0   -49.0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 235  2015.05.29  -386.0   146.0  2460.0  1434.0   578.0 -2547.0 -1477.0
# 236  2015.05.29  -339.0   204.0  2548.0  1551.0   568.0 -2619.0 -1515.0
# 237  2015.05.29  -355.0   181.0  2563.0  1476.0   558.0 -2660.0 -1545.0
# 238  2015.05.29  -323.0   192.0  2595.0  1503.0   546.0 -2659.0 -1499.0
# 239  2015.05.29  -346.0   138.0  2611.0  1496.0   459.0 -2718.0 -1549.0
#
#      empty    sum
# 0      NaN -211.0
# 1      NaN   43.0
# 2      NaN  106.0
# 3      NaN  -43.0
# 4      NaN -175.0
# ..     ...    ...
# 235    NaN  208.0
# 236    NaN  398.0
# 237    NaN  218.0
# 238    NaN  355.0
# 239    NaN   91.0
#
# [240 rows x 10 columns]}, {'week': '2015.05.24', 'profit_df':            date  EURUSD  NZDUSD  EURCHF  EURGBP  empty     sum
# 0    2015.06.01    -7.0   -86.0    70.0   -40.0    NaN   -63.0
# 1    2015.06.01    46.0   -57.0   149.0   -12.0    NaN   126.0
# 2    2015.06.01    51.0   -41.0    78.0   -54.0    NaN    34.0
# 3    2015.06.01   159.0   -90.0   128.0    43.0    NaN   240.0
# 4    2015.06.01   267.0  -132.0   169.0    66.0    NaN   370.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.06.05 -1332.0   446.0 -1136.0 -1004.0    NaN -3026.0
# 236  2015.06.05 -1314.0   440.0 -1183.0 -1004.0    NaN -3061.0
# 237  2015.06.05 -1270.0   423.0 -1133.0  -983.0    NaN -2963.0
# 238  2015.06.05 -1282.0   410.0 -1152.0  -962.0    NaN -2986.0
# 239  2015.06.05 -1328.0   401.0 -1106.0 -1001.0    NaN -3034.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  EURUSD  NZDUSD  EURCHF  EURGBP  empty     sum
# 0    2015.06.01   -41.0  -106.0   -16.0   -98.0    NaN  -261.0
# 1    2015.06.01   -34.0   -89.0    82.0   -57.0    NaN   -98.0
# 2    2015.06.01    21.0   -64.0    55.0   -58.0    NaN   -46.0
# 3    2015.06.01    51.0   -95.0    65.0   -55.0    NaN   -34.0
# 4    2015.06.01   153.0  -187.0   123.0    41.0    NaN   130.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2015.06.05 -1524.0   398.0 -1190.0 -1087.0    NaN -3403.0
# 236  2015.06.05 -1351.0   431.0 -1194.0 -1021.0    NaN -3135.0
# 237  2015.06.05 -1336.0   406.0 -1192.0 -1015.0    NaN -3137.0
# 238  2015.06.05 -1372.0   392.0 -1198.0 -1007.0    NaN -3185.0
# 239  2015.06.05 -1334.0   367.0 -1152.0 -1006.0    NaN -3125.0
#
# [240 rows x 7 columns]}, {'week': '2015.05.31', 'profit_df':            date  GBPUSD  EURUSD  USDJPY  empty     sum
# 0    2015.06.08    39.0   -12.0   -21.0    NaN     6.0
# 1    2015.06.08    81.0    36.0   -17.0    NaN   100.0
# 2    2015.06.08    23.0   -48.0    31.0    NaN     6.0
# 3    2015.06.08    20.0   -57.0    69.0    NaN    32.0
# 4    2015.06.08    16.0   -55.0    62.0    NaN    23.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.06.12 -2841.0 -1569.0 -2157.0    NaN -6567.0
# 236  2015.06.12 -2757.0 -1508.0 -2171.0    NaN -6436.0
# 237  2015.06.12 -2911.0 -1524.0 -2199.0    NaN -6634.0
# 238  2015.06.12 -2981.0 -1603.0 -2230.0    NaN -6814.0
# 239  2015.06.12 -2880.0 -1603.0 -2169.0    NaN -6652.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  GBPUSD  EURUSD  USDJPY  empty     sum
# 0    2015.06.08   -36.0   -46.0   -51.0    NaN  -133.0
# 1    2015.06.08     6.0   -37.0   -31.0    NaN   -62.0
# 2    2015.06.08    16.0   -55.0   -39.0    NaN   -78.0
# 3    2015.06.08    11.0   -77.0    12.0    NaN   -54.0
# 4    2015.06.08    12.0   -65.0    42.0    NaN   -11.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.06.12 -2901.0 -1742.0 -2175.0    NaN -6818.0
# 236  2015.06.12 -2864.0 -1785.0 -2181.0    NaN -6830.0
# 237  2015.06.12 -2930.0 -1676.0 -2218.0    NaN -6824.0
# 238  2015.06.12 -2997.0 -1698.0 -2235.0    NaN -6930.0
# 239  2015.06.12 -2988.0 -1678.0 -2264.0    NaN -6930.0
#
# [240 rows x 6 columns]}, {'week': '2015.06.07', 'profit_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  EURJPY  empty     sum
# 0    2015.06.15   -57.0   -99.0    86.0   -13.0  -187.0    NaN  -270.0
# 1    2015.06.15   -26.0     5.0    40.0    -2.0     4.0    NaN    21.0
# 2    2015.06.15    -8.0   -53.0   129.0    31.0  -166.0    NaN   -67.0
# 3    2015.06.15   -45.0  -130.0   123.0   -10.0  -256.0    NaN  -318.0
# 4    2015.06.15     1.0   -49.0   141.0    41.0  -188.0    NaN   -54.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2015.06.19 -1240.0 -1395.0  -499.0  -528.0 -1104.0    NaN -4766.0
# 236  2015.06.19 -1288.0 -1405.0  -500.0  -453.0 -1118.0    NaN -4764.0
# 237  2015.06.19 -1245.0 -1322.0  -431.0  -471.0 -1091.0    NaN -4560.0
# 238  2015.06.19 -1284.0 -1372.0  -484.0  -452.0 -1096.0    NaN -4688.0
# 239  2015.06.19 -1161.0 -1350.0  -489.0  -437.0 -1055.0    NaN -4492.0
#
# [240 rows x 8 columns], 'drawdown_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  EURJPY  empty     sum
# 0    2015.06.15   -81.0  -176.0     0.0   -37.0  -263.0    NaN  -557.0
# 1    2015.06.15  -113.0  -101.0   -22.0  -102.0  -199.0    NaN  -537.0
# 2    2015.06.15   -73.0   -93.0    38.0    -8.0  -208.0    NaN  -344.0
# 3    2015.06.15   -79.0  -138.0   109.0   -42.0  -296.0    NaN  -446.0
# 4    2015.06.15   -71.0  -139.0   111.0   -34.0  -282.0    NaN  -415.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2015.06.19 -1303.0 -1512.0  -576.0  -607.0 -1177.0    NaN -5175.0
# 236  2015.06.19 -1329.0 -1439.0  -559.0  -538.0 -1141.0    NaN -5006.0
# 237  2015.06.19 -1294.0 -1406.0  -501.0  -475.0 -1118.0    NaN -4794.0
# 238  2015.06.19 -1284.0 -1372.0  -490.0  -484.0 -1096.0    NaN -4726.0
# 239  2015.06.19 -1292.0 -1398.0  -516.0  -493.0 -1134.0    NaN -4833.0
#
# [240 rows x 8 columns]}, {'week': '2015.06.14', 'profit_df':            date  EURUSD  NZDUSD  EURGBP  empty     sum
# 0    2015.06.22    73.0     7.0    27.0    NaN   107.0
# 1    2015.06.22    67.0     2.0     3.0    NaN    72.0
# 2    2015.06.22   141.0    28.0    53.0    NaN   222.0
# 3    2015.06.22   138.0    18.0    59.0    NaN   215.0
# 4    2015.06.22    53.0     6.0    40.0    NaN    99.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.06.26  2154.0   588.0   689.0    NaN  3431.0
# 236  2015.06.26  2089.0   612.0   668.0    NaN  3369.0
# 237  2015.06.26  2047.0   596.0   676.0    NaN  3319.0
# 238  2015.06.26  2130.0   619.0   738.0    NaN  3487.0
# 239  2015.06.26  2027.0   658.0   688.0    NaN  3373.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  EURUSD  NZDUSD  EURGBP  empty     sum
# 0    2015.06.22    -3.0   -24.0   -15.0    NaN   -42.0
# 1    2015.06.22    15.0   -41.0    -5.0    NaN   -31.0
# 2    2015.06.22    65.0   -11.0     2.0    NaN    56.0
# 3    2015.06.22   113.0   -23.0    48.0    NaN   138.0
# 4    2015.06.22    41.0   -17.0    33.0    NaN    57.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.06.26  2076.0   572.0   639.0    NaN  3287.0
# 236  2015.06.26  2059.0   576.0   653.0    NaN  3288.0
# 237  2015.06.26  2038.0   592.0   635.0    NaN  3265.0
# 238  2015.06.26  1979.0   575.0   641.0    NaN  3195.0
# 239  2015.06.26  2027.0   620.0   683.0    NaN  3330.0
#
# [240 rows x 6 columns]}, {'week': '2015.06.21', 'profit_df':            date  GBPUSD  EURUSD  NZDUSD  empty     sum
# 0    2015.06.29   135.0   248.0   -48.0    NaN   335.0
# 1    2015.06.29    94.0   169.0    39.0    NaN   302.0
# 2    2015.06.29   -57.0    31.0   -30.0    NaN   -56.0
# 3    2015.06.29  -121.0   147.0    45.0    NaN    71.0
# 4    2015.06.29   -78.0   143.0    -4.0    NaN    61.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.07.03  1110.0  -900.0  1370.0    NaN  1580.0
# 236  2015.07.03  1155.0  -936.0  1369.0    NaN  1588.0
# 237  2015.07.03  1126.0 -1009.0  1244.0    NaN  1361.0
# 238  2015.07.03  1066.0 -1003.0  1427.0    NaN  1490.0
# 239  2015.07.03  1187.0  -991.0  1375.0    NaN  1571.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  GBPUSD  EURUSD  NZDUSD  empty     sum
# 0    2015.06.29   -47.0   -32.0  -162.0    NaN  -241.0
# 1    2015.06.29   -13.0   133.0   -53.0    NaN    67.0
# 2    2015.06.29  -174.0  -107.0  -148.0    NaN  -429.0
# 3    2015.06.29  -326.0   -22.0   -57.0    NaN  -405.0
# 4    2015.06.29  -210.0    21.0   -67.0    NaN  -256.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2015.07.03  1068.0  -956.0  1278.0    NaN  1390.0
# 236  2015.07.03  1081.0  -941.0  1345.0    NaN  1485.0
# 237  2015.07.03  1089.0 -1044.0  1242.0    NaN  1287.0
# 238  2015.07.03   907.0 -1072.0  1244.0    NaN  1079.0
# 239  2015.07.03  1033.0 -1046.0  1264.0    NaN  1251.0
#
# [240 rows x 6 columns]}, {'week': '2015.06.28', 'profit_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  EURJPY  empty     sum
# 0    2015.07.06    72.0    49.0   137.0    32.0    -7.0   -64.0    NaN   219.0
# 1    2015.07.06     6.0    -5.0    17.0    83.0    58.0   -10.0    NaN   149.0
# 2    2015.07.06    46.0  -369.0   384.0    10.0  -117.0  -861.0    NaN  -907.0
# 3    2015.07.06   -32.0  -419.0   378.0   -11.0  -121.0  -923.0    NaN -1128.0
# 4    2015.07.06   -82.0  -458.0   321.0   -41.0  -277.0  -904.0    NaN -1441.0
# ..          ...     ...     ...     ...     ...     ...     ...    ...     ...
# 235  2015.07.10  -168.0 -1482.0   858.0   954.0   400.0 -2753.0    NaN -2191.0
# 236  2015.07.10  -188.0 -1489.0   856.0   906.0   331.0 -2756.0    NaN -2340.0
# 237  2015.07.10  -318.0 -1650.0   845.0   817.0   316.0 -2937.0    NaN -2927.0
# 238  2015.07.10  -392.0 -1727.0   753.0   871.0   342.0 -2935.0    NaN -3088.0
# 239  2015.07.10  -489.0 -1747.0   766.0   741.0   381.0 -2975.0    NaN -3323.0
#
# [240 rows x 9 columns], 'drawdown_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  EURJPY  empty     sum
# 0    2015.07.06   -50.0  -168.0   -23.0    -7.0   -38.0  -375.0    NaN  -661.0
# 239  2015.07.31   316.0   -72.0    97.0   487.0  -283.0  -166.0    NaN   379.0
#
# [240 rows x 9 columns], 'drawdown_df':            date  USDCHF  EURUSD  USDJPY  USDCAD  AUDUSD  EURJPY  empty    sum
# 0    2015.07.27     0.0   -23.0   -65.0   -54.0   -36.0    -9.0    NaN -187.0
# 1    2015.07.27   -68.0   -15.0   -76.0   -20.0   -20.0    32.0    NaN -167.0
# 2    2015.07.27    16.0   -44.0   -19.0    18.0   -65.0   -82.0    NaN -176.0
# 3    2015.07.27    -3.0   -44.0    46.0    40.0   -80.0   -84.0    NaN -125.0
# 4    2015.07.27    20.0     7.0    11.0    -2.0  -136.0   -37.0    NaN -137.0
# ..          ...     ...     ...     ...     ...     ...     ...    ...    ...
# 235  2015.07.31   303.0  -151.0   108.0   347.0  -470.0  -316.0    NaN -179.0
# 236  2015.07.31   372.0  -115.0   140.0   408.0  -352.0  -287.0    NaN  166.0
# 237  2015.07.31   350.0  -129.0   105.0   311.0  -397.0  -283.0    NaN  -43.0
# 238  2015.07.31   326.0  -140.0   126.0   313.0  -412.0  -314.0    NaN -101.0
# 239  2015.07.31   259.0   -98.0    97.0   444.0  -394.0  -297.0    NaN   11.0
#
# [240 rows x 9 columns]}, {'week': '2015.07.26', 'profit_df':            date  EURUSD  USDJPY  NZDUSD  EURGBP  empty    sum
# 0    2015.08.03   -73.0     8.0     5.0   -35.0    NaN  -95.0
# 1    2015.08.03   -71.0    49.0   -15.0   -42.0    NaN  -79.0
# 2    2015.08.03   -41.0    75.0   110.0   -40.0    NaN  104.0
# 3    2015.08.03   -40.0    71.0   108.0   -26.0    NaN  113.0
# 4    2015.08.03   -41.0   118.0   150.0    -4.0    NaN  223.0
# ..          ...     ...     ...     ...     ...    ...    ...
# ...
# 4    2021.09.27     0.0   119.0  -107.0   -79.0    NaN   -67.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2021.10.01   209.0  -698.0  1659.0   124.0    NaN  1294.0
# 236  2021.10.01   194.0  -736.0  1652.0     8.0    NaN  1118.0
# 237  2021.10.01   186.0  -763.0  1641.0   -37.0    NaN  1027.0
# 238  2021.10.01   187.0  -793.0  1701.0    67.0    NaN  1162.0
# 239  2021.10.01   181.0  -793.0  1680.0   -41.0    NaN  1027.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  EURGBP  GBPJPY  EURCAD  EURNZD  empty     sum
# 0    2021.09.27    -2.0   -85.0  -120.0  -443.0    NaN  -650.0
# 1    2021.09.27    19.0   -68.0  -169.0  -175.0    NaN  -393.0
# 2    2021.09.27    18.0   -66.0  -129.0  -149.0    NaN  -326.0
# 3    2021.09.27    14.0   161.0  -110.0  -169.0    NaN  -104.0
# 4    2021.09.27    -5.0   116.0  -111.0  -182.0    NaN  -182.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2021.10.01   181.0  -749.0  1641.0     8.0    NaN  1081.0
# 236  2021.10.01   188.0  -752.0  1646.0    -6.0    NaN  1076.0
# 237  2021.10.01   174.0  -805.0  1587.0   -61.0    NaN   895.0
# 238  2021.10.01   176.0  -803.0  1642.0   -58.0    NaN   957.0
# 239  2021.10.01   169.0  -820.0  1657.0   -51.0    NaN   955.0
#
# [240 rows x 7 columns]}, {'week': '2021.09.26', 'profit_df':            date  USDCAD  EURJPY  empty     sum
# 0    2021.10.04    50.0  -134.0    NaN   -84.0
# 1    2021.10.04    12.0  -163.0    NaN  -151.0
# 2    2021.10.04   271.0    51.0    NaN   322.0
# 3    2021.10.04   237.0    88.0    NaN   325.0
# 4    2021.10.04   217.0    77.0    NaN   294.0
# ..          ...     ...     ...    ...     ...
# 235  2021.10.08  1854.0  1135.0    NaN  2989.0
# 236  2021.10.08  1798.0  1122.0    NaN  2920.0
# 237  2021.10.08  1745.0  1088.0    NaN  2833.0
# 238  2021.10.08  1759.0  1130.0    NaN  2889.0
# 239  2021.10.08  1704.0  1140.0    NaN  2844.0
#
# [240 rows x 5 columns], 'drawdown_df':            date  USDCAD  EURJPY  empty     sum
# 0    2021.10.04     0.0  -211.0    NaN  -211.0
# 1    2021.10.04     6.0  -196.0    NaN  -190.0
# 2    2021.10.04     0.0  -163.0    NaN  -163.0
# 3    2021.10.04   218.0    44.0    NaN   262.0
# 4    2021.10.04   185.0    50.0    NaN   235.0
# ..          ...     ...     ...    ...     ...
# 235  2021.10.08  1762.0  1078.0    NaN  2840.0
# 236  2021.10.08  1793.0  1111.0    NaN  2904.0
# 237  2021.10.08  1688.0  1079.0    NaN  2767.0
# 238  2021.10.08  1701.0  1078.0    NaN  2779.0
# 239  2021.10.08  1692.0  1099.0    NaN  2791.0
#
# [240 rows x 5 columns]}, {'week': '2021.10.03', 'profit_df':            date  USDJPY  CHFJPY  EURGBP  empty     sum
# 0    2021.10.11   107.0   251.0  -106.0    NaN   252.0
# 1    2021.10.11   145.0   275.0   -98.0    NaN   322.0
# 2    2021.10.11   204.0   307.0  -130.0    NaN   381.0
# 3    2021.10.11   166.0   286.0  -121.0    NaN   331.0
# 4    2021.10.11   175.0   283.0  -122.0    NaN   336.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2021.10.15  2155.0  3050.0   417.0    NaN  5622.0
# 236  2021.10.15  2141.0  3031.0   414.0    NaN  5586.0
# 237  2021.10.15  2104.0  3036.0   402.0    NaN  5542.0
# 238  2021.10.15  2178.0  3072.0   411.0    NaN  5661.0
# 239  2021.10.15  2146.0  2999.0   450.0    NaN  5595.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  USDJPY  CHFJPY  EURGBP  empty     sum
# 0    2021.10.11     0.0     0.0  -129.0    NaN  -129.0
# 1    2021.10.11    97.0   154.0  -135.0    NaN   116.0
# 2    2021.10.11   123.0   253.0  -140.0    NaN   236.0
# 3    2021.10.11   158.0   286.0  -142.0    NaN   302.0
# 4    2021.10.11   140.0   269.0  -138.0    NaN   271.0
# ..          ...     ...     ...     ...    ...     ...
# 235  2021.10.15  2140.0  2908.0   416.0    NaN  5464.0
# 236  2021.10.15  2126.0  3007.0   380.0    NaN  5513.0
# 237  2021.10.15  2084.0  3013.0   400.0    NaN  5497.0
# 238  2021.10.15  2102.0  3022.0   392.0    NaN  5516.0
# 239  2021.10.15  2136.0  2980.0   401.0    NaN  5517.0
#
# [240 rows x 6 columns]}, {'week': '2021.10.10', 'profit_df':            date  NZDCHF  EURGBP  GBPJPY  EURCAD  EURNZD  empty    sum
# 0    2021.10.18    72.0   -31.0   -88.0  -230.0   -62.0    NaN -339.0
# 1    2021.10.18   225.0    -2.0    54.0  -225.0   206.0    NaN  258.0
# 2    2021.10.18   233.0   -40.0   291.0   -37.0   397.0    NaN  844.0
# 3    2021.10.18   190.0   -22.0   303.0  -124.0   295.0    NaN  642.0
# 4    2021.10.18   203.0    -2.0   330.0  -151.0   310.0    NaN  690.0
# ..          ...     ...     ...     ...     ...     ...    ...    ...
# 235  2021.10.22   186.0  -316.0  -992.0  -578.0   990.0    NaN -710.0
# 236  2021.10.22   249.0  -365.0 -1019.0  -657.0  1049.0    NaN -743.0
# 237  2021.10.22   275.0  -335.0  -914.0  -672.0  1151.0    NaN -495.0
# 238  2021.10.22   229.0  -349.0  -924.0  -662.0  1022.0    NaN -684.0
# 239  2021.10.22   227.0  -341.0  -868.0  -688.0  1015.0    NaN -655.0
#
# [240 rows x 8 columns], 'drawdown_df':            date  NZDCHF  EURGBP  GBPJPY  EURCAD  EURNZD  empty    sum
# 0    2021.10.18  -160.0   -49.0  -190.0  -230.0  -120.0    NaN -749.0
# 1    2021.10.18  -130.0   -64.0   -74.0  -268.0  -223.0    NaN -759.0
# 2    2021.10.18    60.0   -72.0    18.0  -223.0   105.0    NaN -112.0
# 3    2021.10.18   187.0   -47.0   231.0  -134.0   288.0    NaN  525.0
# 4    2021.10.18   187.0   -37.0   225.0  -171.0   255.0    NaN  459.0
# ..          ...     ...     ...     ...     ...     ...    ...    ...
# 235  2021.10.22   186.0  -346.0 -1021.0  -604.0   975.0    NaN -810.0
# 236  2021.10.22   175.0  -369.0 -1031.0  -670.0   952.0    NaN -943.0
# 237  2021.10.22   246.0  -368.0 -1034.0  -713.0  1049.0    NaN -820.0
# 238  2021.10.22   216.0  -352.0  -972.0  -684.0   999.0    NaN -793.0
# 239  2021.10.22   209.0  -362.0  -963.0  -724.0   990.0    NaN -850.0
#
# [240 rows x 8 columns]}, {'week': '2021.10.17', 'profit_df':            date  USDCAD  EURJPY  CADJPY  AUDJPY  NZDJPY  empty     sum
# 0    2021.10.25    -5.0   -23.0   -11.0   -34.0    54.0    NaN   -19.0
# 1    2021.10.25   -33.0   -36.0   -10.0   -51.0    82.0    NaN   -48.0
# 2    2021.10.25   -75.0    30.0     3.0    18.0   125.0    NaN   101.0
# 3    2021.10.25   -43.0    77.0    30.0    64.0   152.0    NaN   280.0
# 4    2021.10.25   -97.0    83.0    44.0    71.0   166.0    NaN   267.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2021.10.29  -101.0  -470.0   291.0   976.0   574.0    NaN  1270.0
# 236  2021.10.29  -231.0  -512.0   191.0   881.0   495.0    NaN   824.0
# 237  2021.10.29  -146.0  -400.0   308.0   975.0   588.0    NaN  1325.0
# 238  2021.10.29  -149.0  -327.0   335.0  1038.0   664.0    NaN  1561.0
# 239  2021.10.29  -185.0  -387.0   250.0   943.0   583.0    NaN  1204.0
#
# [240 rows x 8 columns], 'drawdown_df':            date  USDCAD  EURJPY  CADJPY  AUDJPY  NZDJPY  empty     sum
# 0    2021.10.25   -45.0   -67.0   -53.0   -81.0   -23.0    NaN  -269.0
# 1    2021.10.25   -36.0   -78.0   -23.0   -72.0   -27.0    NaN  -236.0
# 2    2021.10.25   -87.0  -100.0   -78.0   -88.0    29.0    NaN  -324.0
# 3    2021.10.25   -82.0     3.0   -21.0     8.0   109.0    NaN    17.0
# 4    2021.10.25  -100.0    19.0    -7.0    -1.0    95.0    NaN     6.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2021.10.29  -191.0  -503.0   228.0   837.0   415.0    NaN   786.0
# 236  2021.10.29  -277.0  -537.0   169.0   863.0   467.0    NaN   685.0
# 237  2021.10.29  -258.0  -519.0   180.0   873.0   490.0    NaN   766.0
# 238  2021.10.29  -157.0  -453.0   273.0   952.0   568.0    NaN  1183.0
# 239  2021.10.29  -208.0  -439.0   238.0   939.0   583.0    NaN  1113.0
#
# [240 rows x 8 columns]}, {'week': '2021.10.24', 'profit_df':            date  USDJPY  CHFJPY  EURGBP  GBPJPY  CADJPY  empty     sum
# 0    2021.11.01    62.0   250.0   -15.0   127.0   120.0    NaN   544.0
# 1    2021.11.01    46.0   286.0    -7.0   127.0    69.0    NaN   521.0
# 2    2021.11.01    65.0   300.0    -8.0   160.0   110.0    NaN   627.0
# 3    2021.11.01   137.0   318.0     5.0   210.0   140.0    NaN   810.0
# 4    2021.11.01    80.0   293.0    12.0   183.0   142.0    NaN   710.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2021.11.05  -771.0   -94.0 -1273.0 -3174.0 -1039.0    NaN -6351.0
# 236  2021.11.05  -762.0  -106.0 -1272.0 -3162.0 -1062.0    NaN -6364.0
# 237  2021.11.05  -715.0   -61.0 -1244.0 -3070.0 -1073.0    NaN -6163.0
# 238  2021.11.05  -715.0   -61.0 -1244.0 -3070.0 -1073.0    NaN -6163.0
# 239  2021.11.05  -715.0   -61.0 -1244.0 -3070.0 -1073.0    NaN -6163.0
#
# [240 rows x 8 columns], 'drawdown_df':            date  USDJPY  CHFJPY  EURGBP  GBPJPY  CADJPY  empty     sum
# 0    2021.11.01    -8.0   -23.0   -28.0   -24.0   -25.0    NaN  -108.0
# 1    2021.11.01     0.0   238.0   -22.0    57.0    43.0    NaN   316.0
# 2    2021.11.01    -4.0   224.0   -27.0    19.0    17.0    NaN   229.0
# 3    2021.11.01    65.0   284.0   -24.0   140.0    99.0    NaN   564.0
# 4    2021.11.01    35.0   238.0    -8.0   113.0   107.0    NaN   485.0
# ..          ...     ...     ...     ...     ...     ...    ...     ...
# 235  2021.11.05  -785.0  -119.0 -1299.0 -3282.0 -1074.0    NaN -6559.0
# 236  2021.11.05  -780.0  -110.0 -1291.0 -3201.0 -1063.0    NaN -6445.0
# 237  2021.11.05  -764.0  -108.0 -1322.0 -3198.0 -1101.0    NaN -6493.0
# 238  2021.11.05  -764.0  -108.0 -1322.0 -3198.0 -1101.0    NaN -6493.0
# 239  2021.11.05  -764.0  -108.0 -1322.0 -3198.0 -1101.0    NaN -6493.0
#
# [240 rows x 8 columns]}, {'week': '2021.10.31', 'profit_df':            date  EURGBP  GBPJPY  EURNZD  empty    sum
# 0    2021.11.08    11.0   131.0   -45.0    NaN   97.0
# 1    2021.11.08     5.0   153.0  -120.0    NaN   38.0
# 2    2021.11.08   -27.0   316.0  -256.0    NaN   33.0
# 3    2021.11.08   -46.0   295.0  -333.0    NaN  -84.0
# 4    2021.11.08   -21.0   417.0  -379.0    NaN   17.0
# ..          ...     ...     ...     ...    ...    ...
# 235  2021.11.12   398.0    72.0   -81.0    NaN  389.0
# 236  2021.11.12   417.0    76.0   -49.0    NaN  444.0
# 237  2021.11.12   419.0    52.0   -33.0    NaN  438.0
# 238  2021.11.12   415.0    43.0   -21.0    NaN  437.0
# 239  2021.11.12   400.0    17.0   -99.0    NaN  318.0
#
# [240 rows x 6 columns], 'drawdown_df':            date  EURGBP  GBPJPY  EURNZD  empty    sum
# 0    2021.11.08   -29.0     0.0  -118.0    NaN -147.0
# 1    2021.11.08   -18.0   113.0  -144.0    NaN  -49.0
# 2    2021.11.08   -59.0   150.0  -267.0    NaN -176.0
# 3    2021.11.08   -61.0   275.0  -339.0    NaN -125.0
# 4    2021.11.08   -66.0   187.0  -394.0    NaN -273.0
# ..          ...     ...     ...     ...    ...    ...
# 235  2021.11.12   388.0    54.0   -94.0    NaN  348.0
# 236  2021.11.12   386.0    20.0   -89.0    NaN  317.0
# 237  2021.11.12   410.0    14.0   -58.0    NaN  366.0
# 238  2021.11.12   412.0    22.0   -51.0    NaN  383.0
# 239  2021.11.12   382.0   -23.0  -129.0    NaN  230.0
#
# [240 rows x 6 columns]}, {'week': '2021.11.07', 'profit_df':            date  USDJPY  USDCAD  EURCHF  EURJPY  empty     sum
# 0    2021.11.15    49.0   -86.0   -70.0    34.0    NaN   -73.0
# 1    2021.11.15    56.0   -98.0   -77.0    50.0    NaN   -69.0
# 2    2021.11.15   126.0  -114.0   -62.0   109.0    NaN    59.0
# 3    2021.11.15    73.0  -101.0   -42.0    37.0    NaN   -33.0
# 4    2021.11.15    25.0  -201.0   -58.0     8.0    NaN  -226.0
# ..          ...     ...     ...     ...     ...    ...     ...
# 235  2021.11.19    26.0 -1257.0   520.0 -1743.0    NaN -2454.0
# 236  2021.11.19    92.0 -1144.0   511.0 -1679.0    NaN -2220.0
# 237  2021.11.19    84.0 -1137.0   527.0 -1692.0    NaN -2218.0
# 238  2021.11.19    98.0 -1101.0   525.0 -1714.0    NaN -2192.0
# 239  2021.11.19   110.0 -1082.0   542.0 -1722.0    NaN -2152.0
#
# [240 rows x 7 columns], 'drawdown_df':            date  USDJPY  USDCAD  EURCHF  EURJPY  empty     sum
# 238  2021.11.26  -405.0  -809.0   314.0  -357.0  1907.0 -1011.0 -2238.0
# 239  2021.11.26  -405.0  -731.0   296.0  -154.0  1872.0 -1018.0 -2243.0
#
#      empty     sum
# 0      NaN  -382.0
# 1      NaN   -65.0
# 2      NaN   -35.0
# 3      NaN   245.0
# 4      NaN   -30.0
# ..     ...     ...
# 235    NaN -1761.0
# 236    NaN -1744.0
# 237    NaN -1935.0
# 238    NaN -2599.0
# 239    NaN -2383.0
#
# [240 rows x 10 columns]}, {'week': '2021.11.21', 'profit_df':            date  EURGBP  EURNZD  empty     sum
# 0    2021.11.29  -160.0  -718.0    NaN  -878.0
# 1    2021.11.29  -105.0  -568.0    NaN  -673.0
# 2    2021.11.29    27.0  -328.0    NaN  -301.0
# 3    2021.11.29    -2.0  -297.0    NaN  -299.0
# 4    2021.11.29   -49.0  -221.0    NaN  -270.0
# ..          ...     ...     ...    ...     ...
# 235  2021.12.03  -859.0 -2481.0    NaN -3340.0
# 236  2021.12.03  -818.0 -2423.0    NaN -3241.0
# 237  2021.12.03  -777.0 -2369.0    NaN -3146.0
# 238  2021.12.03  -799.0 -2431.0    NaN -3230.0
# 239  2021.12.03  -771.0 -2309.0    NaN -3080.0
#
# [240 rows x 5 columns], 'drawdown_df':            date  EURGBP  EURNZD  empty     sum
# 0    2021.11.29  -163.0  -860.0    NaN -1023.0
# 1    2021.11.29  -209.0  -832.0    NaN -1041.0
# 2    2021.11.29  -117.0  -588.0    NaN  -705.0
# 3    2021.11.29   -18.0  -361.0    NaN  -379.0
# 4    2021.11.29   -64.0  -362.0    NaN  -426.0
# ..          ...     ...     ...    ...     ...
# 235  2021.12.03  -859.0 -2502.0    NaN -3361.0
# 236  2021.12.03  -866.0 -2599.0    NaN -3465.0
# 237  2021.12.03  -826.0 -2482.0    NaN -3308.0
# 238  2021.12.03  -806.0 -2449.0    NaN -3255.0
# 239  2021.12.03  -833.0 -2524.0    NaN -3357.0
#
# [240 rows x 5 columns]}]

# %%
statistic_df = pd.DataFrame()

start_date_index_list =[]

cut_off_date_index_list =[]

draw_down_list = []

total_spread_list = []

profit_list=[]

profit_ratio_list=[]


#combine_week_drawdown_df = pd.read_csv("files/" + 'combine_week_drawdown_df.csv')
#combine_week_profit_df = pd.read_csv("files/" + 'combine_week_profit_df.csv')


#print(combine_week_drawdown_df)

start_date_index = [f for f in range(0, 239)]


draw_down = [f*-1 for f in range(100, 3000, 100)] 


total_spread = -200





for t in start_date_index:
    
    cut_off_date_index =   [f+1 for f in range( 1,(240-t)  ) ]
    
    #print(cut_off_date_index)
    
    for g in cut_off_date_index:
        
        
        for q in draw_down :
            
            
            strategy_profit = []
            
            current_maximal_drawdown = q + total_spread
            
            
            for s in qualified_weeks_dfs:
                
                current_week_calculated_profit = None
                
                current_drawdown_df = s['drawdown_df'].copy()
                current_drawdown_df = current_drawdown_df.iloc[t:]
              
                current_drawdown_df = current_drawdown_df.reset_index(drop=True)   
                current_drawdown_df = current_drawdown_df.iloc[:g]
                current_week_drawdown_list = current_drawdown_df['sum'].values
                
               
                
                

                current_profit_df = s['profit_df'].copy()
                current_profit_df = current_profit_df.iloc[t:]
                current_profit_df = current_profit_df.reset_index(drop=True)
                current_profit_df = current_profit_df.iloc[:g]
                current_week_profit_list = current_profit_df['sum'].values
                
                
                
                #print(current_week_profit_list)
                
            
                for r in range(len(current_week_drawdown_list)):
                    
                    
                    
                    current_drawdown = current_week_drawdown_list[r] - current_week_profit_list[0]
                    
                    current_profit = current_week_profit_list[r] - current_week_profit_list[0]
                    
                    
                    if r == 0:
                        #skipping the first row
                        continue
                    
                    
                    if current_drawdown <= q:
                        
                        
                        current_week_calculated_profit = current_maximal_drawdown
                    
                        break
                        
                    
                    
                if current_week_calculated_profit == None:
                    
                    current_week_calculated_profit = current_profit - total_spread
                    
                
                strategy_profit.append(current_week_calculated_profit)
                
            total_profit = sum(strategy_profit)
            
            profit_ratio = total_profit/(10*current_maximal_drawdown*-1)
            
            if profit_ratio > 4 :
                
                print( 'profit_ratio : ', profit_ratio)
                
                
            
            
            #print( 'start:', t+1, '  end:', g, '  drawdown:',q , '  profit:', total_profit, 'profit_ratio:',profit_ratio )
                
            start_date_index_list.append(t+1)

            cut_off_date_index_list.append(g)

            draw_down_list.append(q)

            total_spread_list.append(total_spread)

            profit_list.append(total_profit)

            profit_ratio_list.append(profit_ratio)
            
    print(t)
# Out:
# profit_ratio :  1.0094999999999887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_10856/1901821379.py in <module>
#      64
#      65
# ---> 66                 current_profit_df = s['profit_df'].copy()
#      67                 current_profit_df = current_profit_df.iloc[t:]
#      68                 current_profit_df = current_profit_df.reset_index(drop=True)
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5922         dtype: object
#    5923         """
# -> 5924         data = self._mgr.copy(deep=deep)
#    5925         self._clear_item_cache()
#    5926         return self._constructor(data).__finalize__(self, method="copy")
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     593             new_axes = list(self.axes)
#     594
# --> 595         res = self.apply("copy", deep=deep)
#     596         res.axes = new_axes
#     597         return res
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# c:\users\akinshipe\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     649         values = self.values
#     650         if deep:
# --> 651             values = values.copy()
#     652         return self.make_block_same_class(values)
#     653
#
# KeyboardInterrupt:

# %%
statistic_df['start_date_index'] = start_date_index_list


statistic_df['cut_off_date_index'] = cut_off_date_index_list

statistic_df['total_spread'] = total_spread_list

statistic_df['draw_down'] = draw_down_list





statistic_df['profit'] = profit_list

statistic_df['profit_ratio'] = profit_ratio_list





print(statistic_df)
statistic_df.to_csv('files/statistic_df.csv')
