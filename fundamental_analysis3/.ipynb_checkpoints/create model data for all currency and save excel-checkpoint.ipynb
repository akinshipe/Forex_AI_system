# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np



currency_list = [
                'USDCHF10080',
                 'GBPUSD10080',
                 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]

# %%
# read  combined data frame from excel
original_data = pd.read_excel('files/combine_data_dataframe_with_addon_columns.xlsx', sheet_name=0)



headers = ['date_start', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

#get needed timeframe from the list of available fundamental timeframes
needed_time_frame = original_data['date_start'].dt.strftime('%Y-%m-%d').to_list()


for x in currency_list:
    
    currency1 =x[ 0 : 3 ].lower()
    currency2 = x[3:6].lower()
    
    index1 = original_data.columns.get_loc(currency1+'_buy_percent')
    index2 = original_data.columns.get_loc(currency2+'_buy_percent')
    
    data = original_data.iloc[:, [ 1, index1, index1+1, index1+2, index1+3, index2, index2+1, index2+2, index1+3]   ]
    
    print(data)
    
    # initiating the arrays to populate next week data into
    currency_price_info =[[], [], [], []]
    
    #initiating the array to populate weekly currency volume into
    current_currency_volume =[]
    
    
    current_currency_data = pd.read_csv('recent_data/' + x + '.csv', names = headers)
    
    #loop through all rows in needed timeframe and loop through all the rows in historical price data to match the correct row
    for q in needed_time_frame:
        
        for index, row in current_currency_data.iterrows():
                      
            if q == row.date_start.replace(".", "-"):
                
                #populates the price info data into there respective array
                currency_price_info[0].append(row.open)
                currency_price_info[1].append(row.high)
                currency_price_info[2].append(row.low)
                currency_price_info[3].append(row.close)
                current_currency_volume.append(row.volume)
        
   
           
    # this for loop shifts the row down by 1 step so as to have nextweek data on the same row ith this week data
    for b in currency_price_info:
        b.insert(0,0)
        b.pop()
        
        
    #merges all the nextweek info in a dataframe in preparation to merge it the main data    
    next_week_data_frame = pd.DataFrame( columns = ['nextweek_open', 'nextweek_high', 'nextweek_low', 'nextweek_close', 'volume'])
    
    next_week_data_frame['nextweek_open'] = currency_price_info[0]
    next_week_data_frame['nextweek_high'] = currency_price_info[1]
    next_week_data_frame['nextweek_low'] = currency_price_info[2]
    next_week_data_frame['nextweek_close'] = currency_price_info[3]
    next_week_data_frame['volume'] = current_currency_volume
    
    #copies original data so as not to mutate it
    #data = original_data.copy( deep = True)
    
    
    
     #deletes the column 5 the column 5 is a duplicate of the index when two dataframes where concated together   
    #data.drop(data.columns[5], axis=1, inplace=True)
    
    
    #deletes the first row of the column as it has invalid data for nextweek forecast
    data = data.iloc[1: , :]
    
    #data for each currency is exported to different excel files
    
    data.to_excel("files/currency_training_data/" + x.replace('10080','') + "_combine_data_dataframe.xlsx") 
    
    print(x)
# Out:
#     date_start  usd_buy_percent  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   2021-08-22         8.888889   41.379310   62.500000   38.000000
# 1   2021-08-15        41.379310   62.500000   38.000000   66.666667
# 2   2021-08-08        62.500000   38.000000   66.666667   18.518519
# 3   2021-08-01        38.000000   66.666667   18.518519   64.705882
# 4   2021-07-25        66.666667   18.518519   64.705882   34.782609
# ..         ...              ...         ...         ...         ...
# 357 2014-09-28        45.833333   54.761905   26.530612   37.931034
# 358 2014-09-21        54.761905   26.530612   37.931034   29.268293
# 359 2014-09-14        26.530612   37.931034   29.268293   55.555556
# 360 2014-09-07        37.931034   29.268293   55.555556   78.378378
# 361 2014-08-31        29.268293   55.555556   78.378378   32.558140
#
#      chf_buy_percent  Unnamed: 19  Unnamed: 20  Unnamed: 5
# 0          50.000000    50.000000    50.000000   38.000000
# 1          50.000000    50.000000    50.000000   66.666667
# 2          50.000000    50.000000     0.000000   18.518519
# 3          50.000000     0.000000    50.000000   64.705882
# 4           0.000000    50.000000    50.000000   34.782609
# ..               ...          ...          ...         ...
# 357        50.000000    50.000000     0.000000   37.931034
# 358        50.000000     0.000000    60.000000   29.268293
# 359         0.000000    60.000000    14.285714   55.555556
# 360        60.000000    14.285714    50.000000   78.378378
# 361        14.285714    50.000000   100.000000   32.558140
#
# [362 rows x 9 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\LAOLUH~1\AppData\Local\Temp/ipykernel_14228/3132943061.py in <module>
#      36         for index, row in current_currency_data.iterrows():
#      37
# ---> 38             if q == row.date_start.replace(".", "-"):
#      39
#      40                 #populates the price info data into there respective array
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5482             and name not in self._metadata
#    5483             and name not in self._accessors
# -> 5484             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485         ):
#    5486             return self[name]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in _can_hold_identifiers_and_holds_name(self, name)
#    4646         https://github.com/pandas-dev/pandas/issues/19764
#    4647         """
# -> 4648         if self.is_object() or self.is_categorical():
#    4649             return name in self
#    4650         return False
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in is_object(self)
#    2255         False
#    2256         """
# -> 2257         return is_object_dtype(self.dtype)
#    2258
#    2259     @final
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\dtypes\common.py in is_object_dtype(arr_or_dtype)
#     185     False
#     186     """
# --> 187     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#     188
#     189
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\dtypes\common.py in classes(*klasses)
#     144 def classes(*klasses) -> Callable:
#     145     """evaluate if the tipo is a subclass of the klasses"""
# --> 146     return lambda tipo: issubclass(tipo, klasses)
#     147
#     148
#
# KeyboardInterrupt:
