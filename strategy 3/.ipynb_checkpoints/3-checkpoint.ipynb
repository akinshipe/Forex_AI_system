# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
#import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import time
from datetime import datetime, timedelta

all_currency_pairs = ['USDCHF10080',
                 'GBPUSD10080', 'EURUSD10080', 'USDJPY10080', 'USDCAD10080', 'AUDUSD10080', 'NZDUSD10080',
                 'GBPCHF10080', 'EURCHF10080', 'CHFJPY10080', 'CADCHF10080', 'AUDCHF10080', 'NZDCHF10080', 'EURGBP10080',
                 'GBPJPY10080', 'GBPCAD10080', 'GBPAUD10080', 'EURJPY10080', 'EURCAD10080', 'EURAUD10080', 'EURNZD10080',
                'CADJPY10080', 'AUDJPY10080', 'NZDJPY10080', 'AUDCAD10080', 'NZDCAD10080', 'AUDNZD10080'
                ]



headers = ['date', 'ignore', 'open', 'high', 'low', 'close', 'volume'  ]

# %%
raw_df = pd.read_csv("../raw_weekly_data/NZDCAD10080.csv", names = headers )

needed_weeks_df = raw_df.loc[(raw_df['date'] >= "2015.01.01")   ]   

needed_weeks_df = needed_weeks_df.reset_index(drop=True)

available_weeks = needed_weeks_df['date'].values



#print(raw_df)
print(available_weeks)
# Out:
# ['2015.01.04' '2015.01.11' '2015.01.18' '2015.01.25' '2015.02.01'
#  '2015.02.08' '2015.02.15' '2015.02.22' '2015.03.01' '2015.03.08'
#  '2015.03.15' '2015.03.22' '2015.03.29' '2015.04.05' '2015.04.12'
#  '2015.04.19' '2015.04.26' '2015.05.03' '2015.05.10' '2015.05.17'
#  '2015.05.24' '2015.05.31' '2015.06.07' '2015.06.14' '2015.06.21'
#  '2015.06.28' '2015.07.05' '2015.07.12' '2015.07.19' '2015.07.26'
#  '2015.08.02' '2015.08.09' '2015.08.16' '2015.08.23' '2015.08.30'
#  '2015.09.06' '2015.09.13' '2015.09.20' '2015.09.27' '2015.10.04'
#  '2015.10.11' '2015.10.18' '2015.10.25' '2015.11.01' '2015.11.08'
#  '2015.11.15' '2015.11.22' '2015.11.29' '2015.12.06' '2015.12.13'
#  '2015.12.20' '2015.12.27' '2016.01.03' '2016.01.10' '2016.01.17'
#  '2016.01.24' '2016.01.31' '2016.02.07' '2016.02.14' '2016.02.21'
#  '2016.02.28' '2016.03.06' '2016.03.13' '2016.03.20' '2016.03.27'
#  '2016.04.03' '2016.04.10' '2016.04.17' '2016.04.24' '2016.05.01'
#  '2016.05.08' '2016.05.15' '2016.05.22' '2016.05.29' '2016.06.05'
#  '2016.06.12' '2016.06.19' '2016.06.26' '2016.07.03' '2016.07.10'
#  '2016.07.17' '2016.07.24' '2016.07.31' '2016.08.07' '2016.08.14'
#  '2016.08.21' '2016.08.28' '2016.09.04' '2016.09.11' '2016.09.18'
#  '2016.09.25' '2016.10.02' '2016.10.09' '2016.10.16' '2016.10.23'
#  '2016.10.30' '2016.11.06' '2016.11.13' '2016.11.20' '2016.11.27'
#  '2016.12.04' '2016.12.11' '2016.12.18' '2016.12.25' '2017.01.01'
#  '2017.01.08' '2017.01.15' '2017.01.22' '2017.01.29' '2017.02.05'
#  '2017.02.12' '2017.02.19' '2017.02.26' '2017.03.05' '2017.03.19'
#  '2020.08.02' '2020.08.09' '2020.08.16' '2020.08.23' '2020.08.30'
#  '2020.09.06' '2020.09.13' '2020.09.20' '2020.09.27' '2020.10.04'
#  '2020.10.11' '2020.10.18' '2020.10.25' '2020.11.01' '2020.11.08'
#  '2020.11.15' '2020.11.22' '2020.11.29' '2020.12.06' '2020.12.13'
#  '2020.12.20' '2020.12.27' '2021.01.03' '2021.01.10' '2021.01.17'
#  '2021.01.24' '2021.01.31' '2021.02.07' '2021.02.14' '2021.02.21'
#  '2021.02.28' '2021.03.07' '2021.03.14' '2021.03.21' '2021.03.28'
#  '2021.04.04' '2021.04.11' '2021.04.18' '2021.04.25' '2021.05.02'
#  '2021.05.09' '2021.05.16' '2021.05.23' '2021.05.30' '2021.06.06'
#  '2021.06.13' '2021.06.20' '2021.06.27' '2021.07.04' '2021.07.11'
#  '2021.07.18' '2021.07.25' '2021.08.01' '2021.08.08' '2021.08.15'
#  '2021.08.22' '2021.08.29' '2021.09.05' '2021.09.12' '2021.09.19'
#  '2021.09.26' '2021.10.03' '2021.10.10' '2021.10.17' '2021.10.24'
#  '2021.10.31' '2021.11.07' '2021.11.14' '2021.11.21' '2021.11.28']

# %%
for y in available_weeks:
    
    current_date = datetime.strptime(y, '%Y.%m.%d').strftime('%A')
    
    if current_date != 'Sunday':
        available_weeks = [x for x in available_weeks if x != y]
        print(y)

# %%
for a in available_weeks:
  
  
    path = "./files/" + a

    try: 
        os.makedirs(path)
        control_file = pd.DataFrame()
        
        for  b in range(8):
            control_file['control' + str(b)] = -1
            
            
        control_file.to_csv(path + '/control.csv')
        
        

    except OSError as error: 
         print(error)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './files/2015.01.04'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.01.11'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.01.18'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.01.25'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.02.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.02.08'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.02.15'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.02.22'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.03.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.03.08'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.03.15'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.03.22'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.03.29'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.04.05'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.04.12'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.04.19'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.04.26'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.05.03'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.05.10'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.05.17'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.05.24'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.05.31'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.06.07'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.06.14'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.06.21'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.06.28'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.07.05'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.07.12'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.07.19'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.07.26'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.08.02'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.08.09'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.08.16'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.08.23'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.08.30'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.09.06'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.09.13'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.09.20'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.09.27'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.10.04'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.10.11'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.10.18'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.10.25'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.11.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.11.08'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.11.15'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.11.22'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.11.29'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.12.06'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.12.13'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.12.20'
# [WinError 183] Cannot create a file when that file already exists: './files/2015.12.27'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.01.03'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.01.10'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.01.17'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.01.24'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.01.31'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.02.07'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.02.14'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.02.21'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.02.28'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.03.06'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.03.13'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.03.20'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.03.27'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.04.03'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.04.10'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.04.17'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.04.24'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.05.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.05.08'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.05.15'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.05.22'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.05.29'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.06.05'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.06.12'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.06.19'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.06.26'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.07.03'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.07.10'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.07.17'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.07.24'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.07.31'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.08.07'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.08.14'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.08.21'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.08.28'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.09.04'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.09.11'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.09.18'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.09.25'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.10.02'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.10.09'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.10.16'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.10.23'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.10.30'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.11.06'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.11.13'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.11.20'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.11.27'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.12.04'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.12.11'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.12.18'
# [WinError 183] Cannot create a file when that file already exists: './files/2016.12.25'
# [WinError 183] Cannot create a file when that file already exists: './files/2017.01.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2017

# [WinError 183] Cannot create a file when that file already exists: './files/2021.08.01'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.08.08'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.08.15'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.08.22'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.08.29'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.09.05'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.09.12'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.09.19'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.09.26'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.10.03'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.10.10'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.10.17'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.10.24'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.10.31'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.11.07'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.11.14'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.11.21'
# [WinError 183] Cannot create a file when that file already exists: './files/2021.11.28'

# %%
all_currency_pair_df = []

for d in all_currency_pairs:
    
    current_currency_df = pd.read_csv("../raw_weekly_data/" + d + ".csv", names = headers ) 
    
    current_currency_df = current_currency_df.iloc[::-1]
    current_currency_df = current_currency_df.reset_index(drop=True)
      
    current_currency_df = {'name': d.replace('10080',''),'dataframe': current_currency_df }
    
    all_currency_pair_df.append(current_currency_df)
    

print(all_currency_pair_df)
# Out:
# [{'name': 'USDCHF', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  0.91625  0.92690  0.91625  0.92396   37199
# 1     2021.11.28  00:00  0.92287  0.92729  0.91574  0.91767  170181
# 2     2021.11.21  00:00  0.92768  0.93736  0.92151  0.92393  154242
# 3     2021.11.14  00:00  0.91932  0.93297  0.91869  0.92866  153577
# 4     2021.11.07  00:00  0.91268  0.92377  0.91016  0.92097  150396
# ...          ...    ...      ...      ...      ...      ...     ...
# 2597  1971.01.31  00:00  4.29680  4.29690  4.29650  4.29690       5
# 2598  1971.01.24  00:00  4.30050  4.30050  4.29630  4.29630       5
# 2599  1971.01.17  00:00  4.30290  4.30290  4.29960  4.29960       5
# 2600  1971.01.10  00:00  4.31020  4.31020  4.30760  4.30760       5
# 2601  1971.01.03  00:00  4.31800  4.31800  4.31030  4.31090       5
#
# [2602 rows x 7 columns]}, {'name': 'GBPUSD', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  1.32122  1.32892  1.32122  1.32570   62801
# 1     2021.11.28  00:00  1.33328  1.33702  1.31953  1.32303  255177
# 2     2021.11.21  00:00  1.34458  1.34495  1.32787  1.33268  222030
# 3     2021.11.14  00:00  1.34112  1.35136  1.33962  1.34365  205384
# 4     2021.11.07  00:00  1.34705  1.36061  1.33531  1.34121  200996
# ...          ...    ...      ...      ...      ...      ...     ...
# 1477  1993.06.06  00:00  1.50630  1.54050  1.50600  1.52150   14865
# 1478  1993.05.30  00:00  1.56050  1.56700  1.50600  1.50850   13945
# 1479  1993.05.23  00:00  1.54000  1.56800  1.52890  1.56070   12105
# 1480  1993.05.16  00:00  1.53650  1.56030  1.52370  1.54250   13705
# 1481  1993.05.09  00:00  1.53700  1.54450  1.51800  1.53870    8063
#
# [1482 rows x 7 columns]}, {'name': 'EURUSD', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  1.13001  1.13103  1.12534  1.12609   51372
# 1     2021.11.28  00:00  1.12979  1.13828  1.12355  1.13061  232172
# 2     2021.11.21  00:00  1.12850  1.13289  1.11861  1.13111  216896
# 3     2021.11.14  00:00  1.14399  1.14640  1.12500  1.12811  212444
# 4     2021.11.07  00:00  1.15515  1.16083  1.14329  1.14429  166057
# ...          ...    ...      ...      ...      ...      ...     ...
# 2597  1971.01.31  00:00  0.53860  0.53890  0.53840  0.53840       5
# 2598  1971.01.24  00:00  0.53850  0.53880  0.53850  0.53870       5
# 2599  1971.01.17  00:00  0.53790  0.53860  0.53770  0.53860       5
# 2600  1971.01.10  00:00  0.53710  0.53760  0.53710  0.53760       5
# 2601  1971.01.03  00:00  0.53690  0.53710  0.53650  0.53710       5
#
# [2602 rows x 7 columns]}, {'name': 'USDJPY', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021
 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  0.90056  0.90056  0.90048  0.90048       4
# 1     2021.11.28  00:00  0.90920  0.91527  0.89714  0.89895  370206
# 2     2021.11.21  00:00  0.91430  0.92040  0.90685  0.91088  288107
# 3     2021.11.14  00:00  0.91790  0.92306  0.91374  0.91469  230486
# 4     2021.11.07  00:00  0.91970  0.92497  0.91255  0.91977  240884
# ...          ...    ...      ...      ...      ...      ...     ...
# 1458  1993.05.23  00:00  0.87610  0.88330  0.87480  0.87480       5
# 1459  1993.05.16  00:00  0.89590  0.89590  0.87450  0.87950       5
# 1460  1993.05.09  00:00  0.89160  0.89650  0.89160  0.89650       5
# 1461  1993.05.02  00:00  0.89550  0.90030  0.88800  0.90030       5
# 1462  1993.04.25  00:00  0.91090  0.91090  0.89900  0.89900       4
#
# [1463 rows x 7 columns]}, {'name': 'NZDCAD', 'dataframe':            date ignore     open     high      low    close  volume
# 0    2021.11.28   0:00  0.87070  0.87554  0.86330  0.86665  234995
# 1    2021.11.21   0:00  0.88495  0.88652  0.86562  0.87205  203830
# 2    2021.11.14   0:00  0.88181  0.88877  0.87666  0.88434  166964
# 3    2021.11.07   0:00  0.88400  0.89404  0.87878  0.88340  157262
# 4    2021.10.31   0:00  0.88632  0.89067  0.88019  0.88679  164295
# ..          ...    ...      ...      ...      ...      ...     ...
# 736  2007.09.16   0:00  0.73390  0.74840  0.72010  0.74410   48732
# 737  2007.09.09   0:00  0.72440  0.74260  0.72130  0.73450   35770
# 738  2007.09.02   0:00  0.74150  0.74360  0.72040  0.72930   23055
# 739  2007.08.26   0:00  0.76320  0.76460  0.73300  0.74080   20523
# 740  2007.08.19   0:00  0.73240  0.75930  0.73080  0.75890   27092
#
# [741 rows x 7 columns]}, {'name': 'AUDNZD', 'dataframe':             date ignore     open     high      low    close  volume
# 0     2021.12.05  00:00  1.04703  1.04703  1.04702  1.04702       2
# 1     2021.11.28  00:00  1.04248  1.04964  1.03662  1.03710  269664
# 2     2021.11.21  00:00  1.03106  1.05018  1.03106  1.04460  226249
# 3     2021.11.14  00:00  1.03961  1.04559  1.03117  1.03383  198917
# 4     2021.11.07  00:00  1.03862  1.04171  1.03297  1.04085  200277
# ...          ...    ...      ...      ...      ...      ...     ...
# 1447  1993.05.02  00:00  1.30420  1.30420  1.29080  1.29490       5
# 1448  1993.04.25  00:00  1.31890  1.31890  1.30470  1.30470       5
# 1449  1993.04.18  00:00  1.32660  1.32660  1.31320  1.31320       5
# 1450  1993.04.11  00:00  1.31770  1.33640  1.31770  1.33140       5
# 1451  1993.04.04  00:00  1.31610  1.32550  1.31610  1.31740       5
#
# [1452 rows x 7 columns]}]

# %%
acceptable_signal_percent = 70

analysis_span = 52

analysis_interval = 3

no_of_weeks_analysis = [c for c in range(0, analysis_span, analysis_interval)]

all_time_next_week_trade =[]

for e in available_weeks:
    
    next_week_trade = []

    for f in all_currency_pair_df:
        
        
        current_currency_df = f['dataframe'].copy(deep = True)

        current_currency_df = current_currency_df.loc[(current_currency_df['date'] <= e )   ] 
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True)
        
        

        current_currency_df = current_currency_df.head(52)
        
        #print(f['name'], current_currency_df)

        needed_value_list = []
        
        needed_direction_list = []
        
        for g in no_of_weeks_analysis:
            
            needed_value = current_currency_df.copy()['close'][g]
            
            needed_value_list.append(needed_value)
            
            
        
        #print(f['name'], needed_value_list)
       
        
        for index, h in enumerate(needed_value_list):
            
            if index == 0:
                
                continue
                
            if h - needed_value_list[index-1] > 0 :
                
                needed_direction_list.append('S')
            
            else:
                
                needed_direction_list.append('B')
                
                
        #print(f['name'],needed_direction_list)  
        
        if (100 * needed_direction_list.count('S') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'B'})
        
        if ( 100 * needed_direction_list.count('B') / len(needed_direction_list) ) > acceptable_signal_percent:
            
            next_week_trade.append({'name': f['name'], 'direction': 'S'})
    
    
    
    if len(next_week_trade) > 0:
        
        all_time_next_week_trade.append( {'week': e, 'next_week_trades': next_week_trade} )
    
    
    
    
    #print('--------------------------------------------------------------------------------------------', e )
    #print(next_week_trade)
    #print(len(next_week_trade))
    
    
    
if len(all_time_next_week_trade) == 0:
             
    raise Exception("no week passed the acceptable_signal_percent ")
        
        
    
print(len(all_time_next_week_trade))
# Out:
# 316

# %%
# creating a dataframe for nextweek trades and saving it in csv

for i in all_time_next_week_trade:
    
    current_week_data = i['next_week_trades']
    current_week_name = i['week']
    
    currency_name =[]
    trade_direction = []
    
    for j in current_week_data:
        
        currency_name.append(j['name'])
        trade_direction.append(j['direction'])
        
        
    
    
    
    
    next_week_trades_dataframe = pd.DataFrame()
    next_week_trades_dataframe['name']= currency_name
    next_week_trades_dataframe['direction'] = trade_direction
    
    
    print(next_week_trades_dataframe)

    next_week_trades_dataframe.to_csv("files/" + current_week_name + '/next_week_trades.csv')
# Out:
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  EURCHF         B
#      name direction
# 0  EURUSD         B
# 1  EURCHF         B
# 2  EURGBP         B
# 3  EURCAD         B
#      name direction
# 0  EURUSD         B
# 1  EURCHF         B
# 2  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  EURGBP         B
#      name direction
# 0  EURUSD         B
# 1  EURCHF         B
# 2  EURGBP         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
# 4  EURNZD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
# 4  EURJPY         B
# 5  EURCAD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDCAD         S
# 3  AUDUSD         B
# 4  NZDUSD         B
# 5  GBPCHF         S
# 6  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
# 4  EURNZD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  EURGBP         B
# 3  EURJPY         B
# 4  EURCAD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDCAD         S
# 3  AUDUSD         B
# 4  NZDUSD         B
# 5  GBPCHF         S
# 6  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  EURCHF         B
# 3  CADCHF         S
# 4  EURGBP         B
# 5  EURJPY         B
# 6  EURCAD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  GBPCHF         S
# 3  EURGBP         B
# 4  EURNZD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  EURJPY         B
# 3  EURCAD         B
#      name direction
# 0  EURUSD         B
# 1  NZDUSD         B
# 2  EURGBP         B
#      name direction
# 0  EURUSD         B
# 1  USDJPY         S
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  USDCAD         S
# 4  EURCHF         B
# 5  EURJPY         B
# 6  EURCAD         B
#      name direction
# 0  EURUSD         B
# 1  NZDUSD         B
# 2  EURCHF         B
# 3  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  USDJPY         S
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  USDCAD         S
# 4  EURJPY         B
#      name direction
# 0  EURUSD         B
# 1  NZDUSD         B
# 2  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  NZDUSD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  USDCAD         S
# 4  AUDUSD         B
# 5  EURJPY         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  USDJPY         S
# 3  NZDUSD         B
# 4  AUDCHF         B
#      name direction
# 0  GBPUSD         B
# 1  EURUSD         B
# 2  USDJPY         S
# 3  NZDUSD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  USDCAD         S
# 4  AUDUSD         B
# 5  EURJPY         B
#      name direction
# 0  EURUSD         B
# 1  USDJPY         S
# 2  NZDUSD         B
# 3  EURGBP         B
#      name direction
# 0  GBPUSD         B
# 1  USDJPY         S
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  USDCAD         S
# 4  AUDUSD         B
# 5  GBPCAD         S
# 6  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  NZDUSD         B
# 2  AUDCHF         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDCAD         S
# 3  AUDUSD         B
# 4  GBPCAD         S
# 5  EURJPY         B
# 6  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  NZDUSD         B
# 2  AUDCHF         B
#      name direction
# 0  USDCAD         S
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
# 2  GBPCAD         S
# 3  NZDJPY         B
#      name direction
# 0  AUDCHF         B
# 1  NZDCAD         S
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
# 2  GBPCAD         S
#      name direction
# 0  AUDCHF         B
# 1  NZDCAD         S
#      name direction
# 0  GBPAUD         S
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
# 2  GBPCAD         S
# 3  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  AUDJPY         B
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
# 2  GBPCAD         S
# 3  EURJPY         B
# 4  NZDJPY         B
#      name direction
# 0  USDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  USDCAD         S
# 1  GBPCAD         S
# 2  NZDJPY         B
#      name direction
# 0  USDCAD         S
#      name direction
# 0  EURCHF         B
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
# 2  GBPCAD         S
# 3  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  EURCAD         S
#      name direction
# 0  USDCHF         S
# 1  USDCAD         S
#      name direction
# 0  USDCAD         S
# 1  NZDJPY         B
#      name direction
# 0  USDCAD         S
# 1  NZDJPY         B
#      name direction
# 0  CADJPY         B
#      name direction
# 0  NZDJPY         B
#      name direction
# 0  EURGBP         S
# 1  GBPJPY         B
# 2  CADJPY         B
#      name direction
# 0  AUDJPY         B
#      name direction
# 0  CHFJPY         B
# 1  GBPJPY         B
# 2  EURJPY         B
# 3  CADJPY         B
#      name direction
# 0  EURCHF         S
# 1  AUDJPY         B
#      name direction
# 0  CHFJPY         B
# 1  GBPJPY         B
# 2  EURJPY         B
# 3  CADJPY         B
#      name direction
# 0  EURJPY         B
# 1  AUDJPY         B
# 2  AUDNZD         B
#      name direction
# 0  CHFJPY         B
# 1  GBPJPY         B
# 2  EURJPY         B
# 3  CADJPY         B
#      name direction
# 0  USDJPY         B
# 1  EURJPY         B
# 2  AUDJPY         B
#      name direction
# 0  CHFJPY         B
# 1  EURGBP         S
# 2  GBPJPY         B
# 3  EURJPY         B
# 4  CADJPY         B
# 5  AUDNZD         B
#      name direction
# 0  AUDUSD         S
# 1  EURGBP         S
#      name direction
# 0  GBPUSD         B
# 1  USDJPY         B
# 2  AUDJPY         B
#      name direction
# 0  GBPJPY         B
# 1  EURJPY         B
# 2  CADJPY         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         S
# 2  EURGBP         S
#      name direction
# 0  GBPUSD         B
# 1  USDJPY         B
# 2  GBPAUD         B
# 3  EURJPY         B
# 4  EURAUD         B
# 5  AUDJPY         B
#      name direction
# 0  AUDUSD         S
# 1  CHFJPY         B
# 2  GBPJPY         B
# 3  EURJPY         B
# 4  CADJPY         B
#      name direction
# 0  AUDUSD         S
# 1  NZDUSD         S
# 2  NZDCHF         S
# 3  EURGBP         S
#      name direction
# 0  GBPUSD         B
# 1  NZDUSD         S
# 2  GBPAUD         B
# 3  EURAUD         B
#      name direction
# 0  CADJPY         B
# 1  AUDNZD         B
#      name direction
# 0  GBPUSD         B
# 1  NZDUSD         S
# 2  NZDCHF         S
# 3  EURGBP         S
#      name direction
# 0  GBPUSD         B
# 1  GBPAUD         B
# 2  EURAUD         B
#      name direction
# 0  CHFJPY         B
# 1  EURJPY         B
# 2  CADJPY         B
#      name direction
# 0  GBPUSD         B
# 1  EURGBP         S
# 2  GBPJPY         B
#      name direction
# 0  GBPUSD         B
# 1  GBPAUD         B
# 2  EURAUD         B
#      name direction
# 0  GBPCHF         B
# 1  GBPJPY         B
# 2  EURJPY         B
# 3  CADJPY         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         S
# 2  GBPCHF         B
# 3  EURGBP         S
# 4  GBPJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDJPY         B
# 2  GBPAUD         B
#      name direction
# 0  GBPCHF         B
# 1  GBPJPY         B
#      name direction
# 0  GBPUSD         B
# 1  GBPCHF         B
# 2  EURGBP         S
# 3  GBPJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDJPY         B
#      name direction
# 0  GBPCAD         B
#      name direction
# 0  AUDUSD         S
# 1  NZDCHF         S
# 2  EURGBP         S
# 3  GBPCAD         B
#      name direction
# 0  GBPCAD         B
#      name direction
# 0  AUDUSD         S
# 1  NZDCHF         S
# 2  EURGBP         S
# 3  GBPCAD         B
#      name direction
# 0  GBPCAD         B
#      name direction
# 0  AUDUSD         S
# 1  GBPCHF         B
# 2  NZDCHF         S
# 3  EURGBP         S
# 4  GBPJPY         B
# 5  GBPCAD         B
#      name direction
# 0  AUDUSD         S
# 1  NZDCHF         S
# 2  GBPJPY         B
# 3  GBPCAD         B
# 4  EURAUD         B
# 5  EURNZD         B
#      name direction
# 0  NZDCHF         S
# 1  GBPJPY         B
#      name direction
# 0  GBPUSD         B
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  NZDCHF         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  AUDCAD         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  AUDCAD         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  EURCHF         B
# 1  EURCAD         S
#      name direction
# 0  AUDCAD         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  EURCHF         B
# 1  CHFJPY         S
#      name direction
# 0  AUDJPY         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  AUDJPY         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  CHFJPY         S
# 1  EURJPY         S
#      name direction
# 0  AUDJPY         S
#      name direction
# 0  GBPJPY         B
#      name direction
# 0  AUDUSD         S
# 1  EURCHF         B
# 2  CHFJPY         S
#      name direction
# 0  AUDJPY         S
# 1  NZDCAD         B
#      name direction
# 0  GBPJPY         B
# 1  GBPCAD         B
#      name direction
# 0  AUDUSD         S
# 1  CHFJPY         S
# 2  EURJPY         S
#      name direction
# 0  AUDJPY         S
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURUSD         S
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURUSD         S
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURUSD         S
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURUSD         S
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         S
# 1  EURJPY         S
# 2  EURAUD         S
#      name direction
# 0  EURUSD         S
#      name direction
# 0  EURUSD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURUSD         S
#      name direction
# 0  EURCHF         S
# 1  AUDNZD         B
#      name direction
# 0  EURUSD         S
# 1  EURCAD         S
# 2  EURAUD         S
#      name direction
# 0  EURUSD         S
# 1  EURCHF         S
# 2  EURNZD         S
#      name direction
# 0  EURCHF         S
# 1  EURJPY         S
# 2  EURAUD         S
# 3  AUDNZD         B
#      name direction
# 0  EURUSD         S
# 1  EURCHF         S
#      name direction
# 0  EURCHF         S
# 1  EURNZD         S
# 2  AUDCAD         B
#      name direction
# 0  EURCHF         S
# 1  EURJPY         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURNZD         S
# 1  AUDCAD         B
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURNZD         S
# 1  AUDCAD         B
# 2  AUDNZD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  EURNZD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  AUDUSD         B
# 1  NZDCHF         B
# 2  EURNZD         S
#      name direction
# 0  USDCAD         S
# 1  EURCAD         S
#      name direction
# 0  EURCHF         S
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDCHF         B
# 3  AUDCAD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
#      name direction
# 0  AUDUSD         B
# 1  EURCHF         S
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDCHF         B
# 3  AUDCAD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  AUDUSD         B
# 3  EURCAD         S
#      name direction
# 0  AUDUSD         B
# 1  NZDUSD         B
# 2  CADJPY         B
# 3  NZDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDUSD         B
# 3  NZDCHF         B
# 4  EURNZD         S
# 5  AUDJPY         B
# 6  NZDJPY         B
# 7  AUDCAD         B
#      name direction
# 0  EURCAD         S
#      name direction
# 0  AUDUSD         B
#      name direction
# 0  AUDUSD         B
# 1  NZDUSD         B
# 2  NZDCHF         B
# 3  EURNZD         S
# 4  NZDJPY         B
# 5  AUDCAD         B
#      name direction
# 0  AUDUSD         B
#      name direction
# 0  AUDUSD         B
# 1  NZDJPY         B
#      name direction
# 0  GBPUSD         B
#      name direction
# 0  EURUSD         B
#      name direction
# 0  GBPUSD         B
# 1  AUDUSD         B
# 2  NZDJPY         B
#      name direction
# 0  EURUSD         B
# 1  GBPCHF         B
#      name direction
# 0  USDCAD         S
# 1  CADJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  NZDCHF         B
# 5  EURNZD         S
# 6  AUDJPY         B
# 7  NZDJPY         B
#      name direction
# 0  EURUSD         B
# 1  GBPCHF         B
#      name direction
# 0  USDCAD         S
# 1  EURJPY         B
# 2  NZDJPY         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
# 4  NZDJPY         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  GBPCHF         B
#      name direction
# 0  GBPUSD         B
# 1  USDCAD         S
# 2  AUDUSD         B
# 3  NZDUSD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  GBPCHF         B
#      name direction
# 0  AUDCAD         B
# 1  NZDCAD         B
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
# 2  NZDUSD         B
#      name direction
# 0  USDCHF         S
# 1  EURUSD         B
# 2  USDJPY         S
# 3  GBPCHF         B
#      name direction
# 0  EURUSD         B
# 1  EURNZD         B
# 2  NZDCAD         B
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
#      name direction
# 0  EURUSD         B
# 1  GBPCHF         B
#      name direction
# 0  EURUSD         B
# 1  USDCAD         S
# 2  NZDCAD         B
#      name direction
# 0  USDCAD         S
#      name direction
# 0  GBPCHF         B
#      name direction
# 0  EURUSD         B
# 1  USDCAD         S
# 2  NZDCAD         B
#      name direction
# 0  USDCAD         S
# 1  AUDNZD         B
#      name direction
# 0  GBPCHF         B
#      name direction
# 0  USDCAD         S
# 1  NZDCAD         B
#      name direction
# 0  USDCAD         S
# 1  AUDUSD         B
# 2  NZDUSD         B
# 3  AUDNZD         B
#      name direction
# 0  GBPCHF         B
#      name direction
# 0  EURJPY         B
# 1  NZDCAD         B
#      name direction
# 0  AUDUSD         B
# 1  NZDUSD         B
#      name direction
# 0  GBPCHF         B
#      name direction
# 0  EURJPY         B
# 1  NZDCAD         B
#      name direction
# 0  USDJPY         B
# 1  AUDNZD         B
#      name direction
# 0  GBPCHF         B
# 1  EURCHF         B
#      name direction
# 0  EURJPY         B
# 1  AUDNZD         B
#      name direction
# 0  USDCAD         S
# 1  AUDNZD         B
#      name direction
# 0  GBPCHF         B
# 1  EURCHF         B
#      name direction
# 0  EURJPY         B
# 1  AUDNZD         B
#      name direction
# 0  USDCAD         S
#      name direction
# 0  GBPCHF         B
# 1  EURCHF         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURUSD         B
# 1  USDCAD         S
# 2  EURCHF         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  USDCAD         S
# 1  EURJPY         B
#      name direction
# 0  EURUSD         B
# 1  USDCAD         S
# 2  GBPCHF         B
# 3  EURCHF         B
# 4  GBPJPY         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURCHF         B
# 1  AUDCAD         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURCHF         B
# 1  AUDCAD         B
#      name direction
# 0  AUDCAD         B
#      name direction
# 0  EURCAD         B
#      name direction
# 0  EURCAD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURCHF         B
# 1  EURCAD         B
#      name direction
# 0  EURCHF         B
# 1  CADCHF         B
# 2  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  EURCAD         B
#      name direction
# 0  EURCHF         B
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  CADCHF         B
# 2  EURJPY         B
# 3  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  EURCAD         B
#      name direction
# 0  EURCHF         B
# 1  AUDCAD         B
# 2  NZDCAD         B
#      name direction
# 0  USDCAD         S
# 1  EURCHF         B
# 2  CADCHF         B
# 3  EURJPY         B
# 4  EURNZD         S
# 5  AUDCAD         B
# 6  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  GBPAUD         S
#      name direction
# 0  AUDUSD         B
# 1  EURCHF         B
# 2  EURAUD         S
# 3  AUDCAD         B
# 4  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  CADCHF         B
# 2  EURJPY         B
# 3  AUDCAD         B
# 4  NZDCAD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURCHF         B
# 1  AUDCAD         B
# 2  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  CADCHF         B
# 2  EURJPY         B
#      name direction
# 0  EURCHF         B
# 1  EURCAD         B
#      name direction
# 0  EURCHF         B
# 1  NZDCAD         B
#      name direction
# 0  EURCHF         B
# 1  EURJPY         B
#      name direction
# 0  EURCAD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURCAD         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  EURCHF         B
#      name direction
# 0  EURJPY         B
#      name direction
# 0  CHFJPY         S
# 1  GBPCAD         S
# 2  GBPAUD         S
#      name direction
# 0  EURGBP         B
# 1  GBPJPY         S
#      name direction
# 0  AUDUSD         S
# 1  CHFJPY         S
#      name direction
# 0  USDCHF         B
# 1  EURGBP         B
# 2  GBPJPY         S
#      name direction
# 0  EURJPY         B
#      name direction
# 0  AUDUSD         S
# 1  CHFJPY         S
#      name direction
# 0  USDCHF         B
#      name direction
# 0  CADCHF         B
# 1  EURJPY         B
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  USDCHF         B
#      name direction
# 0  CADCHF         B
# 1  EURJPY         B
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  USDCHF         B
# 1  CADCHF         B
# 2  EURGBP         B
#      name direction
# 0  AUDUSD         S
# 1  CADCHF         B
# 2  EURJPY         B
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  USDCHF         B
# 1  USDJPY         B
# 2  EURGBP         B
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
# 2  CADCHF         B
#      name direction
# 0  CHFJPY         S
#      name direction
# 0  USDCHF         B
# 1  EURGBP         B
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
# 2  CADCHF         B
#      name direction
# 0  USDCHF         B
# 1  USDJPY         B
# 2  EURGBP         B
#      name direction
# 0  USDCAD         B
# 1  AUDUSD         S
# 2  AUDJPY         S
#      name direction
# 0  AUDUSD         S
# 1  AUDJPY         S
#      name direction
# 0  USDCHF         B
# 1  EURGBP         B
# 2  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  AUDJPY         S
#      name direction
# 0  AUDUSD         S
# 1  NZDUSD         S
# 2  CHFJPY         S
# 3  NZDCHF         S
# 4  AUDJPY         S
#      name direction
# 0  USDCHF         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  AUDJPY         S
# 4  AUDCAD         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  GBPAUD         B
# 5  CADJPY         S
# 6  AUDJPY         S
# 7  NZDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDUSD         S
# 3  CHFJPY         S
# 4  AUDCHF         S
# 5  NZDCHF         S
# 6  EURNZD         B
# 7  AUDJPY         S
# 8  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  EURNZD         B
# 4  AUDJPY         S
# 5  AUDCAD         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  AUDCHF         S
# 5  GBPJPY         S
# 6  GBPAUD         B
# 7  CADJPY         S
# 8  AUDJPY         S
# 9  NZDJPY         S
#       name direction
# 0   GBPUSD         S
# 1   USDCAD         B
# 2   AUDUSD         S
# 3   NZDUSD         S
# 4   CADCHF         S
# 5   AUDCHF         S
# 6   NZDCHF         S
# 7   GBPJPY         S
# 8   EURCAD         B
# 9   EURNZD         B
# 10  CADJPY         S
# 11  AUDJPY         S
# 12  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  AUDCHF         S
# 3  EURGBP         B
# 4  EURJPY         S
# 5  EURAUD         B
# 6  EURNZD         B
# 7  AUDJPY         S
# 8  AUDCAD         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  GBPJPY         S
# 4  CADJPY         S
# 5  AUDJPY         S
# 6  NZDJPY         S
#       name direction
# 0   USDCAD         B
# 1   AUDUSD         S
# 2   NZDUSD         S
# 3   CHFJPY         S
# 4   AUDCHF         S
# 5   NZDCHF         S
# 6   GBPJPY         S
# 7   EURJPY         S
# 8   EURNZD         B
# 9   CADJPY         S
# 10  AUDJPY         S
# 11  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  EURJPY         S
# 4  EURNZD         B
# 5  AUDJPY         S
# 6  AUDCAD         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  CHFJPY         S
# 5  GBPJPY         S
# 6  CADJPY         S
# 7  AUDJPY         S
# 8  NZDJPY         S
#       name direction
# 0   GBPUSD         S
# 1   USDCAD         B
# 2   AUDUSD         S
# 3   NZDUSD         S
# 4   CHFJPY         S
# 5   NZDCHF         S
# 6   GBPJPY         S
# 7   EURJPY         S
# 8   EURNZD         B
# 9   CADJPY         S
# 10  AUDJPY         S
# 11  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  EURJPY         S
# 5  EURNZD         B
# 6  CADJPY         S
# 7  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  NZDUSD         S
# 4  CHFJPY         S
# 5  GBPJPY         S
# 6  EURJPY         S
# 7  CADJPY         S
# 8  AUDJPY         S
# 9  NZDJPY         S
#       name direction
# 0   GBPUSD         S
# 1   USDCAD         B
# 2   AUDUSD         S
# 3   NZDUSD         S
# 4   CHFJPY         S
# 5   NZDCHF         S
# 6   GBPJPY         S
# 7   EURJPY         S
# 8   EURCAD         B
# 9   EURNZD         B
# 10  CADJPY         S
# 11  AUDJPY         S
# 12  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  EURJPY         S
# 5  EURNZD         B
# 6  CADJPY         S
# 7  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  AUDUSD         S
# 3  CHFJPY         S
# 4  EURGBP         B
# 5  GBPJPY         S
# 6  EURJPY         S
# 7  CADJPY         S
# 8  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  AUDUSD         S
# 2  NZDUSD         S
# 3  CHFJPY         S
# 4  GBPJPY         S
# 5  EURJPY         S
# 6  EURNZD         B
# 7  CADJPY         S
# 8  AUDJPY         S
# 9  NZDJPY         S
#      name direction
# 0  USDCAD         B
# 1  GBPCHF         S
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  EURJPY         S
# 5  EURNZD         B
# 6  CADJPY         S
# 7  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  CHFJPY         S
# 3  EURGBP         B
# 4  GBPJPY         S
# 5  EURJPY         S
# 6  CADJPY         S
#      name direction
# 0  GBPUSD         S
# 1  CHFJPY         S
# 2  GBPJPY         S
# 3  EURJPY         S
# 4  EURCAD         B
# 5  EURNZD         B
# 6  CADJPY         S
# 7  AUDJPY         S
#      name direction
# 0  USDCAD         B
# 1  EURGBP         B
# 2  GBPJPY         S
# 3  EURJPY         S
# 4  EURNZD         B
# 5  CADJPY         S
# 6  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  CADJPY         S
#      name direction
# 0  GBPJPY         S
# 1  EURJPY         S
# 2  EURCAD         B
# 3  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURGBP         B
# 2  EURJPY         S
# 3  EURNZD         B
# 4  AUDJPY         S
#      name direction
# 0  GBPUSD         S
# 1  USDCAD         B
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  CADJPY         S
#      name direction
# 0  NZDCHF         S
# 1  EURGBP         B
# 2  GBPJPY         S
# 3  EURCAD         B
# 4  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  GBPAUD         S
# 2  EURJPY         S
#      name direction
# 0  EURCHF         B
# 1  CHFJPY         S
# 2  NZDCHF         B
# 3  EURGBP         B
#      name direction
# 0  NZDCHF         S
# 1  EURGBP         B
# 2  GBPJPY         S
# 3  EURCAD         B
# 4  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURGBP         B
# 2  GBPCAD         S
# 3  GBPAUD         S
# 4  EURJPY         S
# 5  AUDJPY         S
#      name direction
# 0  CHFJPY         S
# 1  EURGBP         B
#      name direction
# 0  EURGBP         B
# 1  GBPJPY         S
# 2  EURCAD         B
# 3  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURJPY         S
#      name direction
# 0  USDJPY         S
# 1  CHFJPY         S
# 2  EURGBP         B
#      name direction
# 0  NZDCHF         S
# 1  EURGBP         B
# 2  GBPJPY         S
# 3  EURCAD         B
# 4  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURJPY         S
# 2  CADJPY         S
# 3  AUDJPY         S
# 4  NZDJPY         S
#      name direction
# 0  USDJPY         S
# 1  CHFJPY         S
# 2  EURGBP         B
# 3  GBPJPY         S
# 4  CADJPY         S
#      name direction
# 0  EURGBP         B
# 1  GBPJPY         S
# 2  EURNZD         B
#      name direction
# 0  USDJPY         S
# 1  USDCAD         B
# 2  EURCHF         B
# 3  EURJPY         S
#      name direction
# 0  EURUSD         B
# 1  USDJPY         S
# 2  EURCHF         B
# 3  CHFJPY         S
# 4  NZDCHF         B
# 5  EURGBP         B
# 6  EURCAD         B
#      name direction
# 0  EURGBP         B
# 1  EURNZD         B
#      name direction
# 0  USDCAD         B
# 1  EURCHF         B

# %%
all_currency_thirty_minutes_data = {}

for z in all_currency_pairs:
    current_currency = z.replace('10080','')
    current_currency_df = pd.read_csv('../raw_30_minutes_data/' + current_currency + '30.csv', names=headers ) 
    
    all_currency_thirty_minutes_data[current_currency] = current_currency_df
    
    #print( current_currency, )
    
    
print(len(all_currency_thirty_minutes_data))
# Out:
# 27

# %%
qualified_weeks =[]

for k in all_time_next_week_trade:
    
    current_week_data = k['next_week_trades']
    current_week_date = k['week']
    
    current_week_date = datetime.strptime(current_week_date, '%Y.%m.%d')

    week_start_date  = current_week_date + timedelta(days=7)
    week_end_date = current_week_date + timedelta(days=12)
    
    current_week_date = current_week_date.strftime("%Y.%m.%d")
    week_start_date = week_start_date.strftime("%Y.%m.%d")
    week_end_date = week_end_date.strftime("%Y.%m.%d")      

    
    

    #print(current_week_date, week_start_date, week_end_date)
    
    qualified_currencies = 0
   
    for l in current_week_data:
        
        
        current_currency = l['name'] 
        
        current_currency_df = all_currency_thirty_minutes_data[l['name']].copy()
        
        
        
        
        current_currency_df = current_currency_df.loc[  (current_currency_df['date'] >= week_start_date)
                                                   
                                                                                 & 
                                                              (current_currency_df['date'] <= week_end_date)
                                                            ]  
    
        
        
        
        current_currency_df = current_currency_df.reset_index(drop=True )
        #print( week_start_date, current_currency, current_currency_df)
        
       
        current_currency_dataframe_row_ammount = len(current_currency_df.index)
        
        if  current_currency_dataframe_row_ammount < 238:
            
            print(current_currency,len(current_currency_df),week_start_date,'less than 238, skipping ',current_week_date)
            continue
            #raise Exception("lenght is lesss than 238")
            
            
        
        if  current_currency_dataframe_row_ammount != 240:
            
            if (current_currency_df['ignore'].tail(1).values == '22:30' ):
                
                
                
                last_row = current_currency_df.copy().tail(1)
                
                last_row.tail()['ignore'] = '23:00'
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
                
                last_row.tail()['ignore'] = '23:30'
                
                current_currency_df = current_currency_df.append(last_row, ignore_index = True)
                
                #print(current_currency, current_currency_df)
                
                if  len(current_currency_df.index) != 240:
              
                    print(current_currency, current_currency_df)
                    raise Exception("number of rows is still wrong after repair")
        
            else:
                
                print(current_currency,len(current_currency_df),week_start_date,"irrepairable,skipping ",current_week_date)
                continue
        
        if current_currency_df['ignore'].iloc[-1] != '23:30' :
        
            print(current_currency, current_currency_df)
            raise Exception("last row is not 23:30")
        
        
      
            
             
        
        
       
        current_currency_df.to_csv("files/" + k['week'] + '/' + current_currency +".csv", index=None)
        
        qualified_currencies = qualified_currencies +1
        
        
        
    if qualified_currencies == len(current_week_data):
            
        qualified_weeks.append(k)
        
    
   
        
        #print(current_currency_df)
        
        
        
    #print('-----------------------------------------------------------------------------------------------', week_start_date)


print(len(qualified_weeks))
# Out:
# EURCHF 0 2015.01.11 less than 238, skipping  2015.01.04
# EURCHF 239 2015.02.08 irrepairable,skipping  2015.02.01
# USDCAD 182 2015.12.20 less than 238, skipping  2015.12.13
# GBPCAD 182 2015.12.20 less than 238, skipping  2015.12.13
# NZDJPY 182 2015.12.20 less than 238, skipping  2015.12.13
# USDCAD 184 2015.12.27 less than 238, skipping  2015.12.20
# GBPUSD 237 2016.10.09 less than 238, skipping  2016.10.02
# EURGBP 237 2016.10.09 less than 238, skipping  2016.10.02
# GBPJPY 237 2016.10.09 less than 238, skipping  2016.10.02
# GBPCAD 228 2016.12.25 less than 238, skipping  2016.12.18
# NZDCAD 218 2017.09.03 less than 238, skipping  2017.08.27
# GBPJPY 239 2017.09.10 irrepairable,skipping  2017.09.03
# GBPCAD 239 2017.09.10 irrepairable,skipping  2017.09.03
# EURCHF 180 2017.12.24 less than 238, skipping  2017.12.17
# USDCAD 174 2018.12.23 less than 238, skipping  2018.12.16
# CADJPY 174 2018.12.23 less than 238, skipping  2018.12.16
# GBPUSD 178 2018.12.30 less than 238, skipping  2018.12.23
# USDCAD 178 2018.12.30 less than 238, skipping  2018.12.23
# AUDUSD 178 2018.12.30 less than 238, skipping  2018.12.23
# NZDUSD 178 2018.12.30 less than 238, skipping  2018.12.23
# NZDCHF 172 2018.12.30 less than 238, skipping  2018.12.23
# EURNZD 178 2018.12.30 less than 238, skipping  2018.12.23
# AUDJPY 178 2018.12.30 less than 238, skipping  2018.12.23
# NZDJPY 178 2018.12.30 less than 238, skipping  2018.12.23
# GBPAUD 224 2020.03.29 less than 238, skipping  2020.03.22
# USDCAD 186 2020.12.20 less than 238, skipping  2020.12.13
# AUDUSD 186 2020.12.20 less than 238, skipping  2020.12.13
# CADCHF 186 2020.12.20 less than 238, skipping  2020.12.13
# GBPUSD 233 2021.06.13 less than 238, skipping  2021.06.06
# AUDUSD 233 2021.06.13 less than 238, skipping  2021.06.06
# NZDUSD 233 2021.06.13 less than 238, skipping  2021.06.06
# CHFJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# GBPJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# EURJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# EURNZD 233 2021.06.13 less than 238, skipping  2021.06.06
# CADJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# AUDJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# NZDJPY 233 2021.06.13 less than 238, skipping  2021.06.06
# USDCAD 176 2021.12.05 less than 238, skipping  2021.11.28
# EURCHF 175 2021.12.05 less than 238, skipping  2021.11.28
# 301

# %%
timeframe = []
trade_values = []
unique_time_frames = []

for m in qualified_weeks:

    
    
    current_week = m['week']
    current_week_data = m['next_week_trades']
    
    current_week_drawdown_df = pd.DataFrame()
    
    current_week_profit = pd.DataFrame()
  

    
    
    for index, n in enumerate(current_week_data):
        
        
        
        current_currency = n['name']
        current_currency_direction = n['direction']
        current_currency_df =  pd.read_csv("files/" + current_week + '/' + current_currency +".csv" ) 
        
        
        # adding timeframe to the maximal draw down df
        if index == 0:
            
            current_week_drawdown_df['date'] = current_currency_df['date']
            current_week_profit['date'] = current_currency_df['date']
           
            #saving unique_timeframes in a week to use later in the script
            if len(unique_time_frames) == 0:
                
                unique_time_frames = current_currency_df['ignore'].values
            
        
        
        #print(current_currency_df)
        maximal_draw_down =[]
        profit = []
        pips_corrector = 100000
            
        if current_currency.endswith('JPY'):
                
            pips_corrector = 1000
            
        
        
        
        for o in range(240):
                   
            if current_currency_direction == 'B':
                
                
                dd = current_currency_df.loc[o,'low'] - current_currency_df.loc[0,'open']
                p = current_currency_df.loc[o,'close'] - current_currency_df.loc[0,'open']
              
            if current_currency_direction == 'S':
                
                
                dd = current_currency_df.loc[0,'open'] - current_currency_df.loc[o,'high']
                p = current_currency_df.loc[0,'open'] - current_currency_df.loc[o,'close']
            
            
            maximal_draw_down.append(dd*pips_corrector)
            profit.append(p*pips_corrector)
                
        
        current_week_drawdown_df[current_currency] = maximal_draw_down
        current_week_profit[current_currency] = profit
            
    current_week_drawdown_df['empty'] = ['' for p in range(240)]      
    current_week_drawdown_df["sum"] = current_week_drawdown_df.drop(["empty", 'date'], axis=1, inplace=False).sum(axis=1)        
    
    current_week_drawdown_df.to_csv("files/" + m['week'] + '/' + 'maximal_draw_down.csv', index= None)
    
    
    
    current_week_profit['empty'] = ['' for p in range(240)]      
    current_week_profit["sum"] = current_week_profit.drop(["empty", 'date'], axis=1, inplace=False).sum(axis=1)        
    
    current_week_profit.to_csv("files/" + m['week'] + '/' + 'profit.csv', index= None)
    
    
    
    #print(current_week_drawdown_df)
        
    
    
    
    
    
    
    
    
    
    print('--------------------------------------------------------------------------------------------------', m)   
    
    
print(current_week_drawdown_df)

print(unique_time_frames)
# Out:
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.01.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.08', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.15', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.02.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.08', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.15', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.03.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'CADCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.12', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.04.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.03', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.17', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.24', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.05.31', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.07', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.21', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.06.28', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.05', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.12', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.19', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.07.26', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.02', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.09', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.16', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.23', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.08.30', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'AUDCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.13', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.20', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.09.27', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.11', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.18', 'next_week_trades': [{'name': 'AUDCHF', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.10.25', 'next_week_trades': [{'name': 'GBPAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.01', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.08', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.22', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.11.29', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.06', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2015.12.27', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.03', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.10', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.01.24', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.02.14', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.03.20', 'next_week_trades': [{'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.03', 'next_week_trades': [{'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.10', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.04.24', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.01', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.05.22', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.05', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.12', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.06.26', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.03', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.10', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.17', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.24', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.07.31', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.07', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.14', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.21', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.08.28', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.04', 'next_week_trades': [{'name': 'CADJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.18', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.09.25', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.16', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.23', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.10.30', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.06', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.13', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.20', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.11.27', 'next_week_trades': [{'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.12.04', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2016.12.25', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.01.08', 'next_week_trades': [{'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.01.15', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.02.05', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'B'}, {'name': 'EURAUD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.02.26', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.05', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.19', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.03.26', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.09', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.16', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.23', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.04.30', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.07', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.14', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.21', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.05.28', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.04', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.11', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.18', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.06.25', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.02', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.09', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.16', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.23', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.07.30', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.06', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.13', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.08.20', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.10', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.17', 'next_week_trades': [{'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.09.24', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.01', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.08', 'next_week_trades': [{'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.10.29', 'next_week_trades': [{'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.05', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.19', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.11.26', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.12.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2017.12.31', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.07', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.21', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.01.28', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.04', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.11', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.18', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.02.25', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.11', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.03.25', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.01', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.08', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.15', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.04.29', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.06', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.13', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.20', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.05.27', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.06.10', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.06.17', 'next_week_trades': [{'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.01', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.08', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.15', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.07.29', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.05', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.12', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.19', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.08.26', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.02', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.16', 'next_week_trades': [{'name': 'EURCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.23', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.09.30', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'B'}, {'name': 'AUDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.10.14', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.10.21', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.11.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.11.18', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.02', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.09', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2018.12.30', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.06', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.13', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'NZDJPY', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.01.20', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.03', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.10', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.17', 'next_week_trades': [{'name': 'AUDCAD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.02.24', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.03', 'next_week_trades': [{'name': 'USDCHF', 'direction': 'S'}, {'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.10', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.17', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.24', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.03.31', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.07', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.14', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.21', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.04.28', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.05', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.12', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.19', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.05.26', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.02', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.09', 'next_week_trades': [{'name': 'AUDUSD', 'direction': 'B'}, {'name': 'NZDUSD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.16', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.23', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'B'}, {'name': 'NZDCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.06.30', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.07', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.14', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.21', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'S'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.07.28', 'next_week_trades': [{'name': 'GBPCHF', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2019.08.04', 'next_week_trades': [{'name': 'EURJPY', 'direction': 'B'}, {'name': 'AUDNZD', 'direction': 'B'}]}
# ...
# -------------------------------------------------------------------------------------------------- {'week': '2021.03.21', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURAUD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.03.28', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.04', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'AUDCHF', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.11', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'AUDCAD', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.18', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.04.25', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.02', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.09', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.16', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'NZDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.23', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.05.30', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'AUDUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.13', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.20', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.06.27', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.04', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.11', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.18', 'next_week_trades': [{'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.07.25', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.01', 'next_week_trades': [{'name': 'GBPUSD', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.08', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.15', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.22', 'next_week_trades': [{'name': 'EURCHF', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.08.29', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.05', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPCAD', 'direction': 'S'}, {'name': 'GBPAUD', 'direction': 'S'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.12', 'next_week_trades': [{'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.19', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.09.26', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.03', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.10', 'next_week_trades': [{'name': 'NZDCHF', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURCAD', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.17', 'next_week_trades': [{'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}, {'name': 'AUDJPY', 'direction': 'S'}, {'name': 'NZDJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.24', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'S'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'CADJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.10.31', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'B'}, {'name': 'GBPJPY', 'direction': 'S'}, {'name': 'EURNZD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.07', 'next_week_trades': [{'name': 'USDJPY', 'direction': 'S'}, {'name': 'USDCAD', 'direction': 'B'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'EURJPY', 'direction': 'S'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.14', 'next_week_trades': [{'name': 'EURUSD', 'direction': 'B'}, {'name': 'USDJPY', 'direction': 'S'}, {'name': 'EURCHF', 'direction': 'B'}, {'name': 'CHFJPY', 'direction': 'S'}, {'name': 'NZDCHF', 'direction': 'B'}, {'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURCAD', 'direction': 'B'}]}
# -------------------------------------------------------------------------------------------------- {'week': '2021.11.21', 'next_week_trades': [{'name': 'EURGBP', 'direction': 'B'}, {'name': 'EURNZD', 'direction': 'B'}]}
#  '21:00' '21:30' '22:00' '22:30' '23:00' '23:30']

# %%
day_time_frames = []

for index, w in enumerate(unique_time_frames):
    
    if index >= 192: 
        day = 'FRI'  
        day_time_frames.append(day + ' ' + w)
        
    elif index >= 144: 
        day = 'THUR'  
        day_time_frames.append(day + ' ' + w)
        
    elif index >=96: 
        day = 'WED'  
        day_time_frames.append(day + ' ' + w)
        
    elif index >=48: 
        day = 'TUE'  
        day_time_frames.append(day + ' ' + w)
        
    else: 
        day = 'MON'  
        day_time_frames.append(day + ' ' + w)
    
   
    
print(len(day_time_frames))
# Out:
# 240

# %%
#combining all maximal drawdowns for all weeks
combine_week_drawdown_df = pd.DataFrame()

combine_week_drawdown_df['date'] = day_time_frames

for index, q in enumerate(qualified_weeks):
    
    current_week = q['week']
    current_week_dd_df = pd.read_csv("files/" + current_week + '/' + 'maximal_draw_down' +".csv" ) 
    #print(current_week_dd_df)
    
   
    combine_week_drawdown_df[current_week] = current_week_dd_df['sum']
    

combine_week_drawdown_df['empty'] = ['' for r in range(240)]      
combine_week_drawdown_df["sum"] = combine_week_drawdown_df.drop(["empty",'date' ], axis=1, inplace=False).sum(axis=1)        

combine_week_drawdown_df.to_csv("files/" + 'combine_week_drawdown_df.csv', index= None)

print(combine_week_drawdown_df)
# Out:
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_18204/567915654.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   combine_week_drawdown_df[current_week] = current_week_dd_df['sum']
#           date  2015.01.11  2015.01.18  2015.01.25  2015.02.08  2015.02.15  \
# 0    MON 00:00      -246.0      -444.0      -256.0      -364.0      -426.0
# 1    MON 00:30       -16.0      -256.0      -242.0      -351.0      -436.0
# 2    MON 01:00        31.0      -716.0      -203.0      -256.0      -448.0
# 3    MON 01:30      -172.0     -1173.0      -264.0      -152.0      -396.0
# 4    MON 02:00      -337.0      -318.0      -265.0       -59.0      -963.0
# ..         ...         ...         ...         ...         ...         ...
# 235  FRI 21:30     -4372.0      7364.0       631.0     -2752.0     -9053.0
# 236  FRI 22:00     -4574.0      7399.0       796.0     -3085.0     -9261.0
# 237  FRI 22:30     -5271.0      7533.0       784.0     -2995.0     -9155.0
# 238  FRI 23:00     -5115.0      7351.0       773.0     -2592.0     -8999.0
# 239  FRI 23:30     -5703.0      7183.0       555.0     -2349.0     -9067.0
#
#      2015.02.22  2015.03.01  2015.03.08  2015.03.15  ...  2021.10.03  \
# 0        -307.0      -276.0      -604.0     -1034.0  ...      -365.0
# 1        -317.0      -459.0      -312.0     -1146.0  ...      -351.0
# 2        -868.0       118.0      -344.0     -1737.0  ...      -472.0
# 3        -833.0       415.0      -446.0     -1633.0  ...      -447.0
# 4        -904.0       441.0      -316.0     -1854.0  ...      -376.0
# ..          ...         ...         ...         ...  ...         ...
# 235    -13928.0     -9641.0      8238.0      2544.0  ...     -5763.0
# 236    -14054.0     -9466.0      8318.0      2252.0  ...     -5649.0
# 237    -14264.0     -9207.0      8379.0      2254.0  ...     -5652.0
# 238    -14499.0     -9207.0      8379.0      2254.0  ...     -5681.0
# 239    -14595.0     -9207.0      8379.0      2254.0  ...     -5716.0
#
#      2021.10.10  2021.10.17  2021.10.24  2021.10.31  2021.11.07  2021.11.14  \
# 0        -712.0      -157.0      -622.0      -621.0      -109.0      -524.0
# 1        -677.0      -108.0      -631.0      -302.0         5.0      -400.0
# 2       -1251.0      -186.0      -645.0      -306.0      -161.0      -707.0
# 3       -1089.0      -315.0      -886.0      -135.0      -102.0      -690.0
# 4        -979.0      -371.0      -984.0       -99.0       -23.0      -574.0
# ..          ...         ...         ...         ...         ...         ...
# 235       370.0     -1330.0      6127.0      -604.0      2240.0       608.0
# 236       551.0     -1351.0      6127.0      -551.0      2123.0       772.0
# 237       415.0     -1411.0      6065.0      -537.0      2137.0      1097.0
# 238       411.0     -1669.0      6065.0      -536.0      2102.0       830.0
# 239       576.0     -1619.0      6065.0      -470.0      2093.0       710.0
#
#      2021.11.21  empty      sum
# 0         -69.0        -89145.0
# 1         483.0        -67646.0
# 2         -44.0        -79985.0
# 3          56.0        -62779.0
# 4         116.0        -63595.0
# ..          ...    ...      ...
# 235      3230.0         74045.0
# 236      3174.0         77352.0
# 237      3073.0         79754.0
# 238      3108.0         79179.0
# 239      3007.0         59096.0
#
# [240 rows x 304 columns]
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_18204/567915654.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   combine_week_drawdown_df['empty'] = ['' for r in range(240)]

# %%
#combining all profits drawdowns for all weeks
combine_week_profit_df = pd.DataFrame()

combine_week_profit_df['date'] = day_time_frames

for index, q in enumerate(qualified_weeks):
    
    current_week = q['week']
    current_week_profit_df = pd.read_csv("files/" + current_week + '/' + 'profit' +".csv" ) 
    #print(current_week_dd_df)
    
   
    combine_week_profit_df[current_week] = current_week_profit_df['sum']
    

combine_week_profit_df['empty'] = ['' for r in range(240)]      
combine_week_profit_df["sum"] = combine_week_profit_df.drop(["empty",'date' ], axis=1, inplace=False).sum(axis=1)        

combine_week_profit_df.to_csv("files/" + 'combine_week_profit_df.csv', index= None)

print(combine_week_profit_df)
# Out:
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_18204/1757970898.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   combine_week_profit_df[current_week] = current_week_profit_df['sum']
#           date  2015.01.11  2015.01.18  2015.01.25  2015.02.08  2015.02.15  \
# 0    MON 00:00       249.0      -143.0      -132.0       -10.0      -162.0
# 1    MON 00:30       293.0      -191.0       -22.0        10.0      -158.0
# 2    MON 01:00       493.0      -681.0      -112.0       -14.0        -8.0
# 3    MON 01:30      -151.0      -180.0      -104.0       123.0      -295.0
# 4    MON 02:00      -196.0       410.0      -102.0       245.0      -556.0
# ..         ...         ...         ...         ...         ...         ...
# 235  FRI 21:30     -4060.0      7416.0       847.0     -2508.0     -8946.0
# 236  FRI 22:00     -4482.0      7591.0       933.0     -2901.0     -8956.0
# 237  FRI 22:30     -5126.0      7711.0       887.0     -2330.0     -8893.0
# 238  FRI 23:00     -4797.0      7558.0       934.0     -2202.0     -8774.0
# 239  FRI 23:30     -5657.0      7682.0       619.0     -1802.0     -8874.0
#
#      2015.02.22  2015.03.01  2015.03.08  2015.03.15  ...  2021.10.03  \
# 0         -54.0        14.0       147.0      -649.0  ...      -252.0
# 1        -163.0       256.0        53.0      -861.0  ...      -322.0
# 2        -402.0       606.0      -140.0     -1318.0  ...      -381.0
# 3        -585.0       640.0       -98.0     -1278.0  ...      -331.0
# 4        -564.0       789.0       189.0     -1828.0  ...      -336.0
# ..          ...         ...         ...         ...  ...         ...
# 235    -13657.0     -9274.0      8625.0      3048.0  ...     -5622.0
# 236    -13927.0     -8735.0      8890.0      2930.0  ...     -5586.0
# 237    -14040.0     -8850.0      8889.0      2402.0  ...     -5542.0
# 238    -14096.0     -8850.0      8889.0      2402.0  ...     -5661.0
# 239    -14090.0     -8850.0      8889.0      2402.0  ...     -5595.0
#
#      2021.10.10  2021.10.17  2021.10.24  2021.10.31  2021.11.07  2021.11.14  \
# 0         339.0        19.0      -544.0       -97.0        73.0       -84.0
# 1        -258.0        48.0      -521.0       -38.0        69.0      -185.0
# 2        -844.0      -101.0      -627.0       -33.0       -59.0      -471.0
# 3        -642.0      -280.0      -810.0        84.0        33.0      -488.0
# 4        -690.0      -267.0      -710.0       -17.0       226.0      -112.0
# ..          ...         ...         ...         ...         ...         ...
# 235       710.0     -1270.0      6351.0      -389.0      2454.0      1143.0
# 236       743.0      -824.0      6364.0      -444.0      2220.0      1324.0
# 237       495.0     -1325.0      6163.0      -438.0      2218.0      1774.0
# 238       684.0     -1561.0      6163.0      -437.0      2192.0      1882.0
# 239       655.0     -1204.0      6163.0      -318.0      2152.0      1535.0
#
#      2021.11.21  empty       sum
# 0         878.0          -6673.0
# 1         673.0          -9333.0
# 2         301.0         -18263.0
# 3         299.0         -18532.0
# 4         270.0         -17618.0
# ..          ...    ...       ...
# 235      3340.0         119727.0
# 236      3241.0         122117.0
# 237      3146.0         124061.0
# 238      3230.0         120242.0
# 239      3080.0         111454.0
#
# [240 rows x 304 columns]
# C:\Users\AKINSH~1\AppData\Local\Temp/ipykernel_18204/1757970898.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   combine_week_profit_df['empty'] = ['' for r in range(240)]

# %%
#loading all profit and drawdown dataframe to memory to speed up processing

qualified_weeks_dfs=[]

for v in qualified_weeks:
    
    current_week = v['week']

    current_week_profit_df = pd.read_csv("files/" + current_week + '/profit.csv')
    current_week_drawdown_df = pd.read_csv("files/" + current_week + '/maximal_draw_down.csv')
    
    qualified_weeks_dfs.append( 
                                { 'week': current_week,
                                   'profit_df' : current_week_profit_df,
                                   'drawdown_df': current_week_drawdown_df
                                }
                                )
    

print(len(qualified_weeks_dfs))
# Out:
# 301

# %%
statistic_df = pd.DataFrame()

start_date_index_list =[]

cut_off_date_index_list =[]

draw_down_list = []

total_spread_list = []

maximal_draw_down_list = []

profit_list=[]

profit_ratio_list=[]


combine_week_drawdown_df = pd.read_csv("files/" + 'combine_week_drawdown_df.csv')
combine_week_profit_df = pd.read_csv("files/" + 'combine_week_profit_df.csv')


#print(combine_week_drawdown_df)

start_date_index = [f for f in range(220, 240)]


draw_down = [f*-1 for f in range(900, 1000, 100)] 


total_spread = -200





for t in start_date_index:
    
    cut_off_date_index =   [f for f in range( 1,(241-t)  ) ]
    
    #print(cut_off_date_index)
    
    for g in cut_off_date_index:
        
        
        for q in draw_down :
            
            
            #print(current_profit_df)
            
            
            for s in qualified_weeks_dfs:
                
                current_week_calculated_profit = []
                
                current_drawdown_df = s['drawdown_df'].copy()
                current_drawdown_df = current_drawdown_df.iloc[t:]
                current_drawdown_df = current_drawdown_df.reset_index(drop=True)   
                current_drawdown_df = current_drawdown_df.iloc[:g]
                current_week_drawdown_list = current_drawdown_df['sum'].values
                
                

                current_profit_df = s['profit_df'].copy()
                current_profit_df = current_profit_df.iloc[t:]
                current_profit_df = current_profit_df.reset_index(drop=True)
                current_profit_df = current_profit_df.iloc[:g]
                current_week_profit_list = current_profit_df['sum'].values
                
                #print(current_week_profit_list)
                
            
                for r in range(len(current_week_drawdown_list)):
                    
                    if r == 0:
                        #skipping the first row
                        continue
                    
                    current_drawdown = current_week_drawdown_list[r] - current_week_profit_list[0]
                    
                    current_profit = current_week_profit_list[r] - current_week_profit_list[0]
                    
                    
                    
                    if current_drawdown <= q:
                        
                        current_maximal_drawdown = q + total_spread
                        current_week_calculated_profit.append(current_maximal_drawdown )
                    
                        break
                        
               
                    current_week_calculated_profit.append(current_profit)
                    
                
              
                #print(current_week_calculated_profit, s['week'])
                
                
                    
                print(sum(current_week_calculated_profit), s['week'] )        
            
            print('drawdown------------------------------------------------------------------', q, g, t)
            
        
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx', g, t)
    
    
    print('===========================================================================================================', t)
# Out:
# 0 2015.01.11
# 0 2015.01.18
# 0 2015.01.25
# 0 2015.02.08
# 0 2015.02.15
# 0 2015.02.22
# 0 2015.03.01
# 0 2015.03.08
# 0 2015.03.15
# 0 2015.03.22
# 0 2015.03.29
# 0 2015.04.05
# 0 2015.04.12
# 0 2015.04.19
# 0 2015.04.26
# 0 2015.05.03
# 0 2015.05.10
# 0 2015.05.17
# 0 2015.05.24
# 0 2015.05.31
# 0 2015.06.07
# 0 2015.06.14
# 0 2015.06.21
# 0 2015.06.28
# 0 2015.07.05
# 0 2015.07.12
# 0 2015.07.19
# 0 2015.07.26
# 0 2015.08.02
# 0 2015.08.09
# 0 2015.08.16
# 0 2015.08.23
# 0 2015.08.30
# 0 2015.09.06
# 0 2015.09.13
# 0 2015.09.20
# 0 2015.09.27
# 0 2015.10.11
# 0 2015.10.18
# 0 2015.10.25
# 0 2015.11.01
# 0 2015.11.08
# 0 2015.11.22
# 0 2015.11.29
# 0 2015.12.06
# 0 2015.12.27
# 0 2016.01.03
# 0 2016.01.10
# 0 2016.01.24
# 0 2016.02.14
# 0 2016.03.06
# 0 2016.03.20
# 0 2016.04.03
# 0 2016.04.10
# 0 2016.04.24
# 0 2016.05.01
# 0 2016.05.15
# 0 2016.05.22
# 0 2016.06.05
# 0 2016.06.12
# 0 2016.06.26
# 0 2016.07.03
# 0 2016.07.10
# 0 2016.07.17
# 0 2016.07.24
# 0 2016.07.31
# 0 2016.08.07
